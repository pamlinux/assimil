# %%
from database import get_lessons_errors, MarkedSentence, engine
# Out:
# 2024-08-30 18:21:25,216 INFO sqlalchemy.engine.Engine BEGIN (implicit)
# 2024-08-30 18:21:25,217 INFO sqlalchemy.engine.Engine PRAGMA main.table_info("word_dict")
# 2024-08-30 18:21:25,217 INFO sqlalchemy.engine.Engine [raw sql] ()
# 2024-08-30 18:21:25,218 INFO sqlalchemy.engine.Engine PRAGMA main.table_info("word_index")
# 2024-08-30 18:21:25,218 INFO sqlalchemy.engine.Engine [raw sql] ()
# 2024-08-30 18:21:25,218 INFO sqlalchemy.engine.Engine PRAGMA main.table_info("sentences")
# 2024-08-30 18:21:25,218 INFO sqlalchemy.engine.Engine [raw sql] ()
# 2024-08-30 18:21:25,219 INFO sqlalchemy.engine.Engine PRAGMA main.table_info("marked_sentences")
# 2024-08-30 18:21:25,219 INFO sqlalchemy.engine.Engine [raw sql] ()
# 2024-08-30 18:21:25,219 INFO sqlalchemy.engine.Engine COMMIT

# %%
from sqlalchemy import ForeignKey, select, String, and_
from sqlalchemy.orm import Session

# %%
from tonic_accent import get_html_sentences

# %%
errors = get_lessons_errors()
# Out:
# 2024-08-30 18:21:33,026 INFO sqlalchemy.engine.Engine BEGIN (implicit)
# 2024-08-30 18:21:33,037 INFO sqlalchemy.engine.Engine SELECT marked_sentences.id, marked_sentences.date_time, marked_sentences.sentence, marked_sentences.comment, marked_sentences.lesson, marked_sentences.line
# FROM marked_sentences
# WHERE marked_sentences.date_time > ? AND marked_sentences.date_time < ? AND marked_sentences.lesson = ?
# 2024-08-30 18:21:33,038 INFO sqlalchemy.engine.Engine [generated in 0.00116s] ('0001-01-01 00:00:00.000000', '9999-12-31 23:59:59.999999', 1)
# 2024-08-30 18:21:33,039 INFO sqlalchemy.engine.Engine ROLLBACK
# 2024-08-30 18:21:33,041 INFO sqlalchemy.engine.Engine BEGIN (implicit)
# 2024-08-30 18:21:33,042 INFO sqlalchemy.engine.Engine SELECT marked_sentences.id, marked_sentences.date_time, marked_sentences.sentence, marked_sentences.comment, marked_sentences.lesson, marked_sentences.line
# FROM marked_sentences
# WHERE marked_sentences.date_time > ? AND marked_sentences.date_time < ? AND marked_sentences.lesson = ?
# 2024-08-30 18:21:33,042 INFO sqlalchemy.engine.Engine [cached since 0.005338s ago] ('0001-01-01 00:00:00.000000', '9999-12-31 23:59:59.999999', 2)
# 2024-08-30 18:21:33,043 INFO sqlalchemy.engine.Engine ROLLBACK
# 2024-08-30 18:21:33,044 INFO sqlalchemy.engine.Engine BEGIN (implicit)
# 2024-08-30 18:21:33,045 INFO sqlalchemy.engine.Engine SELECT marked_sentences.id, marked_sentences.date_time, marked_sentences.sentence, marked_sentences.comment, marked_sentences.lesson, marked_sentences.line
# FROM marked_sentences
# WHERE marked_sentences.date_time > ? AND marked_sentences.date_time < ? AND marked_sentences.lesson = ?
# 2024-08-30 18:21:33,046 INFO sqlalchemy.engine.Engine [cached since 0.008614s ago] ('0001-01-01 00:00:00.000000', '9999-12-31 23:59:59.999999', 3)
# 2024-08-30 18:21:33,046 INFO sqlalchemy.engine.Engine ROLLBACK
# 2024-08-30 18:21:33,047 INFO sqlalchemy.engine.Engine BEGIN (implicit)
# 2024-08-30 18:21:33,047 INFO sqlalchemy.engine.Engine SELECT marked_sentences.id, marked_sentences.date_time, marked_sentences.sentence, marked_sentences.comment, marked_sentences.lesson, marked_sentences.line
# FROM marked_sentences
# WHERE marked_sentences.date_time > ? AND marked_sentences.date_time < ? AND marked_sentences.lesson = ?
# 2024-08-30 18:21:33,048 INFO sqlalchemy.engine.Engine [cached since 0.01071s ago] ('0001-01-01 00:00:00.000000', '9999-12-31 23:59:59.999999', 4)
# 2024-08-30 18:21:33,050 INFO sqlalchemy.engine.Engine ROLLBACK
# 2024-08-30 18:21:33,050 INFO sqlalchemy.engine.Engine BEGIN (implicit)
# 2024-08-30 18:21:33,051 INFO sqlalchemy.engine.Engine SELECT marked_sentences.id, marked_sentences.date_time, marked_sentences.sentence, marked_sentences.comment, marked_sentences.lesson, marked_sentences.line
# FROM marked_sentences
# WHERE marked_sentences.date_time > ? AND marked_sentences.date_time < ? AND marked_sentences.lesson = ?
# 2024-08-30 18:21:33,051 INFO sqlalchemy.engine.Engine [cached since 0.01421s ago] ('0001-01-01 00:00:00.000000', '9999-12-31 23:59:59.999999', 5)
# 2024-08-30 18:21:33,052 INFO sqlalchemy.engine.Engine ROLLBACK
# 2024-08-30 18:21:33,052 INFO sqlalchemy.engine.Engine BEGIN (implicit)
# 2024-08-30 18:21:33,053 INFO sqlalchemy.engine.Engine SELECT marked_sentences.id, marked_sentences.date_time, marked_sentences.sentence, marked_sentences.comment, marked_sentences.lesson, marked_sentences.line
# FROM marked_sentences
# WHERE marked_sentences.date_time > ? AND marked_sentences.date_time < ? AND marked_sentences.lesson = ?
# 2024-08-30 18:21:33,053 INFO sqlalchemy.engine.Engine [cached since 0.0161s ago] ('0001-01-01 00:00:00.000000', '9999-12-31 23:59:59.999999', 6)
# 2024-08-30 18:21:33,054 INFO sqlalchemy.engine.Engine ROLLBACK
# 2024-08-30 18:21:33,054 INFO sqlalchemy.engine.Engine BEGIN (implicit)
# 2024-08-30 18:21:33,055 INFO sqlalchemy.engine.Engine SELECT marked_sentences.id, marked_sentences.date_time, marked_sentences.sentence, marked_sentences.comment, marked_sentences.lesson, marked_sentences.line
# FROM marked_sentences
# WHERE marked_sentences.date_time > ? AND marked_sentences.date_time < ? AND marked_sentences.lesson = ?
# 2024-08-30 18:21:33,055 INFO sqlalchemy.engine.Engine [cached since 0.01791s ago] ('0001-01-01 00:00:00.000000', '9999-12-31 23:59:59.999999', 7)
# 2024-08-30 18:21:33,056 INFO sqlalchemy.engine.Engine ROLLBACK
# 2024-08-30 18:21:33,057 INFO sqlalchemy.engine.Engine BEGIN (implicit)
# 2024-08-30 18:21:33,057 INFO sqlalchemy.engine.Engine SELECT marked_sentences.id, marked_sentences.date_time, marked_sentences.sentence, marked_sentences.comment, marked_sentences.lesson, marked_sentences.line
# FROM marked_sentences
# WHERE marked_sentences.date_time > ? AND marked_sentences.date_time < ? AND marked_sentences.lesson = ?
# 2024-08-30 18:21:33,058 INFO sqlalchemy.engine.Engine [cached since 0.02087s ago] ('0001-01-01 00:00:00.000000', '9999-12-31 23:59:59.999999', 8)
# 2024-08-30 18:21:33,059 INFO sqlalchemy.engine.Engine ROLLBACK
# 2024-08-30 18:21:33,060 INFO sqlalchemy.engine.Engine BEGIN (implicit)
# 2024-08-30 18:21:33,060 INFO sqlalchemy.engine.Engine SELECT marked_sentences.id, marked_sentences.date_time, marked_sentences.sentence, marked_sentences.comment, marked_sentences.lesson, marked_sentences.line
# FROM marked_sentences
# WHERE marked_sentences.date_time > ? AND marked_sentences.date_time < ? AND marked_sentences.lesson = ?
# 2024-08-30 18:21:33,061 INFO sqlalchemy.engine.Engine [cached since 0.02355s ago] ('0001-01-01 00:00:00.000000', '9999-12-31 23:59:59.999999', 9)
# 2024-08-30 18:21:33,061 INFO sqlalchemy.engine.Engine ROLLBACK
# 2024-08-30 18:21:33,061 INFO sqlalchemy.engine.Engine BEGIN (implicit)
# 2024-08-30 18:21:33,062 INFO sqlalchemy.engine.Engine SELECT marked_sentences.id, marked_sentences.date_time, marked_sentences.sentence, marked_sentences.comment, marked_sentences.lesson, marked_sentences.line
# FROM marked_sentences
# WHERE marked_sentences.date_time > ? AND marked_sentences.date_time < ? AND marked_sentences.lesson = ?
# 2024-08-30 18:21:33,062 INFO sqlalchemy.engine.Engine [cached since 0.02532s ago] ('0001-01-01 00:00:00.000000', '9999-12-31 23:59:59.999999', 10)
# 2024-08-30 18:21:33,063 INFO sqlalchemy.engine.Engine ROLLBACK
# 2024-08-30 18:21:33,063 INFO sqlalchemy.engine.Engine BEGIN (implicit)
# 2024-08-30 18:21:33,064 INFO sqlalchemy.engine.Engine SELECT marked_sentences.id, marked_sentences.date_time, marked_sentences.sentence, marked_sentences.comment, marked_sentences.lesson, marked_sentences.line
# FROM marked_sentences
# WHERE marked_sentences.date_time > ? AND marked_sentences.date_time < ? AND marked_sentences.lesson = ?
# 2024-08-30 18:21:33,064 INFO sqlalchemy.engine.Engine [cached since 0.02706s ago] ('0001-01-01 00:00:00.000000', '9999-12-31 23:59:59.999999', 11)
# 2024-08-30 18:21:33,065 INFO sqlalchemy.engine.Engine ROLLBACK
# 2024-08-30 18:21:33,065 INFO sqlalchemy.engine.Engine BEGIN (implicit)
# 2024-08-30 18:21:33,065 INFO sqlalchemy.engine.Engine SELECT marked_sentences.id, marked_sentences.date_time, marked_sentences.sentence, marked_sentences.comment, marked_sentences.lesson, marked_sentences.line
# FROM marked_sentences
# WHERE marked_sentences.date_time > ? AND marked_sentences.date_time < ? AND marked_sentences.lesson = ?
# 2024-08-30 18:21:33,065 INFO sqlalchemy.engine.Engine [cached since 0.02848s ago] ('0001-01-01 00:00:00.000000', '9999-12-31 23:59:59.999999', 12)
# 2024-08-30 18:21:33,066 INFO sqlalchemy.engine.Engine ROLLBACK
# 2024-08-30 18:21:33,066 INFO sqlalchemy.engine.Engine BEGIN (implicit)
# 2024-08-30 18:21:33,067 INFO sqlalchemy.engine.Engine SELECT marked_sentences.id, marked_sentences.date_time, marked_sentences.sentence, marked_sentences.comment, marked_sentences.lesson, marked_sentences.line
# FROM marked_sentences
# WHERE marked_sentences.date_time > ? AND marked_sentences.date_time < ? AND marked_sentences.lesson = ?
# 2024-08-30 18:21:33,068 INFO sqlalchemy.engine.Engine [cached since 0.03064s ago] ('0001-01-01 00:00:00.000000', '9999-12-31 23:59:59.999999', 13)
# 2024-08-30 18:21:33,068 INFO sqlalchemy.engine.Engine ROLLBACK
# 2024-08-30 18:21:33,069 INFO sqlalchemy.engine.Engine BEGIN (implicit)
# 2024-08-30 18:21:33,070 INFO sqlalchemy.engine.Engine SELECT marked_sentences.id, marked_sentences.date_time, marked_sentences.sentence, marked_sentences.comment, marked_sentences.lesson, marked_sentences.line
# FROM marked_sentences
# WHERE marked_sentences.date_time > ? AND marked_sentences.date_time < ? AND marked_sentences.lesson = ?
# 2024-08-30 18:21:33,070 INFO sqlalchemy.engine.Engine [cached since 0.0329s ago] ('0001-01-01 00:00:00.000000', '9999-12-31 23:59:59.999999', 14)
# 2024-08-30 18:21:33,071 INFO sqlalchemy.engine.Engine ROLLBACK
# 2024-08-30 18:21:33,071 INFO sqlalchemy.engine.Engine BEGIN (implicit)
# 2024-08-30 18:21:33,072 INFO sqlalchemy.engine.Engine SELECT marked_sentences.id, marked_sentences.date_time, marked_sentences.sentence, marked_sentences.comment, marked_sentences.lesson, marked_sentences.line
# FROM marked_sentences
# WHERE marked_sentences.date_time > ? AND marked_sentences.date_time < ? AND marked_sentences.lesson = ?
# 2024-08-30 18:21:33,072 INFO sqlalchemy.engine.Engine [cached since 0.03519s ago] ('0001-01-01 00:00:00.000000', '9999-12-31 23:59:59.999999', 15)
# 2024-08-30 18:21:33,073 INFO sqlalchemy.engine.Engine ROLLBACK
# 2024-08-30 18:21:33,074 INFO sqlalchemy.engine.Engine BEGIN (implicit)
# 2024-08-30 18:21:33,074 INFO sqlalchemy.engine.Engine SELECT marked_sentences.id, marked_sentences.date_time, marked_sentences.sentence, marked_sentences.comment, marked_sentences.lesson, marked_sentences.line
# FROM marked_sentences
# WHERE marked_sentences.date_time > ? AND marked_sentences.date_time < ? AND marked_sentences.lesson = ?
# 2024-08-30 18:21:33,074 INFO sqlalchemy.engine.Engine [cached since 0.03748s ago] ('0001-01-01 00:00:00.000000', '9999-12-31 23:59:59.999999', 16)
# 2024-08-30 18:21:33,075 INFO sqlalchemy.engine.Engine ROLLBACK
# 2024-08-30 18:21:33,076 INFO sqlalchemy.engine.Engine BEGIN (implicit)
# 2024-08-30 18:21:33,076 INFO sqlalchemy.engine.Engine SELECT marked_sentences.id, marked_sentences.date_time, marked_sentences.sentence, marked_sentences.comment, marked_sentences.lesson, marked_sentences.line
# FROM marked_sentences
# WHERE marked_sentences.date_time > ? AND marked_sentences.date_time < ? AND marked_sentences.lesson = ?
# 2024-08-30 18:21:33,076 INFO sqlalchemy.engine.Engine [cached since 0.03924s ago] ('0001-01-01 00:00:00.000000', '9999-12-31 23:59:59.999999', 17)
# 2024-08-30 18:21:33,077 INFO sqlalchemy.engine.Engine ROLLBACK
# 2024-08-30 18:21:33,078 INFO sqlalchemy.engine.Engine BEGIN (implicit)
# 2024-08-30 18:21:33,079 INFO sqlalchemy.engine.Engine SELECT marked_sentences.id, marked_sentences.date_time, marked_sentences.sentence, marked_sentences.comment, marked_sentences.lesson, marked_sentences.line
# FROM marked_sentences
# WHERE marked_sentences.date_time > ? AND marked_sentences.date_time < ? AND marked_sentences.lesson = ?
# 2024-08-30 18:21:33,079 INFO sqlalchemy.engine.Engine [cached since 0.04222s ago] ('0001-01-01 00:00:00.000000', '9999-12-31 23:59:59.999999', 18)
# 2024-08-30 18:21:33,080 INFO sqlalchemy.engine.Engine ROLLBACK
# 2024-08-30 18:21:33,080 INFO sqlalchemy.engine.Engine BEGIN (implicit)
# 2024-08-30 18:21:33,081 INFO sqlalchemy.engine.Engine SELECT marked_sentences.id, marked_sentences.date_time, marked_sentences.sentence, marked_sentences.comment, marked_sentences.lesson, marked_sentences.line
# FROM marked_sentences
# WHERE marked_sentences.date_time > ? AND marked_sentences.date_time < ? AND marked_sentences.lesson = ?
# 2024-08-30 18:21:33,081 INFO sqlalchemy.engine.Engine [cached since 0.04408s ago] ('0001-01-01 00:00:00.000000', '9999-12-31 23:59:59.999999', 19)
# 2024-08-30 18:21:33,081 INFO sqlalchemy.engine.Engine ROLLBACK
# 2024-08-30 18:21:33,082 INFO sqlalchemy.engine.Engine BEGIN (implicit)
# 2024-08-30 18:21:33,082 INFO sqlalchemy.engine.Engine SELECT marked_sentences.id, marked_sentences.date_time, marked_sentences.sentence, marked_sentences.comment, marked_sentences.lesson, marked_sentences.line
# FROM marked_sentences
# WHERE marked_sentences.date_time > ? AND marked_sentences.date_time < ? AND marked_sentences.lesson = ?
# 2024-08-30 18:21:33,082 INFO sqlalchemy.engine.Engine [cached since 0.04542s ago] ('0001-01-01 00:00:00.000000', '9999-12-31 23:59:59.999999', 20)
# 2024-08-30 18:21:33,083 INFO sqlalchemy.engine.Engine ROLLBACK
# 2024-08-30 18:21:33,083 INFO sqlalchemy.engine.Engine BEGIN (implicit)
# 2024-08-30 18:21:33,083 INFO sqlalchemy.engine.Engine SELECT marked_sentences.id, marked_sentences.date_time, marked_sentences.sentence, marked_sentences.comment, marked_sentences.lesson, marked_sentences.line
# FROM marked_sentences
# WHERE marked_sentences.date_time > ? AND marked_sentences.date_time < ? AND marked_sentences.lesson = ?
# 2024-08-30 18:21:33,084 INFO sqlalchemy.engine.Engine [cached since 0.04665s ago] ('0001-01-01 00:00:00.000000', '9999-12-31 23:59:59.999999', 21)
# 2024-08-30 18:21:33,084 INFO sqlalchemy.engine.Engine ROLLBACK
# 2024-08-30 18:21:33,084 INFO sqlalchemy.engine.Engine BEGIN (implicit)
# 2024-08-30 18:21:33,085 INFO sqlalchemy.engine.Engine SELECT marked_sentences.id, marked_sentences.date_time, marked_sentences.sentence, marked_sentences.comment, marked_sentences.lesson, marked_sentences.line
# FROM marked_sentences
# WHERE marked_sentences.date_time > ? AND marked_sentences.date_time < ? AND marked_sentences.lesson = ?
# 2024-08-30 18:21:33,085 INFO sqlalchemy.engine.Engine [cached since 0.04787s ago] ('0001-01-01 00:00:00.000000', '9999-12-31 23:59:59.999999', 22)
# 2024-08-30 18:21:33,085 INFO sqlalchemy.engine.Engine ROLLBACK
# 2024-08-30 18:21:33,086 INFO sqlalchemy.engine.Engine BEGIN (implicit)
# 2024-08-30 18:21:33,086 INFO sqlalchemy.engine.Engine SELECT marked_sentences.id, marked_sentences.date_time, marked_sentences.sentence, marked_sentences.comment, marked_sentences.lesson, marked_sentences.line
# FROM marked_sentences
# WHERE marked_sentences.date_time > ? AND marked_sentences.date_time < ? AND marked_sentences.lesson = ?
# 2024-08-30 18:21:33,086 INFO sqlalchemy.engine.Engine [cached since 0.04898s ago] ('0001-01-01 00:00:00.000000', '9999-12-31 23:59:59.999999', 23)
# 2024-08-30 18:21:33,086 INFO sqlalchemy.engine.Engine ROLLBACK
# 2024-08-30 18:21:33,087 INFO sqlalchemy.engine.Engine BEGIN (implicit)
# 2024-08-30 18:21:33,087 INFO sqlalchemy.engine.Engine SELECT marked_sentences.id, marked_sentences.date_time, marked_sentences.sentence, marked_sentences.comment, marked_sentences.lesson, marked_sentences.line
# FROM marked_sentences
# WHERE marked_sentences.date_time > ? AND marked_sentences.date_time < ? AND marked_sentences.lesson = ?
# 2024-08-30 18:21:33,087 INFO sqlalchemy.engine.Engine [cached since 0.05016s ago] ('0001-01-01 00:00:00.000000', '9999-12-31 23:59:59.999999', 24)
# 2024-08-30 18:21:33,087 INFO sqlalchemy.engine.Engine ROLLBACK
# 2024-08-30 18:21:33,088 INFO sqlalchemy.engine.Engine BEGIN (implicit)
# 2024-08-30 18:21:33,088 INFO sqlalchemy.engine.Engine SELECT marked_sentences.id, marked_sentences.date_time, marked_sentences.sentence, marked_sentences.comment, marked_sentences.lesson, marked_sentences.line
# FROM marked_sentences
# WHERE marked_sentences.date_time > ? AND marked_sentences.date_time < ? AND marked_sentences.lesson = ?
# 2024-08-30 18:21:33,088 INFO sqlalchemy.engine.Engine [cached since 0.05144s ago] ('0001-01-01 00:00:00.000000', '9999-12-31 23:59:59.999999', 25)
# 2024-08-30 18:21:33,089 INFO sqlalchemy.engine.Engine ROLLBACK
# 2024-08-30 18:21:33,089 INFO sqlalchemy.engine.Engine BEGIN (implicit)
# 2024-08-30 18:21:33,089 INFO sqlalchemy.engine.Engine SELECT marked_sentences.id, marked_sentences.date_time, marked_sentences.sentence, marked_sentences.comment, marked_sentences.lesson, marked_sentences.line
# FROM marked_sentences
# WHERE marked_sentences.date_time > ? AND marked_sentences.date_time < ? AND marked_sentences.lesson = ?
# 2024-08-30 18:21:33,090 INFO sqlalchemy.engine.Engine [cached since 0.05277s ago] ('0001-01-01 00:00:00.000000', '9999-12-31 23:59:59.999999', 26)
# 2024-08-30 18:21:33,090 INFO sqlalchemy.engine.Engine ROLLBACK
# 2024-08-30 18:21:33,090 INFO sqlalchemy.engine.Engine BEGIN (implicit)
# 2024-08-30 18:21:33,091 INFO sqlalchemy.engine.Engine SELECT marked_sentences.id, marked_sentences.date_time, marked_sentences.sentence, marked_sentences.comment, marked_sentences.lesson, marked_sentences.line
# FROM marked_sentences
# WHERE marked_sentences.date_time > ? AND marked_sentences.date_time < ? AND marked_sentences.lesson = ?
# 2024-08-30 18:21:33,091 INFO sqlalchemy.engine.Engine [cached since 0.05404s ago] ('0001-01-01 00:00:00.000000', '9999-12-31 23:59:59.999999', 27)
# 2024-08-30 18:21:33,091 INFO sqlalchemy.engine.Engine ROLLBACK
# 2024-08-30 18:21:33,092 INFO sqlalchemy.engine.Engine BEGIN (implicit)
# 2024-08-30 18:21:33,092 INFO sqlalchemy.engine.Engine SELECT marked_sentences.id, marked_sentences.date_time, marked_sentences.sentence, marked_sentences.comment, marked_sentences.lesson, marked_sentences.line
# FROM marked_sentences
# WHERE marked_sentences.date_time > ? AND marked_sentences.date_time < ? AND marked_sentences.lesson = ?
# 2024-08-30 18:21:33,092 INFO sqlalchemy.engine.Engine [cached since 0.05533s ago] ('0001-01-01 00:00:00.000000', '9999-12-31 23:59:59.999999', 28)
# 2024-08-30 18:21:33,093 INFO sqlalchemy.engine.Engine ROLLBACK
# 2024-08-30 18:21:33,093 INFO sqlalchemy.engine.Engine BEGIN (implicit)
# 2024-08-30 18:21:33,093 INFO sqlalchemy.engine.Engine SELECT marked_sentences.id, marked_sentences.date_time, marked_sentences.sentence, marked_sentences.comment, marked_sentences.lesson, marked_sentences.line
# FROM marked_sentences
# WHERE marked_sentences.date_time > ? AND marked_sentences.date_time < ? AND marked_sentences.lesson = ?
# 2024-08-30 18:21:33,094 INFO sqlalchemy.engine.Engine [cached since 0.0566s ago] ('0001-01-01 00:00:00.000000', '9999-12-31 23:59:59.999999', 29)
# 2024-08-30 18:21:33,094 INFO sqlalchemy.engine.Engine ROLLBACK
# 2024-08-30 18:21:33,094 INFO sqlalchemy.engine.Engine BEGIN (implicit)
# 2024-08-30 18:21:33,095 INFO sqlalchemy.engine.Engine SELECT marked_sentences.id, marked_sentences.date_time, marked_sentences.sentence, marked_sentences.comment, marked_sentences.lesson, marked_sentences.line
# FROM marked_sentences
# WHERE marked_sentences.date_time > ? AND marked_sentences.date_time < ? AND marked_sentences.lesson = ?
# 2024-08-30 18:21:33,095 INFO sqlalchemy.engine.Engine [cached since 0.05798s ago] ('0001-01-01 00:00:00.000000', '9999-12-31 23:59:59.999999', 30)
# 2024-08-30 18:21:33,096 INFO sqlalchemy.engine.Engine ROLLBACK
# 2024-08-30 18:21:33,096 INFO sqlalchemy.engine.Engine BEGIN (implicit)
# 2024-08-30 18:21:33,096 INFO sqlalchemy.engine.Engine SELECT marked_sentences.id, marked_sentences.date_time, marked_sentences.sentence, marked_sentences.comment, marked_sentences.lesson, marked_sentences.line
# FROM marked_sentences
# WHERE marked_sentences.date_time > ? AND marked_sentences.date_time < ? AND marked_sentences.lesson = ?
# 2024-08-30 18:21:33,097 INFO sqlalchemy.engine.Engine [cached since 0.05963s ago] ('0001-01-01 00:00:00.000000', '9999-12-31 23:59:59.999999', 31)
# 2024-08-30 18:21:33,097 INFO sqlalchemy.engine.Engine ROLLBACK
# 2024-08-30 18:21:33,097 INFO sqlalchemy.engine.Engine BEGIN (implicit)
# 2024-08-30 18:21:33,098 INFO sqlalchemy.engine.Engine SELECT marked_sentences.id, marked_sentences.date_time, marked_sentences.sentence, marked_sentences.comment, marked_sentences.lesson, marked_sentences.line
# FROM marked_sentences
# WHERE marked_sentences.date_time > ? AND marked_sentences.date_time < ? AND marked_sentences.lesson = ?
# 2024-08-30 18:21:33,098 INFO sqlalchemy.engine.Engine [cached since 0.06089s ago] ('0001-01-01 00:00:00.000000', '9999-12-31 23:59:59.999999', 32)
# 2024-08-30 18:21:33,098 INFO sqlalchemy.engine.Engine ROLLBACK
# 2024-08-30 18:21:33,099 INFO sqlalchemy.engine.Engine BEGIN (implicit)
# 2024-08-30 18:21:33,099 INFO sqlalchemy.engine.Engine SELECT marked_sentences.id, marked_sentences.date_time, marked_sentences.sentence, marked_sentences.comment, marked_sentences.lesson, marked_sentences.line
# FROM marked_sentences
# WHERE marked_sentences.date_time > ? AND marked_sentences.date_time < ? AND marked_sentences.lesson = ?
# 2024-08-30 18:21:33,099 INFO sqlalchemy.engine.Engine [cached since 0.06225s ago] ('0001-01-01 00:00:00.000000', '9999-12-31 23:59:59.999999', 33)
# 2024-08-30 18:21:33,100 INFO sqlalchemy.engine.Engine ROLLBACK
# 2024-08-30 18:21:33,100 INFO sqlalchemy.engine.Engine BEGIN (implicit)
# 2024-08-30 18:21:33,101 INFO sqlalchemy.engine.Engine SELECT marked_sentences.id, marked_sentences.date_time, marked_sentences.sentence, marked_sentences.comment, marked_sentences.lesson, marked_sentences.line
# FROM marked_sentences
# WHERE marked_sentences.date_time > ? AND marked_sentences.date_time < ? AND marked_sentences.lesson = ?
# 2024-08-30 18:21:33,101 INFO sqlalchemy.engine.Engine [cached since 0.06378s ago] ('0001-01-01 00:00:00.000000', '9999-12-31 23:59:59.999999', 34)
# 2024-08-30 18:21:33,101 INFO sqlalchemy.engine.Engine ROLLBACK
# 2024-08-30 18:21:33,102 INFO sqlalchemy.engine.Engine BEGIN (implicit)
# 2024-08-30 18:21:33,102 INFO sqlalchemy.engine.Engine SELECT marked_sentences.id, marked_sentences.date_time, marked_sentences.sentence, marked_sentences.comment, marked_sentences.lesson, marked_sentences.line
# FROM marked_sentences
# WHERE marked_sentences.date_time > ? AND marked_sentences.date_time < ? AND marked_sentences.lesson = ?
# 2024-08-30 18:21:33,102 INFO sqlalchemy.engine.Engine [cached since 0.06528s ago] ('0001-01-01 00:00:00.000000', '9999-12-31 23:59:59.999999', 35)
# 2024-08-30 18:21:33,103 INFO sqlalchemy.engine.Engine ROLLBACK
# 2024-08-30 18:21:33,103 INFO sqlalchemy.engine.Engine BEGIN (implicit)
# 2024-08-30 18:21:33,103 INFO sqlalchemy.engine.Engine SELECT marked_sentences.id, marked_sentences.date_time, marked_sentences.sentence, marked_sentences.comment, marked_sentences.lesson, marked_sentences.line
# FROM marked_sentences
# WHERE marked_sentences.date_time > ? AND marked_sentences.date_time < ? AND marked_sentences.lesson = ?
# 2024-08-30 18:21:33,104 INFO sqlalchemy.engine.Engine [cached since 0.06664s ago] ('0001-01-01 00:00:00.000000', '9999-12-31 23:59:59.999999', 36)
# 2024-08-30 18:21:33,104 INFO sqlalchemy.engine.Engine ROLLBACK
# 2024-08-30 18:21:33,104 INFO sqlalchemy.engine.Engine BEGIN (implicit)
# 2024-08-30 18:21:33,105 INFO sqlalchemy.engine.Engine SELECT marked_sentences.id, marked_sentences.date_time, marked_sentences.sentence, marked_sentences.comment, marked_sentences.lesson, marked_sentences.line
# FROM marked_sentences
# WHERE marked_sentences.date_time > ? AND marked_sentences.date_time < ? AND marked_sentences.lesson = ?
# 2024-08-30 18:21:33,105 INFO sqlalchemy.engine.Engine [cached since 0.06791s ago] ('0001-01-01 00:00:00.000000', '9999-12-31 23:59:59.999999', 37)
# 2024-08-30 18:21:33,105 INFO sqlalchemy.engine.Engine ROLLBACK
# 2024-08-30 18:21:33,106 INFO sqlalchemy.engine.Engine BEGIN (implicit)
# 2024-08-30 18:21:33,106 INFO sqlalchemy.engine.Engine SELECT marked_sentences.id, marked_sentences.date_time, marked_sentences.sentence, marked_sentences.comment, marked_sentences.lesson, marked_sentences.line
# FROM marked_sentences
# WHERE marked_sentences.date_time > ? AND marked_sentences.date_time < ? AND marked_sentences.lesson = ?
# 2024-08-30 18:21:33,106 INFO sqlalchemy.engine.Engine [cached since 0.06917s ago] ('0001-01-01 00:00:00.000000', '9999-12-31 23:59:59.999999', 38)
# 2024-08-30 18:21:33,106 INFO sqlalchemy.engine.Engine ROLLBACK
# 2024-08-30 18:21:33,107 INFO sqlalchemy.engine.Engine BEGIN (implicit)
# 2024-08-30 18:21:33,107 INFO sqlalchemy.engine.Engine SELECT marked_sentences.id, marked_sentences.date_time, marked_sentences.sentence, marked_sentences.comment, marked_sentences.lesson, marked_sentences.line
# FROM marked_sentences
# WHERE marked_sentences.date_time > ? AND marked_sentences.date_time < ? AND marked_sentences.lesson = ?
# 2024-08-30 18:21:33,107 INFO sqlalchemy.engine.Engine [cached since 0.07024s ago] ('0001-01-01 00:00:00.000000', '9999-12-31 23:59:59.999999', 39)
# 2024-08-30 18:21:33,108 INFO sqlalchemy.engine.Engine ROLLBACK
# 2024-08-30 18:21:33,108 INFO sqlalchemy.engine.Engine BEGIN (implicit)
# 2024-08-30 18:21:33,109 INFO sqlalchemy.engine.Engine SELECT marked_sentences.id, marked_sentences.date_time, marked_sentences.sentence, marked_sentences.comment, marked_sentences.lesson, marked_sentences.line
# FROM marked_sentences
# WHERE marked_sentences.date_time > ? AND marked_sentences.date_time < ? AND marked_sentences.lesson = ?
# 2024-08-30 18:21:33,109 INFO sqlalchemy.engine.Engine [cached since 0.07207s ago] ('0001-01-01 00:00:00.000000', '9999-12-31 23:59:59.999999', 40)
# 2024-08-30 18:21:33,110 INFO sqlalchemy.engine.Engine ROLLBACK
# 2024-08-30 18:21:33,110 INFO sqlalchemy.engine.Engine BEGIN (implicit)
# 2024-08-30 18:21:33,111 INFO sqlalchemy.engine.Engine SELECT marked_sentences.id, marked_sentences.date_time, marked_sentences.sentence, marked_sentences.comment, marked_sentences.lesson, marked_sentences.line
# FROM marked_sentences
# WHERE marked_sentences.date_time > ? AND marked_sentences.date_time < ? AND marked_sentences.lesson = ?
# 2024-08-30 18:21:33,111 INFO sqlalchemy.engine.Engine [cached since 0.07402s ago] ('0001-01-01 00:00:00.000000', '9999-12-31 23:59:59.999999', 41)
# 2024-08-30 18:21:33,111 INFO sqlalchemy.engine.Engine ROLLBACK
# 2024-08-30 18:21:33,112 INFO sqlalchemy.engine.Engine BEGIN (implicit)
# 2024-08-30 18:21:33,113 INFO sqlalchemy.engine.Engine SELECT marked_sentences.id, marked_sentences.date_time, marked_sentences.sentence, marked_sentences.comment, marked_sentences.lesson, marked_sentences.line
# FROM marked_sentences
# WHERE marked_sentences.date_time > ? AND marked_sentences.date_time < ? AND marked_sentences.lesson = ?
# 2024-08-30 18:21:33,113 INFO sqlalchemy.engine.Engine [cached since 0.07582s ago] ('0001-01-01 00:00:00.000000', '9999-12-31 23:59:59.999999', 42)
# 2024-08-30 18:21:33,114 INFO sqlalchemy.engine.Engine ROLLBACK
# 2024-08-30 18:21:33,114 INFO sqlalchemy.engine.Engine BEGIN (implicit)
# 2024-08-30 18:21:33,115 INFO sqlalchemy.engine.Engine SELECT marked_sentences.id, marked_sentences.date_time, marked_sentences.sentence, marked_sentences.comment, marked_sentences.lesson, marked_sentences.line
# FROM marked_sentences
# WHERE marked_sentences.date_time > ? AND marked_sentences.date_time < ? AND marked_sentences.lesson = ?
# 2024-08-30 18:21:33,120 INFO sqlalchemy.engine.Engine [cached since 0.08302s ago] ('0001-01-01 00:00:00.000000', '9999-12-31 23:59:59.999999', 43)
# 2024-08-30 18:21:33,131 INFO sqlalchemy.engine.Engine ROLLBACK
# 2024-08-30 18:21:33,132 INFO sqlalchemy.engine.Engine BEGIN (implicit)
# 2024-08-30 18:21:33,132 INFO sqlalchemy.engine.Engine SELECT marked_sentences.id, marked_sentences.date_time, marked_sentences.sentence, marked_sentences.comment, marked_sentences.lesson, marked_sentences.line
# FROM marked_sentences
# WHERE marked_sentences.date_time > ? AND marked_sentences.date_time < ? AND marked_sentences.lesson = ?
# 2024-08-30 18:21:33,132 INFO sqlalchemy.engine.Engine [cached since 0.09523s ago] ('0001-01-01 00:00:00.000000', '9999-12-31 23:59:59.999999', 44)
# 2024-08-30 18:21:33,133 INFO sqlalchemy.engine.Engine ROLLBACK
# 2024-08-30 18:21:33,133 INFO sqlalchemy.engine.Engine BEGIN (implicit)
# 2024-08-30 18:21:33,133 INFO sqlalchemy.engine.Engine SELECT marked_sentences.id, marked_sentences.date_time, marked_sentences.sentence, marked_sentences.comment, marked_sentences.lesson, marked_sentences.line
# FROM marked_sentences
# WHERE marked_sentences.date_time > ? AND marked_sentences.date_time < ? AND marked_sentences.lesson = ?
# 2024-08-30 18:21:33,134 INFO sqlalchemy.engine.Engine [cached since 0.09681s ago] ('0001-01-01 00:00:00.000000', '9999-12-31 23:59:59.999999', 45)
# 2024-08-30 18:21:33,134 INFO sqlalchemy.engine.Engine ROLLBACK
# 2024-08-30 18:21:33,135 INFO sqlalchemy.engine.Engine BEGIN (implicit)
# 2024-08-30 18:21:33,135 INFO sqlalchemy.engine.Engine SELECT marked_sentences.id, marked_sentences.date_time, marked_sentences.sentence, marked_sentences.comment, marked_sentences.lesson, marked_sentences.line
# FROM marked_sentences
# WHERE marked_sentences.date_time > ? AND marked_sentences.date_time < ? AND marked_sentences.lesson = ?
# 2024-08-30 18:21:33,136 INFO sqlalchemy.engine.Engine [cached since 0.09866s ago] ('0001-01-01 00:00:00.000000', '9999-12-31 23:59:59.999999', 46)
# 2024-08-30 18:21:33,136 INFO sqlalchemy.engine.Engine ROLLBACK
# 2024-08-30 18:21:33,136 INFO sqlalchemy.engine.Engine BEGIN (implicit)
# 2024-08-30 18:21:33,137 INFO sqlalchemy.engine.Engine SELECT marked_sentences.id, marked_sentences.date_time, marked_sentences.sentence, marked_sentences.comment, marked_sentences.lesson, marked_sentences.line
# FROM marked_sentences
# WHERE marked_sentences.date_time > ? AND marked_sentences.date_time < ? AND marked_sentences.lesson = ?
# 2024-08-30 18:21:33,137 INFO sqlalchemy.engine.Engine [cached since 0.09984s ago] ('0001-01-01 00:00:00.000000', '9999-12-31 23:59:59.999999', 47)
# 2024-08-30 18:21:33,137 INFO sqlalchemy.engine.Engine ROLLBACK
# 2024-08-30 18:21:33,137 INFO sqlalchemy.engine.Engine BEGIN (implicit)
# 2024-08-30 18:21:33,138 INFO sqlalchemy.engine.Engine SELECT marked_sentences.id, marked_sentences.date_time, marked_sentences.sentence, marked_sentences.comment, marked_sentences.lesson, marked_sentences.line
# FROM marked_sentences
# WHERE marked_sentences.date_time > ? AND marked_sentences.date_time < ? AND marked_sentences.lesson = ?
# 2024-08-30 18:21:33,138 INFO sqlalchemy.engine.Engine [cached since 0.101s ago] ('0001-01-01 00:00:00.000000', '9999-12-31 23:59:59.999999', 48)
# 2024-08-30 18:21:33,138 INFO sqlalchemy.engine.Engine ROLLBACK
# 2024-08-30 18:21:33,139 INFO sqlalchemy.engine.Engine BEGIN (implicit)
# 2024-08-30 18:21:33,139 INFO sqlalchemy.engine.Engine SELECT marked_sentences.id, marked_sentences.date_time, marked_sentences.sentence, marked_sentences.comment, marked_sentences.lesson, marked_sentences.line
# FROM marked_sentences
# WHERE marked_sentences.date_time > ? AND marked_sentences.date_time < ? AND marked_sentences.lesson = ?
# 2024-08-30 18:21:33,139 INFO sqlalchemy.engine.Engine [cached since 0.102s ago] ('0001-01-01 00:00:00.000000', '9999-12-31 23:59:59.999999', 49)
# 2024-08-30 18:21:33,139 INFO sqlalchemy.engine.Engine ROLLBACK
# 2024-08-30 18:21:33,140 INFO sqlalchemy.engine.Engine BEGIN (implicit)
# 2024-08-30 18:21:33,140 INFO sqlalchemy.engine.Engine SELECT marked_sentences.id, marked_sentences.date_time, marked_sentences.sentence, marked_sentences.comment, marked_sentences.lesson, marked_sentences.line
# FROM marked_sentences
# WHERE marked_sentences.date_time > ? AND marked_sentences.date_time < ? AND marked_sentences.lesson = ?
# 2024-08-30 18:21:33,140 INFO sqlalchemy.engine.Engine [cached since 0.1031s ago] ('0001-01-01 00:00:00.000000', '9999-12-31 23:59:59.999999', 50)
# 2024-08-30 18:21:33,140 INFO sqlalchemy.engine.Engine ROLLBACK
# 2024-08-30 18:21:33,141 INFO sqlalchemy.engine.Engine BEGIN (implicit)
# 2024-08-30 18:21:33,141 INFO sqlalchemy.engine.Engine SELECT marked_sentences.id, marked_sentences.date_time, marked_sentences.sentence, marked_sentences.comment, marked_sentences.lesson, marked_sentences.line
# FROM marked_sentences
# WHERE marked_sentences.date_time > ? AND marked_sentences.date_time < ? AND marked_sentences.lesson = ?
# 2024-08-30 18:21:33,141 INFO sqlalchemy.engine.Engine [cached since 0.1043s ago] ('0001-01-01 00:00:00.000000', '9999-12-31 23:59:59.999999', 51)
# 2024-08-30 18:21:33,142 INFO sqlalchemy.engine.Engine ROLLBACK
# 2024-08-30 18:21:33,142 INFO sqlalchemy.engine.Engine BEGIN (implicit)
# 2024-08-30 18:21:33,142 INFO sqlalchemy.engine.Engine SELECT marked_sentences.id, marked_sentences.date_time, marked_sentences.sentence, marked_sentences.comment, marked_sentences.lesson, marked_sentences.line
# FROM marked_sentences
# WHERE marked_sentences.date_time > ? AND marked_sentences.date_time < ? AND marked_sentences.lesson = ?
# 2024-08-30 18:21:33,142 INFO sqlalchemy.engine.Engine [cached since 0.1055s ago] ('0001-01-01 00:00:00.000000', '9999-12-31 23:59:59.999999', 52)
# 2024-08-30 18:21:33,143 INFO sqlalchemy.engine.Engine ROLLBACK
# 2024-08-30 18:21:33,143 INFO sqlalchemy.engine.Engine BEGIN (implicit)
# 2024-08-30 18:21:33,143 INFO sqlalchemy.engine.Engine SELECT marked_sentences.id, marked_sentences.date_time, marked_sentences.sentence, marked_sentences.comment, marked_sentences.lesson, marked_sentences.line
# FROM marked_sentences
# WHERE marked_sentences.date_time > ? AND marked_sentences.date_time < ? AND marked_sentences.lesson = ?
# 2024-08-30 18:21:33,144 INFO sqlalchemy.engine.Engine [cached since 0.1066s ago] ('0001-01-01 00:00:00.000000', '9999-12-31 23:59:59.999999', 53)
# 2024-08-30 18:21:33,144 INFO sqlalchemy.engine.Engine ROLLBACK
# 2024-08-30 18:21:33,144 INFO sqlalchemy.engine.Engine BEGIN (implicit)
# 2024-08-30 18:21:33,144 INFO sqlalchemy.engine.Engine SELECT marked_sentences.id, marked_sentences.date_time, marked_sentences.sentence, marked_sentences.comment, marked_sentences.lesson, marked_sentences.line
# FROM marked_sentences
# WHERE marked_sentences.date_time > ? AND marked_sentences.date_time < ? AND marked_sentences.lesson = ?
# 2024-08-30 18:21:33,145 INFO sqlalchemy.engine.Engine [cached since 0.1076s ago] ('0001-01-01 00:00:00.000000', '9999-12-31 23:59:59.999999', 54)
# 2024-08-30 18:21:33,145 INFO sqlalchemy.engine.Engine ROLLBACK
# 2024-08-30 18:21:33,145 INFO sqlalchemy.engine.Engine BEGIN (implicit)
# 2024-08-30 18:21:33,145 INFO sqlalchemy.engine.Engine SELECT marked_sentences.id, marked_sentences.date_time, marked_sentences.sentence, marked_sentences.comment, marked_sentences.lesson, marked_sentences.line
# FROM marked_sentences
# WHERE marked_sentences.date_time > ? AND marked_sentences.date_time < ? AND marked_sentences.lesson = ?
# 2024-08-30 18:21:33,146 INFO sqlalchemy.engine.Engine [cached since 0.1087s ago] ('0001-01-01 00:00:00.000000', '9999-12-31 23:59:59.999999', 55)
# 2024-08-30 18:21:33,146 INFO sqlalchemy.engine.Engine ROLLBACK
# 2024-08-30 18:21:33,146 INFO sqlalchemy.engine.Engine BEGIN (implicit)
# 2024-08-30 18:21:33,146 INFO sqlalchemy.engine.Engine SELECT marked_sentences.id, marked_sentences.date_time, marked_sentences.sentence, marked_sentences.comment, marked_sentences.lesson, marked_sentences.line
# FROM marked_sentences
# WHERE marked_sentences.date_time > ? AND marked_sentences.date_time < ? AND marked_sentences.lesson = ?
# 2024-08-30 18:21:33,147 INFO sqlalchemy.engine.Engine [cached since 0.1097s ago] ('0001-01-01 00:00:00.000000', '9999-12-31 23:59:59.999999', 56)
# 2024-08-30 18:21:33,147 INFO sqlalchemy.engine.Engine ROLLBACK
# 2024-08-30 18:21:33,147 INFO sqlalchemy.engine.Engine BEGIN (implicit)
# 2024-08-30 18:21:33,148 INFO sqlalchemy.engine.Engine SELECT marked_sentences.id, marked_sentences.date_time, marked_sentences.sentence, marked_sentences.comment, marked_sentences.lesson, marked_sentences.line
# FROM marked_sentences
# WHERE marked_sentences.date_time > ? AND marked_sentences.date_time < ? AND marked_sentences.lesson = ?
# 2024-08-30 18:21:33,148 INFO sqlalchemy.engine.Engine [cached since 0.1107s ago] ('0001-01-01 00:00:00.000000', '9999-12-31 23:59:59.999999', 57)
# 2024-08-30 18:21:33,148 INFO sqlalchemy.engine.Engine ROLLBACK
# 2024-08-30 18:21:33,148 INFO sqlalchemy.engine.Engine BEGIN (implicit)
# 2024-08-30 18:21:33,149 INFO sqlalchemy.engine.Engine SELECT marked_sentences.id, marked_sentences.date_time, marked_sentences.sentence, marked_sentences.comment, marked_sentences.lesson, marked_sentences.line
# FROM marked_sentences
# WHERE marked_sentences.date_time > ? AND marked_sentences.date_time < ? AND marked_sentences.lesson = ?
# 2024-08-30 18:21:33,149 INFO sqlalchemy.engine.Engine [cached since 0.1118s ago] ('0001-01-01 00:00:00.000000', '9999-12-31 23:59:59.999999', 58)
# 2024-08-30 18:21:33,149 INFO sqlalchemy.engine.Engine ROLLBACK
# 2024-08-30 18:21:33,149 INFO sqlalchemy.engine.Engine BEGIN (implicit)
# 2024-08-30 18:21:33,150 INFO sqlalchemy.engine.Engine SELECT marked_sentences.id, marked_sentences.date_time, marked_sentences.sentence, marked_sentences.comment, marked_sentences.lesson, marked_sentences.line
# FROM marked_sentences
# WHERE marked_sentences.date_time > ? AND marked_sentences.date_time < ? AND marked_sentences.lesson = ?
# 2024-08-30 18:21:33,150 INFO sqlalchemy.engine.Engine [cached since 0.1129s ago] ('0001-01-01 00:00:00.000000', '9999-12-31 23:59:59.999999', 59)
# 2024-08-30 18:21:33,150 INFO sqlalchemy.engine.Engine ROLLBACK
# 2024-08-30 18:21:33,151 INFO sqlalchemy.engine.Engine BEGIN (implicit)
# 2024-08-30 18:21:33,151 INFO sqlalchemy.engine.Engine SELECT marked_sentences.id, marked_sentences.date_time, marked_sentences.sentence, marked_sentences.comment, marked_sentences.lesson, marked_sentences.line
# FROM marked_sentences
# WHERE marked_sentences.date_time > ? AND marked_sentences.date_time < ? AND marked_sentences.lesson = ?
# 2024-08-30 18:21:33,151 INFO sqlalchemy.engine.Engine [cached since 0.1142s ago] ('0001-01-01 00:00:00.000000', '9999-12-31 23:59:59.999999', 60)
# 2024-08-30 18:21:33,152 INFO sqlalchemy.engine.Engine ROLLBACK
# 2024-08-30 18:21:33,152 INFO sqlalchemy.engine.Engine BEGIN (implicit)
# 2024-08-30 18:21:33,155 INFO sqlalchemy.engine.Engine SELECT marked_sentences.id, marked_sentences.date_time, marked_sentences.sentence, marked_sentences.comment, marked_sentences.lesson, marked_sentences.line
# FROM marked_sentences
# WHERE marked_sentences.date_time > ? AND marked_sentences.date_time < ? AND marked_sentences.lesson = ?
# 2024-08-30 18:21:33,156 INFO sqlalchemy.engine.Engine [cached since 0.1188s ago] ('0001-01-01 00:00:00.000000', '9999-12-31 23:59:59.999999', 61)
# 2024-08-30 18:21:33,156 INFO sqlalchemy.engine.Engine ROLLBACK
# 2024-08-30 18:21:33,157 INFO sqlalchemy.engine.Engine BEGIN (implicit)
# 2024-08-30 18:21:33,157 INFO sqlalchemy.engine.Engine SELECT marked_sentences.id, marked_sentences.date_time, marked_sentences.sentence, marked_sentences.comment, marked_sentences.lesson, marked_sentences.line
# FROM marked_sentences
# WHERE marked_sentences.date_time > ? AND marked_sentences.date_time < ? AND marked_sentences.lesson = ?
# 2024-08-30 18:21:33,157 INFO sqlalchemy.engine.Engine [cached since 0.1204s ago] ('0001-01-01 00:00:00.000000', '9999-12-31 23:59:59.999999', 62)
# 2024-08-30 18:21:33,158 INFO sqlalchemy.engine.Engine ROLLBACK
# 2024-08-30 18:21:33,158 INFO sqlalchemy.engine.Engine BEGIN (implicit)
# 2024-08-30 18:21:33,158 INFO sqlalchemy.engine.Engine SELECT marked_sentences.id, marked_sentences.date_time, marked_sentences.sentence, marked_sentences.comment, marked_sentences.lesson, marked_sentences.line
# FROM marked_sentences
# WHERE marked_sentences.date_time > ? AND marked_sentences.date_time < ? AND marked_sentences.lesson = ?
# 2024-08-30 18:21:33,159 INFO sqlalchemy.engine.Engine [cached since 0.1215s ago] ('0001-01-01 00:00:00.000000', '9999-12-31 23:59:59.999999', 63)
# 2024-08-30 18:21:33,159 INFO sqlalchemy.engine.Engine ROLLBACK
# 2024-08-30 18:21:33,159 INFO sqlalchemy.engine.Engine BEGIN (implicit)
# 2024-08-30 18:21:33,159 INFO sqlalchemy.engine.Engine SELECT marked_sentences.id, marked_sentences.date_time, marked_sentences.sentence, marked_sentences.comment, marked_sentences.lesson, marked_sentences.line
# FROM marked_sentences
# WHERE marked_sentences.date_time > ? AND marked_sentences.date_time < ? AND marked_sentences.lesson = ?
# 2024-08-30 18:21:33,160 INFO sqlalchemy.engine.Engine [cached since 0.1226s ago] ('0001-01-01 00:00:00.000000', '9999-12-31 23:59:59.999999', 64)
# 2024-08-30 18:21:33,160 INFO sqlalchemy.engine.Engine ROLLBACK
# 2024-08-30 18:21:33,160 INFO sqlalchemy.engine.Engine BEGIN (implicit)
# 2024-08-30 18:21:33,161 INFO sqlalchemy.engine.Engine SELECT marked_sentences.id, marked_sentences.date_time, marked_sentences.sentence, marked_sentences.comment, marked_sentences.lesson, marked_sentences.line
# FROM marked_sentences
# WHERE marked_sentences.date_time > ? AND marked_sentences.date_time < ? AND marked_sentences.lesson = ?
# 2024-08-30 18:21:33,161 INFO sqlalchemy.engine.Engine [cached since 0.1237s ago] ('0001-01-01 00:00:00.000000', '9999-12-31 23:59:59.999999', 65)
# 2024-08-30 18:21:33,161 INFO sqlalchemy.engine.Engine ROLLBACK
# 2024-08-30 18:21:33,161 INFO sqlalchemy.engine.Engine BEGIN (implicit)
# 2024-08-30 18:21:33,162 INFO sqlalchemy.engine.Engine SELECT marked_sentences.id, marked_sentences.date_time, marked_sentences.sentence, marked_sentences.comment, marked_sentences.lesson, marked_sentences.line
# FROM marked_sentences
# WHERE marked_sentences.date_time > ? AND marked_sentences.date_time < ? AND marked_sentences.lesson = ?
# 2024-08-30 18:21:33,162 INFO sqlalchemy.engine.Engine [cached since 0.1248s ago] ('0001-01-01 00:00:00.000000', '9999-12-31 23:59:59.999999', 66)
# 2024-08-30 18:21:33,162 INFO sqlalchemy.engine.Engine ROLLBACK
# 2024-08-30 18:21:33,162 INFO sqlalchemy.engine.Engine BEGIN (implicit)
# 2024-08-30 18:21:33,163 INFO sqlalchemy.engine.Engine SELECT marked_sentences.id, marked_sentences.date_time, marked_sentences.sentence, marked_sentences.comment, marked_sentences.lesson, marked_sentences.line
# FROM marked_sentences
# WHERE marked_sentences.date_time > ? AND marked_sentences.date_time < ? AND marked_sentences.lesson = ?
# 2024-08-30 18:21:33,163 INFO sqlalchemy.engine.Engine [cached since 0.1259s ago] ('0001-01-01 00:00:00.000000', '9999-12-31 23:59:59.999999', 67)
# 2024-08-30 18:21:33,163 INFO sqlalchemy.engine.Engine ROLLBACK
# 2024-08-30 18:21:33,163 INFO sqlalchemy.engine.Engine BEGIN (implicit)
# 2024-08-30 18:21:33,164 INFO sqlalchemy.engine.Engine SELECT marked_sentences.id, marked_sentences.date_time, marked_sentences.sentence, marked_sentences.comment, marked_sentences.lesson, marked_sentences.line
# FROM marked_sentences
# WHERE marked_sentences.date_time > ? AND marked_sentences.date_time < ? AND marked_sentences.lesson = ?
# 2024-08-30 18:21:33,164 INFO sqlalchemy.engine.Engine [cached since 0.1269s ago] ('0001-01-01 00:00:00.000000', '9999-12-31 23:59:59.999999', 68)
# 2024-08-30 18:21:33,164 INFO sqlalchemy.engine.Engine ROLLBACK
# 2024-08-30 18:21:33,165 INFO sqlalchemy.engine.Engine BEGIN (implicit)
# 2024-08-30 18:21:33,165 INFO sqlalchemy.engine.Engine SELECT marked_sentences.id, marked_sentences.date_time, marked_sentences.sentence, marked_sentences.comment, marked_sentences.lesson, marked_sentences.line
# FROM marked_sentences
# WHERE marked_sentences.date_time > ? AND marked_sentences.date_time < ? AND marked_sentences.lesson = ?
# 2024-08-30 18:21:33,165 INFO sqlalchemy.engine.Engine [cached since 0.1284s ago] ('0001-01-01 00:00:00.000000', '9999-12-31 23:59:59.999999', 69)
# 2024-08-30 18:21:33,166 INFO sqlalchemy.engine.Engine ROLLBACK
# 2024-08-30 18:21:33,166 INFO sqlalchemy.engine.Engine BEGIN (implicit)
# 2024-08-30 18:21:33,166 INFO sqlalchemy.engine.Engine SELECT marked_sentences.id, marked_sentences.date_time, marked_sentences.sentence, marked_sentences.comment, marked_sentences.lesson, marked_sentences.line
# FROM marked_sentences
# WHERE marked_sentences.date_time > ? AND marked_sentences.date_time < ? AND marked_sentences.lesson = ?
# 2024-08-30 18:21:33,166 INFO sqlalchemy.engine.Engine [cached since 0.1295s ago] ('0001-01-01 00:00:00.000000', '9999-12-31 23:59:59.999999', 70)
# 2024-08-30 18:21:33,167 INFO sqlalchemy.engine.Engine ROLLBACK
# 2024-08-30 18:21:33,167 INFO sqlalchemy.engine.Engine BEGIN (implicit)
# 2024-08-30 18:21:33,168 INFO sqlalchemy.engine.Engine SELECT marked_sentences.id, marked_sentences.date_time, marked_sentences.sentence, marked_sentences.comment, marked_sentences.lesson, marked_sentences.line
# FROM marked_sentences
# WHERE marked_sentences.date_time > ? AND marked_sentences.date_time < ? AND marked_sentences.lesson = ?
# 2024-08-30 18:21:33,168 INFO sqlalchemy.engine.Engine [cached since 0.1309s ago] ('0001-01-01 00:00:00.000000', '9999-12-31 23:59:59.999999', 71)
# 2024-08-30 18:21:33,168 INFO sqlalchemy.engine.Engine ROLLBACK
# 2024-08-30 18:21:33,169 INFO sqlalchemy.engine.Engine BEGIN (implicit)
# 2024-08-30 18:21:33,169 INFO sqlalchemy.engine.Engine SELECT marked_sentences.id, marked_sentences.date_time, marked_sentences.sentence, marked_sentences.comment, marked_sentences.lesson, marked_sentences.line
# FROM marked_sentences
# WHERE marked_sentences.date_time > ? AND marked_sentences.date_time < ? AND marked_sentences.lesson = ?
# 2024-08-30 18:21:33,169 INFO sqlalchemy.engine.Engine [cached since 0.1322s ago] ('0001-01-01 00:00:00.000000', '9999-12-31 23:59:59.999999', 72)
# 2024-08-30 18:21:33,170 INFO sqlalchemy.engine.Engine ROLLBACK
# 2024-08-30 18:21:33,170 INFO sqlalchemy.engine.Engine BEGIN (implicit)
# 2024-08-30 18:21:33,170 INFO sqlalchemy.engine.Engine SELECT marked_sentences.id, marked_sentences.date_time, marked_sentences.sentence, marked_sentences.comment, marked_sentences.lesson, marked_sentences.line
# FROM marked_sentences
# WHERE marked_sentences.date_time > ? AND marked_sentences.date_time < ? AND marked_sentences.lesson = ?
# 2024-08-30 18:21:33,170 INFO sqlalchemy.engine.Engine [cached since 0.1333s ago] ('0001-01-01 00:00:00.000000', '9999-12-31 23:59:59.999999', 73)
# 2024-08-30 18:21:33,171 INFO sqlalchemy.engine.Engine ROLLBACK
# 2024-08-30 18:21:33,171 INFO sqlalchemy.engine.Engine BEGIN (implicit)
# 2024-08-30 18:21:33,171 INFO sqlalchemy.engine.Engine SELECT marked_sentences.id, marked_sentences.date_time, marked_sentences.sentence, marked_sentences.comment, marked_sentences.lesson, marked_sentences.line
# FROM marked_sentences
# WHERE marked_sentences.date_time > ? AND marked_sentences.date_time < ? AND marked_sentences.lesson = ?
# 2024-08-30 18:21:33,171 INFO sqlalchemy.engine.Engine [cached since 0.1344s ago] ('0001-01-01 00:00:00.000000', '9999-12-31 23:59:59.999999', 74)
# 2024-08-30 18:21:33,172 INFO sqlalchemy.engine.Engine ROLLBACK
# 2024-08-30 18:21:33,172 INFO sqlalchemy.engine.Engine BEGIN (implicit)
# 2024-08-30 18:21:33,172 INFO sqlalchemy.engine.Engine SELECT marked_sentences.id, marked_sentences.date_time, marked_sentences.sentence, marked_sentences.comment, marked_sentences.lesson, marked_sentences.line
# FROM marked_sentences
# WHERE marked_sentences.date_time > ? AND marked_sentences.date_time < ? AND marked_sentences.lesson = ?
# 2024-08-30 18:21:33,172 INFO sqlalchemy.engine.Engine [cached since 0.1353s ago] ('0001-01-01 00:00:00.000000', '9999-12-31 23:59:59.999999', 75)
# 2024-08-30 18:21:33,173 INFO sqlalchemy.engine.Engine ROLLBACK
# 2024-08-30 18:21:33,173 INFO sqlalchemy.engine.Engine BEGIN (implicit)
# 2024-08-30 18:21:33,173 INFO sqlalchemy.engine.Engine SELECT marked_sentences.id, marked_sentences.date_time, marked_sentences.sentence, marked_sentences.comment, marked_sentences.lesson, marked_sentences.line
# FROM marked_sentences
# WHERE marked_sentences.date_time > ? AND marked_sentences.date_time < ? AND marked_sentences.lesson = ?
# 2024-08-30 18:21:33,173 INFO sqlalchemy.engine.Engine [cached since 0.1363s ago] ('0001-01-01 00:00:00.000000', '9999-12-31 23:59:59.999999', 76)
# 2024-08-30 18:21:33,174 INFO sqlalchemy.engine.Engine ROLLBACK
# 2024-08-30 18:21:33,174 INFO sqlalchemy.engine.Engine BEGIN (implicit)
# 2024-08-30 18:21:33,174 INFO sqlalchemy.engine.Engine SELECT marked_sentences.id, marked_sentences.date_time, marked_sentences.sentence, marked_sentences.comment, marked_sentences.lesson, marked_sentences.line
# FROM marked_sentences
# WHERE marked_sentences.date_time > ? AND marked_sentences.date_time < ? AND marked_sentences.lesson = ?
# 2024-08-30 18:21:33,174 INFO sqlalchemy.engine.Engine [cached since 0.1375s ago] ('0001-01-01 00:00:00.000000', '9999-12-31 23:59:59.999999', 77)
# 2024-08-30 18:21:33,175 INFO sqlalchemy.engine.Engine ROLLBACK
# 2024-08-30 18:21:33,175 INFO sqlalchemy.engine.Engine BEGIN (implicit)
# 2024-08-30 18:21:33,175 INFO sqlalchemy.engine.Engine SELECT marked_sentences.id, marked_sentences.date_time, marked_sentences.sentence, marked_sentences.comment, marked_sentences.lesson, marked_sentences.line
# FROM marked_sentences
# WHERE marked_sentences.date_time > ? AND marked_sentences.date_time < ? AND marked_sentences.lesson = ?
# 2024-08-30 18:21:33,175 INFO sqlalchemy.engine.Engine [cached since 0.1385s ago] ('0001-01-01 00:00:00.000000', '9999-12-31 23:59:59.999999', 78)
# 2024-08-30 18:21:33,176 INFO sqlalchemy.engine.Engine ROLLBACK
# 2024-08-30 18:21:33,176 INFO sqlalchemy.engine.Engine BEGIN (implicit)
# 2024-08-30 18:21:33,176 INFO sqlalchemy.engine.Engine SELECT marked_sentences.id, marked_sentences.date_time, marked_sentences.sentence, marked_sentences.comment, marked_sentences.lesson, marked_sentences.line
# FROM marked_sentences
# WHERE marked_sentences.date_time > ? AND marked_sentences.date_time < ? AND marked_sentences.lesson = ?
# 2024-08-30 18:21:33,176 INFO sqlalchemy.engine.Engine [cached since 0.1395s ago] ('0001-01-01 00:00:00.000000', '9999-12-31 23:59:59.999999', 79)
# 2024-08-30 18:21:33,177 INFO sqlalchemy.engine.Engine ROLLBACK
# 2024-08-30 18:21:33,177 INFO sqlalchemy.engine.Engine BEGIN (implicit)
# 2024-08-30 18:21:33,177 INFO sqlalchemy.engine.Engine SELECT marked_sentences.id, marked_sentences.date_time, marked_sentences.sentence, marked_sentences.comment, marked_sentences.lesson, marked_sentences.line
# FROM marked_sentences
# WHERE marked_sentences.date_time > ? AND marked_sentences.date_time < ? AND marked_sentences.lesson = ?
# 2024-08-30 18:21:33,178 INFO sqlalchemy.engine.Engine [cached since 0.1406s ago] ('0001-01-01 00:00:00.000000', '9999-12-31 23:59:59.999999', 80)
# 2024-08-30 18:21:33,178 INFO sqlalchemy.engine.Engine ROLLBACK
# 2024-08-30 18:21:33,178 INFO sqlalchemy.engine.Engine BEGIN (implicit)
# 2024-08-30 18:21:33,178 INFO sqlalchemy.engine.Engine SELECT marked_sentences.id, marked_sentences.date_time, marked_sentences.sentence, marked_sentences.comment, marked_sentences.lesson, marked_sentences.line
# FROM marked_sentences
# WHERE marked_sentences.date_time > ? AND marked_sentences.date_time < ? AND marked_sentences.lesson = ?
# 2024-08-30 18:21:33,179 INFO sqlalchemy.engine.Engine [cached since 0.1416s ago] ('0001-01-01 00:00:00.000000', '9999-12-31 23:59:59.999999', 81)
# 2024-08-30 18:21:33,179 INFO sqlalchemy.engine.Engine ROLLBACK
# 2024-08-30 18:21:33,179 INFO sqlalchemy.engine.Engine BEGIN (implicit)
# 2024-08-30 18:21:33,179 INFO sqlalchemy.engine.Engine SELECT marked_sentences.id, marked_sentences.date_time, marked_sentences.sentence, marked_sentences.comment, marked_sentences.lesson, marked_sentences.line
# FROM marked_sentences
# WHERE marked_sentences.date_time > ? AND marked_sentences.date_time < ? AND marked_sentences.lesson = ?
# 2024-08-30 18:21:33,180 INFO sqlalchemy.engine.Engine [cached since 0.1427s ago] ('0001-01-01 00:00:00.000000', '9999-12-31 23:59:59.999999', 82)
# 2024-08-30 18:21:33,180 INFO sqlalchemy.engine.Engine ROLLBACK
# 2024-08-30 18:21:33,180 INFO sqlalchemy.engine.Engine BEGIN (implicit)
# 2024-08-30 18:21:33,180 INFO sqlalchemy.engine.Engine SELECT marked_sentences.id, marked_sentences.date_time, marked_sentences.sentence, marked_sentences.comment, marked_sentences.lesson, marked_sentences.line
# FROM marked_sentences
# WHERE marked_sentences.date_time > ? AND marked_sentences.date_time < ? AND marked_sentences.lesson = ?
# 2024-08-30 18:21:33,181 INFO sqlalchemy.engine.Engine [cached since 0.1437s ago] ('0001-01-01 00:00:00.000000', '9999-12-31 23:59:59.999999', 83)
# 2024-08-30 18:21:33,181 INFO sqlalchemy.engine.Engine ROLLBACK
# 2024-08-30 18:21:33,181 INFO sqlalchemy.engine.Engine BEGIN (implicit)
# 2024-08-30 18:21:33,182 INFO sqlalchemy.engine.Engine SELECT marked_sentences.id, marked_sentences.date_time, marked_sentences.sentence, marked_sentences.comment, marked_sentences.lesson, marked_sentences.line
# FROM marked_sentences
# WHERE marked_sentences.date_time > ? AND marked_sentences.date_time < ? AND marked_sentences.lesson = ?
# 2024-08-30 18:21:33,182 INFO sqlalchemy.engine.Engine [cached since 0.1447s ago] ('0001-01-01 00:00:00.000000', '9999-12-31 23:59:59.999999', 84)
# 2024-08-30 18:21:33,182 INFO sqlalchemy.engine.Engine ROLLBACK
# 2024-08-30 18:21:33,182 INFO sqlalchemy.engine.Engine BEGIN (implicit)
# 2024-08-30 18:21:33,182 INFO sqlalchemy.engine.Engine SELECT marked_sentences.id, marked_sentences.date_time, marked_sentences.sentence, marked_sentences.comment, marked_sentences.lesson, marked_sentences.line
# FROM marked_sentences
# WHERE marked_sentences.date_time > ? AND marked_sentences.date_time < ? AND marked_sentences.lesson = ?
# 2024-08-30 18:21:33,183 INFO sqlalchemy.engine.Engine [cached since 0.1456s ago] ('0001-01-01 00:00:00.000000', '9999-12-31 23:59:59.999999', 85)
# 2024-08-30 18:21:33,183 INFO sqlalchemy.engine.Engine ROLLBACK
# 2024-08-30 18:21:33,183 INFO sqlalchemy.engine.Engine BEGIN (implicit)
# 2024-08-30 18:21:33,183 INFO sqlalchemy.engine.Engine SELECT marked_sentences.id, marked_sentences.date_time, marked_sentences.sentence, marked_sentences.comment, marked_sentences.lesson, marked_sentences.line
# FROM marked_sentences
# WHERE marked_sentences.date_time > ? AND marked_sentences.date_time < ? AND marked_sentences.lesson = ?
# 2024-08-30 18:21:33,184 INFO sqlalchemy.engine.Engine [cached since 0.1466s ago] ('0001-01-01 00:00:00.000000', '9999-12-31 23:59:59.999999', 86)
# 2024-08-30 18:21:33,184 INFO sqlalchemy.engine.Engine ROLLBACK
# 2024-08-30 18:21:33,184 INFO sqlalchemy.engine.Engine BEGIN (implicit)
# 2024-08-30 18:21:33,184 INFO sqlalchemy.engine.Engine SELECT marked_sentences.id, marked_sentences.date_time, marked_sentences.sentence, marked_sentences.comment, marked_sentences.lesson, marked_sentences.line
# FROM marked_sentences
# WHERE marked_sentences.date_time > ? AND marked_sentences.date_time < ? AND marked_sentences.lesson = ?
# 2024-08-30 18:21:33,185 INFO sqlalchemy.engine.Engine [cached since 0.1476s ago] ('0001-01-01 00:00:00.000000', '9999-12-31 23:59:59.999999', 87)
# 2024-08-30 18:21:33,185 INFO sqlalchemy.engine.Engine ROLLBACK
# 2024-08-30 18:21:33,185 INFO sqlalchemy.engine.Engine BEGIN (implicit)
# 2024-08-30 18:21:33,185 INFO sqlalchemy.engine.Engine SELECT marked_sentences.id, marked_sentences.date_time, marked_sentences.sentence, marked_sentences.comment, marked_sentences.lesson, marked_sentences.line
# FROM marked_sentences
# WHERE marked_sentences.date_time > ? AND marked_sentences.date_time < ? AND marked_sentences.lesson = ?
# 2024-08-30 18:21:33,186 INFO sqlalchemy.engine.Engine [cached since 0.1486s ago] ('0001-01-01 00:00:00.000000', '9999-12-31 23:59:59.999999', 88)
# 2024-08-30 18:21:33,186 INFO sqlalchemy.engine.Engine ROLLBACK
# 2024-08-30 18:21:33,186 INFO sqlalchemy.engine.Engine BEGIN (implicit)
# 2024-08-30 18:21:33,186 INFO sqlalchemy.engine.Engine SELECT marked_sentences.id, marked_sentences.date_time, marked_sentences.sentence, marked_sentences.comment, marked_sentences.lesson, marked_sentences.line
# FROM marked_sentences
# WHERE marked_sentences.date_time > ? AND marked_sentences.date_time < ? AND marked_sentences.lesson = ?
# 2024-08-30 18:21:33,186 INFO sqlalchemy.engine.Engine [cached since 0.1495s ago] ('0001-01-01 00:00:00.000000', '9999-12-31 23:59:59.999999', 89)
# 2024-08-30 18:21:33,187 INFO sqlalchemy.engine.Engine ROLLBACK
# 2024-08-30 18:21:33,187 INFO sqlalchemy.engine.Engine BEGIN (implicit)
# 2024-08-30 18:21:33,187 INFO sqlalchemy.engine.Engine SELECT marked_sentences.id, marked_sentences.date_time, marked_sentences.sentence, marked_sentences.comment, marked_sentences.lesson, marked_sentences.line
# FROM marked_sentences
# WHERE marked_sentences.date_time > ? AND marked_sentences.date_time < ? AND marked_sentences.lesson = ?
# 2024-08-30 18:21:33,187 INFO sqlalchemy.engine.Engine [cached since 0.1504s ago] ('0001-01-01 00:00:00.000000', '9999-12-31 23:59:59.999999', 90)
# 2024-08-30 18:21:33,188 INFO sqlalchemy.engine.Engine ROLLBACK
# 2024-08-30 18:21:33,188 INFO sqlalchemy.engine.Engine BEGIN (implicit)
# 2024-08-30 18:21:33,188 INFO sqlalchemy.engine.Engine SELECT marked_sentences.id, marked_sentences.date_time, marked_sentences.sentence, marked_sentences.comment, marked_sentences.lesson, marked_sentences.line
# FROM marked_sentences
# WHERE marked_sentences.date_time > ? AND marked_sentences.date_time < ? AND marked_sentences.lesson = ?
# 2024-08-30 18:21:33,188 INFO sqlalchemy.engine.Engine [cached since 0.1513s ago] ('0001-01-01 00:00:00.000000', '9999-12-31 23:59:59.999999', 91)
# 2024-08-30 18:21:33,189 INFO sqlalchemy.engine.Engine ROLLBACK
# 2024-08-30 18:21:33,189 INFO sqlalchemy.engine.Engine BEGIN (implicit)
# 2024-08-30 18:21:33,189 INFO sqlalchemy.engine.Engine SELECT marked_sentences.id, marked_sentences.date_time, marked_sentences.sentence, marked_sentences.comment, marked_sentences.lesson, marked_sentences.line
# FROM marked_sentences
# WHERE marked_sentences.date_time > ? AND marked_sentences.date_time < ? AND marked_sentences.lesson = ?
# 2024-08-30 18:21:33,189 INFO sqlalchemy.engine.Engine [cached since 0.1522s ago] ('0001-01-01 00:00:00.000000', '9999-12-31 23:59:59.999999', 92)
# 2024-08-30 18:21:33,189 INFO sqlalchemy.engine.Engine ROLLBACK
# 2024-08-30 18:21:33,190 INFO sqlalchemy.engine.Engine BEGIN (implicit)
# 2024-08-30 18:21:33,190 INFO sqlalchemy.engine.Engine SELECT marked_sentences.id, marked_sentences.date_time, marked_sentences.sentence, marked_sentences.comment, marked_sentences.lesson, marked_sentences.line
# FROM marked_sentences
# WHERE marked_sentences.date_time > ? AND marked_sentences.date_time < ? AND marked_sentences.lesson = ?
# 2024-08-30 18:21:33,190 INFO sqlalchemy.engine.Engine [cached since 0.1531s ago] ('0001-01-01 00:00:00.000000', '9999-12-31 23:59:59.999999', 93)
# 2024-08-30 18:21:33,190 INFO sqlalchemy.engine.Engine ROLLBACK
# 2024-08-30 18:21:33,191 INFO sqlalchemy.engine.Engine BEGIN (implicit)
# 2024-08-30 18:21:33,191 INFO sqlalchemy.engine.Engine SELECT marked_sentences.id, marked_sentences.date_time, marked_sentences.sentence, marked_sentences.comment, marked_sentences.lesson, marked_sentences.line
# FROM marked_sentences
# WHERE marked_sentences.date_time > ? AND marked_sentences.date_time < ? AND marked_sentences.lesson = ?
# 2024-08-30 18:21:33,191 INFO sqlalchemy.engine.Engine [cached since 0.154s ago] ('0001-01-01 00:00:00.000000', '9999-12-31 23:59:59.999999', 94)
# 2024-08-30 18:21:33,191 INFO sqlalchemy.engine.Engine ROLLBACK
# 2024-08-30 18:21:33,192 INFO sqlalchemy.engine.Engine BEGIN (implicit)
# 2024-08-30 18:21:33,192 INFO sqlalchemy.engine.Engine SELECT marked_sentences.id, marked_sentences.date_time, marked_sentences.sentence, marked_sentences.comment, marked_sentences.lesson, marked_sentences.line
# FROM marked_sentences
# WHERE marked_sentences.date_time > ? AND marked_sentences.date_time < ? AND marked_sentences.lesson = ?
# 2024-08-30 18:21:33,192 INFO sqlalchemy.engine.Engine [cached since 0.155s ago] ('0001-01-01 00:00:00.000000', '9999-12-31 23:59:59.999999', 95)
# 2024-08-30 18:21:33,192 INFO sqlalchemy.engine.Engine ROLLBACK
# 2024-08-30 18:21:33,192 INFO sqlalchemy.engine.Engine BEGIN (implicit)
# 2024-08-30 18:21:33,193 INFO sqlalchemy.engine.Engine SELECT marked_sentences.id, marked_sentences.date_time, marked_sentences.sentence, marked_sentences.comment, marked_sentences.lesson, marked_sentences.line
# FROM marked_sentences
# WHERE marked_sentences.date_time > ? AND marked_sentences.date_time < ? AND marked_sentences.lesson = ?
# 2024-08-30 18:21:33,193 INFO sqlalchemy.engine.Engine [cached since 0.1559s ago] ('0001-01-01 00:00:00.000000', '9999-12-31 23:59:59.999999', 96)
# 2024-08-30 18:21:33,193 INFO sqlalchemy.engine.Engine ROLLBACK
# 2024-08-30 18:21:33,194 INFO sqlalchemy.engine.Engine BEGIN (implicit)
# 2024-08-30 18:21:33,194 INFO sqlalchemy.engine.Engine SELECT marked_sentences.id, marked_sentences.date_time, marked_sentences.sentence, marked_sentences.comment, marked_sentences.lesson, marked_sentences.line
# FROM marked_sentences
# WHERE marked_sentences.date_time > ? AND marked_sentences.date_time < ? AND marked_sentences.lesson = ?
# 2024-08-30 18:21:33,194 INFO sqlalchemy.engine.Engine [cached since 0.1569s ago] ('0001-01-01 00:00:00.000000', '9999-12-31 23:59:59.999999', 97)
# 2024-08-30 18:21:33,194 INFO sqlalchemy.engine.Engine ROLLBACK
# 2024-08-30 18:21:33,194 INFO sqlalchemy.engine.Engine BEGIN (implicit)
# 2024-08-30 18:21:33,195 INFO sqlalchemy.engine.Engine SELECT marked_sentences.id, marked_sentences.date_time, marked_sentences.sentence, marked_sentences.comment, marked_sentences.lesson, marked_sentences.line
# FROM marked_sentences
# WHERE marked_sentences.date_time > ? AND marked_sentences.date_time < ? AND marked_sentences.lesson = ?
# 2024-08-30 18:21:33,195 INFO sqlalchemy.engine.Engine [cached since 0.1578s ago] ('0001-01-01 00:00:00.000000', '9999-12-31 23:59:59.999999', 98)
# 2024-08-30 18:21:33,195 INFO sqlalchemy.engine.Engine ROLLBACK
# 2024-08-30 18:21:33,195 INFO sqlalchemy.engine.Engine BEGIN (implicit)
# 2024-08-30 18:21:33,196 INFO sqlalchemy.engine.Engine SELECT marked_sentences.id, marked_sentences.date_time, marked_sentences.sentence, marked_sentences.comment, marked_sentences.lesson, marked_sentences.line
# FROM marked_sentences
# WHERE marked_sentences.date_time > ? AND marked_sentences.date_time < ? AND marked_sentences.lesson = ?
# 2024-08-30 18:21:33,196 INFO sqlalchemy.engine.Engine [cached since 0.1588s ago] ('0001-01-01 00:00:00.000000', '9999-12-31 23:59:59.999999', 99)
# 2024-08-30 18:21:33,196 INFO sqlalchemy.engine.Engine ROLLBACK
# 2024-08-30 18:21:33,196 INFO sqlalchemy.engine.Engine BEGIN (implicit)
# 2024-08-30 18:21:33,197 INFO sqlalchemy.engine.Engine SELECT marked_sentences.id, marked_sentences.date_time, marked_sentences.sentence, marked_sentences.comment, marked_sentences.lesson, marked_sentences.line
# FROM marked_sentences
# WHERE marked_sentences.date_time > ? AND marked_sentences.date_time < ? AND marked_sentences.lesson = ?
# 2024-08-30 18:21:33,197 INFO sqlalchemy.engine.Engine [cached since 0.1597s ago] ('0001-01-01 00:00:00.000000', '9999-12-31 23:59:59.999999', 100)
# 2024-08-30 18:21:33,197 INFO sqlalchemy.engine.Engine ROLLBACK

# %%
errors.keys()
# Out:
# dict_keys([4, 5, 45])

# %%
lesson_nb = 45
sentences = get_html_sentences(lesson_nb)

# %%
sentences
# Out:
# ['N45-Lec<b>ción</b> cua<b>ren</b>ta y <b>cin</b>co',
#  'S00-TITLE-En el <b>cí</b>ber',
#  'S01-Los ar<b>chi</b>vos es<b>tán</b> en la car<b>pe</b>ta <b>fo</b>tos.',
#  'S02-Sí, los <b>ve</b>o, se los im<b>pri</b>mo ense<b>gui</b>da.',
#  'S03-¡Oh, per<b>dón</b>, los he bo<b>rra</b>do en vez de impri<b>mir</b>los!',
#  'S04-<b>Va</b>ya, pues <b>me</b>nos mal que los <b>ten</b>go en el co<b>rre</b>o. ¿Me da un e<b>qui</b>po <b>pa</b>ra que los recu<b>pe</b>re?',
#  'S05-Si, <b>pón</b>gase en el 4.',
#  'S06-<b>Oi</b>ga, el ordena<b>dor</b> no se en<b>cien</b>de.',
#  'S07-¿Ah? <b>Co</b>ja el 6.',
#  'S08-Y el te<b>cla</b>do de <b>es</b>te no fun<b>cio</b>na.',
#  'S09-Qué <b>ra</b>ro, <b>va</b>ya al e<b>qui</b>po 8.',
#  'S10-<b>Mi</b>re, ya es<b>tá</b> bien, de<b>vuél</b>vame el pen y me voy.',
#  'S11-<b>Co</b>mo us<b>ted</b> <b>quie</b>ra, son dos con cin<b>cuen</b>ta.',
#  'S12-¿Y en<b>ci</b>ma <b>quie</b>re co<b>brar</b>? ¡<b>Pe</b>ro qué <b>ca</b>ra <b>du</b>ra!',
#  'S13-No se <b>pon</b>ga ner<b>vio</b>so. ¡Es <b>pa</b>ra la <b>cá</b>mara o<b>cul</b>ta!',
#  'T00-TRANSLATE-Ejer<b>ci</b>cio 1 – Tra<b>duz</b>ca',
#  'T01-<b>Me</b>nos mal que <b>ten</b>go tam<b>bién</b> los ar<b>chi</b>vos en el pen.',
#  'T02-<b>U</b>na vez impri<b>mi</b>da, ¿<b>pue</b>do bo<b>rrar</b> la car<b>pe</b>ta?',
#  'T03-Qué <b>ra</b>ro, el te<b>cla</b>do no fun<b>cio</b>na.',
#  'T04-<b>Es</b>te ordena<b>dor</b> no se en<b>cien</b>de <b>pón</b>gase en <b>o</b>tro e<b>qui</b>po.',
#  'T05-No te <b>pon</b>gas ner<b>vio</b>so, co<b>noz</b>co <b>o</b>tro <b>cí</b>ber me<b>jor</b> que <b>es</b>te.']

# %%
errors[lesson_nb]
# Out:
# {0: 'N45-Lec<b>ción</b> cua<b>r</b><mark><b>en</b>ta y <b>cin</b>co </mark>',
#  1: '<mark> S00-TITLE-En el <b>cí</b>b</mark>er',
#  5: 'S04-<b>Va</b>ya, pues <b>me</b>nos mal que los <b>ten</b>go en el co<b>rre</b>o. ¿Me da un e<b>qui</b>po <b>pa</b>ra que los <mark>recu<b>pe</b>re</mark>?',
#  6: 'S05-Si, <b></b><mark><b>pón</b>gase</mark> en el 4.',
#  8: 'S07-¿Ah? <b></b><mark><b>Co</b>ja</mark> el 6.'}

# %%
lesson = ""
for k, sentence in enumerate(sentences):
    if k in errors[lesson_nb]:
        lesson += "<p>" + errors[lesson_nb][k] + "</p>"
    else:
        lesson += "<p>" + sentences[k] + "</p>"

# %%
lesson
# Out:
# '<p>N45-Lec<b>ción</b> cua<b>r</b><mark><b>en</b>ta y <b>cin</b>co </mark></p><p><mark> S00-TITLE-En el <b>cí</b>b</mark>er</p><p>S01-Los ar<b>chi</b>vos es<b>tán</b> en la car<b>pe</b>ta <b>fo</b>tos.</p><p>S02-Sí, los <b>ve</b>o, se los im<b>pri</b>mo ense<b>gui</b>da.</p><p>S03-¡Oh, per<b>dón</b>, los he bo<b>rra</b>do en vez de impri<b>mir</b>los!</p><p>S04-<b>Va</b>ya, pues <b>me</b>nos mal que los <b>ten</b>go en el co<b>rre</b>o. ¿Me da un e<b>qui</b>po <b>pa</b>ra que los <mark>recu<b>pe</b>re</mark>?</p><p>S05-Si, <b></b><mark><b>pón</b>gase</mark> en el 4.</p><p>S06-<b>Oi</b>ga, el ordena<b>dor</b> no se en<b>cien</b>de.</p><p>S07-¿Ah? <b></b><mark><b>Co</b>ja</mark> el 6.</p><p>S08-Y el te<b>cla</b>do de <b>es</b>te no fun<b>cio</b>na.</p><p>S09-Qué <b>ra</b>ro, <b>va</b>ya al e<b>qui</b>po 8.</p><p>S10-<b>Mi</b>re, ya es<b>tá</b> bien, de<b>vuél</b>vame el pen y me voy.</p><p>S11-<b>Co</b>mo us<b>ted</b> <b>quie</b>ra, son dos con cin<b>cuen</b>ta.</p><p>S12-¿Y en<b>ci</b>ma <b>quie</b>re co<b>brar</b>? ¡<b>Pe</b>ro qué <b>ca</b>ra <b>du</b>ra!</p><p>S13-No se <b>pon</b>ga ner<b>vio</b>so. ¡Es <b>pa</b>ra la <b>cá</b>mara o<b>cul</b>ta!</p><p>T00-TRANSLATE-Ejer<b>ci</b>cio 1 – Tra<b>duz</b>ca</p><p>T01-<b>Me</b>nos mal que <b>ten</b>go tam<b>bién</b> los ar<b>chi</b>vos en el pen.</p><p>T02-<b>U</b>na vez impri<b>mi</b>da, ¿<b>pue</b>do bo<b>rrar</b> la car<b>pe</b>ta?</p><p>T03-Qué <b>ra</b>ro, el te<b>cla</b>do no fun<b>cio</b>na.</p><p>T04-<b>Es</b>te ordena<b>dor</b> no se en<b>cien</b>de <b>pón</b>gase en <b>o</b>tro e<b>qui</b>po.</p><p>T05-No te <b>pon</b>gas ner<b>vio</b>so, co<b>noz</b>co <b>o</b>tro <b>cí</b>ber me<b>jor</b> que <b>es</b>te.</p>'

# %%
errors[5]
# Out:
# {datetime.datetime(2024, 8, 30, 18, 12, 5, 788656): {0: 'N5-Lec<b>ción</b> <b>q</b><mark><b>uin</b>ta </mark>',
#   1: '<mark> S00-TITLE-Entr</mark>e<b>vis</b>ta de tra<b>ba</b>jo',
#   4: 'S03-¡Enhor<mark>a<b>bue</b>na! ¿Ha<b>bla</b>mos in<b>glés</b> en<b>ton</b>ces?  </mark>',
#   5: '<mark> S04-E<b>jem</b>, el in<b>glés</b> lo </mark><b>le</b>o, <b>pe</b>ro no lo <b>ha</b>blo muy bien.',
#   9: 'T02-¿<b>Cuá</b>ntos i<b></b><mark><b>dio</b>mas es<b>cri</b>be us<b>ted</b>?  </mark>',
#   10: '<mark> T03-No <b>ha</b>blo fran<b>cés</b>.  </mark>',
#   11: '<mark></mark>'}}

# %%
lesson
# Out:
# {12: 'T05-¿<b>Có</b>mo es<b>tá</b> us<b>ted</b>?'}

# %%
sentences[7]
# Out:
# 'T00-TRANSLATE-Ejer<b>ci</b>cio 1 – Tra<b>duz</b>ca'

# %%
engine
# Out:
# Engine(sqlite:///db/testassimildb.db)

# %%
import datetime
begin_date = datetime.datetime.min
end_date = datetime.datetime.max
stmt = select(MarkedSentence).where(
                    and_(
                        MarkedSentence.date_time > begin_date,
                        MarkedSentence.date_time < end_date),
                        MarkedSentence.lesson == 5
                    )

with Session(engine) as session:
    for marked_line in session.scalars(stmt):
        print(marked_line)
# Out:
# Sentence(id=8, date_time = datetime.datetime(2024, 8, 28, 13, 18, 25, 206141), lesson=5, line=2, sentence ='S01-¿<b>Cu</b><mark><b>á</b>ntos i<b>dio</b>mas <b>ha</b>bla us<b>ted</b>?  </mark>', comment=None)
# Sentence(id=9, date_time = datetime.datetime(2024, 8, 28, 13, 18, 25, 206358), lesson=5, line=3, sentence ='<mark> S02-<b>Ha</b>blo in<b>glés</b> y fra</mark>n<b>cés</b>.', comment=None)
# Sentence(id=10, date_time = datetime.datetime(2024, 8, 28, 13, 18, 25, 206400), lesson=5, line=4, sentence ='S03-¡<mark>Enhora<b>bue</b>na! ¿Ha<b>bla</b>mos in<b>glés</b> en<b>ton</b>ces?  </mark>', comment=None)
# Sentence(id=11, date_time = datetime.datetime(2024, 8, 28, 13, 18, 25, 206431), lesson=5, line=5, sentence ='<mark> S04-E<b>jem</b>, el in<b>glés</b> lo <b>le</b>o, <b>pe</b>ro no lo <b>ha</b>blo muy bien.  </mark>', comment=None)
# Sentence(id=12, date_time = datetime.datetime(2024, 8, 28, 13, 18, 25, 206461), lesson=5, line=6, sentence ='<mark> S05-Sí, <b>cla</b>ro</mark> Y el fran<b>cés</b>, ¿lo <b>ha</b>bla o <b>so</b>lo lo es<b>cri</b>be?', comment=None)
# Sentence(id=13, date_time = datetime.datetime(2024, 8, 28, 13, 18, 25, 206490), lesson=5, line=8, sentence ='T01-¿<b>H</b><mark><b>a</b>bla us<b>ted</b> in<b>glés</b>?  </mark>', comment=None)
# Sentence(id=14, date_time = datetime.datetime(2024, 8, 28, 13, 18, 25, 206522), lesson=5, line=9, sentence ='<mark> T02-¿<b>Cuá</b>ntos i<b>dio</b>mas es<b>cri</b>be us<b>te</b></mark><b>d</b>?', comment=None)

# %%
get_html_sentences(4)[1]
# Out:
# ---------------------------------------------------------------------------
# IndexError                                Traceback (most recent call last)
# Cell In[9], line 1
# ----> 1 get_html_sentences(4)[1]
#
# IndexError: list index out of range

# %%
from selection import get_html_sentences

# %%
get_html_sentences
# Out:
# <function selection.get_html_sentences(lesson)>

# %%
get_html_sentences(lesson)
# Out:
# ['N4-Lec<b>ción</b> <b>cua</b>rta',
#  'S00-TITLE-Presenta<b>cio</b>nes',
#  'S01-Él es <b>Ra</b>fa, mi her<b>ma</b>no, y <b>e</b>lla es Luz, mi her<b>ma</b>na.',
#  'S02-Y él es mi <b>pa</b>dre, Mi<b>guel</b>.',
#  'S03-<b>Mu</b>cho <b>gus</b>to. ¿<b>Có</b>mo es<b>tá</b> us<b>ted</b>?',
#  'S04-Muy bien, <b>pe</b>ro ¡<b>há</b>blame de tú, por fa<b>vor</b>!',
#  'S05-¡<b>Va</b>le!',
#  'T00-TRANSLATE-Ejer<b>ci</b>cio 1 – Tra<b>duz</b>ca',
#  'T01-Él es mi <b>pa</b>dre.',
#  'T02-Y <b>e</b>lla es mi her<b>ma</b>na.',
#  'T03-<b>Mu</b>cho <b>gus</b>to.',
#  'T04-<b>Há</b>blame de tú, por fa<b>vor</b>.',
#  'T05-¿<b>Có</b>mo es<b>tá</b> us<b>ted</b>?']

# %%
from tonic_accent import get_html_sentences

# %%
get_html_sentences(4)
# Out:
# ['N4-Lec<b>ción</b> <b>cua</b>rta',
#  'S00-TITLE-Presenta<b>cio</b>nes',
#  'S01-Él es <b>Ra</b>fa, mi her<b>ma</b>no, y <b>e</b>lla es Luz, mi her<b>ma</b>na.',
#  'S02-Y él es mi <b>pa</b>dre, Mi<b>guel</b>.',
#  'S03-<b>Mu</b>cho <b>gus</b>to. ¿<b>Có</b>mo es<b>tá</b> us<b>ted</b>?',
#  'S04-Muy bien, <b>pe</b>ro ¡<b>há</b>blame de tú, por fa<b>vor</b>!',
#  'S05-¡<b>Va</b>le!',
#  'T00-TRANSLATE-Ejer<b>ci</b>cio 1 – Tra<b>duz</b>ca',
#  'T01-Él es mi <b>pa</b>dre.',
#  'T02-Y <b>e</b>lla es mi her<b>ma</b>na.',
#  'T03-<b>Mu</b>cho <b>gus</b>to.',
#  'T04-<b>Há</b>blame de tú, por fa<b>vor</b>.',
#  'T05-¿<b>Có</b>mo es<b>tá</b> us<b>ted</b>?']

# %%
stmt = select(MarkedSentence)
with Session(engine) as session:
    for marked_line in session.scalars(stmt):
        print(marked_line)
# Out:
# Sentence(id=1, date_time = datetime.datetime(2024, 8, 28, 13, 18, 23, 37151), lesson=4, line=1, sentence ='S00-TITLE-Prese<mark>nta<b>cio</b>n</mark>es', comment=None)
# Sentence(id=2, date_time = datetime.datetime(2024, 8, 28, 13, 18, 23, 37552), lesson=4, line=2, sentence ='S01-Él es <b>Ra</b>fa, <mark>mi her<b>ma</b>no, y <b>e</b>lla es Luz, mi her<b>ma</b>na.  </mark>', comment=None)
# Sentence(id=3, date_time = datetime.datetime(2024, 8, 28, 13, 18, 23, 37586), lesson=4, line=3, sentence ='<mark> S02-Y él es mi <b>pa</b>dre, </mark>Mi<b>guel</b>.', comment=None)
# Sentence(id=4, date_time = datetime.datetime(2024, 8, 28, 13, 18, 23, 37610), lesson=4, line=5, sentence ='S04-Muy bien, <b>pe</b>ro ¡<b>h</b><mark><b>á</b>blame d</mark>e tú, por fa<b>vor</b>!', comment=None)
# Sentence(id=5, date_time = datetime.datetime(2024, 8, 28, 13, 18, 23, 37635), lesson=4, line=7, sentence ='T00-TRANSLA<mark>TE-Ejer<b>ci</b>cio </mark>1 – Tra<b>duz</b>ca', comment=None)
# Sentence(id=6, date_time = datetime.datetime(2024, 8, 28, 13, 18, 23, 37657), lesson=4, line=10, sentence ='T03-<b>Mu</b>cho <b></b><mark><b>gus</b>to.  </mark>', comment=None)
# Sentence(id=7, date_time = datetime.datetime(2024, 8, 28, 13, 18, 23, 37678), lesson=4, line=11, sentence ='<mark> T04-<b>Há</b>blame de </mark>tú, por fa<b>vor</b>.', comment=None)
# Sentence(id=8, date_time = datetime.datetime(2024, 8, 28, 13, 18, 25, 206141), lesson=5, line=2, sentence ='S01-¿<b>Cu</b><mark><b>á</b>ntos i<b>dio</b>mas <b>ha</b>bla us<b>ted</b>?  </mark>', comment=None)
# Sentence(id=9, date_time = datetime.datetime(2024, 8, 28, 13, 18, 25, 206358), lesson=5, line=3, sentence ='<mark> S02-<b>Ha</b>blo in<b>glés</b> y fra</mark>n<b>cés</b>.', comment=None)
# Sentence(id=10, date_time = datetime.datetime(2024, 8, 28, 13, 18, 25, 206400), lesson=5, line=4, sentence ='S03-¡<mark>Enhora<b>bue</b>na! ¿Ha<b>bla</b>mos in<b>glés</b> en<b>ton</b>ces?  </mark>', comment=None)
# Sentence(id=11, date_time = datetime.datetime(2024, 8, 28, 13, 18, 25, 206431), lesson=5, line=5, sentence ='<mark> S04-E<b>jem</b>, el in<b>glés</b> lo <b>le</b>o, <b>pe</b>ro no lo <b>ha</b>blo muy bien.  </mark>', comment=None)
# Sentence(id=12, date_time = datetime.datetime(2024, 8, 28, 13, 18, 25, 206461), lesson=5, line=6, sentence ='<mark> S05-Sí, <b>cla</b>ro</mark> Y el fran<b>cés</b>, ¿lo <b>ha</b>bla o <b>so</b>lo lo es<b>cri</b>be?', comment=None)
# Sentence(id=13, date_time = datetime.datetime(2024, 8, 28, 13, 18, 25, 206490), lesson=5, line=8, sentence ='T01-¿<b>H</b><mark><b>a</b>bla us<b>ted</b> in<b>glés</b>?  </mark>', comment=None)
# Sentence(id=14, date_time = datetime.datetime(2024, 8, 28, 13, 18, 25, 206522), lesson=5, line=9, sentence ='<mark> T02-¿<b>Cuá</b>ntos i<b>dio</b>mas es<b>cri</b>be us<b>te</b></mark><b>d</b>?', comment=None)
# Sentence(id=15, date_time = datetime.datetime(2024, 8, 28, 13, 18, 26, 715843), lesson=6, line=3, sentence ='S02-Soy enfer<b>m</b><mark><b>e</b>ra, tra<b>ba</b>jo en el hospi<b>ta</b></mark><b>l</b>.', comment=None)
# Sentence(id=16, date_time = datetime.datetime(2024, 8, 28, 13, 18, 26, 716014), lesson=6, line=8, sentence ='ST00-TRANSLATE-Ejer<b>ci</b>cio 1 – Tra<b>d<mark>u</mark>z</b>ca', comment=None)
# Sentence(id=17, date_time = datetime.datetime(2024, 8, 28, 13, 18, 26, 716048), lesson=6, line=9, sentence ='ST01-¿<b>E</b>res <mark>enfer<b>me</b>ra?  </mark>', comment=None)
# Sentence(id=18, date_time = datetime.datetime(2024, 8, 28, 13, 18, 26, 716079), lesson=6, line=10, sentence ='<mark> ST02-¿Tra<b>ba</b>jas en el hospi<b>tal</b>?  </mark>', comment=None)
# Sentence(id=19, date_time = datetime.datetime(2024, 8, 28, 13, 18, 26, 716108), lesson=6, line=11, sentence ='<mark> ST03-No, tra<b>ba</b>jo en e</mark>l <b>ci</b>ne.', comment=None)
# Sentence(id=20, date_time = datetime.datetime(2024, 8, 28, 16, 18, 49, 95007), lesson=45, line=2, sentence ='S01-Los ar<b>chi</b>vos es<b>tán</b> <mark>en la car<b>pe</b>ta <b>fo</b>tos.  </mark>', comment=None)
# Sentence(id=21, date_time = datetime.datetime(2024, 8, 28, 16, 18, 49, 110628), lesson=45, line=3, sentence ='<mark> S02-Sí, los <b>ve</b>o, se los im</mark><b>pri</b>mo ense<b>gui</b>da.', comment=None)
# Sentence(id=22, date_time = datetime.datetime(2024, 8, 28, 16, 18, 49, 110752), lesson=45, line=5, sentence ='S04-<b>Va</b>ya,<mark> pues <b>me</b>nos mal que los <b>ten</b>go en el co<b>rre</b>o. ¿Me da un e<b>qui</b>po <b>pa</b>ra que los</mark> recu<b>pe</b>re?', comment=None)
# Sentence(id=23, date_time = datetime.datetime(2024, 8, 28, 16, 18, 49, 110803), lesson=45, line=6, sentence ='S05-Si, <b></b><mark><b>pón</b>gase en el 4.  </mark>', comment=None)
# Sentence(id=24, date_time = datetime.datetime(2024, 8, 28, 16, 18, 49, 110863), lesson=45, line=7, sentence ='<mark> S06-<b>Oi</b>ga, el </mark>ordena<b>dor</b> no se en<b>cien</b>de.', comment=None)
# Sentence(id=25, date_time = datetime.datetime(2024, 8, 28, 16, 18, 49, 110901), lesson=45, line=11, sentence ='S10-<b>Mi</b>re, ya es<b>tá</b> bien, <mark>de<b>vuél</b>vame el pe</mark>n y me voy.', comment=None)
# Sentence(id=26, date_time = datetime.datetime(2024, 8, 28, 16, 18, 49, 110938), lesson=45, line=16, sentence ='T01-<b>Me</b>nos mal que <b></b><mark><b>ten</b>go tam<b>bién</b> los ar<b>chi</b>vos en el pen.  </mark>', comment=None)
# Sentence(id=27, date_time = datetime.datetime(2024, 8, 28, 16, 18, 49, 110972), lesson=45, line=17, sentence ='<mark> T02-<b>U</b>na vez impri<b>mi</b>da, ¿<b>pue</b>d</mark>o bo<b>rrar</b> la car<b>pe</b>ta?', comment=None)
# Sentence(id=28, date_time = datetime.datetime(2024, 8, 30, 13, 42, 42, 798321), lesson=4, line=4, sentence ='S03-<b>Mu</b>c<mark>ho <b>gus</b>to. ¿<b>Có</b>mo es<b>tá</b> us<b>ted</b>?  </mark>', comment=None)
# Sentence(id=29, date_time = datetime.datetime(2024, 8, 30, 13, 42, 42, 798321), lesson=4, line=5, sentence ='<mark> S04-Muy bien, <b>pe</b>ro</mark> ¡<b>há</b>blame de tú, por fa<b>vor</b>!', comment=None)
# Sentence(id=30, date_time = datetime.datetime(2024, 8, 30, 13, 42, 50, 930373), lesson=4, line=4, sentence ='S03-<b>Mu</b>c<mark>ho <b>gus</b>to. ¿<b>Có</b>mo es<b>tá</b> us<b>ted</b>?  </mark>', comment=None)
# Sentence(id=31, date_time = datetime.datetime(2024, 8, 30, 13, 42, 50, 930373), lesson=4, line=5, sentence ='<mark> S04-Muy bien, <b>pe</b>ro</mark> ¡<b>há</b>blame de tú, por fa<b>vor</b>!', comment=None)
# Sentence(id=32, date_time = datetime.datetime(2024, 8, 30, 13, 42, 50, 930373), lesson=4, line=10, sentence ='T03-<b>Mu</b>cho <b></b><mark><b>gus</b>to.  </mark>', comment=None)
# Sentence(id=33, date_time = datetime.datetime(2024, 8, 30, 13, 42, 50, 930373), lesson=4, line=11, sentence ='<mark> T04-<b>Há</b>blame de tú, po</mark>r fa<b>vor</b>.', comment=None)
# Sentence(id=34, date_time = datetime.datetime(2024, 8, 30, 13, 51, 56, 298313), lesson=5, line=3, sentence ='S02-<b>Ha</b>blo <mark>in<b>glés</b> y fran<b>cés</b></mark><b></b>.', comment=None)
# Sentence(id=35, date_time = datetime.datetime(2024, 8, 30, 13, 52, 14, 464741), lesson=5, line=3, sentence ='S02-<b>Ha</b>blo <mark>in<b>glés</b> y fran<b>cés</b></mark><b></b>.', comment=None)
# Sentence(id=36, date_time = datetime.datetime(2024, 8, 30, 13, 52, 14, 464741), lesson=5, line=4, sentence ='S03-¡Enhora<b>bue</b>na! ¿<mark>Ha<b>bla</b>mos in<b>glés</b> en<b>ton</b>ces</mark>?', comment=None)
# Sentence(id=37, date_time = datetime.datetime(2024, 8, 30, 13, 52, 22, 896627), lesson=5, line=3, sentence ='S02-<b>Ha</b>blo <mark>in<b>glés</b> y fran<b>cés</b></mark><b></b>.', comment=None)
# Sentence(id=38, date_time = datetime.datetime(2024, 8, 30, 13, 52, 22, 896627), lesson=5, line=4, sentence ='S03-¡Enhora<b>bue</b>na! ¿<mark>Ha<b>bla</b>mos in<b>glés</b> en<b>ton</b>ces</mark>?', comment=None)
# Sentence(id=39, date_time = datetime.datetime(2024, 8, 30, 13, 52, 22, 896627), lesson=5, line=10, sentence ='T03-No <b>ha</b>blo <mark>fran<b>cés</b></mark><b></b>.', comment=None)

# %%
from database import get_lessons_errors
# Out:
# 2024-08-30 18:54:45,508 INFO sqlalchemy.engine.Engine BEGIN (implicit)
# 2024-08-30 18:54:45,509 INFO sqlalchemy.engine.Engine PRAGMA main.table_info("word_dict")
# 2024-08-30 18:54:45,509 INFO sqlalchemy.engine.Engine [raw sql] ()
# 2024-08-30 18:54:45,509 INFO sqlalchemy.engine.Engine PRAGMA main.table_info("word_index")
# 2024-08-30 18:54:45,510 INFO sqlalchemy.engine.Engine [raw sql] ()
# 2024-08-30 18:54:45,510 INFO sqlalchemy.engine.Engine PRAGMA main.table_info("sentences")
# 2024-08-30 18:54:45,510 INFO sqlalchemy.engine.Engine [raw sql] ()
# 2024-08-30 18:54:45,510 INFO sqlalchemy.engine.Engine PRAGMA main.table_info("marked_sentences")
# 2024-08-30 18:54:45,510 INFO sqlalchemy.engine.Engine [raw sql] ()
# 2024-08-30 18:54:45,511 INFO sqlalchemy.engine.Engine COMMIT

# %%
errors = get_lessons_errors()
# Out:
# 2024-08-30 18:55:54,510 INFO sqlalchemy.engine.Engine BEGIN (implicit)
# 2024-08-30 18:55:54,512 INFO sqlalchemy.engine.Engine SELECT marked_sentences.id, marked_sentences.date_time, marked_sentences.sentence, marked_sentences.comment, marked_sentences.lesson, marked_sentences.line
# FROM marked_sentences
# WHERE marked_sentences.date_time > ? AND marked_sentences.date_time < ? AND marked_sentences.lesson = ?
# 2024-08-30 18:55:54,512 INFO sqlalchemy.engine.Engine [cached since 16.25s ago] ('0001-01-01 00:00:00.000000', '9999-12-31 23:59:59.999999', 1)
# 2024-08-30 18:55:54,513 INFO sqlalchemy.engine.Engine ROLLBACK
# 2024-08-30 18:55:54,514 INFO sqlalchemy.engine.Engine BEGIN (implicit)
# 2024-08-30 18:55:54,515 INFO sqlalchemy.engine.Engine SELECT marked_sentences.id, marked_sentences.date_time, marked_sentences.sentence, marked_sentences.comment, marked_sentences.lesson, marked_sentences.line
# FROM marked_sentences
# WHERE marked_sentences.date_time > ? AND marked_sentences.date_time < ? AND marked_sentences.lesson = ?
# 2024-08-30 18:55:54,516 INFO sqlalchemy.engine.Engine [cached since 16.26s ago] ('0001-01-01 00:00:00.000000', '9999-12-31 23:59:59.999999', 2)
# 2024-08-30 18:55:54,517 INFO sqlalchemy.engine.Engine ROLLBACK
# 2024-08-30 18:55:54,518 INFO sqlalchemy.engine.Engine BEGIN (implicit)
# 2024-08-30 18:55:54,519 INFO sqlalchemy.engine.Engine SELECT marked_sentences.id, marked_sentences.date_time, marked_sentences.sentence, marked_sentences.comment, marked_sentences.lesson, marked_sentences.line
# FROM marked_sentences
# WHERE marked_sentences.date_time > ? AND marked_sentences.date_time < ? AND marked_sentences.lesson = ?
# 2024-08-30 18:55:54,520 INFO sqlalchemy.engine.Engine [cached since 16.26s ago] ('0001-01-01 00:00:00.000000', '9999-12-31 23:59:59.999999', 3)
# 2024-08-30 18:55:54,521 INFO sqlalchemy.engine.Engine ROLLBACK
# 2024-08-30 18:55:54,522 INFO sqlalchemy.engine.Engine BEGIN (implicit)
# 2024-08-30 18:55:54,523 INFO sqlalchemy.engine.Engine SELECT marked_sentences.id, marked_sentences.date_time, marked_sentences.sentence, marked_sentences.comment, marked_sentences.lesson, marked_sentences.line
# FROM marked_sentences
# WHERE marked_sentences.date_time > ? AND marked_sentences.date_time < ? AND marked_sentences.lesson = ?
# 2024-08-30 18:55:54,523 INFO sqlalchemy.engine.Engine [cached since 16.26s ago] ('0001-01-01 00:00:00.000000', '9999-12-31 23:59:59.999999', 4)
# 2024-08-30 18:55:54,525 INFO sqlalchemy.engine.Engine ROLLBACK
# 2024-08-30 18:55:54,526 INFO sqlalchemy.engine.Engine BEGIN (implicit)
# 2024-08-30 18:55:54,527 INFO sqlalchemy.engine.Engine SELECT marked_sentences.id, marked_sentences.date_time, marked_sentences.sentence, marked_sentences.comment, marked_sentences.lesson, marked_sentences.line
# FROM marked_sentences
# WHERE marked_sentences.date_time > ? AND marked_sentences.date_time < ? AND marked_sentences.lesson = ?
# 2024-08-30 18:55:54,527 INFO sqlalchemy.engine.Engine [cached since 16.27s ago] ('0001-01-01 00:00:00.000000', '9999-12-31 23:59:59.999999', 5)
# 2024-08-30 18:55:54,528 INFO sqlalchemy.engine.Engine ROLLBACK
# 2024-08-30 18:55:54,529 INFO sqlalchemy.engine.Engine BEGIN (implicit)
# 2024-08-30 18:55:54,530 INFO sqlalchemy.engine.Engine SELECT marked_sentences.id, marked_sentences.date_time, marked_sentences.sentence, marked_sentences.comment, marked_sentences.lesson, marked_sentences.line
# FROM marked_sentences
# WHERE marked_sentences.date_time > ? AND marked_sentences.date_time < ? AND marked_sentences.lesson = ?
# 2024-08-30 18:55:54,531 INFO sqlalchemy.engine.Engine [cached since 16.27s ago] ('0001-01-01 00:00:00.000000', '9999-12-31 23:59:59.999999', 6)
# 2024-08-30 18:55:54,532 INFO sqlalchemy.engine.Engine ROLLBACK
# 2024-08-30 18:55:54,533 INFO sqlalchemy.engine.Engine BEGIN (implicit)
# 2024-08-30 18:55:54,534 INFO sqlalchemy.engine.Engine SELECT marked_sentences.id, marked_sentences.date_time, marked_sentences.sentence, marked_sentences.comment, marked_sentences.lesson, marked_sentences.line
# FROM marked_sentences
# WHERE marked_sentences.date_time > ? AND marked_sentences.date_time < ? AND marked_sentences.lesson = ?
# 2024-08-30 18:55:54,534 INFO sqlalchemy.engine.Engine [cached since 16.27s ago] ('0001-01-01 00:00:00.000000', '9999-12-31 23:59:59.999999', 7)
# 2024-08-30 18:55:54,535 INFO sqlalchemy.engine.Engine ROLLBACK
# 2024-08-30 18:55:54,536 INFO sqlalchemy.engine.Engine BEGIN (implicit)
# 2024-08-30 18:55:54,536 INFO sqlalchemy.engine.Engine SELECT marked_sentences.id, marked_sentences.date_time, marked_sentences.sentence, marked_sentences.comment, marked_sentences.lesson, marked_sentences.line
# FROM marked_sentences
# WHERE marked_sentences.date_time > ? AND marked_sentences.date_time < ? AND marked_sentences.lesson = ?
# 2024-08-30 18:55:54,537 INFO sqlalchemy.engine.Engine [cached since 16.28s ago] ('0001-01-01 00:00:00.000000', '9999-12-31 23:59:59.999999', 8)
# 2024-08-30 18:55:54,537 INFO sqlalchemy.engine.Engine ROLLBACK
# 2024-08-30 18:55:54,538 INFO sqlalchemy.engine.Engine BEGIN (implicit)
# 2024-08-30 18:55:54,539 INFO sqlalchemy.engine.Engine SELECT marked_sentences.id, marked_sentences.date_time, marked_sentences.sentence, marked_sentences.comment, marked_sentences.lesson, marked_sentences.line
# FROM marked_sentences
# WHERE marked_sentences.date_time > ? AND marked_sentences.date_time < ? AND marked_sentences.lesson = ?
# 2024-08-30 18:55:54,539 INFO sqlalchemy.engine.Engine [cached since 16.28s ago] ('0001-01-01 00:00:00.000000', '9999-12-31 23:59:59.999999', 9)
# 2024-08-30 18:55:54,540 INFO sqlalchemy.engine.Engine ROLLBACK
# 2024-08-30 18:55:54,541 INFO sqlalchemy.engine.Engine BEGIN (implicit)
# 2024-08-30 18:55:54,541 INFO sqlalchemy.engine.Engine SELECT marked_sentences.id, marked_sentences.date_time, marked_sentences.sentence, marked_sentences.comment, marked_sentences.lesson, marked_sentences.line
# FROM marked_sentences
# WHERE marked_sentences.date_time > ? AND marked_sentences.date_time < ? AND marked_sentences.lesson = ?
# 2024-08-30 18:55:54,542 INFO sqlalchemy.engine.Engine [cached since 16.28s ago] ('0001-01-01 00:00:00.000000', '9999-12-31 23:59:59.999999', 10)
# 2024-08-30 18:55:54,542 INFO sqlalchemy.engine.Engine ROLLBACK
# 2024-08-30 18:55:54,543 INFO sqlalchemy.engine.Engine BEGIN (implicit)
# 2024-08-30 18:55:54,543 INFO sqlalchemy.engine.Engine SELECT marked_sentences.id, marked_sentences.date_time, marked_sentences.sentence, marked_sentences.comment, marked_sentences.lesson, marked_sentences.line
# FROM marked_sentences
# WHERE marked_sentences.date_time > ? AND marked_sentences.date_time < ? AND marked_sentences.lesson = ?
# 2024-08-30 18:55:54,543 INFO sqlalchemy.engine.Engine [cached since 16.28s ago] ('0001-01-01 00:00:00.000000', '9999-12-31 23:59:59.999999', 11)
# 2024-08-30 18:55:54,544 INFO sqlalchemy.engine.Engine ROLLBACK
# 2024-08-30 18:55:54,545 INFO sqlalchemy.engine.Engine BEGIN (implicit)
# 2024-08-30 18:55:54,545 INFO sqlalchemy.engine.Engine SELECT marked_sentences.id, marked_sentences.date_time, marked_sentences.sentence, marked_sentences.comment, marked_sentences.lesson, marked_sentences.line
# FROM marked_sentences
# WHERE marked_sentences.date_time > ? AND marked_sentences.date_time < ? AND marked_sentences.lesson = ?
# 2024-08-30 18:55:54,546 INFO sqlalchemy.engine.Engine [cached since 16.29s ago] ('0001-01-01 00:00:00.000000', '9999-12-31 23:59:59.999999', 12)
# 2024-08-30 18:55:54,546 INFO sqlalchemy.engine.Engine ROLLBACK
# 2024-08-30 18:55:54,547 INFO sqlalchemy.engine.Engine BEGIN (implicit)
# 2024-08-30 18:55:54,547 INFO sqlalchemy.engine.Engine SELECT marked_sentences.id, marked_sentences.date_time, marked_sentences.sentence, marked_sentences.comment, marked_sentences.lesson, marked_sentences.line
# FROM marked_sentences
# WHERE marked_sentences.date_time > ? AND marked_sentences.date_time < ? AND marked_sentences.lesson = ?
# 2024-08-30 18:55:54,548 INFO sqlalchemy.engine.Engine [cached since 16.29s ago] ('0001-01-01 00:00:00.000000', '9999-12-31 23:59:59.999999', 13)
# 2024-08-30 18:55:54,548 INFO sqlalchemy.engine.Engine ROLLBACK
# 2024-08-30 18:55:54,548 INFO sqlalchemy.engine.Engine BEGIN (implicit)
# 2024-08-30 18:55:54,549 INFO sqlalchemy.engine.Engine SELECT marked_sentences.id, marked_sentences.date_time, marked_sentences.sentence, marked_sentences.comment, marked_sentences.lesson, marked_sentences.line
# FROM marked_sentences
# WHERE marked_sentences.date_time > ? AND marked_sentences.date_time < ? AND marked_sentences.lesson = ?
# 2024-08-30 18:55:54,549 INFO sqlalchemy.engine.Engine [cached since 16.29s ago] ('0001-01-01 00:00:00.000000', '9999-12-31 23:59:59.999999', 14)
# 2024-08-30 18:55:54,550 INFO sqlalchemy.engine.Engine ROLLBACK
# 2024-08-30 18:55:54,550 INFO sqlalchemy.engine.Engine BEGIN (implicit)
# 2024-08-30 18:55:54,551 INFO sqlalchemy.engine.Engine SELECT marked_sentences.id, marked_sentences.date_time, marked_sentences.sentence, marked_sentences.comment, marked_sentences.lesson, marked_sentences.line
# FROM marked_sentences
# WHERE marked_sentences.date_time > ? AND marked_sentences.date_time < ? AND marked_sentences.lesson = ?
# 2024-08-30 18:55:54,551 INFO sqlalchemy.engine.Engine [cached since 16.29s ago] ('0001-01-01 00:00:00.000000', '9999-12-31 23:59:59.999999', 15)
# 2024-08-30 18:55:54,552 INFO sqlalchemy.engine.Engine ROLLBACK
# 2024-08-30 18:55:54,553 INFO sqlalchemy.engine.Engine BEGIN (implicit)
# 2024-08-30 18:55:54,554 INFO sqlalchemy.engine.Engine SELECT marked_sentences.id, marked_sentences.date_time, marked_sentences.sentence, marked_sentences.comment, marked_sentences.lesson, marked_sentences.line
# FROM marked_sentences
# WHERE marked_sentences.date_time > ? AND marked_sentences.date_time < ? AND marked_sentences.lesson = ?
# 2024-08-30 18:55:54,554 INFO sqlalchemy.engine.Engine [cached since 16.29s ago] ('0001-01-01 00:00:00.000000', '9999-12-31 23:59:59.999999', 16)
# 2024-08-30 18:55:54,554 INFO sqlalchemy.engine.Engine ROLLBACK
# 2024-08-30 18:55:54,555 INFO sqlalchemy.engine.Engine BEGIN (implicit)
# 2024-08-30 18:55:54,556 INFO sqlalchemy.engine.Engine SELECT marked_sentences.id, marked_sentences.date_time, marked_sentences.sentence, marked_sentences.comment, marked_sentences.lesson, marked_sentences.line
# FROM marked_sentences
# WHERE marked_sentences.date_time > ? AND marked_sentences.date_time < ? AND marked_sentences.lesson = ?
# 2024-08-30 18:55:54,556 INFO sqlalchemy.engine.Engine [cached since 16.3s ago] ('0001-01-01 00:00:00.000000', '9999-12-31 23:59:59.999999', 17)
# 2024-08-30 18:55:54,557 INFO sqlalchemy.engine.Engine ROLLBACK
# 2024-08-30 18:55:54,558 INFO sqlalchemy.engine.Engine BEGIN (implicit)
# 2024-08-30 18:55:54,558 INFO sqlalchemy.engine.Engine SELECT marked_sentences.id, marked_sentences.date_time, marked_sentences.sentence, marked_sentences.comment, marked_sentences.lesson, marked_sentences.line
# FROM marked_sentences
# WHERE marked_sentences.date_time > ? AND marked_sentences.date_time < ? AND marked_sentences.lesson = ?
# 2024-08-30 18:55:54,558 INFO sqlalchemy.engine.Engine [cached since 16.3s ago] ('0001-01-01 00:00:00.000000', '9999-12-31 23:59:59.999999', 18)
# 2024-08-30 18:55:54,559 INFO sqlalchemy.engine.Engine ROLLBACK
# 2024-08-30 18:55:54,560 INFO sqlalchemy.engine.Engine BEGIN (implicit)
# 2024-08-30 18:55:54,560 INFO sqlalchemy.engine.Engine SELECT marked_sentences.id, marked_sentences.date_time, marked_sentences.sentence, marked_sentences.comment, marked_sentences.lesson, marked_sentences.line
# FROM marked_sentences
# WHERE marked_sentences.date_time > ? AND marked_sentences.date_time < ? AND marked_sentences.lesson = ?
# 2024-08-30 18:55:54,560 INFO sqlalchemy.engine.Engine [cached since 16.3s ago] ('0001-01-01 00:00:00.000000', '9999-12-31 23:59:59.999999', 19)
# 2024-08-30 18:55:54,561 INFO sqlalchemy.engine.Engine ROLLBACK
# 2024-08-30 18:55:54,561 INFO sqlalchemy.engine.Engine BEGIN (implicit)
# 2024-08-30 18:55:54,562 INFO sqlalchemy.engine.Engine SELECT marked_sentences.id, marked_sentences.date_time, marked_sentences.sentence, marked_sentences.comment, marked_sentences.lesson, marked_sentences.line
# FROM marked_sentences
# WHERE marked_sentences.date_time > ? AND marked_sentences.date_time < ? AND marked_sentences.lesson = ?
# 2024-08-30 18:55:54,562 INFO sqlalchemy.engine.Engine [cached since 16.3s ago] ('0001-01-01 00:00:00.000000', '9999-12-31 23:59:59.999999', 20)
# 2024-08-30 18:55:54,563 INFO sqlalchemy.engine.Engine ROLLBACK
# 2024-08-30 18:55:54,563 INFO sqlalchemy.engine.Engine BEGIN (implicit)
# 2024-08-30 18:55:54,563 INFO sqlalchemy.engine.Engine SELECT marked_sentences.id, marked_sentences.date_time, marked_sentences.sentence, marked_sentences.comment, marked_sentences.lesson, marked_sentences.line
# FROM marked_sentences
# WHERE marked_sentences.date_time > ? AND marked_sentences.date_time < ? AND marked_sentences.lesson = ?
# 2024-08-30 18:55:54,564 INFO sqlalchemy.engine.Engine [cached since 16.3s ago] ('0001-01-01 00:00:00.000000', '9999-12-31 23:59:59.999999', 21)
# 2024-08-30 18:55:54,564 INFO sqlalchemy.engine.Engine ROLLBACK
# 2024-08-30 18:55:54,565 INFO sqlalchemy.engine.Engine BEGIN (implicit)
# 2024-08-30 18:55:54,565 INFO sqlalchemy.engine.Engine SELECT marked_sentences.id, marked_sentences.date_time, marked_sentences.sentence, marked_sentences.comment, marked_sentences.lesson, marked_sentences.line
# FROM marked_sentences
# WHERE marked_sentences.date_time > ? AND marked_sentences.date_time < ? AND marked_sentences.lesson = ?
# 2024-08-30 18:55:54,566 INFO sqlalchemy.engine.Engine [cached since 16.31s ago] ('0001-01-01 00:00:00.000000', '9999-12-31 23:59:59.999999', 22)
# 2024-08-30 18:55:54,566 INFO sqlalchemy.engine.Engine ROLLBACK
# 2024-08-30 18:55:54,566 INFO sqlalchemy.engine.Engine BEGIN (implicit)
# 2024-08-30 18:55:54,567 INFO sqlalchemy.engine.Engine SELECT marked_sentences.id, marked_sentences.date_time, marked_sentences.sentence, marked_sentences.comment, marked_sentences.lesson, marked_sentences.line
# FROM marked_sentences
# WHERE marked_sentences.date_time > ? AND marked_sentences.date_time < ? AND marked_sentences.lesson = ?
# 2024-08-30 18:55:54,567 INFO sqlalchemy.engine.Engine [cached since 16.31s ago] ('0001-01-01 00:00:00.000000', '9999-12-31 23:59:59.999999', 23)
# 2024-08-30 18:55:54,567 INFO sqlalchemy.engine.Engine ROLLBACK
# 2024-08-30 18:55:54,568 INFO sqlalchemy.engine.Engine BEGIN (implicit)
# 2024-08-30 18:55:54,568 INFO sqlalchemy.engine.Engine SELECT marked_sentences.id, marked_sentences.date_time, marked_sentences.sentence, marked_sentences.comment, marked_sentences.lesson, marked_sentences.line
# FROM marked_sentences
# WHERE marked_sentences.date_time > ? AND marked_sentences.date_time < ? AND marked_sentences.lesson = ?
# 2024-08-30 18:55:54,569 INFO sqlalchemy.engine.Engine [cached since 16.31s ago] ('0001-01-01 00:00:00.000000', '9999-12-31 23:59:59.999999', 24)
# 2024-08-30 18:55:54,569 INFO sqlalchemy.engine.Engine ROLLBACK
# 2024-08-30 18:55:54,569 INFO sqlalchemy.engine.Engine BEGIN (implicit)
# 2024-08-30 18:55:54,570 INFO sqlalchemy.engine.Engine SELECT marked_sentences.id, marked_sentences.date_time, marked_sentences.sentence, marked_sentences.comment, marked_sentences.lesson, marked_sentences.line
# FROM marked_sentences
# WHERE marked_sentences.date_time > ? AND marked_sentences.date_time < ? AND marked_sentences.lesson = ?
# 2024-08-30 18:55:54,570 INFO sqlalchemy.engine.Engine [cached since 16.31s ago] ('0001-01-01 00:00:00.000000', '9999-12-31 23:59:59.999999', 25)
# 2024-08-30 18:55:54,570 INFO sqlalchemy.engine.Engine ROLLBACK
# 2024-08-30 18:55:54,571 INFO sqlalchemy.engine.Engine BEGIN (implicit)
# 2024-08-30 18:55:54,571 INFO sqlalchemy.engine.Engine SELECT marked_sentences.id, marked_sentences.date_time, marked_sentences.sentence, marked_sentences.comment, marked_sentences.lesson, marked_sentences.line
# FROM marked_sentences
# WHERE marked_sentences.date_time > ? AND marked_sentences.date_time < ? AND marked_sentences.lesson = ?
# 2024-08-30 18:55:54,571 INFO sqlalchemy.engine.Engine [cached since 16.31s ago] ('0001-01-01 00:00:00.000000', '9999-12-31 23:59:59.999999', 26)
# 2024-08-30 18:55:54,572 INFO sqlalchemy.engine.Engine ROLLBACK
# 2024-08-30 18:55:54,572 INFO sqlalchemy.engine.Engine BEGIN (implicit)
# 2024-08-30 18:55:54,573 INFO sqlalchemy.engine.Engine SELECT marked_sentences.id, marked_sentences.date_time, marked_sentences.sentence, marked_sentences.comment, marked_sentences.lesson, marked_sentences.line
# FROM marked_sentences
# WHERE marked_sentences.date_time > ? AND marked_sentences.date_time < ? AND marked_sentences.lesson = ?
# 2024-08-30 18:55:54,573 INFO sqlalchemy.engine.Engine [cached since 16.31s ago] ('0001-01-01 00:00:00.000000', '9999-12-31 23:59:59.999999', 27)
# 2024-08-30 18:55:54,574 INFO sqlalchemy.engine.Engine ROLLBACK
# 2024-08-30 18:55:54,574 INFO sqlalchemy.engine.Engine BEGIN (implicit)
# 2024-08-30 18:55:54,575 INFO sqlalchemy.engine.Engine SELECT marked_sentences.id, marked_sentences.date_time, marked_sentences.sentence, marked_sentences.comment, marked_sentences.lesson, marked_sentences.line
# FROM marked_sentences
# WHERE marked_sentences.date_time > ? AND marked_sentences.date_time < ? AND marked_sentences.lesson = ?
# 2024-08-30 18:55:54,575 INFO sqlalchemy.engine.Engine [cached since 16.32s ago] ('0001-01-01 00:00:00.000000', '9999-12-31 23:59:59.999999', 28)
# 2024-08-30 18:55:54,575 INFO sqlalchemy.engine.Engine ROLLBACK
# 2024-08-30 18:55:54,576 INFO sqlalchemy.engine.Engine BEGIN (implicit)
# 2024-08-30 18:55:54,577 INFO sqlalchemy.engine.Engine SELECT marked_sentences.id, marked_sentences.date_time, marked_sentences.sentence, marked_sentences.comment, marked_sentences.lesson, marked_sentences.line
# FROM marked_sentences
# WHERE marked_sentences.date_time > ? AND marked_sentences.date_time < ? AND marked_sentences.lesson = ?
# 2024-08-30 18:55:54,577 INFO sqlalchemy.engine.Engine [cached since 16.32s ago] ('0001-01-01 00:00:00.000000', '9999-12-31 23:59:59.999999', 29)
# 2024-08-30 18:55:54,578 INFO sqlalchemy.engine.Engine ROLLBACK
# 2024-08-30 18:55:54,578 INFO sqlalchemy.engine.Engine BEGIN (implicit)
# 2024-08-30 18:55:54,578 INFO sqlalchemy.engine.Engine SELECT marked_sentences.id, marked_sentences.date_time, marked_sentences.sentence, marked_sentences.comment, marked_sentences.lesson, marked_sentences.line
# FROM marked_sentences
# WHERE marked_sentences.date_time > ? AND marked_sentences.date_time < ? AND marked_sentences.lesson = ?
# 2024-08-30 18:55:54,579 INFO sqlalchemy.engine.Engine [cached since 16.32s ago] ('0001-01-01 00:00:00.000000', '9999-12-31 23:59:59.999999', 30)
# 2024-08-30 18:55:54,579 INFO sqlalchemy.engine.Engine ROLLBACK
# 2024-08-30 18:55:54,580 INFO sqlalchemy.engine.Engine BEGIN (implicit)
# 2024-08-30 18:55:54,580 INFO sqlalchemy.engine.Engine SELECT marked_sentences.id, marked_sentences.date_time, marked_sentences.sentence, marked_sentences.comment, marked_sentences.lesson, marked_sentences.line
# FROM marked_sentences
# WHERE marked_sentences.date_time > ? AND marked_sentences.date_time < ? AND marked_sentences.lesson = ?
# 2024-08-30 18:55:54,580 INFO sqlalchemy.engine.Engine [cached since 16.32s ago] ('0001-01-01 00:00:00.000000', '9999-12-31 23:59:59.999999', 31)
# 2024-08-30 18:55:54,581 INFO sqlalchemy.engine.Engine ROLLBACK
# 2024-08-30 18:55:54,581 INFO sqlalchemy.engine.Engine BEGIN (implicit)
# 2024-08-30 18:55:54,581 INFO sqlalchemy.engine.Engine SELECT marked_sentences.id, marked_sentences.date_time, marked_sentences.sentence, marked_sentences.comment, marked_sentences.lesson, marked_sentences.line
# FROM marked_sentences
# WHERE marked_sentences.date_time > ? AND marked_sentences.date_time < ? AND marked_sentences.lesson = ?
# 2024-08-30 18:55:54,581 INFO sqlalchemy.engine.Engine [cached since 16.32s ago] ('0001-01-01 00:00:00.000000', '9999-12-31 23:59:59.999999', 32)
# 2024-08-30 18:55:54,582 INFO sqlalchemy.engine.Engine ROLLBACK
# 2024-08-30 18:55:54,582 INFO sqlalchemy.engine.Engine BEGIN (implicit)
# 2024-08-30 18:55:54,582 INFO sqlalchemy.engine.Engine SELECT marked_sentences.id, marked_sentences.date_time, marked_sentences.sentence, marked_sentences.comment, marked_sentences.lesson, marked_sentences.line
# FROM marked_sentences
# WHERE marked_sentences.date_time > ? AND marked_sentences.date_time < ? AND marked_sentences.lesson = ?
# 2024-08-30 18:55:54,583 INFO sqlalchemy.engine.Engine [cached since 16.32s ago] ('0001-01-01 00:00:00.000000', '9999-12-31 23:59:59.999999', 33)
# 2024-08-30 18:55:54,583 INFO sqlalchemy.engine.Engine ROLLBACK
# 2024-08-30 18:55:54,583 INFO sqlalchemy.engine.Engine BEGIN (implicit)
# 2024-08-30 18:55:54,584 INFO sqlalchemy.engine.Engine SELECT marked_sentences.id, marked_sentences.date_time, marked_sentences.sentence, marked_sentences.comment, marked_sentences.lesson, marked_sentences.line
# FROM marked_sentences
# WHERE marked_sentences.date_time > ? AND marked_sentences.date_time < ? AND marked_sentences.lesson = ?
# 2024-08-30 18:55:54,584 INFO sqlalchemy.engine.Engine [cached since 16.32s ago] ('0001-01-01 00:00:00.000000', '9999-12-31 23:59:59.999999', 34)
# 2024-08-30 18:55:54,584 INFO sqlalchemy.engine.Engine ROLLBACK
# 2024-08-30 18:55:54,585 INFO sqlalchemy.engine.Engine BEGIN (implicit)
# 2024-08-30 18:55:54,585 INFO sqlalchemy.engine.Engine SELECT marked_sentences.id, marked_sentences.date_time, marked_sentences.sentence, marked_sentences.comment, marked_sentences.lesson, marked_sentences.line
# FROM marked_sentences
# WHERE marked_sentences.date_time > ? AND marked_sentences.date_time < ? AND marked_sentences.lesson = ?
# 2024-08-30 18:55:54,585 INFO sqlalchemy.engine.Engine [cached since 16.33s ago] ('0001-01-01 00:00:00.000000', '9999-12-31 23:59:59.999999', 35)
# 2024-08-30 18:55:54,585 INFO sqlalchemy.engine.Engine ROLLBACK
# 2024-08-30 18:55:54,586 INFO sqlalchemy.engine.Engine BEGIN (implicit)
# 2024-08-30 18:55:54,586 INFO sqlalchemy.engine.Engine SELECT marked_sentences.id, marked_sentences.date_time, marked_sentences.sentence, marked_sentences.comment, marked_sentences.lesson, marked_sentences.line
# FROM marked_sentences
# WHERE marked_sentences.date_time > ? AND marked_sentences.date_time < ? AND marked_sentences.lesson = ?
# 2024-08-30 18:55:54,586 INFO sqlalchemy.engine.Engine [cached since 16.33s ago] ('0001-01-01 00:00:00.000000', '9999-12-31 23:59:59.999999', 36)
# 2024-08-30 18:55:54,586 INFO sqlalchemy.engine.Engine ROLLBACK
# 2024-08-30 18:55:54,587 INFO sqlalchemy.engine.Engine BEGIN (implicit)
# 2024-08-30 18:55:54,587 INFO sqlalchemy.engine.Engine SELECT marked_sentences.id, marked_sentences.date_time, marked_sentences.sentence, marked_sentences.comment, marked_sentences.lesson, marked_sentences.line
# FROM marked_sentences
# WHERE marked_sentences.date_time > ? AND marked_sentences.date_time < ? AND marked_sentences.lesson = ?
# 2024-08-30 18:55:54,587 INFO sqlalchemy.engine.Engine [cached since 16.33s ago] ('0001-01-01 00:00:00.000000', '9999-12-31 23:59:59.999999', 37)
# 2024-08-30 18:55:54,587 INFO sqlalchemy.engine.Engine ROLLBACK
# 2024-08-30 18:55:54,588 INFO sqlalchemy.engine.Engine BEGIN (implicit)
# 2024-08-30 18:55:54,588 INFO sqlalchemy.engine.Engine SELECT marked_sentences.id, marked_sentences.date_time, marked_sentences.sentence, marked_sentences.comment, marked_sentences.lesson, marked_sentences.line
# FROM marked_sentences
# WHERE marked_sentences.date_time > ? AND marked_sentences.date_time < ? AND marked_sentences.lesson = ?
# 2024-08-30 18:55:54,588 INFO sqlalchemy.engine.Engine [cached since 16.33s ago] ('0001-01-01 00:00:00.000000', '9999-12-31 23:59:59.999999', 38)
# 2024-08-30 18:55:54,589 INFO sqlalchemy.engine.Engine ROLLBACK
# 2024-08-30 18:55:54,589 INFO sqlalchemy.engine.Engine BEGIN (implicit)
# 2024-08-30 18:55:54,589 INFO sqlalchemy.engine.Engine SELECT marked_sentences.id, marked_sentences.date_time, marked_sentences.sentence, marked_sentences.comment, marked_sentences.lesson, marked_sentences.line
# FROM marked_sentences
# WHERE marked_sentences.date_time > ? AND marked_sentences.date_time < ? AND marked_sentences.lesson = ?
# 2024-08-30 18:55:54,589 INFO sqlalchemy.engine.Engine [cached since 16.33s ago] ('0001-01-01 00:00:00.000000', '9999-12-31 23:59:59.999999', 39)
# 2024-08-30 18:55:54,590 INFO sqlalchemy.engine.Engine ROLLBACK
# 2024-08-30 18:55:54,590 INFO sqlalchemy.engine.Engine BEGIN (implicit)
# 2024-08-30 18:55:54,590 INFO sqlalchemy.engine.Engine SELECT marked_sentences.id, marked_sentences.date_time, marked_sentences.sentence, marked_sentences.comment, marked_sentences.lesson, marked_sentences.line
# FROM marked_sentences
# WHERE marked_sentences.date_time > ? AND marked_sentences.date_time < ? AND marked_sentences.lesson = ?
# 2024-08-30 18:55:54,591 INFO sqlalchemy.engine.Engine [cached since 16.33s ago] ('0001-01-01 00:00:00.000000', '9999-12-31 23:59:59.999999', 40)
# 2024-08-30 18:55:54,591 INFO sqlalchemy.engine.Engine ROLLBACK
# 2024-08-30 18:55:54,592 INFO sqlalchemy.engine.Engine BEGIN (implicit)
# 2024-08-30 18:55:54,592 INFO sqlalchemy.engine.Engine SELECT marked_sentences.id, marked_sentences.date_time, marked_sentences.sentence, marked_sentences.comment, marked_sentences.lesson, marked_sentences.line
# FROM marked_sentences
# WHERE marked_sentences.date_time > ? AND marked_sentences.date_time < ? AND marked_sentences.lesson = ?
# 2024-08-30 18:55:54,592 INFO sqlalchemy.engine.Engine [cached since 16.33s ago] ('0001-01-01 00:00:00.000000', '9999-12-31 23:59:59.999999', 41)
# 2024-08-30 18:55:54,592 INFO sqlalchemy.engine.Engine ROLLBACK
# 2024-08-30 18:55:54,593 INFO sqlalchemy.engine.Engine BEGIN (implicit)
# 2024-08-30 18:55:54,593 INFO sqlalchemy.engine.Engine SELECT marked_sentences.id, marked_sentences.date_time, marked_sentences.sentence, marked_sentences.comment, marked_sentences.lesson, marked_sentences.line
# FROM marked_sentences
# WHERE marked_sentences.date_time > ? AND marked_sentences.date_time < ? AND marked_sentences.lesson = ?
# 2024-08-30 18:55:54,593 INFO sqlalchemy.engine.Engine [cached since 16.33s ago] ('0001-01-01 00:00:00.000000', '9999-12-31 23:59:59.999999', 42)
# 2024-08-30 18:55:54,593 INFO sqlalchemy.engine.Engine ROLLBACK
# 2024-08-30 18:55:54,594 INFO sqlalchemy.engine.Engine BEGIN (implicit)
# 2024-08-30 18:55:54,594 INFO sqlalchemy.engine.Engine SELECT marked_sentences.id, marked_sentences.date_time, marked_sentences.sentence, marked_sentences.comment, marked_sentences.lesson, marked_sentences.line
# FROM marked_sentences
# WHERE marked_sentences.date_time > ? AND marked_sentences.date_time < ? AND marked_sentences.lesson = ?
# 2024-08-30 18:55:54,594 INFO sqlalchemy.engine.Engine [cached since 16.33s ago] ('0001-01-01 00:00:00.000000', '9999-12-31 23:59:59.999999', 43)
# 2024-08-30 18:55:54,594 INFO sqlalchemy.engine.Engine ROLLBACK
# 2024-08-30 18:55:54,595 INFO sqlalchemy.engine.Engine BEGIN (implicit)
# 2024-08-30 18:55:54,595 INFO sqlalchemy.engine.Engine SELECT marked_sentences.id, marked_sentences.date_time, marked_sentences.sentence, marked_sentences.comment, marked_sentences.lesson, marked_sentences.line
# FROM marked_sentences
# WHERE marked_sentences.date_time > ? AND marked_sentences.date_time < ? AND marked_sentences.lesson = ?
# 2024-08-30 18:55:54,595 INFO sqlalchemy.engine.Engine [cached since 16.34s ago] ('0001-01-01 00:00:00.000000', '9999-12-31 23:59:59.999999', 44)
# 2024-08-30 18:55:54,595 INFO sqlalchemy.engine.Engine ROLLBACK
# 2024-08-30 18:55:54,596 INFO sqlalchemy.engine.Engine BEGIN (implicit)
# 2024-08-30 18:55:54,596 INFO sqlalchemy.engine.Engine SELECT marked_sentences.id, marked_sentences.date_time, marked_sentences.sentence, marked_sentences.comment, marked_sentences.lesson, marked_sentences.line
# FROM marked_sentences
# WHERE marked_sentences.date_time > ? AND marked_sentences.date_time < ? AND marked_sentences.lesson = ?
# 2024-08-30 18:55:54,596 INFO sqlalchemy.engine.Engine [cached since 16.34s ago] ('0001-01-01 00:00:00.000000', '9999-12-31 23:59:59.999999', 45)
# 2024-08-30 18:55:54,596 INFO sqlalchemy.engine.Engine ROLLBACK
# 2024-08-30 18:55:54,597 INFO sqlalchemy.engine.Engine BEGIN (implicit)
# 2024-08-30 18:55:54,597 INFO sqlalchemy.engine.Engine SELECT marked_sentences.id, marked_sentences.date_time, marked_sentences.sentence, marked_sentences.comment, marked_sentences.lesson, marked_sentences.line
# FROM marked_sentences
# WHERE marked_sentences.date_time > ? AND marked_sentences.date_time < ? AND marked_sentences.lesson = ?
# 2024-08-30 18:55:54,597 INFO sqlalchemy.engine.Engine [cached since 16.34s ago] ('0001-01-01 00:00:00.000000', '9999-12-31 23:59:59.999999', 46)
# 2024-08-30 18:55:54,598 INFO sqlalchemy.engine.Engine ROLLBACK
# 2024-08-30 18:55:54,598 INFO sqlalchemy.engine.Engine BEGIN (implicit)
# 2024-08-30 18:55:54,598 INFO sqlalchemy.engine.Engine SELECT marked_sentences.id, marked_sentences.date_time, marked_sentences.sentence, marked_sentences.comment, marked_sentences.lesson, marked_sentences.line
# FROM marked_sentences
# WHERE marked_sentences.date_time > ? AND marked_sentences.date_time < ? AND marked_sentences.lesson = ?
# 2024-08-30 18:55:54,598 INFO sqlalchemy.engine.Engine [cached since 16.34s ago] ('0001-01-01 00:00:00.000000', '9999-12-31 23:59:59.999999', 47)
# 2024-08-30 18:55:54,599 INFO sqlalchemy.engine.Engine ROLLBACK
# 2024-08-30 18:55:54,599 INFO sqlalchemy.engine.Engine BEGIN (implicit)
# 2024-08-30 18:55:54,599 INFO sqlalchemy.engine.Engine SELECT marked_sentences.id, marked_sentences.date_time, marked_sentences.sentence, marked_sentences.comment, marked_sentences.lesson, marked_sentences.line
# FROM marked_sentences
# WHERE marked_sentences.date_time > ? AND marked_sentences.date_time < ? AND marked_sentences.lesson = ?
# 2024-08-30 18:55:54,599 INFO sqlalchemy.engine.Engine [cached since 16.34s ago] ('0001-01-01 00:00:00.000000', '9999-12-31 23:59:59.999999', 48)
# 2024-08-30 18:55:54,600 INFO sqlalchemy.engine.Engine ROLLBACK
# 2024-08-30 18:55:54,600 INFO sqlalchemy.engine.Engine BEGIN (implicit)
# 2024-08-30 18:55:54,600 INFO sqlalchemy.engine.Engine SELECT marked_sentences.id, marked_sentences.date_time, marked_sentences.sentence, marked_sentences.comment, marked_sentences.lesson, marked_sentences.line
# FROM marked_sentences
# WHERE marked_sentences.date_time > ? AND marked_sentences.date_time < ? AND marked_sentences.lesson = ?
# 2024-08-30 18:55:54,600 INFO sqlalchemy.engine.Engine [cached since 16.34s ago] ('0001-01-01 00:00:00.000000', '9999-12-31 23:59:59.999999', 49)
# 2024-08-30 18:55:54,601 INFO sqlalchemy.engine.Engine ROLLBACK
# 2024-08-30 18:55:54,601 INFO sqlalchemy.engine.Engine BEGIN (implicit)
# 2024-08-30 18:55:54,602 INFO sqlalchemy.engine.Engine SELECT marked_sentences.id, marked_sentences.date_time, marked_sentences.sentence, marked_sentences.comment, marked_sentences.lesson, marked_sentences.line
# FROM marked_sentences
# WHERE marked_sentences.date_time > ? AND marked_sentences.date_time < ? AND marked_sentences.lesson = ?
# 2024-08-30 18:55:54,602 INFO sqlalchemy.engine.Engine [cached since 16.34s ago] ('0001-01-01 00:00:00.000000', '9999-12-31 23:59:59.999999', 50)
# 2024-08-30 18:55:54,602 INFO sqlalchemy.engine.Engine ROLLBACK
# 2024-08-30 18:55:54,602 INFO sqlalchemy.engine.Engine BEGIN (implicit)
# 2024-08-30 18:55:54,603 INFO sqlalchemy.engine.Engine SELECT marked_sentences.id, marked_sentences.date_time, marked_sentences.sentence, marked_sentences.comment, marked_sentences.lesson, marked_sentences.line
# FROM marked_sentences
# WHERE marked_sentences.date_time > ? AND marked_sentences.date_time < ? AND marked_sentences.lesson = ?
# 2024-08-30 18:55:54,603 INFO sqlalchemy.engine.Engine [cached since 16.34s ago] ('0001-01-01 00:00:00.000000', '9999-12-31 23:59:59.999999', 51)
# 2024-08-30 18:55:54,603 INFO sqlalchemy.engine.Engine ROLLBACK
# 2024-08-30 18:55:54,603 INFO sqlalchemy.engine.Engine BEGIN (implicit)
# 2024-08-30 18:55:54,604 INFO sqlalchemy.engine.Engine SELECT marked_sentences.id, marked_sentences.date_time, marked_sentences.sentence, marked_sentences.comment, marked_sentences.lesson, marked_sentences.line
# FROM marked_sentences
# WHERE marked_sentences.date_time > ? AND marked_sentences.date_time < ? AND marked_sentences.lesson = ?
# 2024-08-30 18:55:54,604 INFO sqlalchemy.engine.Engine [cached since 16.34s ago] ('0001-01-01 00:00:00.000000', '9999-12-31 23:59:59.999999', 52)
# 2024-08-30 18:55:54,604 INFO sqlalchemy.engine.Engine ROLLBACK
# 2024-08-30 18:55:54,604 INFO sqlalchemy.engine.Engine BEGIN (implicit)
# 2024-08-30 18:55:54,605 INFO sqlalchemy.engine.Engine SELECT marked_sentences.id, marked_sentences.date_time, marked_sentences.sentence, marked_sentences.comment, marked_sentences.lesson, marked_sentences.line
# FROM marked_sentences
# WHERE marked_sentences.date_time > ? AND marked_sentences.date_time < ? AND marked_sentences.lesson = ?
# 2024-08-30 18:55:54,605 INFO sqlalchemy.engine.Engine [cached since 16.35s ago] ('0001-01-01 00:00:00.000000', '9999-12-31 23:59:59.999999', 53)
# 2024-08-30 18:55:54,605 INFO sqlalchemy.engine.Engine ROLLBACK
# 2024-08-30 18:55:54,606 INFO sqlalchemy.engine.Engine BEGIN (implicit)
# 2024-08-30 18:55:54,606 INFO sqlalchemy.engine.Engine SELECT marked_sentences.id, marked_sentences.date_time, marked_sentences.sentence, marked_sentences.comment, marked_sentences.lesson, marked_sentences.line
# FROM marked_sentences
# WHERE marked_sentences.date_time > ? AND marked_sentences.date_time < ? AND marked_sentences.lesson = ?
# 2024-08-30 18:55:54,606 INFO sqlalchemy.engine.Engine [cached since 16.35s ago] ('0001-01-01 00:00:00.000000', '9999-12-31 23:59:59.999999', 54)
# 2024-08-30 18:55:54,606 INFO sqlalchemy.engine.Engine ROLLBACK
# 2024-08-30 18:55:54,607 INFO sqlalchemy.engine.Engine BEGIN (implicit)
# 2024-08-30 18:55:54,607 INFO sqlalchemy.engine.Engine SELECT marked_sentences.id, marked_sentences.date_time, marked_sentences.sentence, marked_sentences.comment, marked_sentences.lesson, marked_sentences.line
# FROM marked_sentences
# WHERE marked_sentences.date_time > ? AND marked_sentences.date_time < ? AND marked_sentences.lesson = ?
# 2024-08-30 18:55:54,607 INFO sqlalchemy.engine.Engine [cached since 16.35s ago] ('0001-01-01 00:00:00.000000', '9999-12-31 23:59:59.999999', 55)
# 2024-08-30 18:55:54,608 INFO sqlalchemy.engine.Engine ROLLBACK
# 2024-08-30 18:55:54,608 INFO sqlalchemy.engine.Engine BEGIN (implicit)
# 2024-08-30 18:55:54,608 INFO sqlalchemy.engine.Engine SELECT marked_sentences.id, marked_sentences.date_time, marked_sentences.sentence, marked_sentences.comment, marked_sentences.lesson, marked_sentences.line
# FROM marked_sentences
# WHERE marked_sentences.date_time > ? AND marked_sentences.date_time < ? AND marked_sentences.lesson = ?
# 2024-08-30 18:55:54,608 INFO sqlalchemy.engine.Engine [cached since 16.35s ago] ('0001-01-01 00:00:00.000000', '9999-12-31 23:59:59.999999', 56)
# 2024-08-30 18:55:54,608 INFO sqlalchemy.engine.Engine ROLLBACK
# 2024-08-30 18:55:54,609 INFO sqlalchemy.engine.Engine BEGIN (implicit)
# 2024-08-30 18:55:54,609 INFO sqlalchemy.engine.Engine SELECT marked_sentences.id, marked_sentences.date_time, marked_sentences.sentence, marked_sentences.comment, marked_sentences.lesson, marked_sentences.line
# FROM marked_sentences
# WHERE marked_sentences.date_time > ? AND marked_sentences.date_time < ? AND marked_sentences.lesson = ?
# 2024-08-30 18:55:54,609 INFO sqlalchemy.engine.Engine [cached since 16.35s ago] ('0001-01-01 00:00:00.000000', '9999-12-31 23:59:59.999999', 57)
# 2024-08-30 18:55:54,610 INFO sqlalchemy.engine.Engine ROLLBACK
# 2024-08-30 18:55:54,610 INFO sqlalchemy.engine.Engine BEGIN (implicit)
# 2024-08-30 18:55:54,610 INFO sqlalchemy.engine.Engine SELECT marked_sentences.id, marked_sentences.date_time, marked_sentences.sentence, marked_sentences.comment, marked_sentences.lesson, marked_sentences.line
# FROM marked_sentences
# WHERE marked_sentences.date_time > ? AND marked_sentences.date_time < ? AND marked_sentences.lesson = ?
# 2024-08-30 18:55:54,610 INFO sqlalchemy.engine.Engine [cached since 16.35s ago] ('0001-01-01 00:00:00.000000', '9999-12-31 23:59:59.999999', 58)
# 2024-08-30 18:55:54,611 INFO sqlalchemy.engine.Engine ROLLBACK
# 2024-08-30 18:55:54,611 INFO sqlalchemy.engine.Engine BEGIN (implicit)
# 2024-08-30 18:55:54,611 INFO sqlalchemy.engine.Engine SELECT marked_sentences.id, marked_sentences.date_time, marked_sentences.sentence, marked_sentences.comment, marked_sentences.lesson, marked_sentences.line
# FROM marked_sentences
# WHERE marked_sentences.date_time > ? AND marked_sentences.date_time < ? AND marked_sentences.lesson = ?
# 2024-08-30 18:55:54,611 INFO sqlalchemy.engine.Engine [cached since 16.35s ago] ('0001-01-01 00:00:00.000000', '9999-12-31 23:59:59.999999', 59)
# 2024-08-30 18:55:54,611 INFO sqlalchemy.engine.Engine ROLLBACK
# 2024-08-30 18:55:54,612 INFO sqlalchemy.engine.Engine BEGIN (implicit)
# 2024-08-30 18:55:54,612 INFO sqlalchemy.engine.Engine SELECT marked_sentences.id, marked_sentences.date_time, marked_sentences.sentence, marked_sentences.comment, marked_sentences.lesson, marked_sentences.line
# FROM marked_sentences
# WHERE marked_sentences.date_time > ? AND marked_sentences.date_time < ? AND marked_sentences.lesson = ?
# 2024-08-30 18:55:54,612 INFO sqlalchemy.engine.Engine [cached since 16.35s ago] ('0001-01-01 00:00:00.000000', '9999-12-31 23:59:59.999999', 60)
# 2024-08-30 18:55:54,613 INFO sqlalchemy.engine.Engine ROLLBACK
# 2024-08-30 18:55:54,613 INFO sqlalchemy.engine.Engine BEGIN (implicit)
# 2024-08-30 18:55:54,613 INFO sqlalchemy.engine.Engine SELECT marked_sentences.id, marked_sentences.date_time, marked_sentences.sentence, marked_sentences.comment, marked_sentences.lesson, marked_sentences.line
# FROM marked_sentences
# WHERE marked_sentences.date_time > ? AND marked_sentences.date_time < ? AND marked_sentences.lesson = ?
# 2024-08-30 18:55:54,613 INFO sqlalchemy.engine.Engine [cached since 16.35s ago] ('0001-01-01 00:00:00.000000', '9999-12-31 23:59:59.999999', 61)
# 2024-08-30 18:55:54,614 INFO sqlalchemy.engine.Engine ROLLBACK
# 2024-08-30 18:55:54,614 INFO sqlalchemy.engine.Engine BEGIN (implicit)
# 2024-08-30 18:55:54,614 INFO sqlalchemy.engine.Engine SELECT marked_sentences.id, marked_sentences.date_time, marked_sentences.sentence, marked_sentences.comment, marked_sentences.lesson, marked_sentences.line
# FROM marked_sentences
# WHERE marked_sentences.date_time > ? AND marked_sentences.date_time < ? AND marked_sentences.lesson = ?
# 2024-08-30 18:55:54,614 INFO sqlalchemy.engine.Engine [cached since 16.35s ago] ('0001-01-01 00:00:00.000000', '9999-12-31 23:59:59.999999', 62)
# 2024-08-30 18:55:54,614 INFO sqlalchemy.engine.Engine ROLLBACK
# 2024-08-30 18:55:54,615 INFO sqlalchemy.engine.Engine BEGIN (implicit)
# 2024-08-30 18:55:54,615 INFO sqlalchemy.engine.Engine SELECT marked_sentences.id, marked_sentences.date_time, marked_sentences.sentence, marked_sentences.comment, marked_sentences.lesson, marked_sentences.line
# FROM marked_sentences
# WHERE marked_sentences.date_time > ? AND marked_sentences.date_time < ? AND marked_sentences.lesson = ?
# 2024-08-30 18:55:54,615 INFO sqlalchemy.engine.Engine [cached since 16.36s ago] ('0001-01-01 00:00:00.000000', '9999-12-31 23:59:59.999999', 63)
# 2024-08-30 18:55:54,616 INFO sqlalchemy.engine.Engine ROLLBACK
# 2024-08-30 18:55:54,616 INFO sqlalchemy.engine.Engine BEGIN (implicit)
# 2024-08-30 18:55:54,616 INFO sqlalchemy.engine.Engine SELECT marked_sentences.id, marked_sentences.date_time, marked_sentences.sentence, marked_sentences.comment, marked_sentences.lesson, marked_sentences.line
# FROM marked_sentences
# WHERE marked_sentences.date_time > ? AND marked_sentences.date_time < ? AND marked_sentences.lesson = ?
# 2024-08-30 18:55:54,617 INFO sqlalchemy.engine.Engine [cached since 16.36s ago] ('0001-01-01 00:00:00.000000', '9999-12-31 23:59:59.999999', 64)
# 2024-08-30 18:55:54,617 INFO sqlalchemy.engine.Engine ROLLBACK
# 2024-08-30 18:55:54,617 INFO sqlalchemy.engine.Engine BEGIN (implicit)
# 2024-08-30 18:55:54,617 INFO sqlalchemy.engine.Engine SELECT marked_sentences.id, marked_sentences.date_time, marked_sentences.sentence, marked_sentences.comment, marked_sentences.lesson, marked_sentences.line
# FROM marked_sentences
# WHERE marked_sentences.date_time > ? AND marked_sentences.date_time < ? AND marked_sentences.lesson = ?
# 2024-08-30 18:55:54,618 INFO sqlalchemy.engine.Engine [cached since 16.36s ago] ('0001-01-01 00:00:00.000000', '9999-12-31 23:59:59.999999', 65)
# 2024-08-30 18:55:54,618 INFO sqlalchemy.engine.Engine ROLLBACK
# 2024-08-30 18:55:54,618 INFO sqlalchemy.engine.Engine BEGIN (implicit)
# 2024-08-30 18:55:54,618 INFO sqlalchemy.engine.Engine SELECT marked_sentences.id, marked_sentences.date_time, marked_sentences.sentence, marked_sentences.comment, marked_sentences.lesson, marked_sentences.line
# FROM marked_sentences
# WHERE marked_sentences.date_time > ? AND marked_sentences.date_time < ? AND marked_sentences.lesson = ?
# 2024-08-30 18:55:54,619 INFO sqlalchemy.engine.Engine [cached since 16.36s ago] ('0001-01-01 00:00:00.000000', '9999-12-31 23:59:59.999999', 66)
# 2024-08-30 18:55:54,619 INFO sqlalchemy.engine.Engine ROLLBACK
# 2024-08-30 18:55:54,619 INFO sqlalchemy.engine.Engine BEGIN (implicit)
# 2024-08-30 18:55:54,619 INFO sqlalchemy.engine.Engine SELECT marked_sentences.id, marked_sentences.date_time, marked_sentences.sentence, marked_sentences.comment, marked_sentences.lesson, marked_sentences.line
# FROM marked_sentences
# WHERE marked_sentences.date_time > ? AND marked_sentences.date_time < ? AND marked_sentences.lesson = ?
# 2024-08-30 18:55:54,620 INFO sqlalchemy.engine.Engine [cached since 16.36s ago] ('0001-01-01 00:00:00.000000', '9999-12-31 23:59:59.999999', 67)
# 2024-08-30 18:55:54,620 INFO sqlalchemy.engine.Engine ROLLBACK
# 2024-08-30 18:55:54,620 INFO sqlalchemy.engine.Engine BEGIN (implicit)
# 2024-08-30 18:55:54,620 INFO sqlalchemy.engine.Engine SELECT marked_sentences.id, marked_sentences.date_time, marked_sentences.sentence, marked_sentences.comment, marked_sentences.lesson, marked_sentences.line
# FROM marked_sentences
# WHERE marked_sentences.date_time > ? AND marked_sentences.date_time < ? AND marked_sentences.lesson = ?
# 2024-08-30 18:55:54,621 INFO sqlalchemy.engine.Engine [cached since 16.36s ago] ('0001-01-01 00:00:00.000000', '9999-12-31 23:59:59.999999', 68)
# 2024-08-30 18:55:54,621 INFO sqlalchemy.engine.Engine ROLLBACK
# 2024-08-30 18:55:54,621 INFO sqlalchemy.engine.Engine BEGIN (implicit)
# 2024-08-30 18:55:54,621 INFO sqlalchemy.engine.Engine SELECT marked_sentences.id, marked_sentences.date_time, marked_sentences.sentence, marked_sentences.comment, marked_sentences.lesson, marked_sentences.line
# FROM marked_sentences
# WHERE marked_sentences.date_time > ? AND marked_sentences.date_time < ? AND marked_sentences.lesson = ?
# 2024-08-30 18:55:54,622 INFO sqlalchemy.engine.Engine [cached since 16.36s ago] ('0001-01-01 00:00:00.000000', '9999-12-31 23:59:59.999999', 69)
# 2024-08-30 18:55:54,622 INFO sqlalchemy.engine.Engine ROLLBACK
# 2024-08-30 18:55:54,622 INFO sqlalchemy.engine.Engine BEGIN (implicit)
# 2024-08-30 18:55:54,622 INFO sqlalchemy.engine.Engine SELECT marked_sentences.id, marked_sentences.date_time, marked_sentences.sentence, marked_sentences.comment, marked_sentences.lesson, marked_sentences.line
# FROM marked_sentences
# WHERE marked_sentences.date_time > ? AND marked_sentences.date_time < ? AND marked_sentences.lesson = ?
# 2024-08-30 18:55:54,623 INFO sqlalchemy.engine.Engine [cached since 16.36s ago] ('0001-01-01 00:00:00.000000', '9999-12-31 23:59:59.999999', 70)
# 2024-08-30 18:55:54,623 INFO sqlalchemy.engine.Engine ROLLBACK
# 2024-08-30 18:55:54,623 INFO sqlalchemy.engine.Engine BEGIN (implicit)
# 2024-08-30 18:55:54,623 INFO sqlalchemy.engine.Engine SELECT marked_sentences.id, marked_sentences.date_time, marked_sentences.sentence, marked_sentences.comment, marked_sentences.lesson, marked_sentences.line
# FROM marked_sentences
# WHERE marked_sentences.date_time > ? AND marked_sentences.date_time < ? AND marked_sentences.lesson = ?
# 2024-08-30 18:55:54,624 INFO sqlalchemy.engine.Engine [cached since 16.36s ago] ('0001-01-01 00:00:00.000000', '9999-12-31 23:59:59.999999', 71)
# 2024-08-30 18:55:54,624 INFO sqlalchemy.engine.Engine ROLLBACK
# 2024-08-30 18:55:54,624 INFO sqlalchemy.engine.Engine BEGIN (implicit)
# 2024-08-30 18:55:54,624 INFO sqlalchemy.engine.Engine SELECT marked_sentences.id, marked_sentences.date_time, marked_sentences.sentence, marked_sentences.comment, marked_sentences.lesson, marked_sentences.line
# FROM marked_sentences
# WHERE marked_sentences.date_time > ? AND marked_sentences.date_time < ? AND marked_sentences.lesson = ?
# 2024-08-30 18:55:54,625 INFO sqlalchemy.engine.Engine [cached since 16.36s ago] ('0001-01-01 00:00:00.000000', '9999-12-31 23:59:59.999999', 72)
# 2024-08-30 18:55:54,625 INFO sqlalchemy.engine.Engine ROLLBACK
# 2024-08-30 18:55:54,625 INFO sqlalchemy.engine.Engine BEGIN (implicit)
# 2024-08-30 18:55:54,625 INFO sqlalchemy.engine.Engine SELECT marked_sentences.id, marked_sentences.date_time, marked_sentences.sentence, marked_sentences.comment, marked_sentences.lesson, marked_sentences.line
# FROM marked_sentences
# WHERE marked_sentences.date_time > ? AND marked_sentences.date_time < ? AND marked_sentences.lesson = ?
# 2024-08-30 18:55:54,626 INFO sqlalchemy.engine.Engine [cached since 16.37s ago] ('0001-01-01 00:00:00.000000', '9999-12-31 23:59:59.999999', 73)
# 2024-08-30 18:55:54,626 INFO sqlalchemy.engine.Engine ROLLBACK
# 2024-08-30 18:55:54,626 INFO sqlalchemy.engine.Engine BEGIN (implicit)
# 2024-08-30 18:55:54,626 INFO sqlalchemy.engine.Engine SELECT marked_sentences.id, marked_sentences.date_time, marked_sentences.sentence, marked_sentences.comment, marked_sentences.lesson, marked_sentences.line
# FROM marked_sentences
# WHERE marked_sentences.date_time > ? AND marked_sentences.date_time < ? AND marked_sentences.lesson = ?
# 2024-08-30 18:55:54,627 INFO sqlalchemy.engine.Engine [cached since 16.37s ago] ('0001-01-01 00:00:00.000000', '9999-12-31 23:59:59.999999', 74)
# 2024-08-30 18:55:54,627 INFO sqlalchemy.engine.Engine ROLLBACK
# 2024-08-30 18:55:54,627 INFO sqlalchemy.engine.Engine BEGIN (implicit)
# 2024-08-30 18:55:54,628 INFO sqlalchemy.engine.Engine SELECT marked_sentences.id, marked_sentences.date_time, marked_sentences.sentence, marked_sentences.comment, marked_sentences.lesson, marked_sentences.line
# FROM marked_sentences
# WHERE marked_sentences.date_time > ? AND marked_sentences.date_time < ? AND marked_sentences.lesson = ?
# 2024-08-30 18:55:54,628 INFO sqlalchemy.engine.Engine [cached since 16.37s ago] ('0001-01-01 00:00:00.000000', '9999-12-31 23:59:59.999999', 75)
# 2024-08-30 18:55:54,628 INFO sqlalchemy.engine.Engine ROLLBACK
# 2024-08-30 18:55:54,628 INFO sqlalchemy.engine.Engine BEGIN (implicit)
# 2024-08-30 18:55:54,629 INFO sqlalchemy.engine.Engine SELECT marked_sentences.id, marked_sentences.date_time, marked_sentences.sentence, marked_sentences.comment, marked_sentences.lesson, marked_sentences.line
# FROM marked_sentences
# WHERE marked_sentences.date_time > ? AND marked_sentences.date_time < ? AND marked_sentences.lesson = ?
# 2024-08-30 18:55:54,629 INFO sqlalchemy.engine.Engine [cached since 16.37s ago] ('0001-01-01 00:00:00.000000', '9999-12-31 23:59:59.999999', 76)
# 2024-08-30 18:55:54,629 INFO sqlalchemy.engine.Engine ROLLBACK
# 2024-08-30 18:55:54,629 INFO sqlalchemy.engine.Engine BEGIN (implicit)
# 2024-08-30 18:55:54,630 INFO sqlalchemy.engine.Engine SELECT marked_sentences.id, marked_sentences.date_time, marked_sentences.sentence, marked_sentences.comment, marked_sentences.lesson, marked_sentences.line
# FROM marked_sentences
# WHERE marked_sentences.date_time > ? AND marked_sentences.date_time < ? AND marked_sentences.lesson = ?
# 2024-08-30 18:55:54,630 INFO sqlalchemy.engine.Engine [cached since 16.37s ago] ('0001-01-01 00:00:00.000000', '9999-12-31 23:59:59.999999', 77)
# 2024-08-30 18:55:54,630 INFO sqlalchemy.engine.Engine ROLLBACK
# 2024-08-30 18:55:54,630 INFO sqlalchemy.engine.Engine BEGIN (implicit)
# 2024-08-30 18:55:54,630 INFO sqlalchemy.engine.Engine SELECT marked_sentences.id, marked_sentences.date_time, marked_sentences.sentence, marked_sentences.comment, marked_sentences.lesson, marked_sentences.line
# FROM marked_sentences
# WHERE marked_sentences.date_time > ? AND marked_sentences.date_time < ? AND marked_sentences.lesson = ?
# 2024-08-30 18:55:54,631 INFO sqlalchemy.engine.Engine [cached since 16.37s ago] ('0001-01-01 00:00:00.000000', '9999-12-31 23:59:59.999999', 78)
# 2024-08-30 18:55:54,632 INFO sqlalchemy.engine.Engine ROLLBACK
# 2024-08-30 18:55:54,632 INFO sqlalchemy.engine.Engine BEGIN (implicit)
# 2024-08-30 18:55:54,632 INFO sqlalchemy.engine.Engine SELECT marked_sentences.id, marked_sentences.date_time, marked_sentences.sentence, marked_sentences.comment, marked_sentences.lesson, marked_sentences.line
# FROM marked_sentences
# WHERE marked_sentences.date_time > ? AND marked_sentences.date_time < ? AND marked_sentences.lesson = ?
# 2024-08-30 18:55:54,632 INFO sqlalchemy.engine.Engine [cached since 16.37s ago] ('0001-01-01 00:00:00.000000', '9999-12-31 23:59:59.999999', 79)
# 2024-08-30 18:55:54,633 INFO sqlalchemy.engine.Engine ROLLBACK
# 2024-08-30 18:55:54,633 INFO sqlalchemy.engine.Engine BEGIN (implicit)
# 2024-08-30 18:55:54,633 INFO sqlalchemy.engine.Engine SELECT marked_sentences.id, marked_sentences.date_time, marked_sentences.sentence, marked_sentences.comment, marked_sentences.lesson, marked_sentences.line
# FROM marked_sentences
# WHERE marked_sentences.date_time > ? AND marked_sentences.date_time < ? AND marked_sentences.lesson = ?
# 2024-08-30 18:55:54,633 INFO sqlalchemy.engine.Engine [cached since 16.37s ago] ('0001-01-01 00:00:00.000000', '9999-12-31 23:59:59.999999', 80)
# 2024-08-30 18:55:54,634 INFO sqlalchemy.engine.Engine ROLLBACK
# 2024-08-30 18:55:54,634 INFO sqlalchemy.engine.Engine BEGIN (implicit)
# 2024-08-30 18:55:54,634 INFO sqlalchemy.engine.Engine SELECT marked_sentences.id, marked_sentences.date_time, marked_sentences.sentence, marked_sentences.comment, marked_sentences.lesson, marked_sentences.line
# FROM marked_sentences
# WHERE marked_sentences.date_time > ? AND marked_sentences.date_time < ? AND marked_sentences.lesson = ?
# 2024-08-30 18:55:54,634 INFO sqlalchemy.engine.Engine [cached since 16.37s ago] ('0001-01-01 00:00:00.000000', '9999-12-31 23:59:59.999999', 81)
# 2024-08-30 18:55:54,635 INFO sqlalchemy.engine.Engine ROLLBACK
# 2024-08-30 18:55:54,635 INFO sqlalchemy.engine.Engine BEGIN (implicit)
# 2024-08-30 18:55:54,635 INFO sqlalchemy.engine.Engine SELECT marked_sentences.id, marked_sentences.date_time, marked_sentences.sentence, marked_sentences.comment, marked_sentences.lesson, marked_sentences.line
# FROM marked_sentences
# WHERE marked_sentences.date_time > ? AND marked_sentences.date_time < ? AND marked_sentences.lesson = ?
# 2024-08-30 18:55:54,635 INFO sqlalchemy.engine.Engine [cached since 16.38s ago] ('0001-01-01 00:00:00.000000', '9999-12-31 23:59:59.999999', 82)
# 2024-08-30 18:55:54,636 INFO sqlalchemy.engine.Engine ROLLBACK
# 2024-08-30 18:55:54,636 INFO sqlalchemy.engine.Engine BEGIN (implicit)
# 2024-08-30 18:55:54,636 INFO sqlalchemy.engine.Engine SELECT marked_sentences.id, marked_sentences.date_time, marked_sentences.sentence, marked_sentences.comment, marked_sentences.lesson, marked_sentences.line
# FROM marked_sentences
# WHERE marked_sentences.date_time > ? AND marked_sentences.date_time < ? AND marked_sentences.lesson = ?
# 2024-08-30 18:55:54,637 INFO sqlalchemy.engine.Engine [cached since 16.38s ago] ('0001-01-01 00:00:00.000000', '9999-12-31 23:59:59.999999', 83)
# 2024-08-30 18:55:54,637 INFO sqlalchemy.engine.Engine ROLLBACK
# 2024-08-30 18:55:54,637 INFO sqlalchemy.engine.Engine BEGIN (implicit)
# 2024-08-30 18:55:54,637 INFO sqlalchemy.engine.Engine SELECT marked_sentences.id, marked_sentences.date_time, marked_sentences.sentence, marked_sentences.comment, marked_sentences.lesson, marked_sentences.line
# FROM marked_sentences
# WHERE marked_sentences.date_time > ? AND marked_sentences.date_time < ? AND marked_sentences.lesson = ?
# 2024-08-30 18:55:54,638 INFO sqlalchemy.engine.Engine [cached since 16.38s ago] ('0001-01-01 00:00:00.000000', '9999-12-31 23:59:59.999999', 84)
# 2024-08-30 18:55:54,638 INFO sqlalchemy.engine.Engine ROLLBACK
# 2024-08-30 18:55:54,638 INFO sqlalchemy.engine.Engine BEGIN (implicit)
# 2024-08-30 18:55:54,638 INFO sqlalchemy.engine.Engine SELECT marked_sentences.id, marked_sentences.date_time, marked_sentences.sentence, marked_sentences.comment, marked_sentences.lesson, marked_sentences.line
# FROM marked_sentences
# WHERE marked_sentences.date_time > ? AND marked_sentences.date_time < ? AND marked_sentences.lesson = ?
# 2024-08-30 18:55:54,639 INFO sqlalchemy.engine.Engine [cached since 16.38s ago] ('0001-01-01 00:00:00.000000', '9999-12-31 23:59:59.999999', 85)
# 2024-08-30 18:55:54,639 INFO sqlalchemy.engine.Engine ROLLBACK
# 2024-08-30 18:55:54,639 INFO sqlalchemy.engine.Engine BEGIN (implicit)
# 2024-08-30 18:55:54,639 INFO sqlalchemy.engine.Engine SELECT marked_sentences.id, marked_sentences.date_time, marked_sentences.sentence, marked_sentences.comment, marked_sentences.lesson, marked_sentences.line
# FROM marked_sentences
# WHERE marked_sentences.date_time > ? AND marked_sentences.date_time < ? AND marked_sentences.lesson = ?
# 2024-08-30 18:55:54,640 INFO sqlalchemy.engine.Engine [cached since 16.38s ago] ('0001-01-01 00:00:00.000000', '9999-12-31 23:59:59.999999', 86)
# 2024-08-30 18:55:54,640 INFO sqlalchemy.engine.Engine ROLLBACK
# 2024-08-30 18:55:54,640 INFO sqlalchemy.engine.Engine BEGIN (implicit)
# 2024-08-30 18:55:54,640 INFO sqlalchemy.engine.Engine SELECT marked_sentences.id, marked_sentences.date_time, marked_sentences.sentence, marked_sentences.comment, marked_sentences.lesson, marked_sentences.line
# FROM marked_sentences
# WHERE marked_sentences.date_time > ? AND marked_sentences.date_time < ? AND marked_sentences.lesson = ?
# 2024-08-30 18:55:54,641 INFO sqlalchemy.engine.Engine [cached since 16.38s ago] ('0001-01-01 00:00:00.000000', '9999-12-31 23:59:59.999999', 87)
# 2024-08-30 18:55:54,641 INFO sqlalchemy.engine.Engine ROLLBACK
# 2024-08-30 18:55:54,641 INFO sqlalchemy.engine.Engine BEGIN (implicit)
# 2024-08-30 18:55:54,641 INFO sqlalchemy.engine.Engine SELECT marked_sentences.id, marked_sentences.date_time, marked_sentences.sentence, marked_sentences.comment, marked_sentences.lesson, marked_sentences.line
# FROM marked_sentences
# WHERE marked_sentences.date_time > ? AND marked_sentences.date_time < ? AND marked_sentences.lesson = ?
# 2024-08-30 18:55:54,641 INFO sqlalchemy.engine.Engine [cached since 16.38s ago] ('0001-01-01 00:00:00.000000', '9999-12-31 23:59:59.999999', 88)
# 2024-08-30 18:55:54,642 INFO sqlalchemy.engine.Engine ROLLBACK
# 2024-08-30 18:55:54,642 INFO sqlalchemy.engine.Engine BEGIN (implicit)
# 2024-08-30 18:55:54,642 INFO sqlalchemy.engine.Engine SELECT marked_sentences.id, marked_sentences.date_time, marked_sentences.sentence, marked_sentences.comment, marked_sentences.lesson, marked_sentences.line
# FROM marked_sentences
# WHERE marked_sentences.date_time > ? AND marked_sentences.date_time < ? AND marked_sentences.lesson = ?
# 2024-08-30 18:55:54,642 INFO sqlalchemy.engine.Engine [cached since 16.38s ago] ('0001-01-01 00:00:00.000000', '9999-12-31 23:59:59.999999', 89)
# 2024-08-30 18:55:54,643 INFO sqlalchemy.engine.Engine ROLLBACK
# 2024-08-30 18:55:54,643 INFO sqlalchemy.engine.Engine BEGIN (implicit)
# 2024-08-30 18:55:54,643 INFO sqlalchemy.engine.Engine SELECT marked_sentences.id, marked_sentences.date_time, marked_sentences.sentence, marked_sentences.comment, marked_sentences.lesson, marked_sentences.line
# FROM marked_sentences
# WHERE marked_sentences.date_time > ? AND marked_sentences.date_time < ? AND marked_sentences.lesson = ?
# 2024-08-30 18:55:54,643 INFO sqlalchemy.engine.Engine [cached since 16.38s ago] ('0001-01-01 00:00:00.000000', '9999-12-31 23:59:59.999999', 90)
# 2024-08-30 18:55:54,644 INFO sqlalchemy.engine.Engine ROLLBACK
# 2024-08-30 18:55:54,644 INFO sqlalchemy.engine.Engine BEGIN (implicit)
# 2024-08-30 18:55:54,644 INFO sqlalchemy.engine.Engine SELECT marked_sentences.id, marked_sentences.date_time, marked_sentences.sentence, marked_sentences.comment, marked_sentences.lesson, marked_sentences.line
# FROM marked_sentences
# WHERE marked_sentences.date_time > ? AND marked_sentences.date_time < ? AND marked_sentences.lesson = ?
# 2024-08-30 18:55:54,644 INFO sqlalchemy.engine.Engine [cached since 16.38s ago] ('0001-01-01 00:00:00.000000', '9999-12-31 23:59:59.999999', 91)
# 2024-08-30 18:55:54,645 INFO sqlalchemy.engine.Engine ROLLBACK
# 2024-08-30 18:55:54,645 INFO sqlalchemy.engine.Engine BEGIN (implicit)
# 2024-08-30 18:55:54,645 INFO sqlalchemy.engine.Engine SELECT marked_sentences.id, marked_sentences.date_time, marked_sentences.sentence, marked_sentences.comment, marked_sentences.lesson, marked_sentences.line
# FROM marked_sentences
# WHERE marked_sentences.date_time > ? AND marked_sentences.date_time < ? AND marked_sentences.lesson = ?
# 2024-08-30 18:55:54,645 INFO sqlalchemy.engine.Engine [cached since 16.39s ago] ('0001-01-01 00:00:00.000000', '9999-12-31 23:59:59.999999', 92)
# 2024-08-30 18:55:54,646 INFO sqlalchemy.engine.Engine ROLLBACK
# 2024-08-30 18:55:54,646 INFO sqlalchemy.engine.Engine BEGIN (implicit)
# 2024-08-30 18:55:54,646 INFO sqlalchemy.engine.Engine SELECT marked_sentences.id, marked_sentences.date_time, marked_sentences.sentence, marked_sentences.comment, marked_sentences.lesson, marked_sentences.line
# FROM marked_sentences
# WHERE marked_sentences.date_time > ? AND marked_sentences.date_time < ? AND marked_sentences.lesson = ?
# 2024-08-30 18:55:54,647 INFO sqlalchemy.engine.Engine [cached since 16.39s ago] ('0001-01-01 00:00:00.000000', '9999-12-31 23:59:59.999999', 93)
# 2024-08-30 18:55:54,647 INFO sqlalchemy.engine.Engine ROLLBACK
# 2024-08-30 18:55:54,648 INFO sqlalchemy.engine.Engine BEGIN (implicit)
# 2024-08-30 18:55:54,648 INFO sqlalchemy.engine.Engine SELECT marked_sentences.id, marked_sentences.date_time, marked_sentences.sentence, marked_sentences.comment, marked_sentences.lesson, marked_sentences.line
# FROM marked_sentences
# WHERE marked_sentences.date_time > ? AND marked_sentences.date_time < ? AND marked_sentences.lesson = ?
# 2024-08-30 18:55:54,649 INFO sqlalchemy.engine.Engine [cached since 16.39s ago] ('0001-01-01 00:00:00.000000', '9999-12-31 23:59:59.999999', 94)
# 2024-08-30 18:55:54,649 INFO sqlalchemy.engine.Engine ROLLBACK
# 2024-08-30 18:55:54,650 INFO sqlalchemy.engine.Engine BEGIN (implicit)
# 2024-08-30 18:55:54,650 INFO sqlalchemy.engine.Engine SELECT marked_sentences.id, marked_sentences.date_time, marked_sentences.sentence, marked_sentences.comment, marked_sentences.lesson, marked_sentences.line
# FROM marked_sentences
# WHERE marked_sentences.date_time > ? AND marked_sentences.date_time < ? AND marked_sentences.lesson = ?
# 2024-08-30 18:55:54,650 INFO sqlalchemy.engine.Engine [cached since 16.39s ago] ('0001-01-01 00:00:00.000000', '9999-12-31 23:59:59.999999', 95)
# 2024-08-30 18:55:54,651 INFO sqlalchemy.engine.Engine ROLLBACK
# 2024-08-30 18:55:54,651 INFO sqlalchemy.engine.Engine BEGIN (implicit)
# 2024-08-30 18:55:54,651 INFO sqlalchemy.engine.Engine SELECT marked_sentences.id, marked_sentences.date_time, marked_sentences.sentence, marked_sentences.comment, marked_sentences.lesson, marked_sentences.line
# FROM marked_sentences
# WHERE marked_sentences.date_time > ? AND marked_sentences.date_time < ? AND marked_sentences.lesson = ?
# 2024-08-30 18:55:54,652 INFO sqlalchemy.engine.Engine [cached since 16.39s ago] ('0001-01-01 00:00:00.000000', '9999-12-31 23:59:59.999999', 96)
# 2024-08-30 18:55:54,652 INFO sqlalchemy.engine.Engine ROLLBACK
# 2024-08-30 18:55:54,653 INFO sqlalchemy.engine.Engine BEGIN (implicit)
# 2024-08-30 18:55:54,653 INFO sqlalchemy.engine.Engine SELECT marked_sentences.id, marked_sentences.date_time, marked_sentences.sentence, marked_sentences.comment, marked_sentences.lesson, marked_sentences.line
# FROM marked_sentences
# WHERE marked_sentences.date_time > ? AND marked_sentences.date_time < ? AND marked_sentences.lesson = ?
# 2024-08-30 18:55:54,653 INFO sqlalchemy.engine.Engine [cached since 16.39s ago] ('0001-01-01 00:00:00.000000', '9999-12-31 23:59:59.999999', 97)
# 2024-08-30 18:55:54,653 INFO sqlalchemy.engine.Engine ROLLBACK
# 2024-08-30 18:55:54,654 INFO sqlalchemy.engine.Engine BEGIN (implicit)
# 2024-08-30 18:55:54,654 INFO sqlalchemy.engine.Engine SELECT marked_sentences.id, marked_sentences.date_time, marked_sentences.sentence, marked_sentences.comment, marked_sentences.lesson, marked_sentences.line
# FROM marked_sentences
# WHERE marked_sentences.date_time > ? AND marked_sentences.date_time < ? AND marked_sentences.lesson = ?
# 2024-08-30 18:55:54,654 INFO sqlalchemy.engine.Engine [cached since 16.39s ago] ('0001-01-01 00:00:00.000000', '9999-12-31 23:59:59.999999', 98)
# 2024-08-30 18:55:54,654 INFO sqlalchemy.engine.Engine ROLLBACK
# 2024-08-30 18:55:54,655 INFO sqlalchemy.engine.Engine BEGIN (implicit)
# 2024-08-30 18:55:54,655 INFO sqlalchemy.engine.Engine SELECT marked_sentences.id, marked_sentences.date_time, marked_sentences.sentence, marked_sentences.comment, marked_sentences.lesson, marked_sentences.line
# FROM marked_sentences
# WHERE marked_sentences.date_time > ? AND marked_sentences.date_time < ? AND marked_sentences.lesson = ?
# 2024-08-30 18:55:54,655 INFO sqlalchemy.engine.Engine [cached since 16.4s ago] ('0001-01-01 00:00:00.000000', '9999-12-31 23:59:59.999999', 99)
# 2024-08-30 18:55:54,656 INFO sqlalchemy.engine.Engine ROLLBACK
# 2024-08-30 18:55:54,656 INFO sqlalchemy.engine.Engine BEGIN (implicit)
# 2024-08-30 18:55:54,656 INFO sqlalchemy.engine.Engine SELECT marked_sentences.id, marked_sentences.date_time, marked_sentences.sentence, marked_sentences.comment, marked_sentences.lesson, marked_sentences.line
# FROM marked_sentences
# WHERE marked_sentences.date_time > ? AND marked_sentences.date_time < ? AND marked_sentences.lesson = ?
# 2024-08-30 18:55:54,656 INFO sqlalchemy.engine.Engine [cached since 16.4s ago] ('0001-01-01 00:00:00.000000', '9999-12-31 23:59:59.999999', 100)
# 2024-08-30 18:55:54,657 INFO sqlalchemy.engine.Engine ROLLBACK

# %%
errors
# Out:
# {4: {datetime.datetime(2024, 8, 30, 18, 11, 11, 870753): {0: 'N4-Le<mark>c<b>ción</b> <b>cua</b>rta </mark>',
#    1: '<mark> S00-TITLE-Pres</mark>enta<b>cio</b>nes',
#    3: 'S02-Y él es <mark>mi <b>pa</b>dre, Mi<b>guel</b>.  </mark>',
#    4: '<mark> S03-<b>Mu</b>cho <b>gus</b>to. ¿<b>C</b></mark><b>ó</b>mo es<b>tá</b> us<b>ted</b>?',
#    9: 'T02-Y <b>e</b>lla e<mark>s mi her<b>ma</b>na.  </mark>',
#    10: '<mark> T03-<b>Mu</b>cho <b>gus</b>to.  </mark>',
#    11: '<mark></mark>'},
#   datetime.datetime(2024, 8, 30, 18, 37, 31, 497652): {7: 'T00-TRANSLATE-Ejer<b>ci</b>cio 1 – <mark>Tra<b>duz</b>ca</mark>',
#    10: 'T03-<b></b><mark><b>Mu</b>cho <b>gus</b>to.</mark>'}},
#  5: {datetime.datetime(2024, 8, 30, 18, 12, 5, 788656): {0: 'N5-Lec<b>ción</b> <b>q</b><mark><b>uin</b>ta </mark>',
#    1: '<mark> S00-TITLE-Entr</mark>e<b>vis</b>ta de tra<b>ba</b>jo',
#    4: 'S03-¡Enhor<mark>a<b>bue</b>na! ¿Ha<b>bla</b>mos in<b>glés</b> en<b>ton</b>ces?  </mark>',
#    5: '<mark> S04-E<b>jem</b>, el in<b>glés</b> lo </mark><b>le</b>o, <b>pe</b>ro no lo <b>ha</b>blo muy bien.',
#    9: 'T02-¿<b>Cuá</b>ntos i<b></b><mark><b>dio</b>mas es<b>cri</b>be us<b>ted</b>?  </mark>',
#    10: '<mark> T03-No <b>ha</b>blo fran<b>cés</b>.  </mark>',
#    11: '<mark></mark>'}},
#  45: {datetime.datetime(2024, 8, 30, 18, 13, 24, 955334): {0: 'N45-Lec<b>ción</b> cua<b>r</b><mark><b>en</b>ta y <b>cin</b>co </mark>',
#    1: '<mark> S00-TITLE-En el <b>cí</b>b</mark>er',
#    5: 'S04-<b>Va</b>ya, pues <b>me</b>nos mal que los <b>ten</b>go en el co<b>rre</b>o. ¿Me da un e<b>qui</b>po <b>pa</b>ra que los <mark>recu<b>pe</b>re</mark>?',
#    6: 'S05-Si, <b></b><mark><b>pón</b>gase</mark> en el 4.',
#    8: 'S07-¿Ah? <b></b><mark><b>Co</b>ja</mark> el 6.'}}}

# %%
errors[4]
# Out:
# {datetime.datetime(2024, 8, 30, 18, 11, 11, 870753): {0: 'N4-Le<mark>c<b>ción</b> <b>cua</b>rta </mark>',
#   1: '<mark> S00-TITLE-Pres</mark>enta<b>cio</b>nes',
#   3: 'S02-Y él es <mark>mi <b>pa</b>dre, Mi<b>guel</b>.  </mark>',
#   4: '<mark> S03-<b>Mu</b>cho <b>gus</b>to. ¿<b>C</b></mark><b>ó</b>mo es<b>tá</b> us<b>ted</b>?',
#   9: 'T02-Y <b>e</b>lla e<mark>s mi her<b>ma</b>na.  </mark>',
#   10: '<mark> T03-<b>Mu</b>cho <b>gus</b>to.  </mark>',
#   11: '<mark></mark>'},
#  datetime.datetime(2024, 8, 30, 18, 37, 31, 497652): {7: 'T00-TRANSLATE-Ejer<b>ci</b>cio 1 – <mark>Tra<b>duz</b>ca</mark>',
#   10: 'T03-<b></b><mark><b>Mu</b>cho <b>gus</b>to.</mark>'}}

# %%
errors.keys()[0]
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[10], line 1
# ----> 1 errors.keys()[0]
#
# TypeError: 'dict_keys' object is not subscriptable

# %%
from datetime import date

# %%
dir(date)
# Out:
# ['__add__',
#  '__class__',
#  '__delattr__',
#  '__dir__',
#  '__doc__',
#  '__eq__',
#  '__format__',
#  '__ge__',
#  '__getattribute__',
#  '__getstate__',
#  '__gt__',
#  '__hash__',
#  '__init__',
#  '__init_subclass__',
#  '__le__',
#  '__lt__',
#  '__ne__',
#  '__new__',
#  '__radd__',
#  '__reduce__',
#  '__reduce_ex__',
#  '__repr__',
#  '__rsub__',
#  '__setattr__',
#  '__sizeof__',
#  '__str__',
#  '__sub__',
#  '__subclasshook__',
#  'ctime',
#  'day',
#  'fromisocalendar',
#  'fromisoformat',
#  'fromordinal',
#  'fromtimestamp',
#  'isocalendar',
#  'isoformat',
#  'isoweekday',
#  'max',
#  'min',
#  'month',
#  'replace',
#  'resolution',
#  'strftime',
#  'timetuple',
#  'today',
#  'toordinal',
#  'weekday',
#  'year']

# %%
date.today()
# Out:
# datetime.date(2024, 8, 31)

# %%
from tonic_accent import get_lessons_with_errors

# %%
lessons = get_lessons_with_errors()
# Out:
# 2024-08-31 17:34:30,902 INFO sqlalchemy.engine.Engine BEGIN (implicit)
# 2024-08-31 17:34:30,905 INFO sqlalchemy.engine.Engine SELECT marked_sentences.id, marked_sentences.date_time, marked_sentences.sentence, marked_sentences.comment, marked_sentences.lesson, marked_sentences.line
# FROM marked_sentences
# WHERE marked_sentences.date_time > ? AND marked_sentences.date_time < ? AND marked_sentences.lesson = ?
# 2024-08-31 17:34:30,906 INFO sqlalchemy.engine.Engine [cached since 7144s ago] ('0001-01-01 00:00:00.000000', '9999-12-31 23:59:59.999999', 1)
# 2024-08-31 17:34:30,908 INFO sqlalchemy.engine.Engine ROLLBACK
# 2024-08-31 17:34:30,909 INFO sqlalchemy.engine.Engine BEGIN (implicit)
# 2024-08-31 17:34:30,910 INFO sqlalchemy.engine.Engine SELECT marked_sentences.id, marked_sentences.date_time, marked_sentences.sentence, marked_sentences.comment, marked_sentences.lesson, marked_sentences.line
# FROM marked_sentences
# WHERE marked_sentences.date_time > ? AND marked_sentences.date_time < ? AND marked_sentences.lesson = ?
# 2024-08-31 17:34:30,911 INFO sqlalchemy.engine.Engine [cached since 7144s ago] ('0001-01-01 00:00:00.000000', '9999-12-31 23:59:59.999999', 2)
# 2024-08-31 17:34:30,911 INFO sqlalchemy.engine.Engine ROLLBACK
# 2024-08-31 17:34:30,912 INFO sqlalchemy.engine.Engine BEGIN (implicit)
# 2024-08-31 17:34:30,913 INFO sqlalchemy.engine.Engine SELECT marked_sentences.id, marked_sentences.date_time, marked_sentences.sentence, marked_sentences.comment, marked_sentences.lesson, marked_sentences.line
# FROM marked_sentences
# WHERE marked_sentences.date_time > ? AND marked_sentences.date_time < ? AND marked_sentences.lesson = ?
# 2024-08-31 17:34:30,914 INFO sqlalchemy.engine.Engine [cached since 7144s ago] ('0001-01-01 00:00:00.000000', '9999-12-31 23:59:59.999999', 3)
# 2024-08-31 17:34:30,915 INFO sqlalchemy.engine.Engine ROLLBACK
# 2024-08-31 17:34:30,916 INFO sqlalchemy.engine.Engine BEGIN (implicit)
# 2024-08-31 17:34:30,918 INFO sqlalchemy.engine.Engine SELECT marked_sentences.id, marked_sentences.date_time, marked_sentences.sentence, marked_sentences.comment, marked_sentences.lesson, marked_sentences.line
# FROM marked_sentences
# WHERE marked_sentences.date_time > ? AND marked_sentences.date_time < ? AND marked_sentences.lesson = ?
# 2024-08-31 17:34:30,918 INFO sqlalchemy.engine.Engine [cached since 7144s ago] ('0001-01-01 00:00:00.000000', '9999-12-31 23:59:59.999999', 4)
# 2024-08-31 17:34:30,920 INFO sqlalchemy.engine.Engine ROLLBACK
# 2024-08-31 17:34:30,922 INFO sqlalchemy.engine.Engine BEGIN (implicit)
# 2024-08-31 17:34:30,923 INFO sqlalchemy.engine.Engine SELECT marked_sentences.id, marked_sentences.date_time, marked_sentences.sentence, marked_sentences.comment, marked_sentences.lesson, marked_sentences.line
# FROM marked_sentences
# WHERE marked_sentences.date_time > ? AND marked_sentences.date_time < ? AND marked_sentences.lesson = ?
# 2024-08-31 17:34:30,923 INFO sqlalchemy.engine.Engine [cached since 7144s ago] ('0001-01-01 00:00:00.000000', '9999-12-31 23:59:59.999999', 5)
# 2024-08-31 17:34:30,925 INFO sqlalchemy.engine.Engine ROLLBACK
# 2024-08-31 17:34:30,926 INFO sqlalchemy.engine.Engine BEGIN (implicit)
# 2024-08-31 17:34:30,927 INFO sqlalchemy.engine.Engine SELECT marked_sentences.id, marked_sentences.date_time, marked_sentences.sentence, marked_sentences.comment, marked_sentences.lesson, marked_sentences.line
# FROM marked_sentences
# WHERE marked_sentences.date_time > ? AND marked_sentences.date_time < ? AND marked_sentences.lesson = ?
# 2024-08-31 17:34:30,928 INFO sqlalchemy.engine.Engine [cached since 7144s ago] ('0001-01-01 00:00:00.000000', '9999-12-31 23:59:59.999999', 6)
# 2024-08-31 17:34:30,929 INFO sqlalchemy.engine.Engine ROLLBACK
# 2024-08-31 17:34:30,930 INFO sqlalchemy.engine.Engine BEGIN (implicit)
# 2024-08-31 17:34:30,931 INFO sqlalchemy.engine.Engine SELECT marked_sentences.id, marked_sentences.date_time, marked_sentences.sentence, marked_sentences.comment, marked_sentences.lesson, marked_sentences.line
# FROM marked_sentences
# WHERE marked_sentences.date_time > ? AND marked_sentences.date_time < ? AND marked_sentences.lesson = ?
# 2024-08-31 17:34:30,931 INFO sqlalchemy.engine.Engine [cached since 7144s ago] ('0001-01-01 00:00:00.000000', '9999-12-31 23:59:59.999999', 7)
# 2024-08-31 17:34:30,932 INFO sqlalchemy.engine.Engine ROLLBACK
# 2024-08-31 17:34:30,932 INFO sqlalchemy.engine.Engine BEGIN (implicit)
# 2024-08-31 17:34:30,933 INFO sqlalchemy.engine.Engine SELECT marked_sentences.id, marked_sentences.date_time, marked_sentences.sentence, marked_sentences.comment, marked_sentences.lesson, marked_sentences.line
# FROM marked_sentences
# WHERE marked_sentences.date_time > ? AND marked_sentences.date_time < ? AND marked_sentences.lesson = ?
# 2024-08-31 17:34:30,933 INFO sqlalchemy.engine.Engine [cached since 7144s ago] ('0001-01-01 00:00:00.000000', '9999-12-31 23:59:59.999999', 8)
# 2024-08-31 17:34:30,934 INFO sqlalchemy.engine.Engine ROLLBACK
# 2024-08-31 17:34:30,934 INFO sqlalchemy.engine.Engine BEGIN (implicit)
# 2024-08-31 17:34:30,935 INFO sqlalchemy.engine.Engine SELECT marked_sentences.id, marked_sentences.date_time, marked_sentences.sentence, marked_sentences.comment, marked_sentences.lesson, marked_sentences.line
# FROM marked_sentences
# WHERE marked_sentences.date_time > ? AND marked_sentences.date_time < ? AND marked_sentences.lesson = ?
# 2024-08-31 17:34:30,935 INFO sqlalchemy.engine.Engine [cached since 7144s ago] ('0001-01-01 00:00:00.000000', '9999-12-31 23:59:59.999999', 9)
# 2024-08-31 17:34:30,935 INFO sqlalchemy.engine.Engine ROLLBACK
# 2024-08-31 17:34:30,936 INFO sqlalchemy.engine.Engine BEGIN (implicit)
# 2024-08-31 17:34:30,936 INFO sqlalchemy.engine.Engine SELECT marked_sentences.id, marked_sentences.date_time, marked_sentences.sentence, marked_sentences.comment, marked_sentences.lesson, marked_sentences.line
# FROM marked_sentences
# WHERE marked_sentences.date_time > ? AND marked_sentences.date_time < ? AND marked_sentences.lesson = ?
# 2024-08-31 17:34:30,937 INFO sqlalchemy.engine.Engine [cached since 7144s ago] ('0001-01-01 00:00:00.000000', '9999-12-31 23:59:59.999999', 10)
# 2024-08-31 17:34:30,937 INFO sqlalchemy.engine.Engine ROLLBACK
# 2024-08-31 17:34:30,938 INFO sqlalchemy.engine.Engine BEGIN (implicit)
# 2024-08-31 17:34:30,938 INFO sqlalchemy.engine.Engine SELECT marked_sentences.id, marked_sentences.date_time, marked_sentences.sentence, marked_sentences.comment, marked_sentences.lesson, marked_sentences.line
# FROM marked_sentences
# WHERE marked_sentences.date_time > ? AND marked_sentences.date_time < ? AND marked_sentences.lesson = ?
# 2024-08-31 17:34:30,938 INFO sqlalchemy.engine.Engine [cached since 7144s ago] ('0001-01-01 00:00:00.000000', '9999-12-31 23:59:59.999999', 11)
# 2024-08-31 17:34:30,939 INFO sqlalchemy.engine.Engine ROLLBACK
# 2024-08-31 17:34:30,939 INFO sqlalchemy.engine.Engine BEGIN (implicit)
# 2024-08-31 17:34:30,940 INFO sqlalchemy.engine.Engine SELECT marked_sentences.id, marked_sentences.date_time, marked_sentences.sentence, marked_sentences.comment, marked_sentences.lesson, marked_sentences.line
# FROM marked_sentences
# WHERE marked_sentences.date_time > ? AND marked_sentences.date_time < ? AND marked_sentences.lesson = ?
# 2024-08-31 17:34:30,940 INFO sqlalchemy.engine.Engine [cached since 7144s ago] ('0001-01-01 00:00:00.000000', '9999-12-31 23:59:59.999999', 12)
# 2024-08-31 17:34:30,940 INFO sqlalchemy.engine.Engine ROLLBACK
# 2024-08-31 17:34:30,941 INFO sqlalchemy.engine.Engine BEGIN (implicit)
# 2024-08-31 17:34:30,941 INFO sqlalchemy.engine.Engine SELECT marked_sentences.id, marked_sentences.date_time, marked_sentences.sentence, marked_sentences.comment, marked_sentences.lesson, marked_sentences.line
# FROM marked_sentences
# WHERE marked_sentences.date_time > ? AND marked_sentences.date_time < ? AND marked_sentences.lesson = ?
# 2024-08-31 17:34:30,941 INFO sqlalchemy.engine.Engine [cached since 7144s ago] ('0001-01-01 00:00:00.000000', '9999-12-31 23:59:59.999999', 13)
# 2024-08-31 17:34:30,942 INFO sqlalchemy.engine.Engine ROLLBACK
# 2024-08-31 17:34:30,942 INFO sqlalchemy.engine.Engine BEGIN (implicit)
# 2024-08-31 17:34:30,942 INFO sqlalchemy.engine.Engine SELECT marked_sentences.id, marked_sentences.date_time, marked_sentences.sentence, marked_sentences.comment, marked_sentences.lesson, marked_sentences.line
# FROM marked_sentences
# WHERE marked_sentences.date_time > ? AND marked_sentences.date_time < ? AND marked_sentences.lesson = ?
# 2024-08-31 17:34:30,943 INFO sqlalchemy.engine.Engine [cached since 7144s ago] ('0001-01-01 00:00:00.000000', '9999-12-31 23:59:59.999999', 14)
# 2024-08-31 17:34:30,943 INFO sqlalchemy.engine.Engine ROLLBACK
# 2024-08-31 17:34:30,944 INFO sqlalchemy.engine.Engine BEGIN (implicit)
# 2024-08-31 17:34:30,944 INFO sqlalchemy.engine.Engine SELECT marked_sentences.id, marked_sentences.date_time, marked_sentences.sentence, marked_sentences.comment, marked_sentences.lesson, marked_sentences.line
# FROM marked_sentences
# WHERE marked_sentences.date_time > ? AND marked_sentences.date_time < ? AND marked_sentences.lesson = ?
# 2024-08-31 17:34:30,944 INFO sqlalchemy.engine.Engine [cached since 7144s ago] ('0001-01-01 00:00:00.000000', '9999-12-31 23:59:59.999999', 15)
# 2024-08-31 17:34:30,944 INFO sqlalchemy.engine.Engine ROLLBACK
# 2024-08-31 17:34:30,945 INFO sqlalchemy.engine.Engine BEGIN (implicit)
# 2024-08-31 17:34:30,945 INFO sqlalchemy.engine.Engine SELECT marked_sentences.id, marked_sentences.date_time, marked_sentences.sentence, marked_sentences.comment, marked_sentences.lesson, marked_sentences.line
# FROM marked_sentences
# WHERE marked_sentences.date_time > ? AND marked_sentences.date_time < ? AND marked_sentences.lesson = ?
# 2024-08-31 17:34:30,945 INFO sqlalchemy.engine.Engine [cached since 7144s ago] ('0001-01-01 00:00:00.000000', '9999-12-31 23:59:59.999999', 16)
# 2024-08-31 17:34:30,948 INFO sqlalchemy.engine.Engine ROLLBACK
# 2024-08-31 17:34:30,949 INFO sqlalchemy.engine.Engine BEGIN (implicit)
# 2024-08-31 17:34:30,949 INFO sqlalchemy.engine.Engine SELECT marked_sentences.id, marked_sentences.date_time, marked_sentences.sentence, marked_sentences.comment, marked_sentences.lesson, marked_sentences.line
# FROM marked_sentences
# WHERE marked_sentences.date_time > ? AND marked_sentences.date_time < ? AND marked_sentences.lesson = ?
# 2024-08-31 17:34:30,950 INFO sqlalchemy.engine.Engine [cached since 7144s ago] ('0001-01-01 00:00:00.000000', '9999-12-31 23:59:59.999999', 17)
# 2024-08-31 17:34:30,950 INFO sqlalchemy.engine.Engine ROLLBACK
# 2024-08-31 17:34:30,951 INFO sqlalchemy.engine.Engine BEGIN (implicit)
# 2024-08-31 17:34:30,952 INFO sqlalchemy.engine.Engine SELECT marked_sentences.id, marked_sentences.date_time, marked_sentences.sentence, marked_sentences.comment, marked_sentences.lesson, marked_sentences.line
# FROM marked_sentences
# WHERE marked_sentences.date_time > ? AND marked_sentences.date_time < ? AND marked_sentences.lesson = ?
# 2024-08-31 17:34:30,952 INFO sqlalchemy.engine.Engine [cached since 7144s ago] ('0001-01-01 00:00:00.000000', '9999-12-31 23:59:59.999999', 18)
# 2024-08-31 17:34:30,953 INFO sqlalchemy.engine.Engine ROLLBACK
# 2024-08-31 17:34:30,954 INFO sqlalchemy.engine.Engine BEGIN (implicit)
# 2024-08-31 17:34:30,954 INFO sqlalchemy.engine.Engine SELECT marked_sentences.id, marked_sentences.date_time, marked_sentences.sentence, marked_sentences.comment, marked_sentences.lesson, marked_sentences.line
# FROM marked_sentences
# WHERE marked_sentences.date_time > ? AND marked_sentences.date_time < ? AND marked_sentences.lesson = ?
# 2024-08-31 17:34:30,955 INFO sqlalchemy.engine.Engine [cached since 7144s ago] ('0001-01-01 00:00:00.000000', '9999-12-31 23:59:59.999999', 19)
# 2024-08-31 17:34:30,955 INFO sqlalchemy.engine.Engine ROLLBACK
# 2024-08-31 17:34:30,956 INFO sqlalchemy.engine.Engine BEGIN (implicit)
# 2024-08-31 17:34:30,956 INFO sqlalchemy.engine.Engine SELECT marked_sentences.id, marked_sentences.date_time, marked_sentences.sentence, marked_sentences.comment, marked_sentences.lesson, marked_sentences.line
# FROM marked_sentences
# WHERE marked_sentences.date_time > ? AND marked_sentences.date_time < ? AND marked_sentences.lesson = ?
# 2024-08-31 17:34:30,957 INFO sqlalchemy.engine.Engine [cached since 7144s ago] ('0001-01-01 00:00:00.000000', '9999-12-31 23:59:59.999999', 20)
# 2024-08-31 17:34:30,958 INFO sqlalchemy.engine.Engine ROLLBACK
# 2024-08-31 17:34:30,959 INFO sqlalchemy.engine.Engine BEGIN (implicit)
# 2024-08-31 17:34:30,959 INFO sqlalchemy.engine.Engine SELECT marked_sentences.id, marked_sentences.date_time, marked_sentences.sentence, marked_sentences.comment, marked_sentences.lesson, marked_sentences.line
# FROM marked_sentences
# WHERE marked_sentences.date_time > ? AND marked_sentences.date_time < ? AND marked_sentences.lesson = ?
# 2024-08-31 17:34:30,959 INFO sqlalchemy.engine.Engine [cached since 7144s ago] ('0001-01-01 00:00:00.000000', '9999-12-31 23:59:59.999999', 21)
# 2024-08-31 17:34:30,960 INFO sqlalchemy.engine.Engine ROLLBACK
# 2024-08-31 17:34:30,960 INFO sqlalchemy.engine.Engine BEGIN (implicit)
# 2024-08-31 17:34:30,961 INFO sqlalchemy.engine.Engine SELECT marked_sentences.id, marked_sentences.date_time, marked_sentences.sentence, marked_sentences.comment, marked_sentences.lesson, marked_sentences.line
# FROM marked_sentences
# WHERE marked_sentences.date_time > ? AND marked_sentences.date_time < ? AND marked_sentences.lesson = ?
# 2024-08-31 17:34:30,961 INFO sqlalchemy.engine.Engine [cached since 7144s ago] ('0001-01-01 00:00:00.000000', '9999-12-31 23:59:59.999999', 22)
# 2024-08-31 17:34:30,961 INFO sqlalchemy.engine.Engine ROLLBACK
# 2024-08-31 17:34:30,961 INFO sqlalchemy.engine.Engine BEGIN (implicit)
# 2024-08-31 17:34:30,962 INFO sqlalchemy.engine.Engine SELECT marked_sentences.id, marked_sentences.date_time, marked_sentences.sentence, marked_sentences.comment, marked_sentences.lesson, marked_sentences.line
# FROM marked_sentences
# WHERE marked_sentences.date_time > ? AND marked_sentences.date_time < ? AND marked_sentences.lesson = ?
# 2024-08-31 17:34:30,962 INFO sqlalchemy.engine.Engine [cached since 7144s ago] ('0001-01-01 00:00:00.000000', '9999-12-31 23:59:59.999999', 23)
# 2024-08-31 17:34:30,962 INFO sqlalchemy.engine.Engine ROLLBACK
# 2024-08-31 17:34:30,963 INFO sqlalchemy.engine.Engine BEGIN (implicit)
# 2024-08-31 17:34:30,963 INFO sqlalchemy.engine.Engine SELECT marked_sentences.id, marked_sentences.date_time, marked_sentences.sentence, marked_sentences.comment, marked_sentences.lesson, marked_sentences.line
# FROM marked_sentences
# WHERE marked_sentences.date_time > ? AND marked_sentences.date_time < ? AND marked_sentences.lesson = ?
# 2024-08-31 17:34:30,963 INFO sqlalchemy.engine.Engine [cached since 7144s ago] ('0001-01-01 00:00:00.000000', '9999-12-31 23:59:59.999999', 24)
# 2024-08-31 17:34:30,964 INFO sqlalchemy.engine.Engine ROLLBACK
# 2024-08-31 17:34:30,964 INFO sqlalchemy.engine.Engine BEGIN (implicit)
# 2024-08-31 17:34:30,964 INFO sqlalchemy.engine.Engine SELECT marked_sentences.id, marked_sentences.date_time, marked_sentences.sentence, marked_sentences.comment, marked_sentences.lesson, marked_sentences.line
# FROM marked_sentences
# WHERE marked_sentences.date_time > ? AND marked_sentences.date_time < ? AND marked_sentences.lesson = ?
# 2024-08-31 17:34:30,965 INFO sqlalchemy.engine.Engine [cached since 7144s ago] ('0001-01-01 00:00:00.000000', '9999-12-31 23:59:59.999999', 25)
# 2024-08-31 17:34:30,965 INFO sqlalchemy.engine.Engine ROLLBACK
# 2024-08-31 17:34:30,965 INFO sqlalchemy.engine.Engine BEGIN (implicit)
# 2024-08-31 17:34:30,966 INFO sqlalchemy.engine.Engine SELECT marked_sentences.id, marked_sentences.date_time, marked_sentences.sentence, marked_sentences.comment, marked_sentences.lesson, marked_sentences.line
# FROM marked_sentences
# WHERE marked_sentences.date_time > ? AND marked_sentences.date_time < ? AND marked_sentences.lesson = ?
# 2024-08-31 17:34:30,966 INFO sqlalchemy.engine.Engine [cached since 7144s ago] ('0001-01-01 00:00:00.000000', '9999-12-31 23:59:59.999999', 26)
# 2024-08-31 17:34:30,966 INFO sqlalchemy.engine.Engine ROLLBACK
# 2024-08-31 17:34:30,967 INFO sqlalchemy.engine.Engine BEGIN (implicit)
# 2024-08-31 17:34:30,967 INFO sqlalchemy.engine.Engine SELECT marked_sentences.id, marked_sentences.date_time, marked_sentences.sentence, marked_sentences.comment, marked_sentences.lesson, marked_sentences.line
# FROM marked_sentences
# WHERE marked_sentences.date_time > ? AND marked_sentences.date_time < ? AND marked_sentences.lesson = ?
# 2024-08-31 17:34:30,967 INFO sqlalchemy.engine.Engine [cached since 7144s ago] ('0001-01-01 00:00:00.000000', '9999-12-31 23:59:59.999999', 27)
# 2024-08-31 17:34:30,968 INFO sqlalchemy.engine.Engine ROLLBACK
# 2024-08-31 17:34:30,968 INFO sqlalchemy.engine.Engine BEGIN (implicit)
# 2024-08-31 17:34:30,968 INFO sqlalchemy.engine.Engine SELECT marked_sentences.id, marked_sentences.date_time, marked_sentences.sentence, marked_sentences.comment, marked_sentences.lesson, marked_sentences.line
# FROM marked_sentences
# WHERE marked_sentences.date_time > ? AND marked_sentences.date_time < ? AND marked_sentences.lesson = ?
# 2024-08-31 17:34:30,969 INFO sqlalchemy.engine.Engine [cached since 7144s ago] ('0001-01-01 00:00:00.000000', '9999-12-31 23:59:59.999999', 28)
# 2024-08-31 17:34:30,969 INFO sqlalchemy.engine.Engine ROLLBACK
# 2024-08-31 17:34:30,970 INFO sqlalchemy.engine.Engine BEGIN (implicit)
# 2024-08-31 17:34:30,970 INFO sqlalchemy.engine.Engine SELECT marked_sentences.id, marked_sentences.date_time, marked_sentences.sentence, marked_sentences.comment, marked_sentences.lesson, marked_sentences.line
# FROM marked_sentences
# WHERE marked_sentences.date_time > ? AND marked_sentences.date_time < ? AND marked_sentences.lesson = ?
# 2024-08-31 17:34:30,971 INFO sqlalchemy.engine.Engine [cached since 7144s ago] ('0001-01-01 00:00:00.000000', '9999-12-31 23:59:59.999999', 29)
# 2024-08-31 17:34:30,971 INFO sqlalchemy.engine.Engine ROLLBACK
# 2024-08-31 17:34:30,972 INFO sqlalchemy.engine.Engine BEGIN (implicit)
# 2024-08-31 17:34:30,972 INFO sqlalchemy.engine.Engine SELECT marked_sentences.id, marked_sentences.date_time, marked_sentences.sentence, marked_sentences.comment, marked_sentences.lesson, marked_sentences.line
# FROM marked_sentences
# WHERE marked_sentences.date_time > ? AND marked_sentences.date_time < ? AND marked_sentences.lesson = ?
# 2024-08-31 17:34:30,973 INFO sqlalchemy.engine.Engine [cached since 7144s ago] ('0001-01-01 00:00:00.000000', '9999-12-31 23:59:59.999999', 30)
# 2024-08-31 17:34:30,973 INFO sqlalchemy.engine.Engine ROLLBACK
# 2024-08-31 17:34:30,973 INFO sqlalchemy.engine.Engine BEGIN (implicit)
# 2024-08-31 17:34:30,974 INFO sqlalchemy.engine.Engine SELECT marked_sentences.id, marked_sentences.date_time, marked_sentences.sentence, marked_sentences.comment, marked_sentences.lesson, marked_sentences.line
# FROM marked_sentences
# WHERE marked_sentences.date_time > ? AND marked_sentences.date_time < ? AND marked_sentences.lesson = ?
# 2024-08-31 17:34:30,974 INFO sqlalchemy.engine.Engine [cached since 7144s ago] ('0001-01-01 00:00:00.000000', '9999-12-31 23:59:59.999999', 31)
# 2024-08-31 17:34:30,974 INFO sqlalchemy.engine.Engine ROLLBACK
# 2024-08-31 17:34:30,975 INFO sqlalchemy.engine.Engine BEGIN (implicit)
# 2024-08-31 17:34:30,975 INFO sqlalchemy.engine.Engine SELECT marked_sentences.id, marked_sentences.date_time, marked_sentences.sentence, marked_sentences.comment, marked_sentences.lesson, marked_sentences.line
# FROM marked_sentences
# WHERE marked_sentences.date_time > ? AND marked_sentences.date_time < ? AND marked_sentences.lesson = ?
# 2024-08-31 17:34:30,975 INFO sqlalchemy.engine.Engine [cached since 7144s ago] ('0001-01-01 00:00:00.000000', '9999-12-31 23:59:59.999999', 32)
# 2024-08-31 17:34:30,975 INFO sqlalchemy.engine.Engine ROLLBACK
# 2024-08-31 17:34:30,976 INFO sqlalchemy.engine.Engine BEGIN (implicit)
# 2024-08-31 17:34:30,976 INFO sqlalchemy.engine.Engine SELECT marked_sentences.id, marked_sentences.date_time, marked_sentences.sentence, marked_sentences.comment, marked_sentences.lesson, marked_sentences.line
# FROM marked_sentences
# WHERE marked_sentences.date_time > ? AND marked_sentences.date_time < ? AND marked_sentences.lesson = ?
# 2024-08-31 17:34:30,976 INFO sqlalchemy.engine.Engine [cached since 7144s ago] ('0001-01-01 00:00:00.000000', '9999-12-31 23:59:59.999999', 33)
# 2024-08-31 17:34:30,977 INFO sqlalchemy.engine.Engine ROLLBACK
# 2024-08-31 17:34:30,977 INFO sqlalchemy.engine.Engine BEGIN (implicit)
# 2024-08-31 17:34:30,977 INFO sqlalchemy.engine.Engine SELECT marked_sentences.id, marked_sentences.date_time, marked_sentences.sentence, marked_sentences.comment, marked_sentences.lesson, marked_sentences.line
# FROM marked_sentences
# WHERE marked_sentences.date_time > ? AND marked_sentences.date_time < ? AND marked_sentences.lesson = ?
# 2024-08-31 17:34:30,977 INFO sqlalchemy.engine.Engine [cached since 7144s ago] ('0001-01-01 00:00:00.000000', '9999-12-31 23:59:59.999999', 34)
# 2024-08-31 17:34:30,978 INFO sqlalchemy.engine.Engine ROLLBACK
# 2024-08-31 17:34:30,978 INFO sqlalchemy.engine.Engine BEGIN (implicit)
# 2024-08-31 17:34:30,978 INFO sqlalchemy.engine.Engine SELECT marked_sentences.id, marked_sentences.date_time, marked_sentences.sentence, marked_sentences.comment, marked_sentences.lesson, marked_sentences.line
# FROM marked_sentences
# WHERE marked_sentences.date_time > ? AND marked_sentences.date_time < ? AND marked_sentences.lesson = ?
# 2024-08-31 17:34:30,978 INFO sqlalchemy.engine.Engine [cached since 7144s ago] ('0001-01-01 00:00:00.000000', '9999-12-31 23:59:59.999999', 35)
# 2024-08-31 17:34:30,979 INFO sqlalchemy.engine.Engine ROLLBACK
# 2024-08-31 17:34:30,979 INFO sqlalchemy.engine.Engine BEGIN (implicit)
# 2024-08-31 17:34:30,979 INFO sqlalchemy.engine.Engine SELECT marked_sentences.id, marked_sentences.date_time, marked_sentences.sentence, marked_sentences.comment, marked_sentences.lesson, marked_sentences.line
# FROM marked_sentences
# WHERE marked_sentences.date_time > ? AND marked_sentences.date_time < ? AND marked_sentences.lesson = ?
# 2024-08-31 17:34:30,979 INFO sqlalchemy.engine.Engine [cached since 7144s ago] ('0001-01-01 00:00:00.000000', '9999-12-31 23:59:59.999999', 36)
# 2024-08-31 17:34:30,980 INFO sqlalchemy.engine.Engine ROLLBACK
# 2024-08-31 17:34:30,980 INFO sqlalchemy.engine.Engine BEGIN (implicit)
# 2024-08-31 17:34:30,980 INFO sqlalchemy.engine.Engine SELECT marked_sentences.id, marked_sentences.date_time, marked_sentences.sentence, marked_sentences.comment, marked_sentences.lesson, marked_sentences.line
# FROM marked_sentences
# WHERE marked_sentences.date_time > ? AND marked_sentences.date_time < ? AND marked_sentences.lesson = ?
# 2024-08-31 17:34:30,981 INFO sqlalchemy.engine.Engine [cached since 7144s ago] ('0001-01-01 00:00:00.000000', '9999-12-31 23:59:59.999999', 37)
# 2024-08-31 17:34:30,981 INFO sqlalchemy.engine.Engine ROLLBACK
# 2024-08-31 17:34:30,981 INFO sqlalchemy.engine.Engine BEGIN (implicit)
# 2024-08-31 17:34:30,981 INFO sqlalchemy.engine.Engine SELECT marked_sentences.id, marked_sentences.date_time, marked_sentences.sentence, marked_sentences.comment, marked_sentences.lesson, marked_sentences.line
# FROM marked_sentences
# WHERE marked_sentences.date_time > ? AND marked_sentences.date_time < ? AND marked_sentences.lesson = ?
# 2024-08-31 17:34:30,982 INFO sqlalchemy.engine.Engine [cached since 7144s ago] ('0001-01-01 00:00:00.000000', '9999-12-31 23:59:59.999999', 38)
# 2024-08-31 17:34:30,982 INFO sqlalchemy.engine.Engine ROLLBACK
# 2024-08-31 17:34:30,982 INFO sqlalchemy.engine.Engine BEGIN (implicit)
# 2024-08-31 17:34:30,983 INFO sqlalchemy.engine.Engine SELECT marked_sentences.id, marked_sentences.date_time, marked_sentences.sentence, marked_sentences.comment, marked_sentences.lesson, marked_sentences.line
# FROM marked_sentences
# WHERE marked_sentences.date_time > ? AND marked_sentences.date_time < ? AND marked_sentences.lesson = ?
# 2024-08-31 17:34:30,983 INFO sqlalchemy.engine.Engine [cached since 7144s ago] ('0001-01-01 00:00:00.000000', '9999-12-31 23:59:59.999999', 39)
# 2024-08-31 17:34:30,983 INFO sqlalchemy.engine.Engine ROLLBACK
# 2024-08-31 17:34:30,983 INFO sqlalchemy.engine.Engine BEGIN (implicit)
# 2024-08-31 17:34:30,984 INFO sqlalchemy.engine.Engine SELECT marked_sentences.id, marked_sentences.date_time, marked_sentences.sentence, marked_sentences.comment, marked_sentences.lesson, marked_sentences.line
# FROM marked_sentences
# WHERE marked_sentences.date_time > ? AND marked_sentences.date_time < ? AND marked_sentences.lesson = ?
# 2024-08-31 17:34:30,984 INFO sqlalchemy.engine.Engine [cached since 7144s ago] ('0001-01-01 00:00:00.000000', '9999-12-31 23:59:59.999999', 40)
# 2024-08-31 17:34:30,984 INFO sqlalchemy.engine.Engine ROLLBACK
# 2024-08-31 17:34:30,984 INFO sqlalchemy.engine.Engine BEGIN (implicit)
# 2024-08-31 17:34:30,985 INFO sqlalchemy.engine.Engine SELECT marked_sentences.id, marked_sentences.date_time, marked_sentences.sentence, marked_sentences.comment, marked_sentences.lesson, marked_sentences.line
# FROM marked_sentences
# WHERE marked_sentences.date_time > ? AND marked_sentences.date_time < ? AND marked_sentences.lesson = ?
# 2024-08-31 17:34:30,985 INFO sqlalchemy.engine.Engine [cached since 7144s ago] ('0001-01-01 00:00:00.000000', '9999-12-31 23:59:59.999999', 41)
# 2024-08-31 17:34:30,985 INFO sqlalchemy.engine.Engine ROLLBACK
# 2024-08-31 17:34:30,985 INFO sqlalchemy.engine.Engine BEGIN (implicit)
# 2024-08-31 17:34:30,986 INFO sqlalchemy.engine.Engine SELECT marked_sentences.id, marked_sentences.date_time, marked_sentences.sentence, marked_sentences.comment, marked_sentences.lesson, marked_sentences.line
# FROM marked_sentences
# WHERE marked_sentences.date_time > ? AND marked_sentences.date_time < ? AND marked_sentences.lesson = ?
# 2024-08-31 17:34:30,986 INFO sqlalchemy.engine.Engine [cached since 7144s ago] ('0001-01-01 00:00:00.000000', '9999-12-31 23:59:59.999999', 42)
# 2024-08-31 17:34:30,986 INFO sqlalchemy.engine.Engine ROLLBACK
# 2024-08-31 17:34:30,986 INFO sqlalchemy.engine.Engine BEGIN (implicit)
# 2024-08-31 17:34:30,987 INFO sqlalchemy.engine.Engine SELECT marked_sentences.id, marked_sentences.date_time, marked_sentences.sentence, marked_sentences.comment, marked_sentences.lesson, marked_sentences.line
# FROM marked_sentences
# WHERE marked_sentences.date_time > ? AND marked_sentences.date_time < ? AND marked_sentences.lesson = ?
# 2024-08-31 17:34:30,987 INFO sqlalchemy.engine.Engine [cached since 7144s ago] ('0001-01-01 00:00:00.000000', '9999-12-31 23:59:59.999999', 43)
# 2024-08-31 17:34:30,987 INFO sqlalchemy.engine.Engine ROLLBACK
# 2024-08-31 17:34:30,987 INFO sqlalchemy.engine.Engine BEGIN (implicit)
# 2024-08-31 17:34:30,988 INFO sqlalchemy.engine.Engine SELECT marked_sentences.id, marked_sentences.date_time, marked_sentences.sentence, marked_sentences.comment, marked_sentences.lesson, marked_sentences.line
# FROM marked_sentences
# WHERE marked_sentences.date_time > ? AND marked_sentences.date_time < ? AND marked_sentences.lesson = ?
# 2024-08-31 17:34:30,988 INFO sqlalchemy.engine.Engine [cached since 7144s ago] ('0001-01-01 00:00:00.000000', '9999-12-31 23:59:59.999999', 44)
# 2024-08-31 17:34:30,988 INFO sqlalchemy.engine.Engine ROLLBACK
# 2024-08-31 17:34:30,988 INFO sqlalchemy.engine.Engine BEGIN (implicit)
# 2024-08-31 17:34:30,989 INFO sqlalchemy.engine.Engine SELECT marked_sentences.id, marked_sentences.date_time, marked_sentences.sentence, marked_sentences.comment, marked_sentences.lesson, marked_sentences.line
# FROM marked_sentences
# WHERE marked_sentences.date_time > ? AND marked_sentences.date_time < ? AND marked_sentences.lesson = ?
# 2024-08-31 17:34:30,989 INFO sqlalchemy.engine.Engine [cached since 7144s ago] ('0001-01-01 00:00:00.000000', '9999-12-31 23:59:59.999999', 45)
# 2024-08-31 17:34:30,989 INFO sqlalchemy.engine.Engine ROLLBACK
# 2024-08-31 17:34:30,990 INFO sqlalchemy.engine.Engine BEGIN (implicit)
# 2024-08-31 17:34:30,990 INFO sqlalchemy.engine.Engine SELECT marked_sentences.id, marked_sentences.date_time, marked_sentences.sentence, marked_sentences.comment, marked_sentences.lesson, marked_sentences.line
# FROM marked_sentences
# WHERE marked_sentences.date_time > ? AND marked_sentences.date_time < ? AND marked_sentences.lesson = ?
# 2024-08-31 17:34:30,990 INFO sqlalchemy.engine.Engine [cached since 7144s ago] ('0001-01-01 00:00:00.000000', '9999-12-31 23:59:59.999999', 46)
# 2024-08-31 17:34:30,990 INFO sqlalchemy.engine.Engine ROLLBACK
# 2024-08-31 17:34:30,991 INFO sqlalchemy.engine.Engine BEGIN (implicit)
# 2024-08-31 17:34:30,991 INFO sqlalchemy.engine.Engine SELECT marked_sentences.id, marked_sentences.date_time, marked_sentences.sentence, marked_sentences.comment, marked_sentences.lesson, marked_sentences.line
# FROM marked_sentences
# WHERE marked_sentences.date_time > ? AND marked_sentences.date_time < ? AND marked_sentences.lesson = ?
# 2024-08-31 17:34:30,991 INFO sqlalchemy.engine.Engine [cached since 7144s ago] ('0001-01-01 00:00:00.000000', '9999-12-31 23:59:59.999999', 47)
# 2024-08-31 17:34:30,991 INFO sqlalchemy.engine.Engine ROLLBACK
# 2024-08-31 17:34:30,992 INFO sqlalchemy.engine.Engine BEGIN (implicit)
# 2024-08-31 17:34:30,992 INFO sqlalchemy.engine.Engine SELECT marked_sentences.id, marked_sentences.date_time, marked_sentences.sentence, marked_sentences.comment, marked_sentences.lesson, marked_sentences.line
# FROM marked_sentences
# WHERE marked_sentences.date_time > ? AND marked_sentences.date_time < ? AND marked_sentences.lesson = ?
# 2024-08-31 17:34:30,992 INFO sqlalchemy.engine.Engine [cached since 7144s ago] ('0001-01-01 00:00:00.000000', '9999-12-31 23:59:59.999999', 48)
# 2024-08-31 17:34:30,992 INFO sqlalchemy.engine.Engine ROLLBACK
# 2024-08-31 17:34:30,993 INFO sqlalchemy.engine.Engine BEGIN (implicit)
# 2024-08-31 17:34:30,993 INFO sqlalchemy.engine.Engine SELECT marked_sentences.id, marked_sentences.date_time, marked_sentences.sentence, marked_sentences.comment, marked_sentences.lesson, marked_sentences.line
# FROM marked_sentences
# WHERE marked_sentences.date_time > ? AND marked_sentences.date_time < ? AND marked_sentences.lesson = ?
# 2024-08-31 17:34:30,993 INFO sqlalchemy.engine.Engine [cached since 7144s ago] ('0001-01-01 00:00:00.000000', '9999-12-31 23:59:59.999999', 49)
# 2024-08-31 17:34:30,993 INFO sqlalchemy.engine.Engine ROLLBACK
# 2024-08-31 17:34:30,994 INFO sqlalchemy.engine.Engine BEGIN (implicit)
# 2024-08-31 17:34:30,994 INFO sqlalchemy.engine.Engine SELECT marked_sentences.id, marked_sentences.date_time, marked_sentences.sentence, marked_sentences.comment, marked_sentences.lesson, marked_sentences.line
# FROM marked_sentences
# WHERE marked_sentences.date_time > ? AND marked_sentences.date_time < ? AND marked_sentences.lesson = ?
# 2024-08-31 17:34:30,994 INFO sqlalchemy.engine.Engine [cached since 7144s ago] ('0001-01-01 00:00:00.000000', '9999-12-31 23:59:59.999999', 50)
# 2024-08-31 17:34:30,994 INFO sqlalchemy.engine.Engine ROLLBACK
# 2024-08-31 17:34:30,995 INFO sqlalchemy.engine.Engine BEGIN (implicit)
# 2024-08-31 17:34:30,995 INFO sqlalchemy.engine.Engine SELECT marked_sentences.id, marked_sentences.date_time, marked_sentences.sentence, marked_sentences.comment, marked_sentences.lesson, marked_sentences.line
# FROM marked_sentences
# WHERE marked_sentences.date_time > ? AND marked_sentences.date_time < ? AND marked_sentences.lesson = ?
# 2024-08-31 17:34:30,995 INFO sqlalchemy.engine.Engine [cached since 7144s ago] ('0001-01-01 00:00:00.000000', '9999-12-31 23:59:59.999999', 51)
# 2024-08-31 17:34:30,995 INFO sqlalchemy.engine.Engine ROLLBACK
# 2024-08-31 17:34:30,996 INFO sqlalchemy.engine.Engine BEGIN (implicit)
# 2024-08-31 17:34:30,996 INFO sqlalchemy.engine.Engine SELECT marked_sentences.id, marked_sentences.date_time, marked_sentences.sentence, marked_sentences.comment, marked_sentences.lesson, marked_sentences.line
# FROM marked_sentences
# WHERE marked_sentences.date_time > ? AND marked_sentences.date_time < ? AND marked_sentences.lesson = ?
# 2024-08-31 17:34:30,996 INFO sqlalchemy.engine.Engine [cached since 7144s ago] ('0001-01-01 00:00:00.000000', '9999-12-31 23:59:59.999999', 52)
# 2024-08-31 17:34:30,996 INFO sqlalchemy.engine.Engine ROLLBACK
# 2024-08-31 17:34:30,997 INFO sqlalchemy.engine.Engine BEGIN (implicit)
# 2024-08-31 17:34:30,997 INFO sqlalchemy.engine.Engine SELECT marked_sentences.id, marked_sentences.date_time, marked_sentences.sentence, marked_sentences.comment, marked_sentences.lesson, marked_sentences.line
# FROM marked_sentences
# WHERE marked_sentences.date_time > ? AND marked_sentences.date_time < ? AND marked_sentences.lesson = ?
# 2024-08-31 17:34:30,997 INFO sqlalchemy.engine.Engine [cached since 7144s ago] ('0001-01-01 00:00:00.000000', '9999-12-31 23:59:59.999999', 53)
# 2024-08-31 17:34:30,998 INFO sqlalchemy.engine.Engine ROLLBACK
# 2024-08-31 17:34:30,998 INFO sqlalchemy.engine.Engine BEGIN (implicit)
# 2024-08-31 17:34:30,998 INFO sqlalchemy.engine.Engine SELECT marked_sentences.id, marked_sentences.date_time, marked_sentences.sentence, marked_sentences.comment, marked_sentences.lesson, marked_sentences.line
# FROM marked_sentences
# WHERE marked_sentences.date_time > ? AND marked_sentences.date_time < ? AND marked_sentences.lesson = ?
# 2024-08-31 17:34:30,998 INFO sqlalchemy.engine.Engine [cached since 7144s ago] ('0001-01-01 00:00:00.000000', '9999-12-31 23:59:59.999999', 54)
# 2024-08-31 17:34:30,999 INFO sqlalchemy.engine.Engine ROLLBACK
# 2024-08-31 17:34:30,999 INFO sqlalchemy.engine.Engine BEGIN (implicit)
# 2024-08-31 17:34:30,999 INFO sqlalchemy.engine.Engine SELECT marked_sentences.id, marked_sentences.date_time, marked_sentences.sentence, marked_sentences.comment, marked_sentences.lesson, marked_sentences.line
# FROM marked_sentences
# WHERE marked_sentences.date_time > ? AND marked_sentences.date_time < ? AND marked_sentences.lesson = ?
# 2024-08-31 17:34:30,999 INFO sqlalchemy.engine.Engine [cached since 7144s ago] ('0001-01-01 00:00:00.000000', '9999-12-31 23:59:59.999999', 55)
# 2024-08-31 17:34:31,000 INFO sqlalchemy.engine.Engine ROLLBACK
# 2024-08-31 17:34:31,000 INFO sqlalchemy.engine.Engine BEGIN (implicit)
# 2024-08-31 17:34:31,000 INFO sqlalchemy.engine.Engine SELECT marked_sentences.id, marked_sentences.date_time, marked_sentences.sentence, marked_sentences.comment, marked_sentences.lesson, marked_sentences.line
# FROM marked_sentences
# WHERE marked_sentences.date_time > ? AND marked_sentences.date_time < ? AND marked_sentences.lesson = ?
# 2024-08-31 17:34:31,001 INFO sqlalchemy.engine.Engine [cached since 7144s ago] ('0001-01-01 00:00:00.000000', '9999-12-31 23:59:59.999999', 56)
# 2024-08-31 17:34:31,001 INFO sqlalchemy.engine.Engine ROLLBACK
# 2024-08-31 17:34:31,001 INFO sqlalchemy.engine.Engine BEGIN (implicit)
# 2024-08-31 17:34:31,001 INFO sqlalchemy.engine.Engine SELECT marked_sentences.id, marked_sentences.date_time, marked_sentences.sentence, marked_sentences.comment, marked_sentences.lesson, marked_sentences.line
# FROM marked_sentences
# WHERE marked_sentences.date_time > ? AND marked_sentences.date_time < ? AND marked_sentences.lesson = ?
# 2024-08-31 17:34:31,002 INFO sqlalchemy.engine.Engine [cached since 7144s ago] ('0001-01-01 00:00:00.000000', '9999-12-31 23:59:59.999999', 57)
# 2024-08-31 17:34:31,002 INFO sqlalchemy.engine.Engine ROLLBACK
# 2024-08-31 17:34:31,002 INFO sqlalchemy.engine.Engine BEGIN (implicit)
# 2024-08-31 17:34:31,003 INFO sqlalchemy.engine.Engine SELECT marked_sentences.id, marked_sentences.date_time, marked_sentences.sentence, marked_sentences.comment, marked_sentences.lesson, marked_sentences.line
# FROM marked_sentences
# WHERE marked_sentences.date_time > ? AND marked_sentences.date_time < ? AND marked_sentences.lesson = ?
# 2024-08-31 17:34:31,003 INFO sqlalchemy.engine.Engine [cached since 7144s ago] ('0001-01-01 00:00:00.000000', '9999-12-31 23:59:59.999999', 58)
# 2024-08-31 17:34:31,003 INFO sqlalchemy.engine.Engine ROLLBACK
# 2024-08-31 17:34:31,004 INFO sqlalchemy.engine.Engine BEGIN (implicit)
# 2024-08-31 17:34:31,004 INFO sqlalchemy.engine.Engine SELECT marked_sentences.id, marked_sentences.date_time, marked_sentences.sentence, marked_sentences.comment, marked_sentences.lesson, marked_sentences.line
# FROM marked_sentences
# WHERE marked_sentences.date_time > ? AND marked_sentences.date_time < ? AND marked_sentences.lesson = ?
# 2024-08-31 17:34:31,004 INFO sqlalchemy.engine.Engine [cached since 7144s ago] ('0001-01-01 00:00:00.000000', '9999-12-31 23:59:59.999999', 59)
# 2024-08-31 17:34:31,004 INFO sqlalchemy.engine.Engine ROLLBACK
# 2024-08-31 17:34:31,005 INFO sqlalchemy.engine.Engine BEGIN (implicit)
# 2024-08-31 17:34:31,005 INFO sqlalchemy.engine.Engine SELECT marked_sentences.id, marked_sentences.date_time, marked_sentences.sentence, marked_sentences.comment, marked_sentences.lesson, marked_sentences.line
# FROM marked_sentences
# WHERE marked_sentences.date_time > ? AND marked_sentences.date_time < ? AND marked_sentences.lesson = ?
# 2024-08-31 17:34:31,005 INFO sqlalchemy.engine.Engine [cached since 7144s ago] ('0001-01-01 00:00:00.000000', '9999-12-31 23:59:59.999999', 60)
# 2024-08-31 17:34:31,006 INFO sqlalchemy.engine.Engine ROLLBACK
# 2024-08-31 17:34:31,006 INFO sqlalchemy.engine.Engine BEGIN (implicit)
# 2024-08-31 17:34:31,006 INFO sqlalchemy.engine.Engine SELECT marked_sentences.id, marked_sentences.date_time, marked_sentences.sentence, marked_sentences.comment, marked_sentences.lesson, marked_sentences.line
# FROM marked_sentences
# WHERE marked_sentences.date_time > ? AND marked_sentences.date_time < ? AND marked_sentences.lesson = ?
# 2024-08-31 17:34:31,007 INFO sqlalchemy.engine.Engine [cached since 7144s ago] ('0001-01-01 00:00:00.000000', '9999-12-31 23:59:59.999999', 61)
# 2024-08-31 17:34:31,007 INFO sqlalchemy.engine.Engine ROLLBACK
# 2024-08-31 17:34:31,007 INFO sqlalchemy.engine.Engine BEGIN (implicit)
# 2024-08-31 17:34:31,007 INFO sqlalchemy.engine.Engine SELECT marked_sentences.id, marked_sentences.date_time, marked_sentences.sentence, marked_sentences.comment, marked_sentences.lesson, marked_sentences.line
# FROM marked_sentences
# WHERE marked_sentences.date_time > ? AND marked_sentences.date_time < ? AND marked_sentences.lesson = ?
# 2024-08-31 17:34:31,008 INFO sqlalchemy.engine.Engine [cached since 7144s ago] ('0001-01-01 00:00:00.000000', '9999-12-31 23:59:59.999999', 62)
# 2024-08-31 17:34:31,008 INFO sqlalchemy.engine.Engine ROLLBACK
# 2024-08-31 17:34:31,008 INFO sqlalchemy.engine.Engine BEGIN (implicit)
# 2024-08-31 17:34:31,009 INFO sqlalchemy.engine.Engine SELECT marked_sentences.id, marked_sentences.date_time, marked_sentences.sentence, marked_sentences.comment, marked_sentences.lesson, marked_sentences.line
# FROM marked_sentences
# WHERE marked_sentences.date_time > ? AND marked_sentences.date_time < ? AND marked_sentences.lesson = ?
# 2024-08-31 17:34:31,009 INFO sqlalchemy.engine.Engine [cached since 7144s ago] ('0001-01-01 00:00:00.000000', '9999-12-31 23:59:59.999999', 63)
# 2024-08-31 17:34:31,009 INFO sqlalchemy.engine.Engine ROLLBACK
# 2024-08-31 17:34:31,009 INFO sqlalchemy.engine.Engine BEGIN (implicit)
# 2024-08-31 17:34:31,010 INFO sqlalchemy.engine.Engine SELECT marked_sentences.id, marked_sentences.date_time, marked_sentences.sentence, marked_sentences.comment, marked_sentences.lesson, marked_sentences.line
# FROM marked_sentences
# WHERE marked_sentences.date_time > ? AND marked_sentences.date_time < ? AND marked_sentences.lesson = ?
# 2024-08-31 17:34:31,010 INFO sqlalchemy.engine.Engine [cached since 7144s ago] ('0001-01-01 00:00:00.000000', '9999-12-31 23:59:59.999999', 64)
# 2024-08-31 17:34:31,010 INFO sqlalchemy.engine.Engine ROLLBACK
# 2024-08-31 17:34:31,010 INFO sqlalchemy.engine.Engine BEGIN (implicit)
# 2024-08-31 17:34:31,011 INFO sqlalchemy.engine.Engine SELECT marked_sentences.id, marked_sentences.date_time, marked_sentences.sentence, marked_sentences.comment, marked_sentences.lesson, marked_sentences.line
# FROM marked_sentences
# WHERE marked_sentences.date_time > ? AND marked_sentences.date_time < ? AND marked_sentences.lesson = ?
# 2024-08-31 17:34:31,011 INFO sqlalchemy.engine.Engine [cached since 7144s ago] ('0001-01-01 00:00:00.000000', '9999-12-31 23:59:59.999999', 65)
# 2024-08-31 17:34:31,011 INFO sqlalchemy.engine.Engine ROLLBACK
# 2024-08-31 17:34:31,011 INFO sqlalchemy.engine.Engine BEGIN (implicit)
# 2024-08-31 17:34:31,012 INFO sqlalchemy.engine.Engine SELECT marked_sentences.id, marked_sentences.date_time, marked_sentences.sentence, marked_sentences.comment, marked_sentences.lesson, marked_sentences.line
# FROM marked_sentences
# WHERE marked_sentences.date_time > ? AND marked_sentences.date_time < ? AND marked_sentences.lesson = ?
# 2024-08-31 17:34:31,012 INFO sqlalchemy.engine.Engine [cached since 7144s ago] ('0001-01-01 00:00:00.000000', '9999-12-31 23:59:59.999999', 66)
# 2024-08-31 17:34:31,012 INFO sqlalchemy.engine.Engine ROLLBACK
# 2024-08-31 17:34:31,012 INFO sqlalchemy.engine.Engine BEGIN (implicit)
# 2024-08-31 17:34:31,013 INFO sqlalchemy.engine.Engine SELECT marked_sentences.id, marked_sentences.date_time, marked_sentences.sentence, marked_sentences.comment, marked_sentences.lesson, marked_sentences.line
# FROM marked_sentences
# WHERE marked_sentences.date_time > ? AND marked_sentences.date_time < ? AND marked_sentences.lesson = ?
# 2024-08-31 17:34:31,013 INFO sqlalchemy.engine.Engine [cached since 7144s ago] ('0001-01-01 00:00:00.000000', '9999-12-31 23:59:59.999999', 67)
# 2024-08-31 17:34:31,013 INFO sqlalchemy.engine.Engine ROLLBACK
# 2024-08-31 17:34:31,013 INFO sqlalchemy.engine.Engine BEGIN (implicit)
# 2024-08-31 17:34:31,014 INFO sqlalchemy.engine.Engine SELECT marked_sentences.id, marked_sentences.date_time, marked_sentences.sentence, marked_sentences.comment, marked_sentences.lesson, marked_sentences.line
# FROM marked_sentences
# WHERE marked_sentences.date_time > ? AND marked_sentences.date_time < ? AND marked_sentences.lesson = ?
# 2024-08-31 17:34:31,014 INFO sqlalchemy.engine.Engine [cached since 7144s ago] ('0001-01-01 00:00:00.000000', '9999-12-31 23:59:59.999999', 68)
# 2024-08-31 17:34:31,014 INFO sqlalchemy.engine.Engine ROLLBACK
# 2024-08-31 17:34:31,014 INFO sqlalchemy.engine.Engine BEGIN (implicit)
# 2024-08-31 17:34:31,015 INFO sqlalchemy.engine.Engine SELECT marked_sentences.id, marked_sentences.date_time, marked_sentences.sentence, marked_sentences.comment, marked_sentences.lesson, marked_sentences.line
# FROM marked_sentences
# WHERE marked_sentences.date_time > ? AND marked_sentences.date_time < ? AND marked_sentences.lesson = ?
# 2024-08-31 17:34:31,015 INFO sqlalchemy.engine.Engine [cached since 7144s ago] ('0001-01-01 00:00:00.000000', '9999-12-31 23:59:59.999999', 69)
# 2024-08-31 17:34:31,015 INFO sqlalchemy.engine.Engine ROLLBACK
# 2024-08-31 17:34:31,015 INFO sqlalchemy.engine.Engine BEGIN (implicit)
# 2024-08-31 17:34:31,016 INFO sqlalchemy.engine.Engine SELECT marked_sentences.id, marked_sentences.date_time, marked_sentences.sentence, marked_sentences.comment, marked_sentences.lesson, marked_sentences.line
# FROM marked_sentences
# WHERE marked_sentences.date_time > ? AND marked_sentences.date_time < ? AND marked_sentences.lesson = ?
# 2024-08-31 17:34:31,016 INFO sqlalchemy.engine.Engine [cached since 7144s ago] ('0001-01-01 00:00:00.000000', '9999-12-31 23:59:59.999999', 70)
# 2024-08-31 17:34:31,016 INFO sqlalchemy.engine.Engine ROLLBACK
# 2024-08-31 17:34:31,016 INFO sqlalchemy.engine.Engine BEGIN (implicit)
# 2024-08-31 17:34:31,017 INFO sqlalchemy.engine.Engine SELECT marked_sentences.id, marked_sentences.date_time, marked_sentences.sentence, marked_sentences.comment, marked_sentences.lesson, marked_sentences.line
# FROM marked_sentences
# WHERE marked_sentences.date_time > ? AND marked_sentences.date_time < ? AND marked_sentences.lesson = ?
# 2024-08-31 17:34:31,017 INFO sqlalchemy.engine.Engine [cached since 7144s ago] ('0001-01-01 00:00:00.000000', '9999-12-31 23:59:59.999999', 71)
# 2024-08-31 17:34:31,017 INFO sqlalchemy.engine.Engine ROLLBACK
# 2024-08-31 17:34:31,017 INFO sqlalchemy.engine.Engine BEGIN (implicit)
# 2024-08-31 17:34:31,018 INFO sqlalchemy.engine.Engine SELECT marked_sentences.id, marked_sentences.date_time, marked_sentences.sentence, marked_sentences.comment, marked_sentences.lesson, marked_sentences.line
# FROM marked_sentences
# WHERE marked_sentences.date_time > ? AND marked_sentences.date_time < ? AND marked_sentences.lesson = ?
# 2024-08-31 17:34:31,018 INFO sqlalchemy.engine.Engine [cached since 7144s ago] ('0001-01-01 00:00:00.000000', '9999-12-31 23:59:59.999999', 72)
# 2024-08-31 17:34:31,018 INFO sqlalchemy.engine.Engine ROLLBACK
# 2024-08-31 17:34:31,018 INFO sqlalchemy.engine.Engine BEGIN (implicit)
# 2024-08-31 17:34:31,019 INFO sqlalchemy.engine.Engine SELECT marked_sentences.id, marked_sentences.date_time, marked_sentences.sentence, marked_sentences.comment, marked_sentences.lesson, marked_sentences.line
# FROM marked_sentences
# WHERE marked_sentences.date_time > ? AND marked_sentences.date_time < ? AND marked_sentences.lesson = ?
# 2024-08-31 17:34:31,019 INFO sqlalchemy.engine.Engine [cached since 7144s ago] ('0001-01-01 00:00:00.000000', '9999-12-31 23:59:59.999999', 73)
# 2024-08-31 17:34:31,019 INFO sqlalchemy.engine.Engine ROLLBACK
# 2024-08-31 17:34:31,019 INFO sqlalchemy.engine.Engine BEGIN (implicit)
# 2024-08-31 17:34:31,020 INFO sqlalchemy.engine.Engine SELECT marked_sentences.id, marked_sentences.date_time, marked_sentences.sentence, marked_sentences.comment, marked_sentences.lesson, marked_sentences.line
# FROM marked_sentences
# WHERE marked_sentences.date_time > ? AND marked_sentences.date_time < ? AND marked_sentences.lesson = ?
# 2024-08-31 17:34:31,020 INFO sqlalchemy.engine.Engine [cached since 7144s ago] ('0001-01-01 00:00:00.000000', '9999-12-31 23:59:59.999999', 74)
# 2024-08-31 17:34:31,020 INFO sqlalchemy.engine.Engine ROLLBACK
# 2024-08-31 17:34:31,020 INFO sqlalchemy.engine.Engine BEGIN (implicit)
# 2024-08-31 17:34:31,021 INFO sqlalchemy.engine.Engine SELECT marked_sentences.id, marked_sentences.date_time, marked_sentences.sentence, marked_sentences.comment, marked_sentences.lesson, marked_sentences.line
# FROM marked_sentences
# WHERE marked_sentences.date_time > ? AND marked_sentences.date_time < ? AND marked_sentences.lesson = ?
# 2024-08-31 17:34:31,021 INFO sqlalchemy.engine.Engine [cached since 7144s ago] ('0001-01-01 00:00:00.000000', '9999-12-31 23:59:59.999999', 75)
# 2024-08-31 17:34:31,021 INFO sqlalchemy.engine.Engine ROLLBACK
# 2024-08-31 17:34:31,021 INFO sqlalchemy.engine.Engine BEGIN (implicit)
# 2024-08-31 17:34:31,022 INFO sqlalchemy.engine.Engine SELECT marked_sentences.id, marked_sentences.date_time, marked_sentences.sentence, marked_sentences.comment, marked_sentences.lesson, marked_sentences.line
# FROM marked_sentences
# WHERE marked_sentences.date_time > ? AND marked_sentences.date_time < ? AND marked_sentences.lesson = ?
# 2024-08-31 17:34:31,022 INFO sqlalchemy.engine.Engine [cached since 7144s ago] ('0001-01-01 00:00:00.000000', '9999-12-31 23:59:59.999999', 76)
# 2024-08-31 17:34:31,031 INFO sqlalchemy.engine.Engine ROLLBACK
# 2024-08-31 17:34:31,046 INFO sqlalchemy.engine.Engine BEGIN (implicit)
# 2024-08-31 17:34:31,047 INFO sqlalchemy.engine.Engine SELECT marked_sentences.id, marked_sentences.date_time, marked_sentences.sentence, marked_sentences.comment, marked_sentences.lesson, marked_sentences.line
# FROM marked_sentences
# WHERE marked_sentences.date_time > ? AND marked_sentences.date_time < ? AND marked_sentences.lesson = ?
# 2024-08-31 17:34:31,047 INFO sqlalchemy.engine.Engine [cached since 7144s ago] ('0001-01-01 00:00:00.000000', '9999-12-31 23:59:59.999999', 77)
# 2024-08-31 17:34:31,047 INFO sqlalchemy.engine.Engine ROLLBACK
# 2024-08-31 17:34:31,048 INFO sqlalchemy.engine.Engine BEGIN (implicit)
# 2024-08-31 17:34:31,048 INFO sqlalchemy.engine.Engine SELECT marked_sentences.id, marked_sentences.date_time, marked_sentences.sentence, marked_sentences.comment, marked_sentences.lesson, marked_sentences.line
# FROM marked_sentences
# WHERE marked_sentences.date_time > ? AND marked_sentences.date_time < ? AND marked_sentences.lesson = ?
# 2024-08-31 17:34:31,048 INFO sqlalchemy.engine.Engine [cached since 7144s ago] ('0001-01-01 00:00:00.000000', '9999-12-31 23:59:59.999999', 78)
# 2024-08-31 17:34:31,049 INFO sqlalchemy.engine.Engine ROLLBACK
# 2024-08-31 17:34:31,050 INFO sqlalchemy.engine.Engine BEGIN (implicit)
# 2024-08-31 17:34:31,051 INFO sqlalchemy.engine.Engine SELECT marked_sentences.id, marked_sentences.date_time, marked_sentences.sentence, marked_sentences.comment, marked_sentences.lesson, marked_sentences.line
# FROM marked_sentences
# WHERE marked_sentences.date_time > ? AND marked_sentences.date_time < ? AND marked_sentences.lesson = ?
# 2024-08-31 17:34:31,051 INFO sqlalchemy.engine.Engine [cached since 7144s ago] ('0001-01-01 00:00:00.000000', '9999-12-31 23:59:59.999999', 79)
# 2024-08-31 17:34:31,052 INFO sqlalchemy.engine.Engine ROLLBACK
# 2024-08-31 17:34:31,052 INFO sqlalchemy.engine.Engine BEGIN (implicit)
# 2024-08-31 17:34:31,053 INFO sqlalchemy.engine.Engine SELECT marked_sentences.id, marked_sentences.date_time, marked_sentences.sentence, marked_sentences.comment, marked_sentences.lesson, marked_sentences.line
# FROM marked_sentences
# WHERE marked_sentences.date_time > ? AND marked_sentences.date_time < ? AND marked_sentences.lesson = ?
# 2024-08-31 17:34:31,053 INFO sqlalchemy.engine.Engine [cached since 7144s ago] ('0001-01-01 00:00:00.000000', '9999-12-31 23:59:59.999999', 80)
# 2024-08-31 17:34:31,053 INFO sqlalchemy.engine.Engine ROLLBACK
# 2024-08-31 17:34:31,054 INFO sqlalchemy.engine.Engine BEGIN (implicit)
# 2024-08-31 17:34:31,054 INFO sqlalchemy.engine.Engine SELECT marked_sentences.id, marked_sentences.date_time, marked_sentences.sentence, marked_sentences.comment, marked_sentences.lesson, marked_sentences.line
# FROM marked_sentences
# WHERE marked_sentences.date_time > ? AND marked_sentences.date_time < ? AND marked_sentences.lesson = ?
# 2024-08-31 17:34:31,054 INFO sqlalchemy.engine.Engine [cached since 7144s ago] ('0001-01-01 00:00:00.000000', '9999-12-31 23:59:59.999999', 81)
# 2024-08-31 17:34:31,055 INFO sqlalchemy.engine.Engine ROLLBACK
# 2024-08-31 17:34:31,055 INFO sqlalchemy.engine.Engine BEGIN (implicit)
# 2024-08-31 17:34:31,055 INFO sqlalchemy.engine.Engine SELECT marked_sentences.id, marked_sentences.date_time, marked_sentences.sentence, marked_sentences.comment, marked_sentences.lesson, marked_sentences.line
# FROM marked_sentences
# WHERE marked_sentences.date_time > ? AND marked_sentences.date_time < ? AND marked_sentences.lesson = ?
# 2024-08-31 17:34:31,055 INFO sqlalchemy.engine.Engine [cached since 7144s ago] ('0001-01-01 00:00:00.000000', '9999-12-31 23:59:59.999999', 82)
# 2024-08-31 17:34:31,056 INFO sqlalchemy.engine.Engine ROLLBACK
# 2024-08-31 17:34:31,056 INFO sqlalchemy.engine.Engine BEGIN (implicit)
# 2024-08-31 17:34:31,056 INFO sqlalchemy.engine.Engine SELECT marked_sentences.id, marked_sentences.date_time, marked_sentences.sentence, marked_sentences.comment, marked_sentences.lesson, marked_sentences.line
# FROM marked_sentences
# WHERE marked_sentences.date_time > ? AND marked_sentences.date_time < ? AND marked_sentences.lesson = ?
# 2024-08-31 17:34:31,057 INFO sqlalchemy.engine.Engine [cached since 7144s ago] ('0001-01-01 00:00:00.000000', '9999-12-31 23:59:59.999999', 83)
# 2024-08-31 17:34:31,057 INFO sqlalchemy.engine.Engine ROLLBACK
# 2024-08-31 17:34:31,057 INFO sqlalchemy.engine.Engine BEGIN (implicit)
# 2024-08-31 17:34:31,057 INFO sqlalchemy.engine.Engine SELECT marked_sentences.id, marked_sentences.date_time, marked_sentences.sentence, marked_sentences.comment, marked_sentences.lesson, marked_sentences.line
# FROM marked_sentences
# WHERE marked_sentences.date_time > ? AND marked_sentences.date_time < ? AND marked_sentences.lesson = ?
# 2024-08-31 17:34:31,058 INFO sqlalchemy.engine.Engine [cached since 7144s ago] ('0001-01-01 00:00:00.000000', '9999-12-31 23:59:59.999999', 84)
# 2024-08-31 17:34:31,058 INFO sqlalchemy.engine.Engine ROLLBACK
# 2024-08-31 17:34:31,058 INFO sqlalchemy.engine.Engine BEGIN (implicit)
# 2024-08-31 17:34:31,059 INFO sqlalchemy.engine.Engine SELECT marked_sentences.id, marked_sentences.date_time, marked_sentences.sentence, marked_sentences.comment, marked_sentences.lesson, marked_sentences.line
# FROM marked_sentences
# WHERE marked_sentences.date_time > ? AND marked_sentences.date_time < ? AND marked_sentences.lesson = ?
# 2024-08-31 17:34:31,059 INFO sqlalchemy.engine.Engine [cached since 7144s ago] ('0001-01-01 00:00:00.000000', '9999-12-31 23:59:59.999999', 85)
# 2024-08-31 17:34:31,059 INFO sqlalchemy.engine.Engine ROLLBACK
# 2024-08-31 17:34:31,059 INFO sqlalchemy.engine.Engine BEGIN (implicit)
# 2024-08-31 17:34:31,060 INFO sqlalchemy.engine.Engine SELECT marked_sentences.id, marked_sentences.date_time, marked_sentences.sentence, marked_sentences.comment, marked_sentences.lesson, marked_sentences.line
# FROM marked_sentences
# WHERE marked_sentences.date_time > ? AND marked_sentences.date_time < ? AND marked_sentences.lesson = ?
# 2024-08-31 17:34:31,060 INFO sqlalchemy.engine.Engine [cached since 7144s ago] ('0001-01-01 00:00:00.000000', '9999-12-31 23:59:59.999999', 86)
# 2024-08-31 17:34:31,060 INFO sqlalchemy.engine.Engine ROLLBACK
# 2024-08-31 17:34:31,061 INFO sqlalchemy.engine.Engine BEGIN (implicit)
# 2024-08-31 17:34:31,061 INFO sqlalchemy.engine.Engine SELECT marked_sentences.id, marked_sentences.date_time, marked_sentences.sentence, marked_sentences.comment, marked_sentences.lesson, marked_sentences.line
# FROM marked_sentences
# WHERE marked_sentences.date_time > ? AND marked_sentences.date_time < ? AND marked_sentences.lesson = ?
# 2024-08-31 17:34:31,061 INFO sqlalchemy.engine.Engine [cached since 7144s ago] ('0001-01-01 00:00:00.000000', '9999-12-31 23:59:59.999999', 87)
# 2024-08-31 17:34:31,061 INFO sqlalchemy.engine.Engine ROLLBACK
# 2024-08-31 17:34:31,062 INFO sqlalchemy.engine.Engine BEGIN (implicit)
# 2024-08-31 17:34:31,062 INFO sqlalchemy.engine.Engine SELECT marked_sentences.id, marked_sentences.date_time, marked_sentences.sentence, marked_sentences.comment, marked_sentences.lesson, marked_sentences.line
# FROM marked_sentences
# WHERE marked_sentences.date_time > ? AND marked_sentences.date_time < ? AND marked_sentences.lesson = ?
# 2024-08-31 17:34:31,062 INFO sqlalchemy.engine.Engine [cached since 7144s ago] ('0001-01-01 00:00:00.000000', '9999-12-31 23:59:59.999999', 88)
# 2024-08-31 17:34:31,062 INFO sqlalchemy.engine.Engine ROLLBACK
# 2024-08-31 17:34:31,063 INFO sqlalchemy.engine.Engine BEGIN (implicit)
# 2024-08-31 17:34:31,063 INFO sqlalchemy.engine.Engine SELECT marked_sentences.id, marked_sentences.date_time, marked_sentences.sentence, marked_sentences.comment, marked_sentences.lesson, marked_sentences.line
# FROM marked_sentences
# WHERE marked_sentences.date_time > ? AND marked_sentences.date_time < ? AND marked_sentences.lesson = ?
# 2024-08-31 17:34:31,063 INFO sqlalchemy.engine.Engine [cached since 7144s ago] ('0001-01-01 00:00:00.000000', '9999-12-31 23:59:59.999999', 89)
# 2024-08-31 17:34:31,064 INFO sqlalchemy.engine.Engine ROLLBACK
# 2024-08-31 17:34:31,064 INFO sqlalchemy.engine.Engine BEGIN (implicit)
# 2024-08-31 17:34:31,065 INFO sqlalchemy.engine.Engine SELECT marked_sentences.id, marked_sentences.date_time, marked_sentences.sentence, marked_sentences.comment, marked_sentences.lesson, marked_sentences.line
# FROM marked_sentences
# WHERE marked_sentences.date_time > ? AND marked_sentences.date_time < ? AND marked_sentences.lesson = ?
# 2024-08-31 17:34:31,065 INFO sqlalchemy.engine.Engine [cached since 7144s ago] ('0001-01-01 00:00:00.000000', '9999-12-31 23:59:59.999999', 90)
# 2024-08-31 17:34:31,065 INFO sqlalchemy.engine.Engine ROLLBACK
# 2024-08-31 17:34:31,065 INFO sqlalchemy.engine.Engine BEGIN (implicit)
# 2024-08-31 17:34:31,066 INFO sqlalchemy.engine.Engine SELECT marked_sentences.id, marked_sentences.date_time, marked_sentences.sentence, marked_sentences.comment, marked_sentences.lesson, marked_sentences.line
# FROM marked_sentences
# WHERE marked_sentences.date_time > ? AND marked_sentences.date_time < ? AND marked_sentences.lesson = ?
# 2024-08-31 17:34:31,066 INFO sqlalchemy.engine.Engine [cached since 7144s ago] ('0001-01-01 00:00:00.000000', '9999-12-31 23:59:59.999999', 91)
# 2024-08-31 17:34:31,066 INFO sqlalchemy.engine.Engine ROLLBACK
# 2024-08-31 17:34:31,071 INFO sqlalchemy.engine.Engine BEGIN (implicit)
# 2024-08-31 17:34:31,073 INFO sqlalchemy.engine.Engine SELECT marked_sentences.id, marked_sentences.date_time, marked_sentences.sentence, marked_sentences.comment, marked_sentences.lesson, marked_sentences.line
# FROM marked_sentences
# WHERE marked_sentences.date_time > ? AND marked_sentences.date_time < ? AND marked_sentences.lesson = ?
# 2024-08-31 17:34:31,074 INFO sqlalchemy.engine.Engine [cached since 7144s ago] ('0001-01-01 00:00:00.000000', '9999-12-31 23:59:59.999999', 92)
# 2024-08-31 17:34:31,074 INFO sqlalchemy.engine.Engine ROLLBACK
# 2024-08-31 17:34:31,075 INFO sqlalchemy.engine.Engine BEGIN (implicit)
# 2024-08-31 17:34:31,076 INFO sqlalchemy.engine.Engine SELECT marked_sentences.id, marked_sentences.date_time, marked_sentences.sentence, marked_sentences.comment, marked_sentences.lesson, marked_sentences.line
# FROM marked_sentences
# WHERE marked_sentences.date_time > ? AND marked_sentences.date_time < ? AND marked_sentences.lesson = ?
# 2024-08-31 17:34:31,076 INFO sqlalchemy.engine.Engine [cached since 7144s ago] ('0001-01-01 00:00:00.000000', '9999-12-31 23:59:59.999999', 93)
# 2024-08-31 17:34:31,076 INFO sqlalchemy.engine.Engine ROLLBACK
# 2024-08-31 17:34:31,077 INFO sqlalchemy.engine.Engine BEGIN (implicit)
# 2024-08-31 17:34:31,077 INFO sqlalchemy.engine.Engine SELECT marked_sentences.id, marked_sentences.date_time, marked_sentences.sentence, marked_sentences.comment, marked_sentences.lesson, marked_sentences.line
# FROM marked_sentences
# WHERE marked_sentences.date_time > ? AND marked_sentences.date_time < ? AND marked_sentences.lesson = ?
# 2024-08-31 17:34:31,077 INFO sqlalchemy.engine.Engine [cached since 7144s ago] ('0001-01-01 00:00:00.000000', '9999-12-31 23:59:59.999999', 94)
# 2024-08-31 17:34:31,078 INFO sqlalchemy.engine.Engine ROLLBACK
# 2024-08-31 17:34:31,078 INFO sqlalchemy.engine.Engine BEGIN (implicit)
# 2024-08-31 17:34:31,078 INFO sqlalchemy.engine.Engine SELECT marked_sentences.id, marked_sentences.date_time, marked_sentences.sentence, marked_sentences.comment, marked_sentences.lesson, marked_sentences.line
# FROM marked_sentences
# WHERE marked_sentences.date_time > ? AND marked_sentences.date_time < ? AND marked_sentences.lesson = ?
# 2024-08-31 17:34:31,078 INFO sqlalchemy.engine.Engine [cached since 7144s ago] ('0001-01-01 00:00:00.000000', '9999-12-31 23:59:59.999999', 95)
# 2024-08-31 17:34:31,079 INFO sqlalchemy.engine.Engine ROLLBACK
# 2024-08-31 17:34:31,079 INFO sqlalchemy.engine.Engine BEGIN (implicit)
# 2024-08-31 17:34:31,079 INFO sqlalchemy.engine.Engine SELECT marked_sentences.id, marked_sentences.date_time, marked_sentences.sentence, marked_sentences.comment, marked_sentences.lesson, marked_sentences.line
# FROM marked_sentences
# WHERE marked_sentences.date_time > ? AND marked_sentences.date_time < ? AND marked_sentences.lesson = ?
# 2024-08-31 17:34:31,080 INFO sqlalchemy.engine.Engine [cached since 7144s ago] ('0001-01-01 00:00:00.000000', '9999-12-31 23:59:59.999999', 96)
# 2024-08-31 17:34:31,080 INFO sqlalchemy.engine.Engine ROLLBACK
# 2024-08-31 17:34:31,080 INFO sqlalchemy.engine.Engine BEGIN (implicit)
# 2024-08-31 17:34:31,080 INFO sqlalchemy.engine.Engine SELECT marked_sentences.id, marked_sentences.date_time, marked_sentences.sentence, marked_sentences.comment, marked_sentences.lesson, marked_sentences.line
# FROM marked_sentences
# WHERE marked_sentences.date_time > ? AND marked_sentences.date_time < ? AND marked_sentences.lesson = ?
# 2024-08-31 17:34:31,080 INFO sqlalchemy.engine.Engine [cached since 7144s ago] ('0001-01-01 00:00:00.000000', '9999-12-31 23:59:59.999999', 97)
# 2024-08-31 17:34:31,081 INFO sqlalchemy.engine.Engine ROLLBACK
# 2024-08-31 17:34:31,081 INFO sqlalchemy.engine.Engine BEGIN (implicit)
# 2024-08-31 17:34:31,081 INFO sqlalchemy.engine.Engine SELECT marked_sentences.id, marked_sentences.date_time, marked_sentences.sentence, marked_sentences.comment, marked_sentences.lesson, marked_sentences.line
# FROM marked_sentences
# WHERE marked_sentences.date_time > ? AND marked_sentences.date_time < ? AND marked_sentences.lesson = ?
# 2024-08-31 17:34:31,082 INFO sqlalchemy.engine.Engine [cached since 7144s ago] ('0001-01-01 00:00:00.000000', '9999-12-31 23:59:59.999999', 98)
# 2024-08-31 17:34:31,082 INFO sqlalchemy.engine.Engine ROLLBACK
# 2024-08-31 17:34:31,082 INFO sqlalchemy.engine.Engine BEGIN (implicit)
# 2024-08-31 17:34:31,083 INFO sqlalchemy.engine.Engine SELECT marked_sentences.id, marked_sentences.date_time, marked_sentences.sentence, marked_sentences.comment, marked_sentences.lesson, marked_sentences.line
# FROM marked_sentences
# WHERE marked_sentences.date_time > ? AND marked_sentences.date_time < ? AND marked_sentences.lesson = ?
# 2024-08-31 17:34:31,083 INFO sqlalchemy.engine.Engine [cached since 7144s ago] ('0001-01-01 00:00:00.000000', '9999-12-31 23:59:59.999999', 99)
# 2024-08-31 17:34:31,083 INFO sqlalchemy.engine.Engine ROLLBACK
# 2024-08-31 17:34:31,083 INFO sqlalchemy.engine.Engine BEGIN (implicit)
# 2024-08-31 17:34:31,083 INFO sqlalchemy.engine.Engine SELECT marked_sentences.id, marked_sentences.date_time, marked_sentences.sentence, marked_sentences.comment, marked_sentences.lesson, marked_sentences.line
# FROM marked_sentences
# WHERE marked_sentences.date_time > ? AND marked_sentences.date_time < ? AND marked_sentences.lesson = ?
# 2024-08-31 17:34:31,084 INFO sqlalchemy.engine.Engine [cached since 7144s ago] ('0001-01-01 00:00:00.000000', '9999-12-31 23:59:59.999999', 100)
# 2024-08-31 17:34:31,084 INFO sqlalchemy.engine.Engine ROLLBACK

# %%
lessons
# Out:
# {4: {datetime.datetime(2024, 8, 30, 18, 11, 11, 870753): ['N4-Le<mark>c<b>ción</b> <b>cua</b>rta </mark>',
#    '<mark> S00-TITLE-Pres</mark>enta<b>cio</b>nes',
#    'S01-Él es <b>Ra</b>fa, mi her<b>ma</b>no, y <b>e</b>lla es Luz, mi her<b>ma</b>na.',
#    'S02-Y él es <mark>mi <b>pa</b>dre, Mi<b>guel</b>.  </mark>',
#    '<mark> S03-<b>Mu</b>cho <b>gus</b>to. ¿<b>C</b></mark><b>ó</b>mo es<b>tá</b> us<b>ted</b>?',
#    'S04-Muy bien, <b>pe</b>ro ¡<b>há</b>blame de tú, por fa<b>vor</b>!',
#    'S05-¡<b>Va</b>le!',
#    'T00-TRANSLATE-Ejer<b>ci</b>cio 1 – Tra<b>duz</b>ca',
#    'T01-Él es mi <b>pa</b>dre.',
#    'T02-Y <b>e</b>lla e<mark>s mi her<b>ma</b>na.  </mark>',
#    '<mark> T03-<b>Mu</b>cho <b>gus</b>to.  </mark>',
#    '<mark></mark>',
#    'T05-¿<b>Có</b>mo es<b>tá</b> us<b>ted</b>?'],
#   datetime.datetime(2024, 8, 30, 18, 37, 31, 497652): ['N4-Lec<b>ción</b> <b>cua</b>rta',
#    'S00-TITLE-Presenta<b>cio</b>nes',
#    'S01-Él es <b>Ra</b>fa, mi her<b>ma</b>no, y <b>e</b>lla es Luz, mi her<b>ma</b>na.',
#    'S02-Y él es mi <b>pa</b>dre, Mi<b>guel</b>.',
#    'S03-<b>Mu</b>cho <b>gus</b>to. ¿<b>Có</b>mo es<b>tá</b> us<b>ted</b>?',
#    'S04-Muy bien, <b>pe</b>ro ¡<b>há</b>blame de tú, por fa<b>vor</b>!',
#    'S05-¡<b>Va</b>le!',
#    'T00-TRANSLATE-Ejer<b>ci</b>cio 1 – <mark>Tra<b>duz</b>ca</mark>',
#    'T01-Él es mi <b>pa</b>dre.',
#    'T02-Y <b>e</b>lla es mi her<b>ma</b>na.',
#    'T03-<b></b><mark><b>Mu</b>cho <b>gus</b>to.</mark>',
#    'T04-<b>Há</b>blame de tú, por fa<b>vor</b>.',
#    'T05-¿<b>Có</b>mo es<b>tá</b> us<b>ted</b>?']},
#  5: {datetime.datetime(2024, 8, 30, 18, 12, 5, 788656): ['N5-Lec<b>ción</b> <b>q</b><mark><b>uin</b>ta </mark>',
#    '<mark> S00-TITLE-Entr</mark>e<b>vis</b>ta de tra<b>ba</b>jo',
#    'S01-¿<b>Cuá</b>ntos i<b>dio</b>mas <b>ha</b>bla us<b>ted</b>?',
#    'S02-<b>Ha</b>blo in<b>glés</b> y fran<b>cés</b>.',
#    'S03-¡Enhor<mark>a<b>bue</b>na! ¿Ha<b>bla</b>mos in<b>glés</b> en<b>ton</b>ces?  </mark>',
#    '<mark> S04-E<b>jem</b>, el in<b>glés</b> lo </mark><b>le</b>o, <b>pe</b>ro no lo <b>ha</b>blo muy bien.',
#    'S05-Sí, <b>cla</b>ro Y el fran<b>cés</b>, ¿lo <b>ha</b>bla o <b>so</b>lo lo es<b>cri</b>be?',
#    'T00-TRANSLATE-Ejer<b>ci</b>cio 1 – Tra<b>duz</b>ca',
#    'T01-¿<b>Ha</b>bla us<b>ted</b> in<b>glés</b>?',
#    'T02-¿<b>Cuá</b>ntos i<b></b><mark><b>dio</b>mas es<b>cri</b>be us<b>ted</b>?  </mark>',
#    '<mark> T03-No <b>ha</b>blo fran<b>cés</b>.  </mark>',
#    '<mark></mark>',
#    'T05-Lo <b>le</b>o, <b>pe</b>ro no lo es<b>cri</b>bo.']},
#  45: {datetime.datetime(2024, 8, 30, 18, 13, 24, 955334): ['N45-Lec<b>ción</b> cua<b>r</b><mark><b>en</b>ta y <b>cin</b>co </mark>',
#    '<mark> S00-TITLE-En el <b>cí</b>b</mark>er',
#    'S01-Los ar<b>chi</b>vos es<b>tán</b> en la car<b>pe</b>ta <b>fo</b>tos.',
#    'S02-Sí, los <b>ve</b>o, se los im<b>pri</b>mo ense<b>gui</b>da.',
#    'S03-¡Oh, per<b>dón</b>, los he bo<b>rra</b>do en vez de impri<b>mir</b>los!',
#    'S04-<b>Va</b>ya, pues <b>me</b>nos mal que los <b>ten</b>go en el co<b>rre</b>o. ¿Me da un e<b>qui</b>po <b>pa</b>ra que los <mark>recu<b>pe</b>re</mark>?',
#    'S05-Si, <b></b><mark><b>pón</b>gase</mark> en el 4.',
#    'S06-<b>Oi</b>ga, el ordena<b>dor</b> no se en<b>cien</b>de.',
#    'S07-¿Ah? <b></b><mark><b>Co</b>ja</mark> el 6.',
#    'S08-Y el te<b>cla</b>do de <b>es</b>te no fun<b>cio</b>na.',
#    'S09-Qué <b>ra</b>ro, <b>va</b>ya al e<b>qui</b>po 8.',
#    'S10-<b>Mi</b>re, ya es<b>tá</b> bien, de<b>vuél</b>vame el pen y me voy.',
#    'S11-<b>Co</b>mo us<b>ted</b> <b>quie</b>ra, son dos con cin<b>cuen</b>ta.',
#    'S12-¿Y en<b>ci</b>ma <b>quie</b>re co<b>brar</b>? ¡<b>Pe</b>ro qué <b>ca</b>ra <b>du</b>ra!',
#    'S13-No se <b>pon</b>ga ner<b>vio</b>so. ¡Es <b>pa</b>ra la <b>cá</b>mara o<b>cul</b>ta!',
#    'T00-TRANSLATE-Ejer<b>ci</b>cio 1 – Tra<b>duz</b>ca',
#    'T01-<b>Me</b>nos mal que <b>ten</b>go tam<b>bién</b> los ar<b>chi</b>vos en el pen.',
#    'T02-<b>U</b>na vez impri<b>mi</b>da, ¿<b>pue</b>do bo<b>rrar</b> la car<b>pe</b>ta?',
#    'T03-Qué <b>ra</b>ro, el te<b>cla</b>do no fun<b>cio</b>na.',
#    'T04-<b>Es</b>te ordena<b>dor</b> no se en<b>cien</b>de <b>pón</b>gase en <b>o</b>tro e<b>qui</b>po.',
#    'T05-No te <b>pon</b>gas ner<b>vio</b>so, co<b>noz</b>co <b>o</b>tro <b>cí</b>ber me<b>jor</b> que <b>es</b>te.']}}

# %%
lessons[4]
# Out:
# {datetime.datetime(2024, 8, 30, 18, 11, 11, 870753): ['N4-Le<mark>c<b>ción</b> <b>cua</b>rta </mark>',
#   '<mark> S00-TITLE-Pres</mark>enta<b>cio</b>nes',
#   'S01-Él es <b>Ra</b>fa, mi her<b>ma</b>no, y <b>e</b>lla es Luz, mi her<b>ma</b>na.',
#   'S02-Y él es <mark>mi <b>pa</b>dre, Mi<b>guel</b>.  </mark>',
#   '<mark> S03-<b>Mu</b>cho <b>gus</b>to. ¿<b>C</b></mark><b>ó</b>mo es<b>tá</b> us<b>ted</b>?',
#   'S04-Muy bien, <b>pe</b>ro ¡<b>há</b>blame de tú, por fa<b>vor</b>!',
#   'S05-¡<b>Va</b>le!',
#   'T00-TRANSLATE-Ejer<b>ci</b>cio 1 – Tra<b>duz</b>ca',
#   'T01-Él es mi <b>pa</b>dre.',
#   'T02-Y <b>e</b>lla e<mark>s mi her<b>ma</b>na.  </mark>',
#   '<mark> T03-<b>Mu</b>cho <b>gus</b>to.  </mark>',
#   '<mark></mark>',
#   'T05-¿<b>Có</b>mo es<b>tá</b> us<b>ted</b>?'],
#  datetime.datetime(2024, 8, 30, 18, 37, 31, 497652): ['N4-Lec<b>ción</b> <b>cua</b>rta',
#   'S00-TITLE-Presenta<b>cio</b>nes',
#   'S01-Él es <b>Ra</b>fa, mi her<b>ma</b>no, y <b>e</b>lla es Luz, mi her<b>ma</b>na.',
#   'S02-Y él es mi <b>pa</b>dre, Mi<b>guel</b>.',
#   'S03-<b>Mu</b>cho <b>gus</b>to. ¿<b>Có</b>mo es<b>tá</b> us<b>ted</b>?',
#   'S04-Muy bien, <b>pe</b>ro ¡<b>há</b>blame de tú, por fa<b>vor</b>!',
#   'S05-¡<b>Va</b>le!',
#   'T00-TRANSLATE-Ejer<b>ci</b>cio 1 – <mark>Tra<b>duz</b>ca</mark>',
#   'T01-Él es mi <b>pa</b>dre.',
#   'T02-Y <b>e</b>lla es mi her<b>ma</b>na.',
#   'T03-<b></b><mark><b>Mu</b>cho <b>gus</b>to.</mark>',
#   'T04-<b>Há</b>blame de tú, por fa<b>vor</b>.',
#   'T05-¿<b>Có</b>mo es<b>tá</b> us<b>ted</b>?'],
#  datetime.datetime(2024, 8, 31, 17, 32, 18, 58630): ['N4-Lec<b>ción</b> <b>cua</b>rta',
#   'S00-TITLE-Presenta<b>cio</b>nes',
#   'S01-Él es <b>Ra</b>fa, mi her<b>ma</b>no, y <b>e</b>lla es Luz, mi her<b>ma</b>na.',
#   'S02-Y <mark>él</mark> es mi <b>pa</b>dre, <mark>Mi<b>guel</b></mark><b></b>.',
#   'S03-<b>Mu</b>cho <b>gus</b>to. ¿<b>Có</b>mo es<b>tá</b> us<b>ted</b>?',
#   'S04-Muy bien, <b>pe</b>ro ¡<b>há</b>blame de tú, por fa<b>vor</b>!',
#   'S05-¡<b>Va</b>le!',
#   'T00-TRANSLATE-Ejer<b>ci</b>cio 1 – Tra<b>duz</b>ca',
#   'T01-Él es mi <b>pa</b>dre.',
#   'T02-Y <b>e</b>lla es mi her<b>ma</b>na.',
#   'T03-<b>Mu</b>cho <b>gus</b>to.',
#   'T04-<b>Há</b>blame de tú, por fa<b>vor</b>.',
#   'T05-¿<b>Có</b>mo es<b>tá</b> us<b>ted</b>?']}

# %%
import datetime
lessons[4][datetime.datetime(2024, 8, 30, 18, 11, 11, 870753)]
# Out:
# ['N4-Le<mark>c<b>ción</b> <b>cua</b>rta </mark>',
#  '<mark> S00-TITLE-Pres</mark>enta<b>cio</b>nes',
#  'S01-Él es <b>Ra</b>fa, mi her<b>ma</b>no, y <b>e</b>lla es Luz, mi her<b>ma</b>na.',
#  'S02-Y él es <mark>mi <b>pa</b>dre, Mi<b>guel</b>.  </mark>',
#  '<mark> S03-<b>Mu</b>cho <b>gus</b>to. ¿<b>C</b></mark><b>ó</b>mo es<b>tá</b> us<b>ted</b>?',
#  'S04-Muy bien, <b>pe</b>ro ¡<b>há</b>blame de tú, por fa<b>vor</b>!',
#  'S05-¡<b>Va</b>le!',
#  'T00-TRANSLATE-Ejer<b>ci</b>cio 1 – Tra<b>duz</b>ca',
#  'T01-Él es mi <b>pa</b>dre.',
#  'T02-Y <b>e</b>lla e<mark>s mi her<b>ma</b>na.  </mark>',
#  '<mark> T03-<b>Mu</b>cho <b>gus</b>to.  </mark>',
#  '<mark></mark>',
#  'T05-¿<b>Có</b>mo es<b>tá</b> us<b>ted</b>?']

# %%
lessons[4][datetime.datetime(2024, 8, 30, 18, 37, 31, 497652)]
# Out:
# ['N4-Lec<b>ción</b> <b>cua</b>rta',
#  'S00-TITLE-Presenta<b>cio</b>nes',
#  'S01-Él es <b>Ra</b>fa, mi her<b>ma</b>no, y <b>e</b>lla es Luz, mi her<b>ma</b>na.',
#  'S02-Y él es mi <b>pa</b>dre, Mi<b>guel</b>.',
#  'S03-<b>Mu</b>cho <b>gus</b>to. ¿<b>Có</b>mo es<b>tá</b> us<b>ted</b>?',
#  'S04-Muy bien, <b>pe</b>ro ¡<b>há</b>blame de tú, por fa<b>vor</b>!',
#  'S05-¡<b>Va</b>le!',
#  'T00-TRANSLATE-Ejer<b>ci</b>cio 1 – <mark>Tra<b>duz</b>ca</mark>',
#  'T01-Él es mi <b>pa</b>dre.',
#  'T02-Y <b>e</b>lla es mi her<b>ma</b>na.',
#  'T03-<b></b><mark><b>Mu</b>cho <b>gus</b>to.</mark>',
#  'T04-<b>Há</b>blame de tú, por fa<b>vor</b>.',
#  'T05-¿<b>Có</b>mo es<b>tá</b> us<b>ted</b>?']

# %%
d=datetime.datetime(2024, 8, 30, 18, 37, 31, 497652)

# %%
d
# Out:
# datetime.datetime(2024, 8, 30, 18, 37, 31, 497652)

# %%
d.strftime('%d-%m-%Y %H:%M:%S')
# Out:
# '30-08-2024 18:37:31'

# %%
td_data = []
th_row = []
for lesson_nb in lessons:
    row=[]
    th_row.append(lesson_nb)
    for date in lessons[lesson_nb]:
        row.append(date)
    td_data.append(row)

# %%
th_row
# Out:
# [4, 5, 45, 97]

# %%
td_data
# Out:
# [[datetime.datetime(2024, 8, 30, 18, 11, 11, 870753),
#   datetime.datetime(2024, 8, 30, 18, 37, 31, 497652),
#   datetime.datetime(2024, 8, 31, 17, 32, 18, 58630)],
#  [datetime.datetime(2024, 8, 30, 18, 12, 5, 788656),
#   datetime.datetime(2024, 8, 31, 17, 33, 16, 342000)],
#  [datetime.datetime(2024, 8, 30, 18, 13, 24, 955334)],
#  [datetime.datetime(2024, 8, 31, 17, 34, 3, 198940)]]

# %%
txt = ""
for k, row in enumerate(td_data):
    txt += str(th_row[k]) + " "
    for date in row:
        txt += date.strftime('%d-%m-%Y %H:%M:%S') + " "
    txt += "\n"
print(txt)
# Out:
# 4 30-08-2024 18:11:11 30-08-2024 18:37:31 31-08-2024 17:32:18
# 5 30-08-2024 18:12:05 31-08-2024 17:33:16
# 45 30-08-2024 18:13:24
# 97 31-08-2024 17:34:03

# %%
from tonic_accent import get_history
# Out:
# 2024-08-31 18:02:15,498 INFO sqlalchemy.engine.Engine BEGIN (implicit)
# 2024-08-31 18:02:15,499 INFO sqlalchemy.engine.Engine PRAGMA main.table_info("word_dict")
# 2024-08-31 18:02:15,499 INFO sqlalchemy.engine.Engine [raw sql] ()
# 2024-08-31 18:02:15,499 INFO sqlalchemy.engine.Engine PRAGMA main.table_info("word_index")
# 2024-08-31 18:02:15,500 INFO sqlalchemy.engine.Engine [raw sql] ()
# 2024-08-31 18:02:15,500 INFO sqlalchemy.engine.Engine PRAGMA main.table_info("sentences")
# 2024-08-31 18:02:15,500 INFO sqlalchemy.engine.Engine [raw sql] ()
# 2024-08-31 18:02:15,500 INFO sqlalchemy.engine.Engine PRAGMA main.table_info("marked_sentences")
# 2024-08-31 18:02:15,500 INFO sqlalchemy.engine.Engine [raw sql] ()
# 2024-08-31 18:02:15,501 INFO sqlalchemy.engine.Engine COMMIT

# %%
th_row, rows= get_history()
# Out:
# 2024-08-31 18:02:17,361 INFO sqlalchemy.engine.Engine BEGIN (implicit)
# 2024-08-31 18:02:17,375 INFO sqlalchemy.engine.Engine SELECT marked_sentences.id, marked_sentences.date_time, marked_sentences.sentence, marked_sentences.comment, marked_sentences.lesson, marked_sentences.line
# FROM marked_sentences
# WHERE marked_sentences.date_time > ? AND marked_sentences.date_time < ? AND marked_sentences.lesson = ?
# 2024-08-31 18:02:17,376 INFO sqlalchemy.engine.Engine [generated in 0.00129s] ('0001-01-01 00:00:00.000000', '9999-12-31 23:59:59.999999', 1)
# 2024-08-31 18:02:17,377 INFO sqlalchemy.engine.Engine ROLLBACK
# 2024-08-31 18:02:17,379 INFO sqlalchemy.engine.Engine BEGIN (implicit)
# 2024-08-31 18:02:17,380 INFO sqlalchemy.engine.Engine SELECT marked_sentences.id, marked_sentences.date_time, marked_sentences.sentence, marked_sentences.comment, marked_sentences.lesson, marked_sentences.line
# FROM marked_sentences
# WHERE marked_sentences.date_time > ? AND marked_sentences.date_time < ? AND marked_sentences.lesson = ?
# 2024-08-31 18:02:17,380 INFO sqlalchemy.engine.Engine [cached since 0.005381s ago] ('0001-01-01 00:00:00.000000', '9999-12-31 23:59:59.999999', 2)
# 2024-08-31 18:02:17,381 INFO sqlalchemy.engine.Engine ROLLBACK
# 2024-08-31 18:02:17,382 INFO sqlalchemy.engine.Engine BEGIN (implicit)
# 2024-08-31 18:02:17,383 INFO sqlalchemy.engine.Engine SELECT marked_sentences.id, marked_sentences.date_time, marked_sentences.sentence, marked_sentences.comment, marked_sentences.lesson, marked_sentences.line
# FROM marked_sentences
# WHERE marked_sentences.date_time > ? AND marked_sentences.date_time < ? AND marked_sentences.lesson = ?
# 2024-08-31 18:02:17,384 INFO sqlalchemy.engine.Engine [cached since 0.008918s ago] ('0001-01-01 00:00:00.000000', '9999-12-31 23:59:59.999999', 3)
# 2024-08-31 18:02:17,384 INFO sqlalchemy.engine.Engine ROLLBACK
# 2024-08-31 18:02:17,385 INFO sqlalchemy.engine.Engine BEGIN (implicit)
# 2024-08-31 18:02:17,386 INFO sqlalchemy.engine.Engine SELECT marked_sentences.id, marked_sentences.date_time, marked_sentences.sentence, marked_sentences.comment, marked_sentences.lesson, marked_sentences.line
# FROM marked_sentences
# WHERE marked_sentences.date_time > ? AND marked_sentences.date_time < ? AND marked_sentences.lesson = ?
# 2024-08-31 18:02:17,387 INFO sqlalchemy.engine.Engine [cached since 0.01177s ago] ('0001-01-01 00:00:00.000000', '9999-12-31 23:59:59.999999', 4)
# 2024-08-31 18:02:17,388 INFO sqlalchemy.engine.Engine ROLLBACK
# 2024-08-31 18:02:17,389 INFO sqlalchemy.engine.Engine BEGIN (implicit)
# 2024-08-31 18:02:17,389 INFO sqlalchemy.engine.Engine SELECT marked_sentences.id, marked_sentences.date_time, marked_sentences.sentence, marked_sentences.comment, marked_sentences.lesson, marked_sentences.line
# FROM marked_sentences
# WHERE marked_sentences.date_time > ? AND marked_sentences.date_time < ? AND marked_sentences.lesson = ?
# 2024-08-31 18:02:17,390 INFO sqlalchemy.engine.Engine [cached since 0.01508s ago] ('0001-01-01 00:00:00.000000', '9999-12-31 23:59:59.999999', 5)
# 2024-08-31 18:02:17,391 INFO sqlalchemy.engine.Engine ROLLBACK
# 2024-08-31 18:02:17,392 INFO sqlalchemy.engine.Engine BEGIN (implicit)
# 2024-08-31 18:02:17,393 INFO sqlalchemy.engine.Engine SELECT marked_sentences.id, marked_sentences.date_time, marked_sentences.sentence, marked_sentences.comment, marked_sentences.lesson, marked_sentences.line
# FROM marked_sentences
# WHERE marked_sentences.date_time > ? AND marked_sentences.date_time < ? AND marked_sentences.lesson = ?
# 2024-08-31 18:02:17,394 INFO sqlalchemy.engine.Engine [cached since 0.01877s ago] ('0001-01-01 00:00:00.000000', '9999-12-31 23:59:59.999999', 6)
# 2024-08-31 18:02:17,395 INFO sqlalchemy.engine.Engine ROLLBACK
# 2024-08-31 18:02:17,396 INFO sqlalchemy.engine.Engine BEGIN (implicit)
# 2024-08-31 18:02:17,396 INFO sqlalchemy.engine.Engine SELECT marked_sentences.id, marked_sentences.date_time, marked_sentences.sentence, marked_sentences.comment, marked_sentences.lesson, marked_sentences.line
# FROM marked_sentences
# WHERE marked_sentences.date_time > ? AND marked_sentences.date_time < ? AND marked_sentences.lesson = ?
# 2024-08-31 18:02:17,397 INFO sqlalchemy.engine.Engine [cached since 0.02176s ago] ('0001-01-01 00:00:00.000000', '9999-12-31 23:59:59.999999', 7)
# 2024-08-31 18:02:17,397 INFO sqlalchemy.engine.Engine ROLLBACK
# 2024-08-31 18:02:17,398 INFO sqlalchemy.engine.Engine BEGIN (implicit)
# 2024-08-31 18:02:17,399 INFO sqlalchemy.engine.Engine SELECT marked_sentences.id, marked_sentences.date_time, marked_sentences.sentence, marked_sentences.comment, marked_sentences.lesson, marked_sentences.line
# FROM marked_sentences
# WHERE marked_sentences.date_time > ? AND marked_sentences.date_time < ? AND marked_sentences.lesson = ?
# 2024-08-31 18:02:17,399 INFO sqlalchemy.engine.Engine [cached since 0.02426s ago] ('0001-01-01 00:00:00.000000', '9999-12-31 23:59:59.999999', 8)
# 2024-08-31 18:02:17,400 INFO sqlalchemy.engine.Engine ROLLBACK
# 2024-08-31 18:02:17,400 INFO sqlalchemy.engine.Engine BEGIN (implicit)
# 2024-08-31 18:02:17,401 INFO sqlalchemy.engine.Engine SELECT marked_sentences.id, marked_sentences.date_time, marked_sentences.sentence, marked_sentences.comment, marked_sentences.lesson, marked_sentences.line
# FROM marked_sentences
# WHERE marked_sentences.date_time > ? AND marked_sentences.date_time < ? AND marked_sentences.lesson = ?
# 2024-08-31 18:02:17,401 INFO sqlalchemy.engine.Engine [cached since 0.02621s ago] ('0001-01-01 00:00:00.000000', '9999-12-31 23:59:59.999999', 9)
# 2024-08-31 18:02:17,401 INFO sqlalchemy.engine.Engine ROLLBACK
# 2024-08-31 18:02:17,402 INFO sqlalchemy.engine.Engine BEGIN (implicit)
# 2024-08-31 18:02:17,403 INFO sqlalchemy.engine.Engine SELECT marked_sentences.id, marked_sentences.date_time, marked_sentences.sentence, marked_sentences.comment, marked_sentences.lesson, marked_sentences.line
# FROM marked_sentences
# WHERE marked_sentences.date_time > ? AND marked_sentences.date_time < ? AND marked_sentences.lesson = ?
# 2024-08-31 18:02:17,403 INFO sqlalchemy.engine.Engine [cached since 0.0286s ago] ('0001-01-01 00:00:00.000000', '9999-12-31 23:59:59.999999', 10)
# 2024-08-31 18:02:17,404 INFO sqlalchemy.engine.Engine ROLLBACK
# 2024-08-31 18:02:17,405 INFO sqlalchemy.engine.Engine BEGIN (implicit)
# 2024-08-31 18:02:17,405 INFO sqlalchemy.engine.Engine SELECT marked_sentences.id, marked_sentences.date_time, marked_sentences.sentence, marked_sentences.comment, marked_sentences.lesson, marked_sentences.line
# FROM marked_sentences
# WHERE marked_sentences.date_time > ? AND marked_sentences.date_time < ? AND marked_sentences.lesson = ?
# 2024-08-31 18:02:17,405 INFO sqlalchemy.engine.Engine [cached since 0.03062s ago] ('0001-01-01 00:00:00.000000', '9999-12-31 23:59:59.999999', 11)
# 2024-08-31 18:02:17,406 INFO sqlalchemy.engine.Engine ROLLBACK
# 2024-08-31 18:02:17,406 INFO sqlalchemy.engine.Engine BEGIN (implicit)
# 2024-08-31 18:02:17,407 INFO sqlalchemy.engine.Engine SELECT marked_sentences.id, marked_sentences.date_time, marked_sentences.sentence, marked_sentences.comment, marked_sentences.lesson, marked_sentences.line
# FROM marked_sentences
# WHERE marked_sentences.date_time > ? AND marked_sentences.date_time < ? AND marked_sentences.lesson = ?
# 2024-08-31 18:02:17,408 INFO sqlalchemy.engine.Engine [cached since 0.03285s ago] ('0001-01-01 00:00:00.000000', '9999-12-31 23:59:59.999999', 12)
# 2024-08-31 18:02:17,408 INFO sqlalchemy.engine.Engine ROLLBACK
# 2024-08-31 18:02:17,409 INFO sqlalchemy.engine.Engine BEGIN (implicit)
# 2024-08-31 18:02:17,410 INFO sqlalchemy.engine.Engine SELECT marked_sentences.id, marked_sentences.date_time, marked_sentences.sentence, marked_sentences.comment, marked_sentences.lesson, marked_sentences.line
# FROM marked_sentences
# WHERE marked_sentences.date_time > ? AND marked_sentences.date_time < ? AND marked_sentences.lesson = ?
# 2024-08-31 18:02:17,410 INFO sqlalchemy.engine.Engine [cached since 0.03554s ago] ('0001-01-01 00:00:00.000000', '9999-12-31 23:59:59.999999', 13)
# 2024-08-31 18:02:17,411 INFO sqlalchemy.engine.Engine ROLLBACK
# 2024-08-31 18:02:17,411 INFO sqlalchemy.engine.Engine BEGIN (implicit)
# 2024-08-31 18:02:17,412 INFO sqlalchemy.engine.Engine SELECT marked_sentences.id, marked_sentences.date_time, marked_sentences.sentence, marked_sentences.comment, marked_sentences.lesson, marked_sentences.line
# FROM marked_sentences
# WHERE marked_sentences.date_time > ? AND marked_sentences.date_time < ? AND marked_sentences.lesson = ?
# 2024-08-31 18:02:17,412 INFO sqlalchemy.engine.Engine [cached since 0.03746s ago] ('0001-01-01 00:00:00.000000', '9999-12-31 23:59:59.999999', 14)
# 2024-08-31 18:02:17,413 INFO sqlalchemy.engine.Engine ROLLBACK
# 2024-08-31 18:02:17,413 INFO sqlalchemy.engine.Engine BEGIN (implicit)
# 2024-08-31 18:02:17,414 INFO sqlalchemy.engine.Engine SELECT marked_sentences.id, marked_sentences.date_time, marked_sentences.sentence, marked_sentences.comment, marked_sentences.lesson, marked_sentences.line
# FROM marked_sentences
# WHERE marked_sentences.date_time > ? AND marked_sentences.date_time < ? AND marked_sentences.lesson = ?
# 2024-08-31 18:02:17,414 INFO sqlalchemy.engine.Engine [cached since 0.03919s ago] ('0001-01-01 00:00:00.000000', '9999-12-31 23:59:59.999999', 15)
# 2024-08-31 18:02:17,414 INFO sqlalchemy.engine.Engine ROLLBACK
# 2024-08-31 18:02:17,415 INFO sqlalchemy.engine.Engine BEGIN (implicit)
# 2024-08-31 18:02:17,415 INFO sqlalchemy.engine.Engine SELECT marked_sentences.id, marked_sentences.date_time, marked_sentences.sentence, marked_sentences.comment, marked_sentences.lesson, marked_sentences.line
# FROM marked_sentences
# WHERE marked_sentences.date_time > ? AND marked_sentences.date_time < ? AND marked_sentences.lesson = ?
# 2024-08-31 18:02:17,416 INFO sqlalchemy.engine.Engine [cached since 0.04091s ago] ('0001-01-01 00:00:00.000000', '9999-12-31 23:59:59.999999', 16)
# 2024-08-31 18:02:17,416 INFO sqlalchemy.engine.Engine ROLLBACK
# 2024-08-31 18:02:17,417 INFO sqlalchemy.engine.Engine BEGIN (implicit)
# 2024-08-31 18:02:17,417 INFO sqlalchemy.engine.Engine SELECT marked_sentences.id, marked_sentences.date_time, marked_sentences.sentence, marked_sentences.comment, marked_sentences.lesson, marked_sentences.line
# FROM marked_sentences
# WHERE marked_sentences.date_time > ? AND marked_sentences.date_time < ? AND marked_sentences.lesson = ?
# 2024-08-31 18:02:17,417 INFO sqlalchemy.engine.Engine [cached since 0.04245s ago] ('0001-01-01 00:00:00.000000', '9999-12-31 23:59:59.999999', 17)
# 2024-08-31 18:02:17,418 INFO sqlalchemy.engine.Engine ROLLBACK
# 2024-08-31 18:02:17,418 INFO sqlalchemy.engine.Engine BEGIN (implicit)
# 2024-08-31 18:02:17,419 INFO sqlalchemy.engine.Engine SELECT marked_sentences.id, marked_sentences.date_time, marked_sentences.sentence, marked_sentences.comment, marked_sentences.lesson, marked_sentences.line
# FROM marked_sentences
# WHERE marked_sentences.date_time > ? AND marked_sentences.date_time < ? AND marked_sentences.lesson = ?
# 2024-08-31 18:02:17,419 INFO sqlalchemy.engine.Engine [cached since 0.04419s ago] ('0001-01-01 00:00:00.000000', '9999-12-31 23:59:59.999999', 18)
# 2024-08-31 18:02:17,419 INFO sqlalchemy.engine.Engine ROLLBACK
# 2024-08-31 18:02:17,420 INFO sqlalchemy.engine.Engine BEGIN (implicit)
# 2024-08-31 18:02:17,420 INFO sqlalchemy.engine.Engine SELECT marked_sentences.id, marked_sentences.date_time, marked_sentences.sentence, marked_sentences.comment, marked_sentences.lesson, marked_sentences.line
# FROM marked_sentences
# WHERE marked_sentences.date_time > ? AND marked_sentences.date_time < ? AND marked_sentences.lesson = ?
# 2024-08-31 18:02:17,421 INFO sqlalchemy.engine.Engine [cached since 0.0459s ago] ('0001-01-01 00:00:00.000000', '9999-12-31 23:59:59.999999', 19)
# 2024-08-31 18:02:17,421 INFO sqlalchemy.engine.Engine ROLLBACK
# 2024-08-31 18:02:17,422 INFO sqlalchemy.engine.Engine BEGIN (implicit)
# 2024-08-31 18:02:17,423 INFO sqlalchemy.engine.Engine SELECT marked_sentences.id, marked_sentences.date_time, marked_sentences.sentence, marked_sentences.comment, marked_sentences.lesson, marked_sentences.line
# FROM marked_sentences
# WHERE marked_sentences.date_time > ? AND marked_sentences.date_time < ? AND marked_sentences.lesson = ?
# 2024-08-31 18:02:17,423 INFO sqlalchemy.engine.Engine [cached since 0.04808s ago] ('0001-01-01 00:00:00.000000', '9999-12-31 23:59:59.999999', 20)
# 2024-08-31 18:02:17,423 INFO sqlalchemy.engine.Engine ROLLBACK
# 2024-08-31 18:02:17,424 INFO sqlalchemy.engine.Engine BEGIN (implicit)
# 2024-08-31 18:02:17,425 INFO sqlalchemy.engine.Engine SELECT marked_sentences.id, marked_sentences.date_time, marked_sentences.sentence, marked_sentences.comment, marked_sentences.lesson, marked_sentences.line
# FROM marked_sentences
# WHERE marked_sentences.date_time > ? AND marked_sentences.date_time < ? AND marked_sentences.lesson = ?
# 2024-08-31 18:02:17,425 INFO sqlalchemy.engine.Engine [cached since 0.05066s ago] ('0001-01-01 00:00:00.000000', '9999-12-31 23:59:59.999999', 21)
# 2024-08-31 18:02:17,426 INFO sqlalchemy.engine.Engine ROLLBACK
# 2024-08-31 18:02:17,426 INFO sqlalchemy.engine.Engine BEGIN (implicit)
# 2024-08-31 18:02:17,427 INFO sqlalchemy.engine.Engine SELECT marked_sentences.id, marked_sentences.date_time, marked_sentences.sentence, marked_sentences.comment, marked_sentences.lesson, marked_sentences.line
# FROM marked_sentences
# WHERE marked_sentences.date_time > ? AND marked_sentences.date_time < ? AND marked_sentences.lesson = ?
# 2024-08-31 18:02:17,427 INFO sqlalchemy.engine.Engine [cached since 0.05254s ago] ('0001-01-01 00:00:00.000000', '9999-12-31 23:59:59.999999', 22)
# 2024-08-31 18:02:17,428 INFO sqlalchemy.engine.Engine ROLLBACK
# 2024-08-31 18:02:17,428 INFO sqlalchemy.engine.Engine BEGIN (implicit)
# 2024-08-31 18:02:17,429 INFO sqlalchemy.engine.Engine SELECT marked_sentences.id, marked_sentences.date_time, marked_sentences.sentence, marked_sentences.comment, marked_sentences.lesson, marked_sentences.line
# FROM marked_sentences
# WHERE marked_sentences.date_time > ? AND marked_sentences.date_time < ? AND marked_sentences.lesson = ?
# 2024-08-31 18:02:17,429 INFO sqlalchemy.engine.Engine [cached since 0.05396s ago] ('0001-01-01 00:00:00.000000', '9999-12-31 23:59:59.999999', 23)
# 2024-08-31 18:02:17,429 INFO sqlalchemy.engine.Engine ROLLBACK
# 2024-08-31 18:02:17,430 INFO sqlalchemy.engine.Engine BEGIN (implicit)
# 2024-08-31 18:02:17,430 INFO sqlalchemy.engine.Engine SELECT marked_sentences.id, marked_sentences.date_time, marked_sentences.sentence, marked_sentences.comment, marked_sentences.lesson, marked_sentences.line
# FROM marked_sentences
# WHERE marked_sentences.date_time > ? AND marked_sentences.date_time < ? AND marked_sentences.lesson = ?
# 2024-08-31 18:02:17,430 INFO sqlalchemy.engine.Engine [cached since 0.05529s ago] ('0001-01-01 00:00:00.000000', '9999-12-31 23:59:59.999999', 24)
# 2024-08-31 18:02:17,430 INFO sqlalchemy.engine.Engine ROLLBACK
# 2024-08-31 18:02:17,431 INFO sqlalchemy.engine.Engine BEGIN (implicit)
# 2024-08-31 18:02:17,431 INFO sqlalchemy.engine.Engine SELECT marked_sentences.id, marked_sentences.date_time, marked_sentences.sentence, marked_sentences.comment, marked_sentences.lesson, marked_sentences.line
# FROM marked_sentences
# WHERE marked_sentences.date_time > ? AND marked_sentences.date_time < ? AND marked_sentences.lesson = ?
# 2024-08-31 18:02:17,431 INFO sqlalchemy.engine.Engine [cached since 0.0565s ago] ('0001-01-01 00:00:00.000000', '9999-12-31 23:59:59.999999', 25)
# 2024-08-31 18:02:17,432 INFO sqlalchemy.engine.Engine ROLLBACK
# 2024-08-31 18:02:17,432 INFO sqlalchemy.engine.Engine BEGIN (implicit)
# 2024-08-31 18:02:17,432 INFO sqlalchemy.engine.Engine SELECT marked_sentences.id, marked_sentences.date_time, marked_sentences.sentence, marked_sentences.comment, marked_sentences.lesson, marked_sentences.line
# FROM marked_sentences
# WHERE marked_sentences.date_time > ? AND marked_sentences.date_time < ? AND marked_sentences.lesson = ?
# 2024-08-31 18:02:17,433 INFO sqlalchemy.engine.Engine [cached since 0.05795s ago] ('0001-01-01 00:00:00.000000', '9999-12-31 23:59:59.999999', 26)
# 2024-08-31 18:02:17,433 INFO sqlalchemy.engine.Engine ROLLBACK
# 2024-08-31 18:02:17,433 INFO sqlalchemy.engine.Engine BEGIN (implicit)
# 2024-08-31 18:02:17,434 INFO sqlalchemy.engine.Engine SELECT marked_sentences.id, marked_sentences.date_time, marked_sentences.sentence, marked_sentences.comment, marked_sentences.lesson, marked_sentences.line
# FROM marked_sentences
# WHERE marked_sentences.date_time > ? AND marked_sentences.date_time < ? AND marked_sentences.lesson = ?
# 2024-08-31 18:02:17,434 INFO sqlalchemy.engine.Engine [cached since 0.05925s ago] ('0001-01-01 00:00:00.000000', '9999-12-31 23:59:59.999999', 27)
# 2024-08-31 18:02:17,434 INFO sqlalchemy.engine.Engine ROLLBACK
# 2024-08-31 18:02:17,435 INFO sqlalchemy.engine.Engine BEGIN (implicit)
# 2024-08-31 18:02:17,435 INFO sqlalchemy.engine.Engine SELECT marked_sentences.id, marked_sentences.date_time, marked_sentences.sentence, marked_sentences.comment, marked_sentences.lesson, marked_sentences.line
# FROM marked_sentences
# WHERE marked_sentences.date_time > ? AND marked_sentences.date_time < ? AND marked_sentences.lesson = ?
# 2024-08-31 18:02:17,435 INFO sqlalchemy.engine.Engine [cached since 0.06048s ago] ('0001-01-01 00:00:00.000000', '9999-12-31 23:59:59.999999', 28)
# 2024-08-31 18:02:17,436 INFO sqlalchemy.engine.Engine ROLLBACK
# 2024-08-31 18:02:17,436 INFO sqlalchemy.engine.Engine BEGIN (implicit)
# 2024-08-31 18:02:17,436 INFO sqlalchemy.engine.Engine SELECT marked_sentences.id, marked_sentences.date_time, marked_sentences.sentence, marked_sentences.comment, marked_sentences.lesson, marked_sentences.line
# FROM marked_sentences
# WHERE marked_sentences.date_time > ? AND marked_sentences.date_time < ? AND marked_sentences.lesson = ?
# 2024-08-31 18:02:17,436 INFO sqlalchemy.engine.Engine [cached since 0.06174s ago] ('0001-01-01 00:00:00.000000', '9999-12-31 23:59:59.999999', 29)
# 2024-08-31 18:02:17,437 INFO sqlalchemy.engine.Engine ROLLBACK
# 2024-08-31 18:02:17,437 INFO sqlalchemy.engine.Engine BEGIN (implicit)
# 2024-08-31 18:02:17,438 INFO sqlalchemy.engine.Engine SELECT marked_sentences.id, marked_sentences.date_time, marked_sentences.sentence, marked_sentences.comment, marked_sentences.lesson, marked_sentences.line
# FROM marked_sentences
# WHERE marked_sentences.date_time > ? AND marked_sentences.date_time < ? AND marked_sentences.lesson = ?
# 2024-08-31 18:02:17,438 INFO sqlalchemy.engine.Engine [cached since 0.06308s ago] ('0001-01-01 00:00:00.000000', '9999-12-31 23:59:59.999999', 30)
# 2024-08-31 18:02:17,438 INFO sqlalchemy.engine.Engine ROLLBACK
# 2024-08-31 18:02:17,438 INFO sqlalchemy.engine.Engine BEGIN (implicit)
# 2024-08-31 18:02:17,439 INFO sqlalchemy.engine.Engine SELECT marked_sentences.id, marked_sentences.date_time, marked_sentences.sentence, marked_sentences.comment, marked_sentences.lesson, marked_sentences.line
# FROM marked_sentences
# WHERE marked_sentences.date_time > ? AND marked_sentences.date_time < ? AND marked_sentences.lesson = ?
# 2024-08-31 18:02:17,439 INFO sqlalchemy.engine.Engine [cached since 0.06418s ago] ('0001-01-01 00:00:00.000000', '9999-12-31 23:59:59.999999', 31)
# 2024-08-31 18:02:17,439 INFO sqlalchemy.engine.Engine ROLLBACK
# 2024-08-31 18:02:17,440 INFO sqlalchemy.engine.Engine BEGIN (implicit)
# 2024-08-31 18:02:17,440 INFO sqlalchemy.engine.Engine SELECT marked_sentences.id, marked_sentences.date_time, marked_sentences.sentence, marked_sentences.comment, marked_sentences.lesson, marked_sentences.line
# FROM marked_sentences
# WHERE marked_sentences.date_time > ? AND marked_sentences.date_time < ? AND marked_sentences.lesson = ?
# 2024-08-31 18:02:17,440 INFO sqlalchemy.engine.Engine [cached since 0.06535s ago] ('0001-01-01 00:00:00.000000', '9999-12-31 23:59:59.999999', 32)
# 2024-08-31 18:02:17,441 INFO sqlalchemy.engine.Engine ROLLBACK
# 2024-08-31 18:02:17,441 INFO sqlalchemy.engine.Engine BEGIN (implicit)
# 2024-08-31 18:02:17,442 INFO sqlalchemy.engine.Engine SELECT marked_sentences.id, marked_sentences.date_time, marked_sentences.sentence, marked_sentences.comment, marked_sentences.lesson, marked_sentences.line
# FROM marked_sentences
# WHERE marked_sentences.date_time > ? AND marked_sentences.date_time < ? AND marked_sentences.lesson = ?
# 2024-08-31 18:02:17,442 INFO sqlalchemy.engine.Engine [cached since 0.06744s ago] ('0001-01-01 00:00:00.000000', '9999-12-31 23:59:59.999999', 33)
# 2024-08-31 18:02:17,443 INFO sqlalchemy.engine.Engine ROLLBACK
# 2024-08-31 18:02:17,443 INFO sqlalchemy.engine.Engine BEGIN (implicit)
# 2024-08-31 18:02:17,444 INFO sqlalchemy.engine.Engine SELECT marked_sentences.id, marked_sentences.date_time, marked_sentences.sentence, marked_sentences.comment, marked_sentences.lesson, marked_sentences.line
# FROM marked_sentences
# WHERE marked_sentences.date_time > ? AND marked_sentences.date_time < ? AND marked_sentences.lesson = ?
# 2024-08-31 18:02:17,444 INFO sqlalchemy.engine.Engine [cached since 0.06904s ago] ('0001-01-01 00:00:00.000000', '9999-12-31 23:59:59.999999', 34)
# 2024-08-31 18:02:17,444 INFO sqlalchemy.engine.Engine ROLLBACK
# 2024-08-31 18:02:17,445 INFO sqlalchemy.engine.Engine BEGIN (implicit)
# 2024-08-31 18:02:17,445 INFO sqlalchemy.engine.Engine SELECT marked_sentences.id, marked_sentences.date_time, marked_sentences.sentence, marked_sentences.comment, marked_sentences.lesson, marked_sentences.line
# FROM marked_sentences
# WHERE marked_sentences.date_time > ? AND marked_sentences.date_time < ? AND marked_sentences.lesson = ?
# 2024-08-31 18:02:17,445 INFO sqlalchemy.engine.Engine [cached since 0.07026s ago] ('0001-01-01 00:00:00.000000', '9999-12-31 23:59:59.999999', 35)
# 2024-08-31 18:02:17,445 INFO sqlalchemy.engine.Engine ROLLBACK
# 2024-08-31 18:02:17,446 INFO sqlalchemy.engine.Engine BEGIN (implicit)
# 2024-08-31 18:02:17,446 INFO sqlalchemy.engine.Engine SELECT marked_sentences.id, marked_sentences.date_time, marked_sentences.sentence, marked_sentences.comment, marked_sentences.lesson, marked_sentences.line
# FROM marked_sentences
# WHERE marked_sentences.date_time > ? AND marked_sentences.date_time < ? AND marked_sentences.lesson = ?
# 2024-08-31 18:02:17,446 INFO sqlalchemy.engine.Engine [cached since 0.07169s ago] ('0001-01-01 00:00:00.000000', '9999-12-31 23:59:59.999999', 36)
# 2024-08-31 18:02:17,447 INFO sqlalchemy.engine.Engine ROLLBACK
# 2024-08-31 18:02:17,447 INFO sqlalchemy.engine.Engine BEGIN (implicit)
# 2024-08-31 18:02:17,447 INFO sqlalchemy.engine.Engine SELECT marked_sentences.id, marked_sentences.date_time, marked_sentences.sentence, marked_sentences.comment, marked_sentences.lesson, marked_sentences.line
# FROM marked_sentences
# WHERE marked_sentences.date_time > ? AND marked_sentences.date_time < ? AND marked_sentences.lesson = ?
# 2024-08-31 18:02:17,448 INFO sqlalchemy.engine.Engine [cached since 0.07302s ago] ('0001-01-01 00:00:00.000000', '9999-12-31 23:59:59.999999', 37)
# 2024-08-31 18:02:17,448 INFO sqlalchemy.engine.Engine ROLLBACK
# 2024-08-31 18:02:17,448 INFO sqlalchemy.engine.Engine BEGIN (implicit)
# 2024-08-31 18:02:17,449 INFO sqlalchemy.engine.Engine SELECT marked_sentences.id, marked_sentences.date_time, marked_sentences.sentence, marked_sentences.comment, marked_sentences.lesson, marked_sentences.line
# FROM marked_sentences
# WHERE marked_sentences.date_time > ? AND marked_sentences.date_time < ? AND marked_sentences.lesson = ?
# 2024-08-31 18:02:17,449 INFO sqlalchemy.engine.Engine [cached since 0.07407s ago] ('0001-01-01 00:00:00.000000', '9999-12-31 23:59:59.999999', 38)
# 2024-08-31 18:02:17,449 INFO sqlalchemy.engine.Engine ROLLBACK
# 2024-08-31 18:02:17,449 INFO sqlalchemy.engine.Engine BEGIN (implicit)
# 2024-08-31 18:02:17,450 INFO sqlalchemy.engine.Engine SELECT marked_sentences.id, marked_sentences.date_time, marked_sentences.sentence, marked_sentences.comment, marked_sentences.lesson, marked_sentences.line
# FROM marked_sentences
# WHERE marked_sentences.date_time > ? AND marked_sentences.date_time < ? AND marked_sentences.lesson = ?
# 2024-08-31 18:02:17,450 INFO sqlalchemy.engine.Engine [cached since 0.07517s ago] ('0001-01-01 00:00:00.000000', '9999-12-31 23:59:59.999999', 39)
# 2024-08-31 18:02:17,450 INFO sqlalchemy.engine.Engine ROLLBACK
# 2024-08-31 18:02:17,450 INFO sqlalchemy.engine.Engine BEGIN (implicit)
# 2024-08-31 18:02:17,451 INFO sqlalchemy.engine.Engine SELECT marked_sentences.id, marked_sentences.date_time, marked_sentences.sentence, marked_sentences.comment, marked_sentences.lesson, marked_sentences.line
# FROM marked_sentences
# WHERE marked_sentences.date_time > ? AND marked_sentences.date_time < ? AND marked_sentences.lesson = ?
# 2024-08-31 18:02:17,451 INFO sqlalchemy.engine.Engine [cached since 0.07631s ago] ('0001-01-01 00:00:00.000000', '9999-12-31 23:59:59.999999', 40)
# 2024-08-31 18:02:17,451 INFO sqlalchemy.engine.Engine ROLLBACK
# 2024-08-31 18:02:17,452 INFO sqlalchemy.engine.Engine BEGIN (implicit)
# 2024-08-31 18:02:17,452 INFO sqlalchemy.engine.Engine SELECT marked_sentences.id, marked_sentences.date_time, marked_sentences.sentence, marked_sentences.comment, marked_sentences.lesson, marked_sentences.line
# FROM marked_sentences
# WHERE marked_sentences.date_time > ? AND marked_sentences.date_time < ? AND marked_sentences.lesson = ?
# 2024-08-31 18:02:17,452 INFO sqlalchemy.engine.Engine [cached since 0.07737s ago] ('0001-01-01 00:00:00.000000', '9999-12-31 23:59:59.999999', 41)
# 2024-08-31 18:02:17,453 INFO sqlalchemy.engine.Engine ROLLBACK
# 2024-08-31 18:02:17,453 INFO sqlalchemy.engine.Engine BEGIN (implicit)
# 2024-08-31 18:02:17,453 INFO sqlalchemy.engine.Engine SELECT marked_sentences.id, marked_sentences.date_time, marked_sentences.sentence, marked_sentences.comment, marked_sentences.lesson, marked_sentences.line
# FROM marked_sentences
# WHERE marked_sentences.date_time > ? AND marked_sentences.date_time < ? AND marked_sentences.lesson = ?
# 2024-08-31 18:02:17,453 INFO sqlalchemy.engine.Engine [cached since 0.07854s ago] ('0001-01-01 00:00:00.000000', '9999-12-31 23:59:59.999999', 42)
# 2024-08-31 18:02:17,454 INFO sqlalchemy.engine.Engine ROLLBACK
# 2024-08-31 18:02:17,454 INFO sqlalchemy.engine.Engine BEGIN (implicit)
# 2024-08-31 18:02:17,454 INFO sqlalchemy.engine.Engine SELECT marked_sentences.id, marked_sentences.date_time, marked_sentences.sentence, marked_sentences.comment, marked_sentences.lesson, marked_sentences.line
# FROM marked_sentences
# WHERE marked_sentences.date_time > ? AND marked_sentences.date_time < ? AND marked_sentences.lesson = ?
# 2024-08-31 18:02:17,454 INFO sqlalchemy.engine.Engine [cached since 0.07956s ago] ('0001-01-01 00:00:00.000000', '9999-12-31 23:59:59.999999', 43)
# 2024-08-31 18:02:17,455 INFO sqlalchemy.engine.Engine ROLLBACK
# 2024-08-31 18:02:17,455 INFO sqlalchemy.engine.Engine BEGIN (implicit)
# 2024-08-31 18:02:17,455 INFO sqlalchemy.engine.Engine SELECT marked_sentences.id, marked_sentences.date_time, marked_sentences.sentence, marked_sentences.comment, marked_sentences.lesson, marked_sentences.line
# FROM marked_sentences
# WHERE marked_sentences.date_time > ? AND marked_sentences.date_time < ? AND marked_sentences.lesson = ?
# 2024-08-31 18:02:17,455 INFO sqlalchemy.engine.Engine [cached since 0.08068s ago] ('0001-01-01 00:00:00.000000', '9999-12-31 23:59:59.999999', 44)
# 2024-08-31 18:02:17,456 INFO sqlalchemy.engine.Engine ROLLBACK
# 2024-08-31 18:02:17,456 INFO sqlalchemy.engine.Engine BEGIN (implicit)
# 2024-08-31 18:02:17,456 INFO sqlalchemy.engine.Engine SELECT marked_sentences.id, marked_sentences.date_time, marked_sentences.sentence, marked_sentences.comment, marked_sentences.lesson, marked_sentences.line
# FROM marked_sentences
# WHERE marked_sentences.date_time > ? AND marked_sentences.date_time < ? AND marked_sentences.lesson = ?
# 2024-08-31 18:02:17,456 INFO sqlalchemy.engine.Engine [cached since 0.08165s ago] ('0001-01-01 00:00:00.000000', '9999-12-31 23:59:59.999999', 45)
# 2024-08-31 18:02:17,457 INFO sqlalchemy.engine.Engine ROLLBACK
# 2024-08-31 18:02:17,457 INFO sqlalchemy.engine.Engine BEGIN (implicit)
# 2024-08-31 18:02:17,457 INFO sqlalchemy.engine.Engine SELECT marked_sentences.id, marked_sentences.date_time, marked_sentences.sentence, marked_sentences.comment, marked_sentences.lesson, marked_sentences.line
# FROM marked_sentences
# WHERE marked_sentences.date_time > ? AND marked_sentences.date_time < ? AND marked_sentences.lesson = ?
# 2024-08-31 18:02:17,458 INFO sqlalchemy.engine.Engine [cached since 0.08283s ago] ('0001-01-01 00:00:00.000000', '9999-12-31 23:59:59.999999', 46)
# 2024-08-31 18:02:17,458 INFO sqlalchemy.engine.Engine ROLLBACK
# 2024-08-31 18:02:17,458 INFO sqlalchemy.engine.Engine BEGIN (implicit)
# 2024-08-31 18:02:17,459 INFO sqlalchemy.engine.Engine SELECT marked_sentences.id, marked_sentences.date_time, marked_sentences.sentence, marked_sentences.comment, marked_sentences.lesson, marked_sentences.line
# FROM marked_sentences
# WHERE marked_sentences.date_time > ? AND marked_sentences.date_time < ? AND marked_sentences.lesson = ?
# 2024-08-31 18:02:17,459 INFO sqlalchemy.engine.Engine [cached since 0.08402s ago] ('0001-01-01 00:00:00.000000', '9999-12-31 23:59:59.999999', 47)
# 2024-08-31 18:02:17,459 INFO sqlalchemy.engine.Engine ROLLBACK
# 2024-08-31 18:02:17,459 INFO sqlalchemy.engine.Engine BEGIN (implicit)
# 2024-08-31 18:02:17,460 INFO sqlalchemy.engine.Engine SELECT marked_sentences.id, marked_sentences.date_time, marked_sentences.sentence, marked_sentences.comment, marked_sentences.lesson, marked_sentences.line
# FROM marked_sentences
# WHERE marked_sentences.date_time > ? AND marked_sentences.date_time < ? AND marked_sentences.lesson = ?
# 2024-08-31 18:02:17,460 INFO sqlalchemy.engine.Engine [cached since 0.08521s ago] ('0001-01-01 00:00:00.000000', '9999-12-31 23:59:59.999999', 48)
# 2024-08-31 18:02:17,460 INFO sqlalchemy.engine.Engine ROLLBACK
# 2024-08-31 18:02:17,461 INFO sqlalchemy.engine.Engine BEGIN (implicit)
# 2024-08-31 18:02:17,461 INFO sqlalchemy.engine.Engine SELECT marked_sentences.id, marked_sentences.date_time, marked_sentences.sentence, marked_sentences.comment, marked_sentences.lesson, marked_sentences.line
# FROM marked_sentences
# WHERE marked_sentences.date_time > ? AND marked_sentences.date_time < ? AND marked_sentences.lesson = ?
# 2024-08-31 18:02:17,461 INFO sqlalchemy.engine.Engine [cached since 0.0866s ago] ('0001-01-01 00:00:00.000000', '9999-12-31 23:59:59.999999', 49)
# 2024-08-31 18:02:17,462 INFO sqlalchemy.engine.Engine ROLLBACK
# 2024-08-31 18:02:17,462 INFO sqlalchemy.engine.Engine BEGIN (implicit)
# 2024-08-31 18:02:17,462 INFO sqlalchemy.engine.Engine SELECT marked_sentences.id, marked_sentences.date_time, marked_sentences.sentence, marked_sentences.comment, marked_sentences.lesson, marked_sentences.line
# FROM marked_sentences
# WHERE marked_sentences.date_time > ? AND marked_sentences.date_time < ? AND marked_sentences.lesson = ?
# 2024-08-31 18:02:17,462 INFO sqlalchemy.engine.Engine [cached since 0.08773s ago] ('0001-01-01 00:00:00.000000', '9999-12-31 23:59:59.999999', 50)
# 2024-08-31 18:02:17,463 INFO sqlalchemy.engine.Engine ROLLBACK
# 2024-08-31 18:02:17,463 INFO sqlalchemy.engine.Engine BEGIN (implicit)
# 2024-08-31 18:02:17,464 INFO sqlalchemy.engine.Engine SELECT marked_sentences.id, marked_sentences.date_time, marked_sentences.sentence, marked_sentences.comment, marked_sentences.lesson, marked_sentences.line
# FROM marked_sentences
# WHERE marked_sentences.date_time > ? AND marked_sentences.date_time < ? AND marked_sentences.lesson = ?
# 2024-08-31 18:02:17,464 INFO sqlalchemy.engine.Engine [cached since 0.08915s ago] ('0001-01-01 00:00:00.000000', '9999-12-31 23:59:59.999999', 51)
# 2024-08-31 18:02:17,464 INFO sqlalchemy.engine.Engine ROLLBACK
# 2024-08-31 18:02:17,465 INFO sqlalchemy.engine.Engine BEGIN (implicit)
# 2024-08-31 18:02:17,465 INFO sqlalchemy.engine.Engine SELECT marked_sentences.id, marked_sentences.date_time, marked_sentences.sentence, marked_sentences.comment, marked_sentences.lesson, marked_sentences.line
# FROM marked_sentences
# WHERE marked_sentences.date_time > ? AND marked_sentences.date_time < ? AND marked_sentences.lesson = ?
# 2024-08-31 18:02:17,465 INFO sqlalchemy.engine.Engine [cached since 0.09029s ago] ('0001-01-01 00:00:00.000000', '9999-12-31 23:59:59.999999', 52)
# 2024-08-31 18:02:17,465 INFO sqlalchemy.engine.Engine ROLLBACK
# 2024-08-31 18:02:17,466 INFO sqlalchemy.engine.Engine BEGIN (implicit)
# 2024-08-31 18:02:17,466 INFO sqlalchemy.engine.Engine SELECT marked_sentences.id, marked_sentences.date_time, marked_sentences.sentence, marked_sentences.comment, marked_sentences.lesson, marked_sentences.line
# FROM marked_sentences
# WHERE marked_sentences.date_time > ? AND marked_sentences.date_time < ? AND marked_sentences.lesson = ?
# 2024-08-31 18:02:17,466 INFO sqlalchemy.engine.Engine [cached since 0.09139s ago] ('0001-01-01 00:00:00.000000', '9999-12-31 23:59:59.999999', 53)
# 2024-08-31 18:02:17,466 INFO sqlalchemy.engine.Engine ROLLBACK
# 2024-08-31 18:02:17,467 INFO sqlalchemy.engine.Engine BEGIN (implicit)
# 2024-08-31 18:02:17,467 INFO sqlalchemy.engine.Engine SELECT marked_sentences.id, marked_sentences.date_time, marked_sentences.sentence, marked_sentences.comment, marked_sentences.lesson, marked_sentences.line
# FROM marked_sentences
# WHERE marked_sentences.date_time > ? AND marked_sentences.date_time < ? AND marked_sentences.lesson = ?
# 2024-08-31 18:02:17,467 INFO sqlalchemy.engine.Engine [cached since 0.09242s ago] ('0001-01-01 00:00:00.000000', '9999-12-31 23:59:59.999999', 54)
# 2024-08-31 18:02:17,467 INFO sqlalchemy.engine.Engine ROLLBACK
# 2024-08-31 18:02:17,468 INFO sqlalchemy.engine.Engine BEGIN (implicit)
# 2024-08-31 18:02:17,468 INFO sqlalchemy.engine.Engine SELECT marked_sentences.id, marked_sentences.date_time, marked_sentences.sentence, marked_sentences.comment, marked_sentences.lesson, marked_sentences.line
# FROM marked_sentences
# WHERE marked_sentences.date_time > ? AND marked_sentences.date_time < ? AND marked_sentences.lesson = ?
# 2024-08-31 18:02:17,468 INFO sqlalchemy.engine.Engine [cached since 0.0934s ago] ('0001-01-01 00:00:00.000000', '9999-12-31 23:59:59.999999', 55)
# 2024-08-31 18:02:17,468 INFO sqlalchemy.engine.Engine ROLLBACK
# 2024-08-31 18:02:17,469 INFO sqlalchemy.engine.Engine BEGIN (implicit)
# 2024-08-31 18:02:17,469 INFO sqlalchemy.engine.Engine SELECT marked_sentences.id, marked_sentences.date_time, marked_sentences.sentence, marked_sentences.comment, marked_sentences.lesson, marked_sentences.line
# FROM marked_sentences
# WHERE marked_sentences.date_time > ? AND marked_sentences.date_time < ? AND marked_sentences.lesson = ?
# 2024-08-31 18:02:17,469 INFO sqlalchemy.engine.Engine [cached since 0.09433s ago] ('0001-01-01 00:00:00.000000', '9999-12-31 23:59:59.999999', 56)
# 2024-08-31 18:02:17,477 INFO sqlalchemy.engine.Engine ROLLBACK
# 2024-08-31 18:02:17,479 INFO sqlalchemy.engine.Engine BEGIN (implicit)
# 2024-08-31 18:02:17,492 INFO sqlalchemy.engine.Engine SELECT marked_sentences.id, marked_sentences.date_time, marked_sentences.sentence, marked_sentences.comment, marked_sentences.lesson, marked_sentences.line
# FROM marked_sentences
# WHERE marked_sentences.date_time > ? AND marked_sentences.date_time < ? AND marked_sentences.lesson = ?
# 2024-08-31 18:02:17,492 INFO sqlalchemy.engine.Engine [cached since 0.1177s ago] ('0001-01-01 00:00:00.000000', '9999-12-31 23:59:59.999999', 57)
# 2024-08-31 18:02:17,495 INFO sqlalchemy.engine.Engine ROLLBACK
# 2024-08-31 18:02:17,496 INFO sqlalchemy.engine.Engine BEGIN (implicit)
# 2024-08-31 18:02:17,496 INFO sqlalchemy.engine.Engine SELECT marked_sentences.id, marked_sentences.date_time, marked_sentences.sentence, marked_sentences.comment, marked_sentences.lesson, marked_sentences.line
# FROM marked_sentences
# WHERE marked_sentences.date_time > ? AND marked_sentences.date_time < ? AND marked_sentences.lesson = ?
# 2024-08-31 18:02:17,496 INFO sqlalchemy.engine.Engine [cached since 0.1213s ago] ('0001-01-01 00:00:00.000000', '9999-12-31 23:59:59.999999', 58)
# 2024-08-31 18:02:17,496 INFO sqlalchemy.engine.Engine ROLLBACK
# 2024-08-31 18:02:17,497 INFO sqlalchemy.engine.Engine BEGIN (implicit)
# 2024-08-31 18:02:17,497 INFO sqlalchemy.engine.Engine SELECT marked_sentences.id, marked_sentences.date_time, marked_sentences.sentence, marked_sentences.comment, marked_sentences.lesson, marked_sentences.line
# FROM marked_sentences
# WHERE marked_sentences.date_time > ? AND marked_sentences.date_time < ? AND marked_sentences.lesson = ?
# 2024-08-31 18:02:17,497 INFO sqlalchemy.engine.Engine [cached since 0.1224s ago] ('0001-01-01 00:00:00.000000', '9999-12-31 23:59:59.999999', 59)
# 2024-08-31 18:02:17,497 INFO sqlalchemy.engine.Engine ROLLBACK
# 2024-08-31 18:02:17,498 INFO sqlalchemy.engine.Engine BEGIN (implicit)
# 2024-08-31 18:02:17,498 INFO sqlalchemy.engine.Engine SELECT marked_sentences.id, marked_sentences.date_time, marked_sentences.sentence, marked_sentences.comment, marked_sentences.lesson, marked_sentences.line
# FROM marked_sentences
# WHERE marked_sentences.date_time > ? AND marked_sentences.date_time < ? AND marked_sentences.lesson = ?
# 2024-08-31 18:02:17,498 INFO sqlalchemy.engine.Engine [cached since 0.1235s ago] ('0001-01-01 00:00:00.000000', '9999-12-31 23:59:59.999999', 60)
# 2024-08-31 18:02:17,499 INFO sqlalchemy.engine.Engine ROLLBACK
# 2024-08-31 18:02:17,499 INFO sqlalchemy.engine.Engine BEGIN (implicit)
# 2024-08-31 18:02:17,499 INFO sqlalchemy.engine.Engine SELECT marked_sentences.id, marked_sentences.date_time, marked_sentences.sentence, marked_sentences.comment, marked_sentences.lesson, marked_sentences.line
# FROM marked_sentences
# WHERE marked_sentences.date_time > ? AND marked_sentences.date_time < ? AND marked_sentences.lesson = ?
# 2024-08-31 18:02:17,499 INFO sqlalchemy.engine.Engine [cached since 0.1247s ago] ('0001-01-01 00:00:00.000000', '9999-12-31 23:59:59.999999', 61)
# 2024-08-31 18:02:17,500 INFO sqlalchemy.engine.Engine ROLLBACK
# 2024-08-31 18:02:17,500 INFO sqlalchemy.engine.Engine BEGIN (implicit)
# 2024-08-31 18:02:17,500 INFO sqlalchemy.engine.Engine SELECT marked_sentences.id, marked_sentences.date_time, marked_sentences.sentence, marked_sentences.comment, marked_sentences.lesson, marked_sentences.line
# FROM marked_sentences
# WHERE marked_sentences.date_time > ? AND marked_sentences.date_time < ? AND marked_sentences.lesson = ?
# 2024-08-31 18:02:17,500 INFO sqlalchemy.engine.Engine [cached since 0.1257s ago] ('0001-01-01 00:00:00.000000', '9999-12-31 23:59:59.999999', 62)
# 2024-08-31 18:02:17,501 INFO sqlalchemy.engine.Engine ROLLBACK
# 2024-08-31 18:02:17,501 INFO sqlalchemy.engine.Engine BEGIN (implicit)
# 2024-08-31 18:02:17,501 INFO sqlalchemy.engine.Engine SELECT marked_sentences.id, marked_sentences.date_time, marked_sentences.sentence, marked_sentences.comment, marked_sentences.lesson, marked_sentences.line
# FROM marked_sentences
# WHERE marked_sentences.date_time > ? AND marked_sentences.date_time < ? AND marked_sentences.lesson = ?
# 2024-08-31 18:02:17,501 INFO sqlalchemy.engine.Engine [cached since 0.1267s ago] ('0001-01-01 00:00:00.000000', '9999-12-31 23:59:59.999999', 63)
# 2024-08-31 18:02:17,502 INFO sqlalchemy.engine.Engine ROLLBACK
# 2024-08-31 18:02:17,502 INFO sqlalchemy.engine.Engine BEGIN (implicit)
# 2024-08-31 18:02:17,502 INFO sqlalchemy.engine.Engine SELECT marked_sentences.id, marked_sentences.date_time, marked_sentences.sentence, marked_sentences.comment, marked_sentences.lesson, marked_sentences.line
# FROM marked_sentences
# WHERE marked_sentences.date_time > ? AND marked_sentences.date_time < ? AND marked_sentences.lesson = ?
# 2024-08-31 18:02:17,502 INFO sqlalchemy.engine.Engine [cached since 0.1277s ago] ('0001-01-01 00:00:00.000000', '9999-12-31 23:59:59.999999', 64)
# 2024-08-31 18:02:17,503 INFO sqlalchemy.engine.Engine ROLLBACK
# 2024-08-31 18:02:17,503 INFO sqlalchemy.engine.Engine BEGIN (implicit)
# 2024-08-31 18:02:17,503 INFO sqlalchemy.engine.Engine SELECT marked_sentences.id, marked_sentences.date_time, marked_sentences.sentence, marked_sentences.comment, marked_sentences.lesson, marked_sentences.line
# FROM marked_sentences
# WHERE marked_sentences.date_time > ? AND marked_sentences.date_time < ? AND marked_sentences.lesson = ?
# 2024-08-31 18:02:17,503 INFO sqlalchemy.engine.Engine [cached since 0.1286s ago] ('0001-01-01 00:00:00.000000', '9999-12-31 23:59:59.999999', 65)
# 2024-08-31 18:02:17,504 INFO sqlalchemy.engine.Engine ROLLBACK
# 2024-08-31 18:02:17,504 INFO sqlalchemy.engine.Engine BEGIN (implicit)
# 2024-08-31 18:02:17,504 INFO sqlalchemy.engine.Engine SELECT marked_sentences.id, marked_sentences.date_time, marked_sentences.sentence, marked_sentences.comment, marked_sentences.lesson, marked_sentences.line
# FROM marked_sentences
# WHERE marked_sentences.date_time > ? AND marked_sentences.date_time < ? AND marked_sentences.lesson = ?
# 2024-08-31 18:02:17,504 INFO sqlalchemy.engine.Engine [cached since 0.1296s ago] ('0001-01-01 00:00:00.000000', '9999-12-31 23:59:59.999999', 66)
# 2024-08-31 18:02:17,505 INFO sqlalchemy.engine.Engine ROLLBACK
# 2024-08-31 18:02:17,505 INFO sqlalchemy.engine.Engine BEGIN (implicit)
# 2024-08-31 18:02:17,505 INFO sqlalchemy.engine.Engine SELECT marked_sentences.id, marked_sentences.date_time, marked_sentences.sentence, marked_sentences.comment, marked_sentences.lesson, marked_sentences.line
# FROM marked_sentences
# WHERE marked_sentences.date_time > ? AND marked_sentences.date_time < ? AND marked_sentences.lesson = ?
# 2024-08-31 18:02:17,506 INFO sqlalchemy.engine.Engine [cached since 0.1308s ago] ('0001-01-01 00:00:00.000000', '9999-12-31 23:59:59.999999', 67)
# 2024-08-31 18:02:17,506 INFO sqlalchemy.engine.Engine ROLLBACK
# 2024-08-31 18:02:17,506 INFO sqlalchemy.engine.Engine BEGIN (implicit)
# 2024-08-31 18:02:17,506 INFO sqlalchemy.engine.Engine SELECT marked_sentences.id, marked_sentences.date_time, marked_sentences.sentence, marked_sentences.comment, marked_sentences.lesson, marked_sentences.line
# FROM marked_sentences
# WHERE marked_sentences.date_time > ? AND marked_sentences.date_time < ? AND marked_sentences.lesson = ?
# 2024-08-31 18:02:17,506 INFO sqlalchemy.engine.Engine [cached since 0.1317s ago] ('0001-01-01 00:00:00.000000', '9999-12-31 23:59:59.999999', 68)
# 2024-08-31 18:02:17,507 INFO sqlalchemy.engine.Engine ROLLBACK
# 2024-08-31 18:02:17,507 INFO sqlalchemy.engine.Engine BEGIN (implicit)
# 2024-08-31 18:02:17,507 INFO sqlalchemy.engine.Engine SELECT marked_sentences.id, marked_sentences.date_time, marked_sentences.sentence, marked_sentences.comment, marked_sentences.lesson, marked_sentences.line
# FROM marked_sentences
# WHERE marked_sentences.date_time > ? AND marked_sentences.date_time < ? AND marked_sentences.lesson = ?
# 2024-08-31 18:02:17,507 INFO sqlalchemy.engine.Engine [cached since 0.1327s ago] ('0001-01-01 00:00:00.000000', '9999-12-31 23:59:59.999999', 69)
# 2024-08-31 18:02:17,508 INFO sqlalchemy.engine.Engine ROLLBACK
# 2024-08-31 18:02:17,508 INFO sqlalchemy.engine.Engine BEGIN (implicit)
# 2024-08-31 18:02:17,508 INFO sqlalchemy.engine.Engine SELECT marked_sentences.id, marked_sentences.date_time, marked_sentences.sentence, marked_sentences.comment, marked_sentences.lesson, marked_sentences.line
# FROM marked_sentences
# WHERE marked_sentences.date_time > ? AND marked_sentences.date_time < ? AND marked_sentences.lesson = ?
# 2024-08-31 18:02:17,508 INFO sqlalchemy.engine.Engine [cached since 0.1337s ago] ('0001-01-01 00:00:00.000000', '9999-12-31 23:59:59.999999', 70)
# 2024-08-31 18:02:17,509 INFO sqlalchemy.engine.Engine ROLLBACK
# 2024-08-31 18:02:17,509 INFO sqlalchemy.engine.Engine BEGIN (implicit)
# 2024-08-31 18:02:17,509 INFO sqlalchemy.engine.Engine SELECT marked_sentences.id, marked_sentences.date_time, marked_sentences.sentence, marked_sentences.comment, marked_sentences.lesson, marked_sentences.line
# FROM marked_sentences
# WHERE marked_sentences.date_time > ? AND marked_sentences.date_time < ? AND marked_sentences.lesson = ?
# 2024-08-31 18:02:17,509 INFO sqlalchemy.engine.Engine [cached since 0.1346s ago] ('0001-01-01 00:00:00.000000', '9999-12-31 23:59:59.999999', 71)
# 2024-08-31 18:02:17,510 INFO sqlalchemy.engine.Engine ROLLBACK
# 2024-08-31 18:02:17,510 INFO sqlalchemy.engine.Engine BEGIN (implicit)
# 2024-08-31 18:02:17,510 INFO sqlalchemy.engine.Engine SELECT marked_sentences.id, marked_sentences.date_time, marked_sentences.sentence, marked_sentences.comment, marked_sentences.lesson, marked_sentences.line
# FROM marked_sentences
# WHERE marked_sentences.date_time > ? AND marked_sentences.date_time < ? AND marked_sentences.lesson = ?
# 2024-08-31 18:02:17,510 INFO sqlalchemy.engine.Engine [cached since 0.1357s ago] ('0001-01-01 00:00:00.000000', '9999-12-31 23:59:59.999999', 72)
# 2024-08-31 18:02:17,511 INFO sqlalchemy.engine.Engine ROLLBACK
# 2024-08-31 18:02:17,511 INFO sqlalchemy.engine.Engine BEGIN (implicit)
# 2024-08-31 18:02:17,511 INFO sqlalchemy.engine.Engine SELECT marked_sentences.id, marked_sentences.date_time, marked_sentences.sentence, marked_sentences.comment, marked_sentences.lesson, marked_sentences.line
# FROM marked_sentences
# WHERE marked_sentences.date_time > ? AND marked_sentences.date_time < ? AND marked_sentences.lesson = ?
# 2024-08-31 18:02:17,512 INFO sqlalchemy.engine.Engine [cached since 0.1369s ago] ('0001-01-01 00:00:00.000000', '9999-12-31 23:59:59.999999', 73)
# 2024-08-31 18:02:17,512 INFO sqlalchemy.engine.Engine ROLLBACK
# 2024-08-31 18:02:17,512 INFO sqlalchemy.engine.Engine BEGIN (implicit)
# 2024-08-31 18:02:17,512 INFO sqlalchemy.engine.Engine SELECT marked_sentences.id, marked_sentences.date_time, marked_sentences.sentence, marked_sentences.comment, marked_sentences.lesson, marked_sentences.line
# FROM marked_sentences
# WHERE marked_sentences.date_time > ? AND marked_sentences.date_time < ? AND marked_sentences.lesson = ?
# 2024-08-31 18:02:17,513 INFO sqlalchemy.engine.Engine [cached since 0.1378s ago] ('0001-01-01 00:00:00.000000', '9999-12-31 23:59:59.999999', 74)
# 2024-08-31 18:02:17,513 INFO sqlalchemy.engine.Engine ROLLBACK
# 2024-08-31 18:02:17,513 INFO sqlalchemy.engine.Engine BEGIN (implicit)
# 2024-08-31 18:02:17,513 INFO sqlalchemy.engine.Engine SELECT marked_sentences.id, marked_sentences.date_time, marked_sentences.sentence, marked_sentences.comment, marked_sentences.lesson, marked_sentences.line
# FROM marked_sentences
# WHERE marked_sentences.date_time > ? AND marked_sentences.date_time < ? AND marked_sentences.lesson = ?
# 2024-08-31 18:02:17,514 INFO sqlalchemy.engine.Engine [cached since 0.1389s ago] ('0001-01-01 00:00:00.000000', '9999-12-31 23:59:59.999999', 75)
# 2024-08-31 18:02:17,514 INFO sqlalchemy.engine.Engine ROLLBACK
# 2024-08-31 18:02:17,514 INFO sqlalchemy.engine.Engine BEGIN (implicit)
# 2024-08-31 18:02:17,515 INFO sqlalchemy.engine.Engine SELECT marked_sentences.id, marked_sentences.date_time, marked_sentences.sentence, marked_sentences.comment, marked_sentences.lesson, marked_sentences.line
# FROM marked_sentences
# WHERE marked_sentences.date_time > ? AND marked_sentences.date_time < ? AND marked_sentences.lesson = ?
# 2024-08-31 18:02:17,515 INFO sqlalchemy.engine.Engine [cached since 0.1401s ago] ('0001-01-01 00:00:00.000000', '9999-12-31 23:59:59.999999', 76)
# 2024-08-31 18:02:17,515 INFO sqlalchemy.engine.Engine ROLLBACK
# 2024-08-31 18:02:17,515 INFO sqlalchemy.engine.Engine BEGIN (implicit)
# 2024-08-31 18:02:17,516 INFO sqlalchemy.engine.Engine SELECT marked_sentences.id, marked_sentences.date_time, marked_sentences.sentence, marked_sentences.comment, marked_sentences.lesson, marked_sentences.line
# FROM marked_sentences
# WHERE marked_sentences.date_time > ? AND marked_sentences.date_time < ? AND marked_sentences.lesson = ?
# 2024-08-31 18:02:17,516 INFO sqlalchemy.engine.Engine [cached since 0.1412s ago] ('0001-01-01 00:00:00.000000', '9999-12-31 23:59:59.999999', 77)
# 2024-08-31 18:02:17,516 INFO sqlalchemy.engine.Engine ROLLBACK
# 2024-08-31 18:02:17,517 INFO sqlalchemy.engine.Engine BEGIN (implicit)
# 2024-08-31 18:02:17,518 INFO sqlalchemy.engine.Engine SELECT marked_sentences.id, marked_sentences.date_time, marked_sentences.sentence, marked_sentences.comment, marked_sentences.lesson, marked_sentences.line
# FROM marked_sentences
# WHERE marked_sentences.date_time > ? AND marked_sentences.date_time < ? AND marked_sentences.lesson = ?
# 2024-08-31 18:02:17,521 INFO sqlalchemy.engine.Engine [cached since 0.1462s ago] ('0001-01-01 00:00:00.000000', '9999-12-31 23:59:59.999999', 78)
# 2024-08-31 18:02:17,522 INFO sqlalchemy.engine.Engine ROLLBACK
# 2024-08-31 18:02:17,522 INFO sqlalchemy.engine.Engine BEGIN (implicit)
# 2024-08-31 18:02:17,522 INFO sqlalchemy.engine.Engine SELECT marked_sentences.id, marked_sentences.date_time, marked_sentences.sentence, marked_sentences.comment, marked_sentences.lesson, marked_sentences.line
# FROM marked_sentences
# WHERE marked_sentences.date_time > ? AND marked_sentences.date_time < ? AND marked_sentences.lesson = ?
# 2024-08-31 18:02:17,523 INFO sqlalchemy.engine.Engine [cached since 0.1479s ago] ('0001-01-01 00:00:00.000000', '9999-12-31 23:59:59.999999', 79)
# 2024-08-31 18:02:17,523 INFO sqlalchemy.engine.Engine ROLLBACK
# 2024-08-31 18:02:17,524 INFO sqlalchemy.engine.Engine BEGIN (implicit)
# 2024-08-31 18:02:17,524 INFO sqlalchemy.engine.Engine SELECT marked_sentences.id, marked_sentences.date_time, marked_sentences.sentence, marked_sentences.comment, marked_sentences.lesson, marked_sentences.line
# FROM marked_sentences
# WHERE marked_sentences.date_time > ? AND marked_sentences.date_time < ? AND marked_sentences.lesson = ?
# 2024-08-31 18:02:17,524 INFO sqlalchemy.engine.Engine [cached since 0.1495s ago] ('0001-01-01 00:00:00.000000', '9999-12-31 23:59:59.999999', 80)
# 2024-08-31 18:02:17,525 INFO sqlalchemy.engine.Engine ROLLBACK
# 2024-08-31 18:02:17,525 INFO sqlalchemy.engine.Engine BEGIN (implicit)
# 2024-08-31 18:02:17,525 INFO sqlalchemy.engine.Engine SELECT marked_sentences.id, marked_sentences.date_time, marked_sentences.sentence, marked_sentences.comment, marked_sentences.lesson, marked_sentences.line
# FROM marked_sentences
# WHERE marked_sentences.date_time > ? AND marked_sentences.date_time < ? AND marked_sentences.lesson = ?
# 2024-08-31 18:02:17,525 INFO sqlalchemy.engine.Engine [cached since 0.1507s ago] ('0001-01-01 00:00:00.000000', '9999-12-31 23:59:59.999999', 81)
# 2024-08-31 18:02:17,526 INFO sqlalchemy.engine.Engine ROLLBACK
# 2024-08-31 18:02:17,526 INFO sqlalchemy.engine.Engine BEGIN (implicit)
# 2024-08-31 18:02:17,526 INFO sqlalchemy.engine.Engine SELECT marked_sentences.id, marked_sentences.date_time, marked_sentences.sentence, marked_sentences.comment, marked_sentences.lesson, marked_sentences.line
# FROM marked_sentences
# WHERE marked_sentences.date_time > ? AND marked_sentences.date_time < ? AND marked_sentences.lesson = ?
# 2024-08-31 18:02:17,526 INFO sqlalchemy.engine.Engine [cached since 0.1517s ago] ('0001-01-01 00:00:00.000000', '9999-12-31 23:59:59.999999', 82)
# 2024-08-31 18:02:17,527 INFO sqlalchemy.engine.Engine ROLLBACK
# 2024-08-31 18:02:17,527 INFO sqlalchemy.engine.Engine BEGIN (implicit)
# 2024-08-31 18:02:17,527 INFO sqlalchemy.engine.Engine SELECT marked_sentences.id, marked_sentences.date_time, marked_sentences.sentence, marked_sentences.comment, marked_sentences.lesson, marked_sentences.line
# FROM marked_sentences
# WHERE marked_sentences.date_time > ? AND marked_sentences.date_time < ? AND marked_sentences.lesson = ?
# 2024-08-31 18:02:17,528 INFO sqlalchemy.engine.Engine [cached since 0.1528s ago] ('0001-01-01 00:00:00.000000', '9999-12-31 23:59:59.999999', 83)
# 2024-08-31 18:02:17,528 INFO sqlalchemy.engine.Engine ROLLBACK
# 2024-08-31 18:02:17,528 INFO sqlalchemy.engine.Engine BEGIN (implicit)
# 2024-08-31 18:02:17,528 INFO sqlalchemy.engine.Engine SELECT marked_sentences.id, marked_sentences.date_time, marked_sentences.sentence, marked_sentences.comment, marked_sentences.lesson, marked_sentences.line
# FROM marked_sentences
# WHERE marked_sentences.date_time > ? AND marked_sentences.date_time < ? AND marked_sentences.lesson = ?
# 2024-08-31 18:02:17,529 INFO sqlalchemy.engine.Engine [cached since 0.1538s ago] ('0001-01-01 00:00:00.000000', '9999-12-31 23:59:59.999999', 84)
# 2024-08-31 18:02:17,529 INFO sqlalchemy.engine.Engine ROLLBACK
# 2024-08-31 18:02:17,529 INFO sqlalchemy.engine.Engine BEGIN (implicit)
# 2024-08-31 18:02:17,529 INFO sqlalchemy.engine.Engine SELECT marked_sentences.id, marked_sentences.date_time, marked_sentences.sentence, marked_sentences.comment, marked_sentences.lesson, marked_sentences.line
# FROM marked_sentences
# WHERE marked_sentences.date_time > ? AND marked_sentences.date_time < ? AND marked_sentences.lesson = ?
# 2024-08-31 18:02:17,530 INFO sqlalchemy.engine.Engine [cached since 0.155s ago] ('0001-01-01 00:00:00.000000', '9999-12-31 23:59:59.999999', 85)
# 2024-08-31 18:02:17,530 INFO sqlalchemy.engine.Engine ROLLBACK
# 2024-08-31 18:02:17,531 INFO sqlalchemy.engine.Engine BEGIN (implicit)
# 2024-08-31 18:02:17,531 INFO sqlalchemy.engine.Engine SELECT marked_sentences.id, marked_sentences.date_time, marked_sentences.sentence, marked_sentences.comment, marked_sentences.lesson, marked_sentences.line
# FROM marked_sentences
# WHERE marked_sentences.date_time > ? AND marked_sentences.date_time < ? AND marked_sentences.lesson = ?
# 2024-08-31 18:02:17,532 INFO sqlalchemy.engine.Engine [cached since 0.1571s ago] ('0001-01-01 00:00:00.000000', '9999-12-31 23:59:59.999999', 86)
# 2024-08-31 18:02:17,532 INFO sqlalchemy.engine.Engine ROLLBACK
# 2024-08-31 18:02:17,533 INFO sqlalchemy.engine.Engine BEGIN (implicit)
# 2024-08-31 18:02:17,534 INFO sqlalchemy.engine.Engine SELECT marked_sentences.id, marked_sentences.date_time, marked_sentences.sentence, marked_sentences.comment, marked_sentences.lesson, marked_sentences.line
# FROM marked_sentences
# WHERE marked_sentences.date_time > ? AND marked_sentences.date_time < ? AND marked_sentences.lesson = ?
# 2024-08-31 18:02:17,534 INFO sqlalchemy.engine.Engine [cached since 0.1591s ago] ('0001-01-01 00:00:00.000000', '9999-12-31 23:59:59.999999', 87)
# 2024-08-31 18:02:17,534 INFO sqlalchemy.engine.Engine ROLLBACK
# 2024-08-31 18:02:17,535 INFO sqlalchemy.engine.Engine BEGIN (implicit)
# 2024-08-31 18:02:17,535 INFO sqlalchemy.engine.Engine SELECT marked_sentences.id, marked_sentences.date_time, marked_sentences.sentence, marked_sentences.comment, marked_sentences.lesson, marked_sentences.line
# FROM marked_sentences
# WHERE marked_sentences.date_time > ? AND marked_sentences.date_time < ? AND marked_sentences.lesson = ?
# 2024-08-31 18:02:17,535 INFO sqlalchemy.engine.Engine [cached since 0.1605s ago] ('0001-01-01 00:00:00.000000', '9999-12-31 23:59:59.999999', 88)
# 2024-08-31 18:02:17,536 INFO sqlalchemy.engine.Engine ROLLBACK
# 2024-08-31 18:02:17,536 INFO sqlalchemy.engine.Engine BEGIN (implicit)
# 2024-08-31 18:02:17,536 INFO sqlalchemy.engine.Engine SELECT marked_sentences.id, marked_sentences.date_time, marked_sentences.sentence, marked_sentences.comment, marked_sentences.lesson, marked_sentences.line
# FROM marked_sentences
# WHERE marked_sentences.date_time > ? AND marked_sentences.date_time < ? AND marked_sentences.lesson = ?
# 2024-08-31 18:02:17,536 INFO sqlalchemy.engine.Engine [cached since 0.1615s ago] ('0001-01-01 00:00:00.000000', '9999-12-31 23:59:59.999999', 89)
# 2024-08-31 18:02:17,537 INFO sqlalchemy.engine.Engine ROLLBACK
# 2024-08-31 18:02:17,537 INFO sqlalchemy.engine.Engine BEGIN (implicit)
# 2024-08-31 18:02:17,537 INFO sqlalchemy.engine.Engine SELECT marked_sentences.id, marked_sentences.date_time, marked_sentences.sentence, marked_sentences.comment, marked_sentences.lesson, marked_sentences.line
# FROM marked_sentences
# WHERE marked_sentences.date_time > ? AND marked_sentences.date_time < ? AND marked_sentences.lesson = ?
# 2024-08-31 18:02:17,537 INFO sqlalchemy.engine.Engine [cached since 0.1625s ago] ('0001-01-01 00:00:00.000000', '9999-12-31 23:59:59.999999', 90)
# 2024-08-31 18:02:17,537 INFO sqlalchemy.engine.Engine ROLLBACK
# 2024-08-31 18:02:17,538 INFO sqlalchemy.engine.Engine BEGIN (implicit)
# 2024-08-31 18:02:17,538 INFO sqlalchemy.engine.Engine SELECT marked_sentences.id, marked_sentences.date_time, marked_sentences.sentence, marked_sentences.comment, marked_sentences.lesson, marked_sentences.line
# FROM marked_sentences
# WHERE marked_sentences.date_time > ? AND marked_sentences.date_time < ? AND marked_sentences.lesson = ?
# 2024-08-31 18:02:17,538 INFO sqlalchemy.engine.Engine [cached since 0.1636s ago] ('0001-01-01 00:00:00.000000', '9999-12-31 23:59:59.999999', 91)
# 2024-08-31 18:02:17,539 INFO sqlalchemy.engine.Engine ROLLBACK
# 2024-08-31 18:02:17,539 INFO sqlalchemy.engine.Engine BEGIN (implicit)
# 2024-08-31 18:02:17,539 INFO sqlalchemy.engine.Engine SELECT marked_sentences.id, marked_sentences.date_time, marked_sentences.sentence, marked_sentences.comment, marked_sentences.lesson, marked_sentences.line
# FROM marked_sentences
# WHERE marked_sentences.date_time > ? AND marked_sentences.date_time < ? AND marked_sentences.lesson = ?
# 2024-08-31 18:02:17,539 INFO sqlalchemy.engine.Engine [cached since 0.1646s ago] ('0001-01-01 00:00:00.000000', '9999-12-31 23:59:59.999999', 92)
# 2024-08-31 18:02:17,540 INFO sqlalchemy.engine.Engine ROLLBACK
# 2024-08-31 18:02:17,540 INFO sqlalchemy.engine.Engine BEGIN (implicit)
# 2024-08-31 18:02:17,540 INFO sqlalchemy.engine.Engine SELECT marked_sentences.id, marked_sentences.date_time, marked_sentences.sentence, marked_sentences.comment, marked_sentences.lesson, marked_sentences.line
# FROM marked_sentences
# WHERE marked_sentences.date_time > ? AND marked_sentences.date_time < ? AND marked_sentences.lesson = ?
# 2024-08-31 18:02:17,540 INFO sqlalchemy.engine.Engine [cached since 0.1656s ago] ('0001-01-01 00:00:00.000000', '9999-12-31 23:59:59.999999', 93)
# 2024-08-31 18:02:17,541 INFO sqlalchemy.engine.Engine ROLLBACK
# 2024-08-31 18:02:17,541 INFO sqlalchemy.engine.Engine BEGIN (implicit)
# 2024-08-31 18:02:17,541 INFO sqlalchemy.engine.Engine SELECT marked_sentences.id, marked_sentences.date_time, marked_sentences.sentence, marked_sentences.comment, marked_sentences.lesson, marked_sentences.line
# FROM marked_sentences
# WHERE marked_sentences.date_time > ? AND marked_sentences.date_time < ? AND marked_sentences.lesson = ?
# 2024-08-31 18:02:17,542 INFO sqlalchemy.engine.Engine [cached since 0.1668s ago] ('0001-01-01 00:00:00.000000', '9999-12-31 23:59:59.999999', 94)
# 2024-08-31 18:02:17,542 INFO sqlalchemy.engine.Engine ROLLBACK
# 2024-08-31 18:02:17,542 INFO sqlalchemy.engine.Engine BEGIN (implicit)
# 2024-08-31 18:02:17,542 INFO sqlalchemy.engine.Engine SELECT marked_sentences.id, marked_sentences.date_time, marked_sentences.sentence, marked_sentences.comment, marked_sentences.lesson, marked_sentences.line
# FROM marked_sentences
# WHERE marked_sentences.date_time > ? AND marked_sentences.date_time < ? AND marked_sentences.lesson = ?
# 2024-08-31 18:02:17,542 INFO sqlalchemy.engine.Engine [cached since 0.1678s ago] ('0001-01-01 00:00:00.000000', '9999-12-31 23:59:59.999999', 95)
# 2024-08-31 18:02:17,543 INFO sqlalchemy.engine.Engine ROLLBACK
# 2024-08-31 18:02:17,543 INFO sqlalchemy.engine.Engine BEGIN (implicit)
# 2024-08-31 18:02:17,543 INFO sqlalchemy.engine.Engine SELECT marked_sentences.id, marked_sentences.date_time, marked_sentences.sentence, marked_sentences.comment, marked_sentences.lesson, marked_sentences.line
# FROM marked_sentences
# WHERE marked_sentences.date_time > ? AND marked_sentences.date_time < ? AND marked_sentences.lesson = ?
# 2024-08-31 18:02:17,543 INFO sqlalchemy.engine.Engine [cached since 0.1687s ago] ('0001-01-01 00:00:00.000000', '9999-12-31 23:59:59.999999', 96)
# 2024-08-31 18:02:17,544 INFO sqlalchemy.engine.Engine ROLLBACK
# 2024-08-31 18:02:17,544 INFO sqlalchemy.engine.Engine BEGIN (implicit)
# 2024-08-31 18:02:17,544 INFO sqlalchemy.engine.Engine SELECT marked_sentences.id, marked_sentences.date_time, marked_sentences.sentence, marked_sentences.comment, marked_sentences.lesson, marked_sentences.line
# FROM marked_sentences
# WHERE marked_sentences.date_time > ? AND marked_sentences.date_time < ? AND marked_sentences.lesson = ?
# 2024-08-31 18:02:17,544 INFO sqlalchemy.engine.Engine [cached since 0.1696s ago] ('0001-01-01 00:00:00.000000', '9999-12-31 23:59:59.999999', 97)
# 2024-08-31 18:02:17,545 INFO sqlalchemy.engine.Engine ROLLBACK
# 2024-08-31 18:02:17,545 INFO sqlalchemy.engine.Engine BEGIN (implicit)
# 2024-08-31 18:02:17,545 INFO sqlalchemy.engine.Engine SELECT marked_sentences.id, marked_sentences.date_time, marked_sentences.sentence, marked_sentences.comment, marked_sentences.lesson, marked_sentences.line
# FROM marked_sentences
# WHERE marked_sentences.date_time > ? AND marked_sentences.date_time < ? AND marked_sentences.lesson = ?
# 2024-08-31 18:02:17,545 INFO sqlalchemy.engine.Engine [cached since 0.1706s ago] ('0001-01-01 00:00:00.000000', '9999-12-31 23:59:59.999999', 98)
# 2024-08-31 18:02:17,546 INFO sqlalchemy.engine.Engine ROLLBACK
# 2024-08-31 18:02:17,546 INFO sqlalchemy.engine.Engine BEGIN (implicit)
# 2024-08-31 18:02:17,546 INFO sqlalchemy.engine.Engine SELECT marked_sentences.id, marked_sentences.date_time, marked_sentences.sentence, marked_sentences.comment, marked_sentences.lesson, marked_sentences.line
# FROM marked_sentences
# WHERE marked_sentences.date_time > ? AND marked_sentences.date_time < ? AND marked_sentences.lesson = ?
# 2024-08-31 18:02:17,546 INFO sqlalchemy.engine.Engine [cached since 0.1716s ago] ('0001-01-01 00:00:00.000000', '9999-12-31 23:59:59.999999', 99)
# 2024-08-31 18:02:17,547 INFO sqlalchemy.engine.Engine ROLLBACK
# 2024-08-31 18:02:17,547 INFO sqlalchemy.engine.Engine BEGIN (implicit)
# 2024-08-31 18:02:17,547 INFO sqlalchemy.engine.Engine SELECT marked_sentences.id, marked_sentences.date_time, marked_sentences.sentence, marked_sentences.comment, marked_sentences.lesson, marked_sentences.line
# FROM marked_sentences
# WHERE marked_sentences.date_time > ? AND marked_sentences.date_time < ? AND marked_sentences.lesson = ?
# 2024-08-31 18:02:17,547 INFO sqlalchemy.engine.Engine [cached since 0.1727s ago] ('0001-01-01 00:00:00.000000', '9999-12-31 23:59:59.999999', 100)
# 2024-08-31 18:02:17,548 INFO sqlalchemy.engine.Engine ROLLBACK

# %%
th_row, rows
# Out:
# ([4, 5, 45, 97],
#  [[datetime.datetime(2024, 8, 30, 18, 11, 11, 870753),
#    datetime.datetime(2024, 8, 30, 18, 37, 31, 497652),
#    datetime.datetime(2024, 8, 31, 17, 32, 18, 58630)],
#   [datetime.datetime(2024, 8, 30, 18, 12, 5, 788656),
#    datetime.datetime(2024, 8, 31, 17, 33, 16, 342000)],
#   [datetime.datetime(2024, 8, 30, 18, 13, 24, 955334)],
#   [datetime.datetime(2024, 8, 31, 17, 34, 3, 198940)]])

# %%
test = {1 : "toto", 3 : "titi", 2 : "tati", 4 : "tonton"}

# %%
test.keys()
# Out:
# dict_keys([1, 3, 2, 4])

# %%
str(rows[0][0])
# Out:
# '2024-08-30 18:11:11.870753'

# %%
rows[0][0]
# Out:
# datetime.datetime(2024, 8, 30, 18, 11, 11, 870753)

# %%
import datetime

# %%
date = '2024-08-30 18:11:11.870753'

# %%
try:
    date_to_datetime = datetime.datetime.strptime(date, '%Y-%m-%d %H:%M:%S.%f')
except ValueError as exc:
    raise ValueError('Bad datetime:', date) from exc

# %%
date_to_datetime
# Out:
# datetime.datetime(2024, 8, 30, 18, 11, 11, 870753)

# %%
rows[0][0].strftime('%y-%m-%d %H:%M:%S.%f')
# Out:
# '24-08-30 18:11:11.870753'

# %%
str(date_to_datetime)
# Out:
# '2024-08-30 18:11:11.870753'

# %%
datetime.datetime.strptime(str(date_to_datetime), '%Y-%m-%d %H:%M:%S.%f')
# Out:
# datetime.datetime(2024, 8, 30, 18, 11, 11, 870753)
