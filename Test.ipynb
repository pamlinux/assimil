# %%
from tonic_accent import get_history
# Out:
# 2024-09-01 18:39:14,388 INFO sqlalchemy.engine.Engine BEGIN (implicit)
# 2024-09-01 18:39:14,388 INFO sqlalchemy.engine.Engine PRAGMA main.table_info("word_dict")
# 2024-09-01 18:39:14,388 INFO sqlalchemy.engine.Engine [raw sql] ()
# 2024-09-01 18:39:14,389 INFO sqlalchemy.engine.Engine PRAGMA main.table_info("word_index")
# 2024-09-01 18:39:14,389 INFO sqlalchemy.engine.Engine [raw sql] ()
# 2024-09-01 18:39:14,389 INFO sqlalchemy.engine.Engine PRAGMA main.table_info("sentences")
# 2024-09-01 18:39:14,389 INFO sqlalchemy.engine.Engine [raw sql] ()
# 2024-09-01 18:39:14,389 INFO sqlalchemy.engine.Engine PRAGMA main.table_info("marked_sentences")
# 2024-09-01 18:39:14,390 INFO sqlalchemy.engine.Engine [raw sql] ()
# 2024-09-01 18:39:14,390 INFO sqlalchemy.engine.Engine COMMIT

# %%
col_nb, th_rows, rows = get_history()
# Out:
# 2024-09-01 18:44:18,093 INFO sqlalchemy.engine.Engine BEGIN (implicit)
# 2024-09-01 18:44:18,094 INFO sqlalchemy.engine.Engine SELECT marked_sentences.id, marked_sentences.date_time, marked_sentences.sentence, marked_sentences.comment, marked_sentences.lesson, marked_sentences.line
# FROM marked_sentences
# WHERE marked_sentences.date_time > ? AND marked_sentences.date_time < ? AND marked_sentences.lesson = ?
# 2024-09-01 18:44:18,095 INFO sqlalchemy.engine.Engine [cached since 300.6s ago] ('0001-01-01 00:00:00.000000', '9999-12-31 23:59:59.999999', 1)
# 2024-09-01 18:44:18,096 INFO sqlalchemy.engine.Engine ROLLBACK
# 2024-09-01 18:44:18,097 INFO sqlalchemy.engine.Engine BEGIN (implicit)
# 2024-09-01 18:44:18,098 INFO sqlalchemy.engine.Engine SELECT marked_sentences.id, marked_sentences.date_time, marked_sentences.sentence, marked_sentences.comment, marked_sentences.lesson, marked_sentences.line
# FROM marked_sentences
# WHERE marked_sentences.date_time > ? AND marked_sentences.date_time < ? AND marked_sentences.lesson = ?
# 2024-09-01 18:44:18,099 INFO sqlalchemy.engine.Engine [cached since 300.6s ago] ('0001-01-01 00:00:00.000000', '9999-12-31 23:59:59.999999', 2)
# 2024-09-01 18:44:18,100 INFO sqlalchemy.engine.Engine ROLLBACK
# 2024-09-01 18:44:18,101 INFO sqlalchemy.engine.Engine BEGIN (implicit)
# 2024-09-01 18:44:18,103 INFO sqlalchemy.engine.Engine SELECT marked_sentences.id, marked_sentences.date_time, marked_sentences.sentence, marked_sentences.comment, marked_sentences.lesson, marked_sentences.line
# FROM marked_sentences
# WHERE marked_sentences.date_time > ? AND marked_sentences.date_time < ? AND marked_sentences.lesson = ?
# 2024-09-01 18:44:18,103 INFO sqlalchemy.engine.Engine [cached since 300.6s ago] ('0001-01-01 00:00:00.000000', '9999-12-31 23:59:59.999999', 3)
# 2024-09-01 18:44:18,104 INFO sqlalchemy.engine.Engine ROLLBACK
# 2024-09-01 18:44:18,108 INFO sqlalchemy.engine.Engine BEGIN (implicit)
# 2024-09-01 18:44:18,115 INFO sqlalchemy.engine.Engine SELECT marked_sentences.id, marked_sentences.date_time, marked_sentences.sentence, marked_sentences.comment, marked_sentences.lesson, marked_sentences.line
# FROM marked_sentences
# WHERE marked_sentences.date_time > ? AND marked_sentences.date_time < ? AND marked_sentences.lesson = ?
# 2024-09-01 18:44:18,116 INFO sqlalchemy.engine.Engine [cached since 300.7s ago] ('0001-01-01 00:00:00.000000', '9999-12-31 23:59:59.999999', 4)
# 2024-09-01 18:44:18,118 INFO sqlalchemy.engine.Engine ROLLBACK
# 2024-09-01 18:44:18,123 INFO sqlalchemy.engine.Engine BEGIN (implicit)
# 2024-09-01 18:44:18,140 INFO sqlalchemy.engine.Engine SELECT marked_sentences.id, marked_sentences.date_time, marked_sentences.sentence, marked_sentences.comment, marked_sentences.lesson, marked_sentences.line
# FROM marked_sentences
# WHERE marked_sentences.date_time > ? AND marked_sentences.date_time < ? AND marked_sentences.lesson = ?
# 2024-09-01 18:44:18,141 INFO sqlalchemy.engine.Engine [cached since 300.7s ago] ('0001-01-01 00:00:00.000000', '9999-12-31 23:59:59.999999', 5)
# 2024-09-01 18:44:18,142 INFO sqlalchemy.engine.Engine ROLLBACK
# 2024-09-01 18:44:18,143 INFO sqlalchemy.engine.Engine BEGIN (implicit)
# 2024-09-01 18:44:18,144 INFO sqlalchemy.engine.Engine SELECT marked_sentences.id, marked_sentences.date_time, marked_sentences.sentence, marked_sentences.comment, marked_sentences.lesson, marked_sentences.line
# FROM marked_sentences
# WHERE marked_sentences.date_time > ? AND marked_sentences.date_time < ? AND marked_sentences.lesson = ?
# 2024-09-01 18:44:18,145 INFO sqlalchemy.engine.Engine [cached since 300.7s ago] ('0001-01-01 00:00:00.000000', '9999-12-31 23:59:59.999999', 6)
# 2024-09-01 18:44:18,146 INFO sqlalchemy.engine.Engine ROLLBACK
# 2024-09-01 18:44:18,146 INFO sqlalchemy.engine.Engine BEGIN (implicit)
# 2024-09-01 18:44:18,147 INFO sqlalchemy.engine.Engine SELECT marked_sentences.id, marked_sentences.date_time, marked_sentences.sentence, marked_sentences.comment, marked_sentences.lesson, marked_sentences.line
# FROM marked_sentences
# WHERE marked_sentences.date_time > ? AND marked_sentences.date_time < ? AND marked_sentences.lesson = ?
# 2024-09-01 18:44:18,147 INFO sqlalchemy.engine.Engine [cached since 300.7s ago] ('0001-01-01 00:00:00.000000', '9999-12-31 23:59:59.999999', 7)
# 2024-09-01 18:44:18,149 INFO sqlalchemy.engine.Engine ROLLBACK
# 2024-09-01 18:44:18,153 INFO sqlalchemy.engine.Engine BEGIN (implicit)
# 2024-09-01 18:44:18,153 INFO sqlalchemy.engine.Engine SELECT marked_sentences.id, marked_sentences.date_time, marked_sentences.sentence, marked_sentences.comment, marked_sentences.lesson, marked_sentences.line
# FROM marked_sentences
# WHERE marked_sentences.date_time > ? AND marked_sentences.date_time < ? AND marked_sentences.lesson = ?
# 2024-09-01 18:44:18,154 INFO sqlalchemy.engine.Engine [cached since 300.7s ago] ('0001-01-01 00:00:00.000000', '9999-12-31 23:59:59.999999', 8)
# 2024-09-01 18:44:18,154 INFO sqlalchemy.engine.Engine ROLLBACK
# 2024-09-01 18:44:18,155 INFO sqlalchemy.engine.Engine BEGIN (implicit)
# 2024-09-01 18:44:18,155 INFO sqlalchemy.engine.Engine SELECT marked_sentences.id, marked_sentences.date_time, marked_sentences.sentence, marked_sentences.comment, marked_sentences.lesson, marked_sentences.line
# FROM marked_sentences
# WHERE marked_sentences.date_time > ? AND marked_sentences.date_time < ? AND marked_sentences.lesson = ?
# 2024-09-01 18:44:18,156 INFO sqlalchemy.engine.Engine [cached since 300.7s ago] ('0001-01-01 00:00:00.000000', '9999-12-31 23:59:59.999999', 9)
# 2024-09-01 18:44:18,156 INFO sqlalchemy.engine.Engine ROLLBACK
# 2024-09-01 18:44:18,157 INFO sqlalchemy.engine.Engine BEGIN (implicit)
# 2024-09-01 18:44:18,157 INFO sqlalchemy.engine.Engine SELECT marked_sentences.id, marked_sentences.date_time, marked_sentences.sentence, marked_sentences.comment, marked_sentences.lesson, marked_sentences.line
# FROM marked_sentences
# WHERE marked_sentences.date_time > ? AND marked_sentences.date_time < ? AND marked_sentences.lesson = ?
# 2024-09-01 18:44:18,157 INFO sqlalchemy.engine.Engine [cached since 300.7s ago] ('0001-01-01 00:00:00.000000', '9999-12-31 23:59:59.999999', 10)
# 2024-09-01 18:44:18,158 INFO sqlalchemy.engine.Engine ROLLBACK
# 2024-09-01 18:44:18,159 INFO sqlalchemy.engine.Engine BEGIN (implicit)
# 2024-09-01 18:44:18,159 INFO sqlalchemy.engine.Engine SELECT marked_sentences.id, marked_sentences.date_time, marked_sentences.sentence, marked_sentences.comment, marked_sentences.lesson, marked_sentences.line
# FROM marked_sentences
# WHERE marked_sentences.date_time > ? AND marked_sentences.date_time < ? AND marked_sentences.lesson = ?
# 2024-09-01 18:44:18,160 INFO sqlalchemy.engine.Engine [cached since 300.7s ago] ('0001-01-01 00:00:00.000000', '9999-12-31 23:59:59.999999', 11)
# 2024-09-01 18:44:18,160 INFO sqlalchemy.engine.Engine ROLLBACK
# 2024-09-01 18:44:18,160 INFO sqlalchemy.engine.Engine BEGIN (implicit)
# 2024-09-01 18:44:18,161 INFO sqlalchemy.engine.Engine SELECT marked_sentences.id, marked_sentences.date_time, marked_sentences.sentence, marked_sentences.comment, marked_sentences.lesson, marked_sentences.line
# FROM marked_sentences
# WHERE marked_sentences.date_time > ? AND marked_sentences.date_time < ? AND marked_sentences.lesson = ?
# 2024-09-01 18:44:18,161 INFO sqlalchemy.engine.Engine [cached since 300.7s ago] ('0001-01-01 00:00:00.000000', '9999-12-31 23:59:59.999999', 12)
# 2024-09-01 18:44:18,161 INFO sqlalchemy.engine.Engine ROLLBACK
# 2024-09-01 18:44:18,162 INFO sqlalchemy.engine.Engine BEGIN (implicit)
# 2024-09-01 18:44:18,162 INFO sqlalchemy.engine.Engine SELECT marked_sentences.id, marked_sentences.date_time, marked_sentences.sentence, marked_sentences.comment, marked_sentences.lesson, marked_sentences.line
# FROM marked_sentences
# WHERE marked_sentences.date_time > ? AND marked_sentences.date_time < ? AND marked_sentences.lesson = ?
# 2024-09-01 18:44:18,162 INFO sqlalchemy.engine.Engine [cached since 300.7s ago] ('0001-01-01 00:00:00.000000', '9999-12-31 23:59:59.999999', 13)
# 2024-09-01 18:44:18,163 INFO sqlalchemy.engine.Engine ROLLBACK
# 2024-09-01 18:44:18,163 INFO sqlalchemy.engine.Engine BEGIN (implicit)
# 2024-09-01 18:44:18,164 INFO sqlalchemy.engine.Engine SELECT marked_sentences.id, marked_sentences.date_time, marked_sentences.sentence, marked_sentences.comment, marked_sentences.lesson, marked_sentences.line
# FROM marked_sentences
# WHERE marked_sentences.date_time > ? AND marked_sentences.date_time < ? AND marked_sentences.lesson = ?
# 2024-09-01 18:44:18,164 INFO sqlalchemy.engine.Engine [cached since 300.7s ago] ('0001-01-01 00:00:00.000000', '9999-12-31 23:59:59.999999', 14)
# 2024-09-01 18:44:18,164 INFO sqlalchemy.engine.Engine ROLLBACK
# 2024-09-01 18:44:18,164 INFO sqlalchemy.engine.Engine BEGIN (implicit)
# 2024-09-01 18:44:18,165 INFO sqlalchemy.engine.Engine SELECT marked_sentences.id, marked_sentences.date_time, marked_sentences.sentence, marked_sentences.comment, marked_sentences.lesson, marked_sentences.line
# FROM marked_sentences
# WHERE marked_sentences.date_time > ? AND marked_sentences.date_time < ? AND marked_sentences.lesson = ?
# 2024-09-01 18:44:18,165 INFO sqlalchemy.engine.Engine [cached since 300.7s ago] ('0001-01-01 00:00:00.000000', '9999-12-31 23:59:59.999999', 15)
# 2024-09-01 18:44:18,165 INFO sqlalchemy.engine.Engine ROLLBACK
# 2024-09-01 18:44:18,166 INFO sqlalchemy.engine.Engine BEGIN (implicit)
# 2024-09-01 18:44:18,166 INFO sqlalchemy.engine.Engine SELECT marked_sentences.id, marked_sentences.date_time, marked_sentences.sentence, marked_sentences.comment, marked_sentences.lesson, marked_sentences.line
# FROM marked_sentences
# WHERE marked_sentences.date_time > ? AND marked_sentences.date_time < ? AND marked_sentences.lesson = ?
# 2024-09-01 18:44:18,166 INFO sqlalchemy.engine.Engine [cached since 300.7s ago] ('0001-01-01 00:00:00.000000', '9999-12-31 23:59:59.999999', 16)
# 2024-09-01 18:44:18,167 INFO sqlalchemy.engine.Engine ROLLBACK
# 2024-09-01 18:44:18,167 INFO sqlalchemy.engine.Engine BEGIN (implicit)
# 2024-09-01 18:44:18,167 INFO sqlalchemy.engine.Engine SELECT marked_sentences.id, marked_sentences.date_time, marked_sentences.sentence, marked_sentences.comment, marked_sentences.lesson, marked_sentences.line
# FROM marked_sentences
# WHERE marked_sentences.date_time > ? AND marked_sentences.date_time < ? AND marked_sentences.lesson = ?
# 2024-09-01 18:44:18,167 INFO sqlalchemy.engine.Engine [cached since 300.7s ago] ('0001-01-01 00:00:00.000000', '9999-12-31 23:59:59.999999', 17)
# 2024-09-01 18:44:18,168 INFO sqlalchemy.engine.Engine ROLLBACK
# 2024-09-01 18:44:18,168 INFO sqlalchemy.engine.Engine BEGIN (implicit)
# 2024-09-01 18:44:18,168 INFO sqlalchemy.engine.Engine SELECT marked_sentences.id, marked_sentences.date_time, marked_sentences.sentence, marked_sentences.comment, marked_sentences.lesson, marked_sentences.line
# FROM marked_sentences
# WHERE marked_sentences.date_time > ? AND marked_sentences.date_time < ? AND marked_sentences.lesson = ?
# 2024-09-01 18:44:18,169 INFO sqlalchemy.engine.Engine [cached since 300.7s ago] ('0001-01-01 00:00:00.000000', '9999-12-31 23:59:59.999999', 18)
# 2024-09-01 18:44:18,169 INFO sqlalchemy.engine.Engine ROLLBACK
# 2024-09-01 18:44:18,169 INFO sqlalchemy.engine.Engine BEGIN (implicit)
# 2024-09-01 18:44:18,170 INFO sqlalchemy.engine.Engine SELECT marked_sentences.id, marked_sentences.date_time, marked_sentences.sentence, marked_sentences.comment, marked_sentences.lesson, marked_sentences.line
# FROM marked_sentences
# WHERE marked_sentences.date_time > ? AND marked_sentences.date_time < ? AND marked_sentences.lesson = ?
# 2024-09-01 18:44:18,170 INFO sqlalchemy.engine.Engine [cached since 300.7s ago] ('0001-01-01 00:00:00.000000', '9999-12-31 23:59:59.999999', 19)
# 2024-09-01 18:44:18,170 INFO sqlalchemy.engine.Engine ROLLBACK
# 2024-09-01 18:44:18,171 INFO sqlalchemy.engine.Engine BEGIN (implicit)
# 2024-09-01 18:44:18,171 INFO sqlalchemy.engine.Engine SELECT marked_sentences.id, marked_sentences.date_time, marked_sentences.sentence, marked_sentences.comment, marked_sentences.lesson, marked_sentences.line
# FROM marked_sentences
# WHERE marked_sentences.date_time > ? AND marked_sentences.date_time < ? AND marked_sentences.lesson = ?
# 2024-09-01 18:44:18,171 INFO sqlalchemy.engine.Engine [cached since 300.7s ago] ('0001-01-01 00:00:00.000000', '9999-12-31 23:59:59.999999', 20)
# 2024-09-01 18:44:18,171 INFO sqlalchemy.engine.Engine ROLLBACK
# 2024-09-01 18:44:18,172 INFO sqlalchemy.engine.Engine BEGIN (implicit)
# 2024-09-01 18:44:18,172 INFO sqlalchemy.engine.Engine SELECT marked_sentences.id, marked_sentences.date_time, marked_sentences.sentence, marked_sentences.comment, marked_sentences.lesson, marked_sentences.line
# FROM marked_sentences
# WHERE marked_sentences.date_time > ? AND marked_sentences.date_time < ? AND marked_sentences.lesson = ?
# 2024-09-01 18:44:18,172 INFO sqlalchemy.engine.Engine [cached since 300.7s ago] ('0001-01-01 00:00:00.000000', '9999-12-31 23:59:59.999999', 21)
# 2024-09-01 18:44:18,173 INFO sqlalchemy.engine.Engine ROLLBACK
# 2024-09-01 18:44:18,173 INFO sqlalchemy.engine.Engine BEGIN (implicit)
# 2024-09-01 18:44:18,173 INFO sqlalchemy.engine.Engine SELECT marked_sentences.id, marked_sentences.date_time, marked_sentences.sentence, marked_sentences.comment, marked_sentences.lesson, marked_sentences.line
# FROM marked_sentences
# WHERE marked_sentences.date_time > ? AND marked_sentences.date_time < ? AND marked_sentences.lesson = ?
# 2024-09-01 18:44:18,174 INFO sqlalchemy.engine.Engine [cached since 300.7s ago] ('0001-01-01 00:00:00.000000', '9999-12-31 23:59:59.999999', 22)
# 2024-09-01 18:44:18,174 INFO sqlalchemy.engine.Engine ROLLBACK
# 2024-09-01 18:44:18,174 INFO sqlalchemy.engine.Engine BEGIN (implicit)
# 2024-09-01 18:44:18,174 INFO sqlalchemy.engine.Engine SELECT marked_sentences.id, marked_sentences.date_time, marked_sentences.sentence, marked_sentences.comment, marked_sentences.lesson, marked_sentences.line
# FROM marked_sentences
# WHERE marked_sentences.date_time > ? AND marked_sentences.date_time < ? AND marked_sentences.lesson = ?
# 2024-09-01 18:44:18,175 INFO sqlalchemy.engine.Engine [cached since 300.7s ago] ('0001-01-01 00:00:00.000000', '9999-12-31 23:59:59.999999', 23)
# 2024-09-01 18:44:18,175 INFO sqlalchemy.engine.Engine ROLLBACK
# 2024-09-01 18:44:18,176 INFO sqlalchemy.engine.Engine BEGIN (implicit)
# 2024-09-01 18:44:18,177 INFO sqlalchemy.engine.Engine SELECT marked_sentences.id, marked_sentences.date_time, marked_sentences.sentence, marked_sentences.comment, marked_sentences.lesson, marked_sentences.line
# FROM marked_sentences
# WHERE marked_sentences.date_time > ? AND marked_sentences.date_time < ? AND marked_sentences.lesson = ?
# 2024-09-01 18:44:18,177 INFO sqlalchemy.engine.Engine [cached since 300.7s ago] ('0001-01-01 00:00:00.000000', '9999-12-31 23:59:59.999999', 24)
# 2024-09-01 18:44:18,177 INFO sqlalchemy.engine.Engine ROLLBACK
# 2024-09-01 18:44:18,178 INFO sqlalchemy.engine.Engine BEGIN (implicit)
# 2024-09-01 18:44:18,178 INFO sqlalchemy.engine.Engine SELECT marked_sentences.id, marked_sentences.date_time, marked_sentences.sentence, marked_sentences.comment, marked_sentences.lesson, marked_sentences.line
# FROM marked_sentences
# WHERE marked_sentences.date_time > ? AND marked_sentences.date_time < ? AND marked_sentences.lesson = ?
# 2024-09-01 18:44:18,178 INFO sqlalchemy.engine.Engine [cached since 300.7s ago] ('0001-01-01 00:00:00.000000', '9999-12-31 23:59:59.999999', 25)
# 2024-09-01 18:44:18,179 INFO sqlalchemy.engine.Engine ROLLBACK
# 2024-09-01 18:44:18,179 INFO sqlalchemy.engine.Engine BEGIN (implicit)
# 2024-09-01 18:44:18,180 INFO sqlalchemy.engine.Engine SELECT marked_sentences.id, marked_sentences.date_time, marked_sentences.sentence, marked_sentences.comment, marked_sentences.lesson, marked_sentences.line
# FROM marked_sentences
# WHERE marked_sentences.date_time > ? AND marked_sentences.date_time < ? AND marked_sentences.lesson = ?
# 2024-09-01 18:44:18,180 INFO sqlalchemy.engine.Engine [cached since 300.7s ago] ('0001-01-01 00:00:00.000000', '9999-12-31 23:59:59.999999', 26)
# 2024-09-01 18:44:18,180 INFO sqlalchemy.engine.Engine ROLLBACK
# 2024-09-01 18:44:18,180 INFO sqlalchemy.engine.Engine BEGIN (implicit)
# 2024-09-01 18:44:18,181 INFO sqlalchemy.engine.Engine SELECT marked_sentences.id, marked_sentences.date_time, marked_sentences.sentence, marked_sentences.comment, marked_sentences.lesson, marked_sentences.line
# FROM marked_sentences
# WHERE marked_sentences.date_time > ? AND marked_sentences.date_time < ? AND marked_sentences.lesson = ?
# 2024-09-01 18:44:18,181 INFO sqlalchemy.engine.Engine [cached since 300.7s ago] ('0001-01-01 00:00:00.000000', '9999-12-31 23:59:59.999999', 27)
# 2024-09-01 18:44:18,181 INFO sqlalchemy.engine.Engine ROLLBACK
# 2024-09-01 18:44:18,182 INFO sqlalchemy.engine.Engine BEGIN (implicit)
# 2024-09-01 18:44:18,182 INFO sqlalchemy.engine.Engine SELECT marked_sentences.id, marked_sentences.date_time, marked_sentences.sentence, marked_sentences.comment, marked_sentences.lesson, marked_sentences.line
# FROM marked_sentences
# WHERE marked_sentences.date_time > ? AND marked_sentences.date_time < ? AND marked_sentences.lesson = ?
# 2024-09-01 18:44:18,182 INFO sqlalchemy.engine.Engine [cached since 300.7s ago] ('0001-01-01 00:00:00.000000', '9999-12-31 23:59:59.999999', 28)
# 2024-09-01 18:44:18,182 INFO sqlalchemy.engine.Engine ROLLBACK
# 2024-09-01 18:44:18,183 INFO sqlalchemy.engine.Engine BEGIN (implicit)
# 2024-09-01 18:44:18,183 INFO sqlalchemy.engine.Engine SELECT marked_sentences.id, marked_sentences.date_time, marked_sentences.sentence, marked_sentences.comment, marked_sentences.lesson, marked_sentences.line
# FROM marked_sentences
# WHERE marked_sentences.date_time > ? AND marked_sentences.date_time < ? AND marked_sentences.lesson = ?
# 2024-09-01 18:44:18,183 INFO sqlalchemy.engine.Engine [cached since 300.7s ago] ('0001-01-01 00:00:00.000000', '9999-12-31 23:59:59.999999', 29)
# 2024-09-01 18:44:18,183 INFO sqlalchemy.engine.Engine ROLLBACK
# 2024-09-01 18:44:18,184 INFO sqlalchemy.engine.Engine BEGIN (implicit)
# 2024-09-01 18:44:18,184 INFO sqlalchemy.engine.Engine SELECT marked_sentences.id, marked_sentences.date_time, marked_sentences.sentence, marked_sentences.comment, marked_sentences.lesson, marked_sentences.line
# FROM marked_sentences
# WHERE marked_sentences.date_time > ? AND marked_sentences.date_time < ? AND marked_sentences.lesson = ?
# 2024-09-01 18:44:18,184 INFO sqlalchemy.engine.Engine [cached since 300.7s ago] ('0001-01-01 00:00:00.000000', '9999-12-31 23:59:59.999999', 30)
# 2024-09-01 18:44:18,185 INFO sqlalchemy.engine.Engine ROLLBACK
# 2024-09-01 18:44:18,185 INFO sqlalchemy.engine.Engine BEGIN (implicit)
# 2024-09-01 18:44:18,185 INFO sqlalchemy.engine.Engine SELECT marked_sentences.id, marked_sentences.date_time, marked_sentences.sentence, marked_sentences.comment, marked_sentences.lesson, marked_sentences.line
# FROM marked_sentences
# WHERE marked_sentences.date_time > ? AND marked_sentences.date_time < ? AND marked_sentences.lesson = ?
# 2024-09-01 18:44:18,185 INFO sqlalchemy.engine.Engine [cached since 300.7s ago] ('0001-01-01 00:00:00.000000', '9999-12-31 23:59:59.999999', 31)
# 2024-09-01 18:44:18,186 INFO sqlalchemy.engine.Engine ROLLBACK
# 2024-09-01 18:44:18,186 INFO sqlalchemy.engine.Engine BEGIN (implicit)
# 2024-09-01 18:44:18,186 INFO sqlalchemy.engine.Engine SELECT marked_sentences.id, marked_sentences.date_time, marked_sentences.sentence, marked_sentences.comment, marked_sentences.lesson, marked_sentences.line
# FROM marked_sentences
# WHERE marked_sentences.date_time > ? AND marked_sentences.date_time < ? AND marked_sentences.lesson = ?
# 2024-09-01 18:44:18,186 INFO sqlalchemy.engine.Engine [cached since 300.7s ago] ('0001-01-01 00:00:00.000000', '9999-12-31 23:59:59.999999', 32)
# 2024-09-01 18:44:18,187 INFO sqlalchemy.engine.Engine ROLLBACK
# 2024-09-01 18:44:18,187 INFO sqlalchemy.engine.Engine BEGIN (implicit)
# 2024-09-01 18:44:18
INFO sqlalchemy.engine.Engine [cached since 300.8s ago] ('0001-01-01 00:00:00.000000', '9999-12-31 23:59:59.999999', 74)
# 2024-09-01 18:44:18,254 INFO sqlalchemy.engine.Engine ROLLBACK
# 2024-09-01 18:44:18,255 INFO sqlalchemy.engine.Engine BEGIN (implicit)
# 2024-09-01 18:44:18,255 INFO sqlalchemy.engine.Engine SELECT marked_sentences.id, marked_sentences.date_time, marked_sentences.sentence, marked_sentences.comment, marked_sentences.lesson, marked_sentences.line
# FROM marked_sentences
# WHERE marked_sentences.date_time > ? AND marked_sentences.date_time < ? AND marked_sentences.lesson = ?
# 2024-09-01 18:44:18,255 INFO sqlalchemy.engine.Engine [cached since 300.8s ago] ('0001-01-01 00:00:00.000000', '9999-12-31 23:59:59.999999', 75)
# 2024-09-01 18:44:18,255 INFO sqlalchemy.engine.Engine ROLLBACK
# 2024-09-01 18:44:18,256 INFO sqlalchemy.engine.Engine BEGIN (implicit)
# 2024-09-01 18:44:18,256 INFO sqlalchemy.engine.Engine SELECT marked_sentences.id, marked_sentences.date_time, marked_sentences.sentence, marked_sentences.comment, marked_sentences.lesson, marked_sentences.line
# FROM marked_sentences
# WHERE marked_sentences.date_time > ? AND marked_sentences.date_time < ? AND marked_sentences.lesson = ?
# 2024-09-01 18:44:18,256 INFO sqlalchemy.engine.Engine [cached since 300.8s ago] ('0001-01-01 00:00:00.000000', '9999-12-31 23:59:59.999999', 76)
# 2024-09-01 18:44:18,256 INFO sqlalchemy.engine.Engine ROLLBACK
# 2024-09-01 18:44:18,257 INFO sqlalchemy.engine.Engine BEGIN (implicit)
# 2024-09-01 18:44:18,257 INFO sqlalchemy.engine.Engine SELECT marked_sentences.id, marked_sentences.date_time, marked_sentences.sentence, marked_sentences.comment, marked_sentences.lesson, marked_sentences.line
# FROM marked_sentences
# WHERE marked_sentences.date_time > ? AND marked_sentences.date_time < ? AND marked_sentences.lesson = ?
# 2024-09-01 18:44:18,257 INFO sqlalchemy.engine.Engine [cached since 300.8s ago] ('0001-01-01 00:00:00.000000', '9999-12-31 23:59:59.999999', 77)
# 2024-09-01 18:44:18,258 INFO sqlalchemy.engine.Engine ROLLBACK
# 2024-09-01 18:44:18,258 INFO sqlalchemy.engine.Engine BEGIN (implicit)
# 2024-09-01 18:44:18,258 INFO sqlalchemy.engine.Engine SELECT marked_sentences.id, marked_sentences.date_time, marked_sentences.sentence, marked_sentences.comment, marked_sentences.lesson, marked_sentences.line
# FROM marked_sentences
# WHERE marked_sentences.date_time > ? AND marked_sentences.date_time < ? AND marked_sentences.lesson = ?
# 2024-09-01 18:44:18,258 INFO sqlalchemy.engine.Engine [cached since 300.8s ago] ('0001-01-01 00:00:00.000000', '9999-12-31 23:59:59.999999', 78)
# 2024-09-01 18:44:18,259 INFO sqlalchemy.engine.Engine ROLLBACK
# 2024-09-01 18:44:18,259 INFO sqlalchemy.engine.Engine BEGIN (implicit)
# 2024-09-01 18:44:18,259 INFO sqlalchemy.engine.Engine SELECT marked_sentences.id, marked_sentences.date_time, marked_sentences.sentence, marked_sentences.comment, marked_sentences.lesson, marked_sentences.line
# FROM marked_sentences
# WHERE marked_sentences.date_time > ? AND marked_sentences.date_time < ? AND marked_sentences.lesson = ?
# 2024-09-01 18:44:18,260 INFO sqlalchemy.engine.Engine [cached since 300.8s ago] ('0001-01-01 00:00:00.000000', '9999-12-31 23:59:59.999999', 79)
# 2024-09-01 18:44:18,260 INFO sqlalchemy.engine.Engine ROLLBACK
# 2024-09-01 18:44:18,260 INFO sqlalchemy.engine.Engine BEGIN (implicit)
# 2024-09-01 18:44:18,261 INFO sqlalchemy.engine.Engine SELECT marked_sentences.id, marked_sentences.date_time, marked_sentences.sentence, marked_sentences.comment, marked_sentences.lesson, marked_sentences.line
# FROM marked_sentences
# WHERE marked_sentences.date_time > ? AND marked_sentences.date_time < ? AND marked_sentences.lesson = ?
# 2024-09-01 18:44:18,261 INFO sqlalchemy.engine.Engine [cached since 300.8s ago] ('0001-01-01 00:00:00.000000', '9999-12-31 23:59:59.999999', 80)
# 2024-09-01 18:44:18,261 INFO sqlalchemy.engine.Engine ROLLBACK
# 2024-09-01 18:44:18,261 INFO sqlalchemy.engine.Engine BEGIN (implicit)
# 2024-09-01 18:44:18,262 INFO sqlalchemy.engine.Engine SELECT marked_sentences.id, marked_sentences.date_time, marked_sentences.sentence, marked_sentences.comment, marked_sentences.lesson, marked_sentences.line
# FROM marked_sentences
# WHERE marked_sentences.date_time > ? AND marked_sentences.date_time < ? AND marked_sentences.lesson = ?
# 2024-09-01 18:44:18,262 INFO sqlalchemy.engine.Engine [cached since 300.8s ago] ('0001-01-01 00:00:00.000000', '9999-12-31 23:59:59.999999', 81)
# 2024-09-01 18:44:18,262 INFO sqlalchemy.engine.Engine ROLLBACK
# 2024-09-01 18:44:18,263 INFO sqlalchemy.engine.Engine BEGIN (implicit)
# 2024-09-01 18:44:18,263 INFO sqlalchemy.engine.Engine SELECT marked_sentences.id, marked_sentences.date_time, marked_sentences.sentence, marked_sentences.comment, marked_sentences.lesson, marked_sentences.line
# FROM marked_sentences
# WHERE marked_sentences.date_time > ? AND marked_sentences.date_time < ? AND marked_sentences.lesson = ?
# 2024-09-01 18:44:18,263 INFO sqlalchemy.engine.Engine [cached since 300.8s ago] ('0001-01-01 00:00:00.000000', '9999-12-31 23:59:59.999999', 82)
# 2024-09-01 18:44:18,263 INFO sqlalchemy.engine.Engine ROLLBACK
# 2024-09-01 18:44:18,264 INFO sqlalchemy.engine.Engine BEGIN (implicit)
# 2024-09-01 18:44:18,264 INFO sqlalchemy.engine.Engine SELECT marked_sentences.id, marked_sentences.date_time, marked_sentences.sentence, marked_sentences.comment, marked_sentences.lesson, marked_sentences.line
# FROM marked_sentences
# WHERE marked_sentences.date_time > ? AND marked_sentences.date_time < ? AND marked_sentences.lesson = ?
# 2024-09-01 18:44:18,264 INFO sqlalchemy.engine.Engine [cached since 300.8s ago] ('0001-01-01 00:00:00.000000', '9999-12-31 23:59:59.999999', 83)
# 2024-09-01 18:44:18,264 INFO sqlalchemy.engine.Engine ROLLBACK
# 2024-09-01 18:44:18,265 INFO sqlalchemy.engine.Engine BEGIN (implicit)
# 2024-09-01 18:44:18,265 INFO sqlalchemy.engine.Engine SELECT marked_sentences.id, marked_sentences.date_time, marked_sentences.sentence, marked_sentences.comment, marked_sentences.lesson, marked_sentences.line
# FROM marked_sentences
# WHERE marked_sentences.date_time > ? AND marked_sentences.date_time < ? AND marked_sentences.lesson = ?
# 2024-09-01 18:44:18,265 INFO sqlalchemy.engine.Engine [cached since 300.8s ago] ('0001-01-01 00:00:00.000000', '9999-12-31 23:59:59.999999', 84)
# 2024-09-01 18:44:18,266 INFO sqlalchemy.engine.Engine ROLLBACK
# 2024-09-01 18:44:18,266 INFO sqlalchemy.engine.Engine BEGIN (implicit)
# 2024-09-01 18:44:18,266 INFO sqlalchemy.engine.Engine SELECT marked_sentences.id, marked_sentences.date_time, marked_sentences.sentence, marked_sentences.comment, marked_sentences.lesson, marked_sentences.line
# FROM marked_sentences
# WHERE marked_sentences.date_time > ? AND marked_sentences.date_time < ? AND marked_sentences.lesson = ?
# 2024-09-01 18:44:18,266 INFO sqlalchemy.engine.Engine [cached since 300.8s ago] ('0001-01-01 00:00:00.000000', '9999-12-31 23:59:59.999999', 85)
# 2024-09-01 18:44:18,267 INFO sqlalchemy.engine.Engine ROLLBACK
# 2024-09-01 18:44:18,267 INFO sqlalchemy.engine.Engine BEGIN (implicit)
# 2024-09-01 18:44:18,267 INFO sqlalchemy.engine.Engine SELECT marked_sentences.id, marked_sentences.date_time, marked_sentences.sentence, marked_sentences.comment, marked_sentences.lesson, marked_sentences.line
# FROM marked_sentences
# WHERE marked_sentences.date_time > ? AND marked_sentences.date_time < ? AND marked_sentences.lesson = ?
# 2024-09-01 18:44:18,267 INFO sqlalchemy.engine.Engine [cached since 300.8s ago] ('0001-01-01 00:00:00.000000', '9999-12-31 23:59:59.999999', 86)
# 2024-09-01 18:44:18,268 INFO sqlalchemy.engine.Engine ROLLBACK
# 2024-09-01 18:44:18,268 INFO sqlalchemy.engine.Engine BEGIN (implicit)
# 2024-09-01 18:44:18,268 INFO sqlalchemy.engine.Engine SELECT marked_sentences.id, marked_sentences.date_time, marked_sentences.sentence, marked_sentences.comment, marked_sentences.lesson, marked_sentences.line
# FROM marked_sentences
# WHERE marked_sentences.date_time > ? AND marked_sentences.date_time < ? AND marked_sentences.lesson = ?
# 2024-09-01 18:44:18,268 INFO sqlalchemy.engine.Engine [cached since 300.8s ago] ('0001-01-01 00:00:00.000000', '9999-12-31 23:59:59.999999', 87)
# 2024-09-01 18:44:18,269 INFO sqlalchemy.engine.Engine ROLLBACK
# 2024-09-01 18:44:18,269 INFO sqlalchemy.engine.Engine BEGIN (implicit)
# 2024-09-01 18:44:18,269 INFO sqlalchemy.engine.Engine SELECT marked_sentences.id, marked_sentences.date_time, marked_sentences.sentence, marked_sentences.comment, marked_sentences.lesson, marked_sentences.line
# FROM marked_sentences
# WHERE marked_sentences.date_time > ? AND marked_sentences.date_time < ? AND marked_sentences.lesson = ?
# 2024-09-01 18:44:18,269 INFO sqlalchemy.engine.Engine [cached since 300.8s ago] ('0001-01-01 00:00:00.000000', '9999-12-31 23:59:59.999999', 88)
# 2024-09-01 18:44:18,270 INFO sqlalchemy.engine.Engine ROLLBACK
# 2024-09-01 18:44:18,270 INFO sqlalchemy.engine.Engine BEGIN (implicit)
# 2024-09-01 18:44:18,270 INFO sqlalchemy.engine.Engine SELECT marked_sentences.id, marked_sentences.date_time, marked_sentences.sentence, marked_sentences.comment, marked_sentences.lesson, marked_sentences.line
# FROM marked_sentences
# WHERE marked_sentences.date_time > ? AND marked_sentences.date_time < ? AND marked_sentences.lesson = ?
# 2024-09-01 18:44:18,270 INFO sqlalchemy.engine.Engine [cached since 300.8s ago] ('0001-01-01 00:00:00.000000', '9999-12-31 23:59:59.999999', 89)
# 2024-09-01 18:44:18,271 INFO sqlalchemy.engine.Engine ROLLBACK
# 2024-09-01 18:44:18,271 INFO sqlalchemy.engine.Engine BEGIN (implicit)
# 2024-09-01 18:44:18,271 INFO sqlalchemy.engine.Engine SELECT marked_sentences.id, marked_sentences.date_time, marked_sentences.sentence, marked_sentences.comment, marked_sentences.lesson, marked_sentences.line
# FROM marked_sentences
# WHERE marked_sentences.date_time > ? AND marked_sentences.date_time < ? AND marked_sentences.lesson = ?
# 2024-09-01 18:44:18,272 INFO sqlalchemy.engine.Engine [cached since 300.8s ago] ('0001-01-01 00:00:00.000000', '9999-12-31 23:59:59.999999', 90)
# 2024-09-01 18:44:18,272 INFO sqlalchemy.engine.Engine ROLLBACK
# 2024-09-01 18:44:18,272 INFO sqlalchemy.engine.Engine BEGIN (implicit)
# 2024-09-01 18:44:18,272 INFO sqlalchemy.engine.Engine SELECT marked_sentences.id, marked_sentences.date_time, marked_sentences.sentence, marked_sentences.comment, marked_sentences.lesson, marked_sentences.line
# FROM marked_sentences
# WHERE marked_sentences.date_time > ? AND marked_sentences.date_time < ? AND marked_sentences.lesson = ?
# 2024-09-01 18:44:18,273 INFO sqlalchemy.engine.Engine [cached since 300.8s ago] ('0001-01-01 00:00:00.000000', '9999-12-31 23:59:59.999999', 91)
# 2024-09-01 18:44:18,273 INFO sqlalchemy.engine.Engine ROLLBACK
# 2024-09-01 18:44:18,274 INFO sqlalchemy.engine.Engine BEGIN (implicit)
# 2024-09-01 18:44:18,274 INFO sqlalchemy.engine.Engine SELECT marked_sentences.id, marked_sentences.date_time, marked_sentences.sentence, marked_sentences.comment, marked_sentences.lesson, marked_sentences.line
# FROM marked_sentences
# WHERE marked_sentences.date_time > ? AND marked_sentences.date_time < ? AND marked_sentences.lesson = ?
# 2024-09-01 18:44:18,274 INFO sqlalchemy.engine.Engine [cached since 300.8s ago] ('0001-01-01 00:00:00.000000', '9999-12-31 23:59:59.999999', 92)
# 2024-09-01 18:44:18,274 INFO sqlalchemy.engine.Engine ROLLBACK
# 2024-09-01 18:44:18,275 INFO sqlalchemy.engine.Engine BEGIN (implicit)
# 2024-09-01 18:44:18,275 INFO sqlalchemy.engine.Engine SELECT marked_sentences.id, marked_sentences.date_time, marked_sentences.sentence, marked_sentences.comment, marked_sentences.lesson, marked_sentences.line
# FROM marked_sentences
# WHERE marked_sentences.date_time > ? AND marked_sentences.date_time < ? AND marked_sentences.lesson = ?
# 2024-09-01 18:44:18,275 INFO sqlalchemy.engine.Engine [cached since 300.8s ago] ('0001-01-01 00:00:00.000000', '9999-12-31 23:59:59.999999', 93)
# 2024-09-01 18:44:18,276 INFO sqlalchemy.engine.Engine ROLLBACK
# 2024-09-01 18:44:18,276 INFO sqlalchemy.engine.Engine BEGIN (implicit)
# 2024-09-01 18:44:18,277 INFO sqlalchemy.engine.Engine SELECT marked_sentences.id, marked_sentences.date_time, marked_sentences.sentence, marked_sentences.comment, marked_sentences.lesson, marked_sentences.line
# FROM marked_sentences
# WHERE marked_sentences.date_time > ? AND marked_sentences.date_time < ? AND marked_sentences.lesson = ?
# 2024-09-01 18:44:18,279 INFO sqlalchemy.engine.Engine [cached since 300.8s ago] ('0001-01-01 00:00:00.000000', '9999-12-31 23:59:59.999999', 94)
# 2024-09-01 18:44:18,280 INFO sqlalchemy.engine.Engine ROLLBACK
# 2024-09-01 18:44:18,281 INFO sqlalchemy.engine.Engine BEGIN (implicit)
# 2024-09-01 18:44:18,281 INFO sqlalchemy.engine.Engine SELECT marked_sentences.id, marked_sentences.date_time, marked_sentences.sentence, marked_sentences.comment, marked_sentences.lesson, marked_sentences.line
# FROM marked_sentences
# WHERE marked_sentences.date_time > ? AND marked_sentences.date_time < ? AND marked_sentences.lesson = ?
# 2024-09-01 18:44:18,281 INFO sqlalchemy.engine.Engine [cached since 300.8s ago] ('0001-01-01 00:00:00.000000', '9999-12-31 23:59:59.999999', 95)
# 2024-09-01 18:44:18,282 INFO sqlalchemy.engine.Engine ROLLBACK
# 2024-09-01 18:44:18,282 INFO sqlalchemy.engine.Engine BEGIN (implicit)
# 2024-09-01 18:44:18,283 INFO sqlalchemy.engine.Engine SELECT marked_sentences.id, marked_sentences.date_time, marked_sentences.sentence, marked_sentences.comment, marked_sentences.lesson, marked_sentences.line
# FROM marked_sentences
# WHERE marked_sentences.date_time > ? AND marked_sentences.date_time < ? AND marked_sentences.lesson = ?
# 2024-09-01 18:44:18,283 INFO sqlalchemy.engine.Engine [cached since 300.8s ago] ('0001-01-01 00:00:00.000000', '9999-12-31 23:59:59.999999', 96)
# 2024-09-01 18:44:18,284 INFO sqlalchemy.engine.Engine ROLLBACK
# 2024-09-01 18:44:18,284 INFO sqlalchemy.engine.Engine BEGIN (implicit)
# 2024-09-01 18:44:18,284 INFO sqlalchemy.engine.Engine SELECT marked_sentences.id, marked_sentences.date_time, marked_sentences.sentence, marked_sentences.comment, marked_sentences.lesson, marked_sentences.line
# FROM marked_sentences
# WHERE marked_sentences.date_time > ? AND marked_sentences.date_time < ? AND marked_sentences.lesson = ?
# 2024-09-01 18:44:18,284 INFO sqlalchemy.engine.Engine [cached since 300.8s ago] ('0001-01-01 00:00:00.000000', '9999-12-31 23:59:59.999999', 97)
# 2024-09-01 18:44:18,285 INFO sqlalchemy.engine.Engine ROLLBACK
# 2024-09-01 18:44:18,286 INFO sqlalchemy.engine.Engine BEGIN (implicit)
# 2024-09-01 18:44:18,286 INFO sqlalchemy.engine.Engine SELECT marked_sentences.id, marked_sentences.date_time, marked_sentences.sentence, marked_sentences.comment, marked_sentences.lesson, marked_sentences.line
# FROM marked_sentences
# WHERE marked_sentences.date_time > ? AND marked_sentences.date_time < ? AND marked_sentences.lesson = ?
# 2024-09-01 18:44:18,286 INFO sqlalchemy.engine.Engine [cached since 300.8s ago] ('0001-01-01 00:00:00.000000', '9999-12-31 23:59:59.999999', 98)
# 2024-09-01 18:44:18,287 INFO sqlalchemy.engine.Engine ROLLBACK
# 2024-09-01 18:44:18,287 INFO sqlalchemy.engine.Engine BEGIN (implicit)
# 2024-09-01 18:44:18,287 INFO sqlalchemy.engine.Engine SELECT marked_sentences.id, marked_sentences.date_time, marked_sentences.sentence, marked_sentences.comment, marked_sentences.lesson, marked_sentences.line
# FROM marked_sentences
# WHERE marked_sentences.date_time > ? AND marked_sentences.date_time < ? AND marked_sentences.lesson = ?
# 2024-09-01 18:44:18,288 INFO sqlalchemy.engine.Engine [cached since 300.8s ago] ('0001-01-01 00:00:00.000000', '9999-12-31 23:59:59.999999', 99)
# 2024-09-01 18:44:18,288 INFO sqlalchemy.engine.Engine ROLLBACK
# 2024-09-01 18:44:18,288 INFO sqlalchemy.engine.Engine BEGIN (implicit)
# 2024-09-01 18:44:18,289 INFO sqlalchemy.engine.Engine SELECT marked_sentences.id, marked_sentences.date_time, marked_sentences.sentence, marked_sentences.comment, marked_sentences.lesson, marked_sentences.line
# FROM marked_sentences
# WHERE marked_sentences.date_time > ? AND marked_sentences.date_time < ? AND marked_sentences.lesson = ?
# 2024-09-01 18:44:18,289 INFO sqlalchemy.engine.Engine [cached since 300.8s ago] ('0001-01-01 00:00:00.000000', '9999-12-31 23:59:59.999999', 100)
# 2024-09-01 18:44:18,289 INFO sqlalchemy.engine.Engine ROLLBACK

# %%
col_nb, th_rows, rows
# Out:
# (3,
#  [4, 5, 45, 97],
#  [[datetime.datetime(2024, 8, 30, 18, 11, 11, 870753),
#    datetime.datetime(2024, 8, 30, 18, 37, 31, 497652),
#    datetime.datetime(2024, 8, 31, 17, 32, 18, 58630)],
#   [datetime.datetime(2024, 8, 30, 18, 12, 5, 788656),
#    datetime.datetime(2024, 8, 31, 17, 33, 16, 342000)],
#   [datetime.datetime(2024, 8, 30, 18, 13, 24, 955334)],
#   [datetime.datetime(2024, 8, 31, 17, 34, 3, 198940)]])

# %%
from jinja2 import Environment, FileSystemLoader
import os

# %%
env = Environment( loader = FileSystemLoader("templates") )

# %%
template = env.get_template('errors_table.html')

# %%
div0 = template.render(
    col_nb = col_nb,
    th_rows = th_rows,
    rows = rows
)

# %%
div0
# Out:
# '<table>\n    <caption>Erreurs trouvées</caption>\n    <tr>\n      <th scope="col">Leçon</th>\n      <th scope="col" colspan="3">Dates</th>\n    </tr>\n    \n      <tr>\n        <th scope="row">4</th>\n        \n        \n          <td><button onclick=\'loadLesson(0, 0)\'>30-08-2024 18:11:11</button></td>\n        \n          <td><button onclick=\'loadLesson(0, 1)\'>30-08-2024 18:37:31</button></td>\n        \n          <td><button onclick=\'loadLesson(0, 2)\'>31-08-2024 17:32:18</button></td>\n        \n      </tr>\n    \n      <tr>\n        <th scope="row">5</th>\n        \n        \n          <td><button onclick=\'loadLesson(1, 0)\'>30-08-2024 18:12:05</button></td>\n        \n          <td><button onclick=\'loadLesson(1, 1)\'>31-08-2024 17:33:16</button></td>\n        \n      </tr>\n    \n      <tr>\n        <th scope="row">45</th>\n        \n        \n          <td><button onclick=\'loadLesson(2, 0)\'>30-08-2024 18:13:24</button></td>\n        \n      </tr>\n    \n      <tr>\n        <th scope="row">97</th>\n        \n        \n          <td><button onclick=\'loadLesson(3, 0)\'>31-08-2024 17:34:03</button></td>\n        \n      </tr>\n    \n  </table>\n\n  <script>\n          \n    function loadLesson(row, col) {\n        console.log(row);\n        console.log(col);\n\n      }\n\n  </script>'

# %%
div0 = div0.replace('\n', '')
div0
# Out:
# '<table>    <caption>Erreurs trouvées</caption>    <tr>      <th scope="col">Leçon</th>      <th scope="col" colspan="3">Dates</th>    </tr>          <tr>        <th scope="row">4</th>                          <td><button onclick=\'loadLesson(0, 0)\'>30-08-2024 18:11:11</button></td>                  <td><button onclick=\'loadLesson(0, 1)\'>30-08-2024 18:37:31</button></td>                  <td><button onclick=\'loadLesson(0, 2)\'>31-08-2024 17:32:18</button></td>              </tr>          <tr>        <th scope="row">5</th>                          <td><button onclick=\'loadLesson(1, 0)\'>30-08-2024 18:12:05</button></td>                  <td><button onclick=\'loadLesson(1, 1)\'>31-08-2024 17:33:16</button></td>              </tr>          <tr>        <th scope="row">45</th>                          <td><button onclick=\'loadLesson(2, 0)\'>30-08-2024 18:13:24</button></td>              </tr>          <tr>        <th scope="row">97</th>                          <td><button onclick=\'loadLesson(3, 0)\'>31-08-2024 17:34:03</button></td>              </tr>      </table>  <script>              function loadLesson(row, col) {        console.log(row);        console.log(col);      }  </script>'

# %%
from datetime import datetime

# %%
datetime("2024-09-01")
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[29], line 1
# ----> 1 datetime("2024-09-01")
#
# TypeError: 'str' object cannot be interpreted as an integer

# %%
date_to_datetime = datetime.strptime("2024-09-01", '%Y-%m-%d')

# %%
date_to_datetime
# Out:
# datetime.datetime(2024, 9, 1, 0, 0)
