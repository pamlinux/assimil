# %%
with open("subtitles.save", "r", encoding="utf-8") as f:
    contenu = f.read()

# Si votre variable était un dictionnaire ou une liste simple représentée par repr()
try:
    ma_variable_rechargee = eval(contenu)
    print(ma_variable_rechargee)
except (SyntaxError, NameError):
    print("Impossible de réévaluer directement le contenu.")

# Si votre variable était une simple chaîne de caractères
# ma_variable_rechargee = contenu.strip()
# Out:
# [{'french_text': 'Sous-titres : Atresmedia', 'id': 1, 'spanish_text': 'Subtítulos: Atresmedia'}, {'french_text': '"Ici, personne ne peut vivre ici,\npas ici, pas ici."', 'id': 2, 'spanish_text': '"Aquí, aquí no hay quien viva,\naquí no, aquí no."'}, {'french_text': '-Vicenta ! Allez, ça commence maintenant.\n-Non, je vais me coucher.', 'id': 3, 'spanish_text': '-¡Vicenta! Ven que esto empieza ya.\n-No, voy a acostarme.'}, {'french_text': "J'ai des ardeurs...\n-Normal, tu es célibataire depuis toujours.", 'id': 4, 'spanish_text': 'Tengo unos ardores..\n-Normal, soltera toda tu vida.'}, {'french_text': "-Des brûlures d'estomac.", 'id': 5, 'spanish_text': '-Ardor de estómago.'}, {'french_text': "Pourquoi me rappelles-tu toujours\nque je ne me suis pas mariée ? J'ai décidé...", 'id': 6, 'spanish_text': '¿Por qué siempre me recuerdas\nque no me he casado? Yo decidí...'}, {'french_text': "...en attendant l'homme de ma vie.\n-Cela semble prendre du temps.", 'id': 7, 'spanish_text': '...espe
# ...

# %%
ma_variable_rechargee
# Out:
# [{'french_text': 'Sous-titres : Atresmedia',
#   'id': 1,
#   'spanish_text': 'Subtítulos: Atresmedia'},
#  {'french_text': '"Ici, personne ne peut vivre ici,\npas ici, pas ici."',
#   'id': 2,
#   'spanish_text': '"Aquí, aquí no hay quien viva,\naquí no, aquí no."'},
#  {'french_text': '-Vicenta ! Allez, ça commence maintenant.\n-Non, je vais me coucher.',
#   'id': 3,
#   'spanish_text': '-¡Vicenta! Ven que esto empieza ya.\n-No, voy a acostarme.'},
#  {'french_text': "J'ai des ardeurs...\n-Normal, tu es célibataire depuis toujours.",
#   'id': 4,
#   'spanish_text': 'Tengo unos ardores..\n-Normal, soltera toda tu vida.'},
#  {'french_text': "-Des brûlures d'estomac.",
#   'id': 5,
#   'spanish_text': '-Ardor de estómago.'},
#  {'french_text': "Pourquoi me rappelles-tu toujours\nque je ne me suis pas mariée ? J'ai décidé...",
#   'id': 6,
#   'spanish_text': '¿Por qué siempre me recuerdas\nque no me he casado? Yo decidí...'},
# ...
