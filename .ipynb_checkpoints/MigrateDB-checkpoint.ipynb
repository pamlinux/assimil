# %%
import database
import databaseold
from sqlalchemy import ForeignKey, select, delete, String, and_
from sqlalchemy.orm import Session

from database import engine as engine_new
from databaseold import engine as engine_old

# %%
from database import User

# %%
stmt_old = select(databaseold.LessonSession)
with Session(engine_old) as session_old:
    for lesson_session in session_old.scalars(stmt_old):
        print(lesson_session)
# Out:
# 2024-09-13 00:54:30,467 INFO sqlalchemy.engine.Engine BEGIN (implicit)
# 2024-09-13 00:54:30,483 INFO sqlalchemy.engine.Engine SELECT lesson_sessions.id, lesson_sessions.lesson, lesson_sessions.date_time, lesson_sessions.errors_number
# FROM lesson_sessions
# 2024-09-13 00:54:30,484 INFO sqlalchemy.engine.Engine [generated in 0.00129s] ()
# date time : datetime.datetime(2024, 9, 4, 22, 42, 30, 759328), lesson 50 errors number : 6
# date time : datetime.datetime(2024, 9, 4, 23, 2, 0, 780033), lesson 1 errors number : 0
# date time : datetime.datetime(2024, 9, 5, 9, 19, 11, 922138), lesson 51 errors number : 3
# date time : datetime.datetime(2024, 9, 6, 23, 54, 35, 589923), lesson 3 errors number : 3
# date time : datetime.datetime(2024, 9, 6, 23, 30, 29, 589456), lesson 52 errors number : 5
# date time : datetime.datetime(2024, 9, 7, 15, 38, 11, 304630), lesson 53 errors number : 4
# date time : datetime.datetime(2024, 9, 7, 15, 47, 54, 852500), lesson 4 errors number : 0
# date time : datetime.datetime(2024, 9, 9, 0, 33, 9, 558002), lesson 54 errors number : 4
# date time : datetime.datetime(2024, 9, 9, 0, 37, 30, 688736), lesson 5 errors number : 0
# date time : datetime.datetime(2024, 9, 9, 23, 49, 20, 733862), lesson 55 errors number : 8
# date time : datetime.datetime(2024, 9, 10, 11, 28, 32, 681006), lesson 56 errors number : 10
# date time : datetime.datetime(2024, 9, 10, 11, 34, 52, 105091), lesson 7 errors number : 2
# date time : datetime.datetime(2024, 9, 11, 15, 24, 26, 952928), lesson 57 errors number : 7
# date time : datetime.datetime(2024, 9, 12, 18, 13, 29, 359135), lesson 58 errors number : 4
# 2024-09-13 00:54:30,487 INFO sqlalchemy.engine.Engine ROLLBACK

# %%
with Session(engine_new) as session_new:
    pam = User(
        username="pam",
        password="TOTO1234",
        fullname="Pierre-Alain Moret",
        email="moret.pierre.alain@gmail.com"
    )
    session_new.add(pam)
    session_new.commit()
# Out:
# 2024-09-13 00:54:53,088 INFO sqlalchemy.engine.Engine BEGIN (implicit)
# 2024-09-13 00:54:53,092 INFO sqlalchemy.engine.Engine INSERT INTO user_account (username, password, fullname, email) VALUES (?, ?, ?, ?)
# 2024-09-13 00:54:53,094 INFO sqlalchemy.engine.Engine [generated in 0.00178s] ('pam', 'TOTO1234', 'Pierre-Alain Moret', 'moret.pierre.alain@gmail.com')
# 2024-09-13 00:54:53,097 INFO sqlalchemy.engine.Engine COMMIT

# %%
stmt_new = select(User)
with Session(engine_new) as session_new:
    for user in session_new.scalars(stmt_new):
        #for sentence in entry.errored_sentences:
            print(user.id, user.username, user.email)
# Out:
# 2024-09-13 00:54:57,480 INFO sqlalchemy.engine.Engine BEGIN (implicit)
# 2024-09-13 00:54:57,483 INFO sqlalchemy.engine.Engine SELECT user_account.id, user_account.username, user_account.password, user_account.fullname, user_account.email
# FROM user_account
# 2024-09-13 00:54:57,484 INFO sqlalchemy.engine.Engine [generated in 0.00155s] ()
# 1 pam moret.pierre.alain@gmail.com
# 2024-09-13 00:54:57,487 INFO sqlalchemy.engine.Engine ROLLBACK

# %%
session_new = Session(engine_new) 
stmt_new = select(User).where(User.username == "pam")
pam = session_new.scalars(stmt_new).one()
pam
# Out:
# 2024-09-13 00:55:00,004 INFO sqlalchemy.engine.Engine BEGIN (implicit)
# 2024-09-13 00:55:00,009 INFO sqlalchemy.engine.Engine SELECT user_account.id, user_account.username, user_account.password, user_account.fullname, user_account.email
# FROM user_account
# WHERE user_account.username = ?
# 2024-09-13 00:55:00,010 INFO sqlalchemy.engine.Engine [generated in 0.00111s] ('pam',)
# username : 'pam', password : 'TOTO1234', full name :Pierre-Alain Moret

# %%
stmt_old = select(databaseold.LessonSession)
with Session(engine_old) as session_old:
    for lesson_session in session_old.scalars(stmt_old):
        print(lesson_session)
# Out:
# 2024-09-13 00:55:04,074 INFO sqlalchemy.engine.Engine BEGIN (implicit)
# 2024-09-13 00:55:04,075 INFO sqlalchemy.engine.Engine SELECT lesson_sessions.id, lesson_sessions.lesson, lesson_sessions.date_time, lesson_sessions.errors_number
# FROM lesson_sessions
# 2024-09-13 00:55:04,076 INFO sqlalchemy.engine.Engine [cached since 33.59s ago] ()
# date time : datetime.datetime(2024, 9, 4, 22, 42, 30, 759328), lesson 50 errors number : 6
# date time : datetime.datetime(2024, 9, 4, 23, 2, 0, 780033), lesson 1 errors number : 0
# date time : datetime.datetime(2024, 9, 5, 9, 19, 11, 922138), lesson 51 errors number : 3
# date time : datetime.datetime(2024, 9, 6, 23, 54, 35, 589923), lesson 3 errors number : 3
# date time : datetime.datetime(2024, 9, 6, 23, 30, 29, 589456), lesson 52 errors number : 5
# date time : datetime.datetime(2024, 9, 7, 15, 38, 11, 304630), lesson 53 errors number : 4
# date time : datetime.datetime(2024, 9, 7, 15, 47, 54, 852500), lesson 4 errors number : 0
# date time : datetime.datetime(2024, 9, 9, 0, 33, 9, 558002), lesson 54 errors number : 4
# date time : datetime.datetime(2024, 9, 9, 0, 37, 30, 688736), lesson 5 errors number : 0
# date time : datetime.datetime(2024, 9, 9, 23, 49, 20, 733862), lesson 55 errors number : 8
# date time : datetime.datetime(2024, 9, 10, 11, 28, 32, 681006), lesson 56 errors number : 10
# date time : datetime.datetime(2024, 9, 10, 11, 34, 52, 105091), lesson 7 errors number : 2
# date time : datetime.datetime(2024, 9, 11, 15, 24, 26, 952928), lesson 57 errors number : 7
# date time : datetime.datetime(2024, 9, 12, 18, 13, 29, 359135), lesson 58 errors number : 4
# 2024-09-13 00:55:04,078 INFO sqlalchemy.engine.Engine ROLLBACK

# %%
with Session(engine_old) as session_old:
    for lesson_session in session_old.scalars(stmt_old):
        print(lesson_session)
        errored_sentences = []
        for sentence in lesson_session.errored_sentences:
            errored_sentences.append(database.MarkedSentence(
                sentence = sentence.sentence,
                comment = sentence.comment,
                line = sentence.line
            ))
        pam.sessions.append(database.LessonSession(
            user=pam,
            lesson = lesson_session.lesson,
            errors_number = lesson_session.errors_number,
            date_time = lesson_session.date_time,
            errored_sentences = errored_sentences
        ))
    session_new.commit()
# Out:
# 2024-09-13 00:55:12,738 INFO sqlalchemy.engine.Engine BEGIN (implicit)
# 2024-09-13 00:55:12,739 INFO sqlalchemy.engine.Engine SELECT lesson_sessions.id, lesson_sessions.lesson, lesson_sessions.date_time, lesson_sessions.errors_number
# FROM lesson_sessions
# 2024-09-13 00:55:12,739 INFO sqlalchemy.engine.Engine [cached since 42.26s ago] ()
# date time : datetime.datetime(2024, 9, 4, 22, 42, 30, 759328), lesson 50 errors number : 6
# 2024-09-13 00:55:12,749 INFO sqlalchemy.engine.Engine SELECT marked_sentences.id AS marked_sentences_id, marked_sentences.sentence AS marked_sentences_sentence, marked_sentences.comment AS marked_sentences_comment, marked_sentences.line AS marked_sentences_line, marked_sentences.session_id AS marked_sentences_session_id
# FROM marked_sentences
# WHERE ? = marked_sentences.session_id
# 2024-09-13 00:55:12,750 INFO sqlalchemy.engine.Engine [generated in 0.00089s] (1,)
# 2024-09-13 00:55:12,754 INFO sqlalchemy.engine.Engine SELECT lesson_sessions.id AS lesson_sessions_id, lesson_sessions.lesson AS lesson_sessions_lesson, lesson_sessions.date_time AS lesson_sessions_date_time, lesson_sessions.errors_number AS lesson_sessions_errors_number, lesson_sessions.user_id AS lesson_sessions_user_id
# FROM lesson_sessions
# WHERE ? = lesson_sessions.user_id
# 2024-09-13 00:55:12,755 INFO sqlalchemy.engine.Engine [generated in 0.00126s] (1,)
# date time : datetime.datetime(2024, 9, 4, 23, 2, 0, 780033), lesson 1 errors number : 0
# 2024-09-13 00:55:12,759 INFO sqlalchemy.engine.Engine SELECT marked_sentences.id AS marked_sentences_id, marked_sentences.sentence AS marked_sentences_sentence, marked_sentences.comment AS marked_sentences_comment, marked_sentences.line AS marked_sentences_line, marked_sentences.session_id AS marked_sentences_session_id
# FROM marked_sentences
# WHERE ? = marked_sentences.session_id
# 2024-09-13 00:55:12,760 INFO sqlalchemy.engine.Engine [cached since 0.01114s ago] (2,)
# date time : datetime.datetime(2024, 9, 5, 9, 19, 11, 922138), lesson 51 errors number : 3
# 2024-09-13 00:55:12,762 INFO sqlalchemy.engine.Engine SELECT marked_sentences.id AS marked_sentences_id, marked_sentences.sentence AS marked_sentences_sentence, marked_sentences.comment AS marked_sentences_comment, marked_sentences.line AS marked_sentences_line, marked_sentences.session_id AS marked_sentences_session_id
# FROM marked_sentences
# WHERE ? = marked_sentences.session_id
# 2024-09-13 00:55:12,762 INFO sqlalchemy.engine.Engine [cached since 0.01377s ago] (3,)
# date time : datetime.datetime(2024, 9, 6, 23, 54, 35, 589923), lesson 3 errors number : 3
# 2024-09-13 00:55:12,764 INFO sqlalchemy.engine.Engine SELECT marked_sentences.id AS marked_sentences_id, marked_sentences.sentence AS marked_sentences_sentence, marked_sentences.comment AS marked_sentences_comment, marked_sentences.line AS marked_sentences_line, marked_sentences.session_id AS marked_sentences_session_id
# FROM marked_sentences
# WHERE ? = marked_sentences.session_id
# 2024-09-13 00:55:12,764 INFO sqlalchemy.engine.Engine [cached since 0.01553s ago] (5,)
# date time : datetime.datetime(2024, 9, 6, 23, 30, 29, 589456), lesson 52 errors number : 5
# 2024-09-13 00:55:12,766 INFO sqlalchemy.engine.Engine SELECT marked_sentences.id AS marked_sentences_id, marked_sentences.sentence AS marked_sentences_sentence, marked_sentences.comment AS marked_sentences_comment, marked_sentences.line AS marked_sentences_line, marked_sentences.session_id AS marked_sentences_session_id
# FROM marked_sentences
# WHERE ? = marked_sentences.session_id
# 2024-09-13 00:55:12,766 INFO sqlalchemy.engine.Engine [cached since 0.01756s ago] (6,)
# date time : datetime.datetime(2024, 9, 7, 15, 38, 11, 304630), lesson 53 errors number : 4
# 2024-09-13 00:55:12,767 INFO sqlalchemy.engine.Engine SELECT marked_sentences.id AS marked_sentences_id, marked_sentences.sentence AS marked_sentences_sentence, marked_sentences.comment AS marked_sentences_comment, marked_sentences.line AS marked_sentences_line, marked_sentences.session_id AS marked_sentences_session_id
# FROM marked_sentences
# WHERE ? = marked_sentences.session_id
# 2024-09-13 00:55:12,768 INFO sqlalchemy.engine.Engine [cached since 0.0192s ago] (7,)
# date time : datetime.datetime(2024, 9, 7, 15, 47, 54, 852500), lesson 4 errors number : 0
# 2024-09-13 00:55:12,769 INFO sqlalchemy.engine.Engine SELECT marked_sentences.id AS marked_sentences_id, marked_sentences.sentence AS marked_sentences_sentence, marked_sentences.comment AS marked_sentences_comment, marked_sentences.line AS marked_sentences_line, marked_sentences.session_id AS marked_sentences_session_id
# FROM marked_sentences
# WHERE ? = marked_sentences.session_id
# 2024-09-13 00:55:12,769 INFO sqlalchemy.engine.Engine [cached since 0.02088s ago] (8,)
# date time : datetime.datetime(2024, 9, 9, 0, 33, 9, 558002), lesson 54 errors number : 4
# 2024-09-13 00:55:12,771 INFO sqlalchemy.engine.Engine SELECT marked_sentences.id AS marked_sentences_id, marked_sentences.sentence AS marked_sentences_sentence, marked_sentences.comment AS marked_sentences_comment, marked_sentences.line AS marked_sentences_line, marked_sentences.session_id AS marked_sentences_session_id
# FROM marked_sentences
# WHERE ? = marked_sentences.session_id
# 2024-09-13 00:55:12,771 INFO sqlalchemy.engine.Engine [cached since 0.02234s ago] (9,)
# date time : datetime.datetime(2024, 9, 9, 0, 37, 30, 688736), lesson 5 errors number : 0
# 2024-09-13 00:55:12,773 INFO sqlalchemy.engine.Engine SELECT marked_sentences.id AS marked_sentences_id, marked_sentences.sentence AS marked_sentences_sentence, marked_sentences.comment AS marked_sentences_comment, marked_sentences.line AS marked_sentences_line, marked_sentences.session_id AS marked_sentences_session_id
# FROM marked_sentences
# WHERE ? = marked_sentences.session_id
# 2024-09-13 00:55:12,773 INFO sqlalchemy.engine.Engine [cached since 0.02447s ago] (10,)
# date time : datetime.datetime(2024, 9, 9, 23, 49, 20, 733862), lesson 55 errors number : 8
# 2024-09-13 00:55:12,774 INFO sqlalchemy.engine.Engine SELECT marked_sentences.id AS marked_sentences_id, marked_sentences.sentence AS marked_sentences_sentence, marked_sentences.comment AS marked_sentences_comment, marked_sentences.line AS marked_sentences_line, marked_sentences.session_id AS marked_sentences_session_id
# FROM marked_sentences
# WHERE ? = marked_sentences.session_id
# 2024-09-13 00:55:12,774 INFO sqlalchemy.engine.Engine [cached since 0.02584s ago] (11,)
# date time : datetime.datetime(2024, 9, 10, 11, 28, 32, 681006), lesson 56 errors number : 10
# 2024-09-13 00:55:12,776 INFO sqlalchemy.engine.Engine SELECT marked_sentences.id AS marked_sentences_id, marked_sentences.sentence AS marked_sentences_sentence, marked_sentences.comment AS marked_sentences_comment, marked_sentences.line AS marked_sentences_line, marked_sentences.session_id AS marked_sentences_session_id
# FROM marked_sentences
# WHERE ? = marked_sentences.session_id
# 2024-09-13 00:55:12,776 INFO sqlalchemy.engine.Engine [cached since 0.02775s ago] (12,)
# date time : datetime.datetime(2024, 9, 10, 11, 34, 52, 105091), lesson 7 errors number : 2
# 2024-09-13 00:55:12,778 INFO sqlalchemy.engine.Engine SELECT marked_sentences.id AS marked_sentences_id, marked_sentences.sentence AS marked_sentences_sentence, marked_sentences.comment AS marked_sentences_comment, marked_sentences.line AS marked_sentences_line, marked_sentences.session_id AS marked_sentences_session_id
# FROM marked_sentences
# WHERE ? = marked_sentences.session_id
# 2024-09-13 00:55:12,778 INFO sqlalchemy.engine.Engine [cached since 0.0294s ago] (13,)
# date time : datetime.datetime(2024, 9, 11, 15, 24, 26, 952928), lesson 57 errors number : 7
# 2024-09-13 00:55:12,779 INFO sqlalchemy.engine.Engine SELECT marked_sentences.id AS marked_sentences_id, marked_sentences.sentence AS marked_sentences_sentence, marked_sentences.comment AS marked_sentences_comment, marked_sentences.line AS marked_sentences_line, marked_sentences.session_id AS marked_sentences_session_id
# FROM marked_sentences
# WHERE ? = marked_sentences.session_id
# 2024-09-13 00:55:12,780 INFO sqlalchemy.engine.Engine [cached since 0.03096s ago] (14,)
# date time : datetime.datetime(2024, 9, 12, 18, 13, 29, 359135), lesson 58 errors number : 4
# 2024-09-13 00:55:12,781 INFO sqlalchemy.engine.Engine SELECT marked_sentences.id AS marked_sentences_id, marked_sentences.sentence AS marked_sentences_sentence, marked_sentences.comment AS marked_sentences_comment, marked_sentences.line AS marked_sentences_line, marked_sentences.session_id AS marked_sentences_session_id
# FROM marked_sentences
# WHERE ? = marked_sentences.session_id
# 2024-09-13 00:55:12,781 INFO sqlalchemy.engine.Engine [cached since 0.03234s ago] (15,)
# 2024-09-13 00:55:12,784 INFO sqlalchemy.engine.Engine INSERT INTO lesson_sessions (lesson, date_time, errors_number, user_id) VALUES (?, ?, ?, ?) RETURNING id
# 2024-09-13 00:55:12,784 INFO sqlalchemy.engine.Engine [generated in 0.00021s (insertmanyvalues) 1/14 (ordered; batch not supported)] (50, '2024-09-04 22:42:30.759328', 6, 1)
# 2024-09-13 00:55:12,785 INFO sqlalchemy.engine.Engine INSERT INTO lesson_sessions (lesson, date_time, errors_number, user_id) VALUES (?, ?, ?, ?) RETURNING id
# 2024-09-13 00:55:12,786 INFO sqlalchemy.engine.Engine [insertmanyvalues 2/14 (ordered; batch not supported)] (1, '2024-09-04 23:02:00.780033', 0, 1)
# 2024-09-13 00:55:12,786 INFO sqlalchemy.engine.Engine INSERT INTO lesson_sessions (lesson, date_time, errors_number, user_id) VALUES (?, ?, ?, ?) RETURNING id
# 2024-09-13 00:55:12,787 INFO sqlalchemy.engine.Engine [insertmanyvalues 3/14 (ordered; batch not supported)] (51, '2024-09-05 09:19:11.922138', 3, 1)
# 2024-09-13 00:55:12,787 INFO sqlalchemy.engine.Engine INSERT INTO lesson_sessions (lesson, date_time, errors_number, user_id) VALUES (?, ?, ?, ?) RETURNING id
# 2024-09-13 00:55:12,788 INFO sqlalchemy.engine.Engine [insertmanyvalues 4/14 (ordered; batch not supported)] (3, '2024-09-06 23:54:35.589923', 3, 1)
# 2024-09-13 00:55:12,788 INFO sqlalchemy.engine.Engine INSERT INTO lesson_sessions (lesson, date_time, errors_number, user_id) VALUES (?, ?, ?, ?) RETURNING id
# 2024-09-13 00:55:12,789 INFO sqlalchemy.engine.Engine [insertmanyvalues 5/14 (ordered; batch not supported)] (52, '2024-09-06 23:30:29.589456', 5, 1)
# 2024-09-13 00:55:12,789 INFO sqlalchemy.engine.Engine INSERT INTO lesson_sessions (lesson, date_time, errors_number, user_id) VALUES (?, ?, ?, ?) RETURNING id
# 2024-09-13 00:55:12,790 INFO sqlalchemy.engine.Engine [insertmanyvalues 6/14 (ordered; batch not supported)] (53, '2024-09-07 15:38:11.304630', 4, 1)
# 2024-09-13 00:55:12,790 INFO sqlalchemy.engine.Engine INSERT INTO lesson_sessions (lesson, date_time, errors_number, user_id) VALUES (?, ?, ?, ?) RETURNING id
# 2024-09-13 00:55:12,790 INFO sqlalchemy.engine.Engine [insertmanyvalues 7/14 (ordered; batch not supported)] (4, '2024-09-07 15:47:54.852500', 0, 1)
# 2024-09-13 00:55:12,791 INFO sqlalchemy.engine.Engine INSERT INTO lesson_sessions (lesson, date_time, errors_number, user_id) VALUES (?, ?, ?, ?) RETURNING id
# 2024-09-13 00:55:12,791 INFO sqlalchemy.engine.Engine [insertmanyvalues 8/14 (ordered; batch not supported)] (54, '2024-09-09 00:33:09.558002', 4, 1)
# 2024-09-13 00:55:12,791 INFO sqlalchemy.engine.Engine INSERT INTO lesson_sessions (lesson, date_time, errors_number, user_id) VALUES (?, ?, ?, ?) RETURNING id
# 2024-09-13 00:55:12,791 INFO sqlalchemy.engine.Engine [insertmanyvalues 9/14 (ordered; batch not supported)] (5, '2024-09-09 00:37:30.688736', 0, 1)
# 2024-09-13 00:55:12,792 INFO sqlalchemy.engine.Engine INSERT INTO lesson_sessions (lesson, date_time, errors_number, user_id) VALUES (?, ?, ?, ?) RETURNING id
# 2024-09-13 00:55:12,792 INFO sqlalchemy.engine.Engine [insertmanyvalues 10/14 (ordered; batch not supported)] (55, '2024-09-09 23:49:20.733862', 8, 1)
# 2024-09-13 00:55:12,792 INFO sqlalchemy.engine.Engine INSERT INTO lesson_sessions (lesson, date_time, errors_number, user_id) VALUES (?, ?, ?, ?) RETURNING id
# 2024-09-13 00:55:12,792 INFO sqlalchemy.engine.Engine [insertmanyvalues 11/14 (ordered; batch not supported)] (56, '2024-09-10 11:28:32.681006', 10, 1)
# 2024-09-13 00:55:12,793 INFO sqlalchemy.engine.Engine INSERT INTO lesson_sessions (lesson, date_time, errors_number, user_id) VALUES (?, ?, ?, ?) RETURNING id
# 2024-09-13 00:55:12,793 INFO sqlalchemy.engine.Engine [insertmanyvalues 12/14 (ordered; batch not supported)] (7, '2024-09-10 11:34:52.105091', 2, 1)
# 2024-09-13 00:55:12,793 INFO sqlalchemy.engine.Engine INSERT INTO lesson_sessions (lesson, date_time, errors_number, user_id) VALUES (?, ?, ?, ?) RETURNING id
# 2024-09-13 00:55:12,793 INFO sqlalchemy.engine.Engine [insertmanyvalues 13/14 (ordered; batch not supported)] (57, '2024-09-11 15:24:26.952928', 7, 1)
# 2024-09-13 00:55:12,793 INFO sqlalchemy.engine.Engine INSERT INTO lesson_sessions (lesson, date_time, errors_number, user_id) VALUES (?, ?, ?, ?) RETURNING id
# 2024-09-13 00:55:12,794 INFO sqlalchemy.engine.Engine [insertmanyvalues 14/14 (ordered; batch not supported)] (58, '2024-09-12 18:13:29.359135', 4, 1)
# 2024-09-13 00:55:12,796 INFO sqlalchemy.engine.Engine INSERT INTO marked_sentences (sentence, comment, line, session_id) VALUES (?, ?, ?, ?) RETURNING id
# 2024-09-13 00:55:12,796 INFO sqlalchemy.engine.Engine [generated in 0.00014s (insertmanyvalues) 1/56 (ordered; batch not supported)] ("S01-Fe<b>li</b>pe, <b>gua</b>po, <b>da</b>me diez <b>lon</b>chas de <mark class='A'>ja<b>món</b></mark><b></b> de york, por fa<b>vor</b>.", None, 2, 1)
# 2024-09-13 00:55:12,797 INFO sqlalchemy.engine.Engine INSERT INTO marked_sentences (sentence, comment, line, session_id) VALUES (?, ?, ?, ?) RETURNING id
# 2024-09-13 00:55:12,797 INFO sqlalchemy.engine.Engine [insertmanyvalues 2/56 (ordered; batch not supported)] ("S04-Y <mark class='E'>yo</mark> se la di a <b>es</b>ta se<b>ño</b>ra.", None, 5, 1)
# 2024-09-13 00:55:12,797 INFO sqlalchemy.engine.Engine INSERT INTO marked_sentences (sentence, comment, line, session_id) VALUES (?, ?, ?, ?) RETURNING id
# 2024-09-13 00:55:12,797 INFO sqlalchemy.engine.Engine [insertmanyvalues 3/56 (ordered; batch not supported)] ("S05-O <b>se</b>a, que a<b>ho</b>ra me <b>to</b>ca a mí, y us<b>ted</b> ¡a ha<b>cer</b> <b>co</b>la i<b>gual</b> que <mark class='O'>los</mark> de<b>más</b>!", None, 6, 1)
# 2024-09-13 00:55:12,798 INFO sqlalchemy.engine.Engine INSERT INTO marked_sentences (sentence, comment, line, session_id) VALUES (?, ?, ?, ?) RETURNING id
# 2024-09-13 00:55:12,798 INFO sqlalchemy.engine.Engine [insertmanyvalues 4/56 (ordered; batch not supported)] ("S09-<b></b><mark class='E'><b>Ven</b>ga</mark>, <b>pa</b>se, <b>pe</b>ro que <b>se</b>a <b>rá</b>pido.", None, 10, 1)
# 2024-09-13 00:55:12,798 INFO sqlalchemy.engine.Engine INSERT INTO marked_sentences (sentence, comment, line, session_id) VALUES (?, ?, ?, ?) RETURNING id
# 2024-09-13 00:55:12,798 INFO sqlalchemy.engine.Engine [insertmanyvalues 5/56 (ordered; batch not supported)] ("T01-Te <mark class='E'>pe<b>dí</b></mark><b></b> diez <b>lon</b>chas de ja<b>món</b> de York y <b>me</b>dio <b>ki</b>lo de <b>car</b>ne pi<b>ca</b>da.", None, 15, 1)
# 2024-09-13 00:55:12,799 INFO sqlalchemy.engine.Engine INSERT INTO marked_sentences (sentence, comment, line, session_id) VALUES (?, ?, ?, ?) RETURNING id
# 2024-09-13 00:55:12,799 INFO sqlalchemy.engine.Engine [insertmanyvalues 6/56 (ordered; batch not supported)] ("T05-Me <b></b><mark class='G'><b>ha</b>cen</mark> <b>fal</b>ta <b>cua</b>tro <b>mus</b>los de <b>po</b>llo y dos pe<b>chu</b>gas.", None, 19, 1)
# 2024-09-13 00:55:12,799 INFO sqlalchemy.engine.Engine INSERT INTO marked_sentences (sentence, comment, line, session_id) VALUES (?, ?, ?, ?) RETURNING id
# 2024-09-13 00:55:12,799 INFO sqlalchemy.engine.Engine [insertmanyvalues 7/56 (ordered; batch not supported)] ("S06-¡En <b>to</b>das <b>par</b>tes! Pri<b>me</b>ro en <mark class='O'>el</mark> Ca<b>ri</b>be.", None, 7, 3)
# 2024-09-13 00:55:12,800 INFO sqlalchemy.engine.Engine INSERT INTO marked_sentences (sentence, comment, line, session_id) VALUES (?, ?, ?, ?) RETURNING id
# 2024-09-13 00:55:12,800 INFO sqlalchemy.engine.Engine [insertmanyvalues 8/56 (ordered; batch not supported)] ("T03-Via<b>ja</b>mos por <b>to</b>do el pa<b>ís</b> y <b></b><mark class='V'><b>fui</b>mos</mark> a <b>to</b>das <b>par</b>tes.", None, 20, 3)
# 2024-09-13 00:55:12,800 INFO sqlalchemy.engine.Engine INSERT INTO marked_sentences (sentence, comment, line, session_id) VALUES (?, ?, ?, ?) RETURNING id
# 2024-09-13 00:55:12,800 INFO sqlalchemy.engine.Engine [insertmanyvalues 9/56 (ordered; batch not supported)] ("T04-No me gus<b>tó</b> Ciu<b>dad</b> de <b>Mé</b>xico, <b>pe</b>ro la <b>gen</b>te <mark class='V'>me pare<b>ció</b></mark><b></b> encanta<b>do</b>ra.", None, 21, 3)
# 2024-09-13 00:55:12,801 INFO sqlalchemy.engine.Engine INSERT INTO marked_sentences (sentence, comment, line, session_id) VALUES (?, ?, ?, ?) RETURNING id
# 2024-09-13 00:55:12,801 INFO sqlalchemy.engine.Engine [insertmanyvalues 10/56 (ordered; batch not supported)] ("S00-TITLE-¡<mark class='O' title='      '>Bienve<b>ni</b>da</mark>!", None, 1, 4)
# 2024-09-13 00:55:12,801 INFO sqlalchemy.engine.Engine INSERT INTO marked_sentences (sentence, comment, line, session_id) VALUES (?, ?, ?, ?) RETURNING id
# 2024-09-13 00:55:12,801 INFO sqlalchemy.engine.Engine [insertmanyvalues 11/56 (ordered; batch not supported)] ("S04-No, no soy madri<b>le</b>ña. Soy <mark class='O' title='andaluza avec z'>anda<b>lu</b>za</mark>, de Se<b>vi</b>lla.", None, 5, 4)
# 2024-09-13 00:55:12,801 INFO sqlalchemy.engine.Engine INSERT INTO marked_sentences (sentence, comment, line, session_id) VALUES (?, ?, ?, ?) RETURNING id
# 2024-09-13 00:55:12,802 INFO sqlalchemy.engine.Engine [insertmanyvalues 12/56 (ordered; batch not supported)] ("S05-¡Pues <mark class='O' title='bienvenida et non pas benvenida.'>bienve<b>ni</b>da</mark> a Ma<b>drid</b>, mo<b>re</b>na!", None, 6, 4)
# 2024-09-13 00:55:12,802 INFO sqlalchemy.engine.Engine INSERT INTO marked_sentences (sentence, comment, line, session_id) VALUES (?, ?, ?, ?) RETURNING id
# 2024-09-13 00:55:12,802 INFO sqlalchemy.engine.Engine [insertmanyvalues 13/56 (ordered; batch not supported)] ("S04-¿Choco<b>la</b>te pi<b>can</b>te? ¿No te <mark class='V' title='3ème personne du singulier du passé simple de dar : dio et non pas di.'>dio</mark> <b>as</b>co?", None, 5, 5)
# 2024-09-13 00:55:12,802 INFO sqlalchemy.engine.Engine INSERT INTO marked_sentences (sentence, comment, line, session_id) VALUES (?, ?, ?, ?) RETURNING id
# 2024-09-13 00:55:12,803 INFO sqlalchemy.engine.Engine [insertmanyvalues 14/56 (ordered; batch not supported)] ("S08-¿<b>Pe</b>ro <b>nun</b>ca lo <mark class='V' title='3ème personne du pluriel du présent du verbe tomar.'><b>to</b>man</mark> <b></b><b>dul</b>ce?", None, 9, 5)
# 2024-09-13 00:55:12,803 INFO sqlalchemy.engine.Engine INSERT INTO marked_sentences (sentence, comment, line, session_id) VALUES (?, ?, ?, ?) RETURNING id
# 2024-09-13 00:55:12,803 INFO sqlalchemy.engine.Engine [insertmanyvalues 15/56 (ordered; batch not supported)] ("S09-Sí, <b>cla</b>ro, hoy en <b>dí</b>a tam<b>bién</b> <mark class='G' title='cacao est complément d&#039;objet indirect donc=&#034;le&#034; et non pas &#034;lo&#034;'>le</mark> <b>e</b>chan a<b>zú</b>car,", None, 10, 5)
# 2024-09-13 00:55:12,803 INFO sqlalchemy.engine.Engine INSERT INTO marked_sentences (sentence, comment, line, session_id) VALUES (?, ?, ?, ?) RETURNING id
# 2024-09-13 00:55:12,804 INFO sqlalchemy.engine.Engine [insertmanyvalues 16/56 (ordered; batch not supported)] ("S10-<b>pe</b>ro en la tradi<b>ción</b> in<b>dí</b>gena no se <mark class='G' title='cacao est complément d&#039;objet indirect donc=&#034;le&#034; et non pas &#034;lo&#034;'>le</mark> a<b>ña</b>de <b>le</b>che, <b>so</b>lo <b>a</b>gua.", None, 11, 5)
# 2024-09-13 00:55:12,804 INFO sqlalchemy.engine.Engine INSERT INTO marked_sentences (sentence, comment, line, session_id) VALUES (?, ?, ?, ?) RETURNING id
# 2024-09-13 00:55:12,804 INFO sqlalchemy.engine.Engine [insertmanyvalues 17/56 (ordered; batch not supported)] ("S11-<b></b><mark class='O'><b></b><mark class='O' title='Meriendas est féminin, donc nuestras et non pas nuestros.'><b>Nues</b>tras</mark></mark> me<b>rien</b>das sí que las e<b>cha</b>ba de <b>me</b>nos un buen choco<b>la</b>te con <b>chu</b>rros. . .", None, 12, 5)
# 2024-09-13 00:55:12,804 INFO sqlalchemy.engine.Engine INSERT INTO marked_sentences (sentence, comment, line, session_id) VALUES (?, ?, ?, ?) RETURNING id
# 2024-09-13 00:55:12,805 INFO sqlalchemy.engine.Engine [insertmanyvalues 18/56 (ordered; batch not supported)] ("S01-Cris<b>tó</b>bal Co<b>l<mark class='A' title='      '>ó</mark>n</b> sa<b>bí</b>a que la <b>Tie</b>rra <b>e</b>ra re<b>don</b>da y <b>qui</b>so al ... (1 characters truncated) ... an<b>zar</b> las <b>In</b>dias <b>yen</b>do <b>siem</b>pre <b></b><mark class='O' title='hacia et non pas hasta'><b>ha</b>cia</mark> el o<b>es</b>te.", None, 2, 6)
# 2024-09-13 00:55:12,805 INFO sqlalchemy.engine.Engine INSERT INTO marked_sentences (sentence, comment, line, session_id) VALUES (?, ?, ?, ?) RETURNING id
# 2024-09-13 00:55:12,805 INFO sqlalchemy.engine.Engine [insertmanyvalues 19/56 (ordered; batch not supported)] ("S07-y <mark class='V' title='Passé simple irrégulier de traer au passé simple dont le radical devient traj'>tra<b>je</b>ron</mark> <b></b><mark class='G'><b></b><mark class='G' title='Au pluriel'><b>o</b>tros <b>tan</b>tos</mark></mark> a Eu<b>ro</b>pa.", None, 8, 6)
# 2024-09-13 00:55:12,805 INFO sqlalchemy.engine.Engine INSERT INTO marked_sentences (sentence, comment, line, session_id) VALUES (?, ?, ?, ?) RETURNING id
# 2024-09-13 00:55:12,806 INFO sqlalchemy.engine.Engine [insertmanyvalues 20/56 (ordered; batch not supported)] ("S10-<b>nues</b>tros <b>pos</b>tres sin vai<b>ni</b>lla o los <b>Pie</b>les <b></b><mark class='O' title='Terminaison en a de Roja'><b>Ro</b>jas</mark> sin ca<b>ba</b>llos?", None, 11, 6)
# 2024-09-13 00:55:12,806 INFO sqlalchemy.engine.Engine INSERT INTO marked_sentences (sentence, comment, line, session_id) VALUES (?, ?, ?, ?) RETURNING id
# 2024-09-13 00:55:12,806 INFO sqlalchemy.engine.Engine [insertmanyvalues 21/56 (ordered; batch not supported)] ("S11-Un <b>nue</b>vo <b>mun</b>do <mark class='V' title='nació\xa0et non pas naci'>na<b>ció</b></mark><b></b> el 12 de oc<b>tu</b>bre de 1492 mil cuatro<b>cien</b>tos no<b>ven</b>ta y dos.", None, 12, 6)
# 2024-09-13 00:55:12,806 INFO sqlalchemy.engine.Engine INSERT INTO marked_sentences (sentence, comment, line, session_id) VALUES (?, ?, ?, ?) RETURNING id
# 2024-09-13 00:55:12,806 INFO sqlalchemy.engine.Engine [insertmanyvalues 22/56 (ordered; batch not supported)] ("S01-¡<mark class='E' title='&#034;Ya&#034; está au lieu de &#034;Ya&#034;'>Ya</mark> <b></b><mark class='O' title='&#034;fue&#034; au lieu de &#034;hice&#034;'><b>hi</b>ce</mark> la entre<b>vis</b>ta!", None, 2, 8)
# 2024-09-13 00:55:12,807 INFO sqlalchemy.engine.Engine INSERT INTO marked_sentences (sentence, comment, line, session_id) VALUES (?, ?, ?, ?) RETURNING id
# 2024-09-13 00:55:12,807 INFO sqlalchemy.engine.Engine [insertmanyvalues 23/56 (ordered; batch not supported)] ("S14-Por Dios ¿Y qué <mark class='V' title='3ème du singulier du assé simple de pasar.'>pa<b>só</b></mark><b></b>?", None, 15, 8)
# 2024-09-13 00:55:12,807 INFO sqlalchemy.engine.Engine INSERT INTO marked_sentences (sentence, comment, line, session_id) VALUES (?, ?, ?, ?) RETURNING id
# 2024-09-13 00:55:12,808 INFO sqlalchemy.engine.Engine [insertmanyvalues 24/56 (ordered; batch not supported)] ("S16-Te lo <b></b><mark class='V' title='&#034;digo&#034; et non pas &#034;dicho&#034;'><b>di</b>go</mark> el <b>pues</b>to es <b>mí</b>o.", None, 17, 8)
# 2024-09-13 00:55:12,808 INFO sqlalchemy.engine.Engine INSERT INTO marked_sentences (sentence, comment, line, session_id) VALUES (?, ?, ?, ?) RETURNING id
# 2024-09-13 00:55:12,808 INFO sqlalchemy.engine.Engine [insertmanyvalues 25/56 (ordered; batch not supported)] ("T01-He te<b>ni</b>do <b>suer</b>te, la entre<b>vis</b>ta <mark class='E' title='&#034;me fue&#034; et non pas &#034;se pasó&#034;'>me fue</mark> muy bien y he conse<b>gui</b>do el <b>pues</b>to.", None, 19, 8)
# 2024-09-13 00:55:12,808 INFO sqlalchemy.engine.Engine INSERT INTO marked_sentences (sentence, comment, line, session_id) VALUES (?, ?, ?, ?) RETURNING id
# 2024-09-13 00:55:12,809 INFO sqlalchemy.engine.Engine [insertmanyvalues 26/56 (ordered; batch not supported)] ("S02-<mark class='G' title='Cazadora est féminin, donc le pronom est &#034;la&#034;'>La</mark> com<b>pré</b> a<b>yer</b> en el <b>Ras</b>tro, no <b>pu</b>de resis<b>tir</b>me.", None, 3, 10)
# 2024-09-13 00:55:12,809 INFO sqlalchemy.engine.Engine INSERT INTO marked_sentences (sentence, comment, line, session_id) VALUES (?, ?, ?, ?) RETURNING id
# 2024-09-13 00:55:12,809 INFO sqlalchemy.engine.Engine [insertmanyvalues 27/56 (ordered; batch not supported)] ("S03-<b>Tu</b>ve que regate<b>ar</b> un buen <b>ra</b>to, el <b>tí</b>o no <mark class='V' title='Querer à l&#039;imparfait et non pas au passé simple.'>que<b>rí</b>a</mark> ba<b>jar</b> el <b>pre</b>cio.", None, 4, 10)
# 2024-09-13 00:55:12,810 INFO sqlalchemy.engine.Engine INSERT INTO marked_sentences (sentence, comment, line, session_id) VALUES (?, ?, ?, ?) RETURNING id
# 2024-09-13 00:55:12,810 INFO sqlalchemy.engine.Engine [insertmanyvalues 28/56 (ordered; batch not supported)] ("S05-que no <b>i</b>ba a encon<b>trar</b> <b></b><mark class='G' title='Cazadora féminin, donc &#034;otra&#034; et non pas &#034;otro&#034;'><b>o</b>tra</mark> i<b>gual</b>.", None, 6, 10)
# 2024-09-13 00:55:12,811 INFO sqlalchemy.engine.Engine INSERT INTO marked_sentences (sentence, comment, line, session_id) VALUES (?, ?, ?, ?) RETURNING id
# 2024-09-13 00:55:12,811 INFO sqlalchemy.engine.Engine [insertmanyvalues 29/56 (ordered; batch not supported)] ("S06-Le pa<b>gué</b> la mi<b>tad</b> de lo que <mark class='O' title='&#034;pedir&#034; et non pas &#034;preguntar&#034;. De plus à l&#039;imparfait e ... (47 characters truncated) ...  al prin<b>ci</b>pio, <mark class='O' title='&#034;doscientos&#034; en un seul mot.'>dos<b>cien</b>tos</mark> <b>eu</b>ros. ¡<b>U</b>na <b>gan</b>ga!", None, 7, 10)
# 2024-09-13 00:55:12,812 INFO sqlalchemy.engine.Engine INSERT INTO marked_sentences (sentence, comment, line, session_id) VALUES (?, ?, ?, ?) RETURNING id
# 2024-09-13 00:55:12,812 INFO sqlalchemy.engine.Engine [insertmanyvalues 30/56 (ordered; batch not supported)] ("S12-No <b>pe</b>sa <b>mu</b>cho, pa<b>re</b>ce <b>fal</b>sa. . . ¿<mark class='E' title='&#034;De verdad&#034; placé avant crees pour insister dessus.'>De ver<b>dad</b></mark><b></b> <b>cre</b>es que es de <b>cue</b>ro?", None, 13, 10)
# 2024-09-13 00:55:12,812 INFO sqlalchemy.engine.Engine INSERT INTO marked_sentences (sentence, comment, line, session_id) VALUES (?, ?, ?, ?) RETURNING id
# 2024-09-13 00:55:12,812 INFO sqlalchemy.engine.Engine [insertmanyvalues 31/56 (ordered; batch not supported)] ("S14-A<b>mi</b>go <b>mí</b>o, me pa<b>re</b>ce que te han <b>da</b>do <b>ga</b>to por <b></b><mark class='O' title='&#034;liebre&#034; et non pas &#034;liebro&#034;'><b>lie</b>bre</mark>", None, 15, 10)
# 2024-09-13 00:55:12,813 INFO sqlalchemy.engine.Engine INSERT INTO marked_sentences (sentence, comment, line, session_id) VALUES (?, ?, ?, ?) RETURNING id
# 2024-09-13 00:55:12,813 INFO sqlalchemy.engine.Engine [insertmanyvalues 32/56 (ordered; batch not supported)] ("T02-<b></b><mark class='O' title='&#034;Trater&#034; et non pas &#034;probar&#034;'><b>Tra</b>té</mark> de regate<b>ar</b>, <b>pe</b>ro el <b>tí</b>o no <b>qui</b>so ba<b>jar</b> el <b>pre</b>cio.", None, 18, 10)
# 2024-09-13 00:55:12,813 INFO sqlalchemy.engine.Engine INSERT INTO marked_sentences (sentence, comment, line, session_id) VALUES (?, ?, ?, ?) RETURNING id
# 2024-09-13 00:55:12,813 INFO sqlalchemy.engine.Engine [insertmanyvalues 33/56 (ordered; batch not supported)] ("T03-<b>Tu</b>ve que pa<b>gar</b> lo que <mark class='V' title='Imparfait et non pas passé simple.'>pe<b>dí</b>a</mark> al prin<b>ci</b>pio.", None, 19, 10)
# 2024-09-13 00:55:12,814 INFO sqlalchemy.engine.Engine INSERT INTO marked_sentences (sentence, comment, line, session_id) VALUES (?, ?, ?, ?) RETURNING id
# 2024-09-13 00:55:12,814 INFO sqlalchemy.engine.Engine [insertmanyvalues 34/56 (ordered; batch not supported)] ("S02-Es<b>toy</b> conven<b>ci</b>do de que sí. Pa<b>sé</b> la entre<b>vis</b>ta a<b>yer</b> y <b>cre</b>o que <b>su</b>pe contes<b>tar</b> a <b>to</b>do lo que me <mark class='V' title='Passé simple 3ème personne des verbes en -ar : terminaison -aron'>pregun<b>ta</b>ron</mark>.", None, 3, 11)
# 2024-09-13 00:55:12,814 INFO sqlalchemy.engine.Engine INSERT INTO marked_sentences (sentence, comment, line, session_id) VALUES (?, ?, ?, ?) RETURNING id
# 2024-09-13 00:55:12,814 INFO sqlalchemy.engine.Engine [insertmanyvalues 35/56 (ordered; batch not supported)] ("S03-¡Enhora<b>bue</b>na! <b>Pe</b>ro, <b>di</b>me, ¿qué <b>ti</b>po de pre<b>gun</b>tas te <mark class='V' title='Passé simple 3ème personne des verbes en -er et ir : terminaison -ieron'>hi<b>cie</b>ron</mark>? A <b>ve</b>ces hay <b>tram</b>pas en las entre<b>vis</b>tas, ¿<b>sa</b>bes?", None, 4, 11)
# 2024-09-13 00:55:12,815 INFO sqlalchemy.engine.Engine INSERT INTO marked_sentences (sentence, comment, line, session_id) VALUES (?, ?, ?, ?) RETURNING id
# 2024-09-13 00:55:12,815 INFO sqlalchemy.engine.Engine [insertmanyvalues 36/56 (ordered; batch not supported)] ("S04-¡<mark class='E' title='&#034;En absoluto&#034; convient aussi.'>Qué va!</mark> <b>Fue</b>ron la mar de a<b>ma</b>bles y edu<b>ca</b>dos.", None, 5, 11)
# 2024-09-13 00:55:12,815 INFO sqlalchemy.engine.Engine INSERT INTO marked_sentences (sentence, comment, line, session_id) VALUES (?, ?, ?, ?) RETURNING id
# 2024-09-13 00:55:12,815 INFO sqlalchemy.engine.Engine [insertmanyvalues 37/56 (ordered; batch not supported)] ("S05-Me di<b>je</b>ron que a lo me<b>jor</b> <b>i</b>ban a man<b>dar</b>me a traba<b>jar</b> a Ciu<b>dad</b> de <b>Mé</b>xico y qui<b>sier</b>on sa<b>ber</b> si ya <mark class='V' title='Imparfait &#034;había&#034; et non pas le passé simple'>ha<b>bí</b>a</mark> es<b>ta</b>do a<b>llí</b>.", None, 6, 11)
# 2024-09-13 00:55:12,815 INFO sqlalchemy.engine.Engine INSERT INTO marked_sentences (sentence, comment, line, session_id) VALUES (?, ?, ?, ?) RETURNING id
# 2024-09-13 00:55:12,816 INFO sqlalchemy.engine.Engine [insertmanyvalues 38/56 (ordered; batch not supported)] ("S06-Les contes<b>té</b> que por su<b>pues</b>to cono<b>cí</b>a Latinoa<b>mé</b>rica y nos <mark class='V' title='&#034;pusimos&#034;\xa0passé simple de poner'>pu<b>si</b>mos</mark> a ha<b>blar</b> de la <b>vi</b>da en <b>Mé</b>xico.", None, 7, 11)
# 2024-09-13 00:55:12,816 INFO sqlalchemy.engine.Engine INSERT INTO marked_sentences (sentence, comment, line, session_id) VALUES (?, ?, ?, ?) RETURNING id
# 2024-09-13 00:55:12,816 INFO sqlalchemy.engine.Engine [insertmanyvalues 39/56 (ordered; batch not supported)] ("S07-Les con<b>té</b> que ha<b>bí</b>a es<b>ta</b>do en <b>to</b>das <b></b><mark class='V' title='&#034;partes&#034; et non pas &#034;partas&#034;'>< ... (11 characters truncated) ... s</mark> y que <b>has</b>ta ha<b>bí</b>a rega<b>tea</b>do el <b>pre</b>cio de un jer<b>sey</b> muy <b>chu</b>lo en un mer<b>ca</b>do in<b>dí</b>gena.", None, 8, 11)
# 2024-09-13 00:55:12,816 INFO sqlalchemy.engine.Engine INSERT INTO marked_sentences (sentence, comment, line, session_id) VALUES (?, ?, ?, ?) RETURNING id
# 2024-09-13 00:55:12,817 INFO sqlalchemy.engine.Engine [insertmanyvalues 40/56 (ordered; batch not supported)] ("S08-¿Te atre<b>vis</b>te a <mark class='G' title='&#034;contarles&#034; et non pas &#034;les contar&#034;'>con<b>tar</b>les</mark> <b>e</b>so?", None, 9, 11)
# 2024-09-13 00:55:12,817 INFO sqlalchemy.engine.Engine INSERT INTO marked_sentences (sentence, comment, line, session_id) VALUES (?, ?, ?, ?) RETURNING id
# 2024-09-13 00:55:12,817 INFO sqlalchemy.engine.Engine [insertmanyvalues 41/56 (ordered; batch not supported)] ("S09-Sí, ¡les <b></b><mark class='V' title='&#034;hizo&#034; passé simple et non imparfait'><b>hi</b>zo</mark> <b>mu</b>cha <b>gra</b>cia!", None, 10, 11)
# 2024-09-13 00:55:12,817 INFO sqlalchemy.engine.Engine INSERT INTO marked_sentences (sentence, comment, line, session_id) VALUES (?, ?, ?, ?) RETURNING id
# 2024-09-13 00:55:12,817 INFO sqlalchemy.engine.Engine [insertmanyvalues 42/56 (ordered; batch not supported)] ("S10-¿Y les <mark class='V' title='&#034;dijiste&#034; passé simple et non imparfait'>di<b>jis</b>te</mark> tam<b>bién</b> que te ha<b>bí</b>a <b>da</ ... (86 characters truncated) ... >do y que e<b>cha</b>bas de <b>me</b>nos las me<b>rien</b>das <mark class='O' title='&#034;españolas&#034; acord au féminin'>espa<b>ño</b>las</mark>?", None, 11, 11)
# 2024-09-13 00:55:12,818 INFO sqlalchemy.engine.Engine INSERT INTO marked_sentences (sentence, comment, line, session_id) VALUES (?, ?, ?, ?) RETURNING id
# 2024-09-13 00:55:12,818 INFO sqlalchemy.engine.Engine [insertmanyvalues 43/56 (ordered; batch not supported)] ("S11-No, <b></b><mark class='E' title='Formule courrante'><b>e</b>so sí</mark> que no lo <b>di</b>je", None, 12, 11)
# 2024-09-13 00:55:12,818 INFO sqlalchemy.engine.Engine INSERT INTO marked_sentences (sentence, comment, line, session_id) VALUES (?, ?, ?, ?) RETURNING id
# 2024-09-13 00:55:12,818 INFO sqlalchemy.engine.Engine [insertmanyvalues 44/56 (ordered; batch not supported)] ("S03-Muy bien, <b>pe</b>ro ¡<b></b><mark class='A' title='      '><b>há</b>blame</mark> de tú, por fa<b>vor</b>!", None, 4, 12)
# 2024-09-13 00:55:12,818 INFO sqlalchemy.engine.Engine INSERT INTO marked_sentences (sentence, comment, line, session_id) VALUES (?, ?, ?, ?) RETURNING id
# 2024-09-13 00:55:12,819 INFO sqlalchemy.engine.Engine [insertmanyvalues 45/56 (ordered; batch not supported)] ("S05-<mark class='O' title='&#034;Encantada&#034; et non pas &#034;Encantadora&#034;'>Encan<b>ta</b>da</mark>. Me <b>lla</b>mo <b>Mon</b>tse. ¿<b>E</b>res de Barce<b>lo</b>na?", None, 6, 12)
# 2024-09-13 00:55:12,819 INFO sqlalchemy.engine.Engine INSERT INTO marked_sentences (sentence, comment, line, session_id) VALUES (?, ?, ?, ?) RETURNING id
# 2024-09-13 00:55:12,819 INFO sqlalchemy.engine.Engine [insertmanyvalues 46/56 (ordered; batch not supported)] ("S01-<mark class='O' title='&#034;Anoche&#034; et non pas &#034;anteanoche&#034; qui signifie avant hier soir'>A<b>no</b>che</mark> <b>tu</b>ve un <b>sue</b>ño ex<b>tra</b>ño. ", None, 2, 13)
# 2024-09-13 00:55:12,820 INFO sqlalchemy.engine.Engine INSERT INTO marked_sentences (sentence, comment, line, session_id) VALUES (?, ?, ?, ?) RETURNING id
# 2024-09-13 00:55:12,820 INFO sqlalchemy.engine.Engine [insertmanyvalues 47/56 (ordered; batch not supported)] ('S05-¿Por qué? ¿Tú no hay <b>dí</b>as en que es<b>tás</b> can<b>sa</b>do del <b></b><b>trá</b>fico, del <b>rui</b>do y de los a<b>tas</b>cos? ', None, 6, 13)
# 2024-09-13 00:55:12,820 INFO sqlalchemy.engine.Engine INSERT INTO marked_sentences (sentence, comment, line, session_id) VALUES (?, ?, ?, ?) RETURNING id
# 2024-09-13 00:55:12,820 INFO sqlalchemy.engine.Engine [insertmanyvalues 48/56 (ordered; batch not supported)] ("S07-<mark class='E' title='&#034;quizás&#034;\xa0et &#034;tal vez&#034; sont équivalents'>qui<b>zás</b></mark><b></b> <b>ha</b>ya <b>me</b>nos contamina<b>ción</b>, <b>pe</b>ro te a<b>bu</b>rres <b>co</b>mo <b>u</b>na <b>os</b>tra. ", None, 8, 13)
# 2024-09-13 00:55:12,820 INFO sqlalchemy.engine.Engine INSERT INTO marked_sentences (sentence, comment, line, session_id) VALUES (?, ?, ?, ?) RETURNING id
# 2024-09-13 00:55:12,820 INFO sqlalchemy.engine.Engine [insertmanyvalues 49/56 (ordered; batch not supported)] ("S08-Mi cu<b>ña</b>do de<b>cí</b>a lo <b>mis</b>mo que tú. Se <mark class='V' title='&#034;fue&#034; au lieu de &#034;iba&#034;'>fue</mark> a vi<b>vir</b> al <b>pue</b>blo y al <b>ca</b>bo de seis <b>me</b>ses vol<b>vió</b>. ", None, 9, 13)
# 2024-09-13 00:55:12,821 INFO sqlalchemy.engine.Engine INSERT INTO marked_sentences (sentence, comment, line, session_id) VALUES (?, ?, ?, ?) RETURNING id
# 2024-09-13 00:55:12,821 INFO sqlalchemy.engine.Engine [insertmanyvalues 50/56 (ordered; batch not supported)] ("S10-Pues, que yo <b>se</b>pa, <mark class='E' title='&#034;tú no te\xa0pierdes\xa0nunca&#034; au lieu &#034;tú\xa0nunca te\xa0pierdes&#034;'>tú no te <b>pier</b>des <b>nun</b>ca</mark> las <b>fies</b>tas de tu <b>pue</b>blo, ¿no? ", None, 11, 13)
# 2024-09-13 00:55:12,821 INFO sqlalchemy.engine.Engine INSERT INTO marked_sentences (sentence, comment, line, session_id) VALUES (?, ?, ?, ?) RETURNING id
# 2024-09-13 00:55:12,821 INFO sqlalchemy.engine.Engine [insertmanyvalues 51/56 (ordered; batch not supported)] ("S13-Ah, por <b>cier</b>to <mark class='S' title='&#034;el&#034; au lieu de &#034;mi&#034;'>el</mark> <b>je</b>fe no me son<b>rió</b>. ", None, 14, 13)
# 2024-09-13 00:55:12,822 INFO sqlalchemy.engine.Engine INSERT INTO marked_sentences (sentence, comment, line, session_id) VALUES (?, ?, ?, ?) RETURNING id
# 2024-09-13 00:55:12,822 INFO sqlalchemy.engine.Engine [insertmanyvalues 52/56 (ordered; batch not supported)] ("T02-Que yo <b>se</b>pa, <b>nun</b>ca te <mark class='V' title='&#034;has perdido&#034; au lieu &#034;perdies&#034;'>has per<b>di</b>do</mark> las <b>fies</b>tas de tu <b>pue</b>blo. ", None, 17, 13)
# 2024-09-13 00:55:12,822 INFO sqlalchemy.engine.Engine INSERT INTO marked_sentences (sentence, comment, line, session_id) VALUES (?, ?, ?, ?) RETURNING id
# 2024-09-13 00:55:12,822 INFO sqlalchemy.engine.Engine [insertmanyvalues 53/56 (ordered; batch not supported)] ("S06-De<b>cí</b>an que <b>e</b>ra entrete<b>ni</b>do, y me ha pare<b>ci</b>do <mark class='B'>aburri<b>dí</b>simo</mark>. ", None, 7, 14)
# 2024-09-13 00:55:12,822 INFO sqlalchemy.engine.Engine INSERT INTO marked_sentences (sentence, comment, line, session_id) VALUES (?, ?, ?, ?) RETURNING id
# 2024-09-13 00:55:12,823 INFO sqlalchemy.engine.Engine [insertmanyvalues 54/56 (ordered; batch not supported)] ("S08-¿Me es<b>tá</b> <mark class='O' title='&#034;gastando&#034; et non pas &#034;haciendo&#034;'>gas<b>tan</b>do</mark> <b>u</b>na <b>bro</b>ma? ", None, 9, 14)
# 2024-09-13 00:55:12,823 INFO sqlalchemy.engine.Engine INSERT INTO marked_sentences (sentence, comment, line, session_id) VALUES (?, ?, ?, ?) RETURNING id
# 2024-09-13 00:55:12,823 INFO sqlalchemy.engine.Engine [insertmanyvalues 55/56 (ordered; batch not supported)] ("S09-En abso<b>lu</b>to. <b>Cuan</b>do un apa<b>ra</b>to no fun<b>cio</b>na, <b>pi</b>de que se lo a<b>rre</b>glen o que le <mark class='V' title='&#034;devuelvan&#034; est au subjonctif'>de<b>vuel</b>van</mark> el di<b>ne</b>ro, ¿no? ", None, 10, 14)
# 2024-09-13 00:55:12,823 INFO sqlalchemy.engine.Engine INSERT INTO marked_sentences (sentence, comment, line, session_id) VALUES (?, ?, ?, ?) RETURNING id
# 2024-09-13 00:55:12,823 INFO sqlalchemy.engine.Engine [insertmanyvalues 56/56 (ordered; batch not supported)] ("S12-Soy muy cuida<b>do</b>so con los <b>li</b>bros, <mark class='E' title='&#034;incluso&#034; au lieu de &#034;hasta&#034;'>in<b>clu</b>so</mark> con los que no me <b>gus</b>tan. ", None, 13, 14)
# 2024-09-13 00:55:12,824 INFO sqlalchemy.engine.Engine COMMIT
# 2024-09-13 00:55:12,825 INFO sqlalchemy.engine.Engine ROLLBACK

# %%
pam
# Out:
# 2024-09-13 00:55:23,339 INFO sqlalchemy.engine.Engine BEGIN (implicit)
# 2024-09-13 00:55:23,344 INFO sqlalchemy.engine.Engine SELECT user_account.id AS user_account_id, user_account.username AS user_account_username, user_account.password AS user_account_password, user_account.fullname AS user_account_fullname, user_account.email AS user_account_email
# FROM user_account
# WHERE user_account.id = ?
# 2024-09-13 00:55:23,345 INFO sqlalchemy.engine.Engine [generated in 0.00166s] (1,)
# username : 'pam', password : 'TOTO1234', full name :Pierre-Alain Moret

# %%
pam.sessions[0]
# Out:
# 2024-09-13 00:55:25,742 INFO sqlalchemy.engine.Engine SELECT lesson_sessions.id AS lesson_sessions_id, lesson_sessions.lesson AS lesson_sessions_lesson, lesson_sessions.date_time AS lesson_sessions_date_time, lesson_sessions.errors_number AS lesson_sessions_errors_number, lesson_sessions.user_id AS lesson_sessions_user_id
# FROM lesson_sessions
# WHERE ? = lesson_sessions.user_id
# 2024-09-13 00:55:25,743 INFO sqlalchemy.engine.Engine [cached since 12.99s ago] (1,)
# date time : datetime.datetime(2024, 9, 4, 22, 42, 30, 759328), lesson 50 errors number : 6

# %%
for lesson_session in pam.sessions:
    for sentence in lesson_session.errored_sentences:
        print(f"---------- lesson session id : {sentence.session_id} {sentence}")
# Out:
# 2024-09-13 00:55:29,099 INFO sqlalchemy.engine.Engine SELECT marked_sentences.id AS marked_sentences_id, marked_sentences.sentence AS marked_sentences_sentence, marked_sentences.comment AS marked_sentences_comment, marked_sentences.line AS marked_sentences_line, marked_sentences.session_id AS marked_sentences_session_id
# FROM marked_sentences
# WHERE ? = marked_sentences.session_id
# 2024-09-13 00:55:29,101 INFO sqlalchemy.engine.Engine [generated in 0.00138s] (1,)
# ---------- lesson session id : 1 Sentence(id=1, line=2, sentence ="S01-Fe<b>li</b>pe, <b>gua</b>po, <b>da</b>me diez <b>lon</b>chas de <mark class='A'>ja<b>món</b></mark><b></b> de york, por fa<b>vor</b>.", comment=None)
# ---------- lesson session id : 1 Sentence(id=2, line=5, sentence ="S04-Y <mark class='E'>yo</mark> se la di a <b>es</b>ta se<b>ño</b>ra.", comment=None)
# ---------- lesson session id : 1 Sentence(id=3, line=6, sentence ="S05-O <b>se</b>a, que a<b>ho</b>ra me <b>to</b>ca a mí, y us<b>ted</b> ¡a ha<b>cer</b> <b>co</b>la i<b>gual</b> que <mark class='O'>los</mark> de<b>más</b>!", comment=None)
# ---------- lesson session id : 1 Sentence(id=4, line=10, sentence ="S09-<b></b><mark class='E'><b>Ven</b>ga</mark>, <b>pa</b>se, <b>pe</b>ro que <b>se</b>a <b>rá</b>pido.", comment=None)
# ---------- lesson session id : 1 Sentence(id=5, line=15, sentence ="T01-Te <mark class='E'>pe<b>dí</b></mark><b></b> diez <b>lon</b>chas de ja<b>món</b> de York y <b>me</b>dio <b>ki</b>lo de <b>car</b>ne pi<b>ca</b>da.", comment=None)
# ---------- lesson session id : 1 Sentence(id=6, line=19, sentence ="T05-Me <b></b><mark class='G'><b>ha</b>cen</mark> <b>fal</b>ta <b>cua</b>tro <b>mus</b>los de <b>po</b>llo y dos pe<b>chu</b>gas.", comment=None)
# 2024-09-13 00:55:29,104 INFO sqlalchemy.engine.Engine SELECT marked_sentences.id AS marked_sentences_id, marked_sentences.sentence AS marked_sentences_sentence, marked_sentences.comment AS marked_sentences_comment, marked_sentences.line AS marked_sentences_line, marked_sentences.session_id AS marked_sentences_session_id
# FROM marked_sentences
# WHERE ? = marked_sentences.session_id
# 2024-09-13 00:55:29,104 INFO sqlalchemy.engine.Engine [cached since 0.005148s ago] (2,)
# 2024-09-13 00:55:29,106 INFO sqlalchemy.engine.Engine SELECT marked_sentences.id AS marked_sentences_id, marked_sentences.sentence AS marked_sentences_sentence, marked_sentences.comment AS marked_sentences_comment, marked_sentences.line AS marked_sentences_line, marked_sentences.session_id AS marked_sentences_session_id
# FROM marked_sentences
# WHERE ? = marked_sentences.session_id
# 2024-09-13 00:55:29,107 INFO sqlalchemy.engine.Engine [cached since 0.007425s ago] (3,)
# ---------- lesson session id : 3 Sentence(id=7, line=7, sentence ="S06-¡En <b>to</b>das <b>par</b>tes! Pri<b>me</b>ro en <mark class='O'>el</mark> Ca<b>ri</b>be.", comment=None)
# ---------- lesson session id : 3 Sentence(id=8, line=20, sentence ="T03-Via<b>ja</b>mos por <b>to</b>do el pa<b>ís</b> y <b></b><mark class='V'><b>fui</b>mos</mark> a <b>to</b>das <b>par</b>tes.", comment=None)
# ---------- lesson session id : 3 Sentence(id=9, line=21, sentence ="T04-No me gus<b>tó</b> Ciu<b>dad</b> de <b>Mé</b>xico, <b>pe</b>ro la <b>gen</b>te <mark class='V'>me pare<b>ció</b></mark><b></b> encanta<b>do</b>ra.", comment=None)
# 2024-09-13 00:55:29,108 INFO sqlalchemy.engine.Engine SELECT marked_sentences.id AS marked_sentences_id, marked_sentences.sentence AS marked_sentences_sentence, marked_sentences.comment AS marked_sentences_comment, marked_sentences.line AS marked_sentences_line, marked_sentences.session_id AS marked_sentences_session_id
# FROM marked_sentences
# WHERE ? = marked_sentences.session_id
# 2024-09-13 00:55:29,109 INFO sqlalchemy.engine.Engine [cached since 0.00931s ago] (4,)
# ---------- lesson session id : 4 Sentence(id=10, line=1, sentence ="S00-TITLE-¡<mark class='O' title='      '>Bienve<b>ni</b>da</mark>!", comment=None)
# ---------- lesson session id : 4 Sentence(id=11, line=5, sentence ="S04-No, no soy madri<b>le</b>ña. Soy <mark class='O' title='andaluza avec z'>anda<b>lu</b>za</mark>, de Se<b>vi</b>lla.", comment=None)
# ---------- lesson session id : 4 Sentence(id=12, line=6, sentence ="S05-¡Pues <mark class='O' title='bienvenida et non pas benvenida.'>bienve<b>ni</b>da</mark> a Ma<b>drid</b>, mo<b>re</b>na!", comment=None)
# 2024-09-13 00:55:29,110 INFO sqlalchemy.engine.Engine SELECT marked_sentences.id AS marked_sentences_id, marked_sentences.sentence AS marked_sentences_sentence, marked_sentences.comment AS marked_sentences_comment, marked_sentences.line AS marked_sentences_line, marked_sentences.session_id AS marked_sentences_session_id
# FROM marked_sentences
# WHERE ? = marked_sentences.session_id
# 2024-09-13 00:55:29,111 INFO sqlalchemy.engine.Engine [cached since 0.01149s ago] (5,)
# ---------- lesson session id : 5 Sentence(id=13, line=5, sentence ="S04-¿Choco<b>la</b>te pi<b>can</b>te? ¿No te <mark class='V' title='3ème personne du singulier du passé simple de dar : dio et non pas di.'>dio</mark> <b>as</b>co?", comment=None)
# ---------- lesson session id : 5 Sentence(id=14, line=9, sentence ="S08-¿<b>Pe</b>ro <b>nun</b>ca lo <mark class='V' title='3ème personne du pluriel du présent du verbe tomar.'><b>to</b>man</mark> <b></b><b>dul</b>ce?", comment=None)
# ---------- lesson session id : 5 Sentence(id=15, line=10, sentence ="S09-Sí, <b>cla</b>ro, hoy en <b>dí</b>a tam<b>bién</b> <mark class='G' title='cacao est complément d&#039;objet indirect donc=&#034;le&#034; et non pas &#034;lo&#034;'>le</mark> <b>e</b>chan a<b>zú</b>car,", comment=None)
# ---------- lesson session id : 5 Sentence(id=16, line=11, sentence ="S10-<b>pe</b>ro en la tradi<b>ción</b> in<b>dí</b>gena no se <mark class='G' title='cacao est complément d&#039;objet indirect donc=&#034;le&#034; et non pas &#034;lo&#034;'>le</mark> a<b>ña</b>de <b>le</b>che, <b>so</b>lo <b>a</b>gua.", comment=None)
# ---------- lesson session id : 5 Sentence(id=17, line=12, sentence ="S11-<b></b><mark class='O'><b></b><mark class='O' title='Meriendas est féminin, donc nuestras et non pas nuestros.'><b>Nues</b>tras</mark></mark> me<b>rien</b>das sí que las e<b>cha</b>ba de <b>me</b>nos un buen choco<b>la</b>te con <b>chu</b>rros. . .", comment=None)
# 2024-09-13 00:55:29,113 INFO sqlalchemy.engine.Engine SELECT marked_sentences.id AS marked_sentences_id, marked_sentences.sentence AS marked_sentences_sentence, marked_sentences.comment AS marked_sentences_comment, marked_sentences.line AS marked_sentences_line, marked_sentences.session_id AS marked_sentences_session_id
# FROM marked_sentences
# WHERE ? = marked_sentences.session_id
# 2024-09-13 00:55:29,113 INFO sqlalchemy.engine.Engine [cached since 0.01388s ago] (6,)
# ---------- lesson session id : 6 Sentence(id=18, line=2, sentence ="S01-Cris<b>tó</b>bal Co<b>l<mark class='A' title='      '>ó</mark>n</b> sa<b>bí</b>a que la <b>Tie</b>rra <b>e</b>ra re<b>don</b>da y <b>qui</b>so alcan<b>zar</b> las <b>In</b>dias <b>yen</b>do <b>siem</b>pre <b></b><mark class='O' title='hacia et non pas hasta'><b>ha</b>cia</mark> el o<b>es</b>te.", comment=None)
# ---------- lesson session id : 6 Sentence(id=19, line=8, sentence ="S07-y <mark class='V' title='Passé simple irrégulier de traer au passé simple dont le radical devient traj'>tra<b>je</b>ron</mark> <b></b><mark class='G'><b></b><mark class='G' title='Au pluriel'><b>o</b>tros <b>tan</b>tos</mark></mark> a Eu<b>ro</b>pa.", comment=None)
# ---------- lesson session id : 6 Sentence(id=20, line=11, sentence ="S10-<b>nues</b>tros <b>pos</b>tres sin vai<b>ni</b>lla o los <b>Pie</b>les <b></b><mark class='O' title='Terminaison en a de Roja'><b>Ro</b>jas</mark> sin ca<b>ba</b>llos?", comment=None)
# ---------- lesson session id : 6 Sentence(id=21, line=12, sentence ="S11-Un <b>nue</b>vo <b>mun</b>do <mark class='V' title='nació\xa0et non pas naci'>na<b>ció</b></mark><b></b> el 12 de oc<b>tu</b>bre de 1492 mil cuatro<b>cien</b>tos no<b>ven</b>ta y dos.", comment=None)
# 2024-09-13 00:55:29,115 INFO sqlalchemy.engine.Engine SELECT marked_sentences.id AS marked_sentences_id, marked_sentences.sentence AS marked_sentences_sentence, marked_sentences.comment AS marked_sentences_comment, marked_sentences.line AS marked_sentences_line, marked_sentences.session_id AS marked_sentences_session_id
# FROM marked_sentences
# WHERE ? = marked_sentences.session_id
# 2024-09-13 00:55:29,115 INFO sqlalchemy.engine.Engine [cached since 0.01604s ago] (7,)
# 2024-09-13 00:55:29,117 INFO sqlalchemy.engine.Engine SELECT marked_sentences.id AS marked_sentences_id, marked_sentences.sentence AS marked_sentences_sentence, marked_sentences.comment AS marked_sentences_comment, marked_sentences.line AS marked_sentences_line, marked_sentences.session_id AS marked_sentences_session_id
# FROM marked_sentences
# WHERE ? = marked_sentences.session_id
# 2024-09-13 00:55:29,117 INFO sqlalchemy.engine.Engine [cached since 0.01821s ago] (8,)
# ---------- lesson session id : 8 Sentence(id=22, line=2, sentence ="S01-¡<mark class='E' title='&#034;Ya&#034; está au lieu de &#034;Ya&#034;'>Ya</mark> <b></b><mark class='O' title='&#034;fue&#034; au lieu de &#034;hice&#034;'><b>hi</b>ce</mark> la entre<b>vis</b>ta!", comment=None)
# ---------- lesson session id : 8 Sentence(id=23, line=15, sentence ="S14-Por Dios ¿Y qué <mark class='V' title='3ème du singulier du assé simple de pasar.'>pa<b>só</b></mark><b></b>?", comment=None)
# ---------- lesson session id : 8 Sentence(id=24, line=17, sentence ="S16-Te lo <b></b><mark class='V' title='&#034;digo&#034; et non pas &#034;dicho&#034;'><b>di</b>go</mark> el <b>pues</b>to es <b>mí</b>o.", comment=None)
# ---------- lesson session id : 8 Sentence(id=25, line=19, sentence ="T01-He te<b>ni</b>do <b>suer</b>te, la entre<b>vis</b>ta <mark class='E' title='&#034;me fue&#034; et non pas &#034;se pasó&#034;'>me fue</mark> muy bien y he conse<b>gui</b>do el <b>pues</b>to.", comment=None)
# 2024-09-13 00:55:29,119 INFO sqlalchemy.engine.Engine SELECT marked_sentences.id AS marked_sentences_id, marked_sentences.sentence AS marked_sentences_sentence, marked_sentences.comment AS marked_sentences_comment, marked_sentences.line AS marked_sentences_line, marked_sentences.session_id AS marked_sentences_session_id
# FROM marked_sentences
# WHERE ? = marked_sentences.session_id
# 2024-09-13 00:55:29,119 INFO sqlalchemy.engine.Engine [cached since 0.01992s ago] (9,)
# 2024-09-13 00:55:29,120 INFO sqlalchemy.engine.Engine SELECT marked_sentences.id AS marked_sentences_id, marked_sentences.sentence AS marked_sentences_sentence, marked_sentences.comment AS marked_sentences_comment, marked_sentences.line AS marked_sentences_line, marked_sentences.session_id AS marked_sentences_session_id
# FROM marked_sentences
# WHERE ? = marked_sentences.session_id
# 2024-09-13 00:55:29,121 INFO sqlalchemy.engine.Engine [cached since 0.02141s ago] (10,)
# ---------- lesson session id : 10 Sentence(id=26, line=3, sentence ="S02-<mark class='G' title='Cazadora est féminin, donc le pronom est &#034;la&#034;'>La</mark> com<b>pré</b> a<b>yer</b> en el <b>Ras</b>tro, no <b>pu</b>de resis<b>tir</b>me.", comment=None)
# ---------- lesson session id : 10 Sentence(id=27, line=4, sentence ="S03-<b>Tu</b>ve que regate<b>ar</b> un buen <b>ra</b>to, el <b>tí</b>o no <mark class='V' title='Querer à l&#039;imparfait et non pas au passé simple.'>que<b>rí</b>a</mark> ba<b>jar</b> el <b>pre</b>cio.", comment=None)
# ---------- lesson session id : 10 Sentence(id=28, line=6, sentence ="S05-que no <b>i</b>ba a encon<b>trar</b> <b></b><mark class='G' title='Cazadora féminin, donc &#034;otra&#034; et non pas &#034;otro&#034;'><b>o</b>tra</mark> i<b>gual</b>.", comment=None)
# ---------- lesson session id : 10 Sentence(id=29, line=7, sentence ="S06-Le pa<b>gué</b> la mi<b>tad</b> de lo que <mark class='O' title='&#034;pedir&#034; et non pas &#034;preguntar&#034;. De plus à l&#039;imparfait et non pas au passé simple.'>pe<b>dí</b>a</mark> al prin<b>ci</b>pio, <mark class='O' title='&#034;doscientos&#034; en un seul mot.'>dos<b>cien</b>tos</mark> <b>eu</b>ros. ¡<b>U</b>na <b>gan</b>ga!", comment=None)
# ---------- lesson session id : 10 Sentence(id=30, line=13, sentence ="S12-No <b>pe</b>sa <b>mu</b>cho, pa<b>re</b>ce <b>fal</b>sa. . . ¿<mark class='E' title='&#034;De verdad&#034; placé avant crees pour insister dessus.'>De ver<b>dad</b></mark><b></b> <b>cre</b>es que es de <b>cue</b>ro?", comment=None)
# ---------- lesson session id : 10 Sentence(id=31, line=15, sentence ="S14-A<b>mi</b>go <b>mí</b>o, me pa<b>re</b>ce que te han <b>da</b>do <b>ga</b>to por <b></b><mark class='O' title='&#034;liebre&#034; et non pas &#034;liebro&#034;'><b>lie</b>bre</mark>", comment=None)
# ---------- lesson session id : 10 Sentence(id=32, line=18, sentence ="T02-<b></b><mark class='O' title='&#034;Trater&#034; et non pas &#034;probar&#034;'><b>Tra</b>té</mark> de regate<b>ar</b>, <b>pe</b>ro el <b>tí</b>o no <b>qui</b>so ba<b>jar</b> el <b>pre</b>cio.", comment=None)
# ---------- lesson session id : 10 Sentence(id=33, line=19, sentence ="T03-<b>Tu</b>ve que pa<b>gar</b> lo que <mark class='V' title='Imparfait et non pas passé simple.'>pe<b>dí</b>a</mark> al prin<b>ci</b>pio.", comment=None)
# 2024-09-13 00:55:29,122 INFO sqlalchemy.engine.Engine SELECT marked_sentences.id AS marked_sentences_id, marked_sentences.sentence AS marked_sentences_sentence, marked_sentences.comment AS marked_sentences_comment, marked_sentences.line AS marked_sentences_line, marked_sentences.session_id AS marked_sentences_session_id
# FROM marked_sentences
# WHERE ? = marked_sentences.session_id
# 2024-09-13 00:55:29,122 INFO sqlalchemy.engine.Engine [cached since 0.02315s ago] (11,)
# ---------- lesson session id : 11 Sentence(id=34, line=3, sentence ="S02-Es<b>toy</b> conven<b>ci</b>do de que sí. Pa<b>sé</b> la entre<b>vis</b>ta a<b>yer</b> y <b>cre</b>o que <b>su</b>pe contes<b>tar</b> a <b>to</b>do lo que me <mark class='V' title='Passé simple 3ème personne des verbes en -ar : terminaison -aron'>pregun<b>ta</b>ron</mark>.", comment=None)
# ---------- lesson session id : 11 Sentence(id=35, line=4, sentence ="S03-¡Enhora<b>bue</b>na! <b>Pe</b>ro, <b>di</b>me, ¿qué <b>ti</b>po de pre<b>gun</b>tas te <mark class='V' title='Passé simple 3ème personne des verbes en -er et ir : terminaison -ieron'>hi<b>cie</b>ron</mark>? A <b>ve</b>ces hay <b>tram</b>pas en las entre<b>vis</b>tas, ¿<b>sa</b>bes?", comment=None)
# ---------- lesson session id : 11 Sentence(id=36, line=5, sentence ="S04-¡<mark class='E' title='&#034;En absoluto&#034; convient aussi.'>Qué va!</mark> <b>Fue</b>ron la mar de a<b>ma</b>bles y edu<b>ca</b>dos.", comment=None)
# ---------- lesson session id : 11 Sentence(id=37, line=6, sentence ="S05-Me di<b>je</b>ron que a lo me<b>jor</b> <b>i</b>ban a man<b>dar</b>me a traba<b>jar</b> a Ciu<b>dad</b> de <b>Mé</b>xico y qui<b>sier</b>on sa<b>ber</b> si ya <mark class='V' title='Imparfait &#034;había&#034; et non pas le passé simple'>ha<b>bí</b>a</mark> es<b>ta</b>do a<b>llí</b>.", comment=None)
# ---------- lesson session id : 11 Sentence(id=38, line=7, sentence ="S06-Les contes<b>té</b> que por su<b>pues</b>to cono<b>cí</b>a Latinoa<b>mé</b>rica y nos <mark class='V' title='&#034;pusimos&#034;\xa0passé simple de poner'>pu<b>si</b>mos</mark> a ha<b>blar</b> de la <b>vi</b>da en <b>Mé</b>xico.", comment=None)
# ---------- lesson session id : 11 Sentence(id=39, line=8, sentence ="S07-Les con<b>té</b> que ha<b>bí</b>a es<b>ta</b>do en <b>to</b>das <b></b><mark class='V' title='&#034;partes&#034; et non pas &#034;partas&#034;'><b>par</b>tes</mark> y que <b>has</b>ta ha<b>bí</b>a rega<b>tea</b>do el <b>pre</b>cio de un jer<b>sey</b> muy <b>chu</b>lo en un mer<b>ca</b>do in<b>dí</b>gena.", comment=None)
# ---------- lesson session id : 11 Sentence(id=40, line=9, sentence ="S08-¿Te atre<b>vis</b>te a <mark class='G' title='&#034;contarles&#034; et non pas &#034;les contar&#034;'>con<b>tar</b>les</mark> <b>e</b>so?", comment=None)
# ---------- lesson session id : 11 Sentence(id=41, line=10, sentence ="S09-Sí, ¡les <b></b><mark class='V' title='&#034;hizo&#034; passé simple et non imparfait'><b>hi</b>zo</mark> <b>mu</b>cha <b>gra</b>cia!", comment=None)
# ---------- lesson session id : 11 Sentence(id=42, line=11, sentence ="S10-¿Y les <mark class='V' title='&#034;dijiste&#034; passé simple et non imparfait'>di<b>jis</b>te</mark> tam<b>bién</b> que te ha<b>bí</b>a <b>da</b>do <b>as</b>co la co<b>ci</b>na mexi<b>ca</b>na, que no la ha<b>bí</b>as pro<b>ba</b>do y que e<b>cha</b>bas de <b>me</b>nos las me<b>rien</b>das <mark class='O' title='&#034;españolas&#034; acord au féminin'>espa<b>ño</b>las</mark>?", comment=None)
# ---------- lesson session id : 11 Sentence(id=43, line=12, sentence ="S11-No, <b></b><mark class='E' title='Formule courrante'><b>e</b>so sí</mark> que no lo <b>di</b>je", comment=None)
# 2024-09-13 00:55:29,124 INFO sqlalchemy.engine.Engine SELECT marked_sentences.id AS marked_sentences_id, marked_sentences.sentence AS marked_sentences_sentence, marked_sentences.comment AS marked_sentences_comment, marked_sentences.line AS marked_sentences_line, marked_sentences.session_id AS marked_sentences_session_id
# FROM marked_sentences
# WHERE ? = marked_sentences.session_id
# 2024-09-13 00:55:29,124 INFO sqlalchemy.engine.Engine [cached since 0.02472s ago] (12,)
# ---------- lesson session id : 12 Sentence(id=44, line=4, sentence ="S03-Muy bien, <b>pe</b>ro ¡<b></b><mark class='A' title='      '><b>há</b>blame</mark> de tú, por fa<b>vor</b>!", comment=None)
# ---------- lesson session id : 12 Sentence(id=45, line=6, sentence ="S05-<mark class='O' title='&#034;Encantada&#034; et non pas &#034;Encantadora&#034;'>Encan<b>ta</b>da</mark>. Me <b>lla</b>mo <b>Mon</b>tse. ¿<b>E</b>res de Barce<b>lo</b>na?", comment=None)
# 2024-09-13 00:55:29,125 INFO sqlalchemy.engine.Engine SELECT marked_sentences.id AS marked_sentences_id, marked_sentences.sentence AS marked_sentences_sentence, marked_sentences.comment AS marked_sentences_comment, marked_sentences.line AS marked_sentences_line, marked_sentences.session_id AS marked_sentences_session_id
# FROM marked_sentences
# WHERE ? = marked_sentences.session_id
# 2024-09-13 00:55:29,125 INFO sqlalchemy.engine.Engine [cached since 0.02595s ago] (13,)
# ---------- lesson session id : 13 Sentence(id=46, line=2, sentence ="S01-<mark class='O' title='&#034;Anoche&#034; et non pas &#034;anteanoche&#034; qui signifie avant hier soir'>A<b>no</b>che</mark> <b>tu</b>ve un <b>sue</b>ño ex<b>tra</b>ño. ", comment=None)
# ---------- lesson session id : 13 Sentence(id=47, line=6, sentence ='S05-¿Por qué? ¿Tú no hay <b>dí</b>as en que es<b>tás</b> can<b>sa</b>do del <b></b><b>trá</b>fico, del <b>rui</b>do y de los a<b>tas</b>cos? ', comment=None)
# ---------- lesson session id : 13 Sentence(id=48, line=8, sentence ="S07-<mark class='E' title='&#034;quizás&#034;\xa0et &#034;tal vez&#034; sont équivalents'>qui<b>zás</b></mark><b></b> <b>ha</b>ya <b>me</b>nos contamina<b>ción</b>, <b>pe</b>ro te a<b>bu</b>rres <b>co</b>mo <b>u</b>na <b>os</b>tra. ", comment=None)
# ---------- lesson session id : 13 Sentence(id=49, line=9, sentence ="S08-Mi cu<b>ña</b>do de<b>cí</b>a lo <b>mis</b>mo que tú. Se <mark class='V' title='&#034;fue&#034; au lieu de &#034;iba&#034;'>fue</mark> a vi<b>vir</b> al <b>pue</b>blo y al <b>ca</b>bo de seis <b>me</b>ses vol<b>vió</b>. ", comment=None)
# ---------- lesson session id : 13 Sentence(id=50, line=11, sentence ="S10-Pues, que yo <b>se</b>pa, <mark class='E' title='&#034;tú no te\xa0pierdes\xa0nunca&#034; au lieu &#034;tú\xa0nunca te\xa0pierdes&#034;'>tú no te <b>pier</b>des <b>nun</b>ca</mark> las <b>fies</b>tas de tu <b>pue</b>blo, ¿no? ", comment=None)
# ---------- lesson session id : 13 Sentence(id=51, line=14, sentence ="S13-Ah, por <b>cier</b>to <mark class='S' title='&#034;el&#034; au lieu de &#034;mi&#034;'>el</mark> <b>je</b>fe no me son<b>rió</b>. ", comment=None)
# ---------- lesson session id : 13 Sentence(id=52, line=17, sentence ="T02-Que yo <b>se</b>pa, <b>nun</b>ca te <mark class='V' title='&#034;has perdido&#034; au lieu &#034;perdies&#034;'>has per<b>di</b>do</mark> las <b>fies</b>tas de tu <b>pue</b>blo. ", comment=None)
# 2024-09-13 00:55:29,126 INFO sqlalchemy.engine.Engine SELECT marked_sentences.id AS marked_sentences_id, marked_sentences.sentence AS marked_sentences_sentence, marked_sentences.comment AS marked_sentences_comment, marked_sentences.line AS marked_sentences_line, marked_sentences.session_id AS marked_sentences_session_id
# FROM marked_sentences
# WHERE ? = marked_sentences.session_id
# 2024-09-13 00:55:29,126 INFO sqlalchemy.engine.Engine [cached since 0.02719s ago] (14,)
# ---------- lesson session id : 14 Sentence(id=53, line=7, sentence ="S06-De<b>cí</b>an que <b>e</b>ra entrete<b>ni</b>do, y me ha pare<b>ci</b>do <mark class='B'>aburri<b>dí</b>simo</mark>. ", comment=None)
# ---------- lesson session id : 14 Sentence(id=54, line=9, sentence ="S08-¿Me es<b>tá</b> <mark class='O' title='&#034;gastando&#034; et non pas &#034;haciendo&#034;'>gas<b>tan</b>do</mark> <b>u</b>na <b>bro</b>ma? ", comment=None)
# ---------- lesson session id : 14 Sentence(id=55, line=10, sentence ="S09-En abso<b>lu</b>to. <b>Cuan</b>do un apa<b>ra</b>to no fun<b>cio</b>na, <b>pi</b>de que se lo a<b>rre</b>glen o que le <mark class='V' title='&#034;devuelvan&#034; est au subjonctif'>de<b>vuel</b>van</mark> el di<b>ne</b>ro, ¿no? ", comment=None)
# ---------- lesson session id : 14 Sentence(id=56, line=13, sentence ="S12-Soy muy cuida<b>do</b>so con los <b>li</b>bros, <mark class='E' title='&#034;incluso&#034; au lieu de &#034;hasta&#034;'>in<b>clu</b>so</mark> con los que no me <b>gus</b>tan. ", comment=None)
