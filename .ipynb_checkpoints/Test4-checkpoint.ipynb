# %%
s="""/Users/pam/Library/pnpm:/opt/homebrew/Cellar/pyenv-virtualenv/1.2.1/shims:/Users/pam/.pyenv/shims:/Users/pam/.pyenv/bin:/opt/homebrew/Cellar/pyenv-virtualenv/1.2.1/shims:/Users/pam/.pyenv/bin:/Users/pam/bin:/opt/homebrew/bin:/opt/homebrew/sbin:/Users/pam/emsdk:/Users/pam/emsdk/upstream/emscripten:/Users/pam/emsdk/node/14.18.2_64bit/bin:/usr/local/bin:/System/Cryptexes/App/usr/bin:/usr/bin:/bin:/usr/sbin:/sbin:/var/run/com.apple.security.cryptexd/codex.system/bootstrap/usr/local/bin:/var/run/com.apple.security.cryptexd/codex.system/bootstrap/usr/bin:/var/run/com.apple.security.cryptexd/codex.system/bootstrap/usr/appleinternal/bin:/Library/TeX/texbin:/Users/pam/.cargo/bin:/Applications/Visual Studio Code.app/Contents/Resources/app/bin:/Applications/Visual Studio Code.app/Contents/Resources/app/bin:/Applications/Visual Studio Code.app/Contents/Resources/app/bin"""

# %%
s
# Out:
# '/Users/pam/Library/pnpm:/opt/homebrew/Cellar/pyenv-virtualenv/1.2.1/shims:/Users/pam/.pyenv/shims:/Users/pam/.pyenv/bin:/opt/homebrew/Cellar/pyenv-virtualenv/1.2.1/shims:/Users/pam/.pyenv/bin:/Users/pam/bin:/opt/homebrew/bin:/opt/homebrew/sbin:/Users/pam/emsdk:/Users/pam/emsdk/upstream/emscripten:/Users/pam/emsdk/node/14.18.2_64bit/bin:/usr/local/bin:/System/Cryptexes/App/usr/bin:/usr/bin:/bin:/usr/sbin:/sbin:/var/run/com.apple.security.cryptexd/codex.system/bootstrap/usr/local/bin:/var/run/com.apple.security.cryptexd/codex.system/bootstrap/usr/bin:/var/run/com.apple.security.cryptexd/codex.system/bootstrap/usr/appleinternal/bin:/Library/TeX/texbin:/Users/pam/.cargo/bin:/Applications/Visual Studio Code.app/Contents/Resources/app/bin:/Applications/Visual Studio Code.app/Contents/Resources/app/bin:/Applications/Visual Studio Code.app/Contents/Resources/app/bin'

# %%
s.find('shims')
# Out:
# 68

# %%
fn = "application_data_paths.yaml"

import yaml

with open(fn) as f:
    data = yaml.load(f, Loader=yaml.SafeLoader)
print(data)
# Out:
# {'UserName': 'GeeksforGeeks', 'Password': 'GFG@123', 'Phone': 1234567890, 'Website': 'geeksforgeeks.org', 'Skills': '-Python -SQL -Django -JavaScript'}

# %%
import paths
# Out:
# {'UserName': 'GeeksforGeeks', 'Password': 'GFG@123', 'Phone': 1234567890, 'Website': 'geeksforgeeks.org', 'Skills': '-Python -SQL -Django -JavaScript'}

# %%
from paths import get_path

database_name = get_path('database_name')
# Out:
# {'database_name': 'sqlite:///Users/pam/assimil/db/assimil_spanish.db', 'lessons_directory': '/Users/pam/assimil/Sentences', 'html_lessons_directory': '/Users/pam/assimil/lessons/html', 'databases_directory': '/Users/pam/assimil/db', 'word_dict_logfilename': '/Users/pam/assimil/word_dict_logfile.log', 'UserName': 'GeeksforGeeks', 'Password': 'GFG@123', 'Phone': 1234567890, 'Website': 'geeksforgeeks.org', 'Skills': '-Python -SQL -Django -JavaScript'}

# %%
database_name.find('Users')
# Out:
# 10

# %%
open(database_name[9:])
# Out:
# <_io.TextIOWrapper name='/Users/pam/assimil/db/assimil_spanish.db' mode='r' encoding='UTF-8'>

# %%
from sqlalchemy import ForeignKey, select, String, and_, desc
from sqlalchemy.orm import DeclarativeBase
from sqlalchemy.orm import Mapped
from sqlalchemy.orm import mapped_column
from sqlalchemy.orm import relationship
from sqlalchemy.sql import func
from sqlalchemy import create_engine
from sqlalchemy.orm import Session
from paths import get_path

class Base(DeclarativeBase):
    pass

def get_database_engine(name, echo=True):
    engine = create_engine(name, echo = echo)   
    Base.metadata.create_all(engine) 
    return engine

database_name = get_path('database_name')
database_name = 'sqlite:////Users/pam/assimil/db/assimil_spanish.db'

global engine
engine = get_database_engine(database_name, False)

# %%
import database

# %%
from database import get_database_engine
get_database_engine(

# %%
import yaml

# %%
from tonic_accent import global_word_dict
# Out:
# {'database_name': 'sqlite:////Users/pam/assimil/db/assimil_spanish.db', 'lessons_directory': '/Users/pam/AssimilAudio/Sentences', 'html_lessons_directory': '/Users/pam/assimil/lessons/html', 'databases_directory': '/Users/pam/assimil/db', 'word_dict_logfilename': '/Users/pam/assimil/word_dict_logfile.log'}

# %%
import time
ti = time.time()
from tonic_accent import global_word_dict
tf = time.time()
print(f"Time to load global_word_dict : {tf-ti}")
# Out:
# {'database_name': 'sqlite:////Users/pam/assimil/db/assimil_spanish.db', 'lessons_directory': '/Users/pam/AssimilAudio/Sentences', 'html_lessons_directory': '/Users/pam/assimil/lessons/html', 'databases_directory': '/Users/pam/assimil/db', 'word_dict_logfilename': '/Users/pam/assimil/word_dict_logfile.log'}
# Time to load global_word_dict : 0.33871889114379883

# %%
print(yaml.safe_dump(global_word_dict))
# Out:
# '000':
# - - '000'
#   - false
# '1':
# - - '1'
#   - false
# '10':
# - - '10'
#   - false
# '12':
# - - '12'
#   - false
# '13':
# - - '13'
#   - false
# '1325':
# - - '1325'
#   - false
# '1492':
# - - '1492'
#   - false
# '15':
# - - '15'
#   - false
# '1519':
# - - '1519'
#   - false
# '2':
# - - '2'
#   - false
# '2000':
# - - '2000'
#   - false
# '25':
# - - '25'
#   - false
# '250':
# - - '250'
#   - false
# "2\xB0":
# - - "2\xB0"
#   - false
# '3':
# - - '3'
#   - false
# '31':
# - - '31'
#   - false
# '34':
# - - '34'
#   - false
# '38':
# - - '38'
#   - false
# '4':
# - - '4'
#   - false
# '40':
# - - '40'
#   - false
# '42':
# - - '42'
#   - false
# '43':
# - - '43'
#   - false
# '50':
# - - '50'
#   - false
# '6':
# - - '6'
#   - false
# '7':
# - - '7'
#   - false
# '70':
# - - '70'
#   - false
# '718':
# - - '718'
#   - false
# '780':
# - - '780'
#   - false
# '8':
# - - '8'
#   - false
# '87':
# - - '87'
#   - false
# '900':
# - - '900'
#   - false
# a:
# - - a
# ...

# %%
f=open('global_word_dict.yaml', 'w')

# %%
f.write(yaml.safe_dump(global_word_dict))
# Out:
# 184367

# %%
f.close()

# %%
import time

# %%
ti = time.time()
f=open('global_word_dict.yaml')
global_word_dict2 = yaml.safe_load(f.read())
tf = time.time()
print(f"time to load global_word_dict form yaml file : {tf-ti}")
# Out:
# time to load global_word_dict form yaml file : 0.593533992767334

# %%
import yaml
try:
    from yaml import CSafeLoader as SafeLoader
except ImportError:
    from yaml import SafeLoader

import time
ti = time.time()
f=open('global_word_dict.yaml')
global_word_dict2 = yaml.load(f.read(), SafeLoader)
tf = time.time()
print(f"time to load global_word_dict form yaml file : {tf-ti}")
# Out:
# time to load global_word_dict form yaml file : 0.1335752010345459

# %%
ord("\xB0")
# Out:
# 176

# %%
chr(176)
# Out:
# '°'

# %%
global_word_dict2["aburrid\xEDsimo"]
# Out:
# [['aburri', False], ['dí', True], ['simo', False]]

# %%
global_word_dict2["a"]
# Out:
# [['a', False]]

# %%
for word in global_word_dict2:
    if len(global_word_dict2[word]) == 1:
        print(word, global_word_dict2[word])
# Out:
# 000 [['000', False]]
# 1 [['1', False]]
# 10 [['10', False]]
# 12 [['12', False]]
# 13 [['13', False]]
# 1325 [['1325', False]]
# 1492 [['1492', False]]
# 15 [['15', False]]
# 1519 [['1519', False]]
# 2 [['2', False]]
# 2000 [['2000', False]]
# 25 [['25', False]]
# 250 [['250', False]]
# 2° [['2°', False]]
# 3 [['3', False]]
# 31 [['31', False]]
# 34 [['34', False]]
# 38 [['38', False]]
# 4 [['4', False]]
# 40 [['40', False]]
# 42 [['42', False]]
# 43 [['43', False]]
# 50 [['50', False]]
# 6 [['6', False]]
# 7 [['7', False]]
# 70 [['70', False]]
# 718 [['718', False]]
# 780 [['780', False]]
# 8 [['8', False]]
# 87 [['87', False]]
# 900 [['900', False]]
# a [['a', False]]
# abrir [['abrir', False]]
# ah [['ah', False]]
# al [['al', False]]
# aprobé [['aprobé', False]]
# ay [['ay', False]]
# aún [['aún', False]]
# b [['b', False]]
# bar [['bar', False]]
# bien [['bien', False]]
# buen [['buen', False]]
# busco [['busco', False]]
# c [['c', False]]
# chat [['chat', False]]
# ...

# %%
from tonic_accent import fill_word_index_dict_from_html_files, get_html_lesson_list, get_word_index_dict

# %%
word_index_dict = get_word_index_dict()

# %%
word_index_dict["busco"]
# Out:
# [(62, 4)]

# %%
global_word_dict2["busco"]
# Out:
# [['bus', True], ['co', False]]

# %%
from maintenance import database as db_mnt
# Out:
# {'database_name': 'sqlite:////Users/pam/assimil/db/assimil_spanish.db', 'lessons_directory': '/Users/pam/AssimilAudio/Sentences', 'html_lessons_directory': '/Users/pam/assimil/lessons/html', 'databases_directory': '/Users/pam/assimil/db', 'word_dict_logfilename': '/Users/pam/assimil/word_dict_logfile.log'}

# %%
from sqlalchemy.orm import Session
from sqlalchemy import select, and_
from database import Paragraph, engine, update_paragraph, get_paragraphs

# %%
with Session(engine) as session:
    with Session(db_mnt.engine) as db_mnt_session:
        stmt = select(Paragraph)
        for entry in session.scalars(stmt):
            para = db_mnt.Paragraph(
                section = entry.section,
                lesson_nb = entry.lesson_nb,
                line_nb = entry.line_nb,
                paragraph = entry.paragraph,
                translation = entry.translation,
                has_dash_dialogue = entry.has_dash_dialogue,
                data = entry.data
            )
            db_mnt_session.add(para)
        db_mnt_session.commit()

# %%
with Session(engine) as session:
    with Session(db_mnt.engine) as db_mnt_session:
        stmt = select(Paragraph)
        for entry in session.scalars(stmt):
            para = db_mnt.Paragraph(
                section = entry.section,
                lesson_nb = entry.lesson_nb,
                line_nb = entry.line_nb,
                paragraph = entry.paragraph,
                translation = entry.translation,
                has_dash_dialogue = entry.has_dash_dialogue,
                data = entry.data
            )
            db_mnt_session.add(para)
        db_mnt_session.commit()

# %%
from database import User
stmt = select(User)
with Session(engine) as session:
    with Session(db_mnt.engine) as db_mnt_session:
        for entry in session.scalars(stmt):
            user = db_mnt.User(
                username = entry.username,
                password = entry.password,
                fullname = entry.fullname,
                email = entry.email,
                parameters = entry.parameters,
                parameters_version = entry.parameters_version,
                sessions = []
            )
            db_mnt_session.add(user)
        db_mnt_session.commit()
        print(entry.sessions)
# Out:
# [date time : datetime.datetime(2024, 9, 4, 23, 2, 0, 780033), lesson 1 errors number : 0, date time : datetime.datetime(2024, 9, 5, 9, 19, 11, 922138), lesson 51 errors number : 3, date time : datetime.datetime(2024, 9, 6, 23, 54, 35, 589923), lesson 3 errors number : 3, date time : datetime.datetime(2024, 9, 6, 23, 30, 29, 589456), lesson 52 errors number : 5, date time : datetime.datetime(2024, 9, 7, 15, 38, 11, 304630), lesson 53 errors number : 4, date time : datetime.datetime(2024, 9, 7, 15, 47, 54, 852500), lesson 4 errors number : 0, date time : datetime.datetime(2024, 9, 9, 0, 33, 9, 558002), lesson 54 errors number : 4, date time : datetime.datetime(2024, 9, 9, 0, 37, 30, 688736), lesson 5 errors number : 0, date time : datetime.datetime(2024, 9, 9, 23, 49, 20, 733862), lesson 55 errors number : 8, date time : datetime.datetime(2024, 9, 10, 11, 28, 32, 681006), lesson 56 errors number : 10, date time : datetime.datetime(2024, 9, 10, 11, 34, 52, 105091), lesson 7 errors numbe
# ...

# %%
pam = Session(db_mnt.engine).scalars(select(db_mnt.User)).one()
pam.email, pam.fullname
for lesson_session in pam.sessions:
    for ep in lesson_session.errored_paragraphs:
        print(ep)
# Out:
# Paragraph(id=1, line=7, paragraph ="¡En <b>to</b>das <b>par</b>tes! Pri<b>me</b>ro en <mark class='O'>el</mark> Ca<b>ri</b>be.", comment=None)
# Paragraph(id=2, line=20, paragraph ="Via<b>ja</b>mos por <b>to</b>do el pa<b>ís</b> y <b></b><mark class='V'><b>fui</b>mos</mark> a <b>to</b>das <b>par</b>tes.", comment=None)
# Paragraph(id=3, line=21, paragraph ="No me gus<b>tó</b> Ciu<b>dad</b> de <b>Mé</b>xico, <b>pe</b>ro la <b>gen</b>te <mark class='V'>me pare<b>ció</b></mark><b></b> encanta<b>do</b>ra.", comment=None)
# Paragraph(id=4, line=1, paragraph ="¡<mark class='O' title='      '>Bienve<b>ni</b>da</mark>!", comment=None)
# Paragraph(id=5, line=5, paragraph ="No, no soy madri<b>le</b>ña. Soy <mark class='O' title='andaluza avec z'>anda<b>lu</b>za</mark>, de Se<b>vi</b>lla.", comment=None)
# Paragraph(id=6, line=6, paragraph ="¡Pues <mark class='O' title='bienvenida et non pas benvenida.'>bienve<b>ni</b>da</mark> a Ma<b>drid</b>, mo<b>re</b>na!", comment=None)
# ...

# %%
from database import LessonSession
stmt = select(LessonSession)
with Session(engine) as session:
    with Session(db_mnt.engine) as db_mnt_session:
        for entry in session.scalars(stmt):
            lesson_session = db_mnt.LessonSession(
                user = pam,
                lesson = entry.lesson,
                date_time = entry.date_time,
                errors_number = entry.errors_number,
                errored_paragraphs = []
            )
            for ep in entry.errored_sentences:
                errored_paragraph = db_mnt.MarkedParagraph(
                    paragraph = ep.sentence,
                    comment = ep.comment,
                    line = ep.line,
                    session = lesson_session
                )
                lesson_session.errored_paragraphs.append(errored_paragraph)
            db_mnt_session.add(lesson_session)
        db_mnt_session.commit()
# Out:
# /var/folders/2l/kkk_s1ks6vs8jf0jbdk9q0n40000gn/T/ipykernel_44571/2304105297.py:22: SAWarning: Object of type <LessonSession> not in session, add operation along 'User.sessions' will not proceed
#   db_mnt_session.commit()

# %%
pam
# Out:
# ---------------------------------------------------------------------------
# DetachedInstanceError                     Traceback (most recent call last)
# File ~/.pyenv/versions/symbolic/lib/python3.11/site-packages/IPython/core/formatters.py:708, in PlainTextFormatter.__call__(self, obj)
#     701 stream = StringIO()
#     702 printer = pretty.RepresentationPrinter(stream, self.verbose,
#     703     self.max_width, self.newline,
#     704     max_seq_length=self.max_seq_length,
#     705     singleton_pprinters=self.singleton_printers,
#     706     type_pprinters=self.type_printers,
#     707     deferred_pprinters=self.deferred_printers)
# --> 708 printer.pretty(obj)
#     709 printer.flush()
#     710 return stream.getvalue()
#
# File ~/.pyenv/versions/symbolic/lib/python3.11/site-packages/IPython/lib/pretty.py:410, in RepresentationPrinter.pretty(self, obj)
#     407                         return meth(obj, self, cycle)
#     408                 if cls is not object \
# ...

# %%
editor = '{\n  "tagName": "div",\n  "status": "",\n  "attributes": {\n    "id": "editor"\n  },\n  "children": [\n    {\n      "tagName": "",\n      "status": "",\n      "attributes": {},\n      "children": [],\n      "textContent": "\\n    \\n    "\n    },\n    {\n      "tagName": "h2",\n      "status": "",\n      "attributes": {\n        "class": "assimil-title",\n        "id": "id_0",\n        "onclick": "proceedSentence(0)"\n      },\n      "children": [\n        {\n          "tagName": "",\n          "status": "",\n          "attributes": {},\n          "children": [],\n          "textContent": " Lec"\n        },\n        {\n          "tagName": "b",\n          "status": "",\n          "attributes": {},\n          "children": [\n            {\n              "tagName": "",\n              "status": "",\n              "attributes": {},\n              "children": [],\n              "textContent": "ción"\n            }\n          ],\n          "textContent": "ción"\n        },\n        {\n          "tagName": "",\n          "status": "",\n          "attributes": {},\n          "children": [],\n          "textContent": " veinti"\n        },\n        {\n          "tagName": "b",\n          "status": "",\n          "attributes": {},\n          "children": [\n            {\n              "tagName": "",\n              "status": "",\n              "attributes": {},\n              "children": [],\n              "textContent": "nue"\n            }\n          ],\n          "textContent": "nue"\n        },\n        {\n          "tagName": "",\n          "status": "",\n          "attributes": {},\n          "children": [],\n          "textContent": "ve "\n        }\n      ],\n      "textContent": " Lección veintinueve "\n    },\n    {\n      "tagName": "",\n      "status": "",\n      "attributes": {},\n      "children": [],\n      "textContent": "\\n    "\n    },\n    {\n      "tagName": "h2",\n      "status": "",\n      "attributes": {\n        "id": "id_1",\n        "onclick": "proceedSentence(1)"\n      },\n      "children": [\n        {\n          "tagName": "",\n          "status": "",\n          "attributes": {},\n          "children": [],\n          "textContent": " Qui"\n        },\n        {\n          "tagName": "b",\n          "status": "",\n          "attributes": {},\n          "children": [\n            {\n              "tagName": "",\n              "status": "",\n              "attributes": {},\n              "children": [],\n              "textContent": "sie"\n            }\n          ],\n          "textContent": "sie"\n        },\n        {\n          "tagName": "",\n          "status": "",\n          "attributes": {},\n          "children": [],\n          "textContent": "ra un bi"\n        },\n        {\n          "tagName": "b",\n          "status": "",\n          "attributes": {},\n          "children": [\n            {\n              "tagName": "",\n              "status": "",\n              "attributes": {},\n              "children": [],\n              "textContent": "lle"\n            }\n          ],\n          "textContent": "lle"\n        },\n        {\n          "tagName": "",\n          "status": "",\n          "attributes": {},\n          "children": [],\n          "textContent": "te "\n        },\n        {\n          "tagName": "b",\n          "status": "",\n          "attributes": {},\n          "children": [\n            {\n              "tagName": "",\n              "status": "",\n              "attributes": {},\n              "children": [],\n              "textContent": "pa"\n            }\n          ],\n          "textContent": "pa"\n        },\n        {\n          "tagName": "",\n          "status": "",\n          "attributes": {},\n          "children": [],\n          "textContent": "ra… "\n        }\n      ],\n      "textContent": " Quisiera un billete para… "\n    },\n    {\n      "tagName": "",\n      "status": "",\n      "attributes": {},\n      "children": [],\n      "textContent": "\\n    "\n    },\n    {\n      "tagName": "div",\n      "status": "",\n      "attributes": {\n        "class": "lesson-container"\n      },\n      "children": [\n        {\n          "tagName": "",\n          "status": "",\n          "attributes": {},\n          "children": [],\n          "textContent": "\\n      \\n        "\n        },\n        {\n          "tagName": "p",\n          "status": "",\n          "attributes": {\n            "id": "id_2",\n            "onclick": "proceedSentence(2)",\n            "class": "activeP"\n          },\n          "children": [\n            {\n              "tagName": "label",\n              "status": "",\n              "attributes": {\n                "class": "line-nr"\n              },\n              "children": [\n                {\n                  "tagName": "",\n                  "status": "",\n                  "attributes": {},\n                  "children": [],\n                  "textContent": "1"\n                }\n              ],\n              "textContent": "1"\n            },\n            {\n              "tagName": "label",\n              "status": "",\n              "attributes": {\n                "class": "dialogue-dash"\n              },\n              "children": [\n                {\n                  "tagName": "",\n                  "status": "",\n                  "attributes": {},\n                  "children": [],\n                  "textContent": "  — "\n                }\n              ],\n              "textContent": "  — "\n            },\n            {\n              "tagName": "label",\n              "status": "",\n              "attributes": {\n                "class": "activeBox normalText"\n              },\n              "children": [\n                {\n                  "tagName": "b",\n                  "status": "",\n                  "attributes": {},\n                  "children": [\n                    {\n                      "tagName": "",\n                      "status": "isAnchor",\n                      "attributes": {},\n                      "children": [],\n                      "textContent": "Bue"\n                    }\n                  ],\n                  "textContent": "Bue"\n                },\n                {\n                  "tagName": "",\n                  "status": "isFocus",\n                  "attributes": {},\n                  "children": [],\n                  "textContent": "nas, qui"\n                },\n                {\n                  "tagName": "b",\n                  "status": "",\n                  "attributes": {},\n                  "children": [\n                    {\n                      "tagName": "",\n                      "status": "",\n                      "attributes": {},\n                      "children": [],\n                      "textContent": "sie"\n                    }\n                  ],\n                  "textContent": "sie"\n                },\n                {\n                  "tagName": "",\n                  "status": "",\n                  "attributes": {},\n                  "children": [],\n                  "textContent": "ra un bi"\n                },\n                {\n                  "tagName": "b",\n                  "status": "",\n                  "attributes": {},\n                  "children": [\n                    {\n                      "tagName": "",\n                      "status": "",\n                      "attributes": {},\n                      "children": [],\n                      "textContent": "lle"\n                    }\n                  ],\n                  "textContent": "lle"\n                },\n                {\n                  "tagName": "",\n                  "status": "",\n                  "attributes": {},\n                  "children": [],\n                  "textContent": "te de Alme"\n                },\n                {\n                  "tagName": "b",\n                  "status": "",\n                  "attributes": {},\n                  "children": [\n                    {\n                      "tagName": "",\n                      "status": "",\n                      "attributes": {},\n                      "children": [],\n                      "textContent": "rí"\n                    }\n                  ],\n                  "textContent": "rí"\n                },\n                {\n                  "tagName": "",\n                  "status": "",\n                  "attributes": {},\n                  "children": [],\n                  "textContent": "a a Ma"\n                },\n                {\n                  "tagName": "b",\n                  "status": "",\n                  "attributes": {},\n                  "children": [\n                    {\n                      "tagName": "",\n                      "status": "",\n                      "attributes": {},\n                      "children": [],\n                      "textContent": "drid"\n                    }\n                  ],\n                  "textContent": "drid"\n                },\n                {\n                  "tagName": "",\n                  "status": "",\n                  "attributes": {},\n                  "children": [],\n                  "textContent": "."\n                }\n              ],\n              "textContent": "Buenas, quisiera un billete de Almería a Madrid."\n            }\n          ],\n          "textContent": "1  — Buenas, quisiera un billete de Almería a Madrid."\n        },\n        {\n          "tagName": "",\n          "status": "",\n          "attributes": {},\n          "children": [],\n          "textContent": "\\n        \\n      \\n        "\n        },\n        {\n          "tagName": "p",\n          "status": "",\n          "attributes": {\n            "id": "id_3",\n            "onclick": "proceedSentence(3)"\n          },\n          "children": [\n            {\n              "tagName": "label",\n              "status": "",\n              "attributes": {\n                "class": "line-nr"\n              },\n              "children": [\n                {\n                  "tagName": "",\n                  "status": "",\n                  "attributes": {},\n                  "children": [],\n                  "textContent": "2"\n                }\n              ],\n              "textContent": "2"\n            },\n            {\n              "tagName": "label",\n              "status": "",\n              "attributes": {\n                "class": "dialogue-dash"\n              },\n              "children": [\n                {\n                  "tagName": "",\n                  "status": "",\n                  "attributes": {},\n                  "children": [],\n                  "textContent": "  — "\n                }\n              ],\n              "textContent": "  — "\n            },\n            {\n              "tagName": "label",\n              "status": "",\n              "attributes": {},\n              "children": [\n                {\n                  "tagName": "",\n                  "status": "",\n                  "attributes": {},\n                  "children": [],\n                  "textContent": "Sa"\n                },\n                {\n                  "tagName": "b",\n                  "status": "",\n                  "attributes": {},\n                  "children": [\n                    {\n                      "tagName": "",\n                      "status": "",\n                      "attributes": {},\n                      "children": [],\n                      "textContent": "cán"\n                    }\n                  ],\n                  "textContent": "cán"\n                },\n                {\n                  "tagName": "",\n                  "status": "",\n                  "attributes": {},\n                  "children": [],\n                  "textContent": "dolo de "\n                },\n                {\n                  "tagName": "b",\n                  "status": "",\n                  "attributes": {},\n                  "children": [\n                    {\n                      "tagName": "",\n                      "status": "",\n                      "attributes": {},\n                      "children": [],\n                      "textContent": "i"\n                    }\n                  ],\n                  "textContent": "i"\n                },\n                {\n                  "tagName": "",\n                  "status": "",\n                  "attributes": {},\n                  "children": [],\n                  "textContent": "da y "\n                },\n                {\n                  "tagName": "b",\n                  "status": "",\n                  "attributes": {},\n                  "children": [\n                    {\n                      "tagName": "",\n                      "status": "",\n                      "attributes": {},\n                      "children": [],\n                      "textContent": "vuel"\n                    }\n                  ],\n                  "textContent": "vuel"\n                },\n                {\n                  "tagName": "",\n                  "status": "",\n                  "attributes": {},\n                  "children": [],\n                  "textContent": "ta "\n                },\n                {\n                  "tagName": "b",\n                  "status": "",\n                  "attributes": {},\n                  "children": [\n                    {\n                      "tagName": "",\n                      "status": "",\n                      "attributes": {},\n                      "children": [],\n                      "textContent": "tie"\n                    }\n                  ],\n                  "textContent": "tie"\n                },\n                {\n                  "tagName": "",\n                  "status": "",\n                  "attributes": {},\n                  "children": [],\n                  "textContent": "ne us"\n                },\n                {\n                  "tagName": "b",\n                  "status": "",\n                  "attributes": {},\n                  "children": [\n                    {\n                      "tagName": "",\n                      "status": "",\n                      "attributes": {},\n                      "children": [],\n                      "textContent": "ted"\n                    }\n                  ],\n                  "textContent": "ted"\n                },\n                {\n                  "tagName": "",\n                  "status": "",\n                  "attributes": {},\n                  "children": [],\n                  "textContent": " el 25 % (veinti"\n                },\n                {\n                  "tagName": "b",\n                  "status": "",\n                  "attributes": {},\n                  "children": [\n                    {\n                      "tagName": "",\n                      "status": "",\n                      "attributes": {},\n                      "children": [],\n                      "textContent": "cin"\n                    }\n                  ],\n                  "textContent": "cin"\n                },\n                {\n                  "tagName": "",\n                  "status": "",\n                  "attributes": {},\n                  "children": [],\n                  "textContent": "co por "\n                },\n                {\n                  "tagName": "b",\n                  "status": "",\n                  "attributes": {},\n                  "children": [\n                    {\n                      "tagName": "",\n                      "status": "",\n                      "attributes": {},\n                      "children": [],\n                      "textContent": "cien"\n                    }\n                  ],\n                  "textContent": "cien"\n                },\n                {\n                  "tagName": "",\n                  "status": "",\n                  "attributes": {},\n                  "children": [],\n                  "textContent": "to) de des"\n                },\n                {\n                  "tagName": "b",\n                  "status": "",\n                  "attributes": {},\n                  "children": [\n                    {\n                      "tagName": "",\n                      "status": "",\n                      "attributes": {},\n                      "children": [],\n                      "textContent": "cuen"\n                    }\n                  ],\n                  "textContent": "cuen"\n                },\n                {\n                  "tagName": "",\n                  "status": "",\n                  "attributes": {},\n                  "children": [],\n                  "textContent": "to."\n                }\n              ],\n              "textContent": "Sacándolo de ida y vuelta tiene usted el 25 % (veinticinco por ciento) de descuento."\n            }\n          ],\n          "textContent": "2  — Sacándolo de ida y vuelta tiene usted el 25 % (veinticinco por ciento) de descuento."\n        },\n        {\n          "tagName": "",\n          "status": "",\n          "attributes": {},\n          "children": [],\n          "textContent": "\\n        \\n      \\n        "\n        },\n        {\n          "tagName": "p",\n          "status": "",\n          "attributes": {\n            "id": "id_4",\n            "onclick": "proceedSentence(4)"\n          },\n          "children": [\n            {\n              "tagName": "label",\n              "status": "",\n              "attributes": {\n                "class": "line-nr"\n              },\n              "children": [\n                {\n                  "tagName": "",\n                  "status": "",\n                  "attributes": {},\n                  "children": [],\n                  "textContent": "3"\n                }\n              ],\n              "textContent": "3"\n            },\n            {\n              "tagName": "label",\n              "status": "",\n              "attributes": {\n                "class": "dialogue-dash"\n              },\n              "children": [\n                {\n                  "tagName": "",\n                  "status": "",\n                  "attributes": {},\n                  "children": [],\n                  "textContent": "  — "\n                }\n              ],\n              "textContent": "  — "\n            },\n            {\n              "tagName": "label",\n              "status": "",\n              "attributes": {},\n              "children": [\n                {\n                  "tagName": "",\n                  "status": "",\n                  "attributes": {},\n                  "children": [],\n                  "textContent": "De "\n                },\n                {\n                  "tagName": "b",\n                  "status": "",\n                  "attributes": {},\n                  "children": [\n                    {\n                      "tagName": "",\n                      "status": "",\n                      "attributes": {},\n                      "children": [],\n                      "textContent": "i"\n                    }\n                  ],\n                  "textContent": "i"\n                },\n                {\n                  "tagName": "",\n                  "status": "",\n                  "attributes": {},\n                  "children": [],\n                  "textContent": "da y "\n                },\n                {\n                  "tagName": "b",\n                  "status": "",\n                  "attributes": {},\n                  "children": [\n                    {\n                      "tagName": "",\n                      "status": "",\n                      "attributes": {},\n                      "children": [],\n                      "textContent": "vuel"\n                    }\n                  ],\n                  "textContent": "vuel"\n                },\n                {\n                  "tagName": "",\n                  "status": "",\n                  "attributes": {},\n                  "children": [],\n                  "textContent": "ta en"\n                },\n                {\n                  "tagName": "b",\n                  "status": "",\n                  "attributes": {},\n                  "children": [\n                    {\n                      "tagName": "",\n                      "status": "",\n                      "attributes": {},\n                      "children": [],\n                      "textContent": "ton"\n                    }\n                  ],\n                  "textContent": "ton"\n                },\n                {\n                  "tagName": "",\n                  "status": "",\n                  "attributes": {},\n                  "children": [],\n                  "textContent": "ces: "\n                },\n                {\n                  "tagName": "b",\n                  "status": "",\n                  "attributes": {},\n                  "children": [\n                    {\n                      "tagName": "",\n                      "status": "",\n                      "attributes": {},\n                      "children": [],\n                      "textContent": "sal"\n                    }\n                  ],\n                  "textContent": "sal"\n                },\n                {\n                  "tagName": "",\n                  "status": "",\n                  "attributes": {},\n                  "children": [],\n                  "textContent": "go el "\n                },\n                {\n                  "tagName": "b",\n                  "status": "",\n                  "attributes": {},\n                  "children": [\n                    {\n                      "tagName": "",\n                      "status": "",\n                      "attributes": {},\n                      "children": [],\n                      "textContent": "u"\n                    }\n                  ],\n                  "textContent": "u"\n                },\n                {\n                  "tagName": "",\n                  "status": "",\n                  "attributes": {},\n                  "children": [],\n                  "textContent": "no de "\n                },\n                {\n                  "tagName": "b",\n                  "status": "",\n                  "attributes": {},\n                  "children": [\n                    {\n                      "tagName": "",\n                      "status": "",\n                      "attributes": {},\n                      "children": [],\n                      "textContent": "ju"\n                    }\n                  ],\n                  "textContent": "ju"\n                },\n                {\n                  "tagName": "",\n                  "status": "",\n                  "attributes": {},\n                  "children": [],\n                  "textContent": "nio y "\n                },\n                {\n                  "tagName": "b",\n                  "status": "",\n                  "attributes": {},\n                  "children": [\n                    {\n                      "tagName": "",\n                      "status": "",\n                      "attributes": {},\n                      "children": [],\n                      "textContent": "vuel"\n                    }\n                  ],\n                  "textContent": "vuel"\n                },\n                {\n                  "tagName": "",\n                  "status": "",\n                  "attributes": {},\n                  "children": [],\n                  "textContent": "vo el "\n                },\n                {\n                  "tagName": "b",\n                  "status": "",\n                  "attributes": {},\n                  "children": [\n                    {\n                      "tagName": "",\n                      "status": "",\n                      "attributes": {},\n                      "children": [],\n                      "textContent": "quin"\n                    }\n                  ],\n                  "textContent": "quin"\n                },\n                {\n                  "tagName": "",\n                  "status": "",\n                  "attributes": {},\n                  "children": [],\n                  "textContent": "ce."\n                }\n              ],\n              "textContent": "De ida y vuelta entonces: salgo el uno de junio y vuelvo el quince."\n            }\n          ],\n          "textContent": "3  — De ida y vuelta entonces: salgo el uno de junio y vuelvo el quince."\n        },\n        {\n          "tagName": "",\n          "status": "",\n          "attributes": {},\n          "children": [],\n          "textContent": "\\n        \\n      \\n        "\n        },\n        {\n          "tagName": "p",\n          "status": "",\n          "attributes": {\n            "id": "id_5",\n            "onclick": "proceedSentence(5)"\n          },\n          "children": [\n            {\n              "tagName": "label",\n              "status": "",\n              "attributes": {\n                "class": "line-nr"\n              },\n              "children": [\n                {\n                  "tagName": "",\n                  "status": "",\n                  "attributes": {},\n                  "children": [],\n                  "textContent": "4"\n                }\n              ],\n              "textContent": "4"\n            },\n            {\n              "tagName": "label",\n              "status": "",\n              "attributes": {\n                "class": "dialogue-dash"\n              },\n              "children": [\n                {\n                  "tagName": "",\n                  "status": "",\n                  "attributes": {},\n                  "children": [],\n                  "textContent": "  — "\n                }\n              ],\n              "textContent": "  — "\n            },\n            {\n              "tagName": "label",\n              "status": "",\n              "attributes": {},\n              "children": [\n                {\n                  "tagName": "",\n                  "status": "",\n                  "attributes": {},\n                  "children": [],\n                  "textContent": "¿De"\n                },\n                {\n                  "tagName": "b",\n                  "status": "",\n                  "attributes": {},\n                  "children": [\n                    {\n                      "tagName": "",\n                      "status": "",\n                      "attributes": {},\n                      "children": [],\n                      "textContent": "se"\n                    }\n                  ],\n                  "textContent": "se"\n                },\n                {\n                  "tagName": "",\n                  "status": "",\n                  "attributes": {},\n                  "children": [],\n                  "textContent": "a tu"\n                },\n                {\n                  "tagName": "b",\n                  "status": "",\n                  "attributes": {},\n                  "children": [\n                    {\n                      "tagName": "",\n                      "status": "",\n                      "attributes": {},\n                      "children": [],\n                      "textContent": "ris"\n                    }\n                  ],\n                  "textContent": "ris"\n                },\n                {\n                  "tagName": "",\n                  "status": "",\n                  "attributes": {},\n                  "children": [],\n                  "textContent": "ta o prefe"\n                },\n                {\n                  "tagName": "b",\n                  "status": "",\n                  "attributes": {},\n                  "children": [\n                    {\n                      "tagName": "",\n                      "status": "",\n                      "attributes": {},\n                      "children": [],\n                      "textContent": "ren"\n                    }\n                  ],\n                  "textContent": "ren"\n                },\n                {\n                  "tagName": "",\n                  "status": "",\n                  "attributes": {},\n                  "children": [],\n                  "textContent": "te?"\n                }\n              ],\n              "textContent": "¿Desea turista o preferente?"\n            }\n          ],\n          "textContent": "4  — ¿Desea turista o preferente?"\n        },\n        {\n          "tagName": "",\n          "status": "",\n          "attributes": {},\n          "children": [],\n          "textContent": "\\n        \\n      \\n        "\n        },\n        {\n          "tagName": "p",\n          "status": "",\n          "attributes": {\n            "id": "id_6",\n            "onclick": "proceedSentence(6)"\n          },\n          "children": [\n            {\n              "tagName": "label",\n              "status": "",\n              "attributes": {\n                "class": "line-nr"\n              },\n              "children": [\n                {\n                  "tagName": "",\n                  "status": "",\n                  "attributes": {},\n                  "children": [],\n                  "textContent": "5"\n                }\n              ],\n              "textContent": "5"\n            },\n            {\n              "tagName": "label",\n              "status": "",\n              "attributes": {\n                "class": "dialogue-dash"\n              },\n              "children": [\n                {\n                  "tagName": "",\n                  "status": "",\n                  "attributes": {},\n                  "children": [],\n                  "textContent": "  — "\n                }\n              ],\n              "textContent": "  — "\n            },\n            {\n              "tagName": "label",\n              "status": "",\n              "attributes": {},\n              "children": [\n                {\n                  "tagName": "",\n                  "status": "",\n                  "attributes": {},\n                  "children": [],\n                  "textContent": "Prefe"\n                },\n                {\n                  "tagName": "b",\n                  "status": "",\n                  "attributes": {},\n                  "children": [\n                    {\n                      "tagName": "",\n                      "status": "",\n                      "attributes": {},\n                      "children": [],\n                      "textContent": "ren"\n                    }\n                  ],\n                  "textContent": "ren"\n                },\n                {\n                  "tagName": "",\n                  "status": "",\n                  "attributes": {},\n                  "children": [],\n                  "textContent": "te "\n                },\n                {\n                  "tagName": "b",\n                  "status": "",\n                  "attributes": {},\n                  "children": [\n                    {\n                      "tagName": "",\n                      "status": "",\n                      "attributes": {},\n                      "children": [],\n                      "textContent": "so"\n                    }\n                  ],\n                  "textContent": "so"\n                },\n                {\n                  "tagName": "",\n                  "status": "",\n                  "attributes": {},\n                  "children": [],\n                  "textContent": "lo le "\n                },\n                {\n                  "tagName": "b",\n                  "status": "",\n                  "attributes": {},\n                  "children": [\n                    {\n                      "tagName": "",\n                      "status": "",\n                      "attributes": {},\n                      "children": [],\n                      "textContent": "cues"\n                    }\n                  ],\n                  "textContent": "cues"\n                },\n                {\n                  "tagName": "",\n                  "status": "",\n                  "attributes": {},\n                  "children": [],\n                  "textContent": "ta seis "\n                },\n                {\n                  "tagName": "b",\n                  "status": "",\n                  "attributes": {},\n                  "children": [\n                    {\n                      "tagName": "",\n                      "status": "",\n                      "attributes": {},\n                      "children": [],\n                      "textContent": "eu"\n                    }\n                  ],\n                  "textContent": "eu"\n                },\n                {\n                  "tagName": "",\n                  "status": "",\n                  "attributes": {},\n                  "children": [],\n                  "textContent": "ros más. Es "\n                },\n                {\n                  "tagName": "b",\n                  "status": "",\n                  "attributes": {},\n                  "children": [\n                    {\n                      "tagName": "",\n                      "status": "",\n                      "attributes": {},\n                      "children": [],\n                      "textContent": "u"\n                    }\n                  ],\n                  "textContent": "u"\n                },\n                {\n                  "tagName": "",\n                  "status": "",\n                  "attributes": {},\n                  "children": [],\n                  "textContent": "na o"\n                },\n                {\n                  "tagName": "b",\n                  "status": "",\n                  "attributes": {},\n                  "children": [\n                    {\n                      "tagName": "",\n                      "status": "",\n                      "attributes": {},\n                      "children": [],\n                      "textContent": "fer"\n                    }\n                  ],\n                  "textContent": "fer"\n                },\n                {\n                  "tagName": "",\n                  "status": "",\n                  "attributes": {},\n                  "children": [],\n                  "textContent": "ta."\n                }\n              ],\n              "textContent": "Preferente solo le cuesta seis euros más. Es una oferta."\n            }\n          ],\n          "textContent": "5  — Preferente solo le cuesta seis euros más. Es una oferta."\n        },\n        {\n          "tagName": "",\n          "status": "",\n          "attributes": {},\n          "children": [],\n          "textContent": "\\n        \\n      \\n        "\n        },\n        {\n          "tagName": "p",\n          "status": "",\n          "attributes": {\n            "id": "id_7",\n            "onclick": "proceedSentence(7)"\n          },\n          "children": [\n            {\n              "tagName": "label",\n              "status": "",\n              "attributes": {\n                "class": "line-nr"\n              },\n              "children": [\n                {\n                  "tagName": "",\n                  "status": "",\n                  "attributes": {},\n                  "children": [],\n                  "textContent": "6"\n                }\n              ],\n              "textContent": "6"\n            },\n            {\n              "tagName": "label",\n              "status": "",\n              "attributes": {\n                "class": "dialogue-dash"\n              },\n              "children": [\n                {\n                  "tagName": "",\n                  "status": "",\n                  "attributes": {},\n                  "children": [],\n                  "textContent": "  — "\n                }\n              ],\n              "textContent": "  — "\n            },\n            {\n              "tagName": "label",\n              "status": "",\n              "attributes": {},\n              "children": [\n                {\n                  "tagName": "",\n                  "status": "",\n                  "attributes": {},\n                  "children": [],\n                  "textContent": "¡Pues prefe"\n                },\n                {\n                  "tagName": "b",\n                  "status": "",\n                  "attributes": {},\n                  "children": [\n                    {\n                      "tagName": "",\n                      "status": "",\n                      "attributes": {},\n                      "children": [],\n                      "textContent": "ren"\n                    }\n                  ],\n                  "textContent": "ren"\n                },\n                {\n                  "tagName": "",\n                  "status": "",\n                  "attributes": {},\n                  "children": [],\n                  "textContent": "te en"\n                },\n                {\n                  "tagName": "b",\n                  "status": "",\n                  "attributes": {},\n                  "children": [\n                    {\n                      "tagName": "",\n                      "status": "",\n                      "attributes": {},\n                      "children": [],\n                      "textContent": "ton"\n                    }\n                  ],\n                  "textContent": "ton"\n                },\n                {\n                  "tagName": "",\n                  "status": "",\n                  "attributes": {},\n                  "children": [],\n                  "textContent": "ces! "\n                },\n                {\n                  "tagName": "b",\n                  "status": "",\n                  "attributes": {},\n                  "children": [\n                    {\n                      "tagName": "",\n                      "status": "",\n                      "attributes": {},\n                      "children": [],\n                      "textContent": "Pe"\n                    }\n                  ],\n                  "textContent": "Pe"\n                },\n                {\n                  "tagName": "",\n                  "status": "",\n                  "attributes": {},\n                  "children": [],\n                  "textContent": "ro, qué ca"\n                },\n                {\n                  "tagName": "b",\n                  "status": "",\n                  "attributes": {},\n                  "children": [\n                    {\n                      "tagName": "",\n                      "status": "",\n                      "attributes": {},\n                      "children": [],\n                      "textContent": "be"\n                    }\n                  ],\n                  "textContent": "be"\n                },\n                {\n                  "tagName": "",\n                  "status": "",\n                  "attributes": {},\n                  "children": [],\n                  "textContent": "za "\n                },\n                {\n                  "tagName": "b",\n                  "status": "",\n                  "attributes": {},\n                  "children": [\n                    {\n                      "tagName": "",\n                      "status": "",\n                      "attributes": {},\n                      "children": [],\n                      "textContent": "ten"\n                    }\n                  ],\n                  "textContent": "ten"\n                },\n                {\n                  "tagName": "",\n                  "status": "",\n                  "attributes": {},\n                  "children": [],\n                  "textContent": "go…, no en"\n                },\n                {\n                  "tagName": "b",\n                  "status": "",\n                  "attributes": {},\n                  "children": [\n                    {\n                      "tagName": "",\n                      "status": "",\n                      "attributes": {},\n                      "children": [],\n                      "textContent": "cuen"\n                    }\n                  ],\n                  "textContent": "cuen"\n                },\n                {\n                  "tagName": "",\n                  "status": "",\n                  "attributes": {},\n                  "children": [],\n                  "textContent": "tro la tar"\n                },\n                {\n                  "tagName": "b",\n                  "status": "",\n                  "attributes": {},\n                  "children": [\n                    {\n                      "tagName": "",\n                      "status": "",\n                      "attributes": {},\n                      "children": [],\n                      "textContent": "je"\n                    }\n                  ],\n                  "textContent": "je"\n                },\n                {\n                  "tagName": "",\n                  "status": "",\n                  "attributes": {},\n                  "children": [],\n                  "textContent": "ta."\n                }\n              ],\n              "textContent": "¡Pues preferente entonces! Pero, qué cabeza tengo…, no encuentro la tarjeta."\n            }\n          ],\n          "textContent": "6  — ¡Pues preferente entonces! Pero, qué cabeza tengo…, no encuentro la tarjeta."\n        },\n        {\n          "tagName": "",\n          "status": "",\n          "attributes": {},\n          "children": [],\n          "textContent": "\\n        \\n      \\n        "\n        },\n        {\n          "tagName": "p",\n          "status": "",\n          "attributes": {\n            "id": "id_8",\n            "onclick": "proceedSentence(8)"\n          },\n          "children": [\n            {\n              "tagName": "label",\n              "status": "",\n              "attributes": {\n                "class": "line-nr"\n              },\n              "children": [\n                {\n                  "tagName": "",\n                  "status": "",\n                  "attributes": {},\n                  "children": [],\n                  "textContent": "7"\n                }\n              ],\n              "textContent": "7"\n            },\n            {\n              "tagName": "label",\n              "status": "",\n              "attributes": {\n                "class": "dialogue-dash"\n              },\n              "children": [\n                {\n                  "tagName": "",\n                  "status": "",\n                  "attributes": {},\n                  "children": [],\n                  "textContent": "  — "\n                }\n              ],\n              "textContent": "  — "\n            },\n            {\n              "tagName": "label",\n              "status": "",\n              "attributes": {},\n              "children": [\n                {\n                  "tagName": "",\n                  "status": "",\n                  "attributes": {},\n                  "children": [],\n                  "textContent": "Le doy un "\n                },\n                {\n                  "tagName": "b",\n                  "status": "",\n                  "attributes": {},\n                  "children": [\n                    {\n                      "tagName": "",\n                      "status": "",\n                      "attributes": {},\n                      "children": [],\n                      "textContent": "nú"\n                    }\n                  ],\n                  "textContent": "nú"\n                },\n                {\n                  "tagName": "",\n                  "status": "",\n                  "attributes": {},\n                  "children": [],\n                  "textContent": "mero de re"\n                },\n                {\n                  "tagName": "b",\n                  "status": "",\n                  "attributes": {},\n                  "children": [\n                    {\n                      "tagName": "",\n                      "status": "",\n                      "attributes": {},\n                      "children": [],\n                      "textContent": "ser"\n                    }\n                  ],\n                  "textContent": "ser"\n                },\n                {\n                  "tagName": "",\n                  "status": "",\n                  "attributes": {},\n                  "children": [],\n                  "textContent": "va y "\n                },\n                {\n                  "tagName": "b",\n                  "status": "",\n                  "attributes": {},\n                  "children": [\n                    {\n                      "tagName": "",\n                      "status": "",\n                      "attributes": {},\n                      "children": [],\n                      "textContent": "pa"\n                    }\n                  ],\n                  "textContent": "pa"\n                },\n                {\n                  "tagName": "",\n                  "status": "",\n                  "attributes": {},\n                  "children": [],\n                  "textContent": "ga us"\n                },\n                {\n                  "tagName": "b",\n                  "status": "",\n                  "attributes": {},\n                  "children": [\n                    {\n                      "tagName": "",\n                      "status": "",\n                      "attributes": {},\n                      "children": [],\n                      "textContent": "ted"\n                    }\n                  ],\n                  "textContent": "ted"\n                },\n                {\n                  "tagName": "",\n                  "status": "",\n                  "attributes": {},\n                  "children": [],\n                  "textContent": " des"\n                },\n                {\n                  "tagName": "b",\n                  "status": "",\n                  "attributes": {},\n                  "children": [\n                    {\n                      "tagName": "",\n                      "status": "",\n                      "attributes": {},\n                      "children": [],\n                      "textContent": "pués"\n                    }\n                  ],\n                  "textContent": "pués"\n                },\n                {\n                  "tagName": "",\n                  "status": "",\n                  "attributes": {},\n                  "children": [],\n                  "textContent": ", con tar"\n                },\n                {\n                  "tagName": "b",\n                  "status": "",\n                  "attributes": {},\n                  "children": [\n                    {\n                      "tagName": "",\n                      "status": "",\n                      "attributes": {},\n                      "children": [],\n                      "textContent": "je"\n                    }\n                  ],\n                  "textContent": "je"\n                },\n                {\n                  "tagName": "",\n                  "status": "",\n                  "attributes": {},\n                  "children": [],\n                  "textContent": "ta o en efec"\n                },\n                {\n                  "tagName": "b",\n                  "status": "",\n                  "attributes": {},\n                  "children": [\n                    {\n                      "tagName": "",\n                      "status": "",\n                      "attributes": {},\n                      "children": [],\n                      "textContent": "ti"\n                    }\n                  ],\n                  "textContent": "ti"\n                },\n                {\n                  "tagName": "",\n                  "status": "",\n                  "attributes": {},\n                  "children": [],\n                  "textContent": "vo, ¿"\n                },\n                {\n                  "tagName": "b",\n                  "status": "",\n                  "attributes": {},\n                  "children": [\n                    {\n                      "tagName": "",\n                      "status": "",\n                      "attributes": {},\n                      "children": [],\n                      "textContent": "va"\n                    }\n                  ],\n                  "textContent": "va"\n                },\n                {\n                  "tagName": "",\n                  "status": "",\n                  "attributes": {},\n                  "children": [],\n                  "textContent": "le?"\n                }\n              ],\n              "textContent": "Le doy un número de reserva y paga usted después, con tarjeta o en efectivo, ¿vale?"\n            }\n          ],\n          "textContent": "7  — Le doy un número de reserva y paga usted después, con tarjeta o en efectivo, ¿vale?"\n        },\n        {\n          "tagName": "",\n          "status": "",\n          "attributes": {},\n          "children": [],\n          "textContent": "\\n        \\n      \\n        "\n        },\n        {\n          "tagName": "p",\n          "status": "",\n          "attributes": {\n            "id": "id_9",\n            "onclick": "proceedSentence(9)"\n          },\n          "children": [\n            {\n              "tagName": "label",\n              "status": "",\n              "attributes": {\n                "class": "line-nr"\n              },\n              "children": [\n                {\n                  "tagName": "",\n                  "status": "",\n                  "attributes": {},\n                  "children": [],\n                  "textContent": "8"\n                }\n              ],\n              "textContent": "8"\n            },\n            {\n              "tagName": "label",\n              "status": "",\n              "attributes": {\n                "class": "dialogue-dash"\n              },\n              "children": [\n                {\n                  "tagName": "",\n                  "status": "",\n                  "attributes": {},\n                  "children": [],\n                  "textContent": " "\n                }\n              ],\n              "textContent": " "\n            },\n            {\n              "tagName": "label",\n              "status": "",\n              "attributes": {},\n              "children": [\n                {\n                  "tagName": "",\n                  "status": "",\n                  "attributes": {},\n                  "children": [],\n                  "textContent": "La sa"\n                },\n                {\n                  "tagName": "b",\n                  "status": "",\n                  "attributes": {},\n                  "children": [\n                    {\n                      "tagName": "",\n                      "status": "",\n                      "attributes": {},\n                      "children": [],\n                      "textContent": "li"\n                    }\n                  ],\n                  "textContent": "li"\n                },\n                {\n                  "tagName": "",\n                  "status": "",\n                  "attributes": {},\n                  "children": [],\n                  "textContent": "da es a las 7 y 10 de la ma"\n                },\n                {\n                  "tagName": "b",\n                  "status": "",\n                  "attributes": {},\n                  "children": [\n                    {\n                      "tagName": "",\n                      "status": "",\n                      "attributes": {},\n                      "children": [],\n                      "textContent": "ña"\n                    }\n                  ],\n                  "textContent": "ña"\n                },\n                {\n                  "tagName": "",\n                  "status": "",\n                  "attributes": {},\n                  "children": [],\n                  "textContent": "na y la "\n                },\n                {\n                  "tagName": "b",\n                  "status": "",\n                  "attributes": {},\n                  "children": [\n                    {\n                      "tagName": "",\n                      "status": "",\n                      "attributes": {},\n                      "children": [],\n                      "textContent": "vuel"\n                    }\n                  ],\n                  "textContent": "vuel"\n                },\n                {\n                  "tagName": "",\n                  "status": "",\n                  "attributes": {},\n                  "children": [],\n                  "textContent": "ta a las 3 y "\n                },\n                {\n                  "tagName": "b",\n                  "status": "",\n                  "attributes": {},\n                  "children": [\n                    {\n                      "tagName": "",\n                      "status": "",\n                      "attributes": {},\n                      "children": [],\n                      "textContent": "me"\n                    }\n                  ],\n                  "textContent": "me"\n                },\n                {\n                  "tagName": "",\n                  "status": "",\n                  "attributes": {},\n                  "children": [],\n                  "textContent": "dia de la "\n                },\n                {\n                  "tagName": "b",\n                  "status": "",\n                  "attributes": {},\n                  "children": [\n                    {\n                      "tagName": "",\n                      "status": "",\n                      "attributes": {},\n                      "children": [],\n                      "textContent": "tar"\n                    }\n                  ],\n                  "textContent": "tar"\n                },\n                {\n                  "tagName": "",\n                  "status": "",\n                  "attributes": {},\n                  "children": [],\n                  "textContent": "de."\n                }\n              ],\n              "textContent": "La salida es a las 7 y 10 de la mañana y la vuelta a las 3 y media de la tarde."\n            }\n          ],\n          "textContent": "8 La salida es a las 7 y 10 de la mañana y la vuelta a las 3 y media de la tarde."\n        },\n        {\n          "tagName": "",\n          "status": "",\n          "attributes": {},\n          "children": [],\n          "textContent": "\\n        \\n      \\n        "\n        },\n        {\n          "tagName": "p",\n          "status": "",\n          "attributes": {\n            "id": "id_10",\n            "onclick": "proceedSentence(10)"\n          },\n          "children": [\n            {\n              "tagName": "label",\n              "status": "",\n              "attributes": {\n                "class": "line-nr"\n              },\n              "children": [\n                {\n                  "tagName": "",\n                  "status": "",\n                  "attributes": {},\n                  "children": [],\n                  "textContent": "9"\n                }\n              ],\n              "textContent": "9"\n            },\n            {\n              "tagName": "label",\n              "status": "",\n              "attributes": {\n                "class": "dialogue-dash"\n              },\n              "children": [\n                {\n                  "tagName": "",\n                  "status": "",\n                  "attributes": {},\n                  "children": [],\n                  "textContent": " "\n                }\n              ],\n              "textContent": " "\n            },\n            {\n              "tagName": "label",\n              "status": "",\n              "attributes": {},\n              "children": [\n                {\n                  "tagName": "",\n                  "status": "",\n                  "attributes": {},\n                  "children": [],\n                  "textContent": "A"\n                },\n                {\n                  "tagName": "b",\n                  "status": "",\n                  "attributes": {},\n                  "children": [\n                    {\n                      "tagName": "",\n                      "status": "",\n                      "attributes": {},\n                      "children": [],\n                      "textContent": "pun"\n                    }\n                  ],\n                  "textContent": "pun"\n                },\n                {\n                  "tagName": "",\n                  "status": "",\n                  "attributes": {},\n                  "children": [],\n                  "textContent": "te: XH553WB."\n                }\n              ],\n              "textContent": "Apunte: XH553WB."\n            }\n          ],\n          "textContent": "9 Apunte: XH553WB."\n        },\n        {\n          "tagName": "",\n          "status": "",\n          "attributes": {},\n          "children": [],\n          "textContent": "\\n        \\n      \\n        "\n        },\n        {\n          "tagName": "p",\n          "status": "",\n          "attributes": {\n            "id": "id_11",\n            "onclick": "proceedSentence(11)"\n          },\n          "children": [\n            {\n              "tagName": "label",\n              "status": "",\n              "attributes": {\n                "class": "line-nr"\n              },\n              "children": [\n                {\n                  "tagName": "",\n                  "status": "",\n                  "attributes": {},\n                  "children": [],\n                  "textContent": "10"\n                }\n              ],\n              "textContent": "10"\n            },\n            {\n              "tagName": "label",\n              "status": "",\n              "attributes": {\n                "class": "dialogue-dash"\n              },\n              "children": [\n                {\n                  "tagName": "",\n                  "status": "",\n                  "attributes": {},\n                  "children": [],\n                  "textContent": "  — "\n                }\n              ],\n              "textContent": "  — "\n            },\n            {\n              "tagName": "label",\n              "status": "",\n              "attributes": {},\n              "children": [\n                {\n                  "tagName": "",\n                  "status": "",\n                  "attributes": {},\n                  "children": [],\n                  "textContent": "Per"\n                },\n                {\n                  "tagName": "b",\n                  "status": "",\n                  "attributes": {},\n                  "children": [\n                    {\n                      "tagName": "",\n                      "status": "",\n                      "attributes": {},\n                      "children": [],\n                      "textContent": "dón"\n                    }\n                  ],\n                  "textContent": "dón"\n                },\n                {\n                  "tagName": "",\n                  "status": "",\n                  "attributes": {},\n                  "children": [],\n                  "textContent": ", ¿la "\n                },\n                {\n                  "tagName": "b",\n                  "status": "",\n                  "attributes": {},\n                  "children": [\n                    {\n                      "tagName": "",\n                      "status": "",\n                      "attributes": {},\n                      "children": [],\n                      "textContent": "úl"\n                    }\n                  ],\n                  "textContent": "úl"\n                },\n                {\n                  "tagName": "",\n                  "status": "",\n                  "attributes": {},\n                  "children": [],\n                  "textContent": "tima "\n                },\n                {\n                  "tagName": "b",\n                  "status": "",\n                  "attributes": {},\n                  "children": [\n                    {\n                      "tagName": "",\n                      "status": "",\n                      "attributes": {},\n                      "children": [],\n                      "textContent": "le"\n                    }\n                  ],\n                  "textContent": "le"\n                },\n                {\n                  "tagName": "",\n                  "status": "",\n                  "attributes": {},\n                  "children": [],\n                  "textContent": "tra es B o D?"\n                }\n              ],\n              "textContent": "Perdón, ¿la última letra es B o D?"\n            }\n          ],\n          "textContent": "10  — Perdón, ¿la última letra es B o D?"\n        },\n        {\n          "tagName": "",\n          "status": "",\n          "attributes": {},\n          "children": [],\n          "textContent": "\\n        \\n      \\n        "\n        },\n        {\n          "tagName": "p",\n          "status": "",\n          "attributes": {\n            "id": "id_12",\n            "onclick": "proceedSentence(12)"\n          },\n          "children": [\n            {\n              "tagName": "label",\n              "status": "",\n              "attributes": {\n                "class": "line-nr"\n              },\n              "children": [\n                {\n                  "tagName": "",\n                  "status": "",\n                  "attributes": {},\n                  "children": [],\n                  "textContent": "11"\n                }\n              ],\n              "textContent": "11"\n            },\n            {\n              "tagName": "label",\n              "status": "",\n              "attributes": {\n                "class": "dialogue-dash"\n              },\n              "children": [\n                {\n                  "tagName": "",\n                  "status": "",\n                  "attributes": {},\n                  "children": [],\n                  "textContent": "  — "\n                }\n              ],\n              "textContent": "  — "\n            },\n            {\n              "tagName": "label",\n              "status": "",\n              "attributes": {},\n              "children": [\n                {\n                  "tagName": "",\n                  "status": "",\n                  "attributes": {},\n                  "children": [],\n                  "textContent": "B de Barce"\n                },\n                {\n                  "tagName": "b",\n                  "status": "",\n                  "attributes": {},\n                  "children": [\n                    {\n                      "tagName": "",\n                      "status": "",\n                      "attributes": {},\n                      "children": [],\n                      "textContent": "lo"\n                    }\n                  ],\n                  "textContent": "lo"\n                },\n                {\n                  "tagName": "",\n                  "status": "",\n                  "attributes": {},\n                  "children": [],\n                  "textContent": "na."\n                }\n              ],\n              "textContent": "B de Barcelona."\n            }\n          ],\n          "textContent": "11  — B de Barcelona."\n        },\n        {\n          "tagName": "",\n          "status": "",\n          "attributes": {},\n          "children": [],\n          "textContent": "\\n        \\n      \\n    "\n        }\n      ],\n      "textContent": "\\n      \\n        1  — Buenas, quisiera un billete de Almería a Madrid.\\n        \\n      \\n        2  — Sacándolo de ida y vuelta tiene usted el 25 % (veinticinco por ciento) de descuento.\\n        \\n      \\n        3  — De ida y vuelta entonces: salgo el uno de junio y vuelvo el quince.\\n        \\n      \\n        4  — ¿Desea turista o preferente?\\n        \\n      \\n        5  — Preferente solo le cuesta seis euros más. Es una oferta.\\n        \\n      \\n        6  — ¡Pues preferente entonces! Pero, qué cabeza tengo…, no encuentro la tarjeta.\\n        \\n      \\n        7  — Le doy un número de reserva y paga usted después, con tarjeta o en efectivo, ¿vale?\\n        \\n      \\n        8 La salida es a las 7 y 10 de la mañana y la vuelta a las 3 y media de la tarde.\\n        \\n      \\n        9 Apunte: XH553WB.\\n        \\n      \\n        10  — Perdón, ¿la última letra es B o D?\\n        \\n      \\n        11  — B de Barcelona.\\n        \\n      \\n    "\n    },\n    {\n      "tagName": "",\n      "status": "",\n      "attributes": {},\n      "children": [],\n      "textContent": "\\n    \\n      "\n    },\n    {\n      "tagName": "h2",\n      "status": "",\n      "attributes": {\n        "id": "id_13",\n        "onclick": "proceedSentence(13)"\n      },\n      "children": [\n        {\n          "tagName": "",\n          "status": "",\n          "attributes": {},\n          "children": [],\n          "textContent": "Ejer"\n        },\n        {\n          "tagName": "b",\n          "status": "",\n          "attributes": {},\n          "children": [\n            {\n              "tagName": "",\n              "status": "",\n              "attributes": {},\n              "children": [],\n              "textContent": "ci"\n            }\n          ],\n          "textContent": "ci"\n        },\n        {\n          "tagName": "",\n          "status": "",\n          "attributes": {},\n          "children": [],\n          "textContent": "cio 1 – Tra"\n        },\n        {\n          "tagName": "b",\n          "status": "",\n          "attributes": {},\n          "children": [\n            {\n              "tagName": "",\n              "status": "",\n              "attributes": {},\n              "children": [],\n              "textContent": "duz"\n            }\n          ],\n          "textContent": "duz"\n        },\n        {\n          "tagName": "",\n          "status": "",\n          "attributes": {},\n          "children": [],\n          "textContent": "ca"\n        }\n      ],\n      "textContent": "Ejercicio 1 – Traduzca"\n    },\n    {\n      "tagName": "",\n      "status": "",\n      "attributes": {},\n      "children": [],\n      "textContent": "\\n      "\n    },\n    {\n      "tagName": "div",\n      "status": "",\n      "attributes": {\n        "class": "lesson-container"\n      },\n      "children": [\n        {\n          "tagName": "",\n          "status": "",\n          "attributes": {},\n          "children": [],\n          "textContent": "\\n        \\n        \\n          "\n        },\n        {\n          "tagName": "p",\n          "status": "",\n          "attributes": {\n            "id": "id_14",\n            "onclick": "proceedSentence(14)"\n          },\n          "children": [\n            {\n              "tagName": "label",\n              "status": "",\n              "attributes": {\n                "class": "line-nr"\n              },\n              "children": [\n                {\n                  "tagName": "",\n                  "status": "",\n                  "attributes": {},\n                  "children": [],\n                  "textContent": "1"\n                }\n              ],\n              "textContent": "1"\n            },\n            {\n              "tagName": "label",\n              "status": "",\n              "attributes": {\n                "class": "dialogue-dash"\n              },\n              "children": [\n                {\n                  "tagName": "",\n                  "status": "",\n                  "attributes": {},\n                  "children": [],\n                  "textContent": "  — "\n                }\n              ],\n              "textContent": "  — "\n            },\n            {\n              "tagName": "label",\n              "status": "",\n              "attributes": {},\n              "children": [\n                {\n                  "tagName": "",\n                  "status": "",\n                  "attributes": {},\n                  "children": [],\n                  "textContent": "Qui"\n                },\n                {\n                  "tagName": "b",\n                  "status": "",\n                  "attributes": {},\n                  "children": [\n                    {\n                      "tagName": "",\n                      "status": "",\n                      "attributes": {},\n                      "children": [],\n                      "textContent": "sie"\n                    }\n                  ],\n                  "textContent": "sie"\n                },\n                {\n                  "tagName": "",\n                  "status": "",\n                  "attributes": {},\n                  "children": [],\n                  "textContent": "ra un bi"\n                },\n                {\n                  "tagName": "b",\n                  "status": "",\n                  "attributes": {},\n                  "children": [\n                    {\n                      "tagName": "",\n                      "status": "",\n                      "attributes": {},\n                      "children": [],\n                      "textContent": "lle"\n                    }\n                  ],\n                  "textContent": "lle"\n                },\n                {\n                  "tagName": "",\n                  "status": "",\n                  "attributes": {},\n                  "children": [],\n                  "textContent": "te tu"\n                },\n                {\n                  "tagName": "b",\n                  "status": "",\n                  "attributes": {},\n                  "children": [\n                    {\n                      "tagName": "",\n                      "status": "",\n                      "attributes": {},\n                      "children": [],\n                      "textContent": "ris"\n                    }\n                  ],\n                  "textContent": "ris"\n                },\n                {\n                  "tagName": "",\n                  "status": "",\n                  "attributes": {},\n                  "children": [],\n                  "textContent": "ta de "\n                },\n                {\n                  "tagName": "b",\n                  "status": "",\n                  "attributes": {},\n                  "children": [\n                    {\n                      "tagName": "",\n                      "status": "",\n                      "attributes": {},\n                      "children": [],\n                      "textContent": "i"\n                    }\n                  ],\n                  "textContent": "i"\n                },\n                {\n                  "tagName": "",\n                  "status": "",\n                  "attributes": {},\n                  "children": [],\n                  "textContent": "da y "\n                },\n                {\n                  "tagName": "b",\n                  "status": "",\n                  "attributes": {},\n                  "children": [\n                    {\n                      "tagName": "",\n                      "status": "",\n                      "attributes": {},\n                      "children": [],\n                      "textContent": "vuel"\n                    }\n                  ],\n                  "textContent": "vuel"\n                },\n                {\n                  "tagName": "",\n                  "status": "",\n                  "attributes": {},\n                  "children": [],\n                  "textContent": "ta de Barce"\n                },\n                {\n                  "tagName": "b",\n                  "status": "",\n                  "attributes": {},\n                  "children": [\n                    {\n                      "tagName": "",\n                      "status": "",\n                      "attributes": {},\n                      "children": [],\n                      "textContent": "lo"\n                    }\n                  ],\n                  "textContent": "lo"\n                },\n                {\n                  "tagName": "",\n                  "status": "",\n                  "attributes": {},\n                  "children": [],\n                  "textContent": "na a "\n                },\n                {\n                  "tagName": "b",\n                  "status": "",\n                  "attributes": {},\n                  "children": [\n                    {\n                      "tagName": "",\n                      "status": "",\n                      "attributes": {},\n                      "children": [],\n                      "textContent": "Cór"\n                    }\n                  ],\n                  "textContent": "Cór"\n                },\n                {\n                  "tagName": "",\n                  "status": "",\n                  "attributes": {},\n                  "children": [],\n                  "textContent": "doba. "\n                }\n              ],\n              "textContent": "Quisiera un billete turista de ida y vuelta de Barcelona a Córdoba. "\n            }\n          ],\n          "textContent": "1  — Quisiera un billete turista de ida y vuelta de Barcelona a Córdoba. "\n        },\n        {\n          "tagName": "",\n          "status": "",\n          "attributes": {},\n          "children": [],\n          "textContent": "\\n          \\n        \\n          "\n        },\n        {\n          "tagName": "p",\n          "status": "",\n          "attributes": {\n            "id": "id_15",\n            "onclick": "proceedSentence(15)"\n          },\n          "children": [\n            {\n              "tagName": "label",\n              "status": "",\n              "attributes": {\n                "class": "line-nr"\n              },\n              "children": [\n                {\n                  "tagName": "",\n                  "status": "",\n                  "attributes": {},\n                  "children": [],\n                  "textContent": "2"\n                }\n              ],\n              "textContent": "2"\n            },\n            {\n              "tagName": "label",\n              "status": "",\n              "attributes": {\n                "class": "dialogue-dash"\n              },\n              "children": [\n                {\n                  "tagName": "",\n                  "status": "",\n                  "attributes": {},\n                  "children": [],\n                  "textContent": "  — "\n                }\n              ],\n              "textContent": "  — "\n            },\n            {\n              "tagName": "label",\n              "status": "",\n              "attributes": {},\n              "children": [\n                {\n                  "tagName": "b",\n                  "status": "",\n                  "attributes": {},\n                  "children": [\n                    {\n                      "tagName": "",\n                      "status": "",\n                      "attributes": {},\n                      "children": [],\n                      "textContent": "Sal"\n                    }\n                  ],\n                  "textContent": "Sal"\n                },\n                {\n                  "tagName": "",\n                  "status": "",\n                  "attributes": {},\n                  "children": [],\n                  "textContent": "go el diez de e"\n                },\n                {\n                  "tagName": "b",\n                  "status": "",\n                  "attributes": {},\n                  "children": [\n                    {\n                      "tagName": "",\n                      "status": "",\n                      "attributes": {},\n                      "children": [],\n                      "textContent": "ne"\n                    }\n                  ],\n                  "textContent": "ne"\n                },\n                {\n                  "tagName": "",\n                  "status": "",\n                  "attributes": {},\n                  "children": [],\n                  "textContent": "ro por la ma"\n                },\n                {\n                  "tagName": "b",\n                  "status": "",\n                  "attributes": {},\n                  "children": [\n                    {\n                      "tagName": "",\n                      "status": "",\n                      "attributes": {},\n                      "children": [],\n                      "textContent": "ña"\n                    }\n                  ],\n                  "textContent": "ña"\n                },\n                {\n                  "tagName": "",\n                  "status": "",\n                  "attributes": {},\n                  "children": [],\n                  "textContent": "na y "\n                },\n                {\n                  "tagName": "b",\n                  "status": "",\n                  "attributes": {},\n                  "children": [\n                    {\n                      "tagName": "",\n                      "status": "",\n                      "attributes": {},\n                      "children": [],\n                      "textContent": "vuel"\n                    }\n                  ],\n                  "textContent": "vuel"\n                },\n                {\n                  "tagName": "",\n                  "status": "",\n                  "attributes": {},\n                  "children": [],\n                  "textContent": "vo el "\n                },\n                {\n                  "tagName": "b",\n                  "status": "",\n                  "attributes": {},\n                  "children": [\n                    {\n                      "tagName": "",\n                      "status": "",\n                      "attributes": {},\n                      "children": [],\n                      "textContent": "u"\n                    }\n                  ],\n                  "textContent": "u"\n                },\n                {\n                  "tagName": "",\n                  "status": "",\n                  "attributes": {},\n                  "children": [],\n                  "textContent": "no de fe"\n                },\n                {\n                  "tagName": "b",\n                  "status": "",\n                  "attributes": {},\n                  "children": [\n                    {\n                      "tagName": "",\n                      "status": "",\n                      "attributes": {},\n                      "children": [],\n                      "textContent": "bre"\n                    }\n                  ],\n                  "textContent": "bre"\n                },\n                {\n                  "tagName": "",\n                  "status": "",\n                  "attributes": {},\n                  "children": [],\n                  "textContent": "ro por la "\n                },\n                {\n                  "tagName": "b",\n                  "status": "",\n                  "attributes": {},\n                  "children": [\n                    {\n                      "tagName": "",\n                      "status": "",\n                      "attributes": {},\n                      "children": [],\n                      "textContent": "tar"\n                    }\n                  ],\n                  "textContent": "tar"\n                },\n                {\n                  "tagName": "",\n                  "status": "",\n                  "attributes": {},\n                  "children": [],\n                  "textContent": "de. "\n                }\n              ],\n              "textContent": "Salgo el diez de enero por la mañana y vuelvo el uno de febrero por la tarde. "\n            }\n          ],\n          "textContent": "2  — Salgo el diez de enero por la mañana y vuelvo el uno de febrero por la tarde. "\n        },\n        {\n          "tagName": "",\n          "status": "",\n          "attributes": {},\n          "children": [],\n          "textContent": "\\n          \\n        \\n          "\n        },\n        {\n          "tagName": "p",\n          "status": "",\n          "attributes": {\n            "id": "id_16",\n            "onclick": "proceedSentence(16)"\n          },\n          "children": [\n            {\n              "tagName": "label",\n              "status": "",\n              "attributes": {\n                "class": "line-nr"\n              },\n              "children": [\n                {\n                  "tagName": "",\n                  "status": "",\n                  "attributes": {},\n                  "children": [],\n                  "textContent": "3"\n                }\n              ],\n              "textContent": "3"\n            },\n            {\n              "tagName": "label",\n              "status": "",\n              "attributes": {\n                "class": "dialogue-dash"\n              },\n              "children": [\n                {\n                  "tagName": "",\n                  "status": "",\n                  "attributes": {},\n                  "children": [],\n                  "textContent": "  — "\n                }\n              ],\n              "textContent": "  — "\n            },\n            {\n              "tagName": "label",\n              "status": "",\n              "attributes": {},\n              "children": [\n                {\n                  "tagName": "",\n                  "status": "",\n                  "attributes": {},\n                  "children": [],\n                  "textContent": "¿De"\n                },\n                {\n                  "tagName": "b",\n                  "status": "",\n                  "attributes": {},\n                  "children": [\n                    {\n                      "tagName": "",\n                      "status": "",\n                      "attributes": {},\n                      "children": [],\n                      "textContent": "se"\n                    }\n                  ],\n                  "textContent": "se"\n                },\n                {\n                  "tagName": "",\n                  "status": "",\n                  "attributes": {},\n                  "children": [],\n                  "textContent": "a pa"\n                },\n                {\n                  "tagName": "b",\n                  "status": "",\n                  "attributes": {},\n                  "children": [\n                    {\n                      "tagName": "",\n                      "status": "",\n                      "attributes": {},\n                      "children": [],\n                      "textContent": "gar"\n                    }\n                  ],\n                  "textContent": "gar"\n                },\n                {\n                  "tagName": "",\n                  "status": "",\n                  "attributes": {},\n                  "children": [],\n                  "textContent": " con tar"\n                },\n                {\n                  "tagName": "b",\n                  "status": "",\n                  "attributes": {},\n                  "children": [\n                    {\n                      "tagName": "",\n                      "status": "",\n                      "attributes": {},\n                      "children": [],\n                      "textContent": "je"\n                    }\n                  ],\n                  "textContent": "je"\n                },\n                {\n                  "tagName": "",\n                  "status": "",\n                  "attributes": {},\n                  "children": [],\n                  "textContent": "ta o en efec"\n                },\n                {\n                  "tagName": "b",\n                  "status": "",\n                  "attributes": {},\n                  "children": [\n                    {\n                      "tagName": "",\n                      "status": "",\n                      "attributes": {},\n                      "children": [],\n                      "textContent": "ti"\n                    }\n                  ],\n                  "textContent": "ti"\n                },\n                {\n                  "tagName": "",\n                  "status": "",\n                  "attributes": {},\n                  "children": [],\n                  "textContent": "vo? "\n                }\n              ],\n              "textContent": "¿Desea pagar con tarjeta o en efectivo? "\n            }\n          ],\n          "textContent": "3  — ¿Desea pagar con tarjeta o en efectivo? "\n        },\n        {\n          "tagName": "",\n          "status": "",\n          "attributes": {},\n          "children": [],\n          "textContent": "\\n          \\n        \\n          "\n        },\n        {\n          "tagName": "p",\n          "status": "",\n          "attributes": {\n            "id": "id_17",\n            "onclick": "proceedSentence(17)"\n          },\n          "children": [\n            {\n              "tagName": "label",\n              "status": "",\n              "attributes": {\n                "class": "line-nr"\n              },\n              "children": [\n                {\n                  "tagName": "",\n                  "status": "",\n                  "attributes": {},\n                  "children": [],\n                  "textContent": "4"\n                }\n              ],\n              "textContent": "4"\n            },\n            {\n              "tagName": "label",\n              "status": "",\n              "attributes": {\n                "class": "dialogue-dash"\n              },\n              "children": [\n                {\n                  "tagName": "",\n                  "status": "",\n                  "attributes": {},\n                  "children": [],\n                  "textContent": "  — "\n                }\n              ],\n              "textContent": "  — "\n            },\n            {\n              "tagName": "label",\n              "status": "",\n              "attributes": {},\n              "children": [\n                {\n                  "tagName": "",\n                  "status": "",\n                  "attributes": {},\n                  "children": [],\n                  "textContent": "Le doy "\n                },\n                {\n                  "tagName": "b",\n                  "status": "",\n                  "attributes": {},\n                  "children": [\n                    {\n                      "tagName": "",\n                      "status": "",\n                      "attributes": {},\n                      "children": [],\n                      "textContent": "u"\n                    }\n                  ],\n                  "textContent": "u"\n                },\n                {\n                  "tagName": "",\n                  "status": "",\n                  "attributes": {},\n                  "children": [],\n                  "textContent": "na re"\n                },\n                {\n                  "tagName": "b",\n                  "status": "",\n                  "attributes": {},\n                  "children": [\n                    {\n                      "tagName": "",\n                      "status": "",\n                      "attributes": {},\n                      "children": [],\n                      "textContent": "ser"\n                    }\n                  ],\n                  "textContent": "ser"\n                },\n                {\n                  "tagName": "",\n                  "status": "",\n                  "attributes": {},\n                  "children": [],\n                  "textContent": "va con sa"\n                },\n                {\n                  "tagName": "b",\n                  "status": "",\n                  "attributes": {},\n                  "children": [\n                    {\n                      "tagName": "",\n                      "status": "",\n                      "attributes": {},\n                      "children": [],\n                      "textContent": "li"\n                    }\n                  ],\n                  "textContent": "li"\n                },\n                {\n                  "tagName": "",\n                  "status": "",\n                  "attributes": {},\n                  "children": [],\n                  "textContent": "da a las "\n                },\n                {\n                  "tagName": "b",\n                  "status": "",\n                  "attributes": {},\n                  "children": [\n                    {\n                      "tagName": "",\n                      "status": "",\n                      "attributes": {},\n                      "children": [],\n                      "textContent": "o"\n                    }\n                  ],\n                  "textContent": "o"\n                },\n                {\n                  "tagName": "",\n                  "status": "",\n                  "attributes": {},\n                  "children": [],\n                  "textContent": "cho y "\n                },\n                {\n                  "tagName": "b",\n                  "status": "",\n                  "attributes": {},\n                  "children": [\n                    {\n                      "tagName": "",\n                      "status": "",\n                      "attributes": {},\n                      "children": [],\n                      "textContent": "cua"\n                    }\n                  ],\n                  "textContent": "cua"\n                },\n                {\n                  "tagName": "",\n                  "status": "",\n                  "attributes": {},\n                  "children": [],\n                  "textContent": "rto de la ma"\n                },\n                {\n                  "tagName": "b",\n                  "status": "",\n                  "attributes": {},\n                  "children": [\n                    {\n                      "tagName": "",\n                      "status": "",\n                      "attributes": {},\n                      "children": [],\n                      "textContent": "ña"\n                    }\n                  ],\n                  "textContent": "ña"\n                },\n                {\n                  "tagName": "",\n                  "status": "",\n                  "attributes": {},\n                  "children": [],\n                  "textContent": "na y "\n                },\n                {\n                  "tagName": "b",\n                  "status": "",\n                  "attributes": {},\n                  "children": [\n                    {\n                      "tagName": "",\n                      "status": "",\n                      "attributes": {},\n                      "children": [],\n                      "textContent": "vuel"\n                    }\n                  ],\n                  "textContent": "vuel"\n                },\n                {\n                  "tagName": "",\n                  "status": "",\n                  "attributes": {},\n                  "children": [],\n                  "textContent": "ta a las "\n                },\n                {\n                  "tagName": "b",\n                  "status": "",\n                  "attributes": {},\n                  "children": [\n                    {\n                      "tagName": "",\n                      "status": "",\n                      "attributes": {},\n                      "children": [],\n                      "textContent": "sie"\n                    }\n                  ],\n                  "textContent": "sie"\n                },\n                {\n                  "tagName": "",\n                  "status": "",\n                  "attributes": {},\n                  "children": [],\n                  "textContent": "te y "\n                },\n                {\n                  "tagName": "b",\n                  "status": "",\n                  "attributes": {},\n                  "children": [\n                    {\n                      "tagName": "",\n                      "status": "",\n                      "attributes": {},\n                      "children": [],\n                      "textContent": "me"\n                    }\n                  ],\n                  "textContent": "me"\n                },\n                {\n                  "tagName": "",\n                  "status": "",\n                  "attributes": {},\n                  "children": [],\n                  "textContent": "dia de la "\n                },\n                {\n                  "tagName": "b",\n                  "status": "",\n                  "attributes": {},\n                  "children": [\n                    {\n                      "tagName": "",\n                      "status": "",\n                      "attributes": {},\n                      "children": [],\n                      "textContent": "tar"\n                    }\n                  ],\n                  "textContent": "tar"\n                },\n                {\n                  "tagName": "",\n                  "status": "",\n                  "attributes": {},\n                  "children": [],\n                  "textContent": "de, ¿"\n                },\n                {\n                  "tagName": "b",\n                  "status": "",\n                  "attributes": {},\n                  "children": [\n                    {\n                      "tagName": "",\n                      "status": "",\n                      "attributes": {},\n                      "children": [],\n                      "textContent": "va"\n                    }\n                  ],\n                  "textContent": "va"\n                },\n                {\n                  "tagName": "",\n                  "status": "",\n                  "attributes": {},\n                  "children": [],\n                  "textContent": "le?"\n                }\n              ],\n              "textContent": "Le doy una reserva con salida a las ocho y cuarto de la mañana y vuelta a las siete y media de la tarde, ¿vale?"\n            }\n          ],\n          "textContent": "4  — Le doy una reserva con salida a las ocho y cuarto de la mañana y vuelta a las siete y media de la tarde, ¿vale?"\n        },\n        {\n          "tagName": "",\n          "status": "",\n          "attributes": {},\n          "children": [],\n          "textContent": "\\n          \\n        \\n          "\n        },\n        {\n          "tagName": "p",\n          "status": "",\n          "attributes": {\n            "id": "id_18",\n            "onclick": "proceedSentence(18)"\n          },\n          "children": [\n            {\n              "tagName": "label",\n              "status": "",\n              "attributes": {\n                "class": "line-nr"\n              },\n              "children": [\n                {\n                  "tagName": "",\n                  "status": "",\n                  "attributes": {},\n                  "children": [],\n                  "textContent": "5"\n                }\n              ],\n              "textContent": "5"\n            },\n            {\n              "tagName": "label",\n              "status": "",\n              "attributes": {\n                "class": "dialogue-dash"\n              },\n              "children": [\n                {\n                  "tagName": "",\n                  "status": "",\n                  "attributes": {},\n                  "children": [],\n                  "textContent": "  — "\n                }\n              ],\n              "textContent": "  — "\n            },\n            {\n              "tagName": "label",\n              "status": "",\n              "attributes": {},\n              "children": [\n                {\n                  "tagName": "",\n                  "status": "",\n                  "attributes": {},\n                  "children": [],\n                  "textContent": "A"\n                },\n                {\n                  "tagName": "b",\n                  "status": "",\n                  "attributes": {},\n                  "children": [\n                    {\n                      "tagName": "",\n                      "status": "",\n                      "attributes": {},\n                      "children": [],\n                      "textContent": "pun"\n                    }\n                  ],\n                  "textContent": "pun"\n                },\n                {\n                  "tagName": "",\n                  "status": "",\n                  "attributes": {},\n                  "children": [],\n                  "textContent": "te el "\n                },\n                {\n                  "tagName": "b",\n                  "status": "",\n                  "attributes": {},\n                  "children": [\n                    {\n                      "tagName": "",\n                      "status": "",\n                      "attributes": {},\n                      "children": [],\n                      "textContent": "nú"\n                    }\n                  ],\n                  "textContent": "nú"\n                },\n                {\n                  "tagName": "",\n                  "status": "",\n                  "attributes": {},\n                  "children": [],\n                  "textContent": "mero, por fa"\n                },\n                {\n                  "tagName": "b",\n                  "status": "",\n                  "attributes": {},\n                  "children": [\n                    {\n                      "tagName": "",\n                      "status": "",\n                      "attributes": {},\n                      "children": [],\n                      "textContent": "vor"\n                    }\n                  ],\n                  "textContent": "vor"\n                },\n                {\n                  "tagName": "",\n                  "status": "",\n                  "attributes": {},\n                  "children": [],\n                  "textContent": "."\n                }\n              ],\n              "textContent": "Apunte el número, por favor."\n            }\n          ],\n          "textContent": "5  — Apunte el número, por favor."\n        },\n        {\n          "tagName": "",\n          "status": "",\n          "attributes": {},\n          "children": [],\n          "textContent": "\\n          \\n        \\n      "\n        }\n      ],\n      "textContent": "\\n        \\n        \\n          1  — Quisiera un billete turista de ida y vuelta de Barcelona a Córdoba. \\n          \\n        \\n          2  — Salgo el diez de enero por la mañana y vuelvo el uno de febrero por la tarde. \\n          \\n        \\n          3  — ¿Desea pagar con tarjeta o en efectivo? \\n          \\n        \\n          4  — Le doy una reserva con salida a las ocho y cuarto de la mañana y vuelta a las siete y media de la tarde, ¿vale?\\n          \\n        \\n          5  — Apunte el número, por favor.\\n          \\n        \\n      "\n    },\n    {\n      "tagName": "",\n      "status": "",\n      "attributes": {},\n      "children": [],\n      "textContent": "\\n    \\n"\n    }\n  ],\n  "textContent": "\\n    \\n     Lección veintinueve \\n     Quisiera un billete para… \\n    \\n      \\n        1  — Buenas, quisiera un billete de Almería a Madrid.\\n        \\n      \\n        2  — Sacándolo de ida y vuelta tiene usted el 25 % (veinticinco por ciento) de descuento.\\n        \\n      \\n        3  — De ida y vuelta entonces: salgo el uno de junio y vuelvo el quince.\\n        \\n      \\n        4  — ¿Desea turista o preferente?\\n        \\n      \\n        5  — Preferente solo le cuesta seis euros más. Es una oferta.\\n        \\n      \\n        6  — ¡Pues preferente entonces! Pero, qué cabeza tengo…, no encuentro la tarjeta.\\n        \\n      \\n        7  — Le doy un número de reserva y paga usted después, con tarjeta o en efectivo, ¿vale?\\n        \\n      \\n        8 La salida es a las 7 y 10 de la mañana y la vuelta a las 3 y media de la tarde.\\n        \\n      \\n        9 Apunte: XH553WB.\\n        \\n      \\n        10  — Perdón, ¿la última letra es B o D?\\n        \\n      \\n        11  — B de Barcelona.\\n        \\n      \\n    \\n    \\n      Ejercicio 1 – Traduzca\\n      \\n        \\n        \\n          1  — Quisiera un billete turista de ida y vuelta de Barcelona a Córdoba. \\n          \\n        \\n          2  — Salgo el diez de enero por la mañana y vuelvo el uno de febrero por la tarde. \\n          \\n        \\n          3  — ¿Desea pagar con tarjeta o en efectivo? \\n          \\n        \\n          4  — Le doy una reserva con salida a las ocho y cuarto de la mañana y vuelta a las siete y media de la tarde, ¿vale?\\n          \\n        \\n          5  — Apunte el número, por favor.\\n          \\n        \\n      \\n    \\n"\n}'

# %%
print(editor)
# Out:
# {
#   "tagName": "div",
#   "status": "",
#   "attributes": {
#     "id": "editor"
#   },
#   "children": [
#     {
#       "tagName": "",
#       "status": "",
#       "attributes": {},
#       "children": [],
#       "textContent": "\n    \n    "
#     },
#     {
#       "tagName": "h2",
#       "status": "",
#       "attributes": {
#         "class": "assimil-title",
#         "id": "id_0",
#         "onclick": "proceedSentence(0)"
#       },
#       "children": [
#         {
#           "tagName": "",
#           "status": "",
#           "attributes": {},
#           "children": [],
#           "textContent": " Lec"
#         },
#         {
#           "tagName": "b",
#           "status": "",
#           "attributes": {},
#           "children": [
#             {
#               "tagName": "",
#               "status": "",
#               "attributes": {},
#               "children": [],
#               "textContent": "ción"
#             }
#           ],
# ...

# %%
def proceedElement(element):
    if element['status'] != '':
        print(element)
    for child in element['children']:
        proceedElement(child)

# %%
proceedElement(editor)
# Out:
# {'tagName': '', 'status': 'isAnchor', 'attributes': {}, 'children': [], 'textContent': 'Bue'}
# {'tagName': '', 'status': 'isFocus', 'attributes': {}, 'children': [], 'textContent': 'nas, qui'}

# %%
editorDomString='{\n  "tagName": "div",\n  "status": "",\n  "attributes": {\n    "id": "editor"\n  },\n  "children": [\n    {\n      "tagName": "",\n      "status": "",\n      "attributes": {},\n      "children": [],\n      "textContent": "\\n    \\n    "\n    },\n    {\n      "tagName": "h2",\n      "status": "",\n      "attributes": {\n        "class": "assimil-title",\n        "id": "id_0",\n        "onclick": "proceedSentence(0)"\n      },\n      "children": [\n        {\n          "tagName": "",\n          "status": "",\n          "attributes": {},\n          "children": [],\n          "textContent": " Lec"\n        },\n        {\n          "tagName": "b",\n          "status": "",\n          "attributes": {},\n          "children": [\n            {\n              "tagName": "",\n              "status": "",\n              "attributes": {},\n              "children": [],\n              "textContent": "ción"\n            }\n          ],\n          "textContent": "ción"\n        },\n        {\n          "tagName": "",\n          "status": "",\n          "attributes": {},\n          "children": [],\n          "textContent": " veinti"\n        },\n        {\n          "tagName": "b",\n          "status": "",\n          "attributes": {},\n          "children": [\n            {\n              "tagName": "",\n              "status": "",\n              "attributes": {},\n              "children": [],\n              "textContent": "nue"\n            }\n          ],\n          "textContent": "nue"\n        },\n        {\n          "tagName": "",\n          "status": "",\n          "attributes": {},\n          "children": [],\n          "textContent": "ve "\n        }\n      ],\n      "textContent": " Lección veintinueve "\n    },\n    {\n      "tagName": "",\n      "status": "",\n      "attributes": {},\n      "children": [],\n      "textContent": "\\n    "\n    },\n    {\n      "tagName": "h2",\n      "status": "",\n      "attributes": {\n        "id": "id_1",\n        "onclick": "proceedSentence(1)"\n      },\n      "children": [\n        {\n          "tagName": "",\n          "status": "",\n          "attributes": {},\n          "children": [],\n          "textContent": " Qui"\n        },\n        {\n          "tagName": "b",\n          "status": "",\n          "attributes": {},\n          "children": [\n            {\n              "tagName": "",\n              "status": "",\n              "attributes": {},\n              "children": [],\n              "textContent": "sie"\n            }\n          ],\n          "textContent": "sie"\n        },\n        {\n          "tagName": "",\n          "status": "",\n          "attributes": {},\n          "children": [],\n          "textContent": "ra un bi"\n        },\n        {\n          "tagName": "b",\n          "status": "",\n          "attributes": {},\n          "children": [\n            {\n              "tagName": "",\n              "status": "",\n              "attributes": {},\n              "children": [],\n              "textContent": "lle"\n            }\n          ],\n          "textContent": "lle"\n        },\n        {\n          "tagName": "",\n          "status": "",\n          "attributes": {},\n          "children": [],\n          "textContent": "te "\n        },\n        {\n          "tagName": "b",\n          "status": "",\n          "attributes": {},\n          "children": [\n            {\n              "tagName": "",\n              "status": "",\n              "attributes": {},\n              "children": [],\n              "textContent": "pa"\n            }\n          ],\n          "textContent": "pa"\n        },\n        {\n          "tagName": "",\n          "status": "",\n          "attributes": {},\n          "children": [],\n          "textContent": "ra… "\n        }\n      ],\n      "textContent": " Quisiera un billete para… "\n    },\n    {\n      "tagName": "",\n      "status": "",\n      "attributes": {},\n      "children": [],\n      "textContent": "\\n    "\n    },\n    {\n      "tagName": "div",\n      "status": "",\n      "attributes": {\n        "class": "lesson-container"\n      },\n      "children": [\n        {\n          "tagName": "",\n          "status": "",\n          "attributes": {},\n          "children": [],\n          "textContent": "\\n      \\n        "\n        },\n        {\n          "tagName": "p",\n          "status": "",\n          "attributes": {\n            "id": "id_2",\n            "onclick": "proceedSentence(2)",\n            "class": "activeP"\n          },\n          "children": [\n            {\n              "tagName": "label",\n              "status": "",\n              "attributes": {\n                "class": "line-nr"\n              },\n              "children": [\n                {\n                  "tagName": "",\n                  "status": "",\n                  "attributes": {},\n                  "children": [],\n                  "textContent": "1"\n                }\n              ],\n              "textContent": "1"\n            },\n            {\n              "tagName": "label",\n              "status": "",\n              "attributes": {\n                "class": "dialogue-dash"\n              },\n              "children": [\n                {\n                  "tagName": "",\n                  "status": "",\n                  "attributes": {},\n                  "children": [],\n                  "textContent": "  — "\n                }\n              ],\n              "textContent": "  — "\n            },\n            {\n              "tagName": "label",\n              "status": "",\n              "attributes": {\n                "class": "activeBox normalText"\n              },\n              "children": [\n                {\n                  "tagName": "b",\n                  "status": "",\n                  "attributes": {},\n                  "children": [\n                    {\n                      "tagName": "",\n                      "status": "isAnchor",\n                      "attributes": {},\n                      "children": [],\n                      "textContent": "Bue"\n                    }\n                  ],\n                  "textContent": "Bue"\n                },\n                {\n                  "tagName": "",\n                  "status": "isFocus",\n                  "attributes": {},\n                  "children": [],\n                  "textContent": "nas, qui"\n                },\n                {\n                  "tagName": "b",\n                  "status": "",\n                  "attributes": {},\n                  "children": [\n                    {\n                      "tagName": "",\n                      "status": "",\n                      "attributes": {},\n                      "children": [],\n                      "textContent": "sie"\n                    }\n                  ],\n                  "textContent": "sie"\n                },\n                {\n                  "tagName": "",\n                  "status": "",\n                  "attributes": {},\n                  "children": [],\n                  "textContent": "ra un bi"\n                },\n                {\n                  "tagName": "b",\n                  "status": "",\n                  "attributes": {},\n                  "children": [\n                    {\n                      "tagName": "",\n                      "status": "",\n                      "attributes": {},\n                      "children": [],\n                      "textContent": "lle"\n                    }\n                  ],\n                  "textContent": "lle"\n                },\n                {\n                  "tagName": "",\n                  "status": "",\n                  "attributes": {},\n                  "children": [],\n                  "textContent": "te de Alme"\n                },\n                {\n                  "tagName": "b",\n                  "status": "",\n                  "attributes": {},\n                  "children": [\n                    {\n                      "tagName": "",\n                      "status": "",\n                      "attributes": {},\n                      "children": [],\n                      "textContent": "rí"\n                    }\n                  ],\n                  "textContent": "rí"\n                },\n                {\n                  "tagName": "",\n                  "status": "",\n                  "attributes": {},\n                  "children": [],\n                  "textContent": "a a Ma"\n                },\n                {\n                  "tagName": "b",\n                  "status": "",\n                  "attributes": {},\n                  "children": [\n                    {\n                      "tagName": "",\n                      "status": "",\n                      "attributes": {},\n                      "children": [],\n                      "textContent": "drid"\n                    }\n                  ],\n                  "textContent": "drid"\n                },\n                {\n                  "tagName": "",\n                  "status": "",\n                  "attributes": {},\n                  "children": [],\n                  "textContent": "."\n                }\n              ],\n              "textContent": "Buenas, quisiera un billete de Almería a Madrid."\n            }\n          ],\n          "textContent": "1  — Buenas, quisiera un billete de Almería a Madrid."\n        },\n        {\n          "tagName": "",\n          "status": "",\n          "attributes": {},\n          "children": [],\n          "textContent": "\\n        \\n      \\n        "\n        },\n        {\n          "tagName": "p",\n          "status": "",\n          "attributes": {\n            "id": "id_3",\n            "onclick": "proceedSentence(3)"\n          },\n          "children": [\n            {\n              "tagName": "label",\n              "status": "",\n              "attributes": {\n                "class": "line-nr"\n              },\n              "children": [\n                {\n                  "tagName": "",\n                  "status": "",\n                  "attributes": {},\n                  "children": [],\n                  "textContent": "2"\n                }\n              ],\n              "textContent": "2"\n            },\n            {\n              "tagName": "label",\n              "status": "",\n              "attributes": {\n                "class": "dialogue-dash"\n              },\n              "children": [\n                {\n                  "tagName": "",\n                  "status": "",\n                  "attributes": {},\n                  "children": [],\n                  "textContent": "  — "\n                }\n              ],\n              "textContent": "  — "\n            },\n            {\n              "tagName": "label",\n              "status": "",\n              "attributes": {},\n              "children": [\n                {\n                  "tagName": "",\n                  "status": "",\n                  "attributes": {},\n                  "children": [],\n                  "textContent": "Sa"\n                },\n                {\n                  "tagName": "b",\n                  "status": "",\n                  "attributes": {},\n                  "children": [\n                    {\n                      "tagName": "",\n                      "status": "",\n                      "attributes": {},\n                      "children": [],\n                      "textContent": "cán"\n                    }\n                  ],\n                  "textContent": "cán"\n                },\n                {\n                  "tagName": "",\n                  "status": "",\n                  "attributes": {},\n                  "children": [],\n                  "textContent": "dolo de "\n                },\n                {\n                  "tagName": "b",\n                  "status": "",\n                  "attributes": {},\n                  "children": [\n                    {\n                      "tagName": "",\n                      "status": "",\n                      "attributes": {},\n                      "children": [],\n                      "textContent": "i"\n                    }\n                  ],\n                  "textContent": "i"\n                },\n                {\n                  "tagName": "",\n                  "status": "",\n                  "attributes": {},\n                  "children": [],\n                  "textContent": "da y "\n                },\n                {\n                  "tagName": "b",\n                  "status": "",\n                  "attributes": {},\n                  "children": [\n                    {\n                      "tagName": "",\n                      "status": "",\n                      "attributes": {},\n                      "children": [],\n                      "textContent": "vuel"\n                    }\n                  ],\n                  "textContent": "vuel"\n                },\n                {\n                  "tagName": "",\n                  "status": "",\n                  "attributes": {},\n                  "children": [],\n                  "textContent": "ta "\n                },\n                {\n                  "tagName": "b",\n                  "status": "",\n                  "attributes": {},\n                  "children": [\n                    {\n                      "tagName": "",\n                      "status": "",\n                      "attributes": {},\n                      "children": [],\n                      "textContent": "tie"\n                    }\n                  ],\n                  "textContent": "tie"\n                },\n                {\n                  "tagName": "",\n                  "status": "",\n                  "attributes": {},\n                  "children": [],\n                  "textContent": "ne us"\n                },\n                {\n                  "tagName": "b",\n                  "status": "",\n                  "attributes": {},\n                  "children": [\n                    {\n                      "tagName": "",\n                      "status": "",\n                      "attributes": {},\n                      "children": [],\n                      "textContent": "ted"\n                    }\n                  ],\n                  "textContent": "ted"\n                },\n                {\n                  "tagName": "",\n                  "status": "",\n                  "attributes": {},\n                  "children": [],\n                  "textContent": " el 25 % (veinti"\n                },\n                {\n                  "tagName": "b",\n                  "status": "",\n                  "attributes": {},\n                  "children": [\n                    {\n                      "tagName": "",\n                      "status": "",\n                      "attributes": {},\n                      "children": [],\n                      "textContent": "cin"\n                    }\n                  ],\n                  "textContent": "cin"\n                },\n                {\n                  "tagName": "",\n                  "status": "",\n                  "attributes": {},\n                  "children": [],\n                  "textContent": "co por "\n                },\n                {\n                  "tagName": "b",\n                  "status": "",\n                  "attributes": {},\n                  "children": [\n                    {\n                      "tagName": "",\n                      "status": "",\n                      "attributes": {},\n                      "children": [],\n                      "textContent": "cien"\n                    }\n                  ],\n                  "textContent": "cien"\n                },\n                {\n                  "tagName": "",\n                  "status": "",\n                  "attributes": {},\n                  "children": [],\n                  "textContent": "to) de des"\n                },\n                {\n                  "tagName": "b",\n                  "status": "",\n                  "attributes": {},\n                  "children": [\n                    {\n                      "tagName": "",\n                      "status": "",\n                      "attributes": {},\n                      "children": [],\n                      "textContent": "cuen"\n                    }\n                  ],\n                  "textContent": "cuen"\n                },\n                {\n                  "tagName": "",\n                  "status": "",\n                  "attributes": {},\n                  "children": [],\n                  "textContent": "to."\n                }\n              ],\n              "textContent": "Sacándolo de ida y vuelta tiene usted el 25 % (veinticinco por ciento) de descuento."\n            }\n          ],\n          "textContent": "2  — Sacándolo de ida y vuelta tiene usted el 25 % (veinticinco por ciento) de descuento."\n        },\n        {\n          "tagName": "",\n          "status": "",\n          "attributes": {},\n          "children": [],\n          "textContent": "\\n        \\n      \\n        "\n        },\n        {\n          "tagName": "p",\n          "status": "",\n          "attributes": {\n            "id": "id_4",\n            "onclick": "proceedSentence(4)"\n          },\n          "children": [\n            {\n              "tagName": "label",\n              "status": "",\n              "attributes": {\n                "class": "line-nr"\n              },\n              "children": [\n                {\n                  "tagName": "",\n                  "status": "",\n                  "attributes": {},\n                  "children": [],\n                  "textContent": "3"\n                }\n              ],\n              "textContent": "3"\n            },\n            {\n              "tagName": "label",\n              "status": "",\n              "attributes": {\n                "class": "dialogue-dash"\n              },\n              "children": [\n                {\n                  "tagName": "",\n                  "status": "",\n                  "attributes": {},\n                  "children": [],\n                  "textContent": "  — "\n                }\n              ],\n              "textContent": "  — "\n            },\n            {\n              "tagName": "label",\n              "status": "",\n              "attributes": {},\n              "children": [\n                {\n                  "tagName": "",\n                  "status": "",\n                  "attributes": {},\n                  "children": [],\n                  "textContent": "De "\n                },\n                {\n                  "tagName": "b",\n                  "status": "",\n                  "attributes": {},\n                  "children": [\n                    {\n                      "tagName": "",\n                      "status": "",\n                      "attributes": {},\n                      "children": [],\n                      "textContent": "i"\n                    }\n                  ],\n                  "textContent": "i"\n                },\n                {\n                  "tagName": "",\n                  "status": "",\n                  "attributes": {},\n                  "children": [],\n                  "textContent": "da y "\n                },\n                {\n                  "tagName": "b",\n                  "status": "",\n                  "attributes": {},\n                  "children": [\n                    {\n                      "tagName": "",\n                      "status": "",\n                      "attributes": {},\n                      "children": [],\n                      "textContent": "vuel"\n                    }\n                  ],\n                  "textContent": "vuel"\n                },\n                {\n                  "tagName": "",\n                  "status": "",\n                  "attributes": {},\n                  "children": [],\n                  "textContent": "ta en"\n                },\n                {\n                  "tagName": "b",\n                  "status": "",\n                  "attributes": {},\n                  "children": [\n                    {\n                      "tagName": "",\n                      "status": "",\n                      "attributes": {},\n                      "children": [],\n                      "textContent": "ton"\n                    }\n                  ],\n                  "textContent": "ton"\n                },\n                {\n                  "tagName": "",\n                  "status": "",\n                  "attributes": {},\n                  "children": [],\n                  "textContent": "ces: "\n                },\n                {\n                  "tagName": "b",\n                  "status": "",\n                  "attributes": {},\n                  "children": [\n                    {\n                      "tagName": "",\n                      "status": "",\n                      "attributes": {},\n                      "children": [],\n                      "textContent": "sal"\n                    }\n                  ],\n                  "textContent": "sal"\n                },\n                {\n                  "tagName": "",\n                  "status": "",\n                  "attributes": {},\n                  "children": [],\n                  "textContent": "go el "\n                },\n                {\n                  "tagName": "b",\n                  "status": "",\n                  "attributes": {},\n                  "children": [\n                    {\n                      "tagName": "",\n                      "status": "",\n                      "attributes": {},\n                      "children": [],\n                      "textContent": "u"\n                    }\n                  ],\n                  "textContent": "u"\n                },\n                {\n                  "tagName": "",\n                  "status": "",\n                  "attributes": {},\n                  "children": [],\n                  "textContent": "no de "\n                },\n                {\n                  "tagName": "b",\n                  "status": "",\n                  "attributes": {},\n                  "children": [\n                    {\n                      "tagName": "",\n                      "status": "",\n                      "attributes": {},\n                      "children": [],\n                      "textContent": "ju"\n                    }\n                  ],\n                  "textContent": "ju"\n                },\n                {\n                  "tagName": "",\n                  "status": "",\n                  "attributes": {},\n                  "children": [],\n                  "textContent": "nio y "\n                },\n                {\n                  "tagName": "b",\n                  "status": "",\n                  "attributes": {},\n                  "children": [\n                    {\n                      "tagName": "",\n                      "status": "",\n                      "attributes": {},\n                      "children": [],\n                      "textContent": "vuel"\n                    }\n                  ],\n                  "textContent": "vuel"\n                },\n                {\n                  "tagName": "",\n                  "status": "",\n                  "attributes": {},\n                  "children": [],\n                  "textContent": "vo el "\n                },\n                {\n                  "tagName": "b",\n                  "status": "",\n                  "attributes": {},\n                  "children": [\n                    {\n                      "tagName": "",\n                      "status": "",\n                      "attributes": {},\n                      "children": [],\n                      "textContent": "quin"\n                    }\n                  ],\n                  "textContent": "quin"\n                },\n                {\n                  "tagName": "",\n                  "status": "",\n                  "attributes": {},\n                  "children": [],\n                  "textContent": "ce."\n                }\n              ],\n              "textContent": "De ida y vuelta entonces: salgo el uno de junio y vuelvo el quince."\n            }\n          ],\n          "textContent": "3  — De ida y vuelta entonces: salgo el uno de junio y vuelvo el quince."\n        },\n        {\n          "tagName": "",\n          "status": "",\n          "attributes": {},\n          "children": [],\n          "textContent": "\\n        \\n      \\n        "\n        },\n        {\n          "tagName": "p",\n          "status": "",\n          "attributes": {\n            "id": "id_5",\n            "onclick": "proceedSentence(5)"\n          },\n          "children": [\n            {\n              "tagName": "label",\n              "status": "",\n              "attributes": {\n                "class": "line-nr"\n              },\n              "children": [\n                {\n                  "tagName": "",\n                  "status": "",\n                  "attributes": {},\n                  "children": [],\n                  "textContent": "4"\n                }\n              ],\n              "textContent": "4"\n            },\n            {\n              "tagName": "label",\n              "status": "",\n              "attributes": {\n                "class": "dialogue-dash"\n              },\n              "children": [\n                {\n                  "tagName": "",\n                  "status": "",\n                  "attributes": {},\n                  "children": [],\n                  "textContent": "  — "\n                }\n              ],\n              "textContent": "  — "\n            },\n            {\n              "tagName": "label",\n              "status": "",\n              "attributes": {},\n              "children": [\n                {\n                  "tagName": "",\n                  "status": "",\n                  "attributes": {},\n                  "children": [],\n                  "textContent": "¿De"\n                },\n                {\n                  "tagName": "b",\n                  "status": "",\n                  "attributes": {},\n                  "children": [\n                    {\n                      "tagName": "",\n                      "status": "",\n                      "attributes": {},\n                      "children": [],\n                      "textContent": "se"\n                    }\n                  ],\n                  "textContent": "se"\n                },\n                {\n                  "tagName": "",\n                  "status": "",\n                  "attributes": {},\n                  "children": [],\n                  "textContent": "a tu"\n                },\n                {\n                  "tagName": "b",\n                  "status": "",\n                  "attributes": {},\n                  "children": [\n                    {\n                      "tagName": "",\n                      "status": "",\n                      "attributes": {},\n                      "children": [],\n                      "textContent": "ris"\n                    }\n                  ],\n                  "textContent": "ris"\n                },\n                {\n                  "tagName": "",\n                  "status": "",\n                  "attributes": {},\n                  "children": [],\n                  "textContent": "ta o prefe"\n                },\n                {\n                  "tagName": "b",\n                  "status": "",\n                  "attributes": {},\n                  "children": [\n                    {\n                      "tagName": "",\n                      "status": "",\n                      "attributes": {},\n                      "children": [],\n                      "textContent": "ren"\n                    }\n                  ],\n                  "textContent": "ren"\n                },\n                {\n                  "tagName": "",\n                  "status": "",\n                  "attributes": {},\n                  "children": [],\n                  "textContent": "te?"\n                }\n              ],\n              "textContent": "¿Desea turista o preferente?"\n            }\n          ],\n          "textContent": "4  — ¿Desea turista o preferente?"\n        },\n        {\n          "tagName": "",\n          "status": "",\n          "attributes": {},\n          "children": [],\n          "textContent": "\\n        \\n      \\n        "\n        },\n        {\n          "tagName": "p",\n          "status": "",\n          "attributes": {\n            "id": "id_6",\n            "onclick": "proceedSentence(6)"\n          },\n          "children": [\n            {\n              "tagName": "label",\n              "status": "",\n              "attributes": {\n                "class": "line-nr"\n              },\n              "children": [\n                {\n                  "tagName": "",\n                  "status": "",\n                  "attributes": {},\n                  "children": [],\n                  "textContent": "5"\n                }\n              ],\n              "textContent": "5"\n            },\n            {\n              "tagName": "label",\n              "status": "",\n              "attributes": {\n                "class": "dialogue-dash"\n              },\n              "children": [\n                {\n                  "tagName": "",\n                  "status": "",\n                  "attributes": {},\n                  "children": [],\n                  "textContent": "  — "\n                }\n              ],\n              "textContent": "  — "\n            },\n            {\n              "tagName": "label",\n              "status": "",\n              "attributes": {},\n              "children": [\n                {\n                  "tagName": "",\n                  "status": "",\n                  "attributes": {},\n                  "children": [],\n                  "textContent": "Prefe"\n                },\n                {\n                  "tagName": "b",\n                  "status": "",\n                  "attributes": {},\n                  "children": [\n                    {\n                      "tagName": "",\n                      "status": "",\n                      "attributes": {},\n                      "children": [],\n                      "textContent": "ren"\n                    }\n                  ],\n                  "textContent": "ren"\n                },\n                {\n                  "tagName": "",\n                  "status": "",\n                  "attributes": {},\n                  "children": [],\n                  "textContent": "te "\n                },\n                {\n                  "tagName": "b",\n                  "status": "",\n                  "attributes": {},\n                  "children": [\n                    {\n                      "tagName": "",\n                      "status": "",\n                      "attributes": {},\n                      "children": [],\n                      "textContent": "so"\n                    }\n                  ],\n                  "textContent": "so"\n                },\n                {\n                  "tagName": "",\n                  "status": "",\n                  "attributes": {},\n                  "children": [],\n                  "textContent": "lo le "\n                },\n                {\n                  "tagName": "b",\n                  "status": "",\n                  "attributes": {},\n                  "children": [\n                    {\n                      "tagName": "",\n                      "status": "",\n                      "attributes": {},\n                      "children": [],\n                      "textContent": "cues"\n                    }\n                  ],\n                  "textContent": "cues"\n                },\n                {\n                  "tagName": "",\n                  "status": "",\n                  "attributes": {},\n                  "children": [],\n                  "textContent": "ta seis "\n                },\n                {\n                  "tagName": "b",\n                  "status": "",\n                  "attributes": {},\n                  "children": [\n                    {\n                      "tagName": "",\n                      "status": "",\n                      "attributes": {},\n                      "children": [],\n                      "textContent": "eu"\n                    }\n                  ],\n                  "textContent": "eu"\n                },\n                {\n                  "tagName": "",\n                  "status": "",\n                  "attributes": {},\n                  "children": [],\n                  "textContent": "ros más. Es "\n                },\n                {\n                  "tagName": "b",\n                  "status": "",\n                  "attributes": {},\n                  "children": [\n                    {\n                      "tagName": "",\n                      "status": "",\n                      "attributes": {},\n                      "children": [],\n                      "textContent": "u"\n                    }\n                  ],\n                  "textContent": "u"\n                },\n                {\n                  "tagName": "",\n                  "status": "",\n                  "attributes": {},\n                  "children": [],\n                  "textContent": "na o"\n                },\n                {\n                  "tagName": "b",\n                  "status": "",\n                  "attributes": {},\n                  "children": [\n                    {\n                      "tagName": "",\n                      "status": "",\n                      "attributes": {},\n                      "children": [],\n                      "textContent": "fer"\n                    }\n                  ],\n                  "textContent": "fer"\n                },\n                {\n                  "tagName": "",\n                  "status": "",\n                  "attributes": {},\n                  "children": [],\n                  "textContent": "ta."\n                }\n              ],\n              "textContent": "Preferente solo le cuesta seis euros más. Es una oferta."\n            }\n          ],\n          "textContent": "5  — Preferente solo le cuesta seis euros más. Es una oferta."\n        },\n        {\n          "tagName": "",\n          "status": "",\n          "attributes": {},\n          "children": [],\n          "textContent": "\\n        \\n      \\n        "\n        },\n        {\n          "tagName": "p",\n          "status": "",\n          "attributes": {\n            "id": "id_7",\n            "onclick": "proceedSentence(7)"\n          },\n          "children": [\n            {\n              "tagName": "label",\n              "status": "",\n              "attributes": {\n                "class": "line-nr"\n              },\n              "children": [\n                {\n                  "tagName": "",\n                  "status": "",\n                  "attributes": {},\n                  "children": [],\n                  "textContent": "6"\n                }\n              ],\n              "textContent": "6"\n            },\n            {\n              "tagName": "label",\n              "status": "",\n              "attributes": {\n                "class": "dialogue-dash"\n              },\n              "children": [\n                {\n                  "tagName": "",\n                  "status": "",\n                  "attributes": {},\n                  "children": [],\n                  "textContent": "  — "\n                }\n              ],\n              "textContent": "  — "\n            },\n            {\n              "tagName": "label",\n              "status": "",\n              "attributes": {},\n              "children": [\n                {\n                  "tagName": "",\n                  "status": "",\n                  "attributes": {},\n                  "children": [],\n                  "textContent": "¡Pues prefe"\n                },\n                {\n                  "tagName": "b",\n                  "status": "",\n                  "attributes": {},\n                  "children": [\n                    {\n                      "tagName": "",\n                      "status": "",\n                      "attributes": {},\n                      "children": [],\n                      "textContent": "ren"\n                    }\n                  ],\n                  "textContent": "ren"\n                },\n                {\n                  "tagName": "",\n                  "status": "",\n                  "attributes": {},\n                  "children": [],\n                  "textContent": "te en"\n                },\n                {\n                  "tagName": "b",\n                  "status": "",\n                  "attributes": {},\n                  "children": [\n                    {\n                      "tagName": "",\n                      "status": "",\n                      "attributes": {},\n                      "children": [],\n                      "textContent": "ton"\n                    }\n                  ],\n                  "textContent": "ton"\n                },\n                {\n                  "tagName": "",\n                  "status": "",\n                  "attributes": {},\n                  "children": [],\n                  "textContent": "ces! "\n                },\n                {\n                  "tagName": "b",\n                  "status": "",\n                  "attributes": {},\n                  "children": [\n                    {\n                      "tagName": "",\n                      "status": "",\n                      "attributes": {},\n                      "children": [],\n                      "textContent": "Pe"\n                    }\n                  ],\n                  "textContent": "Pe"\n                },\n                {\n                  "tagName": "",\n                  "status": "",\n                  "attributes": {},\n                  "children": [],\n                  "textContent": "ro, qué ca"\n                },\n                {\n                  "tagName": "b",\n                  "status": "",\n                  "attributes": {},\n                  "children": [\n                    {\n                      "tagName": "",\n                      "status": "",\n                      "attributes": {},\n                      "children": [],\n                      "textContent": "be"\n                    }\n                  ],\n                  "textContent": "be"\n                },\n                {\n                  "tagName": "",\n                  "status": "",\n                  "attributes": {},\n                  "children": [],\n                  "textContent": "za "\n                },\n                {\n                  "tagName": "b",\n                  "status": "",\n                  "attributes": {},\n                  "children": [\n                    {\n                      "tagName": "",\n                      "status": "",\n                      "attributes": {},\n                      "children": [],\n                      "textContent": "ten"\n                    }\n                  ],\n                  "textContent": "ten"\n                },\n                {\n                  "tagName": "",\n                  "status": "",\n                  "attributes": {},\n                  "children": [],\n                  "textContent": "go…, no en"\n                },\n                {\n                  "tagName": "b",\n                  "status": "",\n                  "attributes": {},\n                  "children": [\n                    {\n                      "tagName": "",\n                      "status": "",\n                      "attributes": {},\n                      "children": [],\n                      "textContent": "cuen"\n                    }\n                  ],\n                  "textContent": "cuen"\n                },\n                {\n                  "tagName": "",\n                  "status": "",\n                  "attributes": {},\n                  "children": [],\n                  "textContent": "tro la tar"\n                },\n                {\n                  "tagName": "b",\n                  "status": "",\n                  "attributes": {},\n                  "children": [\n                    {\n                      "tagName": "",\n                      "status": "",\n                      "attributes": {},\n                      "children": [],\n                      "textContent": "je"\n                    }\n                  ],\n                  "textContent": "je"\n                },\n                {\n                  "tagName": "",\n                  "status": "",\n                  "attributes": {},\n                  "children": [],\n                  "textContent": "ta."\n                }\n              ],\n              "textContent": "¡Pues preferente entonces! Pero, qué cabeza tengo…, no encuentro la tarjeta."\n            }\n          ],\n          "textContent": "6  — ¡Pues preferente entonces! Pero, qué cabeza tengo…, no encuentro la tarjeta."\n        },\n        {\n          "tagName": "",\n          "status": "",\n          "attributes": {},\n          "children": [],\n          "textContent": "\\n        \\n      \\n        "\n        },\n        {\n          "tagName": "p",\n          "status": "",\n          "attributes": {\n            "id": "id_8",\n            "onclick": "proceedSentence(8)"\n          },\n          "children": [\n            {\n              "tagName": "label",\n              "status": "",\n              "attributes": {\n                "class": "line-nr"\n              },\n              "children": [\n                {\n                  "tagName": "",\n                  "status": "",\n                  "attributes": {},\n                  "children": [],\n                  "textContent": "7"\n                }\n              ],\n              "textContent": "7"\n            },\n            {\n              "tagName": "label",\n              "status": "",\n              "attributes": {\n                "class": "dialogue-dash"\n              },\n              "children": [\n                {\n                  "tagName": "",\n                  "status": "",\n                  "attributes": {},\n                  "children": [],\n                  "textContent": "  — "\n                }\n              ],\n              "textContent": "  — "\n            },\n            {\n              "tagName": "label",\n              "status": "",\n              "attributes": {},\n              "children": [\n                {\n                  "tagName": "",\n                  "status": "",\n                  "attributes": {},\n                  "children": [],\n                  "textContent": "Le doy un "\n                },\n                {\n                  "tagName": "b",\n                  "status": "",\n                  "attributes": {},\n                  "children": [\n                    {\n                      "tagName": "",\n                      "status": "",\n                      "attributes": {},\n                      "children": [],\n                      "textContent": "nú"\n                    }\n                  ],\n                  "textContent": "nú"\n                },\n                {\n                  "tagName": "",\n                  "status": "",\n                  "attributes": {},\n                  "children": [],\n                  "textContent": "mero de re"\n                },\n                {\n                  "tagName": "b",\n                  "status": "",\n                  "attributes": {},\n                  "children": [\n                    {\n                      "tagName": "",\n                      "status": "",\n                      "attributes": {},\n                      "children": [],\n                      "textContent": "ser"\n                    }\n                  ],\n                  "textContent": "ser"\n                },\n                {\n                  "tagName": "",\n                  "status": "",\n                  "attributes": {},\n                  "children": [],\n                  "textContent": "va y "\n                },\n                {\n                  "tagName": "b",\n                  "status": "",\n                  "attributes": {},\n                  "children": [\n                    {\n                      "tagName": "",\n                      "status": "",\n                      "attributes": {},\n                      "children": [],\n                      "textContent": "pa"\n                    }\n                  ],\n                  "textContent": "pa"\n                },\n                {\n                  "tagName": "",\n                  "status": "",\n                  "attributes": {},\n                  "children": [],\n                  "textContent": "ga us"\n                },\n                {\n                  "tagName": "b",\n                  "status": "",\n                  "attributes": {},\n                  "children": [\n                    {\n                      "tagName": "",\n                      "status": "",\n                      "attributes": {},\n                      "children": [],\n                      "textContent": "ted"\n                    }\n                  ],\n                  "textContent": "ted"\n                },\n                {\n                  "tagName": "",\n                  "status": "",\n                  "attributes": {},\n                  "children": [],\n                  "textContent": " des"\n                },\n                {\n                  "tagName": "b",\n                  "status": "",\n                  "attributes": {},\n                  "children": [\n                    {\n                      "tagName": "",\n                      "status": "",\n                      "attributes": {},\n                      "children": [],\n                      "textContent": "pués"\n                    }\n                  ],\n                  "textContent": "pués"\n                },\n                {\n                  "tagName": "",\n                  "status": "",\n                  "attributes": {},\n                  "children": [],\n                  "textContent": ", con tar"\n                },\n                {\n                  "tagName": "b",\n                  "status": "",\n                  "attributes": {},\n                  "children": [\n                    {\n                      "tagName": "",\n                      "status": "",\n                      "attributes": {},\n                      "children": [],\n                      "textContent": "je"\n                    }\n                  ],\n                  "textContent": "je"\n                },\n                {\n                  "tagName": "",\n                  "status": "",\n                  "attributes": {},\n                  "children": [],\n                  "textContent": "ta o en efec"\n                },\n                {\n                  "tagName": "b",\n                  "status": "",\n                  "attributes": {},\n                  "children": [\n                    {\n                      "tagName": "",\n                      "status": "",\n                      "attributes": {},\n                      "children": [],\n                      "textContent": "ti"\n                    }\n                  ],\n                  "textContent": "ti"\n                },\n                {\n                  "tagName": "",\n                  "status": "",\n                  "attributes": {},\n                  "children": [],\n                  "textContent": "vo, ¿"\n                },\n                {\n                  "tagName": "b",\n                  "status": "",\n                  "attributes": {},\n                  "children": [\n                    {\n                      "tagName": "",\n                      "status": "",\n                      "attributes": {},\n                      "children": [],\n                      "textContent": "va"\n                    }\n                  ],\n                  "textContent": "va"\n                },\n                {\n                  "tagName": "",\n                  "status": "",\n                  "attributes": {},\n                  "children": [],\n                  "textContent": "le?"\n                }\n              ],\n              "textContent": "Le doy un número de reserva y paga usted después, con tarjeta o en efectivo, ¿vale?"\n            }\n          ],\n          "textContent": "7  — Le doy un número de reserva y paga usted después, con tarjeta o en efectivo, ¿vale?"\n        },\n        {\n          "tagName": "",\n          "status": "",\n          "attributes": {},\n          "children": [],\n          "textContent": "\\n        \\n      \\n        "\n        },\n        {\n          "tagName": "p",\n          "status": "",\n          "attributes": {\n            "id": "id_9",\n            "onclick": "proceedSentence(9)"\n          },\n          "children": [\n            {\n              "tagName": "label",\n              "status": "",\n              "attributes": {\n                "class": "line-nr"\n              },\n              "children": [\n                {\n                  "tagName": "",\n                  "status": "",\n                  "attributes": {},\n                  "children": [],\n                  "textContent": "8"\n                }\n              ],\n              "textContent": "8"\n            },\n            {\n              "tagName": "label",\n              "status": "",\n              "attributes": {\n                "class": "dialogue-dash"\n              },\n              "children": [\n                {\n                  "tagName": "",\n                  "status": "",\n                  "attributes": {},\n                  "children": [],\n                  "textContent": " "\n                }\n              ],\n              "textContent": " "\n            },\n            {\n              "tagName": "label",\n              "status": "",\n              "attributes": {},\n              "children": [\n                {\n                  "tagName": "",\n                  "status": "",\n                  "attributes": {},\n                  "children": [],\n                  "textContent": "La sa"\n                },\n                {\n                  "tagName": "b",\n                  "status": "",\n                  "attributes": {},\n                  "children": [\n                    {\n                      "tagName": "",\n                      "status": "",\n                      "attributes": {},\n                      "children": [],\n                      "textContent": "li"\n                    }\n                  ],\n                  "textContent": "li"\n                },\n                {\n                  "tagName": "",\n                  "status": "",\n                  "attributes": {},\n                  "children": [],\n                  "textContent": "da es a las 7 y 10 de la ma"\n                },\n                {\n                  "tagName": "b",\n                  "status": "",\n                  "attributes": {},\n                  "children": [\n                    {\n                      "tagName": "",\n                      "status": "",\n                      "attributes": {},\n                      "children": [],\n                      "textContent": "ña"\n                    }\n                  ],\n                  "textContent": "ña"\n                },\n                {\n                  "tagName": "",\n                  "status": "",\n                  "attributes": {},\n                  "children": [],\n                  "textContent": "na y la "\n                },\n                {\n                  "tagName": "b",\n                  "status": "",\n                  "attributes": {},\n                  "children": [\n                    {\n                      "tagName": "",\n                      "status": "",\n                      "attributes": {},\n                      "children": [],\n                      "textContent": "vuel"\n                    }\n                  ],\n                  "textContent": "vuel"\n                },\n                {\n                  "tagName": "",\n                  "status": "",\n                  "attributes": {},\n                  "children": [],\n                  "textContent": "ta a las 3 y "\n                },\n                {\n                  "tagName": "b",\n                  "status": "",\n                  "attributes": {},\n                  "children": [\n                    {\n                      "tagName": "",\n                      "status": "",\n                      "attributes": {},\n                      "children": [],\n                      "textContent": "me"\n                    }\n                  ],\n                  "textContent": "me"\n                },\n                {\n                  "tagName": "",\n                  "status": "",\n                  "attributes": {},\n                  "children": [],\n                  "textContent": "dia de la "\n                },\n                {\n                  "tagName": "b",\n                  "status": "",\n                  "attributes": {},\n                  "children": [\n                    {\n                      "tagName": "",\n                      "status": "",\n                      "attributes": {},\n                      "children": [],\n                      "textContent": "tar"\n                    }\n                  ],\n                  "textContent": "tar"\n                },\n                {\n                  "tagName": "",\n                  "status": "",\n                  "attributes": {},\n                  "children": [],\n                  "textContent": "de."\n                }\n              ],\n              "textContent": "La salida es a las 7 y 10 de la mañana y la vuelta a las 3 y media de la tarde."\n            }\n          ],\n          "textContent": "8 La salida es a las 7 y 10 de la mañana y la vuelta a las 3 y media de la tarde."\n        },\n        {\n          "tagName": "",\n          "status": "",\n          "attributes": {},\n          "children": [],\n          "textContent": "\\n        \\n      \\n        "\n        },\n        {\n          "tagName": "p",\n          "status": "",\n          "attributes": {\n            "id": "id_10",\n            "onclick": "proceedSentence(10)"\n          },\n          "children": [\n            {\n              "tagName": "label",\n              "status": "",\n              "attributes": {\n                "class": "line-nr"\n              },\n              "children": [\n                {\n                  "tagName": "",\n                  "status": "",\n                  "attributes": {},\n                  "children": [],\n                  "textContent": "9"\n                }\n              ],\n              "textContent": "9"\n            },\n            {\n              "tagName": "label",\n              "status": "",\n              "attributes": {\n                "class": "dialogue-dash"\n              },\n              "children": [\n                {\n                  "tagName": "",\n                  "status": "",\n                  "attributes": {},\n                  "children": [],\n                  "textContent": " "\n                }\n              ],\n              "textContent": " "\n            },\n            {\n              "tagName": "label",\n              "status": "",\n              "attributes": {},\n              "children": [\n                {\n                  "tagName": "",\n                  "status": "",\n                  "attributes": {},\n                  "children": [],\n                  "textContent": "A"\n                },\n                {\n                  "tagName": "b",\n                  "status": "",\n                  "attributes": {},\n                  "children": [\n                    {\n                      "tagName": "",\n                      "status": "",\n                      "attributes": {},\n                      "children": [],\n                      "textContent": "pun"\n                    }\n                  ],\n                  "textContent": "pun"\n                },\n                {\n                  "tagName": "",\n                  "status": "",\n                  "attributes": {},\n                  "children": [],\n                  "textContent": "te: XH553WB."\n                }\n              ],\n              "textContent": "Apunte: XH553WB."\n            }\n          ],\n          "textContent": "9 Apunte: XH553WB."\n        },\n        {\n          "tagName": "",\n          "status": "",\n          "attributes": {},\n          "children": [],\n          "textContent": "\\n        \\n      \\n        "\n        },\n        {\n          "tagName": "p",\n          "status": "",\n          "attributes": {\n            "id": "id_11",\n            "onclick": "proceedSentence(11)"\n          },\n          "children": [\n            {\n              "tagName": "label",\n              "status": "",\n              "attributes": {\n                "class": "line-nr"\n              },\n              "children": [\n                {\n                  "tagName": "",\n                  "status": "",\n                  "attributes": {},\n                  "children": [],\n                  "textContent": "10"\n                }\n              ],\n              "textContent": "10"\n            },\n            {\n              "tagName": "label",\n              "status": "",\n              "attributes": {\n                "class": "dialogue-dash"\n              },\n              "children": [\n                {\n                  "tagName": "",\n                  "status": "",\n                  "attributes": {},\n                  "children": [],\n                  "textContent": "  — "\n                }\n              ],\n              "textContent": "  — "\n            },\n            {\n              "tagName": "label",\n              "status": "",\n              "attributes": {},\n              "children": [\n                {\n                  "tagName": "",\n                  "status": "",\n                  "attributes": {},\n                  "children": [],\n                  "textContent": "Per"\n                },\n                {\n                  "tagName": "b",\n                  "status": "",\n                  "attributes": {},\n                  "children": [\n                    {\n                      "tagName": "",\n                      "status": "",\n                      "attributes": {},\n                      "children": [],\n                      "textContent": "dón"\n                    }\n                  ],\n                  "textContent": "dón"\n                },\n                {\n                  "tagName": "",\n                  "status": "",\n                  "attributes": {},\n                  "children": [],\n                  "textContent": ", ¿la "\n                },\n                {\n                  "tagName": "b",\n                  "status": "",\n                  "attributes": {},\n                  "children": [\n                    {\n                      "tagName": "",\n                      "status": "",\n                      "attributes": {},\n                      "children": [],\n                      "textContent": "úl"\n                    }\n                  ],\n                  "textContent": "úl"\n                },\n                {\n                  "tagName": "",\n                  "status": "",\n                  "attributes": {},\n                  "children": [],\n                  "textContent": "tima "\n                },\n                {\n                  "tagName": "b",\n                  "status": "",\n                  "attributes": {},\n                  "children": [\n                    {\n                      "tagName": "",\n                      "status": "",\n                      "attributes": {},\n                      "children": [],\n                      "textContent": "le"\n                    }\n                  ],\n                  "textContent": "le"\n                },\n                {\n                  "tagName": "",\n                  "status": "",\n                  "attributes": {},\n                  "children": [],\n                  "textContent": "tra es B o D?"\n                }\n              ],\n              "textContent": "Perdón, ¿la última letra es B o D?"\n            }\n          ],\n          "textContent": "10  — Perdón, ¿la última letra es B o D?"\n        },\n        {\n          "tagName": "",\n          "status": "",\n          "attributes": {},\n          "children": [],\n          "textContent": "\\n        \\n      \\n        "\n        },\n        {\n          "tagName": "p",\n          "status": "",\n          "attributes": {\n            "id": "id_12",\n            "onclick": "proceedSentence(12)"\n          },\n          "children": [\n            {\n              "tagName": "label",\n              "status": "",\n              "attributes": {\n                "class": "line-nr"\n              },\n              "children": [\n                {\n                  "tagName": "",\n                  "status": "",\n                  "attributes": {},\n                  "children": [],\n                  "textContent": "11"\n                }\n              ],\n              "textContent": "11"\n            },\n            {\n              "tagName": "label",\n              "status": "",\n              "attributes": {\n                "class": "dialogue-dash"\n              },\n              "children": [\n                {\n                  "tagName": "",\n                  "status": "",\n                  "attributes": {},\n                  "children": [],\n                  "textContent": "  — "\n                }\n              ],\n              "textContent": "  — "\n            },\n            {\n              "tagName": "label",\n              "status": "",\n              "attributes": {},\n              "children": [\n                {\n                  "tagName": "",\n                  "status": "",\n                  "attributes": {},\n                  "children": [],\n                  "textContent": "B de Barce"\n                },\n                {\n                  "tagName": "b",\n                  "status": "",\n                  "attributes": {},\n                  "children": [\n                    {\n                      "tagName": "",\n                      "status": "",\n                      "attributes": {},\n                      "children": [],\n                      "textContent": "lo"\n                    }\n                  ],\n                  "textContent": "lo"\n                },\n                {\n                  "tagName": "",\n                  "status": "",\n                  "attributes": {},\n                  "children": [],\n                  "textContent": "na."\n                }\n              ],\n              "textContent": "B de Barcelona."\n            }\n          ],\n          "textContent": "11  — B de Barcelona."\n        },\n        {\n          "tagName": "",\n          "status": "",\n          "attributes": {},\n          "children": [],\n          "textContent": "\\n        \\n      \\n    "\n        }\n      ],\n      "textContent": "\\n      \\n        1  — Buenas, quisiera un billete de Almería a Madrid.\\n        \\n      \\n        2  — Sacándolo de ida y vuelta tiene usted el 25 % (veinticinco por ciento) de descuento.\\n        \\n      \\n        3  — De ida y vuelta entonces: salgo el uno de junio y vuelvo el quince.\\n        \\n      \\n        4  — ¿Desea turista o preferente?\\n        \\n      \\n        5  — Preferente solo le cuesta seis euros más. Es una oferta.\\n        \\n      \\n        6  — ¡Pues preferente entonces! Pero, qué cabeza tengo…, no encuentro la tarjeta.\\n        \\n      \\n        7  — Le doy un número de reserva y paga usted después, con tarjeta o en efectivo, ¿vale?\\n        \\n      \\n        8 La salida es a las 7 y 10 de la mañana y la vuelta a las 3 y media de la tarde.\\n        \\n      \\n        9 Apunte: XH553WB.\\n        \\n      \\n        10  — Perdón, ¿la última letra es B o D?\\n        \\n      \\n        11  — B de Barcelona.\\n        \\n      \\n    "\n    },\n    {\n      "tagName": "",\n      "status": "",\n      "attributes": {},\n      "children": [],\n      "textContent": "\\n    \\n      "\n    },\n    {\n      "tagName": "h2",\n      "status": "",\n      "attributes": {\n        "id": "id_13",\n        "onclick": "proceedSentence(13)"\n      },\n      "children": [\n        {\n          "tagName": "",\n          "status": "",\n          "attributes": {},\n          "children": [],\n          "textContent": "Ejer"\n        },\n        {\n          "tagName": "b",\n          "status": "",\n          "attributes": {},\n          "children": [\n            {\n              "tagName": "",\n              "status": "",\n              "attributes": {},\n              "children": [],\n              "textContent": "ci"\n            }\n          ],\n          "textContent": "ci"\n        },\n        {\n          "tagName": "",\n          "status": "",\n          "attributes": {},\n          "children": [],\n          "textContent": "cio 1 – Tra"\n        },\n        {\n          "tagName": "b",\n          "status": "",\n          "attributes": {},\n          "children": [\n            {\n              "tagName": "",\n              "status": "",\n              "attributes": {},\n              "children": [],\n              "textContent": "duz"\n            }\n          ],\n          "textContent": "duz"\n        },\n        {\n          "tagName": "",\n          "status": "",\n          "attributes": {},\n          "children": [],\n          "textContent": "ca"\n        }\n      ],\n      "textContent": "Ejercicio 1 – Traduzca"\n    },\n    {\n      "tagName": "",\n      "status": "",\n      "attributes": {},\n      "children": [],\n      "textContent": "\\n      "\n    },\n    {\n      "tagName": "div",\n      "status": "",\n      "attributes": {\n        "class": "lesson-container"\n      },\n      "children": [\n        {\n          "tagName": "",\n          "status": "",\n          "attributes": {},\n          "children": [],\n          "textContent": "\\n        \\n        \\n          "\n        },\n        {\n          "tagName": "p",\n          "status": "",\n          "attributes": {\n            "id": "id_14",\n            "onclick": "proceedSentence(14)"\n          },\n          "children": [\n            {\n              "tagName": "label",\n              "status": "",\n              "attributes": {\n                "class": "line-nr"\n              },\n              "children": [\n                {\n                  "tagName": "",\n                  "status": "",\n                  "attributes": {},\n                  "children": [],\n                  "textContent": "1"\n                }\n              ],\n              "textContent": "1"\n            },\n            {\n              "tagName": "label",\n              "status": "",\n              "attributes": {\n                "class": "dialogue-dash"\n              },\n              "children": [\n                {\n                  "tagName": "",\n                  "status": "",\n                  "attributes": {},\n                  "children": [],\n                  "textContent": "  — "\n                }\n              ],\n              "textContent": "  — "\n            },\n            {\n              "tagName": "label",\n              "status": "",\n              "attributes": {},\n              "children": [\n                {\n                  "tagName": "",\n                  "status": "",\n                  "attributes": {},\n                  "children": [],\n                  "textContent": "Qui"\n                },\n                {\n                  "tagName": "b",\n                  "status": "",\n                  "attributes": {},\n                  "children": [\n                    {\n                      "tagName": "",\n                      "status": "",\n                      "attributes": {},\n                      "children": [],\n                      "textContent": "sie"\n                    }\n                  ],\n                  "textContent": "sie"\n                },\n                {\n                  "tagName": "",\n                  "status": "",\n                  "attributes": {},\n                  "children": [],\n                  "textContent": "ra un bi"\n                },\n                {\n                  "tagName": "b",\n                  "status": "",\n                  "attributes": {},\n                  "children": [\n                    {\n                      "tagName": "",\n                      "status": "",\n                      "attributes": {},\n                      "children": [],\n                      "textContent": "lle"\n                    }\n                  ],\n                  "textContent": "lle"\n                },\n                {\n                  "tagName": "",\n                  "status": "",\n                  "attributes": {},\n                  "children": [],\n                  "textContent": "te tu"\n                },\n                {\n                  "tagName": "b",\n                  "status": "",\n                  "attributes": {},\n                  "children": [\n                    {\n                      "tagName": "",\n                      "status": "",\n                      "attributes": {},\n                      "children": [],\n                      "textContent": "ris"\n                    }\n                  ],\n                  "textContent": "ris"\n                },\n                {\n                  "tagName": "",\n                  "status": "",\n                  "attributes": {},\n                  "children": [],\n                  "textContent": "ta de "\n                },\n                {\n                  "tagName": "b",\n                  "status": "",\n                  "attributes": {},\n                  "children": [\n                    {\n                      "tagName": "",\n                      "status": "",\n                      "attributes": {},\n                      "children": [],\n                      "textContent": "i"\n                    }\n                  ],\n                  "textContent": "i"\n                },\n                {\n                  "tagName": "",\n                  "status": "",\n                  "attributes": {},\n                  "children": [],\n                  "textContent": "da y "\n                },\n                {\n                  "tagName": "b",\n                  "status": "",\n                  "attributes": {},\n                  "children": [\n                    {\n                      "tagName": "",\n                      "status": "",\n                      "attributes": {},\n                      "children": [],\n                      "textContent": "vuel"\n                    }\n                  ],\n                  "textContent": "vuel"\n                },\n                {\n                  "tagName": "",\n                  "status": "",\n                  "attributes": {},\n                  "children": [],\n                  "textContent": "ta de Barce"\n                },\n                {\n                  "tagName": "b",\n                  "status": "",\n                  "attributes": {},\n                  "children": [\n                    {\n                      "tagName": "",\n                      "status": "",\n                      "attributes": {},\n                      "children": [],\n                      "textContent": "lo"\n                    }\n                  ],\n                  "textContent": "lo"\n                },\n                {\n                  "tagName": "",\n                  "status": "",\n                  "attributes": {},\n                  "children": [],\n                  "textContent": "na a "\n                },\n                {\n                  "tagName": "b",\n                  "status": "",\n                  "attributes": {},\n                  "children": [\n                    {\n                      "tagName": "",\n                      "status": "",\n                      "attributes": {},\n                      "children": [],\n                      "textContent": "Cór"\n                    }\n                  ],\n                  "textContent": "Cór"\n                },\n                {\n                  "tagName": "",\n                  "status": "",\n                  "attributes": {},\n                  "children": [],\n                  "textContent": "doba. "\n                }\n              ],\n              "textContent": "Quisiera un billete turista de ida y vuelta de Barcelona a Córdoba. "\n            }\n          ],\n          "textContent": "1  — Quisiera un billete turista de ida y vuelta de Barcelona a Córdoba. "\n        },\n        {\n          "tagName": "",\n          "status": "",\n          "attributes": {},\n          "children": [],\n          "textContent": "\\n          \\n        \\n          "\n        },\n        {\n          "tagName": "p",\n          "status": "",\n          "attributes": {\n            "id": "id_15",\n            "onclick": "proceedSentence(15)"\n          },\n          "children": [\n            {\n              "tagName": "label",\n              "status": "",\n              "attributes": {\n                "class": "line-nr"\n              },\n              "children": [\n                {\n                  "tagName": "",\n                  "status": "",\n                  "attributes": {},\n                  "children": [],\n                  "textContent": "2"\n                }\n              ],\n              "textContent": "2"\n            },\n            {\n              "tagName": "label",\n              "status": "",\n              "attributes": {\n                "class": "dialogue-dash"\n              },\n              "children": [\n                {\n                  "tagName": "",\n                  "status": "",\n                  "attributes": {},\n                  "children": [],\n                  "textContent": "  — "\n                }\n              ],\n              "textContent": "  — "\n            },\n            {\n              "tagName": "label",\n              "status": "",\n              "attributes": {},\n              "children": [\n                {\n                  "tagName": "b",\n                  "status": "",\n                  "attributes": {},\n                  "children": [\n                    {\n                      "tagName": "",\n                      "status": "",\n                      "attributes": {},\n                      "children": [],\n                      "textContent": "Sal"\n                    }\n                  ],\n                  "textContent": "Sal"\n                },\n                {\n                  "tagName": "",\n                  "status": "",\n                  "attributes": {},\n                  "children": [],\n                  "textContent": "go el diez de e"\n                },\n                {\n                  "tagName": "b",\n                  "status": "",\n                  "attributes": {},\n                  "children": [\n                    {\n                      "tagName": "",\n                      "status": "",\n                      "attributes": {},\n                      "children": [],\n                      "textContent": "ne"\n                    }\n                  ],\n                  "textContent": "ne"\n                },\n                {\n                  "tagName": "",\n                  "status": "",\n                  "attributes": {},\n                  "children": [],\n                  "textContent": "ro por la ma"\n                },\n                {\n                  "tagName": "b",\n                  "status": "",\n                  "attributes": {},\n                  "children": [\n                    {\n                      "tagName": "",\n                      "status": "",\n                      "attributes": {},\n                      "children": [],\n                      "textContent": "ña"\n                    }\n                  ],\n                  "textContent": "ña"\n                },\n                {\n                  "tagName": "",\n                  "status": "",\n                  "attributes": {},\n                  "children": [],\n                  "textContent": "na y "\n                },\n                {\n                  "tagName": "b",\n                  "status": "",\n                  "attributes": {},\n                  "children": [\n                    {\n                      "tagName": "",\n                      "status": "",\n                      "attributes": {},\n                      "children": [],\n                      "textContent": "vuel"\n                    }\n                  ],\n                  "textContent": "vuel"\n                },\n                {\n                  "tagName": "",\n                  "status": "",\n                  "attributes": {},\n                  "children": [],\n                  "textContent": "vo el "\n                },\n                {\n                  "tagName": "b",\n                  "status": "",\n                  "attributes": {},\n                  "children": [\n                    {\n                      "tagName": "",\n                      "status": "",\n                      "attributes": {},\n                      "children": [],\n                      "textContent": "u"\n                    }\n                  ],\n                  "textContent": "u"\n                },\n                {\n                  "tagName": "",\n                  "status": "",\n                  "attributes": {},\n                  "children": [],\n                  "textContent": "no de fe"\n                },\n                {\n                  "tagName": "b",\n                  "status": "",\n                  "attributes": {},\n                  "children": [\n                    {\n                      "tagName": "",\n                      "status": "",\n                      "attributes": {},\n                      "children": [],\n                      "textContent": "bre"\n                    }\n                  ],\n                  "textContent": "bre"\n                },\n                {\n                  "tagName": "",\n                  "status": "",\n                  "attributes": {},\n                  "children": [],\n                  "textContent": "ro por la "\n                },\n                {\n                  "tagName": "b",\n                  "status": "",\n                  "attributes": {},\n                  "children": [\n                    {\n                      "tagName": "",\n                      "status": "",\n                      "attributes": {},\n                      "children": [],\n                      "textContent": "tar"\n                    }\n                  ],\n                  "textContent": "tar"\n                },\n                {\n                  "tagName": "",\n                  "status": "",\n                  "attributes": {},\n                  "children": [],\n                  "textContent": "de. "\n                }\n              ],\n              "textContent": "Salgo el diez de enero por la mañana y vuelvo el uno de febrero por la tarde. "\n            }\n          ],\n          "textContent": "2  — Salgo el diez de enero por la mañana y vuelvo el uno de febrero por la tarde. "\n        },\n        {\n          "tagName": "",\n          "status": "",\n          "attributes": {},\n          "children": [],\n          "textContent": "\\n          \\n        \\n          "\n        },\n        {\n          "tagName": "p",\n          "status": "",\n          "attributes": {\n            "id": "id_16",\n            "onclick": "proceedSentence(16)"\n          },\n          "children": [\n            {\n              "tagName": "label",\n              "status": "",\n              "attributes": {\n                "class": "line-nr"\n              },\n              "children": [\n                {\n                  "tagName": "",\n                  "status": "",\n                  "attributes": {},\n                  "children": [],\n                  "textContent": "3"\n                }\n              ],\n              "textContent": "3"\n            },\n            {\n              "tagName": "label",\n              "status": "",\n              "attributes": {\n                "class": "dialogue-dash"\n              },\n              "children": [\n                {\n                  "tagName": "",\n                  "status": "",\n                  "attributes": {},\n                  "children": [],\n                  "textContent": "  — "\n                }\n              ],\n              "textContent": "  — "\n            },\n            {\n              "tagName": "label",\n              "status": "",\n              "attributes": {},\n              "children": [\n                {\n                  "tagName": "",\n                  "status": "",\n                  "attributes": {},\n                  "children": [],\n                  "textContent": "¿De"\n                },\n                {\n                  "tagName": "b",\n                  "status": "",\n                  "attributes": {},\n                  "children": [\n                    {\n                      "tagName": "",\n                      "status": "",\n                      "attributes": {},\n                      "children": [],\n                      "textContent": "se"\n                    }\n                  ],\n                  "textContent": "se"\n                },\n                {\n                  "tagName": "",\n                  "status": "",\n                  "attributes": {},\n                  "children": [],\n                  "textContent": "a pa"\n                },\n                {\n                  "tagName": "b",\n                  "status": "",\n                  "attributes": {},\n                  "children": [\n                    {\n                      "tagName": "",\n                      "status": "",\n                      "attributes": {},\n                      "children": [],\n                      "textContent": "gar"\n                    }\n                  ],\n                  "textContent": "gar"\n                },\n                {\n                  "tagName": "",\n                  "status": "",\n                  "attributes": {},\n                  "children": [],\n                  "textContent": " con tar"\n                },\n                {\n                  "tagName": "b",\n                  "status": "",\n                  "attributes": {},\n                  "children": [\n                    {\n                      "tagName": "",\n                      "status": "",\n                      "attributes": {},\n                      "children": [],\n                      "textContent": "je"\n                    }\n                  ],\n                  "textContent": "je"\n                },\n                {\n                  "tagName": "",\n                  "status": "",\n                  "attributes": {},\n                  "children": [],\n                  "textContent": "ta o en efec"\n                },\n                {\n                  "tagName": "b",\n                  "status": "",\n                  "attributes": {},\n                  "children": [\n                    {\n                      "tagName": "",\n                      "status": "",\n                      "attributes": {},\n                      "children": [],\n                      "textContent": "ti"\n                    }\n                  ],\n                  "textContent": "ti"\n                },\n                {\n                  "tagName": "",\n                  "status": "",\n                  "attributes": {},\n                  "children": [],\n                  "textContent": "vo? "\n                }\n              ],\n              "textContent": "¿Desea pagar con tarjeta o en efectivo? "\n            }\n          ],\n          "textContent": "3  — ¿Desea pagar con tarjeta o en efectivo? "\n        },\n        {\n          "tagName": "",\n          "status": "",\n          "attributes": {},\n          "children": [],\n          "textContent": "\\n          \\n        \\n          "\n        },\n        {\n          "tagName": "p",\n          "status": "",\n          "attributes": {\n            "id": "id_17",\n            "onclick": "proceedSentence(17)"\n          },\n          "children": [\n            {\n              "tagName": "label",\n              "status": "",\n              "attributes": {\n                "class": "line-nr"\n              },\n              "children": [\n                {\n                  "tagName": "",\n                  "status": "",\n                  "attributes": {},\n                  "children": [],\n                  "textContent": "4"\n                }\n              ],\n              "textContent": "4"\n            },\n            {\n              "tagName": "label",\n              "status": "",\n              "attributes": {\n                "class": "dialogue-dash"\n              },\n              "children": [\n                {\n                  "tagName": "",\n                  "status": "",\n                  "attributes": {},\n                  "children": [],\n                  "textContent": "  — "\n                }\n              ],\n              "textContent": "  — "\n            },\n            {\n              "tagName": "label",\n              "status": "",\n              "attributes": {},\n              "children": [\n                {\n                  "tagName": "",\n                  "status": "",\n                  "attributes": {},\n                  "children": [],\n                  "textContent": "Le doy "\n                },\n                {\n                  "tagName": "b",\n                  "status": "",\n                  "attributes": {},\n                  "children": [\n                    {\n                      "tagName": "",\n                      "status": "",\n                      "attributes": {},\n                      "children": [],\n                      "textContent": "u"\n                    }\n                  ],\n                  "textContent": "u"\n                },\n                {\n                  "tagName": "",\n                  "status": "",\n                  "attributes": {},\n                  "children": [],\n                  "textContent": "na re"\n                },\n                {\n                  "tagName": "b",\n                  "status": "",\n                  "attributes": {},\n                  "children": [\n                    {\n                      "tagName": "",\n                      "status": "",\n                      "attributes": {},\n                      "children": [],\n                      "textContent": "ser"\n                    }\n                  ],\n                  "textContent": "ser"\n                },\n                {\n                  "tagName": "",\n                  "status": "",\n                  "attributes": {},\n                  "children": [],\n                  "textContent": "va con sa"\n                },\n                {\n                  "tagName": "b",\n                  "status": "",\n                  "attributes": {},\n                  "children": [\n                    {\n                      "tagName": "",\n                      "status": "",\n                      "attributes": {},\n                      "children": [],\n                      "textContent": "li"\n                    }\n                  ],\n                  "textContent": "li"\n                },\n                {\n                  "tagName": "",\n                  "status": "",\n                  "attributes": {},\n                  "children": [],\n                  "textContent": "da a las "\n                },\n                {\n                  "tagName": "b",\n                  "status": "",\n                  "attributes": {},\n                  "children": [\n                    {\n                      "tagName": "",\n                      "status": "",\n                      "attributes": {},\n                      "children": [],\n                      "textContent": "o"\n                    }\n                  ],\n                  "textContent": "o"\n                },\n                {\n                  "tagName": "",\n                  "status": "",\n                  "attributes": {},\n                  "children": [],\n                  "textContent": "cho y "\n                },\n                {\n                  "tagName": "b",\n                  "status": "",\n                  "attributes": {},\n                  "children": [\n                    {\n                      "tagName": "",\n                      "status": "",\n                      "attributes": {},\n                      "children": [],\n                      "textContent": "cua"\n                    }\n                  ],\n                  "textContent": "cua"\n                },\n                {\n                  "tagName": "",\n                  "status": "",\n                  "attributes": {},\n                  "children": [],\n                  "textContent": "rto de la ma"\n                },\n                {\n                  "tagName": "b",\n                  "status": "",\n                  "attributes": {},\n                  "children": [\n                    {\n                      "tagName": "",\n                      "status": "",\n                      "attributes": {},\n                      "children": [],\n                      "textContent": "ña"\n                    }\n                  ],\n                  "textContent": "ña"\n                },\n                {\n                  "tagName": "",\n                  "status": "",\n                  "attributes": {},\n                  "children": [],\n                  "textContent": "na y "\n                },\n                {\n                  "tagName": "b",\n                  "status": "",\n                  "attributes": {},\n                  "children": [\n                    {\n                      "tagName": "",\n                      "status": "",\n                      "attributes": {},\n                      "children": [],\n                      "textContent": "vuel"\n                    }\n                  ],\n                  "textContent": "vuel"\n                },\n                {\n                  "tagName": "",\n                  "status": "",\n                  "attributes": {},\n                  "children": [],\n                  "textContent": "ta a las "\n                },\n                {\n                  "tagName": "b",\n                  "status": "",\n                  "attributes": {},\n                  "children": [\n                    {\n                      "tagName": "",\n                      "status": "",\n                      "attributes": {},\n                      "children": [],\n                      "textContent": "sie"\n                    }\n                  ],\n                  "textContent": "sie"\n                },\n                {\n                  "tagName": "",\n                  "status": "",\n                  "attributes": {},\n                  "children": [],\n                  "textContent": "te y "\n                },\n                {\n                  "tagName": "b",\n                  "status": "",\n                  "attributes": {},\n                  "children": [\n                    {\n                      "tagName": "",\n                      "status": "",\n                      "attributes": {},\n                      "children": [],\n                      "textContent": "me"\n                    }\n                  ],\n                  "textContent": "me"\n                },\n                {\n                  "tagName": "",\n                  "status": "",\n                  "attributes": {},\n                  "children": [],\n                  "textContent": "dia de la "\n                },\n                {\n                  "tagName": "b",\n                  "status": "",\n                  "attributes": {},\n                  "children": [\n                    {\n                      "tagName": "",\n                      "status": "",\n                      "attributes": {},\n                      "children": [],\n                      "textContent": "tar"\n                    }\n                  ],\n                  "textContent": "tar"\n                },\n                {\n                  "tagName": "",\n                  "status": "",\n                  "attributes": {},\n                  "children": [],\n                  "textContent": "de, ¿"\n                },\n                {\n                  "tagName": "b",\n                  "status": "",\n                  "attributes": {},\n                  "children": [\n                    {\n                      "tagName": "",\n                      "status": "",\n                      "attributes": {},\n                      "children": [],\n                      "textContent": "va"\n                    }\n                  ],\n                  "textContent": "va"\n                },\n                {\n                  "tagName": "",\n                  "status": "",\n                  "attributes": {},\n                  "children": [],\n                  "textContent": "le?"\n                }\n              ],\n              "textContent": "Le doy una reserva con salida a las ocho y cuarto de la mañana y vuelta a las siete y media de la tarde, ¿vale?"\n            }\n          ],\n          "textContent": "4  — Le doy una reserva con salida a las ocho y cuarto de la mañana y vuelta a las siete y media de la tarde, ¿vale?"\n        },\n        {\n          "tagName": "",\n          "status": "",\n          "attributes": {},\n          "children": [],\n          "textContent": "\\n          \\n        \\n          "\n        },\n        {\n          "tagName": "p",\n          "status": "",\n          "attributes": {\n            "id": "id_18",\n            "onclick": "proceedSentence(18)"\n          },\n          "children": [\n            {\n              "tagName": "label",\n              "status": "",\n              "attributes": {\n                "class": "line-nr"\n              },\n              "children": [\n                {\n                  "tagName": "",\n                  "status": "",\n                  "attributes": {},\n                  "children": [],\n                  "textContent": "5"\n                }\n              ],\n              "textContent": "5"\n            },\n            {\n              "tagName": "label",\n              "status": "",\n              "attributes": {\n                "class": "dialogue-dash"\n              },\n              "children": [\n                {\n                  "tagName": "",\n                  "status": "",\n                  "attributes": {},\n                  "children": [],\n                  "textContent": "  — "\n                }\n              ],\n              "textContent": "  — "\n            },\n            {\n              "tagName": "label",\n              "status": "",\n              "attributes": {},\n              "children": [\n                {\n                  "tagName": "",\n                  "status": "",\n                  "attributes": {},\n                  "children": [],\n                  "textContent": "A"\n                },\n                {\n                  "tagName": "b",\n                  "status": "",\n                  "attributes": {},\n                  "children": [\n                    {\n                      "tagName": "",\n                      "status": "",\n                      "attributes": {},\n                      "children": [],\n                      "textContent": "pun"\n                    }\n                  ],\n                  "textContent": "pun"\n                },\n                {\n                  "tagName": "",\n                  "status": "",\n                  "attributes": {},\n                  "children": [],\n                  "textContent": "te el "\n                },\n                {\n                  "tagName": "b",\n                  "status": "",\n                  "attributes": {},\n                  "children": [\n                    {\n                      "tagName": "",\n                      "status": "",\n                      "attributes": {},\n                      "children": [],\n                      "textContent": "nú"\n                    }\n                  ],\n                  "textContent": "nú"\n                },\n                {\n                  "tagName": "",\n                  "status": "",\n                  "attributes": {},\n                  "children": [],\n                  "textContent": "mero, por fa"\n                },\n                {\n                  "tagName": "b",\n                  "status": "",\n                  "attributes": {},\n                  "children": [\n                    {\n                      "tagName": "",\n                      "status": "",\n                      "attributes": {},\n                      "children": [],\n                      "textContent": "vor"\n                    }\n                  ],\n                  "textContent": "vor"\n                },\n                {\n                  "tagName": "",\n                  "status": "",\n                  "attributes": {},\n                  "children": [],\n                  "textContent": "."\n                }\n              ],\n              "textContent": "Apunte el número, por favor."\n            }\n          ],\n          "textContent": "5  — Apunte el número, por favor."\n        },\n        {\n          "tagName": "",\n          "status": "",\n          "attributes": {},\n          "children": [],\n          "textContent": "\\n          \\n        \\n      "\n        }\n      ],\n      "textContent": "\\n        \\n        \\n          1  — Quisiera un billete turista de ida y vuelta de Barcelona a Córdoba. \\n          \\n        \\n          2  — Salgo el diez de enero por la mañana y vuelvo el uno de febrero por la tarde. \\n          \\n        \\n          3  — ¿Desea pagar con tarjeta o en efectivo? \\n          \\n        \\n          4  — Le doy una reserva con salida a las ocho y cuarto de la mañana y vuelta a las siete y media de la tarde, ¿vale?\\n          \\n        \\n          5  — Apunte el número, por favor.\\n          \\n        \\n      "\n    },\n    {\n      "tagName": "",\n      "status": "",\n      "attributes": {},\n      "children": [],\n      "textContent": "\\n    \\n"\n    }\n  ],\n  "textContent": "\\n    \\n     Lección veintinueve \\n     Quisiera un billete para… \\n    \\n      \\n        1  — Buenas, quisiera un billete de Almería a Madrid.\\n        \\n      \\n        2  — Sacándolo de ida y vuelta tiene usted el 25 % (veinticinco por ciento) de descuento.\\n        \\n      \\n        3  — De ida y vuelta entonces: salgo el uno de junio y vuelvo el quince.\\n        \\n      \\n        4  — ¿Desea turista o preferente?\\n        \\n      \\n        5  — Preferente solo le cuesta seis euros más. Es una oferta.\\n        \\n      \\n        6  — ¡Pues preferente entonces! Pero, qué cabeza tengo…, no encuentro la tarjeta.\\n        \\n      \\n        7  — Le doy un número de reserva y paga usted después, con tarjeta o en efectivo, ¿vale?\\n        \\n      \\n        8 La salida es a las 7 y 10 de la mañana y la vuelta a las 3 y media de la tarde.\\n        \\n      \\n        9 Apunte: XH553WB.\\n        \\n      \\n        10  — Perdón, ¿la última letra es B o D?\\n        \\n      \\n        11  — B de Barcelona.\\n        \\n      \\n    \\n    \\n      Ejercicio 1 – Traduzca\\n      \\n        \\n        \\n          1  — Quisiera un billete turista de ida y vuelta de Barcelona a Córdoba. \\n          \\n        \\n          2  — Salgo el diez de enero por la mañana y vuelvo el uno de febrero por la tarde. \\n          \\n        \\n          3  — ¿Desea pagar con tarjeta o en efectivo? \\n          \\n        \\n          4  — Le doy una reserva con salida a las ocho y cuarto de la mañana y vuelta a las siete y media de la tarde, ¿vale?\\n          \\n        \\n          5  — Apunte el número, por favor.\\n          \\n        \\n      \\n    \\n"\n}'

# %%
import json

# %%
print(editor)
# Out:
# {'tagName': 'div', 'status': '', 'attributes': {'id': 'editor'}, 'children': [{'tagName': '', 'status': '', 'attributes': {}, 'children': [], 'textContent': '\n    \n    '}, {'tagName': 'h2', 'status': '', 'attributes': {'class': 'assimil-title', 'id': 'id_0', 'onclick': 'proceedSentence(0)'}, 'children': [{'tagName': '', 'status': '', 'attributes': {}, 'children': [], 'textContent': ' Lec'}, {'tagName': 'b', 'status': '', 'attributes': {}, 'children': [{'tagName': '', 'status': '', 'attributes': {}, 'children': [], 'textContent': 'ción'}], 'textContent': 'ción'}, {'tagName': '', 'status': '', 'attributes': {}, 'children': [], 'textContent': ' veinti'}, {'tagName': 'b', 'status': '', 'attributes': {}, 'children': [{'tagName': '', 'status': '', 'attributes': {}, 'children': [], 'textContent': 'nue'}], 'textContent': 'nue'}, {'tagName': '', 'status': '', 'attributes': {}, 'children': [], 'textContent': 've '}], 'textContent': ' Lección veintinueve '}, {'tagName': '', 'status': '', 'att
# ...

# %%
import json
from selection import SelectionItem

def has_one_child_focus(element):
    if element['status'] != '':
        return True
    else:
        for child in element['children']:
            if has_one_child_focus(child):
                return True
    return False

def find_selection_element(element):
    if element['tagName'] in ['p', 'h2']:
        if has_one_child_focus(element):
            return element
    else:
        for child in element['children']:
            result = find_selection_element(child)
            if result:
                return result

def get_html_with_grammar_number(item: SelectionItem):
    editor = json.loads(item.editorDomString)
    print(f"Anchor Offset : {item.anchorOffset}, Focus Offset : {item.focusOffset}")
    print(find_selection_paragraph(editor))

# %%
element = find_selection_paragraph(editor)
element = editor['children'][1]

# %%
element['tagName']
# Out:
# 'h2'

# %%
line_text_fragments = element['children']
line_text_fragments
# Out:
# [{'tagName': '',
#   'status': '',
#   'attributes': {},
#   'children': [],
#   'textContent': ' Lec'},
#  {'tagName': 'b',
#   'status': '',
#   'attributes': {},
#   'children': [{'tagName': '',
#     'status': '',
#     'attributes': {},
#     'children': [],
#     'textContent': 'ción'}],
#   'textContent': 'ción'},
#  {'tagName': '',
#   'status': '',
#   'attributes': {},
#   'children': [],
#   'textContent': ' veinti'},
#  {'tagName': 'b',
#   'status': '',
#   'attributes': {},
#   'children': [{'tagName': '',
#     'status': '',
#     'attributes': {},
#     'children': [],
#     'textContent': 'nue'}],
#   'textContent': 'nue'},
#  {'tagName': '',
#   'status': '',
#   'attributes': {},
#   'children': [],
#   'textContent': 've '}]

# %%
focus_offset = 3
text = ""
if element['tagName'] == 'p':
    line_nb = int(para['children'][0]['children'][0]['textContent'])
    line_text_fragments = element['children'][2]['children']
elif element['tagName'] == 'h2':
    line_text_fragments == element['children']
    
for fragment in line_text_fragments:
    if fragment['tagName'] in ['b', '']:
        if fragment['status'] in ['isFocus', 'isAnchorAndFocus']:
            text += fragment['textContent'][:focus_offset]
            text += '<sup> 1</sup>'
            text += fragment['textContent'][focus_offset:]
        else:
            text += fragment['textContent']
    else:
        raise
print(text)
# Out:
#  Lección veintinueve

# %%
line_text_fragments[1]
# Out:
# {'tagName': '',
#  'status': 'isFocus',
#  'attributes': {},
#  'children': [],
#  'textContent': 'nas, qui'}

# %%
editor['children'][3]['children']
# Out:
# [{'tagName': '',
#   'status': '',
#   'attributes': {},
#   'children': [],
#   'textContent': ' Qui'},
#  {'tagName': 'b',
#   'status': '',
#   'attributes': {},
#   'children': [{'tagName': '',
#     'status': '',
#     'attributes': {},
#     'children': [],
#     'textContent': 'sie'}],
#   'textContent': 'sie'},
#  {'tagName': '',
#   'status': '',
#   'attributes': {},
#   'children': [],
#   'textContent': 'ra un bi'},
#  {'tagName': 'b',
#   'status': '',
#   'attributes': {},
#   'children': [{'tagName': '',
#     'status': '',
#     'attributes': {},
#     'children': [],
#     'textContent': 'lle'}],
#   'textContent': 'lle'},
#  {'tagName': '',
#   'status': '',
#   'attributes': {},
#   'children': [],
#   'textContent': 'te '},
#  {'tagName': 'b',
#   'status': '',
#   'attributes': {},
#   'children': [{'tagName': '',
#     'status': '',
#     'attributes': {},
#     'children': [],
#     'textContent': 'pa'}],
#   'textContent': 'pa'},
#  {'tagName': '',
# ...

# %%
frags = [{'tagName': '', 'status': 'isAnchor', 'attributes': {}, 'children': [], 'textContent': ' Lec'}, {'tagName': 'b', 'status': '', 'attributes': {}, 'children': [{'tagName': '', 'status': 'isFocus', 'attributes': {}, 'children': [], 'textContent': 'ción'}], 'textContent': 'ción'}, {'tagName': '', 'status': '', 'attributes': {}, 'children': [], 'textContent': ' veinti'}, {'tagName': 'b', 'status': '', 'attributes': {}, 'children': [{'tagName': '', 'status': '', 'attributes': {}, 'children': [], 'textContent': 'nue'}], 'textContent': 'nue'}, {'tagName': '', 'status': '', 'attributes': {}, 'children': [], 'textContent': 've '}]

# %%
frags
# Out:
# [{'tagName': '',
#   'status': 'isAnchor',
#   'attributes': {},
#   'children': [],
#   'textContent': ' Lec'},
#  {'tagName': 'b',
#   'status': '',
#   'attributes': {},
#   'children': [{'tagName': '',
#     'status': 'isFocus',
#     'attributes': {},
#     'children': [],
#     'textContent': 'ción'}],
#   'textContent': 'ción'},
#  {'tagName': '',
#   'status': '',
#   'attributes': {},
#   'children': [],
#   'textContent': ' veinti'},
#  {'tagName': 'b',
#   'status': '',
#   'attributes': {},
#   'children': [{'tagName': '',
#     'status': '',
#     'attributes': {},
#     'children': [],
#     'textContent': 'nue'}],
#   'textContent': 'nue'},
#  {'tagName': '',
#   'status': '',
#   'attributes': {},
#   'children': [],
#   'textContent': 've '}]

# %%
json
# Out:
# <module 'json' from '/Users/pam/.pyenv/versions/3.11.3/lib/python3.11/json/__init__.py'>

# %%
json.loads({'toto' : 1, 'titi' : 'tata'})
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[129], line 1
# ----> 1 json.loads({'toto' : 1, 'titi' : 'tata'})
#
# File ~/.pyenv/versions/3.11.3/lib/python3.11/json/__init__.py:339, in loads(s, cls, object_hook, parse_float, parse_int, parse_constant, object_pairs_hook, **kw)
#     337 else:
#     338     if not isinstance(s, (bytes, bytearray)):
# --> 339         raise TypeError(f'the JSON object must be str, bytes or bytearray, '
#     340                         f'not {s.__class__.__name__}')
#     341     s = s.decode(detect_encoding(s), 'surrogatepass')
#     343 if (cls is None and object_hook is None and
#     344         parse_int is None and parse_float is None and
#     345         parse_constant is None and object_pairs_hook is None and not kw):
#
# TypeError: the JSON object must be str, bytes or bytearray, not dict

# %%
# import json module
import json  
     
# define Python dictionary
employee_details ={  
  "id": "04",  
  "name": "sunil",  
  "department": "HR"
}  
     
# Convert Python to JSON  
json_object = json.dumps(employee_details, indent = 4) 

# Print JSON object
print(type(json_object))
# Out:
# <class 'str'>

# %%
# Create a nested dictionary
person = {
    "name": "John Doe",
    "age": 30,
    "address": {
        "street": "123 Main St",
        "city": "Anytown",
        "state": "CA"
    }
}

# Convert person dictionary to JSON
json_string = json.dumps(person, indent=4)  
print(json_string)
# Out:
# {
#     "name": "John Doe",
#     "age": 30,
#     "address": {
#         "street": "123 Main St",
#         "city": "Anytown",
#         "state": "CA"
#     }
# }

# %%
ord('1ª')
# Out:
# 170

# %%
ord('₂')
# Out:
# 8322

# %%
for a in "ʰᵉˡˡᵒ ʷᵒʳˡᵈ":
    print(a, ord(a))
# Out:
# ʰ 688
# ᵉ 7497
# ˡ 737
# ˡ 737
# ᵒ 7506
#   32
# ʷ 695
# ᵒ 7506
# ʳ 691
# ˡ 737
# ᵈ 7496

# %%
ord('ᵖ')
# Out:
# 7510

# %%
ord('ʳ')
# Out:
# 691

# %%
SUPERSCRIPTS = {
  ' ': ' ',
  '0': '⁰',
  '1': '¹',
  '2': '²',
  '3': '³',
  '4': '⁴',
  '5': '⁵',
  '6': '⁶',
  '7': '⁷',
  '8': '⁸',
  '9': '⁹',
  '+': '⁺',
  '-': '⁻',
  'a': 'ᵃ',
  'b': 'ᵇ',
  'c': 'ᶜ',
  'd': 'ᵈ',
  'e': 'ᵉ',
  'f': 'ᶠ',
  'g': 'ᵍ',
  'h': 'ʰ',
  'i': 'ⁱ',
  'j': 'ʲ',
  'k': 'ᵏ',
  'l': 'ˡ',
  'm': 'ᵐ',
  'n': 'ⁿ',
  'o': 'ᵒ',
  'p': 'ᵖ',
  'r': 'ʳ',
  's': 'ˢ',
  't': 'ᵗ',
  'u': 'ᵘ',
  'v': 'ᵛ',
  'w': 'ʷ',
  'x': 'ˣ',
  'y': 'ʸ',
  'z': 'ᶻ'
}

# %%
for c in SUPERSCRIPTS:
    print(SUPERSCRIPTS[c], ord(SUPERSCRIPTS[c]))
# Out:
#   32
# ⁰ 8304
# ¹ 185
# ² 178
# ³ 179
# ⁴ 8308
# ⁵ 8309
# ⁶ 8310
# ⁷ 8311
# ⁸ 8312
# ⁹ 8313
# ⁺ 8314
# ⁻ 8315
# ᵃ 7491
# ᵇ 7495
# ᶜ 7580
# ᵈ 7496
# ᵉ 7497
# ᶠ 7584
# ᵍ 7501
# ʰ 688
# ⁱ 8305
# ʲ 690
# ᵏ 7503
# ˡ 737
# ᵐ 7504
# ⁿ 8319
# ᵒ 7506
# ᵖ 7510
# ʳ 691
# ˢ 738
# ᵗ 7511
# ᵘ 7512
# ᵛ 7515
# ʷ 695
# ˣ 739
# ʸ 696
# ᶻ 7611

# %%
chr(7511)
# Out:
# 'ᵗ'

# %%
superscript="ᵃᵇᶜᵈᵉᶠᵍʰⁱʲᵏˡᵐⁿᵒᵖʳˢᵗᵘᵛʷˣʸᶻ"

# %%
ord('ª')
# Out:
# 170

# %%
ord('ᵃ')
# Out:
# 7491

# %%
ord('ᵉ')
# Out:
# 7497

# %%
ord('ʳ')
# Out:
# 691

# %%
ord("¹")
# Out:
# 185

# %%
import yaml

# %%
dir(yaml)
# Out:
# ['AliasEvent',
#  'AliasToken',
#  'AnchorToken',
#  'BaseDumper',
#  'BaseLoader',
#  'BlockEndToken',
#  'BlockEntryToken',
#  'BlockMappingStartToken',
#  'BlockSequenceStartToken',
#  'CBaseDumper',
#  'CBaseLoader',
#  'CDumper',
#  'CFullLoader',
#  'CLoader',
#  'CSafeDumper',
#  'CSafeLoader',
#  'CUnsafeLoader',
#  'CollectionEndEvent',
#  'CollectionNode',
#  'CollectionStartEvent',
#  'DirectiveToken',
#  'DocumentEndEvent',
#  'DocumentEndToken',
#  'DocumentStartEvent',
#  'DocumentStartToken',
#  'Dumper',
#  'Event',
#  'FlowEntryToken',
#  'FlowMappingEndToken',
#  'FlowMappingStartToken',
#  'FlowSequenceEndToken',
#  'FlowSequenceStartToken',
#  'FullLoader',
#  'KeyToken',
#  'Loader',
#  'MappingEndEvent',
#  'MappingNode',
#  'MappingStartEvent',
#  'Mark',
#  'MarkedYAMLError',
#  'Node',
#  'NodeEvent',
#  'SafeDumper',
#  'SafeLoader',
#  'ScalarEvent',
#  'ScalarNode',
#  'ScalarToken',
#  'SequenceEndEvent',
#  'SequenceNode',
#  'SequenceStartEvent',
# ...

# %%
a = {1 : "test one", 2 : "test two", 3 : "test three"}

# %%
a
# Out:
# {1: 'test one', 2: 'test two', 3: 'test three'}

# %%
s = yaml.dump(a)

# %%
print(s)
# Out:
# 1: test one
# 2: test two
# 3: test three

# %%
a2 = yaml.safe_load(s)

# %%
a2
# Out:
# {1: 'test one', 2: 'test two', 3: 'test three'}

# %%
from sqlalchemy.orm import Session
from sqlalchemy import select, and_
from database import Paragraph, engine, update_paragraph, get_paragraphs
import yaml


stmt = select(Paragraph).where(
        and_(
            Paragraph.lesson_nb == 93,
            Paragraph.line_nb == 2
            )
)
with Session(engine) as session:
    entry = session.scalars(stmt).one()
    print(entry.grammar_indexes)
    gi = yaml.safe_load(entry.grammar_indexes)
note_numbers=gi
note_numbers

# %%
engine
# Out:
# Engine(sqlite:////Users/pam/assimil/db/assimil_spanish.db)

# %%
stmt = select(Paragraph)
with Session(engine) as session:
    for entry in session.scalars(stmt):
        if entry.grammar_indexes:
            print(entry.lesson_nb, entry.line_nb, entry.grammar_indexes)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[4], line 1
# ----> 1 stmt = select(Paragraph)
#       2 with Session(engine) as session:
#       3     for entry in session.scalars(stmt):
#
# NameError: name 'select' is not defined

# %%
stmt = select(Paragraph).where(
    and_(
        Paragraph.lesson_nb == 93,
        Paragraph.line_nb == 1)
)

with Session(engine) as session:
    for entry in session.scalars(stmt):
        print(entry.grammar_indexes)
        entry.grammar_indexes = None
    session.commit()
# Out:
# 1: 8

# %%
a=[(3, "r"), (7, 5), (1, 'toto'), (5, "tata")]

# %%
a
# Out:
# [(3, 'r'), (7, 5), (1, 'toto'), (5, 'tata')]

# %%
b= sorted(a)

# %%
b
# Out:
# [(1, 'toto'), (3, 'r'), (5, 'tata'), (7, 5)]

# %%
a
# Out:
# [(3, 'r'), (7, 5), (1, 'toto'), (5, 'tata')]

# %%
a.sort()

# %%
a
# Out:
# [(1, 'toto'), (3, 'r'), (5, 'tata'), (7, 5)]

# %%
c=[]

# %%
c.sort()
c
# Out:
# []

# %%
import re
from tonic_accent import get_bold_paragraph

# %%
p = "Así empieza una de las obras más famosas de la literatura: Don Quijote de la Mancha."

# %%
p
# Out:
# 'Así empieza una de las obras más famosas de la literatura: Don Quijote de la Mancha.'

# %%
get_bold_paragraph(p)
# Out:
# 'A<b>sí</b> em<b>pie</b>za <b>u</b>na de las <b>o</b>bras más fa<b>mo</b>sas de la litera<b>tu</b>ra: Don Qui<b>jo</b>te de la <b>Man</b>cha.'

# %%
p = "es una frase que cualquier español se sabe <sup class='assimil'>4</sup> de memoria."

# %%
p="“En un lugar de la Mancha, de cuyo nombre no quiero acordarme…”"

# %%
import re
tokens = re.findall(r"[\w]+", p)

# %%
tokens
# Out:
# ['En',
#  'un',
#  'lugar',
#  'de',
#  'la',
#  'Mancha',
#  'de',
#  'cuyo',
#  'nombre',
#  'no',
#  'quiero',
#  'acordarme']

# %%
import re
from tonic_accent import get_html_of_token

note_numbers = {2: 12, 3: 34}
p="“En un lugar de la Mancha, de cuyo nombre no quiero acordarme…”"

def get_bold_paragraph_with_note_numbers(paragraph, note_numbers, lesson_dict = {}):
    note_positions = []
    bold_paragraph = ""
    index = 0
    if note_numbers:
        for n in note_numbers:
            note_positions.append((note_numbers[n], n))
        note_positions.sort()
        np_index = 0
        np = note_positions[np_index][0]
    else:
        np = float('inf')
    tokens = re.findall(r"[\w]+", paragraph)

    for token in tokens:
        token_length = len(token)
        pos = paragraph.find(token, index)
        inter_token = paragraph[index:pos]
        bold_paragraph += inter_token + get_html_of_token(token, lesson_dict)
        if np <= pos + token_length:
            bold_paragraph += f"<sup class='assimil'> {note_positions[np_index][1]} </sup>"
            if np_index < len(note_positions) - 1:
                np_index += 1
                np = note_positions[np_index][0]
            else:
                np = float('inf')
        index += len(inter_token) + token_length
    bold_paragraph += paragraph[index:]
    return bold_paragraph

# %%
get_bold_paragraph_with_note_numbers(p, note_numbers)
# Out:
# "“En un lu<b>gar</b><sup class='assimil'> 2 </sup> de la <b>Man</b>cha, de <b>cu</b>yo<sup class='assimil'> 3 </sup> <b>nom</b>bre no <b>quie</b>ro acor<b>dar</b>me…”"

# %%
1000 < float('inf')
# Out:
# True

# %%
3<inf
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[14], line 1
# ----> 1 3<inf
#
# NameError: name 'inf' is not defined

# %%
from tonic_accent import get_bold_paragraph_with_note_numbers
# Out:
# {'database_name': 'sqlite:////Users/pam/assimil/db/assimil_spanish.db', 'lessons_directory': '/Users/pam/AssimilAudio/Sentences', 'html_lessons_directory': '/Users/pam/assimil/lessons/html', 'databases_directory': '/Users/pam/assimil/db', 'french_translation_lessons_directoy': '/Users/pam/assimil/lessons/new', 'word_dict_logfilename': '/Users/pam/assimil/word_dict_logfile.log'}

# %%
note_numbers = {2: 12, 3: 34}
p="“En un lugar de la Mancha, de cuyo nombre no quiero acordarme…”"

# %%
get_bold_paragraph_with_note_numbers(p, note_numbers)
# Out:
# "“En un lu<b>gar</b><sup class='assimil'> 2</sup> de la <b>Man</b>cha, de <b>cu</b>yo<sup class='assimil'> 3</sup> <b>nom</b>bre no <b>quie</b>ro acor<b>dar</b>me…”"

# %%
stmt = select(Paragraph)

with Session(engine) as session:
    for entry in session.scalars(stmt):
        if entry.grammar_indexes:
            print(entry.grammar_indexes)
            entry.grammar_indexes = None
    session.commit()

# %%
from sqlalchemy.orm import Session
from sqlalchemy import select, and_
from database import Paragraph, engine, update_paragraph, get_paragraphs
import yaml

stmt = select(Paragraph)

with Session(engine) as session:
    for entry in session.scalars(stmt):
        if entry.grammar_indexes:
            note_numbers = yaml.safe_load(entry.grammar_indexes)
            print(f"In lesson {entry.lesson_nb}, line {entry.line_nb} : {note_numbers}")
# Out:
# In lesson 93, line 1 : {1: 8}
# In lesson 93, line 2 : {2: 12, 3: 34}
# In lesson 93, line 3 : {4: 42}
# In lesson 93, line 6 : {5: 45}
# In lesson 93, line 7 : {6: 10}
# In lesson 93, line 8 : {5: 17, 7: 53}
# In lesson 93, line 10 : {8: 33}
# In lesson 93, line 11 : {9: 20}
# In lesson 93, line 12 : {10: 25}
# In lesson 93, line 14 : {4: 44, 11: 58}
# In lesson 93, line 15 : {12: 4, 13: 15}

# %%
from tonic_accent import get_bold_paragraph_with_note_numbers

# %%
stmt = select(Paragraph)

with Session(engine) as session:
    for entry in session.scalars(stmt):
        if entry.grammar_indexes:
            note_numbers = yaml.safe_load(entry.grammar_indexes)
            note_numbers = yaml.safe_load(entry.grammar_indexes)
            print(get_bold_paragraph_with_note_numbers(entry.paragraph, note_numbers))
# Out:
# La <b>ru</b>ta<sup class='assimil'> 1</sup> de don Qui<b>jo</b>te
# “En un lu<b>gar</b><sup class='assimil'> 2</sup> de la <b>Man</b>cha, de <b>cu</b>yo<sup class='assimil'> 3</sup> <b>nom</b>bre no <b>quie</b>ro acor<b>dar</b>me…”
# es <b>u</b>na <b>fra</b>se que cual<b>quier</b> espa<b>ñol</b> se <b>sa</b>be<sup class='assimil'> 4</sup> de me<b>mo</b>ria.
# Hoy en <b>dí</b>a, <b>u</b>na <b>ru</b>ta tu<b>rís</b>tica per<b>mi</b>te se<b>guir</b><sup class='assimil'> 5</sup> los <b>pa</b>sos del <b>hé</b>roe de Cer<b>van</b>tes,
# un hi<b>dal</b>go<sup class='assimil'> 6</sup> <b>po</b>bre, <b>lo</b>co por las no<b>ve</b>las de caballe<b>rí</b>a,
# que de<b>ci</b>de cru<b>zar</b><sup class='assimil'> 5</sup> el <b>mun</b>do, en <b>ple</b>no <b>si</b>glo dieci<b>siete</b><sup class='assimil'> 7</sup>,
# ...

# %%
from database import get_paragraphs
# Out:
# {'database_name': 'sqlite:////Users/pam/assimil/db/assimil_spanish.db', 'lessons_directory': '/Users/pam/AssimilAudio/Sentences', 'html_lessons_directory': '/Users/pam/assimil/lessons/html', 'databases_directory': '/Users/pam/assimil/db', 'french_translation_lessons_directoy': '/Users/pam/assimil/lessons/new', 'word_dict_logfilename': '/Users/pam/assimil/word_dict_logfile.log'}

# %%
paragraphs = get_paragraphs(93)

# %%
paragraphs
# Out:
# {0: [0, False, 'Lección noventa y tres', None],
#  1: [1, False, 'La ruta de don Quijote', {1: 7}],
#  2: [1,
#   False,
#   '“En un lugar de la Mancha, de cuyo nombre no quiero acordarme…”',
#   {2: 12, 3: 34}],
#  3: [1,
#   False,
#   'es una frase que cualquier español se sabe de memoria.',
#   {4: 42}],
#  4: [1,
#   False,
#   'Así empieza una de las obras más famosas de la literatura: Don Quijote de la Mancha.',
#   None],
#  5: [1,
#   False,
#   'Desde luego, ¿quién no conoce la imagen de don Quijote, con Sancho Panza a su lado montado en un burro?',
#   None],
#  6: [1,
#   False,
#   'Hoy en día, una ruta turística permite seguir los pasos del héroe de Cervantes, ',
#   {5: 45}],
#  7: [1,
#   False,
#   'un hidalgo pobre, loco por las novelas de caballería, ',
#   {6: 10}],
#  8: [1,
#   False,
#   'que decide cruzar el mundo, en pleno siglo diecisiete,',
#   {5: 17, 7: 53}],
#  9: [1,
#   False,
#   'defendiendo a los más débiles, como los caballeros de la Edad Media.',
# ...

# %%
from tonic_accent import get_bold_paragraph_with_note_numbers

# %%
for line_nb in paragraphs:
    p = paragraphs[line_nb]
    print(get_bold_paragraph_with_note_numbers(p[2], p[3]))
# Out:
# Lec<b>ción</b> no<b>ven</b>ta y tres
# La <b>ru</b>ta<sup class='assimil'> 1</sup> de don Qui<b>jo</b>te
# “En un lu<b>gar</b><sup class='assimil'> 2</sup> de la <b>Man</b>cha, de <b>cu</b>yo<sup class='assimil'> 3</sup> <b>nom</b>bre no <b>quie</b>ro acor<b>dar</b>me…”
# es <b>u</b>na <b>fra</b>se que cual<b>quier</b> espa<b>ñol</b> se <b>sa</b>be<sup class='assimil'> 4</sup> de me<b>mo</b>ria.
# A<b>sí</b> em<b>pie</b>za <b>u</b>na de las <b>o</b>bras más fa<b>mo</b>sas de la litera<b>tu</b>ra: Don Qui<b>jo</b>te de la <b>Man</b>cha.
# <b>Des</b>de <b>lue</b>go, ¿quién no co<b>no</b>ce la i<b>ma</b>gen de don Qui<b>jo</b>te, con <b>San</b>cho <b>Pan</b>za a su <b>la</b>do mon<b>ta</b>do en un <b>bu</b>rro?
# Hoy en <b>dí</b>a, <b>u</b>na <b>ru</b>ta tu<b>rís</b>tica per<b>mi</b>te se<b>guir</b><sup class='assimil'> 5</sup> los <b>pa</b>sos del <b>hé</b>roe de Cer<b>van</b>tes,
# ...

# %%
paragraphs
# Out:
# {0: [0, False, 'Lección noventa y tres', None],
#  1: [1, False, 'La ruta de don Quijote', {1: 7}],
#  2: [1,
#   False,
#   '“En un lugar de la Mancha, de cuyo nombre no quiero acordarme…”',
#   {2: 12, 3: 34}],
#  3: [1,
#   False,
#   'es una frase que cualquier español se sabe de memoria.',
#   {4: 42}],
#  4: [1,
#   False,
#   'Así empieza una de las obras más famosas de la literatura: Don Quijote de la Mancha.',
#   None],
#  5: [1,
#   False,
#   'Desde luego, ¿quién no conoce la imagen de don Quijote, con Sancho Panza a su lado montado en un burro?',
#   None],
#  6: [1,
#   False,
#   'Hoy en día, una ruta turística permite seguir los pasos del héroe de Cervantes, ',
#   {5: 45}],
#  7: [1,
#   False,
#   'un hidalgo pobre, loco por las novelas de caballería, ',
#   {6: 10}],
#  8: [1,
#   False,
#   'que decide cruzar el mundo, en pleno siglo diecisiete,',
#   {5: 17, 7: 53}],
#  9: [1,
#   False,
#   'defendiendo a los más débiles, como los caballeros de la Edad Media.',
# ...

# %%
from tonic_accent import get_spanish_lesson
# Out:
# {'database_name': 'sqlite:////Users/pam/assimil/db/assimil_spanish.db', 'lessons_directory': '/Users/pam/AssimilAudio/Sentences', 'html_lessons_directory': '/Users/pam/assimil/lessons/html', 'databases_directory': '/Users/pam/assimil/db', 'french_translation_lessons_directoy': '/Users/pam/assimil/lessons/new', 'word_dict_logfilename': '/Users/pam/assimil/word_dict_logfile.log'}

# %%
get_spanish_lesson(1)
# Out:
# (['Lec<b>ción</b> pri<b>me</b>ra',
#   '¡Qué sor<b>pre</b>sa! ',
#   [1,
#    True,
#    "¡<b>Ho</b>la<sup onclick='(function(event) { displayNote(1, event); })(event)' class='assimil'> 1</sup>, <b>Lau</b>ra! "],
#   [2, True, '¡<b>Ho</b>la, <b>Pa</b>co, qué sor<b>pre</b>sa!'],
#   [3,
#    True,
#    "¿<b>Có</b>mo es<b>tás</b><sup onclick='(function(event) { displayNote(3, event); })(event)' class='assimil'> 3</sup>, <b>gua</b>pa? "],
#   [4, True, '¡Bien, <b>gra</b>cias! ¿Y tú, qué tal?'],
#   [5, True, 'Es<b>toy</b> pa<b>chu</b>cho…']],
#  [[0, False, 'Ejer<b>ci</b>cio 1 – Tra<b>duz</b>ca'],
#   [1, False, '¿Qué tal? '],
#   [2, False, '¿<b>Có</b>mo es<b>tás</b>? '],
#   [3, False, '¡<b>Ho</b>la, <b>gua</b>pa, qué sor<b>pre</b>sa!'],
#   [4, False, '¿Es<b>tás</b> pa<b>chu</b>cho? '],
#   [5, False, 'Es<b>toy</b> bien, <b>gra</b>cias. ']])

# %%
from database import store_note
store_note(lesson_nb, note_number, note)
# Out:
# {'database_name': 'sqlite:////Users/pam/assimil/db/assimil_spanish.db', 'lessons_directory': '/Users/pam/AssimilAudio/Sentences', 'html_lessons_directory': '/Users/pam/assimil/lessons/html', 'databases_directory': '/Users/pam/assimil/db', 'french_translation_lessons_directoy': '/Users/pam/assimil/lessons/new', 'word_dict_logfilename': '/Users/pam/assimil/word_dict_logfile.log'}

# %%
(lesson_nb, note_number, note) = (93, 1, "test")

# %%
store_note(lesson_nb, note_number, note)
# Out:
# None

# %%
from database import GrammarNote, engine
from sqlalchemy import select
from sqlalchemy.orm import Session

stmt = select(GrammarNote)

with Session(engine) as session:
    for entry in session.scalars(stmt):
        print(entry)
# Out:
# ---------------------------------------------------------------------------
# OperationalError                          Traceback (most recent call last)
# File ~/.pyenv/versions/symbolic/lib/python3.11/site-packages/sqlalchemy/engine/base.py:1967, in Connection._exec_single_context(self, dialect, context, statement, parameters)
#    1966     if not evt_handled:
# -> 1967         self.dialect.do_execute(
#    1968             cursor, str_statement, effective_parameters, context
#    1969         )
#    1971 if self._has_events or self.engine._has_events:
#
# File ~/.pyenv/versions/symbolic/lib/python3.11/site-packages/sqlalchemy/engine/default.py:941, in DefaultDialect.do_execute(self, cursor, statement, parameters, context)
#     940 def do_execute(self, cursor, statement, parameters, context=None):
# --> 941     cursor.execute(statement, parameters)
#
# OperationalError: no such table: grammar_note
#
# The above exception was the direct cause of the following exception:
#
# ...

# %%
GrammarNote.__table__.drop(engine)

# %%
import re

def separate_notes(texte):
    """Sépare un texte en paragraphes commençant par un numéro.

    Args:
        texte (str): Le texte à séparer.

    Returns:
        list: Une liste de paragraphes.
    """

    pattern = r"\n+"
    paragraphes = re.split(pattern, texte)
    return paragraphes

# %%
text="""1 La route sur laquelle circulent les véhicules s'appelle, comme vous le savez, la carretera ; la ruta désigne l'itinéraire. Il s'agit d'ailleurs d'un gallicisme et on le retrouve avec ce sens-là en français dans des expressions comme "la route de la soie", "la route du rhum", etc.

2 Dans la langue classique et encore aujourd'hui, lugar peut désigner un village, une bourgade. C'est bien en ce sens que l'emploie Cervantès dans l'incipit de son roman.

3 cuyo est un pronom relatif particulier, qui a une fonction de com- plément du nom et se rend souvent par dont. Dans cette phrase, par exemple (un lugar de cuyo nombre no quiero acordarme), cuyo représente lugar et est complément de nombre: el nombre de un lugar → : un lugar cuyo nombre. Son emploi présente de nombreuses singularités que nous verrons en leçon de révision.

4 L'espagnol utilise la forme pronominale de certains verbes pour don- ner une valeur d'intensité à l'action décrite. Cela est vrai de verbes signifiant des opérations mentales comme, par exemple, leer: Me he leído el Quijote varias veces, J'ai lu le Quichotte plusieurs fois. Dans le dialogue, nous avons saber: Cualquier español se sabe de memoria el principio del Quijote. C'est aussi le cas de verbes décrivant l'absorption de liquides ou d'aliments (pour autant que ceux-ci soient spéci- fiés en quantité, qualité ou nature): Como a menudo bocadillos, Je mange souvent des sandwichs / Me he comido dos bocadillos, f'ai: mangé deux sandwichs. Dans la leçon, tomándote un Valdepeñas (phrase 13) donne ainsi une valeur émotionnelle à l'action de boire.

5 permitir, permettre, et decidir, décider, peuvent être suivis d'un infinitif ; remarquez bien que l'espagnol construit directement, alors que le français introduit la préposition "de": permite seguir, ça permet de suivre; decide cruzar, il décide de traverser.

6 hidalgo, qui est passé au français avec un sens souvent imagé, désigne techniquement le degré le plus modeste de la noblesse castillane : un petit noble, un nobliau (on pourra dire génériquement un gentilhomme). C'est bien le cas de don Quichotte, qui vit fort modestement. Il résulte littéralement de la contraction de hijo de algo, "fils de quelque chose".

7 Petit rappel : pour les siècles, on utilise les ordinaux jusqu'à 10 et les cardinaux ensuite, en les postposant : el siglo cuarto, el siglo noveno, le iv siècle, le ix siècle; el siglo quince, el siglo veintiuno, le xv siècle, le xxi siècle.

8 Un peu d'orthographe ! Le groupe initial français imm- (résultant du préfixe négatif ou privatif in-) se transcrit inm- en espagnol, puisque m n'est pas une des quatre consonnes pouvant être redoublées. On dira et écrira donc inmortalizado, immortalisé.

9 Par rapport à encontrar, trouver, encontrarse con apporte une idée de découverte ou de rencontre involontaire : ¿Has encontrado las Ilaves ?, Tu as trouvé les clés ? / Me encontré con Miguel haciendo la compra, Je suis tombé sur Miguel en train de faire les courses.

10 Devant un pronom relatif, l'article espagnol correspond à notre dé. monstratif: el que habla, celui qui parle. En revanche, lorsque le relatif est précédé d'une préposition, on utilisera également un démonstratif, de préférence aquel(los), aquella(s), ou aquello au neutre : aquellos con los que luchó, ceux contre ("avec") lesquels il lutta; aquel de quien te hablé, celui dont je t'ai parlé.

11 Valdepeñas, dans la province de Ciudad Real (Communauté autonome de Castilla-La Mancha), donne son nom aux vins qui se produisent dans la région. Il s'agit de vins populaires, disons davantage "vins de soif" que "vins de gastronomie".

12 ¿Qué?, outre son sens interrogatif, a parfois dans la conversation une valeur de simple interpellation: ¿Qué, te ha gustado este vinito?, Alors, tu as aimé ce petit vin?

13 animarse a + infinitif signifie se décider à / se motiver à : No me animo a decírselo, Je ne me décide pas à le lui dire. Vous utiliserez couramment ce verbe pour convaincre quelqu'un de participer à une activité: Venga, anímate, Allez, fais un effort; ou alors tout simplement ¿Te animas?, Tu viens ? / Ça te dit?"""

# %%
text
# Out:
# '1 La route sur laquelle circulent les véhicules s\'appelle, comme vous le savez, la carretera ; la ruta désigne l\'itinéraire. Il s\'agit d\'ailleurs d\'un gallicisme et on le retrouve avec ce sens-là en français dans des expressions comme "la route de la soie", "la route du rhum", etc.\n\n2 Dans la langue classique et encore aujourd\'hui, lugar peut désigner un village, une bourgade. C\'est bien en ce sens que l\'emploie Cervantès dans l\'incipit de son roman.\n\n3 cuyo est un pronom relatif particulier, qui a une fonction de com- plément du nom et se rend souvent par dont. Dans cette phrase, par exemple (un lugar de cuyo nombre no quiero acordarme), cuyo représente lugar et est complément de nombre: el nombre de un lugar → : un lugar cuyo nombre. Son emploi présente de nombreuses singularités que nous verrons en leçon de révision.\n\n4 L\'espagnol utilise la forme pronominale de certains verbes pour don- ner une valeur d\'intensité à l\'action décrite. Cela est vrai de verbes sign
# ...

# %%
notes = separate_notes(text)

# %%
notes
# Out:
# ['1 La route sur laquelle circulent les véhicules s\'appelle, comme vous le savez, la carretera ; la ruta désigne l\'itinéraire. Il s\'agit d\'ailleurs d\'un gallicisme et on le retrouve avec ce sens-là en français dans des expressions comme "la route de la soie", "la route du rhum", etc.',
#  "2 Dans la langue classique et encore aujourd'hui, lugar peut désigner un village, une bourgade. C'est bien en ce sens que l'emploie Cervantès dans l'incipit de son roman.",
#  '3 cuyo est un pronom relatif particulier, qui a une fonction de com- plément du nom et se rend souvent par dont. Dans cette phrase, par exemple (un lugar de cuyo nombre no quiero acordarme), cuyo représente lugar et est complément de nombre: el nombre de un lugar → : un lugar cuyo nombre. Son emploi présente de nombreuses singularités que nous verrons en leçon de révision.',
# ...

# %%
for index, note in enumerate(notes):
    store_note(93, index + 1,
# Out:
#   Cell In[17], line 1
#     for index, note in enumerate(notes):
#                                         ^
# SyntaxError: incomplete input

# %%
notes[13]
# Out:
# "animarse a + infinitif signifie se décider à / se motiver à : No me animo a decírselo, Je ne me décide pas à le lui dire. Vous utiliserez couramment ce verbe pour convaincre quelqu'un de participer à une activité: Venga, anímate, Allez, fais un effort; ou alors tout simplement ¿Te animas?, Tu viens ? / Ça te dit?\n"

# %%
for index, note in enumerate(notes):
    print(index + 1, " ", note)
    print("-----------------------")

# %%
notes
# Out:
# []

# %%
import os
from notes_parser import NotesParser

notes_directory = "lessons/notes"

fn = "Notes1.html"

f = open(os.path.join(notes_directory, fn))

notes = f.read()


parser = NotesParser()
parser.analyze(notes)

parser.notes

parser.notes[3]
# Out:
# (4,
#  '<span class="c0"></span><span>\xa0Pour demander à quelqu\'un comment il va, la question abrégée simple est: </span><span class="c4">¿Qué tal? </span><span class="c3">Ça</span><span class="c3">\xa0va ?</span><span>\xa0On sous-entend en fait le verbe estar, </span><span class="c3">être </span><span>-</span><span>\xa0</span><span class="c4">¿Qué tal (estás)?</span><span>\xa0-, qui sert à parler de l\'état d\'âme ou de santé (voir phrase 5: </span><span class="c4">Estoy...</span><span>\xa0</span><span class="c3">Je suis</span><span class="c2">...).</span>')

# %%
parser._head
# Out:
# '<meta content="text/html; charset=UTF-8" http-equiv="content-type"><style type="text/css">ol{margin:0;padding:0}table td,table th{padding:0}.c2{color:#000000;font-weight:400;text-decoration:none;vertical-align:baseline;font-size:11pt;font-family:"Arial";font-style:normal}.c1{padding-top:0pt;padding-bottom:0pt;line-height:1.15;orphans:2;widows:2;text-align:left}.c6{background-color:#ffffff;max-width:451.4pt;padding:72pt 72pt 72pt 72pt}.c0{font-size:12pt;color:#cc0000;font-weight:700}.c5{height:11pt}.c4{font-weight:700}.c3{font-style:italic}.title{padding-top:0pt;color:#000000;font-size:26pt;padding-bottom:3pt;font-family:"Arial";line-height:1.15;page-break-after:avoid;orphans:2;widows:2;text-align:left}.subtitle{padding-top:0pt;color:#666666;font-size:15pt;padding-bottom:16pt;font-family:"Arial";line-height:1.15;page-break-after:avoid;orphans:2;widows:2;text-align:left}li{color:#000000;font-size:11pt;font-family:"Arial"}p{margin:0;color:#000000;font-size:11pt;font-family:"Arial"}h1{p
# ...

# %%
buf = """<meta content="text/html; charset=UTF-8" http-equiv="content-type"><style type="text/css">ol{margin:0;padding:0}table td,table th{padding:0}.c2{color:#000000;font-weight:400;text-decoration:none;vertical-align:baseline;font-size:11pt;font-family:"Arial";font-style:normal}.c1{padding-top:0pt;padding-bottom:0pt;line-height:1.15;orphans:2;widows:2;text-align:left}.c6{background-color:#ffffff;max-width:451.4pt;padding:72pt 72pt 72pt 72pt}.c0{font-size:12pt;color:#cc0000;font-weight:700}.c5{height:11pt}.c4{font-weight:700}.c3{font-style:italic}.title{padding-top:0pt;color:#000000;font-size:26pt;padding-bottom:3pt;font-family:"Arial";line-height:1.15;page-break-after:avoid;orphans:2;widows:2;text-align:left}.subtitle{padding-top:0pt;color:#666666;font-size:15pt;padding-bottom:16pt;font-family:"Arial";line-height:1.15;page-break-after:avoid;orphans:2;widows:2;text-align:left}li{color:#000000;font-size:11pt;font-family:"Arial"}p{margin:0;color:#000000;font-size:11pt;font-family:"Arial"}h1{padding-top:20pt;color:#000000;font-size:20pt;padding-bottom:6pt;font-family:"Arial";line-height:1.15;page-break-after:avoid;orphans:2;widows:2;text-align:left}h2{padding-top:18pt;color:#000000;font-size:16pt;padding-bottom:6pt;font-family:"Arial";line-height:1.15;page-break-after:avoid;orphans:2;widows:2;text-align:left}h3{padding-top:16pt;color:#434343;font-size:14pt;padding-bottom:4pt;font-family:"Arial";line-height:1.15;page-break-after:avoid;orphans:2;widows:2;text-align:left}h4{padding-top:14pt;color:#666666;font-size:12pt;padding-bottom:4pt;font-family:"Arial";line-height:1.15;page-break-after:avoid;orphans:2;widows:2;text-align:left}h5{padding-top:12pt;color:#666666;font-size:11pt;padding-bottom:4pt;font-family:"Arial";line-height:1.15;page-break-after:avoid;orphans:2;widows:2;text-align:left}h6{padding-top:12pt;color:#666666;font-size:11pt;padding-bottom:4pt;font-family:"Arial";line-height:1.15;page-break-after:avoid;font-style:italic;orphans:2;widows:2;text-align:left}</style></head><body class="c6 doc-content"><p class="c1"><span class="c0">1</span><span>&nbsp;</span><span class="c4">Hola</span><span>&nbsp;est la salutation de base informelle. On la rendra faute de mieux par salut, mais notez bien que les Espagnols sont globalement moins formalistes que les Fran&ccedil;ais et que </span><span class="c4">hola</span><span class="c2">&nbsp;n&#39;implique donc pas forc&eacute;ment une familiarit&eacute; tr&egrave;s appuy&eacute;e.</span></p><p class="c1 c5"><span class="c2"></span></p><p class="c1"><span class="c0">2</span><span class="c2">&nbsp;En espagnol &eacute;crit, vous n&#39;avez pas besoin d&#39;attendre la fin de la phrase pour savoir si son intonation va &ecirc;tre exclamative ou interrogative: un signe de ponctuation invers&eacute; vous l&#39;indique d&egrave;s le d&eacute;but ! Ce signe peut m&ecirc;me se trouver au milieu de la phrase si l&#39;intonation porte sur un segment de celle-ci; dans ce cas, on ne mettra pas de majuscule apr&egrave;s le point d&#39;interrogation ou d&#39;exclamation ouvrant ou invers&eacute;.</span></p><p class="c1 c5"><span class="c2"></span></p><p class="c1"><span class="c0">3</span><span>&nbsp;Le pronom personnel (je, tu, il, etc.) n&#39;est pas indispensable devant le verbe. On ne l&#39;utilise que pour insister: </span><span class="c4">Est&aacute;s pachucho</span><span>, </span><span class="c3">Tu es patraque</span><span>&nbsp;/ </span><span class="c4">T&uacute; est&aacute;s pachucho</span><span>, </span><span class="c3">Toi, tu es patraque</span><span class="c2">.</span></p><p class="c1 c5"><span class="c2"></span></p><p class="c1"><span class="c0">4</span><span>&nbsp;Pour demander &agrave; quelqu&#39;un comment il va, la question abr&eacute;g&eacute;e simple est: </span><span class="c4">&iquest;Qu&eacute; tal? </span><span class="c3">&Ccedil;a</span><span class="c3">&nbsp;va ?</span><span>&nbsp;On sous-entend en fait le verbe estar, </span><span class="c3">&ecirc;tre </span><span>-</span><span>&nbsp;</span><span class="c4">&iquest;Qu&eacute; tal (est&aacute;s)?</span><span>&nbsp;-, qui sert &agrave; parler de l&#39;&eacute;tat d&#39;&acirc;me ou de sant&eacute; (voir phrase 5: </span><span class="c4">Estoy...</span><span>&nbsp;</span><span class="c3">Je suis</span><span class="c2">...).</span></p></body></html>"""

# %%
for index, char in enumerate(parser._head):
    if char != buf[index]:
        print(index, buf[:index])

# %%
notes
# Out:
# '<html><head><meta content="text/html; charset=UTF-8" http-equiv="content-type"><style type="text/css">ol{margin:0;padding:0}table td,table th{padding:0}.c2{color:#000000;font-weight:400;text-decoration:none;vertical-align:baseline;font-size:11pt;font-family:"Arial";font-style:normal}.c1{padding-top:0pt;padding-bottom:0pt;line-height:1.15;orphans:2;widows:2;text-align:left}.c6{background-color:#ffffff;max-width:451.4pt;padding:72pt 72pt 72pt 72pt}.c0{font-size:12pt;color:#cc0000;font-weight:700}.c5{height:11pt}.c4{font-weight:700}.c3{font-style:italic}.title{padding-top:0pt;color:#000000;font-size:26pt;padding-bottom:3pt;font-family:"Arial";line-height:1.15;page-break-after:avoid;orphans:2;widows:2;text-align:left}.subtitle{padding-top:0pt;color:#666666;font-size:15pt;padding-bottom:16pt;font-family:"Arial";line-height:1.15;page-break-after:avoid;orphans:2;widows:2;text-align:left}li{color:#000000;font-size:11pt;font-family:"Arial"}p{margin:0;color:#000000;font-size:11pt;font-family:
# ...

# %%
ord('¡')
print('\xa0')

# %%
from database import store_note
from notes_parser import NotesParser

parser = NotesParser()
fn = "/Users/pam/assimil/lessons/UsingSpanish/Notes/Notes.html"
notes_html = open(fn).read()
parser.analyze(notes_html)
all_notes = parser.get_notes()
# Out:
# {'database_name': 'sqlite:////Users/pam/assimil/db/assimil_spanish_new.db', 'basic_audio_directory': '/Users/pam/AssimilAudio/Basic', 'using_spanish_audio_directory': '/Users/pam/AssimilAudio/UsingSpanish', 'html_basic_lessons_directory': '/Users/pam/assimil/lessons/Basic/html', 'html_using_spanish_lessons_directory': '/Users/pam/assimil/lessons/UsingSpanish/html', 'databases_directory': '/Users/pam/assimil/db', 'french_translation_lessons_directoy': '/Users/pam/assimil/lessons/new', 'word_dict_logfilename': '/Users/pam/assimil/word_dict_logfile.log', 'notes_directory': '/Users/pam/assimil/lessons/notes'}
# ...

# %%
type(all_notes)
# Out:
# list

# %%
level = 1
for lesson_nb, notes in all_notes:
    print(lesson_nb)
    for note_number, note in notes:
        print(level, lesson_nb, note_number, note)
        store_note(level, lesson_nb, note_number, note)
# Out:
# 8
# 1 8 1 <span class="c3"></span><span class="c2"> habéis llegado, vous êtes arrivés, est le passé composé du verbe llegar. Notez que le passé composé est très utilisé dans ce dialogue; nous y revenons en détail en leçon de révision.</span>
# 1 8 2 <span class="c3"></span><span class="c2"> Dans un couple, lorsque l'un des deux prend du bon temps alors que son conjoint travaille, on dit de ce dernier qu'il ou elle está de rodríguez. Cette expression remonte aux années 60-70, lorsque les femmes partaient en vacances avec les enfants et que leurs époux restaient en ville à travailler.</span>
# 1 8 3 <span class="c3"></span><span class="c2"> Notez que le préfixe privatif in- s'ajoutant à un mot commençant par m- ne change pas en im-. D'autres exemples: inmortal, immortel: inmóvil, immobile, etc.</span>
# ...

# %%
from database import store_note

file_names = os.listdir("lessons/notes")
parser = NotesParser()
for fn in file_names:
    if fn[0] != '.':
        f = open(os.path.join(notes_directory, fn))
        notes = f.read()
        parser.analyze(notes)
        lesson_nb_string = ""
        for char in fn:
            if char.isdigit():
                lesson_nb_string += char
        lesson_nb = int(lesson_nb_string)
        print(lesson_nb, fn)
        for note_number, note in parser.notes:
            store_note(lesson_nb, note_number, note)
# Out:
# 3 Notes3.html
# 19 Notes19.html
# 15 Notes15.html
# 18 Notes18.html
# 2 Notes2.html
# 9 Notes9.html
# 13 Notes13.html
# 5 Notes5.html
# 4 Notes4.html
# 12 Notes12.html
# 8 Notes8.html
# 11 Notes11.html
# 93 Notes93.html
# 6 Notes6.html
# 10 Notes10.html
# 1 Notes1.html
# 17 Notes17.html
# 16 Notes16.html

# %%
from sqlalchemy.orm import Session
from sqlalchemy import select, and_
from database import GrammarNote, engine

stmt = select(GrammarNote)

nb = 0
with Session(engine) as session:
    for entry in session.scalars(stmt):
        nb += 1
        #print(f"lesson : {entry.lesson}, note number : {entry.note_number}, note : {entry.note}")
print(nb)
# Out:
# 103

# %%
ord('¡')
# Out:
# 161

# %%
ord('¡')
# Out:
# 161

# %%
from database import engine, Paragraph, get_paragraphs
from sqlalchemy.orm import Session
from sqlalchemy import select, and_
# Out:
# {'database_name': 'sqlite:////Users/pam/assimil/db/assimil_spanish.db', 'lessons_directory': '/Users/pam/AssimilAudio/Sentences', 'html_lessons_directory': '/Users/pam/assimil/lessons/html', 'databases_directory': '/Users/pam/assimil/db', 'french_translation_lessons_directoy': '/Users/pam/assimil/lessons/new', 'word_dict_logfilename': '/Users/pam/assimil/word_dict_logfile.log'}

# %%
import yaml

# %%
from database import engine, Paragraph, get_paragraphs
from sqlalchemy.orm import Session
from sqlalchemy import select, and_

stmt = select(Paragraph).where(
        and_(
            Paragraph.level == 0,
            Paragraph.lesson_nb == 57,
            Paragraph.line_nb == 3
            )
    )

with Session(engine) as session:
    entry = session.scalars(stmt).one()
    grammar_indexes = yaml.safe_load(entry.grammar_indexes)
    print(entry, grammar_indexes)
# Out:
# Paragraph(id=942, level=0, section=1, lesson_nb=57, line_nb=3, paragraph ='¿Sí? ¿Soñaste que tu jefe te sonreía?', grammar_indexes : '2: 4\n', data = None) {2: 4}

# %%
from tonic_accent import get_bold_paragraph_with_note_numbers

# %%
import re
from tonic_accent import get_html_of_token
def get_bold_paragraph_with_note_numbers(paragraph, note_numbers, lesson_dict = {}):
    note_positions = []
    bold_paragraph = ""
    index = 0
    if note_numbers:
        for n in note_numbers:
            note_positions.append((note_numbers[n], n))
        note_positions.sort()
        np_index = 0
        np = note_positions[np_index][0]
    else:
        np = float('inf')
    tokens = re.findall(r"[\w]+", paragraph)

    for token in tokens:
        token_length = len(token)
        pos = paragraph.find(token, index)
        inter_token = paragraph[index:pos]
        bold_paragraph += inter_token + get_html_of_token(token, lesson_dict)
        if np <= pos + token_length:
            bold_paragraph += f"<sup onclick='(function(event) {{ displayNote({note_positions[np_index][1]}, event); }})(event)' class='assimil'> {note_positions[np_index][1]}</sup>"
            if np_index < len(note_positions) - 1:
                np_index += 1
                np = note_positions[np_index][0]
            else:
                np = float('inf')
        index += len(inter_token) + token_length
    bold_paragraph += paragraph[index:]
    if np != float('inf'):
        bold_paragraph += f"<sup onclick='(function(event) {{ displayNote({note_positions[np_index][1]}, event); }})(event)' class='assimil'> {note_positions[np_index][1]}</sup>"
    return bold_paragraph

# %%
get_bold_paragraph_with_note_numbers
# Out:
# <function __main__.get_bold_paragraph_with_note_numbers(paragraph, note_numbers, lesson_dict={})>

# %%
grammar_indexes
# Out:
# {4: 31}

# %%
get_bold_paragraph_with_note_numbers('¡Bien, gracias! ¿Y tú, qué tal?', grammar_indexes)
# Out:
# "¡Bien, <b>gra</b>cias! ¿Y tú, qué tal?<sup onclick='(function(event) { displayNote(4, event); })(event)' class='assimil'> 4</sup>"

# %%
from maintenance.grammar import store_all_notes
# Out:
# {'database_name': 'sqlite:////Users/pam/assimil/db/assimil_spanish.db', 'lessons_directory': '/Users/pam/AssimilAudio/Sentences', 'html_lessons_directory': '/Users/pam/assimil/lessons/html', 'databases_directory': '/Users/pam/assimil/db', 'french_translation_lessons_directoy': '/Users/pam/assimil/lessons/new', 'word_dict_logfilename': '/Users/pam/assimil/word_dict_logfile.log', 'notes_directory': '/Users/pam/assimil/lessons/notes'}

# %%
store_all_notes()
# Out:
# 3 Notes3.html
# 19 Notes19.html
# 15 Notes15.html
# 18 Notes18.html
# 2 Notes2.html
# 22 Notes22.html
# 9 Notes9.html
# 13 Notes13.html
# 5 Notes5.html
# 4 Notes4.html
# 12 Notes12.html
# 8 Notes8.html
# 11 Notes11.html
# 93 Notes93.html
# 6 Notes6.html
# 10 Notes10.html
# 1 Notes1.html
# 17 Notes17.html
# 16 Notes16.html
# 20 Notes20.html

# %%
from database import get_note
note = get_note(2, 1)

# %%
note
# Out:
# '<span class="c1"></span><span>\xa0Remarquez ici, ainsi qu\'en phrases 4 et 5, les deux premières personnes du verbe </span><span class="c4">vivir</span><span>, </span><span class="c6">vivre</span><span class="c2">.</span>'

# %%
import re

def formater_css(css_string):
    """
    Fonction pour formater une chaîne CSS en ajoutant des retours à la ligne.

    Args:
        css_string (str): La chaîne de caractères CSS non formatée.

    Returns:
        str: La chaîne CSS formatée avec des retours à la ligne.
    """

    # Expression régulière pour identifier les débuts de nouvelles règles CSS
    reg = r'(\{[^}]+\})'

    # Diviser la chaîne en une liste de règles CSS
    regles = re.split(reg, css_string)

    # Reconstruire la chaîne avec des retours à la ligne
    css_formatte = ''
    for i in range(0, len(regles), 2):
        css_formatte += regles[i] + '\n' + regles[i+1] + '\n'

    return css_formatte

# %%
s = """ol{margin:0;padding:0}table td,table th{padding:0}.c2{color:#000000;font-weight:400;text-decoration:none;vertical-align:baseline;font-size:11pt;font-family:"Arial";font-style:normal}.c1{padding-top:0pt;padding-bottom:0pt;line-height:1.15;orphans:2;widows:2;text-align:left}.c6{background-color:#ffffff;max-width:451.4pt;padding:72pt 72pt 72pt 72pt}.c0{font-size:12pt;color:#cc0000;font-weight:700}.c5{height:11pt}.c4{font-weight:700}.c3{font-style:italic}.title{padding-top:0pt;color:#000000;font-size:26pt;padding-bottom:3pt;font-family:"Arial";line-height:1.15;page-break-after:avoid;orphans:2;widows:2;text-align:left}.subtitle{padding-top:0pt;color:#666666;font-size:15pt;padding-bottom:16pt;font-family:"Arial";line-height:1.15;page-break-after:avoid;orphans:2;widows:2;text-align:left}li{color:#000000;font-size:11pt;font-family:"Arial"}p{margin:0;color:#000000;font-size:11pt;font-family:"Arial"}h1{padding-top:20pt;color:#000000;font-size:20pt;padding-bottom:6pt;font-family:"Arial";line-height:1.15;page-break-after:avoid;orphans:2;widows:2;text-align:left}h2{padding-top:18pt;color:#000000;font-size:16pt;padding-bottom:6pt;font-family:"Arial";line-height:1.15;page-break-after:avoid;orphans:2;widows:2;text-align:left}h3{padding-top:16pt;color:#434343;font-size:14pt;padding-bottom:4pt;font-family:"Arial";line-height:1.15;page-break-after:avoid;orphans:2;widows:2;text-align:left}h4{padding-top:14pt;color:#666666;font-size:12pt;padding-bottom:4pt;font-family:"Arial";line-height:1.15;page-break-after:avoid;orphans:2;widows:2;text-align:left}h5{padding-top:12pt;color:#666666;font-size:11pt;padding-bottom:4pt;font-family:"Arial";line-height:1.15;page-break-after:avoid;orphans:2;widows:2;text-align:left}h6{padding-top:12pt;color:#666666;font-size:11pt;padding-bottom:4pt;font-family:"Arial";line-height:1.15;page-break-after:avoid;font-style:italic;orphans:2;widows:2;text-align:left}"""

# %%
formater_css(s)
# Out:
# ---------------------------------------------------------------------------
# IndexError                                Traceback (most recent call last)
# Cell In[6], line 1
# ----> 1 formater_css(s)
#
# Cell In[4], line 23, in formater_css(css_string)
#      21 css_formatte = ''
#      22 for i in range(0, len(regles), 2):
# ---> 23     css_formatte += regles[i] + '\n' + regles[i+1] + '\n'
#      25 return css_formatte
#
# IndexError: list index out of range

# %%
reg = r'(\{[^}]+\})'

# %%
regles = re.split(reg, s)

# %%
regles
# Out:
# ['ol',
#  '{margin:0;padding:0}',
#  'table td,table th',
#  '{padding:0}',
#  '.c2',
#  '{color:#000000;font-weight:400;text-decoration:none;vertical-align:baseline;font-size:11pt;font-family:"Arial";font-style:normal}',
#  '.c1',
#  '{padding-top:0pt;padding-bottom:0pt;line-height:1.15;orphans:2;widows:2;text-align:left}',
#  '.c6',
#  '{background-color:#ffffff;max-width:451.4pt;padding:72pt 72pt 72pt 72pt}',
#  '.c0',
#  '{font-size:12pt;color:#cc0000;font-weight:700}',
#  '.c5',
#  '{height:11pt}',
#  '.c4',
#  '{font-weight:700}',
#  '.c3',
#  '{font-style:italic}',
#  '.title',
#  '{padding-top:0pt;color:#000000;font-size:26pt;padding-bottom:3pt;font-family:"Arial";line-height:1.15;page-break-after:avoid;orphans:2;widows:2;text-align:left}',
#  '.subtitle',
#  '{padding-top:0pt;color:#666666;font-size:15pt;padding-bottom:16pt;font-family:"Arial";line-height:1.15;page-break-after:avoid;orphans:2;widows:2;text-align:left}',
#  'li',
# ...

# %%
len(regles)
# Out:
# 38

# %%
regles=regles[:-1]

# %%
regles
# Out:
# ['ol',
#  '{margin:0;padding:0}',
#  'table td,table th',
#  '{padding:0}',
#  '.c2',
#  '{color:#000000;font-weight:400;text-decoration:none;vertical-align:baseline;font-size:11pt;font-family:"Arial";font-style:normal}',
#  '.c1',
#  '{padding-top:0pt;padding-bottom:0pt;line-height:1.15;orphans:2;widows:2;text-align:left}',
#  '.c6',
#  '{background-color:#ffffff;max-width:451.4pt;padding:72pt 72pt 72pt 72pt}',
#  '.c0',
#  '{font-size:12pt;color:#cc0000;font-weight:700}',
#  '.c5',
#  '{height:11pt}',
#  '.c4',
#  '{font-weight:700}',
#  '.c3',
#  '{font-style:italic}',
#  '.title',
#  '{padding-top:0pt;color:#000000;font-size:26pt;padding-bottom:3pt;font-family:"Arial";line-height:1.15;page-break-after:avoid;orphans:2;widows:2;text-align:left}',
#  '.subtitle',
#  '{padding-top:0pt;color:#666666;font-size:15pt;padding-bottom:16pt;font-family:"Arial";line-height:1.15;page-break-after:avoid;orphans:2;widows:2;text-align:left}',
#  'li',
# ...

# %%
css_formatte = ''
for i in range(0, len(regles), 2):
    css_formatte += regles[i] + ' ' + regles[i+1][0] + '\n' + regles[i+1] + '\n'

# %%
css_formatte
# Out:
# 'ol\n{margin:0;padding:0}\ntable td,table th\n{padding:0}\n.c2\n{color:#000000;font-weight:400;text-decoration:none;vertical-align:baseline;font-size:11pt;font-family:"Arial";font-style:normal}\n.c1\n{padding-top:0pt;padding-bottom:0pt;line-height:1.15;orphans:2;widows:2;text-align:left}\n.c6\n{background-color:#ffffff;max-width:451.4pt;padding:72pt 72pt 72pt 72pt}\n.c0\n{font-size:12pt;color:#cc0000;font-weight:700}\n.c5\n{height:11pt}\n.c4\n{font-weight:700}\n.c3\n{font-style:italic}\n.title\n{padding-top:0pt;color:#000000;font-size:26pt;padding-bottom:3pt;font-family:"Arial";line-height:1.15;page-break-after:avoid;orphans:2;widows:2;text-align:left}\n.subtitle\n{padding-top:0pt;color:#666666;font-size:15pt;padding-bottom:16pt;font-family:"Arial";line-height:1.15;page-break-after:avoid;orphans:2;widows:2;text-align:left}\nli\n{color:#000000;font-size:11pt;font-family:"Arial"}\np\n{margin:0;color:#000000;font-size:11pt;font-family:"Arial"}\nh1\n{padding-top:20pt;color:#000000;font-s
# ...

# %%
print(css_formatte)
# Out:
# ol
# {margin:0;padding:0}
# table td,table th
# {padding:0}
# .c2
# {color:#000000;font-weight:400;text-decoration:none;vertical-align:baseline;font-size:11pt;font-family:"Arial";font-style:normal}
# .c1
# {padding-top:0pt;padding-bottom:0pt;line-height:1.15;orphans:2;widows:2;text-align:left}
# .c6
# {background-color:#ffffff;max-width:451.4pt;padding:72pt 72pt 72pt 72pt}
# .c0
# {font-size:12pt;color:#cc0000;font-weight:700}
# .c5
# {height:11pt}
# .c4
# {font-weight:700}
# .c3
# {font-style:italic}
# .title
# {padding-top:0pt;color:#000000;font-size:26pt;padding-bottom:3pt;font-family:"Arial";line-height:1.15;page-break-after:avoid;orphans:2;widows:2;text-align:left}
# .subtitle
# {padding-top:0pt;color:#666666;font-size:15pt;padding-bottom:16pt;font-family:"Arial";line-height:1.15;page-break-after:avoid;orphans:2;widows:2;text-align:left}
# li
# {color:#000000;font-size:11pt;font-family:"Arial"}
# p
# {margin:0;color:#000000;font-size:11pt;font-family:"Arial"}
# h1
# ...

# %%
''.find("toto")
# Out:
# -1

# %%
from notes_parser import NotesParser

# %%
fn = "lessons/Notes.html"
notes = open(fn).read()

# %%
notes
# Out:
# '<html><head><meta content="text/html; charset=UTF-8" http-equiv="content-type"><style type="text/css">ol{margin:0;padding:0}table td,table th{padding:0}.c3{color:#000000;font-weight:400;text-decoration:none;vertical-align:baseline;font-size:11pt;font-family:"Arial";font-style:normal}.c10{color:#000000;text-decoration:none;vertical-align:baseline;font-size:11pt;font-family:"Arial";font-style:normal}.c2{padding-top:0pt;padding-bottom:0pt;line-height:1.15;orphans:2;widows:2;text-align:left}.c7{color:#000000;font-weight:400;text-decoration:none;vertical-align:baseline;font-size:11pt;font-family:"Arial"}.c9{background-color:#ffffff;max-width:451.4pt;padding:72pt 72pt 72pt 72pt}.c0{font-size:12pt;color:#cc0000;font-weight:700}.c4{font-style:italic}.c8{vertical-align:super}.c5{height:11pt}.c6{color:#cc0000}.c1{font-weight:700}.title{padding-top:0pt;color:#000000;font-size:26pt;padding-bottom:3pt;font-family:"Arial";line-height:1.15;page-break-after:avoid;orphans:2;widows:2;text-align:left}
# ...

# %%
parser = NotesParser()
parser.analyze(notes)
all_notes = parser.get_notes()
# Out:
# ol{margin:0;padding:0}table td,table th{padding:0}.c3{color:#000000;font-weight:400;text-decoration:none;vertical-align:baseline;font-size:11pt;font-family:"Arial";font-style:normal}.c10{color:#000000;text-decoration:none;vertical-align:baseline;font-size:11pt;font-family:"Arial";font-style:normal}.c2{padding-top:0pt;padding-bottom:0pt;line-height:1.15;orphans:2;widows:2;text-align:left}.c7{color:#000000;font-weight:400;text-decoration:none;vertical-align:baseline;font-size:11pt;font-family:"Arial"}.c9{background-color:#ffffff;max-width:451.4pt;padding:72pt 72pt 72pt 72pt}.c0{font-size:12pt;color:#cc0000;font-weight:700}.c4{font-style:italic}.c8{vertical-align:super}.c5{height:11pt}.c6{color:#cc0000}.c1{font-weight:700}.title{padding-top:0pt;color:#000000;font-size:26pt;padding-bottom:3pt;font-family:"Arial";line-height:1.15;page-break-after:avoid;orphans:2;widows:2;text-align:left}.subtitle{padding-top:0pt;color:#666666;font-size:15pt;padding-bottom:16pt;font-family:"Arial";line-hei
# ...

# %%
len(parser._lessons)
# Out:
# 20

# %%
parser._lessons[5]
# Out:
# (6,
#  [(1,
#    '<span class="c0"></span><span>\xa0Puisque le verbe conjugué ne porte pas toujours le pronom personnel sujet, c\'est la terminaison qui vous donne la personne du verbe observez donc bien l\'alternance </span><span class="c1">-o</span><span>\xa0/ </span><span class="c1">-as</span><span>\xa0(</span><span class="c1">trabaj</span><span class="c6 c1">o</span><span>, </span><span class="c1">termin</span><span class="c6">o</span><span>, </span><span class="c1">invit</span><span class="c6 c1">o</span><span>: 1</span><span class="c8">re</span><span>\xa0personne, </span><span class="c4">je...</span><span>\xa0/ </span><span class="c1">trabaj</span><span class="c6 c1">as</span><span>, </span><span class="c1">termin</span><span class="c6 c1">as</span><span>: 2º personne, </span><span class="c4">tu...</span><span class="c3">).</span>'),
#   (2,
# ...

# %%
parser.get_notes()[14]
notes
# Out:
# [(1,
#   [(1,
#     '<span class="c0"></span><span></span><span class="c1">Hola</span><span>\xa0est la salutation de base informelle. On la rendra faute de mieux par salut, mais notez bien que les Espagnols sont globalement moins formalistes que les Français et que </span><span class="c1">hola</span><span class="c3">\xa0n\'implique donc pas forcément une familiarité très appuyée.</span>'),
#    (2,
#     '<span class="c0"></span><span class="c3">\xa0En espagnol écrit, vous n\'avez pas besoin d\'attendre la fin de la phrase pour savoir si son intonation va être exclamative ou interrogative: un signe de ponctuation inversé vous l\'indique dès le début ! Ce signe peut même se trouver au milieu de la phrase si l\'intonation porte sur un segment de celle-ci; dans ce cas, on ne mettra pas de majuscule après le point d\'interrogation ou d\'exclamation ouvrant ou inversé.</span>'),
#    (3,
# ...

# %%
parser._lessons[14]
# Out:
# (17,
#  [(1,
#    '<span class="c0"></span><span>\xa0Comme vous le savez, le "vouvoiement de politesse” passe par la 3º personne: </span><span class="c1">¿En qué puedo ayudar</span><span class="c6 c1">la</span><span class="c1">?</span><span>\xa0peut donc signifier </span><span class="c4">En quoi puis-je </span><span class="c4 c6">vous</span><span class="c4">\xa0aider?</span><span>\xa0ou </span><span class="c4">En quoi puis-je </span><span class="c4 c6">l</span><span class="c7 c4">\'aider ?</span>'),
#   (2,
#    '<span class="c0"></span><span></span><span class="c1">necesitar</span><span>\xa0rend toute l\'expression </span><span class="c4">avoir besoin de</span><span>. Il se construit avec un complément d\'objet direct, sans préposition: </span><span class="c1">Necesito dormir</span><span>, </span><span class="c4">J\'ai besoin de dormir</span><span class="c3">.</span>'),
#   (3,
# ...

# %%
for lesson in parser._lessons:
    print(lesson[0])
# Out:
# 1
# 2
# 3
# 4
# 5
# 6
# 8
# 9
# 10
# 11
# 12
# 13
# 15
# 16
# 17
# 18
# 19
# 20
# 22

# %%
lessonsA = parser._lessons

# %%
lessonsA
# Out:
# [(1,
#   [(1,
#     '<span class="c4 c0"></span><span></span><span class="c0">Hola</span><span>\xa0est la salutation de base informelle. On la rendra faute de mieux par salut, mais notez bien que les Espagnols sont globalement moins formalistes que les Français et que </span><span class="c0">hola</span><span class="c2">\xa0n\'implique donc pas forcément une familiarité très appuyée.</span>'),
#    (2,
#     '<span class="c4 c0"></span><span class="c2">\xa0En espagnol écrit, vous n\'avez pas besoin d\'attendre la fin de la phrase pour savoir si son intonation va être exclamative ou interrogative: un signe de ponctuation inversé vous l\'indique dès le début ! Ce signe peut même se trouver au milieu de la phrase si l\'intonation porte sur un segment de celle-ci; dans ce cas, on ne mettra pas de majuscule après le point d\'interrogation ou d\'exclamation ouvrant ou inversé.</span>'),
#    (3,
# ...

# %%
for i, lesson in enumerate(lessonsA):
    if parser._lessons[i] != lesson:
        print(i, "lessons !=")

# %%
lessonsA
# Out:
# [(1,
#   [(1,
#     '<span class="c4 c0"></span><span></span><span class="c0">Hola</span><span>\xa0est la salutation de base informelle. On la rendra faute de mieux par salut, mais notez bien que les Espagnols sont globalement moins formalistes que les Français et que </span><span class="c0">hola</span><span class="c2">\xa0n\'implique donc pas forcément une familiarité très appuyée.</span>'),
#    (2,
#     '<span class="c4 c0"></span><span class="c2">\xa0En espagnol écrit, vous n\'avez pas besoin d\'attendre la fin de la phrase pour savoir si son intonation va être exclamative ou interrogative: un signe de ponctuation inversé vous l\'indique dès le début ! Ce signe peut même se trouver au milieu de la phrase si l\'intonation porte sur un segment de celle-ci; dans ce cas, on ne mettra pas de majuscule après le point d\'interrogation ou d\'exclamation ouvrant ou inversé.</span>'),
#    (3,
# ...

# %%
from paths import get_path
# Out:
# {'database_name': 'sqlite:////Users/pam/assimil/db/assimil_spanish.db', 'lessons_directory': '/Users/pam/AssimilAudio/Sentences', 'html_lessons_directory': '/Users/pam/assimil/lessons/html', 'databases_directory': '/Users/pam/assimil/db', 'french_translation_lessons_directoy': '/Users/pam/assimil/lessons/new', 'word_dict_logfilename': '/Users/pam/assimil/word_dict_logfile.log', 'notes_directory': '/Users/pam/assimil/lessons/notes'}

# %%
get_path("notes_directory")
# Out:
# '/Users/pam/assimil/lessons/notes'

# %%
notes
# Out:
# [(1,
#   [(1,
#     '<span class="c0"></span><span></span><span class="c1">Hola</span><span>\xa0est la salutation de base informelle. On la rendra faute de mieux par salut, mais notez bien que les Espagnols sont globalement moins formalistes que les Français et que </span><span class="c1">hola</span><span class="c3">\xa0n\'implique donc pas forcément une familiarité très appuyée.</span>'),
#    (2,
#     '<span class="c0"></span><span class="c3">\xa0En espagnol écrit, vous n\'avez pas besoin d\'attendre la fin de la phrase pour savoir si son intonation va être exclamative ou interrogative: un signe de ponctuation inversé vous l\'indique dès le début ! Ce signe peut même se trouver au milieu de la phrase si l\'intonation porte sur un segment de celle-ci; dans ce cas, on ne mettra pas de majuscule après le point d\'interrogation ou d\'exclamation ouvrant ou inversé.</span>'),
#    (3,
# ...

# %%
for lesson_nb, note in notes:
    print(lesson_nb, len(note[1]))
# Out:
# 1 2
# 2 2
# 3 2
# 4 2
# 5 2
# 6 2
# 8 2
# 9 2
# 10 2
# 11 2
# 12 2
# 13 2
# 15 2
# 16 2
# 17 2
# 18 2
# 19 2
# 20 2
# 22 2
# 93 2

# %%
notes[0][1][0][1]
# Out:
# '<span class="c0"></span><span></span><span class="c1">Hola</span><span>\xa0est la salutation de base informelle. On la rendra faute de mieux par salut, mais notez bien que les Espagnols sont globalement moins formalistes que les Français et que </span><span class="c1">hola</span><span class="c3">\xa0n\'implique donc pas forcément une familiarité très appuyée.</span>'

# %%
for notes in all_notes:
    lesson_nb = notes[0]
    print(lesson_nb)
    for note in notes[1]:
        print(note[0], "   ", note[1])
# Out:
# 1
# 1     <span class="c0"></span><span></span><span class="c1">Hola</span><span> est la salutation de base informelle. On la rendra faute de mieux par salut, mais notez bien que les Espagnols sont globalement moins formalistes que les Français et que </span><span class="c1">hola</span><span class="c3"> n'implique donc pas forcément une familiarité très appuyée.</span>
# 2     <span class="c0"></span><span class="c3"> En espagnol écrit, vous n'avez pas besoin d'attendre la fin de la phrase pour savoir si son intonation va être exclamative ou interrogative: un signe de ponctuation inversé vous l'indique dès le début ! Ce signe peut même se trouver au milieu de la phrase si l'intonation porte sur un segment de celle-ci; dans ce cas, on ne mettra pas de majuscule après le point d'interrogation ou d'exclamation ouvrant ou inversé.</span>
# ...

# %%
import os
level_prefix = "Basic"
fn = os.path.join("lessons", level_prefix, "notes/Notes.html")
open(fn)
#os.listdir(os.path.join("lessons", level_prefix, "notes"))
# Out:
# <_io.TextIOWrapper name='lessons/Basic/notes/Notes.html' mode='r' encoding='UTF-8'>

# %%
from maintenance.grammar import store_notes

# %%
store_notes([34], 1)
# Out:
# ol{margin:0;padding:0}table td,table th{padding:0}.c2{color:#000000;font-weight:400;text-decoration:none;vertical-align:baseline;font-size:11pt;font-family:"Arial";font-style:normal}.c3{padding-top:0pt;padding-bottom:0pt;line-height:1.15;orphans:2;widows:2;text-align:left}.c7{color:#000000;font-weight:400;text-decoration:none;vertical-align:baseline;font-size:11pt;font-family:"Arial"}.c9{background-color:#ffffff;max-width:451.4pt;padding:72pt 72pt 72pt 72pt}.c5{color:#00ff00;font-size:12pt}.c8{vertical-align:super}.c4{height:11pt}.c6{color:#00ff00}.c0{font-style:italic}.c1{font-weight:700}.title{padding-top:0pt;color:#000000;font-size:26pt;padding-bottom:3pt;font-family:"Arial";line-height:1.15;page-break-after:avoid;orphans:2;widows:2;text-align:left}.subtitle{padding-top:0pt;color:#666666;font-size:15pt;padding-bottom:16pt;font-family:"Arial";line-height:1.15;page-break-after:avoid;orphans:2;widows:2;text-align:left}li{color:#000000;font-size:11pt;font-family:"Arial"}p{margin:0;col
# ...

# %%
from database import get_note

# %%
get_note(1, 26, 10)
# Out:
# '10       <span class="c1"></span><span></span><span class="c3">estrenar</span><span>\xa0signifie </span><span class="c5">utiliser pour la 1e fois</span><span>, </span><span class="c5">étrenner</span><span>\xa0: </span><span class="c3">Me cuesta andar, estreno zapatos</span><span>, </span><span class="c5">J\'ai du mal à marcher, c\'est la 1™ fois que je mets ces chaussures/ce sont des chaussures toutes neuves</span><span>. Le nom, </span><span class="c3">el estreno</span><span>, désigne la première représentation/projection publique d\'un spectacle : </span><span class="c3">Al estreno de la película asistieron todos los actores</span><span>, </span><span class="c5">Tous les acteurs ont assisté à la première du film</span><span class="c2">.</span>'

# %%
from html.parser import HTMLParser

class ClassFinder(HTMLParser):

    def analyze(self, notes):
        self.classes = {}
        self.feed(notes)

    def handle_starttag(self, tag, attrs):
        for attr in attrs:
            if attr[0] == 'class':
                if attr[1] in self.classes:
                    if tag in self.classes[attr[1]]:
                        pass
                    else:
                        self.classes[attr[1]].append(tag)
                else:
                    self.classes[attr[1]] = [tag]

class_finder = ClassFinder()
fn = "lessons/Notes.html"
notes = open(fn).read()
class_finder.analyze(notes)
print(class_finder.classes)
# Out:
# {'c11 doc-content': ['body'], 'c5': ['p'], 'c2': ['span'], 'c1': ['p'], 'c4 c3': ['span'], 'c3': ['span'], 'c0': ['span'], 'c6': ['span'], 'c8 c0': ['span'], 'c3 c7': ['span'], 'c7': ['span'], 'c7 c0': ['span'], 'c9 c3': ['span'], 'c3 c4': ['span'], 'c0 c8': ['span'], 'c10': ['span'], 'c3 c9': ['span'], 'c3 c0': ['span'], 'c0 c6': ['span']}

# %%
from html.parser import HTMLParser

class ClassFinder(HTMLParser):

    def analyze(self, notes):
        self.classes = {}
        self.feed(notes)

    def handle_starttag(self, tag, attrs):
        for attr in attrs:
            if attr[0] == 'class':
                if attr[1] in self.classes:
                    if tag in self.classes[attr[1]]:
                        pass
                    else:
                        self.classes[attr[1]].append(tag)
                else:
                    self.classes[attr[1]] = [tag]

def display_classes():
    class_finder = ClassFinder()
    fn = "lessons/Notes.html"
    notes = open(fn).read()
    class_finder.analyze(notes)
    print(class_finder.classes)

# %%
display_classes()
# Out:
# {'c11 doc-content': ['body'], 'c1': ['p'], 'c4': ['span'], 'c1 c3': ['p'], 'c5 c2': ['span'], 'c2': ['span'], 'c0': ['span'], 'c7': ['span'], 'c9 c0': ['span'], 'c2 c6': ['span'], 'c6': ['span'], 'c0 c6': ['span'], 'c8 c2': ['span'], 'c10': ['span'], 'c2 c8': ['span'], 'c2 c5': ['span'], 'c0 c2': ['span'], 'c0 c7': ['span'], 'c0 c9': ['span']}

# %%
a=[1, 3, "toto"]

# %%
1 in a
# Out:
# True

# %%
'toto' in a
# Out:
# True

# %%
't' in a
# Out:
# False

# %%
from sqlalchemy import select, and_
from sqlalchemy.orm import Session

from database import GrammarNote, engine

stmt = select(GrammarNote).where(
    and_(
        GrammarNote.lesson == 93,
        GrammarNote.note_number == 11
    )
)
note_nb = 0
with Session(engine) as session:
        for entry in session.scalars(stmt):
            print(entry.note)
            note_nb += 1
print(note_nb)
# Out:
# <span class="c4 c3"></span><span></span><span class="c3">Valdepeñas</span><span>, dans la province de </span><span class="c3">Ciudad Real</span><span> (Communauté autonome de </span><span class="c3">Castilla-La Mancha</span><span class="c2">), donne son nom aux vins qui se produisent dans la région. Il s'agit de vins populaires, disons davantage "vins de soif" que "vins de gastronomie".</span>
# 1
