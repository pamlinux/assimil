# %%
import re
import string
import os

from html.parser import HTMLParser

def get_words(sentence):
    return re.sub('['+string.punctuation+'¿'+'¡'+']', ' ', sentence).split()

def get_syllables(sentence, sentence_fragments):
    words = re.sub('['+string.punctuation+'¿'+'¡'+']', ' ', sentence).split()
    syllables = []

    for f in sentence_fragments:
        frags = re.sub('['+string.punctuation+'¿'+'¡'+']', ' ', f[0]).split()
        for r in frags:
            syllables.append((r, f[1]))
    return syllables

def get_sentence_word_dict(sentence, sentence_fragments):
    index = 0
    buffer = ""
    word_dict = {}
    accentuated_word = []

    words = get_words(sentence)
    syllables = get_syllables(sentence, sentence_fragments)

    for w in words:
        while index < 100:
            buffer += syllables[index][0]
            accentuated_word.append(syllables[index])
            index += 1
            if buffer == w:
                word_dict[w.lower()] = accentuated_word
                buffer = ""
                accentuated_word = []
                break
    return word_dict

class MyHTMLParser(HTMLParser):
        
    def analyze_lesson(self, lesson):
        self.sentences = []
        self.sentences_fragments = []
        self.bold_data = False
        self.feed(lesson)

    def get_lesson_word_dict(self):
        word_dict = {}
        if not hasattr(self, 'sentences'):
            return {}
        for i, s in enumerate(self.sentences):
            wd = get_sentence_word_dict(s, self.sentences_fragments[i])
            for w in wd:
                if not w in word_dict:
                    word_dict[w] = wd[w]
        return word_dict
        
    def handle_starttag(self, tag, attrs):
        if tag == "b":
            self.bold_data = True
        elif tag == "p":
            self.current_sentence = ""
            self.current_sentence_fragments = []
            #self.first_data = True


    def handle_endtag(self, tag):
        if tag == "b":
            self.bold_data = False
        elif tag == "p":
            self.sentences_fragments.append(self.current_sentence_fragments)
            self.sentences.append(self.current_sentence)
            
    def handle_data(self, data):
        #if self.first_data:
        #    self.first_data = False
            #data = data.split('-')[1]
        self.current_sentence_fragments.append((data, self.bold_data))
        self.current_sentence += data

# %%
lesson = open('./pronunciation/lessons/L004.html').read()

# %%
parser = MyHTMLParser()

# %%
parser.analyze_lesson(lesson)

# %%
sentence_number = 6
s = parser.sentences[sentence_number]
sf = parser.sentences_fragments[sentence_number]
s
# Out:
# 'S05-¡Vale!\xa0'

# %%
sf
# Out:
# [('S05-¡', False), ('Va', True), ('le!', False), ('\xa0', False)]

# %%
word_dict = get_sentence_word_dict(s, sf)
word_dict
# Out:
# {'s05': [('S05', False)], 'vale': [('Va', True), ('le', False)]}

# %%
word_dict = {}
for k in range(5):
    s = parser.sentences[k]
    sf = parser.sentences_fragments[k]
    wd = get_sentence_word_dict(s, sf)
    word_dict.update(wd)

# %%
word_dict
# Out:
# {'n4': [('N4', False)],
#  'lección': [('Lec', False), ('ción', True)],
#  'cuarta': [('cua', True), ('rta', False)],
#  's00': [('S00', False)],
#  'title': [('TITLE', False)],
#  'presentaciones': [('Presenta', False), ('cio', True), ('nes', False)],
#  's01': [('S01', False)],
#  'él': [('él', False)],
#  'es': [('es', False)],
#  'rafa': [('Ra', True), ('fa', False)],
#  'mi': [('mi', False)],
#  'hermano': [('her', False), ('ma', True), ('no', False)],
#  'y': [('Y', False)],
#  'ella': [('e', True), ('lla', False)],
#  'luz': [('Luz', False)],
#  'hermana': [('her', False), ('ma', True), ('na', False)],
#  's02': [('S02', False)],
#  'padre': [('pa', True), ('dre', False)],
#  'miguel': [('Mi', False), ('guel', True)],
#  's03': [('S03', False)],
#  'mucho': [('Mu', True), ('cho', False)],
#  'gusto': [('gus', True), ('to', False)],
#  'cómo': [('Có', True), ('mo', False)],
#  'está': [('est', False), ('á', True)],
#  'usted': [('us', False), ('ted', True)]}

# %%
parser.get_lesson_word_dict()
# Out:
# {'n4': [('N4', False)],
#  'lección': [('Lec', False), ('ción', True)],
#  'cuarta': [('cua', True), ('rta', False)],
#  's00': [('S00', False)],
#  'title': [('TITLE', False)],
#  'presentaciones': [('Presenta', False), ('cio', True), ('nes', False)],
#  's01': [('S01', False)],
#  'él': [('Él', False)],
#  'es': [('es', False)],
#  'rafa': [('Ra', True), ('fa', False)],
#  'mi': [('mi', False)],
#  'hermano': [('her', False), ('ma', True), ('no', False)],
#  'y': [('y', False)],
#  'ella': [('e', True), ('lla', False)],
#  'luz': [('Luz', False)],
#  'hermana': [('her', False), ('ma', True), ('na', False)],
#  's02': [('S02', False)],
#  'padre': [('pa', True), ('dre', False)],
#  'miguel': [('Mi', False), ('guel', True)],
#  's03': [('S03', False)],
#  'mucho': [('Mu', True), ('cho', False)],
#  'gusto': [('gus', True), ('to', False)],
#  'cómo': [('Có', True), ('mo', False)],
#  'está': [('est', False), ('á', True)],
#  'usted': [('us', False), ('ted', True)],
#  's04': [('S04', False)],
#  'muy': [('Muy', False)],
#  'bien': [('bien', False)],
#  'pero': [('pe', True), ('ro', False)],
#  'háblame': [('há', True), ('blame', False)],
#  'de': [('de', False)],
#  'tú': [('tú', False)],
#  'por': [('por', False)],
#  'favor': [('fa', False), ('vor', True)],
#  's05': [('S05', False)],
#  'vale': [('Va', True), ('le', False)],
#  't00': [('T00', False)],
#  'translate': [('TRANSLATE', False)],
#  'ejercicio': [('Ejer', False), ('ci', True), ('cio', False)],
#  '1': [('1', False)],
#  '–': [('–', False)],
#  'traduzca': [('Tra', False), ('duz', True), ('ca', False)],
#  't01': [('T01', False)],
#  't02': [('T02', False)],
#  't03': [('T03', False)],
#  't04': [('T04', False)],
#  't05': [('T05', False)]}

# %%
string.punctuation
# Out:
# '!"#$%&\'()*+,-./:;<=>?@[\\]^_`{|}~'

# %%
import re
words = re.sub('['+string.punctuation+'¿'+']', ' ', s).split()
words
# Out:
# ['S00', 'TITLE', 'Presentaciones']

# %%
def get_words(sentence):
    return re.sub('['+string.punctuation+'¿'+']', ' ', sentence).split()

words = get_words(s)
words
# Out:
# ['S00', 'TITLE', 'Presentaciones']

# %%
def get_syllables(sentence, sentence_fragments):
    print(sentence)
    words = re.sub('['+string.punctuation+'¿'+']', ' ', sentence).split()
    print(words)
    syllables = []

    for f in sentence_fragments:
        frags = re.sub('['+string.punctuation+'¿'+']', ' ', f[0]).split()
        for r in frags:
            syllables.append((r, f[1]))
        print(frags)
    return syllables
syllables = get_syllables(s, sf)
syllables
# Out:
# S00-TITLE-Presentaciones
# ['S00', 'TITLE', 'Presentaciones']
# ['S00', 'TITLE', 'Presenta']
# ['cio']
# ['nes']
# []
# [('S00', False),
#  ('TITLE', False),
#  ('Presenta', False),
#  ('cio', True),
#  ('nes', False)]

# %%
def get_word_dict(sentence, sentence_fragments):
    index = 0
    buffer = ""
    word_dict = {}
    accentuated_word = []

    words = get_words(sentence)
    syllables = get_syllables(sentence, sentence_fragments)

    for w in words:
        while index < 100:
            buffer += syllables[index][0]
            print("w and buffer: ", w, buffer)
            accentuated_word.append(syllables[index])
            index += 1
            if buffer == w:
                word_dict[w.lower()] = accentuated_word
                buffer = ""
                accentuated_word = []
                break
    return word_dict

word_dict = get_word_dict(s, sf)
word_dict
# Out:
# S00-TITLE-Presentaciones
# ['S00', 'TITLE', 'Presentaciones']
# ['S00', 'TITLE', 'Presenta']
# ['cio']
# ['nes']
# []
# w and buffer:  S00 S00
# w and buffer:  TITLE TITLE
# w and buffer:  Presentaciones Presenta
# w and buffer:  Presentaciones Presentacio
# w and buffer:  Presentaciones Presentaciones
# {'s00': [('S00', False)],
#  'title': [('TITLE', False)],
#  'presentaciones': [('Presenta', False), ('cio', True), ('nes', False)]}

# %%
parser = MyHTMLParser()
word_dict = {}
lessons_directory = './pronunciation/lessons'

for e in os.walk(lessons_directory):
    print(e)
    for fn in e[2]:
        lesson = open(os.path.join(lessons_directory, fn)).read()
        print(fn, " : ", len(lesson))
        parser.analyze_lesson(lesson)
        wd = parser.get_word_dict()
        word_dict.update(wd)
# Out:
# ('./pronunciation/lessons', [], ['L004.html', 'L003.html', 'L002.html', 'L001.html'])
# L004.html  :  2099
# Encountered a start tag: p
# nouveau paragraphe
# (1, 0)
# Encountered some data  : N4-Lec
# Encountered a start tag: b
# Encountered some data  : ción
# Encountered an end tag : b
# Encountered some data  :
# Encountered a start tag: b
# Encountered some data  : cua
# Encountered an end tag : b
# Encountered some data  : rta
# Encountered a start tag: span
# Encountered some data  :
# Encountered an end tag : span
# Encountered an end tag : p
# Encountered a start tag: p
# nouveau paragraphe
# (1, 153)
# Encountered some data  : S00-TITLE-Presenta
# Encountered a start tag: b
# Encountered some data  : cio
# Encountered an end tag : b
# Encountered some data  : nes
# Encountered a start tag: span
# Encountered some data  :
# Encountered an end tag : span
# Encountered an end tag : p
# Encountered a start tag: p
# nouveau paragraphe
# (1, 306)
# Encountered some data  : S01-Él es
# Encountered a start tag: b
# Encountered some data  : Ra
# Encountered an end tag : b
# Encountered some data  : fa, mi her
# Encountered a start tag: b
# Encountered some data  : ma
# Encountered an end tag : b
# Encountered some data  : no, y
# Encountered a start tag: b
# Encountered some data  : e
# Encountered an end tag : b
# Encountered some data  : lla es Luz, mi her
# Encountered a start tag: b
# Encountered some data  : ma
# Encountered an end tag : b
# Encountered some data  : na.
# Encountered a start tag: span
# Encountered some data  :
# Encountered an end tag : span
# Encountered an end tag : p
# Encountered a start tag: p
# nouveau paragraphe
# (1, 510)
# Encountered some data  : S02-Y él es mi
# Encountered a start tag: b
# Encountered some data  : pa
# Encountered an end tag : b
# Encountered some data  : dre, Mi
# Encountered a start tag: b
# Encountered some data  : guel
# Encountered an end tag : b
# Encountered some data  : .
# Encountered a start tag: span
# Encountered some data  :
# Encountered an end tag : span
# Encountered an end tag : p
# Encountered a start tag: p
# nouveau paragraphe
# (1, 675)
# Encountered some data  : S03-
# Encountered a start tag: b
# Encountered some data  : Mu
# Encountered an end tag : b
# Encountered some data  : cho
# Encountered a start tag: b
# Encountered some data  : gus
# Encountered an end tag : b
# Encountered some data  : to. ¿
# Encountered a start tag: b
# Encountered some data  : Có
# Encountered an end tag : b
# Encountered some data  : mo est
# Encountered a start tag: b
# Encountered some data  : á
# Encountered an end tag : b
# Encountered some data  :  us
# Encountered a start tag: b
# Encountered some data  : ted
# Encountered an end tag : b
# Encountered some data  : ?
# Encountered a start tag: span
# Encountered some data  :
# Encountered an end tag : span
# Encountered an end tag : p
# Encountered a start tag: p
# nouveau paragraphe
# (1, 866)
# Encountered some data  : S04-Muy bien,
# Encountered a start tag: b
# Encountered some data  : pe
# Encountered an end tag : b
# Encountered some data  : ro ¡
# Encountered a start tag: b
# Encountered some data  : há
# Encountered an end tag : b
# Encountered some data  : blame de tú, por fa
# Encountered a start tag: b
# Encountered some data  : vor
# Encountered an end tag : b
# Encountered some data  : !
# Encountered a start tag: span
# Encountered some data  :
# Encountered an end tag : span
# Encountered an end tag : p
# Encountered a start tag: p
# nouveau paragraphe
# (1, 1054)
# Encountered some data  : S05-¡
# Encountered a start tag: b
# Encountered some data  : Va
# Encountered an end tag : b
# Encountered some data  : le!
# Encountered a start tag: span
# Encountered some data  :
# Encountered an end tag : span
# Encountered an end tag : p
# Encountered a start tag: p
# nouveau paragraphe
# (1, 1193)
# Encountered some data  : T00-TRANSLATE-Ejer
# Encountered a start tag: b
# Encountered some data  : ci
# Encountered an end tag : b
# Encountered some data  : cio 1 – Tra
# Encountered a start tag: b
# Encountered some data  : duz
# Encountered an end tag : b
# Encountered some data  : ca
# Encountered a start tag: span
# Encountered some data  :
# Encountered an end tag : span
# Encountered an end tag : p
# Encountered a start tag: p
# nouveau paragraphe
# (1, 1365)
# Encountered some data  : T01-Él es mi
# Encountered a start tag: b
# Encountered some data  : pa
# Encountered an end tag : b
# Encountered some data  : dre.
# Encountered a start tag: span
# Encountered some data  :
# Encountered an end tag : span
# Encountered an end tag : p
# Encountered a start tag: p
# nouveau paragraphe
# (1, 1513)
# Encountered some data  : T02-Y ella es mi her
# Encountered a start tag: b
# Encountered some data  : ma
# Encountered an end tag : b
# Encountered some data  : na.
# Encountered a start tag: span
# Encountered some data  :
# Encountered an end tag : span
# Encountered an end tag : p
# Encountered a start tag: p
# nouveau paragraphe
# (1, 1667)
# Encountered some data  : T03-
# Encountered a start tag: b
# Encountered some data  : Mu
# Encountered an end tag : b
# Encountered some data  : cho
# Encountered a start tag: b
# Encountered some data  : gus
# Encountered an end tag : b
# Encountered some data  : to.
# Encountered a start tag: span
# Encountered some data  :
# Encountered an end tag : span
# Encountered an end tag : p
# Encountered a start tag: p
# nouveau paragraphe
# (1, 1819)
# Encountered some data  : T04-
# Encountered a start tag: b
# Encountered some data  : Há
# Encountered an end tag : b
# Encountered some data  : blame de tú, por fa
# Encountered a start tag: b
# Encountered some data  : vor
# Encountered an end tag : b
# Encountered some data  : .
# Encountered a start tag: span
# Encountered some data  :
# Encountered an end tag : span
# Encountered an end tag : p
# Encountered a start tag: p
# nouveau paragraphe
# (1, 1984)
# Encountered some data  : T05-¿
# Encountered a start tag: b
# Encountered some data  : Có
# Encountered an end tag : b
# Encountered some data  : mo est
# Encountered a start tag: b
# Encountered some data  : á
# Encountered an end tag : b
# Encountered some data  :  ust
# Encountered a start tag: b
# Encountered some data  : ed
# Encountered an end tag : b
# Encountered some data  : ?
# Encountered an end tag : p
# N4-Lección cuarta
# ['N4', 'Lección', 'cuarta']
# ['N4', 'Lec']
# ['ción']
# []
# ['cua']
# ['rta']
# []
# w and buffer:  N4 N4
# w and buffer:  Lección Lec
# w and buffer:  Lección Lección
# w and buffer:  cuarta cua
# w and buffer:  cuarta cuarta
# S00-TITLE-Presentaciones
# ['S00', 'TITLE', 'Presentaciones']
# ['S00', 'TITLE', 'Presenta']
# ['cio']
# ['nes']
# []
# w and buffer:  S00 S00
# w and buffer:  TITLE TITLE
# w and buffer:  Presentaciones Presenta
# w and buffer:  Presentaciones Presentacio
# w and buffer:  Presentaciones Presentaciones
# S01-Él es Rafa, mi hermano, y ella es Luz, mi hermana.
# ['S01', 'Él', 'es', 'Rafa', 'mi', 'hermano', 'y', 'ella', 'es', 'Luz', 'mi', 'hermana']
# ['S01', 'Él', 'es']
# ['Ra']
# ['fa', 'mi', 'her']
# ['ma']
# ['no', 'y']
# ['e']
# ['lla', 'es', 'Luz', 'mi', 'her']
# ['ma']
# ['na']
# []
# w and buffer:  S01 S01
# w and buffer:  Él Él
# w and buffer:  es es
# w and buffer:  Rafa Ra
# w and buffer:  Rafa Rafa
# w and buffer:  mi mi
# w and buffer:  hermano her
# w and buffer:  hermano herma
# w and buffer:  hermano hermano
# w and buffer:  y y
# w and buffer:  ella e
# w and buffer:  ella ella
# w and buffer:  es es
# w and buffer:  Luz Luz
# w and buffer:  mi mi
# w and buffer:  hermana her
# w and buffer:  hermana herma
# w and buffer:  hermana hermana
# S02-Y él es mi padre, Miguel.
# ['S02', 'Y', 'él', 'es', 'mi', 'padre', 'Miguel']
# ['S02', 'Y', 'él', 'es', 'mi']
# ['pa']
# ['dre', 'Mi']
# ['guel']
# []
# []
# w and buffer:  S02 S02
# w and buffer:  Y Y
# w and buffer:  él él
# w and buffer:  es es
# w and buffer:  mi mi
# w and buffer:  padre pa
# w and buffer:  padre padre
# w and buffer:  Miguel Mi
# w and buffer:  Miguel Miguel
# S03-Mucho gusto. ¿Cómo está usted?
# ['S03', 'Mucho', 'gusto', 'Cómo', 'está', 'usted']
# ['S03']
# ['Mu']
# ['cho']
# ['gus']
# ['to']
# ['Có']
# ['mo', 'est']
# ['á']
# ['us']
# ['ted']
# []
# []
# w and buffer:  S03 S03
# w and buffer:  Mucho Mu
# w and buffer:  Mucho Mucho
# w and buffer:  gusto gus
# w and buffer:  gusto gusto
# w and buffer:  Cómo Có
# w and buffer:  Cómo Cómo
# w and buffer:  está est
# w and buffer:  está está
# w and buffer:  usted us
# w and buffer:  usted usted
# S04-Muy bien, pero ¡háblame de tú, por favor!
# ['S04', 'Muy', 'bien', 'pero', 'háblame', 'de', 'tú', 'por', 'favor']
# ['S04', 'Muy', 'bien']
# ['pe']
# ['ro']
# ['há']
# ['blame', 'de', 'tú', 'por', 'fa']
# ['vor']
# []
# []
# w and buffer:  S04 S04
# w and buffer:  Muy Muy
# w and buffer:  bien bien
# w and buffer:  pero pe
# w and buffer:  pero pero
# w and buffer:  háblame há
# w and buffer:  háblame háblame
# w and buffer:  de de
# w and buffer:  tú tú
# w and buffer:  por por
# w and buffer:  favor fa
# w and buffer:  favor favor
# S05-¡Vale!
# ['S05', 'Vale']
# ['S05']
# ['Va']
# ['le']
# []
# w and buffer:  S05 S05
# w and buffer:  Vale Va
# w and buffer:  Vale Vale
# T00-TRANSLATE-Ejercicio 1 – Traduzca
# ['T00', 'TRANSLATE', 'Ejercicio', '1', '–', 'Traduzca']
# ['T00', 'TRANSLATE', 'Ejer']
# ['ci']
# ['cio', '1', '–', 'Tra']
# ['duz']
# ['ca']
# []
# w and buffer:  T00 T00
# w and buffer:  TRANSLATE TRANSLATE
# w and buffer:  Ejercicio Ejer
# w and buffer:  Ejercicio Ejerci
# w and buffer:  Ejercicio Ejercicio
# w and buffer:  1 1
# w and buffer:  – –
# w and buffer:  Traduzca Tra
# w and buffer:  Traduzca Traduz
# w and buffer:  Traduzca Traduzca
# T01-Él es mi padre.
# ['T01', 'Él', 'es', 'mi', 'padre']
# ['T01', 'Él', 'es', 'mi']
# ['pa']
# ['dre']
# []
# w and buffer:  T01 T01
# w and buffer:  Él Él
# w and buffer:  es es
# w and buffer:  mi mi
# w and buffer:  padre pa
# w and buffer:  padre padre
# T02-Y ella es mi hermana.
# ['T02', 'Y', 'ella', 'es', 'mi', 'hermana']
# ['T02', 'Y', 'ella', 'es', 'mi', 'her']
# ['ma']
# ['na']
# []
# w and buffer:  T02 T02
# w and buffer:  Y Y
# w and buffer:  ella ella
# w and buffer:  es es
# w and buffer:  mi mi
# w and buffer:  hermana her
# w and buffer:  hermana herma
# w and buffer:  hermana hermana
# T03-Mucho gusto.
# ['T03', 'Mucho', 'gusto']
# ['T03']
# ['Mu']
# ['cho']
# ['gus']
# ['to']
# []
# w and buffer:  T03 T03
# w and buffer:  Mucho Mu
# w and buffer:  Mucho Mucho
# w and buffer:  gusto gus
# w and buffer:  gusto gusto
# T04-Háblame de tú, por favor.
# ['T04', 'Háblame', 'de', 'tú', 'por', 'favor']
# ['T04']
# ['Há']
# ['blame', 'de', 'tú', 'por', 'fa']
# ['vor']
# []
# []
# w and buffer:  T04 T04
# w and buffer:  Háblame Há
# w and buffer:  Háblame Háblame
# w and buffer:  de de
# w and buffer:  tú tú
# w and buffer:  por por
# w and buffer:  favor fa
# w and buffer:  favor favor
# T05-¿Cómo está usted?
# ['T05', 'Cómo', 'está', 'usted']
# ['T05']
# ['Có']
# ['mo', 'est']
# ['á']
# ['ust']
# ['ed']
# []
# w and buffer:  T05 T05
# w and buffer:  Cómo Có
# w and buffer:  Cómo Cómo
# w and buffer:  está est
# w and buffer:  está está
# w and buffer:  usted ust
# w and buffer:  usted usted
# L003.html  :  2141
# Encountered a start tag: p
# nouveau paragraphe
# (1, 2099)
# Encountered some data  : N3-Lec
# Encountered a start tag: b
# Encountered some data  : ción
# Encountered an end tag : b
# Encountered some data  :  ter
# Encountered a start tag: b
# Encountered some data  : ce
# Encountered an end tag : b
# Encountered some data  : ra
# Encountered a start tag: span
# Encountered some data  :
# Encountered an end tag : span
# Encountered an end tag : p
# Encountered a start tag: p
# nouveau paragraphe
# (1, 2253)
# Encountered some data  : S00-TITLE-¡Bienve
# Encountered a start tag: b
# Encountered some data  : ni
# Encountered an end tag : b
# Encountered some data  : da!
# Encountered a start tag: span
# Encountered some data  :
# Encountered an end tag : span
# Encountered an end tag : p
# Encountered a start tag: p
# nouveau paragraphe
# (1, 2404)
# Encountered some data  : S01-
# Encountered a start tag: b
# Encountered some data  : Bue
# Encountered an end tag : b
# Encountered some data  : nos
# Encountered a start tag: b
# Encountered some data  : dí
# Encountered an end tag : b
# Encountered some data  : as, soy Ja
# Encountered a start tag: b
# Encountered some data  : vier
# Encountered an end tag : b
# Encountered some data  : . ¿
# Encountered a start tag: b
# Encountered some data  : Có
# Encountered an end tag : b
# Encountered some data  : mo te
# Encountered a start tag: b
# Encountered some data  : lla
# Encountered an end tag : b
# Encountered some data  : mas?
# Encountered a start tag: span
# Encountered some data  :
# Encountered an end tag : span
# Encountered an end tag : p
# Encountered a start tag: p
# nouveau paragraphe
# (1, 2606)
# Encountered some data  : S02-Me
# Encountered a start tag: b
# Encountered some data  : lla
# Encountered an end tag : b
# Encountered some data  : mo Ro
# Encountered a start tag: b
# Encountered some data  : cío
# Encountered an end tag : b
# Encountered some data  : .
# Encountered a start tag: span
# Encountered some data  :
# Encountered an end tag : span
# Encountered an end tag : p
# Encountered a start tag: p
# nouveau paragraphe
# (1, 2761)
# Encountered some data  : S03-Encan
# Encountered a start tag: b
# Encountered some data  : ta
# Encountered an end tag : b
# Encountered some data  : do. ¿
# Encountered a start tag: b
# Encountered some data  : E
# Encountered an end tag : b
# Encountered some data  : res de Ma
# Encountered a start tag: b
# Encountered some data  : drid
# Encountered an end tag : b
# Encountered some data  : ?
# Encountered a start tag: span
# Encountered some data  :
# Encountered an end tag : span
# Encountered an end tag : p
# Encountered a start tag: p
# nouveau paragraphe
# (1, 2935)
# Encountered some data  : S04-No, no soy madri
# Encountered a start tag: b
# Encountered some data  : le
# Encountered an end tag : b
# Encountered some data  : ña. Soy anda
# Encountered a start tag: b
# Encountered some data  : lu
# Encountered an end tag : b
# Encountered some data  : za, de Se
# Encountered a start tag: b
# Encountered some data  : vi
# Encountered an end tag : b
# Encountered some data  : lla.
# Encountered a start tag: span
# Encountered some data  :
# Encountered an end tag : span
# Encountered an end tag : p
# Encountered a start tag: p
# nouveau paragraphe
# (1, 3129)
# Encountered some data  : S05-¡Pues bienve
# Encountered a start tag: b
# Encountered some data  : ni
# Encountered an end tag : b
# Encountered some data  : da a Ma
# Encountered a start tag: b
# Encountered some data  : drid
# Encountered an end tag : b
# Encountered some data  : , mo
# Encountered a start tag: b
# Encountered some data  : re
# Encountered an end tag : b
# Encountered some data  : na!
# Encountered a start tag: span
# Encountered some data  :
# Encountered an end tag : span
# Encountered an end tag : p
# Encountered a start tag: p
# nouveau paragraphe
# (1, 3310)
# Encountered some data  : T00-TRANSLATE-Ejer
# Encountered a start tag: b
# Encountered some data  : ci
# Encountered an end tag : b
# Encountered some data  : cio 1 – Tra
# Encountered a start tag: b
# Encountered some data  : duz
# Encountered an end tag : b
# Encountered some data  : ca
# Encountered a start tag: span
# Encountered some data  :
# Encountered an end tag : span
# Encountered an end tag : p
# Encountered a start tag: p
# nouveau paragraphe
# (1, 3482)
# Encountered some data  : T01-No me
# Encountered a start tag: b
# Encountered some data  : lla
# Encountered an end tag : b
# Encountered some data  : mo Ja
# Encountered a start tag: b
# Encountered some data  : vier
# Encountered an end tag : b
# Encountered some data  : .
# Encountered a start tag: span
# Encountered some data  :
# Encountered an end tag : span
# Encountered an end tag : p
# Encountered a start tag: p
# nouveau paragraphe
# (1, 3641)
# Encountered some data  : T02-Encan
# Encountered a start tag: b
# Encountered some data  : ta
# Encountered an end tag : b
# Encountered some data  : da, soy Ro
# Encountered a start tag: b
# Encountered some data  : cío
# Encountered an end tag : b
# Encountered some data  : .
# Encountered a start tag: span
# Encountered some data  :
# Encountered an end tag : span
# Encountered an end tag : p
# Encountered a start tag: p
# nouveau paragraphe
# (1, 3802)
# Encountered some data  : T03-¿Te
# Encountered a start tag: b
# Encountered some data  : lla
# Encountered an end tag : b
# Encountered some data  : mas
# Encountered a start tag: b
# Encountered some data  : Mon
# Encountered an end tag : b
# Encountered some data  : tse?
# Encountered a start tag: span
# Encountered some data  :
# Encountered an end tag : span
# Encountered an end tag : p
# Encountered a start tag: p
# nouveau paragraphe
# (1, 3960)
# Encountered some data  : T04-Soy de Ma
# Encountered a start tag: b
# Encountered some data  : drid
# Encountered an end tag : b
# Encountered some data  : .
# Encountered a start tag: span
# Encountered some data  :
# Encountered an end tag : span
# Encountered an end tag : p
# Encountered a start tag: p
# nouveau paragraphe
# (1, 4107)
# Encountered some data  : T05-
# Encountered a start tag: b
# Encountered some data  : Bue
# Encountered an end tag : b
# Encountered some data  : nos
# Encountered a start tag: b
# Encountered some data  : dí
# Encountered an end tag : b
# Encountered some data  : as, ¿
# Encountered a start tag: b
# Encountered some data  : e
# Encountered an end tag : b
# Encountered some data  : res anda
# Encountered a start tag: b
# Encountered some data  : lu
# Encountered an end tag : b
# Encountered some data  : za?
# Encountered an end tag : p
# N3-Lección tercera
# ['N3', 'Lección', 'tercera']
# ['N3', 'Lec']
# ['ción']
# ['ter']
# ['ce']
# ['ra']
# []
# w and buffer:  N3 N3
# w and buffer:  Lección Lec
# w and buffer:  Lección Lección
# w and buffer:  tercera ter
# w and buffer:  tercera terce
# w and buffer:  tercera tercera
# S00-TITLE-¡Bienvenida!
# ['S00', 'TITLE', 'Bienvenida']
# ['S00', 'TITLE', 'Bienve']
# ['ni']
# ['da']
# []
# w and buffer:  S00 S00
# w and buffer:  TITLE TITLE
# w and buffer:  Bienvenida Bienve
# w and buffer:  Bienvenida Bienveni
# w and buffer:  Bienvenida Bienvenida
# S01-Buenos días, soy Javier. ¿Cómo te llamas?
# ['S01', 'Buenos', 'días', 'soy', 'Javier', 'Cómo', 'te', 'llamas']
# ['S01']
# ['Bue']
# ['nos']
# ['dí']
# ['as', 'soy', 'Ja']
# ['vier']
# []
# ['Có']
# ['mo', 'te']
# ['lla']
# ['mas']
# []
# w and buffer:  S01 S01
# w and buffer:  Buenos Bue
# w and buffer:  Buenos Buenos
# w and buffer:  días dí
# w and buffer:  días días
# w and buffer:  soy soy
# w and buffer:  Javier Ja
# w and buffer:  Javier Javier
# w and buffer:  Cómo Có
# w and buffer:  Cómo Cómo
# w and buffer:  te te
# w and buffer:  llamas lla
# w and buffer:  llamas llamas
# S02-Me llamo Rocío.
# ['S02', 'Me', 'llamo', 'Rocío']
# ['S02', 'Me']
# ['lla']
# ['mo', 'Ro']
# ['cío']
# []
# []
# w and buffer:  S02 S02
# w and buffer:  Me Me
# w and buffer:  llamo lla
# w and buffer:  llamo llamo
# w and buffer:  Rocío Ro
# w and buffer:  Rocío Rocío
# S03-Encantado. ¿Eres de Madrid?
# ['S03', 'Encantado', 'Eres', 'de', 'Madrid']
# ['S03', 'Encan']
# ['ta']
# ['do']
# ['E']
# ['res', 'de', 'Ma']
# ['drid']
# []
# []
# w and buffer:  S03 S03
# w and buffer:  Encantado Encan
# w and buffer:  Encantado Encanta
# w and buffer:  Encantado Encantado
# w and buffer:  Eres E
# w and buffer:  Eres Eres
# w and buffer:  de de
# w and buffer:  Madrid Ma
# w and buffer:  Madrid Madrid
# S04-No, no soy madrileña. Soy andaluza, de Sevilla.
# ['S04', 'No', 'no', 'soy', 'madrileña', 'Soy', 'andaluza', 'de', 'Sevilla']
# ['S04', 'No', 'no', 'soy', 'madri']
# ['le']
# ['ña', 'Soy', 'anda']
# ['lu']
# ['za', 'de', 'Se']
# ['vi']
# ['lla']
# []
# w and buffer:  S04 S04
# w and buffer:  No No
# w and buffer:  no no
# w and buffer:  soy soy
# w and buffer:  madrileña madri
# w and buffer:  madrileña madrile
# w and buffer:  madrileña madrileña
# w and buffer:  Soy Soy
# w and buffer:  andaluza anda
# w and buffer:  andaluza andalu
# w and buffer:  andaluza andaluza
# w and buffer:  de de
# w and buffer:  Sevilla Se
# w and buffer:  Sevilla Sevi
# w and buffer:  Sevilla Sevilla
# S05-¡Pues bienvenida a Madrid, morena!
# ['S05', 'Pues', 'bienvenida', 'a', 'Madrid', 'morena']
# ['S05', 'Pues', 'bienve']
# ['ni']
# ['da', 'a', 'Ma']
# ['drid']
# ['mo']
# ['re']
# ['na']
# []
# w and buffer:  S05 S05
# w and buffer:  Pues Pues
# w and buffer:  bienvenida bienve
# w and buffer:  bienvenida bienveni
# w and buffer:  bienvenida bienvenida
# w and buffer:  a a
# w and buffer:  Madrid Ma
# w and buffer:  Madrid Madrid
# w and buffer:  morena mo
# w and buffer:  morena more
# w and buffer:  morena morena
# T00-TRANSLATE-Ejercicio 1 – Traduzca
# ['T00', 'TRANSLATE', 'Ejercicio', '1', '–', 'Traduzca']
# ['T00', 'TRANSLATE', 'Ejer']
# ['ci']
# ['cio', '1', '–', 'Tra']
# ['duz']
# ['ca']
# []
# w and buffer:  T00 T00
# w and buffer:  TRANSLATE TRANSLATE
# w and buffer:  Ejercicio Ejer
# w and buffer:  Ejercicio Ejerci
# w and buffer:  Ejercicio Ejercicio
# w and buffer:  1 1
# w and buffer:  – –
# w and buffer:  Traduzca Tra
# w and buffer:  Traduzca Traduz
# w and buffer:  Traduzca Traduzca
# T01-No me llamo Javier.
# ['T01', 'No', 'me', 'llamo', 'Javier']
# ['T01', 'No', 'me']
# ['lla']
# ['mo', 'Ja']
# ['vier']
# []
# []
# w and buffer:  T01 T01
# w and buffer:  No No
# w and buffer:  me me
# w and buffer:  llamo lla
# w and buffer:  llamo llamo
# w and buffer:  Javier Ja
# w and buffer:  Javier Javier
# T02-Encantada, soy Rocío.
# ['T02', 'Encantada', 'soy', 'Rocío']
# ['T02', 'Encan']
# ['ta']
# ['da', 'soy', 'Ro']
# ['cío']
# []
# []
# w and buffer:  T02 T02
# w and buffer:  Encantada Encan
# w and buffer:  Encantada Encanta
# w and buffer:  Encantada Encantada
# w and buffer:  soy soy
# w and buffer:  Rocío Ro
# w and buffer:  Rocío Rocío
# T03-¿Te llamas Montse?
# ['T03', 'Te', 'llamas', 'Montse']
# ['T03', 'Te']
# ['lla']
# ['mas']
# ['Mon']
# ['tse']
# []
# w and buffer:  T03 T03
# w and buffer:  Te Te
# w and buffer:  llamas lla
# w and buffer:  llamas llamas
# w and buffer:  Montse Mon
# w and buffer:  Montse Montse
# T04-Soy de Madrid.
# ['T04', 'Soy', 'de', 'Madrid']
# ['T04', 'Soy', 'de', 'Ma']
# ['drid']
# []
# []
# w and buffer:  T04 T04
# w and buffer:  Soy Soy
# w and buffer:  de de
# w and buffer:  Madrid Ma
# w and buffer:  Madrid Madrid
# T05-Buenos días, ¿eres andaluza?
# ['T05', 'Buenos', 'días', 'eres', 'andaluza']
# ['T05']
# ['Bue']
# ['nos']
# ['dí']
# ['as']
# ['e']
# ['res', 'anda']
# ['lu']
# ['za']
# w and buffer:  T05 T05
# w and buffer:  Buenos Bue
# w and buffer:  Buenos Buenos
# w and buffer:  días dí
# w and buffer:  días días
# w and buffer:  eres e
# w and buffer:  eres eres
# w and buffer:  andaluza anda
# w and buffer:  andaluza andalu
# w and buffer:  andaluza andaluza
# L002.html  :  2081
# Encountered a start tag: p
# nouveau paragraphe
# (1, 4240)
# Encountered some data  : N2-Lecc
# Encountered a start tag: b
# Encountered some data  : ión
# Encountered an end tag : b
# Encountered some data  :  se
# Encountered a start tag: b
# Encountered some data  : gun
# Encountered an end tag : b
# Encountered some data  : da
# Encountered a start tag: span
# Encountered some data  :
# Encountered an end tag : span
# Encountered an end tag : p
# Encountered a start tag: p
# nouveau paragraphe
# (1, 4394)
# Encountered some data  : S00-TITLE-¿
# Encountered a start tag: b
# Encountered some data  : Dón
# Encountered an end tag : b
# Encountered some data  : de
# Encountered a start tag: b
# Encountered some data  : vi
# Encountered an end tag : b
# Encountered some data  : ves?
# Encountered a start tag: span
# Encountered some data  :
# Encountered an end tag : span
# Encountered an end tag : p
# Encountered a start tag: p
# nouveau paragraphe
# (1, 4553)
# Encountered some data  : S01-¿De
# Encountered a start tag: b
# Encountered some data  : dón
# Encountered an end tag : b
# Encountered some data  : de
# Encountered a start tag: b
# Encountered some data  : e
# Encountered an end tag : b
# Encountered some data  : res,
# Encountered a start tag: b
# Encountered some data  : Mon
# Encountered an end tag : b
# Encountered some data  : tse?
# Encountered a start tag: span
# Encountered some data  :
# Encountered an end tag : span
# Encountered an end tag : p
# Encountered a start tag: p
# nouveau paragraphe
# (1, 4723)
# Encountered some data  : S02-Mi fa
# Encountered a start tag: b
# Encountered some data  : mi
# Encountered an end tag : b
# Encountered some data  : lia es de Andalu
# Encountered a start tag: b
# Encountered some data  : cí
# Encountered an end tag : b
# Encountered some data  : a.
# Encountered a start tag: span
# Encountered some data  :
# Encountered an end tag : span
# Encountered an end tag : p
# Encountered a start tag: p
# nouveau paragraphe
# (1, 4890)
# Encountered some data  : S03-
# Encountered a start tag: b
# Encountered some data  : Pe
# Encountered an end tag : b
# Encountered some data  : ro yo na
# Encountered a start tag: b
# Encountered some data  : cí
# Encountered an end tag : b
# Encountered some data  :  en Barce
# Encountered a start tag: b
# Encountered some data  : lo
# Encountered an end tag : b
# Encountered some data  : na.
# Encountered a start tag: span
# Encountered some data  :
# Encountered an end tag : span
# Encountered an end tag : p
# Encountered a start tag: p
# nouveau paragraphe
# (1, 5063)
# Encountered some data  : S04-¿Y
# Encountered a start tag: b
# Encountered some data  : vi
# Encountered an end tag : b
# Encountered some data  : ves en Barce
# Encountered a start tag: b
# Encountered some data  : lo
# Encountered an end tag : b
# Encountered some data  : na?
# Encountered a start tag: span
# Encountered some data  :
# Encountered an end tag : span
# Encountered an end tag : p
# Encountered a start tag: p
# nouveau paragraphe
# (1, 5225)
# Encountered some data  : S05-
# Encountered a start tag: b
# Encountered some data  : Vi
# Encountered an end tag : b
# Encountered some data  : vo en las a
# Encountered a start tag: b
# Encountered some data  : fue
# Encountered an end tag : b
# Encountered some data  : ras de Barce
# Encountered a start tag: b
# Encountered some data  : lo
# Encountered an end tag : b
# Encountered some data  : na.
# Encountered a start tag: span
# Encountered some data  :
# Encountered an end tag : span
# Encountered an end tag : p
# Encountered a start tag: p
# nouveau paragraphe
# (1, 5405)
# Encountered some data  : T00-TRANSLATE-Ejer
# Encountered a start tag: b
# Encountered some data  : ci
# Encountered an end tag : b
# Encountered some data  : cio 1 – Tra
# Encountered a start tag: b
# Encountered some data  : duz
# Encountered an end tag : b
# Encountered some data  : ca
# Encountered a start tag: span
# Encountered some data  :
# Encountered an end tag : span
# Encountered an end tag : p
# Encountered a start tag: p
# nouveau paragraphe
# (1, 5577)
# Encountered some data  : T01-¿De
# Encountered a start tag: b
# Encountered some data  : dón
# Encountered an end tag : b
# Encountered some data  : de es
# Encountered a start tag: b
# Encountered some data  : Mon
# Encountered an end tag : b
# Encountered some data  : tse?
# Encountered a start tag: span
# Encountered some data  :
# Encountered an end tag : span
# Encountered an end tag : p
# Encountered a start tag: p
# nouveau paragraphe
# (1, 5737)
# Encountered some data  : T02-¿De
# Encountered a start tag: b
# Encountered some data  : dón
# Encountered an end tag : b
# Encountered some data  : de
# Encountered a start tag: b
# Encountered some data  : e
# Encountered an end tag : b
# Encountered some data  : res?
# Encountered a start tag: span
# Encountered some data  :
# Encountered an end tag : span
# Encountered an end tag : p
# Encountered a start tag: p
# nouveau paragraphe
# (1, 5892)
# Encountered some data  : T03-
# Encountered a start tag: b
# Encountered some data  : Vi
# Encountered an end tag : b
# Encountered some data  : vo en Barce
# Encountered a start tag: b
# Encountered some data  : lo
# Encountered an end tag : b
# Encountered some data  : na.
# Encountered a start tag: span
# Encountered some data  :
# Encountered an end tag : span
# Encountered an end tag : p
# Encountered a start tag: p
# nouveau paragraphe
# (1, 6050)
# Encountered some data  : T04-¿
# Encountered a start tag: b
# Encountered some data  : Vi
# Encountered an end tag : b
# Encountered some data  : ves en las a
# Encountered a start tag: b
# Encountered some data  : fue
# Encountered an end tag : b
# Encountered some data  : ras?
# Encountered a start tag: span
# Encountered some data  :
# Encountered an end tag : span
# Encountered an end tag : p
# Encountered a start tag: p
# nouveau paragraphe
# (1, 6212)
# Encountered some data  : T05-Na
# Encountered a start tag: b
# Encountered some data  : cí
# Encountered an end tag : b
# Encountered some data  :  en Andalu
# Encountered a start tag: b
# Encountered some data  : cí
# Encountered an end tag : b
# Encountered some data  : a.
# Encountered an end tag : p
# N2-Lección segunda
# ['N2', 'Lección', 'segunda']
# ['N2', 'Lecc']
# ['ión']
# ['se']
# ['gun']
# ['da']
# []
# w and buffer:  N2 N2
# w and buffer:  Lección Lecc
# w and buffer:  Lección Lección
# w and buffer:  segunda se
# w and buffer:  segunda segun
# w and buffer:  segunda segunda
# S00-TITLE-¿Dónde vives?
# ['S00', 'TITLE', 'Dónde', 'vives']
# ['S00', 'TITLE']
# ['Dón']
# ['de']
# ['vi']
# ['ves']
# []
# w and buffer:  S00 S00
# w and buffer:  TITLE TITLE
# w and buffer:  Dónde Dón
# w and buffer:  Dónde Dónde
# w and buffer:  vives vi
# w and buffer:  vives vives
# S01-¿De dónde eres, Montse?
# ['S01', 'De', 'dónde', 'eres', 'Montse']
# ['S01', 'De']
# ['dón']
# ['de']
# ['e']
# ['res']
# ['Mon']
# ['tse']
# []
# w and buffer:  S01 S01
# w and buffer:  De De
# w and buffer:  dónde dón
# w and buffer:  dónde dónde
# w and buffer:  eres e
# w and buffer:  eres eres
# w and buffer:  Montse Mon
# w and buffer:  Montse Montse
# S02-Mi familia es de Andalucía.
# ['S02', 'Mi', 'familia', 'es', 'de', 'Andalucía']
# ['S02', 'Mi', 'fa']
# ['mi']
# ['lia', 'es', 'de', 'Andalu']
# ['cí']
# ['a']
# []
# w and buffer:  S02 S02
# w and buffer:  Mi Mi
# w and buffer:  familia fa
# w and buffer:  familia fami
# w and buffer:  familia familia
# w and buffer:  es es
# w and buffer:  de de
# w and buffer:  Andalucía Andalu
# w and buffer:  Andalucía Andalucí
# w and buffer:  Andalucía Andalucía
# S03-Pero yo nací en Barcelona.
# ['S03', 'Pero', 'yo', 'nací', 'en', 'Barcelona']
# ['S03']
# ['Pe']
# ['ro', 'yo', 'na']
# ['cí']
# ['en', 'Barce']
# ['lo']
# ['na']
# []
# w and buffer:  S03 S03
# w and buffer:  Pero Pe
# w and buffer:  Pero Pero
# w and buffer:  yo yo
# w and buffer:  nací na
# w and buffer:  nací nací
# w and buffer:  en en
# w and buffer:  Barcelona Barce
# w and buffer:  Barcelona Barcelo
# w and buffer:  Barcelona Barcelona
# S04-¿Y vives en Barcelona?
# ['S04', 'Y', 'vives', 'en', 'Barcelona']
# ['S04', 'Y']
# ['vi']
# ['ves', 'en', 'Barce']
# ['lo']
# ['na']
# []
# w and buffer:  S04 S04
# w and buffer:  Y Y
# w and buffer:  vives vi
# w and buffer:  vives vives
# w and buffer:  en en
# w and buffer:  Barcelona Barce
# w and buffer:  Barcelona Barcelo
# w and buffer:  Barcelona Barcelona
# S05-Vivo en las afueras de Barcelona.
# ['S05', 'Vivo', 'en', 'las', 'afueras', 'de', 'Barcelona']
# ['S05']
# ['Vi']
# ['vo', 'en', 'las', 'a']
# ['fue']
# ['ras', 'de', 'Barce']
# ['lo']
# ['na']
# []
# w and buffer:  S05 S05
# w and buffer:  Vivo Vi
# w and buffer:  Vivo Vivo
# w and buffer:  en en
# w and buffer:  las las
# w and buffer:  afueras a
# w and buffer:  afueras afue
# w and buffer:  afueras afueras
# w and buffer:  de de
# w and buffer:  Barcelona Barce
# w and buffer:  Barcelona Barcelo
# w and buffer:  Barcelona Barcelona
# T00-TRANSLATE-Ejercicio 1 – Traduzca
# ['T00', 'TRANSLATE', 'Ejercicio', '1', '–', 'Traduzca']
# ['T00', 'TRANSLATE', 'Ejer']
# ['ci']
# ['cio', '1', '–', 'Tra']
# ['duz']
# ['ca']
# []
# w and buffer:  T00 T00
# w and buffer:  TRANSLATE TRANSLATE
# w and buffer:  Ejercicio Ejer
# w and buffer:  Ejercicio Ejerci
# w and buffer:  Ejercicio Ejercicio
# w and buffer:  1 1
# w and buffer:  – –
# w and buffer:  Traduzca Tra
# w and buffer:  Traduzca Traduz
# w and buffer:  Traduzca Traduzca
# T01-¿De dónde es Montse?
# ['T01', 'De', 'dónde', 'es', 'Montse']
# ['T01', 'De']
# ['dón']
# ['de', 'es']
# ['Mon']
# ['tse']
# []
# w and buffer:  T01 T01
# w and buffer:  De De
# w and buffer:  dónde dón
# w and buffer:  dónde dónde
# w and buffer:  es es
# w and buffer:  Montse Mon
# w and buffer:  Montse Montse
# T02-¿De dónde eres?
# ['T02', 'De', 'dónde', 'eres']
# ['T02', 'De']
# ['dón']
# ['de']
# ['e']
# ['res']
# []
# w and buffer:  T02 T02
# w and buffer:  De De
# w and buffer:  dónde dón
# w and buffer:  dónde dónde
# w and buffer:  eres e
# w and buffer:  eres eres
# T03-Vivo en Barcelona.
# ['T03', 'Vivo', 'en', 'Barcelona']
# ['T03']
# ['Vi']
# ['vo', 'en', 'Barce']
# ['lo']
# ['na']
# []
# w and buffer:  T03 T03
# w and buffer:  Vivo Vi
# w and buffer:  Vivo Vivo
# w and buffer:  en en
# w and buffer:  Barcelona Barce
# w and buffer:  Barcelona Barcelo
# w and buffer:  Barcelona Barcelona
# T04-¿Vives en las afueras?
# ['T04', 'Vives', 'en', 'las', 'afueras']
# ['T04']
# ['Vi']
# ['ves', 'en', 'las', 'a']
# ['fue']
# ['ras']
# []
# w and buffer:  T04 T04
# w and buffer:  Vives Vi
# w and buffer:  Vives Vives
# w and buffer:  en en
# w and buffer:  las las
# w and buffer:  afueras a
# w and buffer:  afueras afue
# w and buffer:  afueras afueras
# T05-Nací en Andalucía.
# ['T05', 'Nací', 'en', 'Andalucía']
# ['T05', 'Na']
# ['cí']
# ['en', 'Andalu']
# ['cí']
# ['a']
# w and buffer:  T05 T05
# w and buffer:  Nací Na
# w and buffer:  Nací Nací
# w and buffer:  en en
# w and buffer:  Andalucía Andalu
# w and buffer:  Andalucía Andalucí
# w and buffer:  Andalucía Andalucía
# L001.html  :  805
# Encountered a start tag: div
# Encountered some data  : N1-Lec
# Encountered a start tag: b
# Encountered some data  : ción
# Encountered an end tag : b
# Encountered some data  : pri
# Encountered a start tag: b
# Encountered some data  : me
# Encountered an end tag : b
# Encountered some data  : ra
# Encountered an end tag : div
# Encountered a start tag: div
# Encountered a start tag: br
# Encountered an end tag : div
# Encountered a start tag: div
# Encountered some data  : S00-TITLE-¡Qué sorp
# Encountered a start tag: b
# Encountered some data  : re
# Encountered an end tag : b
# Encountered some data  : sa!
# Encountered an end tag : div
# Encountered a start tag: div
# Encountered a start tag: br
# Encountered an end tag : div
# Encountered a start tag: div
# Encountered some data  : S01-¡
# Encountered a start tag: b
# Encountered some data  : Ho
# Encountered an end tag : b
# Encountered some data  : la,
# Encountered a start tag: b
# Encountered some data  : Lau
# Encountered an end tag : b
# Encountered some data  : ra!
# Encountered an end tag : div
# Encountered a start tag: div
# Encountered a start tag: br
# Encountered an end tag : div
# Encountered a start tag: div
# Encountered some data  : S02-¡
# Encountered a start tag: b
# Encountered some data  : Ho
# Encountered an end tag : b
# Encountered some data  : la,
# Encountered a start tag: b
# Encountered some data  : Pa
# Encountered an end tag : b
# Encountered some data  : co, qué sor
# Encountered a start tag: b
# Encountered some data  : pre
# Encountered an end tag : b
# Encountered some data  : sa!
# Encountered an end tag : div
# Encountered a start tag: div
# Encountered a start tag: br
# Encountered an end tag : div
# Encountered a start tag: div
# Encountered some data  : S03-¿
# Encountered a start tag: b
# Encountered some data  : Có
# Encountered an end tag : b
# Encountered some data  : mo es
# Encountered a start tag: b
# Encountered some data  : tás
# Encountered an end tag : b
# Encountered some data  : ,
# Encountered a start tag: b
# Encountered some data  : gua
# Encountered an end tag : b
# Encountered some data  : pa?
# Encountered an end tag : div
# Encountered a start tag: div
# Encountered a start tag: br
# Encountered an end tag : div
# Encountered a start tag: div
# Encountered some data  : S04-¡Bien,
# Encountered a start tag: b
# Encountered some data  : gra
# Encountered an end tag : b
# Encountered some data  : cias! ¿Y tú, qué tal?
# Encountered an end tag : div
# Encountered a start tag: div
# Encountered a start tag: br
# Encountered an end tag : div
# Encountered a start tag: div
# Encountered some data  : S05-Es
# Encountered a start tag: b
# Encountered some data  : toy
# Encountered an end tag : b
# Encountered some data  : pa
# Encountered a start tag: b
# Encountered some data  : chu
# Encountered an end tag : b
# Encountered some data  : cho…
# Encountered an end tag : div
# Encountered a start tag: div
# Encountered a start tag: br
# Encountered an end tag : div
# Encountered a start tag: div
# Encountered some data  : T00-TRANSLATE-Ejer
# Encountered a start tag: b
# Encountered some data  : ci
# Encountered an end tag : b
# Encountered some data  : cio 1 – Tra
# Encountered a start tag: b
# Encountered some data  : du
# Encountered an end tag : b
# Encountered some data  : zca
# Encountered an end tag : div
# Encountered a start tag: div
# Encountered a start tag: br
# Encountered an end tag : div
# Encountered a start tag: div
# Encountered some data  : T01-¿Qué tal?
# Encountered an end tag : div
# Encountered a start tag: div
# Encountered a start tag: br
# Encountered an end tag : div
# Encountered a start tag: div
# Encountered some data  : T02-¿
# Encountered a start tag: b
# Encountered some data  : Có
# Encountered an end tag : b
# Encountered some data  : mo es
# Encountered a start tag: b
# Encountered some data  : tás
# Encountered an end tag : b
# Encountered some data  : ?
# Encountered an end tag : div
# Encountered a start tag: div
# Encountered a start tag: br
# Encountered an end tag : div
# Encountered a start tag: div
# Encountered some data  : T03-¡
# Encountered a start tag: b
# Encountered some data  : Ho
# Encountered an end tag : b
# Encountered some data  : la,
# Encountered a start tag: b
# Encountered some data  : gua
# Encountered an end tag : b
# Encountered some data  : pa, qué sor
# Encountered a start tag: b
# Encountered some data  : pre
# Encountered an end tag : b
# Encountered some data  : sa!
# Encountered an end tag : div
# Encountered a start tag: div
# Encountered a start tag: br
# Encountered an end tag : div
# Encountered a start tag: div
# Encountered some data  : T04-¿Es
# Encountered a start tag: b
# Encountered some data  : tás
# Encountered an end tag : b
# Encountered some data  : pa
# Encountered a start tag: b
# Encountered some data  : chu
# Encountered an end tag : b
# Encountered some data  : cho?
# Encountered an end tag : div
# Encountered a start tag: div
# Encountered a start tag: br
# Encountered an end tag : div
# Encountered a start tag: div
# Encountered some data  : T05-Es
# Encountered a start tag: b
# Encountered some data  : toy
# Encountered an end tag : b
# Encountered some data  :  bien,
# Encountered a start tag: b
# Encountered some data  : gra
# Encountered an end tag : b
# Encountered some data  : cias.
# Encountered an end tag : div
# Encountered some data  :

# %%
word_dict
# Out:
# {'n4': [('N4', False)],
#  'lección': [('Lecc', False), ('ión', True)],
#  'cuarta': [('cua', True), ('rta', False)],
#  's00': [('S00', False)],
#  'title': [('TITLE', False)],
#  'presentaciones': [('Presenta', False), ('cio', True), ('nes', False)],
#  's01': [('S01', False)],
#  'él': [('Él', False)],
#  'es': [('es', False)],
#  'rafa': [('Ra', True), ('fa', False)],
#  'mi': [('Mi', False)],
#  'hermano': [('her', False), ('ma', True), ('no', False)],
#  'y': [('Y', False)],
#  'ella': [('ella', False)],
#  'luz': [('Luz', False)],
#  'hermana': [('her', False), ('ma', True), ('na', False)],
#  's02': [('S02', False)],
#  'padre': [('pa', True), ('dre', False)],
#  'miguel': [('Mi', False), ('guel', True)],
#  's03': [('S03', False)],
#  'mucho': [('Mu', True), ('cho', False)],
#  'gusto': [('gus', True), ('to', False)],
#  'cómo': [('Có', True), ('mo', False)],
#  'está': [('est', False), ('á', True)],
#  'usted': [('ust', False), ('ed', True)],
#  's04': [('S04', False)],
#  'muy': [('Muy', False)],
#  'bien': [('bien', False)],
#  'pero': [('Pe', True), ('ro', False)],
#  'háblame': [('Há', True), ('blame', False)],
#  'de': [('De', False)],
#  'tú': [('tú', False)],
#  'por': [('por', False)],
#  'favor': [('fa', False), ('vor', True)],
#  's05': [('S05', False)],
#  'vale': [('Va', True), ('le', False)],
#  't00': [('T00', False)],
#  'translate': [('TRANSLATE', False)],
#  'ejercicio': [('Ejer', False), ('ci', True), ('cio', False)],
#  '1': [('1', False)],
#  '–': [('–', False)],
#  'traduzca': [('Tra', False), ('duz', True), ('ca', False)],
#  't01': [('T01', False)],
#  't02': [('T02', False)],
#  't03': [('T03', False)],
#  't04': [('T04', False)],
#  't05': [('T05', False)],
#  'n3': [('N3', False)],
#  'tercera': [('ter', False), ('ce', True), ('ra', False)],
#  'bienvenida': [('bienve', False), ('ni', True), ('da', False)],
#  'buenos': [('Bue', True), ('nos', False)],
#  'días': [('dí', True), ('as', False)],
#  'soy': [('Soy', False)],
#  'javier': [('Ja', False), ('vier', True)],
#  'te': [('Te', False)],
#  'llamas': [('lla', True), ('mas', False)],
#  'me': [('me', False)],
#  'llamo': [('lla', True), ('mo', False)],
#  'rocío': [('Ro', False), ('cío', True)],
#  'encantado': [('Encan', False), ('ta', True), ('do', False)],
#  'eres': [('e', True), ('res', False)],
#  'madrid': [('Ma', False), ('drid', True)],
#  'no': [('No', False)],
#  'madrileña': [('madri', False), ('le', True), ('ña', False)],
#  'andaluza': [('anda', False), ('lu', True), ('za', False)],
#  'sevilla': [('Se', False), ('vi', True), ('lla', False)],
#  'pues': [('Pues', False)],
#  'a': [('a', False)],
#  'morena': [('mo', False), ('re', True), ('na', False)],
#  'encantada': [('Encan', False), ('ta', True), ('da', False)],
#  'montse': [('Mon', True), ('tse', False)],
#  'n2': [('N2', False)],
#  'segunda': [('se', False), ('gun', True), ('da', False)],
#  'dónde': [('dón', True), ('de', False)],
#  'vives': [('Vi', True), ('ves', False)],
#  'familia': [('fa', False), ('mi', True), ('lia', False)],
#  'andalucía': [('Andalu', False), ('cí', True), ('a', False)],
#  'yo': [('yo', False)],
#  'nací': [('Na', False), ('cí', True)],
#  'en': [('en', False)],
#  'barcelona': [('Barce', False), ('lo', True), ('na', False)],
#  'vivo': [('Vi', True), ('vo', False)],
#  'las': [('las', False)],
#  'afueras': [('a', False), ('fue', True), ('ras', False)]}

# %%
word_dict['pero']
# Out:
# [('Pe', True), ('ro', False)]

# %%
word_dict['n5']
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# Cell In[105], line 1
# ----> 1 word_dict['n5']
#
# KeyError: 'n5'

# %%
parser

# %%
dir(parser)
# Out:
# ['CDATA_CONTENT_ELEMENTS',
#  '_HTMLParser__starttag_text',
#  '__class__',
#  '__delattr__',
#  '__dict__',
#  '__dir__',
#  '__doc__',
#  '__eq__',
#  '__format__',
#  '__ge__',
#  '__getattribute__',
#  '__getstate__',
#  '__gt__',
#  '__hash__',
#  '__init__',
#  '__init_subclass__',
#  '__le__',
#  '__lt__',
#  '__module__',
#  '__ne__',
#  '__new__',
#  '__reduce__',
#  '__reduce_ex__',
#  '__repr__',
#  '__setattr__',
#  '__sizeof__',
#  '__str__',
#  '__subclasshook__',
#  '__weakref__',
#  '_decl_otherchars',
#  '_parse_doctype_attlist',
#  '_parse_doctype_element',
#  '_parse_doctype_entity',
#  '_parse_doctype_notation',
#  '_parse_doctype_subset',
#  '_scan_name',
#  'analyze_lesson',
#  'bold_data',
#  'cdata_elem',
#  'check_for_whole_start_tag',
#  'clear_cdata_mode',
#  'close',
#  'convert_charrefs',
#  'current_sentence',
#  'current_sentence_fragments',
#  'feed',
#  'get_starttag_text',
#  'get_word_dict',
#  'getpos',
#  'goahead',
#  'handle_charref',
#  'handle_comment',
#  'handle_data',
#  'handle_decl',
#  'handle_endtag',
#  'handle_entityref',
#  'handle_pi',
#  'handle_startendtag',
#  'handle_starttag',
#  'interesting',
#  'lasttag',
#  'lineno',
#  'offset',
#  'parse_bogus_comment',
#  'parse_comment',
#  'parse_declaration',
#  'parse_endtag',
#  'parse_html_declaration',
#  'parse_marked_section',
#  'parse_pi',
#  'parse_starttag',
#  'rawdata',
#  'reset',
#  'sentences',
#  'sentences_fragments',
#  'set_cdata_mode',
#  'unknown_decl',
#  'updatepos']
